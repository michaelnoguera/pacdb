# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   -- sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   -- avg(l_quantity) as avg_qty,
#   -- avg(l_extendedprice) as avg_price,
#   -- avg(l_discount) as avg_disc,
#   -- count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'A'
#   and l_linestatus = 'F'
# ```

# %%
EXPERIMENT = 'pac-q1-sum-charge'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'A') &
        (lineitem_df['l_linestatus'] == 'F')
    ]
    print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        # float(discounted_price.sum()),                      # sum_disc_price
        float(charged_price.sum()),                         # sum_charge
        # float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        # float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        # float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        # float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# (147790, 16)
# [5256751331.449234]
# [5256751331.449234]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['sum_charge']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 147790  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np
# Out:
# (147790, 16)
# [5256751331.449234]

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    # out_np = generate_samples() # generate samples (results of running the query)
    # print(f"Generate samples... {len(out_np)} samples generated.")

    print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# [5.25522537e+09]
# Getting PAC Noise...
# The dimensions are - 1
# [array([[5.25522537e+09]]), array([[5.25827729e+09]]), array([[5.25916564e+09]]), array([[5.25433702e+09]]), array([[5.25651699e+09]]), array([[5.25698568e+09]]), array([[5.25921345e+09]]), array([[5.25428921e+09]]), array([[5.2625779e+09]]), array([[5.25092476e+09]]), array([[5.24829174e+09]]), array([[5.26521092e+09]]), array([[5.24636305e+09]]), array([[5.26713962e+09]]), array([[5.24187829e+09]]), array([[5.27162437e+09]]), array([[5.27296703e+09]]), array([[5.24053563e+09]]), array([[5.28881997e+09]]), array([[5.2246827e+09]]), array([[5.26156591e+09]]), array([[5.25193675e+09]]), array([[5.2298435e+09]]), array([[5.28365917e+09]]), array([[5.25190934e+09]]), array([[5.26159333e+09]]), array([[5.25700414e+09]]), array([[5.25649852e+09]]), array([[5.23787729e+09]]), array([[5.27562537e+09]]), array([[5.25744362e+09]]), array([[5.25605904e+09]]), array([[5.27537603e+09]]), array([[5.23812664e+09]]), array([[5.24814577e+09]]), array([[5.26535689e+09]]), array([[5.24295383e+09]]), array([[5.27054883e+09]]), array([[5.25804539e+09]]), array([[5.25545727e+09]]), array([[5.25140979e+09]]), array([[5.26209288e+09]]), array([[5.25292151e+09]]), array([[5.26058116e+09]]), array([[5.27574435e+09]]), array([[5.23775831e+09]]), array([[5.24586395e+09]]), array([[5.26763871e+09]]), array([[5.26712858e+09]]), array([[5.24637408e+09]]), array([[5.28095553e+09]]), array([[5.23254713e+09]]), array([[5.23267882e+09]]), array([[5.28082384e+09]]), array([[5.26481879e+09]]), array([[5.24868387e+09]]), array([[5.29663944e+09]]), array([[5.21686322e+09]]), array([[5.23822568e+09]]), array([[5.27527699e+09]]), array([[5.29321439e+09]]), array([[5.22028827e+09]]), array([[5.25451529e+09]]), array([[5.25898737e+09]]), array([[5.2288367e+09]]), array([[5.28466596e+09]]), array([[5.25099534e+09]]), array([[5.26250732e+09]]), array([[5.26867891e+09]]), array([[5.24482375e+09]]), array([[5.26040156e+09]]), array([[5.25310111e+09]]), array([[5.246669e+09]]), array([[5.26683366e+09]]), array([[5.2336518e+09]]), array([[5.27985087e+09]]), array([[5.25501093e+09]]), array([[5.25849173e+09]]), array([[5.2773687e+09]]), array([[5.23613396e+09]]), array([[5.26682765e+09]]), array([[5.24667502e+09]]), array([[5.28945393e+09]]), array([[5.22404874e+09]]), array([[5.2443134e+09]]), array([[5.26918926e+09]]), array([[5.26742107e+09]]), array([[5.24608159e+09]]), array([[5.27127724e+09]]), array([[5.24222542e+09]]), array([[5.27491441e+09]]), array([[5.23858825e+09]]), array([[5.26393948e+09]]), array([[5.24956319e+09]]), array([[5.28210821e+09]]), array([[5.23139446e+09]]), array([[5.24374917e+09]]), array([[5.2697535e+09]]), array([[5.27046147e+09]]), array([[5.2430412e+09]]), array([[5.23482877e+09]]), array([[5.2786739e+09]]), array([[5.22964759e+09]]), array([[5.28385507e+09]]), array([[5.25930847e+09]]), array([[5.25419419e+09]]), array([[5.26164532e+09]]), array([[5.25185734e+09]]), array([[5.29529612e+09]]), array([[5.21820654e+09]]), array([[5.26316492e+09]]), array([[5.25033774e+09]]), array([[5.24933043e+09]]), array([[5.26417223e+09]]), array([[5.23601916e+09]]), array([[5.2774835e+09]]), array([[5.21974272e+09]]), array([[5.29375994e+09]]), array([[5.22571476e+09]]), array([[5.2877879e+09]]), array([[5.25455351e+09]]), array([[5.25894915e+09]]), array([[5.24740111e+09]]), array([[5.26610156e+09]]), array([[5.24084562e+09]]), array([[5.27265705e+09]]), array([[5.2671611e+09]]), array([[5.24634156e+09]]), array([[5.23893096e+09]]), array([[5.2745717e+09]]), array([[5.26379132e+09]]), array([[5.24971134e+09]]), array([[5.23279873e+09]]), array([[5.28070393e+09]]), array([[5.27601101e+09]]), array([[5.23749166e+09]]), array([[5.25018353e+09]]), array([[5.26331913e+09]]), array([[5.26585586e+09]]), array([[5.2476468e+09]]), array([[5.20766677e+09]]), array([[5.30583589e+09]]), array([[5.25020635e+09]]), array([[5.26329631e+09]]), array([[5.26643455e+09]]), array([[5.24706811e+09]]), array([[5.27433436e+09]]), array([[5.2391683e+09]]), array([[5.24481382e+0 ...
# est_y.shape: (1, 8192)
# est_y: [[5.25522537e+09 5.25827729e+09 5.25916564e+09 ... 5.24654550e+09
#   5.28127126e+09 5.23223140e+09]]
# fin_var: [2.69936721e+14]
# sqrt_total_var: 16429751.09100912
# For mi=0.001248318631131131, we should add noise from a normal distribution with scale...
# 	400.5387627251371 * 16429751.09100912 * [16429751.09100912] = [1.0812012e+17]
# pac_noise: [1.0812012e+17]
# mi=0.001248318631131131, scale=[1.0812012e+17]
# Chosen Sample [5.25328315e+09]
# Chosen Sample [5.25351551e+09]
# Chosen Sample [5.25606229e+09]
# Chosen Sample [5.26922298e+09]
# Chosen Sample [5.24971134e+09]
# Chosen Sample [5.24055108e+09]
# Chosen Sample [5.26816303e+09]
# Chosen Sample [5.27162824e+09]
# Chosen Sample [5.26652784e+09]
# Chosen Sample [5.24265086e+09]
# Chosen Sample [5.28635398e+09]
# Chosen Sample [5.25739194e+09]
# Chosen Sample [5.26462197e+09]
# Chosen Sample [5.25181618e+09]
# Chosen Sample [5.23789594e+09]
# Chosen Sample [5.28176649e+09]
# Chosen Sample [5.27422808e+09]
# Chosen Sample [5.22969661e+09]
# Chosen Sample [5.25078569e+09]
# Chosen Sample [5.26770559e+09]
# Chosen Sample [5.26845323e+09]
# Chosen Sample [5.24293552e+09]
# Chosen Sample [5.25599363e+09]
# Chosen Sample [5.28558104e+09]
# Chosen Sample [5.26839429e+09]
# Chosen Sample [5.24303584e+09]
# Chosen Sample [5.26463047e+09]
# Chosen Sample [5.23722116e+09]
# Chosen Sample [5.25386876e+09]
# Chosen Sample [5.25798754e+09]
# Chosen Sample [5.25311771e+09]
# Chosen Sample [5.25971736e+09]
# Chosen Sample [5.24277317e+09]
# Chosen Sample [5.24903675e+09]
# Chosen Sample [5.28588798e+09]
# Chosen Sample [5.24011073e+09]
# Chosen Sample [5.25920673e+09]
# Chosen Sample [5.23779604e+09]
# Chosen Sample [5.26194243e+09]
# Chosen Sample [5.26797039e+09]
# Chosen Sample [5.27218154e+09]
# Chosen Sample [5.27903766e+09]
# Chosen Sample [5.27175181e+09]
# Chosen Sample [5.25814853e+09]
# Chosen Sample [5.24108368e+09]
# Chosen Sample [5.27389325e+09]
# Chosen Sample [5.2540124e+09]
# Chosen Sample [5.25343861e+09]
# Chosen Sample [5.2276246e+09]
# Chosen Sample [5.24755521e+09]
# Chosen Sample [5.25409216e+09]
# Chosen Sample [5.23710269e+09]
# Chosen Sample [5.268504e+09]
# Chosen Sample [5.2499438e+09]
# Chosen Sample [5.26944325e+09]
# Chosen Sample [5.25875346e+09]
# Chosen Sample [5.23803222e+09]
# Chosen Sample [5.26874435e+09]
# Chosen Sample [5.22936229e+09]
# Chosen Sample [5.25241398e+09]
# Chosen Sample [5.28337432e+09]
# Chosen Sample [5.24366874e+09]
# Chosen Sample [5.24627951e+09]
# Chosen Sample [5.28324755e+09]
# Chosen Sample [5.26158342e+09]
# Chosen Sample [5.25190352e+09]
# Chosen Sample [5.25248813e+09]
# Chosen Sample [5.23968358e+09]
# Chosen Sample [5.25132445e+09]
# Chosen Sample [5.24184023e+09]
# Chosen Sample [5.25839408e+09]
# Chosen Sample [5.23641445e+09]
# Chosen Sample [5.27661716e+09]
# Chosen Sample [5.26299226e+09]
# Chosen Sample [5.28429206e+09]
# Chosen Sample [5.25088118e+09]
# Chosen Sample [5.24769282e+09]
# Chosen Sample [5.23393414e+09]
# Chosen Sample [5.23754097e+09]
# Chosen Sample [5.27157295e+09]
# Chosen Sample [5.27210184e+09]
# Chosen Sample [5.26247999e+09]
# Chosen Sample [5.23219184e+09]
# Chosen Sample [5.25899224e+09]
# Chosen Sample [5.25904126e+09]
# Chosen Sample [5.26115997e+09]
# Chosen Sample [5.21664569e+09]
# Chosen Sample [5.25158172e+09]
# Chosen Sample [5.26670043e+09]
# Chosen Sample [5.25961821e+09]
# Chosen Sample [5.27327673e+09]
# Chosen Sample [5.28546509e+09]
# Chosen Sample [5.26526679e+09]
# Chosen Sample [5.26907561e+09]
# Chosen Sample [5.24829054e+09]
# Chosen Sample [5.25582886e+09]
# Chosen Sample [5.24570663e+09]
# Chosen Sample [5.24674017e+09]
# Chosen Sample [5.27596753e+09]
# Chosen Sample [5.26267984e+09]
# Chosen Sample [5.24240976e+09]
# Chosen Sample [5.26802616e+09]
# Chosen Sample [5.25951834e+09]
# Chosen Sample [5.25831666e+09]
# Chosen Sample [5.27708678e+09]
# Chosen Sample [5.25270903e+09]
# Chosen Sample [5.25480098e+09]
# Chosen Sample [5.2279712e+09]
# Chosen Sample [5.22521421e+09]
# Chosen Sample [5.25404854e+09]
# Chosen Sample [5.23676689e+09]
# Chosen Sample [5.27740053e+09]
# Chosen Sample [5.26908722e+09]
# Chosen Sample [5.27832357e+09]
# Chosen Sample [5.23648388e+09]
# Chosen Sample [5.24204639e+09]
# Chosen Sample [5.27038381e+09]
# Chosen Sample [5.2421421e+09]
# Chosen Sample [5.24350813e+09]
# Chosen Sample [5.26921588e+09]
# Chosen Sample [5.26041353e+09]
# Chosen Sample [5.2668471e+09]
# Chosen Sample [5.24110854e+09]
# Chosen Sample [5.24755521e+09]
# Chosen Sample [5.24117435e+09]
# Chosen Sample [5.24439845e+09]
# Chosen Sample [5.25689581e+09]
# Chosen Sample [5.27115367e+09]
# Chosen Sample [5.28553044e+09]
# Chosen Sample [5.24559702e+09]
# Chosen Sample [5.2529637e+09]
# Chosen Sample [5.2735497e+09]
# Chosen Sample [5.25668469e+09]
# Chosen Sample [5.25494698e+09]
# Chosen Sample [5.24525786e+09]
# Chosen Sample [5.26516839e+09]
# Chosen Sample [5.24937434e+09]
# Chosen Sample [5.2368954e+09]
# Chosen Sample [5.21769071e+09]
# Chosen Sample [5.27159793e+09]
# Chosen Sample [5.26845719e+09]
# Chosen Sample [5.28653739e+09]
# Chosen Sample [5.22762701e+09]
# Chosen Sample [5.25404854e+09]
# Chosen Sample [5.23715475e+09]
# Chosen Sample [5.26429823e+09]
# Chosen Sample [5.26921948e+09]
# Chosen Sample [5.25543925e+09]
# Chosen Sample [5.25946537e+09]
# Chosen Sample [5.25446656e+09]
# Chosen Sample [5.25281574e+09]
# Chosen Sample [5.27282249e+09]
# Chosen Sample [5.25337722e+09]
# Chosen Sample [5.27113304e+09]
# Chosen Sample [5.27218154e+09]
# Chosen Sample [5.22896014e+09]
# Chosen Sample [5.24950193e+09]
# Chosen Sample [5.27235708e+09]
# Chosen Sample [5.24464622e+09]
# Chosen Sample [5.24446249e+09]
# Chosen Sample [5.25446709e+09]
# Chosen Sample [5.27193658e+09]
# Chosen Sample [5.26904018e+09]
# Chosen Sample [5.2814007e+09]
# Chosen Sample [5.25026334e+09]
# Chosen Sample [5.22211882e+09]
# Chosen Sample [5.28360433e+09]
# Chosen Sample [5.27741536e+09]
# Chosen Sample [5.29261287e+09]
# Chosen Sample [5.22410335e+09]
# Chosen Sample [5.25760584e+09]
# Chosen Sample [5.26271685e+09]
# Chosen Sample [5.25300321e+09]
# Chosen Sample [5.27410074e+09]
# Chosen Sample [5.27537513e+09]
# Chosen Sample [5.25974745e+09]
# Chosen Sample [5.2337174e+09]
# Chosen Sample [5.2286014e+09]
# Chosen Sample [5.25606393e+09]
# Chosen Sample [5.27059758e+09]
# Chosen Sample [5.26671116e+09]
# Chosen Sample [5.23425247e+09]
# Chosen Sample [5.2726902e+09]
# Chosen Sample [5.29891876e+09]
# Chosen Sample [5.26397779e+09]
# Chosen Sample [5.277442e+09]
# Chosen Sample [5.2524949e+09]
# Chosen Sample [5.2618471e+09]
# Chosen Sample [5.24725617e+09]
# Chosen Sample [5.25993019e+09]
# Chosen Sample [5.25423288e+09]
# Chosen Sample [5.26093318e+09]
# Chosen Sample [5.23522404e+09]
# Chosen Sample [5.24491183e+09]
# Chosen Sample [5.26626367e+09]
# Chosen Sample [5.28310037e+09]
# Chosen Sample [5.25063058e+09]
# Chosen Sample [5.24446249e+09]
# Chosen Sample [5.23560156e+09]
# Chosen Sample [5.26834902e+09]
# Chosen Sample [5.23766914e+09]
# Chosen Sample [5.27486897e+09]
# Chosen Sample [5.22513662e+09]
# Chosen Sample [5.26725153e+09]
# Chosen Sample [5.25217851e+09]
# Chosen Sample [5.26521212e+09]
# Chosen Sample [5.25786905e+09]
# Chosen Sample [5.22874784e+09]
# Chosen Sample [5.25304981e+09]
# Chosen Sample [5.25045126e+09]
# Chosen Sample [5.25536315e+09]
# Chosen Sample [5.26908519e+09]
# Chosen Sample [5.23945312e+09]
# Chosen Sample [5.2744454e+09]
# Chosen Sample [5.2544411e+09]
# Chosen Sample [5.27357979e+09]
# Chosen Sample [5.2582993e+09]
# Chosen Sample [5.21714701e+09]
# Chosen Sample [5.26337477e+09]
# Chosen Sample [5.23962943e+09]
# Chosen Sample [5.25486162e+09]
# Chosen Sample [5.2526006e+09]
# Chosen Sample [5.25497064e+09]
# Chosen Sample [5.26180006e+09]
# Chosen Sample [5.23475813e+09]
# Chosen Sample [5.27531843e+09]
# Chosen Sample [5.26182847e+09]
# Chosen Sample [5.2903235e+09]
# Chosen Sample [5.2708797e+09]
# Chosen Sample [5.27472665e+09]
# Chosen Sample [5.26645367e+09]
# Chosen Sample [5.26699178e+09]
# Chosen Sample [5.26474447e+09]
# Chosen Sample [5.23168481e+09]
# Chosen Sample [5.25073495e+09]
# Chosen Sample [5.26494943e+09]
# Chosen Sample [5.26880223e+09]
# Chosen Sample [5.2464166e+09]
# Chosen Sample [5.23483214e+09]
# Chosen Sample [5.28884526e+09]
# Chosen Sample [5.24405716e+09]
# Chosen Sample [5.2780053e+09]
# Chosen Sample [5.23500468e+09]
# Chosen Sample [5.25928809e+09]
# Chosen Sample [5.23923269e+09]
# Chosen Sample [5.25153282e+09]
# Chosen Sample [5.22903275e+09]
# Chosen Sample [5.27913536e+09]
# Chosen Sample [5.25680785e+09]
# Chosen Sample [5.24631471e+09]
# Chosen Sample [5.26986849e+09]
# Chosen Sample [5.25468558e+09]
# Chosen Sample [5.27024444e+09]
# Chosen Sample [5.23414554e+09]
# Chosen Sample [5.22962922e+09]
# Chosen Sample [5.27475505e+09]
# Chosen Sample [5.27560672e+09]
# Chosen Sample [5.24504943e+09]
# Chosen Sample [5.27265544e+09]
# Chosen Sample [5.21146505e+09]
# Chosen Sample [5.25011871e+09]
# Chosen Sample [5.25590555e+09]
# Chosen Sample [5.23122155e+09]
# Chosen Sample [5.26212854e+09]
# Chosen Sample [5.25143805e+09]
# Chosen Sample [5.22023773e+09]
# Chosen Sample [5.25404748e+09]
# Chosen Sample [5.23383981e+09]
# Chosen Sample [5.2382917e+09]
# Chosen Sample [5.22906136e+09]
# Chosen Sample [5.22678606e+09]
# Chosen Sample [5.23861492e+09]
# Chosen Sample [5.22513714e+09]
# Chosen Sample [5.27397908e+09]
# Chosen Sample [5.2438616e+09]
# Chosen Sample [5.25868901e+09]
# Chosen Sample [5.24899275e+09]
# Chosen Sample [5.22773928e+09]
# Chosen Sample [5.24212834e+09]
# Chosen Sample [5.27008763e+09]
# Chosen Sample [5.27064146e+09]
# Chosen Sample [5.26912062e+09]
# Chosen Sample [5.27093637e+09]
# Chosen Sample [5.28203403e+09]
# Chosen Sample [5.26255145e+09]
# Chosen Sample [5.28877148e+09]
# Chosen Sample [5.26150204e+09]
# Chosen Sample [5.27641984e+09]
# Chosen Sample [5.24602424e+09]
# Chosen Sample [5.24299577e+09]
# Chosen Sample [5.24265086e+09]
# Chosen Sample [5.27896395e+09]
# Chosen Sample [5.25893493e+09]
# Chosen Sample [5.25772092e+09]
# Chosen Sample [5.24335215e+09]
# Chosen Sample [5.26749107e+09]
# Chosen Sample [5.23604444e+09]
# Chosen Sample [5.28414038e+09]
# Chosen Sample [5.27294352e+09]
# Chosen Sample [5.26955297e+09]
# Chosen Sample [5.27285279e+09]
# Chosen Sample [5.26068817e+09]
# Chosen Sample [5.25109021e+09]
# Chosen Sample [5.26753966e+09]
# Chosen Sample [5.27235951e+09]
# Chosen Sample [5.29460388e+09]
# Chosen Sample [5.23890705e+09]
# Chosen Sample [5.25335921e+09]
# Chosen Sample [5.22769266e+09]
# Chosen Sample [5.24922468e+09]
# Chosen Sample [5.2359711e+09]
# Chosen Sample [5.23460452e+09]
# Chosen Sample [5.25098652e+09]
# Chosen Sample [5.26440512e+09]
# Chosen Sample [5.26330653e+09]
# Chosen Sample [5.24667449e+09]
# Chosen Sample [5.24911146e+09]
# Chosen Sample [5.2817687e+09]
# Chosen Sample [5.22797363e+09]
# Chosen Sample [5.26820656e+09]
# Chosen Sample [5.29921406e+09]
# Chosen Sample [5.26594421e+09]
# Chosen Sample [5.25006849e+09]
# Chosen Sample [5.23863883e+09]
# Chosen Sample [5.25469266e+09]
# Chosen Sample [5.2580171e+09]
# Chosen Sample [5.23467942e+09]
# Chosen Sample [5.23769725e+09]
# Chosen Sample [5.25076828e+09]
# Chosen Sample [5.22792163e+09]
# Chosen Sample [5.25814694e+09]
# Chosen Sample [5.27574435e+09]
# Chosen Sample [5.25837351e+09]
# Chosen Sample [5.25190352e+09]
# Chosen Sample [5.27486383e+09]
# Chosen Sample [5.26467436e+09]
# Chosen Sample [5.2647483e+09]
# Chosen Sample [5.25184423e+09]
# Chosen Sample [5.26789961e+09]
# Chosen Sample [5.23960942e+09]
# Chosen Sample [5.27040127e+09]
# Chosen Sample [5.28452383e+09]
# Chosen Sample [5.24723899e+09]
# Chosen Sample [5.28255718e+09]
# Chosen Sample [5.27064146e+09]
# Chosen Sample [5.25981926e+09]
# Chosen Sample [5.26759174e+09]
# Chosen Sample [5.25525195e+09]
# Chosen Sample [5.26994514e+09]
# Chosen Sample [5.26863358e+09]
# Chosen Sample [5.21995544e+09]
# Chosen Sample [5.2923209e+09]
# Chosen Sample [5.26151511e+09]
# Chosen Sample [5.24439499e+09]
# Chosen Sample [5.24586395e+09]
# Chosen Sample [5.23504767e+09]
# Chosen Sample [5.24816897e+09]
# Chosen Sample [5.25893222e+09]
# Chosen Sample [5.24054125e+09]
# Chosen Sample [5.22653624e+09]
# Chosen Sample [5.24243702e+09]
# Chosen Sample [5.25886502e+09]
# Chosen Sample [5.28405509e+09]
# Chosen Sample [5.28251429e+09]
# Chosen Sample [5.25557527e+09]
# Chosen Sample [5.26408676e+09]
# Chosen Sample [5.22076203e+09]
# Chosen Sample [5.23445279e+09]
# Chosen Sample [5.26258211e+09]
# Chosen Sample [5.27097255e+09]
# Chosen Sample [5.23360761e+09]
# Chosen Sample [5.24979152e+09]
# Chosen Sample [5.2625779e+09]
# Chosen Sample [5.24700925e+09]
# Chosen Sample [5.23125029e+09]
# Chosen Sample [5.26223236e+09]
# Chosen Sample [5.27723531e+09]
# Chosen Sample [5.25343331e+09]
# Chosen Sample [5.28117244e+09]
# Chosen Sample [5.23799493e+09]
# Chosen Sample [5.25790246e+09]
# Chosen Sample [5.25682729e+09]
# Chosen Sample [5.24725617e+09]
# Chosen Sample [5.24384703e+09]
# Chosen Sample [5.28021422e+09]
# Chosen Sample [5.22514737e+09]
# Chosen Sample [5.26317059e+09]
# Chosen Sample [5.25767381e+09]
# Chosen Sample [5.24632374e+09]
# Chosen Sample [5.2794101e+09]
# Chosen Sample [5.25095886e+09]
# Chosen Sample [5.26379132e+09]
# Chosen Sample [5.24110923e+09]
# Chosen Sample [5.25288905e+09]
# Chosen Sample [5.28655117e+09]
# Chosen Sample [5.27969937e+09]
# Chosen Sample [5.27848705e+09]
# Chosen Sample [5.24301669e+09]
# Chosen Sample [5.23164314e+09]
# Chosen Sample [5.24190025e+09]
# Chosen Sample [5.22618277e+09]
# Chosen Sample [5.22964759e+09]
# Chosen Sample [5.24634572e+09]
# Chosen Sample [5.26159914e+09]
# Chosen Sample [5.28091678e+09]
# Chosen Sample [5.26399633e+09]
# Chosen Sample [5.22653624e+09]
# Chosen Sample [5.24071528e+09]
# Chosen Sample [5.2595003e+09]
# Chosen Sample [5.24805365e+09]
# Chosen Sample [5.2593608e+09]
# Chosen Sample [5.25332441e+09]
# Chosen Sample [5.25804252e+09]
# Chosen Sample [5.27582745e+09]
# Chosen Sample [5.28618868e+09]
# Chosen Sample [5.23380329e+09]
# Chosen Sample [5.27219506e+09]
# Chosen Sample [5.25328742e+09]
# Chosen Sample [5.24503893e+09]
# Chosen Sample [5.26695716e+09]
# Chosen Sample [5.25404432e+09]
# Chosen Sample [5.25468558e+09]
# Chosen Sample [5.23856838e+09]
# Chosen Sample [5.30061207e+09]
# Chosen Sample [5.23169678e+09]
# Chosen Sample [5.24672532e+09]
# Chosen Sample [5.26624194e+09]
# Chosen Sample [5.27444998e+09]
# Chosen Sample [5.25429523e+09]
# Chosen Sample [5.281239e+09]
# Chosen Sample [5.26753657e+09]
# Chosen Sample [5.2742434e+09]
# Chosen Sample [5.25823871e+09]
# Chosen Sample [5.27699833e+09]
# Chosen Sample [5.22786352e+09]
# Chosen Sample [5.26740487e+09]
# Chosen Sample [5.25276071e+09]
# Chosen Sample [5.26827091e+09]
# Chosen Sample [5.28633206e+09]
# Chosen Sample [5.2502047e+09]
# Chosen Sample [5.28313587e+09]
# Chosen Sample [5.26010874e+09]
# Chosen Sample [5.22227064e+09]
# Chosen Sample [5.26302306e+09]
# Chosen Sample [5.28318679e+09]
# Chosen Sample [5.21455778e+09]
# Chosen Sample [5.27889815e+09]
# Chosen Sample [5.25712755e+09]
# Chosen Sample [5.23802068e+09]
# Chosen Sample [5.2447126e+09]
# Chosen Sample [5.26691009e+09]
# Chosen Sample [5.28159288e+09]
# Chosen Sample [5.23779604e+09]
# Chosen Sample [5.26315162e+09]
# Chosen Sample [5.24490988e+09]
# Chosen Sample [5.24454693e+09]
# Chosen Sample [5.26348085e+09]
# Chosen Sample [5.27316163e+09]
# Chosen Sample [5.23914602e+09]
# Chosen Sample [5.22952875e+09]
# Chosen Sample [5.24680012e+09]
# Chosen Sample [5.25104677e+09]
# Chosen Sample [5.24286121e+09]
# Chosen Sample [5.25392252e+09]
# Chosen Sample [5.26389027e+09]
# Chosen Sample [5.26266992e+09]
# Chosen Sample [5.26740206e+09]
# Chosen Sample [5.23875126e+09]
# Chosen Sample [5.23754097e+09]
# Chosen Sample [5.26635648e+09]
# Chosen Sample [5.25655489e+09]
# Chosen Sample [5.2295423e+09]
# Chosen Sample [5.27603338e+09]
# Chosen Sample [5.26435558e+09]
# Chosen Sample [5.25920814e+09]
# Chosen Sample [5.26457559e+09]
# Chosen Sample [5.24519826e+09]
# Chosen Sample [5.25846718e+09]
# Chosen Sample [5.24396684e+09]
# Chosen Sample [5.25713242e+09]
# Chosen Sample [5.23833028e+09]
# Chosen Sample [5.22929896e+09]
# Chosen Sample [5.27383015e+09]
# Chosen Sample [5.25151211e+09]
# Chosen Sample [5.24667709e+09]
# Chosen Sample [5.2713785e+09]
# Chosen Sample [5.26695101e+09]
# Chosen Sample [5.27628929e+09]
# Chosen Sample [5.2582251e+09]
# Chosen Sample [5.26608735e+09]
# Chosen Sample [5.26540961e+09]
# Chosen Sample [5.23826532e+09]
# Chosen Sample [5.24021439e+09]
# Chosen Sample [5.26371765e+09]
# Chosen Sample [5.27906606e+09]
# Chosen Sample [5.23653385e+09]
# Chosen Sample [5.26820322e+09]
# Chosen Sample [5.27107212e+09]
# Chosen Sample [5.25828702e+09]
# Chosen Sample [5.25450438e+09]
# Chosen Sample [5.25148444e+09]
# Chosen Sample [5.27054362e+09]
# Chosen Sample [5.25317139e+09]
# Chosen Sample [5.25792725e+09]
# Chosen Sample [5.27159793e+09]
# Chosen Sample [5.25699624e+09]
# Chosen Sample [5.27048808e+09]
# Chosen Sample [5.24749283e+09]
# Chosen Sample [5.25031432e+09]
# Chosen Sample [5.23245169e+09]
# Chosen Sample [5.26468372e+09]
# Chosen Sample [5.23807423e+09]
# Chosen Sample [5.26857257e+09]
# Chosen Sample [5.26596979e+09]
# Chosen Sample [5.23286844e+09]
# Chosen Sample [5.27466043e+09]
# Chosen Sample [5.23723052e+09]
# Chosen Sample [5.25184423e+09]
# Chosen Sample [5.24016606e+09]
# Chosen Sample [5.25569573e+09]
# Chosen Sample [5.2348196e+09]
# Chosen Sample [5.24857542e+09]
# Chosen Sample [5.25304981e+09]
# Chosen Sample [5.2446545e+09]
# Chosen Sample [5.28204879e+09]
# Chosen Sample [5.25308914e+09]
# Chosen Sample [5.26425614e+09]
# Chosen Sample [5.23883818e+09]
# Chosen Sample [5.26972464e+09]
# Chosen Sample [5.22678606e+09]
# Chosen Sample [5.26224991e+09]
# Chosen Sample [5.23482877e+09]
# Chosen Sample [5.24270226e+09]
# Chosen Sample [5.22756005e+09]
# Chosen Sample [5.22028827e+09]
# Chosen Sample [5.23952358e+09]
# Chosen Sample [5.25166594e+09]
# Chosen Sample [5.27115361e+09]
# Chosen Sample [5.27512719e+09]
# Chosen Sample [5.26391152e+09]
# Chosen Sample [5.27245742e+09]
# Chosen Sample [5.28835529e+09]
# Chosen Sample [5.27635453e+09]
# Chosen Sample [5.26855202e+09]
# Chosen Sample [5.26537742e+09]
# Chosen Sample [5.24657322e+09]
# Chosen Sample [5.23255332e+09]
# Chosen Sample [5.25104223e+09]
# Chosen Sample [5.27747526e+09]
# Chosen Sample [5.27090277e+09]
# Chosen Sample [5.2744454e+09]
# Chosen Sample [5.26375567e+09]
# Chosen Sample [5.25429452e+09]
# Chosen Sample [5.2784755e+09]
# Chosen Sample [5.23417834e+09]
# Chosen Sample [5.24422756e+09]
# Chosen Sample [5.28767481e+09]
# Chosen Sample [5.28070393e+09]
# Chosen Sample [5.25760584e+09]
# Chosen Sample [5.25016981e+09]
# Chosen Sample [5.24645393e+09]
# Chosen Sample [5.23666229e+09]
# Chosen Sample [5.25034108e+09]
# Chosen Sample [5.25118741e+09]
# Chosen Sample [5.27888482e+09]
# Chosen Sample [5.26525004e+09]
# Chosen Sample [5.26264199e+09]
# Chosen Sample [5.27660727e+09]
# Chosen Sample [5.27869323e+09]
# Chosen Sample [5.24774992e+09]
# Chosen Sample [5.25801558e+09]
# Chosen Sample [5.23761621e+09]
# Chosen Sample [5.29180973e+09]
# Chosen Sample [5.25277851e+09]
# Chosen Sample [5.30248075e+09]
# Chosen Sample [5.26007694e+09]
# Chosen Sample [5.24494149e+09]
# Chosen Sample [5.26865832e+09]
# Chosen Sample [5.25907903e+09]
# Chosen Sample [5.29594464e+09]
# Chosen Sample [5.27071057e+09]
# Chosen Sample [5.23700281e+09]
# Chosen Sample [5.26764134e+09]
# Chosen Sample [5.25928809e+09]
# Chosen Sample [5.24882884e+09]
# Chosen Sample [5.26057586e+09]
# Chosen Sample [5.22641368e+09]
# Chosen Sample [5.24535816e+09]
# Chosen Sample [5.25657806e+09]
# Chosen Sample [5.2446545e+09]
# Chosen Sample [5.24770187e+09]
# Chosen Sample [5.28280863e+09]
# Chosen Sample [5.27166243e+09]
# Chosen Sample [5.24143427e+09]
# Chosen Sample [5.24072865e+09]
# Chosen Sample [5.27503157e+09]
# Chosen Sample [5.23666796e+09]
# Chosen Sample [5.23101436e+09]
# Chosen Sample [5.27557591e+09]
# Chosen Sample [5.26544901e+09]
# Chosen Sample [5.25480098e+09]
# Chosen Sample [5.25655889e+09]
# Chosen Sample [5.25018661e+09]
# Chosen Sample [5.25510767e+09]
# Chosen Sample [5.24492055e+09]
# Chosen Sample [5.25154323e+09]
# Chosen Sample [5.25361335e+09]
# Chosen Sample [5.25591146e+09]
# Chosen Sample [5.23238887e+09]
# Chosen Sample [5.24072865e+09]
# Chosen Sample [5.2554622e+09]
# Chosen Sample [5.24641008e+09]
# Chosen Sample [5.29145706e+09]
# Chosen Sample [5.2714289e+09]
# Chosen Sample [5.28817828e+09]
# Chosen Sample [5.26351735e+09]
# Chosen Sample [5.26498348e+09]
# Chosen Sample [5.25155955e+09]
# Chosen Sample [5.27910258e+09]
# Chosen Sample [5.26485297e+09]
# Chosen Sample [5.28091678e+09]
# Chosen Sample [5.25137412e+09]
# Chosen Sample [5.25109481e+09]
# Chosen Sample [5.28405509e+09]
# Chosen Sample [5.26339073e+09]
# Chosen Sample [5.26790564e+09]
# Chosen Sample [5.26196984e+09]
# Chosen Sample [5.27466043e+09]
# Chosen Sample [5.26492552e+09]
# Chosen Sample [5.25800488e+09]
# Chosen Sample [5.26560285e+09]
# Chosen Sample [5.22585469e+09]
# Chosen Sample [5.26250732e+09]
# Chosen Sample [5.2670485e+09]
# Chosen Sample [5.29123202e+09]
# Chosen Sample [5.26479641e+09]
# Chosen Sample [5.27607008e+09]
# Chosen Sample [5.26151511e+09]
# Chosen Sample [5.26454648e+09]
# Chosen Sample [5.25570805e+09]
# Chosen Sample [5.25913392e+09]
# Chosen Sample [5.25633039e+09]
# Chosen Sample [5.24386007e+09]
# Chosen Sample [5.25441532e+09]
# Chosen Sample [5.24938077e+09]
# Chosen Sample [5.27815919e+09]
# Chosen Sample [5.21888171e+09]
# Chosen Sample [5.25794814e+09]
# Chosen Sample [5.26278977e+09]
# Chosen Sample [5.24528192e+09]
# Chosen Sample [5.25155955e+09]
# Chosen Sample [5.24998892e+09]
# Chosen Sample [5.22190083e+09]
# Chosen Sample [5.24499871e+09]
# Chosen Sample [5.26715695e+09]
# Chosen Sample [5.24133262e+09]
# Chosen Sample [5.24123549e+09]
# Chosen Sample [5.28725502e+09]
# Chosen Sample [5.27814548e+09]
# Chosen Sample [5.2383506e+09]
# Chosen Sample [5.24864623e+09]
# Chosen Sample [5.26687213e+09]
# Chosen Sample [5.27300498e+09]
# Chosen Sample [5.23526099e+09]
# Chosen Sample [5.25437356e+09]
# Chosen Sample [5.26075003e+09]
# Chosen Sample [5.25250712e+09]
# Chosen Sample [5.22110042e+09]
# Chosen Sample [5.24783689e+09]
# Chosen Sample [5.27487706e+09]
# Chosen Sample [5.26750379e+09]
# Chosen Sample [5.2571326e+09]
# Chosen Sample [5.26531937e+09]
# Chosen Sample [5.25686879e+09]
# Chosen Sample [5.24460214e+09]
# Chosen Sample [5.24848384e+09]
# Chosen Sample [5.23420415e+09]
# Chosen Sample [5.26255066e+09]
# Chosen Sample [5.24749586e+09]
# Chosen Sample [5.26519872e+09]
# Chosen Sample [5.25391161e+09]
# Chosen Sample [5.26216063e+09]
# Chosen Sample [5.29699527e+09]
# Chosen Sample [5.27072172e+09]
# Chosen Sample [5.26874435e+09]
# Chosen Sample [5.21879405e+09]
# Chosen Sample [5.24525048e+09]
# Chosen Sample [5.22828397e+09]
# Chosen Sample [5.27030514e+09]
# Chosen Sample [5.25739486e+09]
# Chosen Sample [5.25134619e+09]
# Chosen Sample [5.28767854e+09]
# Chosen Sample [5.27467568e+09]
# Chosen Sample [5.27747526e+09]
# Chosen Sample [5.283752e+09]
# Chosen Sample [5.24306563e+09]
# Chosen Sample [5.2496311e+09]
# Chosen Sample [5.25882991e+09]
# Chosen Sample [5.27319156e+09]
# Chosen Sample [5.2415171e+09]
# Chosen Sample [5.26771227e+09]
# Chosen Sample [5.24655165e+09]
# Chosen Sample [5.22739414e+09]
# Chosen Sample [5.25248771e+09]
# Chosen Sample [5.25741742e+09]
# Chosen Sample [5.25100618e+09]
# Chosen Sample [5.26402972e+09]
# Chosen Sample [5.24217327e+09]
# Chosen Sample [5.24469129e+09]
# Chosen Sample [5.25087305e+09]
# Chosen Sample [5.26454577e+09]
# Chosen Sample [5.24494233e+09]
# Chosen Sample [5.26143245e+09]
# Chosen Sample [5.25956193e+09]
# Chosen Sample [5.23793458e+09]
# Chosen Sample [5.25032664e+09]
# Chosen Sample [5.27133839e+09]
# Chosen Sample [5.255879e+09]
# Chosen Sample [5.26923336e+09]
# Chosen Sample [5.24171143e+09]
# Chosen Sample [5.26553801e+09]
# Chosen Sample [5.25304425e+09]
# Chosen Sample [5.25713242e+09]
# Chosen Sample [5.24358071e+09]
# Chosen Sample [5.31095439e+09]
# Chosen Sample [5.26462793e+09]
# Chosen Sample [5.26825076e+09]
# Chosen Sample [5.24339814e+09]
# Chosen Sample [5.23561081e+09]
# Chosen Sample [5.27470306e+09]
# Chosen Sample [5.24985538e+09]
# Chosen Sample [5.27188008e+09]
# Chosen Sample [5.23417834e+09]
# Chosen Sample [5.2674988e+09]
# Chosen Sample [5.27353632e+09]
# Chosen Sample [5.24536824e+09]
# Chosen Sample [5.25083936e+09]
# Chosen Sample [5.24190872e+09]
# Chosen Sample [5.2361539e+09]
# Chosen Sample [5.21952905e+09]
# Chosen Sample [5.24876532e+09]
# Chosen Sample [5.29175057e+09]
# Chosen Sample [5.24578055e+09]
# Chosen Sample [5.25785603e+09]
# Chosen Sample [5.24947426e+09]
# Chosen Sample [5.26667715e+09]
# Chosen Sample [5.25913096e+09]
# Chosen Sample [5.22906136e+09]
# Chosen Sample [5.24028798e+09]
# Chosen Sample [5.2456404e+09]
# Chosen Sample [5.24250495e+09]
# Chosen Sample [5.2670833e+09]
# Chosen Sample [5.23840756e+09]
# Chosen Sample [5.25547879e+09]
# Chosen Sample [5.26192551e+09]
# Chosen Sample [5.27246791e+09]
# Chosen Sample [5.24414222e+09]
# Chosen Sample [5.24978502e+09]
# Chosen Sample [5.25171829e+09]
# Chosen Sample [5.26773917e+09]
# Chosen Sample [5.25483265e+09]
# Chosen Sample [5.25567144e+09]
# Chosen Sample [5.27932432e+09]
# Chosen Sample [5.22924375e+09]
# Chosen Sample [5.24324489e+09]
# Chosen Sample [5.23171731e+09]
# Chosen Sample [5.23888673e+09]
# Chosen Sample [5.2602694e+09]
# Chosen Sample [5.2620973e+09]
# Chosen Sample [5.2691346e+09]
# Chosen Sample [5.22739414e+09]
# Chosen Sample [5.29180973e+09]
# Chosen Sample [5.28438123e+09]
# Chosen Sample [5.24120883e+09]
# Chosen Sample [5.24960018e+09]
# Chosen Sample [5.23294356e+09]
# Chosen Sample [5.24330767e+09]
# Chosen Sample [5.2679912e+09]
# Chosen Sample [5.25508794e+09]
# Chosen Sample [5.27115367e+09]
# Chosen Sample [5.26494943e+09]
# Chosen Sample [5.26636288e+09]
# Chosen Sample [5.23746365e+09]
# Chosen Sample [5.29292496e+09]
# Chosen Sample [5.25558748e+09]
# Chosen Sample [5.27194369e+09]
# Chosen Sample [5.27019503e+09]
# Chosen Sample [5.2697535e+09]
# Chosen Sample [5.2275183e+09]
# Chosen Sample [5.22297383e+09]
# Chosen Sample [5.25655489e+09]
# Chosen Sample [5.23610214e+09]
# Chosen Sample [5.25581343e+09]
# Chosen Sample [5.26467383e+09]
# Chosen Sample [5.25863684e+09]
# Chosen Sample [5.25539937e+09]
# Chosen Sample [5.26879006e+09]
# Chosen Sample [5.22006699e+09]
# Chosen Sample [5.26134134e+09]
# Chosen Sample [5.25517735e+09]
# Chosen Sample [5.26126748e+09]
# Chosen Sample [5.26961936e+09]
# Chosen Sample [5.24364445e+09]
# Chosen Sample [5.27112265e+09]
# Chosen Sample [5.21889878e+09]
# Chosen Sample [5.24687725e+09]
# Chosen Sample [5.25839552e+09]
# Chosen Sample [5.24895618e+09]
# Chosen Sample [5.27468059e+09]
# Chosen Sample [5.28359398e+09]
# Chosen Sample [5.26239843e+09]
# Chosen Sample [5.2801178e+09]
# Chosen Sample [5.25218141e+09]
# Chosen Sample [5.29581769e+09]
# Chosen Sample [5.25216548e+09]
# Chosen Sample [5.24681181e+09]
# Chosen Sample [5.2697107e+09]
# Chosen Sample [5.24524115e+09]
# Chosen Sample [5.27532844e+09]
# Chosen Sample [5.24451635e+09]
# Chosen Sample [5.24961873e+09]
# Chosen Sample [5.27178386e+09]
# Chosen Sample [5.26265904e+09]
# Chosen Sample [5.2684782e+09]
# Chosen Sample [5.25231954e+09]
# Chosen Sample [5.2490477e+09]
# Chosen Sample [5.25846675e+09]
# Chosen Sample [5.26243217e+09]
# Chosen Sample [5.23374662e+09]
# Chosen Sample [5.24347096e+09]
# Chosen Sample [5.28778508e+09]
# Chosen Sample [5.26908722e+09]
# Chosen Sample [5.24132112e+09]
# Chosen Sample [5.26058469e+09]
# Chosen Sample [5.26844591e+09]
# Chosen Sample [5.24646189e+09]
# Chosen Sample [5.25837351e+09]
# Chosen Sample [5.23641588e+09]
# Chosen Sample [5.25392206e+09]
# Chosen Sample [5.24930889e+09]
# Chosen Sample [5.27216289e+09]
# Chosen Sample [5.25258885e+09]
# Chosen Sample [5.26806949e+09]
# Chosen Sample [5.26680462e+09]
# Chosen Sample [5.24838504e+09]
# Chosen Sample [5.25439107e+09]
# Chosen Sample [5.27523707e+09]
# Chosen Sample [5.26427764e+09]
# Chosen Sample [5.27856315e+09]
# Chosen Sample [5.23545798e+09]
# Chosen Sample [5.22560394e+09]
# Chosen Sample [5.26246688e+09]
# Chosen Sample [5.26980139e+09]
# Chosen Sample [5.24773687e+09]
# Chosen Sample [5.27591065e+09]
# Chosen Sample [5.25424029e+09]
# Chosen Sample [5.26633308e+09]
# Chosen Sample [5.25065994e+09]
# Chosen Sample [5.23787835e+09]
# Chosen Sample [5.27360966e+09]
# Chosen Sample [5.26434552e+09]
# Chosen Sample [5.28032203e+09]
# Chosen Sample [5.26095643e+09]
# Chosen Sample [5.26608701e+09]
# Chosen Sample [5.27358746e+09]
# Chosen Sample [5.26027336e+09]
# Chosen Sample [5.23091741e+09]
# Chosen Sample [5.27818739e+09]
# Chosen Sample [5.26875653e+09]
# Chosen Sample [5.26846496e+09]
# Chosen Sample [5.23416608e+09]
# Chosen Sample [5.27392763e+09]
# Chosen Sample [5.26620056e+09]
# Chosen Sample [5.24606978e+09]
# Chosen Sample [5.23746365e+09]
# Chosen Sample [5.25039425e+09]
# Chosen Sample [5.25792739e+09]
# Chosen Sample [5.23000951e+09]
# Chosen Sample [5.25945413e+09]
# Chosen Sample [5.2608581e+09]
# Chosen Sample [5.28413894e+09]
# Chosen Sample [5.24780764e+09]
# Chosen Sample [5.24565428e+09]
# Chosen Sample [5.28489808e+09]
# Chosen Sample [5.28015529e+09]
# Chosen Sample [5.26256567e+09]
# Chosen Sample [5.27917331e+09]
# Chosen Sample [5.25403972e+09]
# Chosen Sample [5.24579708e+09]
# Chosen Sample [5.24133262e+09]
# Chosen Sample [5.26113693e+09]
# Chosen Sample [5.24706811e+09]
# Chosen Sample [5.25780693e+09]
# Chosen Sample [5.28255718e+09]
# Chosen Sample [5.23976825e+09]
# Chosen Sample [5.27289471e+09]
# Chosen Sample [5.25746243e+09]
# Chosen Sample [5.25037068e+09]
# Chosen Sample [5.29326493e+09]
# Chosen Sample [5.27821e+09]
# Chosen Sample [5.27019072e+09]
# Chosen Sample [5.25457037e+09]
# Chosen Sample [5.26193728e+09]
# Chosen Sample [5.26158229e+09]
# Chosen Sample [5.28594261e+09]
# Chosen Sample [5.2748521e+09]
# Chosen Sample [5.27560722e+09]
# Chosen Sample [5.23097243e+09]
# Chosen Sample [5.27913536e+09]
# Chosen Sample [5.23888673e+09]
# Chosen Sample [5.24967098e+09]
# Chosen Sample [5.24049967e+09]
# Chosen Sample [5.2821424e+09]
# Chosen Sample [5.24108327e+09]
# Chosen Sample [5.24256629e+09]
# Chosen Sample [5.28550046e+09]
# Chosen Sample [5.28444131e+09]
# Chosen Sample [5.27056714e+09]
# Chosen Sample [5.29637738e+09]
# Chosen Sample [5.2716147e+09]
# Chosen Sample [5.26405387e+09]
# Chosen Sample [5.25771827e+09]
# Chosen Sample [5.26380442e+09]
# Chosen Sample [5.24873208e+09]
# Chosen Sample [5.24576628e+09]
# Chosen Sample [5.24769187e+09]
# Chosen Sample [5.26559267e+09]
# Chosen Sample [5.26457709e+09]
# Chosen Sample [5.25739194e+09]
# Chosen Sample [5.24873567e+09]
# Chosen Sample [5.25921345e+09]
# Chosen Sample [5.2481692e+09]
# Chosen Sample [5.25150977e+09]
# Chosen Sample [5.25665576e+09]
# Chosen Sample [5.26807871e+09]
# Chosen Sample [5.23919163e+09]
# Chosen Sample [5.25043771e+09]
# Chosen Sample [5.23381245e+09]
# Chosen Sample [5.23474679e+09]
# Chosen Sample [5.26706477e+09]
# Chosen Sample [5.25463764e+09]
# Chosen Sample [5.2568859e+09]
# Chosen Sample [5.25292461e+09]
# Chosen Sample [5.25649852e+09]
# Chosen Sample [5.26872405e+09]
# Chosen Sample [5.27275956e+09]
# Chosen Sample [5.21431981e+09]
# Chosen Sample [5.3105938e+09]
# Chosen Sample [5.26938612e+09]
# Chosen Sample [5.29891876e+09]
# Chosen Sample [5.27917039e+09]
# Chosen Sample [5.28371654e+09]
# Chosen Sample [5.26277539e+09]
# Chosen Sample [5.21961935e+09]
# Chosen Sample [5.25437454e+09]
# Chosen Sample [5.23355676e+09]
# Chosen Sample [5.26995095e+09]
# Chosen Sample [5.25339392e+09]
# Chosen Sample [5.26400073e+09]
# Chosen Sample [5.25535572e+09]
# Chosen Sample [5.2668271e+09]
# Chosen Sample [5.25083112e+09]
# Chosen Sample [5.24684409e+09]
# Chosen Sample [5.2336456e+09]
# Chosen Sample [5.27355926e+09]
# Chosen Sample [5.26412833e+09]
# Chosen Sample [5.2501244e+09]
# Chosen Sample [5.25926237e+09]
# Chosen Sample [5.26540961e+09]
# Chosen Sample [5.24069741e+09]
# Chosen Sample [5.23817422e+09]
# Chosen Sample [5.24954365e+09]
# Chosen Sample [5.25700414e+09]
# Chosen Sample [5.2510262e+09]
# Chosen Sample [5.26541755e+09]
# Chosen Sample [5.25590774e+09]
# Chosen Sample [5.25765866e+09]
# Chosen Sample [5.26991762e+09]
# Chosen Sample [5.2312859e+09]
# Chosen Sample [5.25871649e+09]
# Chosen Sample [5.22575057e+09]
# Chosen Sample [5.27194369e+09]
# Chosen Sample [5.26712809e+09]
# Chosen Sample [5.21994622e+09]
# Chosen Sample [5.2514752e+09]
# Chosen Sample [5.26089994e+09]
# Chosen Sample [5.27164642e+09]
# Chosen Sample [5.27296703e+09]
# Chosen Sample [5.28061655e+09]
# Chosen Sample [5.24806395e+09]
# Chosen Sample [5.25504167e+09]
# Chosen Sample [5.2421421e+09]
# Chosen Sample [5.24681181e+09]
# Chosen Sample [5.22440865e+09]
# Chosen Sample [5.28327147e+09]
# Chosen Sample [5.24637236e+09]
# Chosen Sample [5.26313908e+09]
# Chosen Sample [5.25236779e+09]
# Chosen Sample [5.26667165e+09]
# Chosen Sample [5.25665576e+09]
# Getting PAC Noise...
# The dimensions are - 1
# [array([[5.25522537e+09]]), array([[5.25827729e+09]]), array([[5.25916564e+09]]), array([[5.25433702e+09]]), array([[5.25651699e+09]]), array([[5.25698568e+09]]), array([[5.25921345e+09]]), array([[5.25428921e+09]]), array([[5.2625779e+09]]), array([[5.25092476e+09]]), array([[5.24829174e+09]]), array([[5.26521092e+09]]), array([[5.24636305e+09]]), array([[5.26713962e+09]]), array([[5.24187829e+09]]), array([[5.27162437e+09]]), array([[5.27296703e+09]]), array([[5.24053563e+09]]), array([[5.28881997e+09]]), array([[5.2246827e+09]]), array([[5.26156591e+09]]), array([[5.25193675e+09]]), array([[5.2298435e+09]]), array([[5.28365917e+09]]), array([[5.25190934e+09]]), array([[5.26159333e+09]]), array([[5.25700414e+09]]), array([[5.25649852e+09]]), array([[5.23787729e+09]]), array([[5.27562537e+09]]), array([[5.25744362e+09]]), array([[5.25605904e+09]]), array([[5.27537603e+09]]), array([[5.23812664e+09]]), array([[5.24814577e+09]]), array([[5.26535689e+09]]), array([[5.24295383e+09]]), array([[5.27054883e+09]]), array([[5.25804539e+09]]), array([[5.25545727e+09]]), array([[5.25140979e+09]]), array([[5.26209288e+09]]), array([[5.25292151e+09]]), array([[5.26058116e+09]]), array([[5.27574435e+09]]), array([[5.23775831e+09]]), array([[5.24586395e+09]]), array([[5.26763871e+09]]), array([[5.26712858e+09]]), array([[5.24637408e+09]]), array([[5.28095553e+09]]), array([[5.23254713e+09]]), array([[5.23267882e+09]]), array([[5.28082384e+09]]), array([[5.26481879e+09]]), array([[5.24868387e+09]]), array([[5.29663944e+09]]), array([[5.21686322e+09]]), array([[5.23822568e+09]]), array([[5.27527699e+09]]), array([[5.29321439e+09]]), array([[5.22028827e+09]]), array([[5.25451529e+09]]), array([[5.25898737e+09]]), array([[5.2288367e+09]]), array([[5.28466596e+09]]), array([[5.25099534e+09]]), array([[5.26250732e+09]]), array([[5.26867891e+09]]), array([[5.24482375e+09]]), array([[5.26040156e+09]]), array([[5.25310111e+09]]), array([[5.246669e+09]]), array([[5.26683366e+09]]), array([[5.2336518e+09]]), array([[5.27985087e+09]]), array([[5.25501093e+09]]), array([[5.25849173e+09]]), array([[5.2773687e+09]]), array([[5.23613396e+09]]), array([[5.26682765e+09]]), array([[5.24667502e+09]]), array([[5.28945393e+09]]), array([[5.22404874e+09]]), array([[5.2443134e+09]]), array([[5.26918926e+09]]), array([[5.26742107e+09]]), array([[5.24608159e+09]]), array([[5.27127724e+09]]), array([[5.24222542e+09]]), array([[5.27491441e+09]]), array([[5.23858825e+09]]), array([[5.26393948e+09]]), array([[5.24956319e+09]]), array([[5.28210821e+09]]), array([[5.23139446e+09]]), array([[5.24374917e+09]]), array([[5.2697535e+09]]), array([[5.27046147e+09]]), array([[5.2430412e+09]]), array([[5.23482877e+09]]), array([[5.2786739e+09]]), array([[5.22964759e+09]]), array([[5.28385507e+09]]), array([[5.25930847e+09]]), array([[5.25419419e+09]]), array([[5.26164532e+09]]), array([[5.25185734e+09]]), array([[5.29529612e+09]]), array([[5.21820654e+09]]), array([[5.26316492e+09]]), array([[5.25033774e+09]]), array([[5.24933043e+09]]), array([[5.26417223e+09]]), array([[5.23601916e+09]]), array([[5.2774835e+09]]), array([[5.21974272e+09]]), array([[5.29375994e+09]]), array([[5.22571476e+09]]), array([[5.2877879e+09]]), array([[5.25455351e+09]]), array([[5.25894915e+09]]), array([[5.24740111e+09]]), array([[5.26610156e+09]]), array([[5.24084562e+09]]), array([[5.27265705e+09]]), array([[5.2671611e+09]]), array([[5.24634156e+09]]), array([[5.23893096e+09]]), array([[5.2745717e+09]]), array([[5.26379132e+09]]), array([[5.24971134e+09]]), array([[5.23279873e+09]]), array([[5.28070393e+09]]), array([[5.27601101e+09]]), array([[5.23749166e+09]]), array([[5.25018353e+09]]), array([[5.26331913e+09]]), array([[5.26585586e+09]]), array([[5.2476468e+09]]), array([[5.20766677e+09]]), array([[5.30583589e+09]]), array([[5.25020635e+09]]), array([[5.26329631e+09]]), array([[5.26643455e+09]]), array([[5.24706811e+09]]), array([[5.27433436e+09]]), array([[5.2391683e+09]]), array([[5.24481382e+0 ...
# est_y.shape: (1, 8192)
# est_y: [[5.25522537e+09 5.25827729e+09 5.25916564e+09 ... 5.24654550e+09
#   5.28127126e+09 5.23223140e+09]]
# fin_var: [2.69936721e+14]
# sqrt_total_var: 16429751.09100912
# For mi=0.015625, we should add noise from a normal distribution with scale...
# 	32.0 * 16429751.09100912 * [16429751.09100912] = [8.63797507e+15]
# pac_noise: [8.63797507e+15]
# mi=0.015625, scale=[8.63797507e+15]
# Chosen Sample [5.27387324e+09]
# Chosen Sample [5.26067793e+09]
# Chosen Sample [5.23277887e+09]
# Chosen Sample [5.25373126e+09]
# Chosen Sample [5.25109493e+09]
# Chosen Sample [5.25164894e+09]
# Chosen Sample [5.27015051e+09]
# Chosen Sample [5.23665151e+09]
# Chosen Sample [5.24049768e+09]
# Chosen Sample [5.26424686e+09]
# Chosen Sample [5.25386644e+09]
# Chosen Sample [5.26374605e+09]
# Chosen Sample [5.25560737e+09]
# Chosen Sample [5.25925409e+09]
# Chosen Sample [5.26995018e+09]
# Chosen Sample [5.25803249e+09]
# Chosen Sample [5.24242894e+09]
# Chosen Sample [5.24406545e+09]
# Chosen Sample [5.25126668e+09]
# Chosen Sample [5.25668903e+09]
# Chosen Sample [5.23926966e+09]
# Chosen Sample [5.25984529e+09]
# Chosen Sample [5.2575666e+09]
# Chosen Sample [5.2511773e+09]
# Chosen Sample [5.23602446e+09]
# Chosen Sample [5.25527756e+09]
# Chosen Sample [5.24950633e+09]
# Chosen Sample [5.24541173e+09]
# Chosen Sample [5.24700925e+09]
# Chosen Sample [5.29355644e+09]
# Chosen Sample [5.26336332e+09]
# Chosen Sample [5.25366007e+09]
# Chosen Sample [5.24612051e+09]
# Chosen Sample [5.25759016e+09]
# Chosen Sample [5.29150586e+09]
# Chosen Sample [5.24081247e+09]
# Chosen Sample [5.22035304e+09]
# Chosen Sample [5.27619484e+09]
# Chosen Sample [5.25207574e+09]
# Chosen Sample [5.24838808e+09]
# Chosen Sample [5.28817828e+09]
# Chosen Sample [5.26833022e+09]
# Chosen Sample [5.23248602e+09]
# Chosen Sample [5.2456404e+09]
# Chosen Sample [5.25216227e+09]
# Chosen Sample [5.25190352e+09]
# Chosen Sample [5.22952875e+09]
# Chosen Sample [5.25683786e+09]
# Chosen Sample [5.22535576e+09]
# Chosen Sample [5.25893229e+09]
# Chosen Sample [5.28504126e+09]
# Chosen Sample [5.25919747e+09]
# Chosen Sample [5.24439499e+09]
# Chosen Sample [5.23840249e+09]
# Chosen Sample [5.24609779e+09]
# Chosen Sample [5.2489175e+09]
# Chosen Sample [5.24841908e+09]
# Chosen Sample [5.24755521e+09]
# Chosen Sample [5.26772705e+09]
# Chosen Sample [5.28125367e+09]
# Chosen Sample [5.23670991e+09]
# Chosen Sample [5.25119405e+09]
# Chosen Sample [5.2505104e+09]
# Chosen Sample [5.26417223e+09]
# Chosen Sample [5.24971442e+09]
# Chosen Sample [5.26445496e+09]
# Chosen Sample [5.25982911e+09]
# Chosen Sample [5.27073693e+09]
# Chosen Sample [5.25262669e+09]
# Chosen Sample [5.27001502e+09]
# Chosen Sample [5.2458263e+09]
# Chosen Sample [5.29017354e+09]
# Chosen Sample [5.25579193e+09]
# Chosen Sample [5.26492552e+09]
# Chosen Sample [5.26842495e+09]
# Chosen Sample [5.27790656e+09]
# Chosen Sample [5.27236965e+09]
# Chosen Sample [5.26908796e+09]
# Chosen Sample [5.25712755e+09]
# Chosen Sample [5.26221784e+09]
# Chosen Sample [5.26867891e+09]
# Chosen Sample [5.25700815e+09]
# Chosen Sample [5.2435271e+09]
# Chosen Sample [5.24968613e+09]
# Chosen Sample [5.27276348e+09]
# Chosen Sample [5.26368712e+09]
# Chosen Sample [5.2472073e+09]
# Chosen Sample [5.27056714e+09]
# Chosen Sample [5.25903368e+09]
# Chosen Sample [5.2390349e+09]
# Chosen Sample [5.27916637e+09]
# Chosen Sample [5.26961656e+09]
# Chosen Sample [5.26337477e+09]
# Chosen Sample [5.27477763e+09]
# Chosen Sample [5.23224899e+09]
# Chosen Sample [5.25144309e+09]
# Chosen Sample [5.26594745e+09]
# Chosen Sample [5.2650798e+09]
# Chosen Sample [5.28060041e+09]
# Chosen Sample [5.28475483e+09]
# Chosen Sample [5.27462042e+09]
# Chosen Sample [5.23754097e+09]
# Chosen Sample [5.24570663e+09]
# Chosen Sample [5.27207798e+09]
# Chosen Sample [5.27224044e+09]
# Chosen Sample [5.24913912e+09]
# Chosen Sample [5.26384025e+09]
# Chosen Sample [5.25783838e+09]
# Chosen Sample [5.25916564e+09]
# Chosen Sample [5.25591146e+09]
# Chosen Sample [5.27525847e+09]
# Chosen Sample [5.25181618e+09]
# Chosen Sample [5.26206525e+09]
# Chosen Sample [5.23817657e+09]
# Chosen Sample [5.25968191e+09]
# Chosen Sample [5.2714289e+09]
# Chosen Sample [5.25794067e+09]
# Chosen Sample [5.28587806e+09]
# Chosen Sample [5.2609678e+09]
# Chosen Sample [5.25872278e+09]
# Chosen Sample [5.26397991e+09]
# Chosen Sample [5.24076279e+09]
# Chosen Sample [5.25935103e+09]
# Chosen Sample [5.26738816e+09]
# Chosen Sample [5.29715383e+09]
# Chosen Sample [5.27527014e+09]
# Chosen Sample [5.28076317e+09]
# Chosen Sample [5.23823695e+09]
# Chosen Sample [5.26485643e+09]
# Chosen Sample [5.24244857e+09]
# Chosen Sample [5.2602694e+09]
# Chosen Sample [5.2620601e+09]
# Chosen Sample [5.26502289e+09]
# Chosen Sample [5.25839552e+09]
# Chosen Sample [5.28204879e+09]
# Chosen Sample [5.23087721e+09]
# Chosen Sample [5.28452383e+09]
# Chosen Sample [5.27620456e+09]
# Chosen Sample [5.24709251e+09]
# Chosen Sample [5.26861278e+09]
# Chosen Sample [5.24445667e+09]
# Chosen Sample [5.22804933e+09]
# Chosen Sample [5.26004246e+09]
# Chosen Sample [5.23801332e+09]
# Chosen Sample [5.2821424e+09]
# Chosen Sample [5.25655489e+09]
# Chosen Sample [5.26497413e+09]
# Chosen Sample [5.24030558e+09]
# Chosen Sample [5.26206525e+09]
# Chosen Sample [5.24731453e+09]
# Chosen Sample [5.24355069e+09]
# Chosen Sample [5.26644967e+09]
# Chosen Sample [5.2533466e+09]
# Chosen Sample [5.25128738e+09]
# Chosen Sample [5.24341503e+09]
# Chosen Sample [5.2764083e+09]
# Chosen Sample [5.24909754e+09]
# Chosen Sample [5.25335921e+09]
# Chosen Sample [5.26758387e+09]
# Chosen Sample [5.26614309e+09]
# Chosen Sample [5.22035304e+09]
# Chosen Sample [5.24669804e+09]
# Chosen Sample [5.25633569e+09]
# Chosen Sample [5.25717359e+09]
# Chosen Sample [5.28545333e+09]
# Chosen Sample [5.24721341e+09]
# Chosen Sample [5.26528312e+09]
# Chosen Sample [5.25186583e+09]
# Chosen Sample [5.28213217e+09]
# Chosen Sample [5.26232152e+09]
# Chosen Sample [5.24767143e+09]
# Chosen Sample [5.24337945e+09]
# Chosen Sample [5.2681445e+09]
# Chosen Sample [5.26903279e+09]
# Chosen Sample [5.26624278e+09]
# Chosen Sample [5.29145706e+09]
# Chosen Sample [5.23860002e+09]
# Chosen Sample [5.23139446e+09]
# Chosen Sample [5.22870073e+09]
# Chosen Sample [5.25002182e+09]
# Chosen Sample [5.22897884e+09]
# Chosen Sample [5.23636025e+09]
# Chosen Sample [5.24647106e+09]
# Chosen Sample [5.2446545e+09]
# Chosen Sample [5.26844591e+09]
# Chosen Sample [5.2536738e+09]
# Chosen Sample [5.24059602e+09]
# Chosen Sample [5.28495211e+09]
# Chosen Sample [5.28136233e+09]
# Chosen Sample [5.2768347e+09]
# Chosen Sample [5.23971472e+09]
# Chosen Sample [5.25710892e+09]
# Chosen Sample [5.2591291e+09]
# Chosen Sample [5.26629537e+09]
# Chosen Sample [5.26895573e+09]
# Chosen Sample [5.27052604e+09]
# Chosen Sample [5.27086839e+09]
# Chosen Sample [5.25654753e+09]
# Chosen Sample [5.23901061e+09]
# Chosen Sample [5.25546295e+09]
# Chosen Sample [5.27525847e+09]
# Chosen Sample [5.27821e+09]
# Chosen Sample [5.24443e+09]
# Chosen Sample [5.26706477e+09]
# Chosen Sample [5.26109977e+09]
# Chosen Sample [5.26012865e+09]
# Chosen Sample [5.27519928e+09]
# Chosen Sample [5.24272382e+09]
# Chosen Sample [5.24205629e+09]
# Chosen Sample [5.23527279e+09]
# Chosen Sample [5.2721044e+09]
# Chosen Sample [5.25576754e+09]
# Chosen Sample [5.24350813e+09]
# Chosen Sample [5.26849166e+09]
# Chosen Sample [5.2659495e+09]
# Chosen Sample [5.2536539e+09]
# Chosen Sample [5.26816303e+09]
# Chosen Sample [5.23514582e+09]
# Chosen Sample [5.27487785e+09]
# Chosen Sample [5.27380858e+09]
# Chosen Sample [5.24663054e+09]
# Chosen Sample [5.27683941e+09]
# Chosen Sample [5.26086127e+09]
# Chosen Sample [5.25421229e+09]
# Chosen Sample [5.25287886e+09]
# Chosen Sample [5.26158229e+09]
# Chosen Sample [5.27138758e+09]
# Chosen Sample [5.24243553e+09]
# Chosen Sample [5.22932668e+09]
# Chosen Sample [5.24615826e+09]
# Chosen Sample [5.25039898e+09]
# Chosen Sample [5.2536473e+09]
# Chosen Sample [5.26991468e+09]
# Chosen Sample [5.26350447e+09]
# Chosen Sample [5.26523825e+09]
# Chosen Sample [5.25839499e+09]
# Chosen Sample [5.25689581e+09]
# Chosen Sample [5.25512313e+09]
# Chosen Sample [5.24714442e+09]
# Chosen Sample [5.24857542e+09]
# Chosen Sample [5.2594105e+09]
# Chosen Sample [5.26187928e+09]
# Chosen Sample [5.25625296e+09]
# Chosen Sample [5.25034108e+09]
# Chosen Sample [5.27226601e+09]
# Chosen Sample [5.26681557e+09]
# Chosen Sample [5.25704609e+09]
# Chosen Sample [5.23254713e+09]
# Chosen Sample [5.25824526e+09]
# Chosen Sample [5.27557591e+09]
# Chosen Sample [5.22786352e+09]
# Chosen Sample [5.26633308e+09]
# Chosen Sample [5.23503012e+09]
# Chosen Sample [5.25264139e+09]
# Chosen Sample [5.25680125e+09]
# Chosen Sample [5.26865832e+09]
# Chosen Sample [5.26372287e+09]
# Chosen Sample [5.2341423e+09]
# Chosen Sample [5.24809305e+09]
# Chosen Sample [5.25724435e+09]
# Chosen Sample [5.27220491e+09]
# Chosen Sample [5.22752095e+09]
# Chosen Sample [5.23819484e+09]
# ...
# Chosen Sample [5.24618846e+09]
# Chosen Sample [5.24510183e+09]
# Chosen Sample [5.24019696e+09]
# Chosen Sample [5.26239843e+09]
# Chosen Sample [5.25656094e+09]
# Chosen Sample [5.26553801e+09]
# Chosen Sample [5.25945364e+09]
# Chosen Sample [5.26362092e+09]
# Chosen Sample [5.27349498e+09]
# Chosen Sample [5.24679444e+09]
# Chosen Sample [5.22828397e+09]
# Chosen Sample [5.26543871e+09]
# Chosen Sample [5.2534552e+09]
# Chosen Sample [5.25576754e+09]
# Chosen Sample [5.24398449e+09]
# Chosen Sample [5.25650642e+09]
# Chosen Sample [5.24814577e+09]
# Chosen Sample [5.26195943e+09]
# Chosen Sample [5.28333909e+09]
# Chosen Sample [5.23189083e+09]
# Chosen Sample [5.2336029e+09]
# Chosen Sample [5.26234755e+09]
# Chosen Sample [5.26462197e+09]
# Chosen Sample [5.27073693e+09]
# Chosen Sample [5.25083112e+09]
# Chosen Sample [5.27380826e+09]
# Chosen Sample [5.2627761e+09]
# Chosen Sample [5.25989813e+09]
# Chosen Sample [5.26156591e+09]
# Chosen Sample [5.27822633e+09]
# Chosen Sample [5.24001917e+09]
# Chosen Sample [5.24837782e+09]
# Chosen Sample [5.27685116e+09]
# Chosen Sample [5.24491921e+09]
# Chosen Sample [5.26820656e+09]
# Chosen Sample [5.2734356e+09]
# Chosen Sample [5.25850994e+09]
# Chosen Sample [5.24615851e+09]
# Chosen Sample [5.27159394e+09]
# Chosen Sample [5.24222669e+09]
# Chosen Sample [5.25154308e+09]
# Chosen Sample [5.26479378e+09]
# Chosen Sample [5.26492143e+09]
# Chosen Sample [5.26583764e+09]
# Chosen Sample [5.26442388e+09]
# Chosen Sample [5.2436456e+09]
# Chosen Sample [5.27235708e+09]
# Chosen Sample [5.24163229e+09]
# Chosen Sample [5.25177087e+09]
# Chosen Sample [5.26452127e+09]
# Chosen Sample [5.2386256e+09]
# Chosen Sample [5.22280163e+09]
# Chosen Sample [5.24494233e+09]
# Chosen Sample [5.27030153e+09]
# Chosen Sample [5.26767645e+09]
# Chosen Sample [5.27351984e+09]
# Chosen Sample [5.26874435e+09]
# Chosen Sample [5.26295709e+09]
# Chosen Sample [5.25663376e+09]
# Chosen Sample [5.25935541e+09]
# Chosen Sample [5.25186469e+09]
# Chosen Sample [5.25806341e+09]
# Chosen Sample [5.2591291e+09]
# Chosen Sample [5.24649858e+09]
# Chosen Sample [5.24859987e+09]
# Chosen Sample [5.26039248e+09]
# Chosen Sample [5.2658008e+09]
# Chosen Sample [5.25104677e+09]
# Chosen Sample [5.25118741e+09]
# Chosen Sample [5.25095886e+09]
# Chosen Sample [5.25967371e+09]
# Chosen Sample [5.2465559e+09]
# Chosen Sample [5.23340296e+09]
# Chosen Sample [5.26198538e+09]
# Chosen Sample [5.25909837e+09]
# Chosen Sample [5.26645367e+09]
# Chosen Sample [5.25065994e+09]
# Chosen Sample [5.27494493e+09]
# Chosen Sample [5.27430357e+09]
# Chosen Sample [5.26992225e+09]
# Chosen Sample [5.24969824e+09]
# Chosen Sample [5.25590774e+09]
# Chosen Sample [5.2704591e+09]
# Chosen Sample [5.2382442e+09]
# Chosen Sample [5.27266965e+09]
# Chosen Sample [5.25750506e+09]
# Chosen Sample [5.24958567e+09]
# Chosen Sample [5.27086788e+09]
# Chosen Sample [5.24950633e+09]
# Chosen Sample [5.22860411e+09]
# Chosen Sample [5.24304357e+09]
# Chosen Sample [5.23190978e+09]
# Chosen Sample [5.25119069e+09]
# Chosen Sample [5.23817422e+09]
# Chosen Sample [5.26577183e+09]
# Chosen Sample [5.25409922e+09]
# Chosen Sample [5.26022948e+09]
# Chosen Sample [5.2791908e+09]
# Chosen Sample [5.23817422e+09]
# Chosen Sample [5.26284964e+09]
# Chosen Sample [5.25104677e+09]
# Chosen Sample [5.25341216e+09]
# Chosen Sample [5.2826169e+09]
# Chosen Sample [5.2559884e+09]
# Chosen Sample [5.26255281e+09]
# Chosen Sample [5.24602173e+09]
# Chosen Sample [5.26185372e+09]
# Chosen Sample [5.25365156e+09]
# Chosen Sample [5.27537603e+09]
# Chosen Sample [5.24185624e+09]
# Chosen Sample [5.23803222e+09]
# Chosen Sample [5.2443134e+09]
# Chosen Sample [5.25667537e+09]
# Chosen Sample [5.26674054e+09]
# Chosen Sample [5.25743566e+09]
# Chosen Sample [5.25439107e+09]
# Chosen Sample [5.27699833e+09]
# Chosen Sample [5.24607902e+09]
# Chosen Sample [5.22582785e+09]
# Chosen Sample [5.27467568e+09]
# Chosen Sample [5.25344606e+09]
# Chosen Sample [5.27226717e+09]
# Chosen Sample [5.26547584e+09]
# Chosen Sample [5.26795625e+09]
# Chosen Sample [5.27494493e+09]
# Chosen Sample [5.26231525e+09]
# Chosen Sample [5.27512719e+09]
# Chosen Sample [5.25748093e+09]
# Chosen Sample [5.24177723e+09]
# Chosen Sample [5.25365156e+09]
# Chosen Sample [5.23657357e+09]
# Chosen Sample [5.2436156e+09]
# Chosen Sample [5.25094986e+09]
# Chosen Sample [5.27875851e+09]
# Chosen Sample [5.25020635e+09]
# Chosen Sample [5.24171143e+09]
# Chosen Sample [5.2510199e+09]
# Chosen Sample [5.26159914e+09]
# Chosen Sample [5.26021951e+09]
# Chosen Sample [5.24116702e+09]
# Chosen Sample [5.27555651e+09]
# Chosen Sample [5.26352672e+09]
# Chosen Sample [5.26454651e+09]
# Chosen Sample [5.25284401e+09]
# Chosen Sample [5.27085e+09]
# Chosen Sample [5.22764029e+09]
# Chosen Sample [5.25753669e+09]
# Chosen Sample [5.27166243e+09]
# Chosen Sample [5.22896467e+09]
# Chosen Sample [5.28501599e+09]
# Chosen Sample [5.25351481e+09]
# Chosen Sample [5.27849798e+09]
# Chosen Sample [5.26068692e+09]
# Chosen Sample [5.27218154e+09]
# Chosen Sample [5.26556894e+09]
# Chosen Sample [5.24472732e+09]
# Chosen Sample [5.24807657e+09]
# Chosen Sample [5.2478894e+09]
# Chosen Sample [5.30131872e+09]
# Chosen Sample [5.26059459e+09]
# Chosen Sample [5.24263427e+09]
# Chosen Sample [5.23809617e+09]
# Chosen Sample [5.27095554e+09]
# Chosen Sample [5.24574213e+09]
# Chosen Sample [5.28849923e+09]
# Chosen Sample [5.27461414e+09]
# Chosen Sample [5.27533579e+09]
# Chosen Sample [5.24272382e+09]
# Chosen Sample [5.21892086e+09]
# Chosen Sample [5.26045841e+09]
# Chosen Sample [5.25563848e+09]
# Chosen Sample [5.24270226e+09]
# Chosen Sample [5.25504167e+09]
# Chosen Sample [5.25881118e+09]
# Chosen Sample [5.25831074e+09]
# Chosen Sample [5.23641445e+09]
# Chosen Sample [5.22416673e+09]
# Chosen Sample [5.2510199e+09]
# Chosen Sample [5.25723579e+09]
# Chosen Sample [5.26767944e+09]
# Chosen Sample [5.2521076e+09]
# Chosen Sample [5.25899461e+09]
# Chosen Sample [5.28521869e+09]
# Chosen Sample [5.26207306e+09]
# Chosen Sample [5.22009554e+09]
# Chosen Sample [5.26423442e+09]
# Chosen Sample [5.26877534e+09]
# Chosen Sample [5.23316023e+09]
# Chosen Sample [5.23910455e+09]
# Chosen Sample [5.27282724e+09]
# Chosen Sample [5.26938612e+09]
# Chosen Sample [5.28298382e+09]
# Chosen Sample [5.25291798e+09]
# Chosen Sample [5.25328315e+09]
# Chosen Sample [5.2784755e+09]
# Chosen Sample [5.31095439e+09]
# Chosen Sample [5.25693143e+09]
# Chosen Sample [5.24864623e+09]
# Chosen Sample [5.24057627e+09]
# Chosen Sample [5.27430967e+09]
# Chosen Sample [5.25845055e+09]
# Chosen Sample [5.2674498e+09]
# Chosen Sample [5.26458064e+09]
# Chosen Sample [5.25140689e+09]
# Chosen Sample [5.26207776e+09]
# Chosen Sample [5.2503231e+09]
# Chosen Sample [5.24528192e+09]
# Chosen Sample [5.25923007e+09]
# Chosen Sample [5.22792163e+09]
# Chosen Sample [5.24789379e+09]
# Chosen Sample [5.26759174e+09]
# Chosen Sample [5.23659511e+09]
# Chosen Sample [5.25019835e+09]
# Chosen Sample [5.23652225e+09]
# Chosen Sample [5.28078849e+09]
# Chosen Sample [5.25557783e+09]
# Chosen Sample [5.25046736e+09]
# Chosen Sample [5.2717536e+09]
# Chosen Sample [5.25553024e+09]
# Chosen Sample [5.26344562e+09]
# Chosen Sample [5.25496694e+09]
# Chosen Sample [5.27260404e+09]
# Chosen Sample [5.27510017e+09]
# Chosen Sample [5.23596356e+09]
# Chosen Sample [5.2893927e+09]
# Chosen Sample [5.26406076e+09]
# Chosen Sample [5.27058505e+09]
# Chosen Sample [5.2683861e+09]
# Chosen Sample [5.26856118e+09]
# Chosen Sample [5.25886242e+09]
# Chosen Sample [5.28372846e+09]
# Chosen Sample [5.22562259e+09]
# Chosen Sample [5.27183979e+09]
# Chosen Sample [5.24900584e+09]
# Chosen Sample [5.2489539e+09]
# Chosen Sample [5.23760198e+09]
# Chosen Sample [5.2544411e+09]
# Chosen Sample [5.23807423e+09]
# Chosen Sample [5.22246307e+09]
# Chosen Sample [5.24793473e+09]
# Chosen Sample [5.25126028e+09]
# Chosen Sample [5.23919163e+09]
# Chosen Sample [5.26336332e+09]
# Chosen Sample [5.25716698e+09]
# Chosen Sample [5.27322086e+09]
# Chosen Sample [5.24080539e+09]
# Chosen Sample [5.26021385e+09]
# Chosen Sample [5.24909754e+09]
# Chosen Sample [5.25879112e+09]
# Chosen Sample [5.27227531e+09]
# Chosen Sample [5.26714083e+09]
# Chosen Sample [5.25034113e+09]
# Chosen Sample [5.28145379e+09]
# Chosen Sample [5.25792483e+09]
# Chosen Sample [5.27017318e+09]
# Chosen Sample [5.2609678e+09]
# Chosen Sample [5.26645765e+09]
# Chosen Sample [5.27033247e+09]
# Chosen Sample [5.26592066e+09]
# Chosen Sample [5.25582886e+09]
# Chosen Sample [5.28009266e+09]
# Chosen Sample [5.25048147e+09]
# Chosen Sample [5.25625832e+09]
# Chosen Sample [5.27537524e+09]
# Chosen Sample [5.27406309e+09]
# Chosen Sample [5.27111805e+09]
# Chosen Sample [5.27085008e+09]
# Chosen Sample [5.27553804e+09]
# Chosen Sample [5.25864282e+09]
# Chosen Sample [5.23246519e+09]
# Chosen Sample [5.26945134e+09]
# Chosen Sample [5.24735127e+09]
# Chosen Sample [5.26206461e+09]
# Chosen Sample [5.25984529e+09]
# Chosen Sample [5.24515595e+09]
# Chosen Sample [5.24181432e+09]
# Chosen Sample [5.26974398e+09]
# Chosen Sample [5.25409216e+09]
# Chosen Sample [5.26645367e+09]
# Chosen Sample [5.25110144e+09]
# Chosen Sample [5.23755918e+09]
# Chosen Sample [5.26458094e+09]
# Chosen Sample [5.25935541e+09]
# Chosen Sample [5.24110923e+09]
# Chosen Sample [5.2718611e+09]
# Chosen Sample [5.25271222e+09]
# Chosen Sample [5.25292681e+09]
# Chosen Sample [5.24641008e+09]
# Chosen Sample [5.25719822e+09]
# Chosen Sample [5.24645393e+09]
# Chosen Sample [5.23897899e+09]
# Chosen Sample [5.2740376e+09]
# Chosen Sample [5.23816687e+09]
# Chosen Sample [5.26212854e+09]
# Chosen Sample [5.26524406e+09]
# Chosen Sample [5.27412783e+09]
# Chosen Sample [5.24895689e+09]
# Chosen Sample [5.28452731e+09]
# Chosen Sample [5.27849798e+09]
# Chosen Sample [5.28263825e+09]
# Chosen Sample [5.29082808e+09]
# Chosen Sample [5.24635283e+09]
# Chosen Sample [5.24674131e+09]
# Chosen Sample [5.27615471e+09]
# Chosen Sample [5.2755388e+09]
# Chosen Sample [5.22702803e+09]
# Chosen Sample [5.26356886e+09]
# Chosen Sample [5.2649714e+09]
# Chosen Sample [5.25569573e+09]
# Chosen Sample [5.25423288e+09]
# Chosen Sample [5.26265615e+09]
# Chosen Sample [5.21804501e+09]
# Chosen Sample [5.27560719e+09]
# Chosen Sample [5.26006935e+09]
# Chosen Sample [5.22806917e+09]
# Chosen Sample [5.26355808e+09]
# Chosen Sample [5.24589964e+09]
# Chosen Sample [5.24699096e+09]
# Chosen Sample [5.2481692e+09]
# Chosen Sample [5.24363551e+09]
# Chosen Sample [5.25904082e+09]
# Chosen Sample [5.27040127e+09]
# Chosen Sample [5.26867817e+09]
# Chosen Sample [5.26035634e+09]
# Chosen Sample [5.27401324e+09]
# Chosen Sample [5.25809506e+09]
# Chosen Sample [5.28540014e+09]
# Chosen Sample [5.23505397e+09]
# Chosen Sample [5.29420337e+09]
# Chosen Sample [5.26454651e+09]
# Chosen Sample [5.23962502e+09]
# Chosen Sample [5.25585581e+09]
# Chosen Sample [5.25456773e+09]
# Chosen Sample [5.28341783e+09]
# Chosen Sample [5.28004732e+09]
# Chosen Sample [5.26767485e+09]
# Chosen Sample [5.24669561e+09]
# Chosen Sample [5.24821336e+09]
# Chosen Sample [5.25162738e+09]
# Chosen Sample [5.26914101e+09]
# Chosen Sample [5.2750951e+09]
# Chosen Sample [5.23646055e+09]
# Chosen Sample [5.24212834e+09]
# Chosen Sample [5.26185488e+09]
# Chosen Sample [5.25153282e+09]
# Chosen Sample [5.25773936e+09]
# Chosen Sample [5.25288905e+09]
# Chosen Sample [5.26985706e+09]
# Chosen Sample [5.25186069e+09]
# Chosen Sample [5.22009554e+09]
# Chosen Sample [5.23001191e+09]
# Chosen Sample [5.23602446e+09]
# Chosen Sample [5.22775743e+09]
# Chosen Sample [5.24994459e+09]
# Chosen Sample [5.25311018e+09]
# Chosen Sample [5.25354377e+09]
# Chosen Sample [5.21488341e+09]
# Chosen Sample [5.24578901e+09]
# Chosen Sample [5.26331605e+09]
# Chosen Sample [5.25798185e+09]
# Chosen Sample [5.26738816e+09]
# Chosen Sample [5.23318063e+09]
# Chosen Sample [5.26476699e+09]
# Chosen Sample [5.24511656e+09]
# Chosen Sample [5.27396542e+09]
# Chosen Sample [5.26014111e+09]
# Chosen Sample [5.28131083e+09]
# Chosen Sample [5.29018305e+09]
# Chosen Sample [5.22391085e+09]
# Chosen Sample [5.26623099e+09]
# Chosen Sample [5.2536082e+09]
# Chosen Sample [5.25075245e+09]
# Chosen Sample [5.27583353e+09]
# Chosen Sample [5.25883425e+09]
# Chosen Sample [5.28170989e+09]
# Chosen Sample [5.26264587e+09]
# Chosen Sample [5.26964259e+09]
# Chosen Sample [5.23433227e+09]
# Chosen Sample [5.26553172e+09]
# Chosen Sample [5.25645657e+09]
# Chosen Sample [5.21930877e+09]
# Chosen Sample [5.27029067e+09]
# Chosen Sample [5.23303903e+09]
# Chosen Sample [5.22113801e+09]
# Chosen Sample [5.24736188e+09]
# Chosen Sample [5.24914826e+09]
# Chosen Sample [5.25974745e+09]
# Chosen Sample [5.27202248e+09]
# Chosen Sample [5.25610192e+09]
# Chosen Sample [5.25351481e+09]
# Chosen Sample [5.26598624e+09]
# Chosen Sample [5.21905163e+09]
# Chosen Sample [5.24892708e+09]
# Chosen Sample [5.2538214e+09]
# Chosen Sample [5.27933813e+09]
# Chosen Sample [5.300985e+09]
# Chosen Sample [5.26409888e+09]
# Chosen Sample [5.26553172e+09]
# Chosen Sample [5.25610312e+09]
# Chosen Sample [5.2383229e+09]
# Chosen Sample [5.27295042e+09]
# Chosen Sample [5.24791688e+09]
# Chosen Sample [5.24052491e+09]
# Chosen Sample [5.25354553e+09]
# Chosen Sample [5.24707989e+09]
# Chosen Sample [5.24589964e+09]
# Chosen Sample [5.27994591e+09]
# Chosen Sample [5.25109493e+09]
# Chosen Sample [5.25567187e+09]
# Chosen Sample [5.25150977e+09]
# Chosen Sample [5.25313982e+09]
# Chosen Sample [5.23766289e+09]
# Chosen Sample [5.294423e+09]
# Chosen Sample [5.23723042e+09]
# Chosen Sample [5.2699509e+09]
# Chosen Sample [5.26624649e+09]
# Chosen Sample [5.23819484e+09]
# Chosen Sample [5.26296964e+09]
# Chosen Sample [5.25800488e+09]
# Chosen Sample [5.26388773e+09]
# Chosen Sample [5.25334322e+09]
# Chosen Sample [5.30061207e+09]
# Chosen Sample [5.24243553e+09]
# Chosen Sample [5.2536539e+09]
# Chosen Sample [5.24495064e+09]
# Chosen Sample [5.26873804e+09]
# Chosen Sample [5.2511183e+09]
# Chosen Sample [5.28789872e+09]
# Chosen Sample [5.258589e+09]
# Chosen Sample [5.2764083e+09]
# Chosen Sample [5.25804477e+09]
# Chosen Sample [5.29017354e+09]
# Chosen Sample [5.25221579e+09]
# Chosen Sample [5.26524406e+09]
# Chosen Sample [5.28061655e+09]
# Chosen Sample [5.26574564e+09]
# Chosen Sample [5.25725136e+09]
# Chosen Sample [5.21608676e+09]
# Chosen Sample [5.27277401e+09]
# Chosen Sample [5.22452288e+09]
# Chosen Sample [5.28220093e+09]
# Chosen Sample [5.23700798e+09]
# Chosen Sample [5.24212566e+09]
# Chosen Sample [5.26166658e+09]
# Chosen Sample [5.25744685e+09]
# Chosen Sample [5.26236651e+09]
# Chosen Sample [5.25888102e+09]
# Chosen Sample [5.2721044e+09]
# Chosen Sample [5.2561078e+09]
# Chosen Sample [5.27096597e+09]
# Chosen Sample [5.24053223e+09]
# Chosen Sample [5.23818423e+09]
# Chosen Sample [5.24596313e+09]
# Chosen Sample [5.2671611e+09]
# Chosen Sample [5.25993019e+09]
# Chosen Sample [5.2665117e+09]
# Chosen Sample [5.22906136e+09]
# Chosen Sample [5.27127739e+09]
# Chosen Sample [5.2814007e+09]
# Chosen Sample [5.28128367e+09]
# Chosen Sample [5.25357355e+09]
# Chosen Sample [5.24014263e+09]
# Chosen Sample [5.2805591e+09]
# Chosen Sample [5.26970097e+09]
# Chosen Sample [5.24106008e+09]
# Chosen Sample [5.26746216e+09]
# Chosen Sample [5.27490265e+09]
# Chosen Sample [5.28385787e+09]
# Chosen Sample [5.24103052e+09]
# Chosen Sample [5.26908279e+09]
# Chosen Sample [5.26526059e+09]
# Chosen Sample [5.23626735e+09]
# Chosen Sample [5.21686322e+09]
# Chosen Sample [5.28103747e+09]
# Chosen Sample [5.24044298e+09]
# Chosen Sample [5.23830669e+09]
# Chosen Sample [5.24309766e+09]
# Chosen Sample [5.27936036e+09]
# Chosen Sample [5.2891885e+09]
# Chosen Sample [5.25123078e+09]
# Chosen Sample [5.26576227e+09]
# Chosen Sample [5.24006737e+09]
# Chosen Sample [5.23078311e+09]
# Chosen Sample [5.27689273e+09]
# Chosen Sample [5.26687213e+09]
# Chosen Sample [5.26247708e+09]
# Chosen Sample [5.27138758e+09]
# Chosen Sample [5.25540761e+09]
# Chosen Sample [5.27102305e+09]
# Chosen Sample [5.25718602e+09]
# Chosen Sample [5.27048597e+09]
# Chosen Sample [5.26132494e+09]
# Chosen Sample [5.24017357e+09]
# Chosen Sample [5.22514737e+09]
# Chosen Sample [5.26898582e+09]
# Chosen Sample [5.26395901e+09]
# Chosen Sample [5.25109021e+09]
# Chosen Sample [5.24436704e+09]
# Chosen Sample [5.25659953e+09]
# Chosen Sample [5.26313908e+09]
# Chosen Sample [5.25525516e+09]
# Chosen Sample [5.25793949e+09]
# Chosen Sample [5.24501196e+09]
# Chosen Sample [5.26771926e+09]
# Chosen Sample [5.2613721e+09]
# Chosen Sample [5.22119015e+09]
# Chosen Sample [5.26327953e+09]
# Chosen Sample [5.25161499e+09]
# Chosen Sample [5.25926978e+09]
# Chosen Sample [5.23753513e+09]
# Chosen Sample [5.24536824e+09]
# Chosen Sample [5.26323104e+09]
# Chosen Sample [5.22335489e+09]
# Chosen Sample [5.27071833e+09]
# Chosen Sample [5.26938612e+09]
# Chosen Sample [5.25560132e+09]
# Chosen Sample [5.24475831e+09]
# Chosen Sample [5.27207798e+09]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                     scale        chosen_sample  \
# 0  0.001248  [1.0812012020837954e+17]  [5253283148.791286]
# 1  0.001248  [1.0812012020837954e+17]  [5253515511.639774]
# 2  0.001248  [1.0812012020837954e+17]  [5256062292.070626]
# 3  0.001248  [1.0812012020837954e+17]   [5269222975.66103]
# 4  0.001248  [1.0812012020837954e+17]  [5249711339.509012]
#
#            chosen_noise              release
# 0   [37643176.69472579]  [5290926325.486012]
# 1   [743126913.3440793]  [5996642424.983853]
# 2  [-493537924.6529726]  [4762524367.417654]
# 3   [40306301.66663353]  [5309529277.327663]
# 4  [123200770.87952399]  [5372912110.388536]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi         scale chosen_sample  chosen_noise       release
# query              sum_charge    sum_charge    sum_charge    sum_charge
# 0      0.001248  1.081201e+17  5.253283e+09  3.764318e+07  5.290926e+09
# 1      0.001248  1.081201e+17  5.253516e+09  7.431269e+08  5.996642e+09
# 2      0.001248  1.081201e+17  5.256062e+09 -4.935379e+08  4.762524e+09
# 3      0.001248  1.081201e+17  5.269223e+09  4.030630e+07  5.309529e+09
# 4      0.001248  1.081201e+17  5.249711e+09  1.232008e+08  5.372912e+09

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71963/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step              scale chosen_sample  chosen_noise       release
# query        sum_charge    sum_charge    sum_charge    sum_charge
# mi
# 0.001248   1.081201e+17  5.256885e+09 -7.763180e+06  5.249122e+09
# 0.015625   8.637975e+15  5.256740e+09  4.267341e+06  5.261007e+09
# 0.031250   4.318988e+15  5.256558e+09 -2.799695e+06  5.253758e+09
# 0.062500   2.159494e+15  5.256451e+09  1.318314e+05  5.256583e+09
# 0.250000   5.398734e+14  5.257070e+09 -7.668649e+05  5.256303e+09
# 1.000000   1.349684e+14  5.256324e+09 -6.628708e+05  5.255661e+09
# 2.000000   6.748418e+13  5.256029e+09  4.044457e+05  5.256433e+09
# 4.000000   3.374209e+13  5.256827e+09  3.758318e+05  5.257203e+09
# 16.000000  8.435523e+12  5.256692e+09  9.752000e+03  5.256702e+09

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['sum_charge'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi            1.248319e-03
# sum_charge    5.290926e+09
# Name: 0, dtype: float64
# mi            1.248319e-03
# sum_charge    5.996642e+09
# Name: 1, dtype: float64
# mi            1.248319e-03
# sum_charge    4.762524e+09
# Name: 2, dtype: float64
# mi            1.248319e-03
# sum_charge    5.309529e+09
# Name: 3, dtype: float64
# mi            1.248319e-03
# sum_charge    5.372912e+09
# Name: 4, dtype: float64
# mi            1.248319e-03
# sum_charge    5.252309e+09
# Name: 5, dtype: float64
# mi            1.248319e-03
# sum_charge    5.170426e+09
# Name: 6, dtype: float64
# mi            1.248319e-03
# sum_charge    5.472978e+09
# Name: 7, dtype: float64
# mi            1.248319e-03
# sum_charge    5.862081e+09
# Name: 8, dtype: float64
# mi            1.248319e-03
# sum_charge    4.934880e+09
# Name: 9, dtype: float64
# mi            1.248319e-03
# sum_charge    5.172068e+09
# Name: 10, dtype: float64
# mi            1.248319e-03
# sum_charge    4.805167e+09
# Name: 11, dtype: float64
# mi            1.248319e-03
# sum_charge    5.089481e+09
# Name: 12, dtype: float64
# mi            1.248319e-03
# sum_charge    5.362783e+09
# Name: 13, dtype: float64
# mi            1.248319e-03
# sum_charge    5.150988e+09
# Name: 14, dtype: float64
# mi            1.248319e-03
# sum_charge    5.377922e+09
# Name: 15, dtype: float64
# mi            1.248319e-03
# sum_charge    5.881352e+09
# Name: 16, dtype: float64
# mi            1.248319e-03
# sum_charge    5.265469e+09
# Name: 17, dtype: float64
# mi            1.248319e-03
# sum_charge    5.288743e+09
# Name: 18, dtype: float64
# mi            1.248319e-03
# sum_charge    5.279860e+09
# Name: 19, dtype: float64
# mi            1.248319e-03
# sum_charge    5.659885e+09
# Name: 20, dtype: float64
# mi            1.248319e-03
# sum_charge    4.898967e+09
# Name: 21, dtype: float64
# mi            1.248319e-03
# sum_charge    4.296374e+09
# Name: 22, dtype: float64
# mi            1.248319e-03
# sum_charge    5.614722e+09
# Name: 23, dtype: float64
# mi            1.248319e-03
# sum_charge    5.171412e+09
# Name: 24, dtype: float64
# mi            1.248319e-03
# sum_charge    5.184614e+09
# Name: 25, dtype: float64
# mi            1.248319e-03
# sum_charge    5.358642e+09
# Name: 26, dtype: float64
# mi            1.248319e-03
# sum_charge    4.731073e+09
# Name: 27, dtype: float64
# mi            1.248319e-03
# sum_charge    5.640791e+09
# Name: 28, dtype: float64
# mi            1.248319e-03
# sum_charge    5.212956e+09
# Name: 29, dtype: float64
# mi            1.248319e-03
# sum_charge    4.758978e+09
# Name: 30, dtype: float64
# mi            1.248319e-03
# sum_charge    5.022444e+09
# Name: 31, dtype: float64
# mi            1.248319e-03
# sum_charge    4.611972e+09
# Name: 32, dtype: float64
# mi            1.248319e-03
# sum_charge    4.667587e+09
# Name: 33, dtype: float64
# mi            1.248319e-03
# sum_charge    4.827577e+09
# Name: 34, dtype: float64
# mi            1.248319e-03
# sum_charge    5.022610e+09
# Name: 35, dtype: float64
# mi            1.248319e-03
# sum_charge    5.081150e+09
# Name: 36, dtype: float64
# mi            1.248319e-03
# sum_charge    5.041325e+09
# Name: 37, dtype: float64
# mi            1.248319e-03
# sum_charge    5.077514e+09
# Name: 38, dtype: float64
# mi            1.248319e-03
# sum_charge    5.218481e+09
# Name: 39, dtype: float64
# mi            1.248319e-03
# sum_charge    5.430411e+09
# Name: 40, dtype: float64
# mi            1.248319e-03
# sum_charge    5.901936e+09
# Name: 41, dtype: float64
# mi            1.248319e-03
# sum_charge    5.476488e+09
# Name: 42, dtype: float64
# mi            1.248319e-03
# sum_charge    4.933694e+09
# Name: 43, dtype: float64
# mi            1.248319e-03
# sum_charge    5.517172e+09
# Name: 44, dtype: float64
# mi            1.248319e-03
# sum_charge    5.653911e+09
# Name: 45, dtype: float64
# mi            1.248319e-03
# sum_charge    5.488571e+09
# Name: 46, dtype: float64
# mi            1.248319e-03
# sum_charge    5.554548e+09
# Name: 47, dtype: float64
# mi            1.248319e-03
# sum_charge    5.114467e+09
# Name: 48, dtype: float64
# mi            1.248319e-03
# sum_charge    5.185768e+09
# Name: 49, dtype: float64
# mi            1.248319e-03
# sum_charge    4.794405e+09
# Name: 50, dtype: float64
# mi            1.248319e-03
# sum_charge    5.046182e+09
# Name: 51, dtype: float64
# mi            1.248319e-03
# sum_charge    5.636703e+09
# Name: 52, dtype: float64
# mi            1.248319e-03
# sum_charge    5.106712e+09
# Name: 53, dtype: float64
# mi            1.248319e-03
# sum_charge    5.226387e+09
# Name: 54, dtype: float64
# mi            1.248319e-03
# sum_charge    4.819589e+09
# Name: 55, dtype: float64
# mi            1.248319e-03
# sum_charge    5.307908e+09
# Name: 56, dtype: float64
# mi            1.248319e-03
# sum_charge    5.854792e+09
# Name: 57, dtype: float64
# mi            1.248319e-03
# sum_charge    4.802782e+09
# Name: 58, dtype: float64
# mi            1.248319e-03
# sum_charge    5.367891e+09
# Name: 59, dtype: float64
# mi            1.248319e-03
# sum_charge    5.222488e+09
# Name: 60, dtype: float64
# mi            1.248319e-03
# sum_charge    5.376657e+09
# Name: 61, dtype: float64
# mi            1.248319e-03
# sum_charge    4.727717e+09
# Name: 62, dtype: float64
# mi            1.248319e-03
# sum_charge    5.031050e+09
# Name: 63, dtype: float64
# mi            1.248319e-03
# sum_charge    5.400702e+09
# Name: 64, dtype: float64
# mi            1.248319e-03
# sum_charge    5.601713e+09
# Name: 65, dtype: float64
# mi            1.248319e-03
# sum_charge    5.094660e+09
# Name: 66, dtype: float64
# mi            1.248319e-03
# sum_charge    5.641615e+09
# Name: 67, dtype: float64
# mi            1.248319e-03
# sum_charge    5.480739e+09
# Name: 68, dtype: float64
# mi            1.248319e-03
# sum_charge    5.049316e+09
# Name: 69, dtype: float64
# mi            1.248319e-03
# sum_charge    5.470291e+09
# Name: 70, dtype: float64
# mi            1.248319e-03
# sum_charge    5.551537e+09
# Name: 71, dtype: float64
# mi            1.248319e-03
# sum_charge    5.302058e+09
# Name: 72, dtype: float64
# mi            1.248319e-03
# sum_charge    5.218157e+09
# Name: 73, dtype: float64
# mi            1.248319e-03
# sum_charge    5.133420e+09
# Name: 74, dtype: float64
# mi            1.248319e-03
# sum_charge    4.911022e+09
# Name: 75, dtype: float64
# mi            1.248319e-03
# sum_charge    5.802354e+09
# Name: 76, dtype: float64
# mi            1.248319e-03
# sum_charge    4.261679e+09
# Name: 77, dtype: float64
# mi            1.248319e-03
# sum_charge    4.837354e+09
# Name: 78, dtype: float64
# mi            1.248319e-03
# sum_charge    4.991675e+09
# Name: 79, dtype: float64
# mi            1.248319e-03
# sum_charge    5.670989e+09
# Name: 80, dtype: float64
# mi            1.248319e-03
# sum_charge    5.653943e+09
# Name: 81, dtype: float64
# mi            1.248319e-03
# sum_charge    5.549686e+09
# Name: 82, dtype: float64
# mi            1.248319e-03
# sum_charge    5.752357e+09
# Name: 83, dtype: float64
# mi            1.248319e-03
# sum_charge    5.211522e+09
# Name: 84, dtype: float64
# mi            1.248319e-03
# sum_charge    5.794034e+09
# Name: 85, dtype: float64
# mi            1.248319e-03
# sum_charge    5.689857e+09
# Name: 86, dtype: float64
# mi            1.248319e-03
# sum_charge    5.330987e+09
# Name: 87, dtype: float64
# mi            1.248319e-03
# sum_charge    4.988491e+09
# Name: 88, dtype: float64
# mi            1.248319e-03
# sum_charge    5.695961e+09
# Name: 89, dtype: float64
# mi            1.248319e-03
# sum_charge    5.407751e+09
# Name: 90, dtype: float64
# mi            1.248319e-03
# sum_charge    6.015851e+09
# Name: 91, dtype: float64
# mi            1.248319e-03
# sum_charge    5.663942e+09
# Name: 92, dtype: float64
# mi            1.248319e-03
# sum_charge    4.906143e+09
# Name: 93, dtype: float64
# mi            1.248319e-03
# sum_charge    5.716973e+09
# Name: 94, dtype: float64
# mi            1.248319e-03
# sum_charge    4.467726e+09
# Name: 95, dtype: float64
# mi            1.248319e-03
# sum_charge    5.125529e+09
# Name: 96, dtype: float64
# mi            1.248319e-03
# sum_charge    5.534912e+09
# Name: 97, dtype: float64
# mi            1.248319e-03
# sum_charge    5.475554e+09
# Name: 98, dtype: float64
# mi            1.248319e-03
# sum_charge    5.319796e+09
# Name: 99, dtype: float64
# mi            1.248319e-03
# sum_charge    5.384174e+09
# Name: 100, dtype: float64
# mi            1.248319e-03
# sum_charge    5.164904e+09
# Name: 101, dtype: float64
# mi            1.248319e-03
# sum_charge    5.180665e+09
# Name: 102, dtype: float64
# mi            1.248319e-03
# sum_charge    5.756218e+09
# Name: 103, dtype: float64
# mi            1.248319e-03
# sum_charge    5.578744e+09
# Name: 104, dtype: float64
# mi            1.248319e-03
# sum_charge    6.204912e+09
# Name: 105, dtype: float64
# mi            1.248319e-03
# sum_charge    4.567416e+09
# Name: 106, dtype: float64
# mi            1.248319e-03
# sum_charge    5.218653e+09
# Name: 107, dtype: float64
# mi            1.248319e-03
# sum_charge    4.733026e+09
# Name: 108, dtype: float64
# mi            1.248319e-03
# sum_charge    4.587808e+09
# Name: 109, dtype: float64
# mi            1.248319e-03
# sum_charge    5.499967e+09
# Name: 110, dtype: float64
# mi            1.248319e-03
# sum_charge    5.258857e+09
# Name: 111, dtype: float64
# mi            1.248319e-03
# sum_charge    4.859582e+09
# Name: 112, dtype: float64
# mi            1.248319e-03
# sum_charge    5.073085e+09
# Name: 113, dtype: float64
# mi            1.248319e-03
# sum_charge    5.775691e+09
# Name: 114, dtype: float64
# mi            1.248319e-03
# sum_charge    4.708954e+09
# Name: 115, dtype: float64
# mi            1.248319e-03
# sum_charge    5.588610e+09
# Name: 116, dtype: float64
# mi            1.248319e-03
# sum_charge    5.317484e+09
# Name: 117, dtype: float64
# mi            1.248319e-03
# sum_charge    5.342661e+09
# Name: 118, dtype: float64
# mi            1.248319e-03
# sum_charge    5.695436e+09
# Name: 119, dtype: float64
# mi            1.248319e-03
# sum_charge    5.667771e+09
# Name: 120, dtype: float64
# mi            1.248319e-03
# sum_charge    5.187972e+09
# Name: 121, dtype: float64
# mi            1.248319e-03
# sum_charge    4.749187e+09
# Name: 122, dtype: float64
# mi            1.248319e-03
# sum_charge    5.293895e+09
# Name: 123, dtype: float64
# mi            1.248319e-03
# sum_charge    5.409658e+09
# Name: 124, dtype: float64
# mi            1.248319e-03
# sum_charge    5.691704e+09
# Name: 125, dtype: float64
# mi            1.248319e-03
# sum_charge    4.747617e+09
# Name: 126, dtype: float64
# mi            1.248319e-03
# sum_charge    5.709387e+09
# Name: 127, dtype: float64
# mi            1.248319e-03
# sum_charge    4.965099e+09
# Name: 128, dtype: float64
# mi            1.248319e-03
# sum_charge    5.411386e+09
# Name: 129, dtype: float64
# mi            1.248319e-03
# sum_charge    5.315157e+09
# Name: 130, dtype: float64
# mi            1.248319e-03
# sum_charge    5.484591e+09
# Name: 131, dtype: float64
# mi            1.248319e-03
# sum_charge    4.533602e+09
# Name: 132, dtype: float64
# mi            1.248319e-03
# sum_charge    5.489134e+09
# Name: 133, dtype: float64
# mi            1.248319e-03
# sum_charge    5.202037e+09
# Name: 134, dtype: float64
# mi            1.248319e-03
# sum_charge    5.118880e+09
# Name: 135, dtype: float64
# mi            1.248319e-03
# sum_charge    5.050746e+09
# Name: 136, dtype: float64
# mi            1.248319e-03
# sum_charge    5.258839e+09
# Name: 137, dtype: float64
# mi            1.248319e-03
# sum_charge    4.641797e+09
# Name: 138, dtype: float64
# mi            1.248319e-03
# sum_charge    4.873517e+09
# Name: 139, dtype: float64
# mi            1.248319e-03
# sum_charge    5.127969e+09
# Name: 140, dtype: float64
# mi            1.248319e-03
# sum_charge    5.168289e+09
# Name: 141, dtype: float64
# mi            1.248319e-03
# sum_charge    5.128115e+09
# Name: 142, dtype: float64
# mi            1.248319e-03
# sum_charge    4.688732e+09
# Name: 143, dtype: float64
# mi            1.248319e-03
# sum_charge    5.314944e+09
# Name: 144, dtype: float64
# mi            1.248319e-03
# sum_charge    5.704957e+09
# Name: 145, dtype: float64
# mi            1.248319e-03
# sum_charge    5.517289e+09
# Name: 146, dtype: float64
# mi            1.248319e-03
# sum_charge    5.018859e+09
# Name: 147, dtype: float64
# mi            1.248319e-03
# sum_charge    4.877318e+09
# Name: 148, dtype: float64
# mi            1.248319e-03
# sum_charge    5.121545e+09
# Name: 149, dtype: float64
# mi            1.248319e-03
# sum_charge    5.583583e+09
# Name: 150, dtype: float64
# mi            1.248319e-03
# sum_charge    5.355256e+09
# Name: 151, dtype: float64
# mi            1.248319e-03
# sum_charge    5.326293e+09
# Name: 152, dtype: float64
# mi            1.248319e-03
# sum_charge    5.135453e+09
# Name: 153, dtype: float64
# mi            1.248319e-03
# sum_charge    5.224129e+09
# Name: 154, dtype: float64
# mi            1.248319e-03
# sum_charge    5.691240e+09
# Name: 155, dtype: float64
# mi            1.248319e-03
# sum_charge    5.128897e+09
# Name: 156, dtype: float64
# mi            1.248319e-03
# sum_charge    5.001673e+09
# Name: 157, dtype: float64
# mi            1.248319e-03
# sum_charge    5.553225e+09
# Name: 158, dtype: float64
# mi            1.248319e-03
# sum_charge    5.171773e+09
# Name: 159, dtype: float64
# mi            1.248319e-03
# sum_charge    4.765043e+09
# Name: 160, dtype: float64
# mi            1.248319e-03
# sum_charge    4.900706e+09
# Name: 161, dtype: float64
# mi            1.248319e-03
# sum_charge    5.291518e+09
# Name: 162, dtype: float64
# mi            1.248319e-03
# sum_charge    4.707850e+09
# Name: 163, dtype: float64
# mi            1.248319e-03
# sum_charge    5.169649e+09
# Name: 164, dtype: float64
# mi            1.248319e-03
# sum_charge    5.787711e+09
# Name: 165, dtype: float64
# mi            1.248319e-03
# sum_charge    4.979978e+09
# Name: 166, dtype: float64
# mi            1.248319e-03
# sum_charge    6.394507e+09
# Name: 167, dtype: float64
# mi            1.248319e-03
# sum_charge    5.375911e+09
# Name: 168, dtype: float64
# mi            1.248319e-03
# sum_charge    4.975133e+09
# Name: 169, dtype: float64
# mi            1.248319e-03
# sum_charge    5.091516e+09
# Name: 170, dtype: float64
# mi            1.248319e-03
# sum_charge    5.407675e+09
# Name: 171, dtype: float64
# mi            1.248319e-03
# sum_charge    4.961954e+09
# Name: 172, dtype: float64
# mi            1.248319e-03
# sum_charge    5.106600e+09
# Name: 173, dtype: float64
# mi            1.248319e-03
# sum_charge    5.226785e+09
# Name: 174, dtype: float64
# mi            1.248319e-03
# sum_charge    5.227072e+09
# Name: 175, dtype: float64
# mi            1.248319e-03
# sum_charge    5.099094e+09
# Name: 176, dtype: float64
# mi            1.248319e-03
# sum_charge    5.635870e+09
# Name: 177, dtype: float64
# mi            1.248319e-03
# sum_charge    4.966395e+09
# Name: 178, dtype: float64
# mi            1.248319e-03
# sum_charge    5.298416e+09
# Name: 179, dtype: float64
# mi            1.248319e-03
# sum_charge    4.774281e+09
# Name: 180, dtype: float64
# mi            1.248319e-03
# sum_charge    5.377779e+09
# Name: 181, dtype: float64
# mi            1.248319e-03
# sum_charge    5.155341e+09
# Name: 182, dtype: float64
# mi            1.248319e-03
# sum_charge    5.884260e+09
# Name: 183, dtype: float64
# mi            1.248319e-03
# sum_charge    5.995940e+09
# Name: 184, dtype: float64
# mi            1.248319e-03
# sum_charge    5.398575e+09
# Name: 185, dtype: float64
# mi            1.248319e-03
# sum_charge    5.708744e+09
# Name: 186, dtype: float64
# mi            1.248319e-03
# sum_charge    4.734679e+09
# Name: 187, dtype: float64
# mi            1.248319e-03
# sum_charge    5.651546e+09
# Name: 188, dtype: float64
# mi            1.248319e-03
# sum_charge    6.121336e+09
# Name: 189, dtype: float64
# mi            1.248319e-03
# sum_charge    4.874680e+09
# Name: 190, dtype: float64
# mi            1.248319e-03
# sum_charge    5.132304e+09
# Name: 191, dtype: float64
# mi            1.248319e-03
# sum_charge    5.153882e+09
# Name: 192, dtype: float64
# mi            1.248319e-03
# sum_charge    4.551182e+09
# Name: 193, dtype: float64
# mi            1.248319e-03
# sum_charge    5.629835e+09
# Name: 194, dtype: float64
# mi            1.248319e-03
# sum_charge    5.177163e+09
# Name: 195, dtype: float64
# mi            1.248319e-03
# sum_charge    5.276212e+09
# Name: 196, dtype: float64
# mi            1.248319e-03
# sum_charge    5.109683e+09
# Name: 197, dtype: float64
# mi            1.248319e-03
# sum_charge    5.588744e+09
# Name: 198, dtype: float64
# mi            1.248319e-03
# sum_charge    4.830708e+09
# Name: 199, dtype: float64
# mi            1.248319e-03
# sum_charge    5.592642e+09
# Name: 200, dtype: float64
# mi            1.248319e-03
# sum_charge    5.409516e+09
# Name: 201, dtype: float64
# mi            1.248319e-03
# sum_charge    5.240109e+09
# Name: 202, dtype: float64
# mi            1.248319e-03
# sum_charge    5.584221e+09
# Name: 203, dtype: float64
# mi            1.248319e-03
# sum_charge    5.238162e+09
# Name: 204, dtype: float64
# mi            1.248319e-03
# sum_charge    5.655732e+09
# Name: 205, dtype: float64
# mi            1.248319e-03
# sum_charge    5.244968e+09
# Name: 206, dtype: float64
# mi            1.248319e-03
# sum_charge    5.338023e+09
# Name: 207, dtype: float64
# mi            1.248319e-03
# sum_charge    5.467589e+09
# Name: 208, dtype: float64
# mi            1.248319e-03
# sum_charge    4.973882e+09
# Name: 209, dtype: float64
# mi            1.248319e-03
# sum_charge    5.769418e+09
# Name: 210, dtype: float64
# mi            1.248319e-03
# sum_charge    5.213881e+09
# Name: 211, dtype: float64
# mi            1.248319e-03
# sum_charge    4.979392e+09
# Name: 212, dtype: float64
# mi            1.248319e-03
# sum_charge    5.685091e+09
# Name: 213, dtype: float64
# mi            1.248319e-03
# sum_charge    4.796605e+09
# Name: 214, dtype: float64
# mi            1.248319e-03
# sum_charge    5.298107e+09
# Name: 215, dtype: float64
# mi            1.248319e-03
# sum_charge    5.163816e+09
# Name: 216, dtype: float64
# mi            1.248319e-03
# sum_charge    5.336658e+09
# Name: 217, dtype: float64
# mi            1.248319e-03
# sum_charge    4.843972e+09
# Name: 218, dtype: float64
# mi            1.248319e-03
# sum_charge    4.759098e+09
# Name: 219, dtype: float64
# mi            1.248319e-03
# sum_charge    5.547079e+09
# Name: 220, dtype: float64
# mi            1.248319e-03
# sum_charge    5.046439e+09
# Name: 221, dtype: float64
# mi            1.248319e-03
# sum_charge    5.388019e+09
# Name: 222, dtype: float64
# mi            1.248319e-03
# sum_charge    4.856481e+09
# Name: 223, dtype: float64
# mi            1.248319e-03
# sum_charge    4.839789e+09
# Name: 224, dtype: float64
# mi            1.248319e-03
# sum_charge    5.195524e+09
# Name: 225, dtype: float64
# mi            1.248319e-03
# sum_charge    5.410392e+09
# Name: 226, dtype: float64
# mi            1.248319e-03
# sum_charge    5.279714e+09
# Name: 227, dtype: float64
# mi            1.248319e-03
# sum_charge    5.212436e+09
# Name: 228, dtype: float64
# mi            1.248319e-03
# sum_charge    5.301066e+09
# Name: 229, dtype: float64
# mi            1.248319e-03
# sum_charge    5.128668e+09
# Name: 230, dtype: float64
# mi            1.248319e-03
# sum_charge    5.174611e+09
# Name: 231, dtype: float64
# mi            1.248319e-03
# sum_charge    5.178155e+09
# Name: 232, dtype: float64
# mi            1.248319e-03
# sum_charge    5.683655e+09
# Name: 233, dtype: float64
# mi            1.248319e-03
# sum_charge    5.112819e+09
# Name: 234, dtype: float64
# mi            1.248319e-03
# sum_charge    6.043305e+09
# Name: 235, dtype: float64
# mi            1.248319e-03
# sum_charge    4.562066e+09
# Name: 236, dtype: float64
# mi            1.248319e-03
# sum_charge    5.114281e+09
# Name: 237, dtype: float64
# mi            1.248319e-03
# sum_charge    4.985914e+09
# Name: 238, dtype: float64
# mi            1.248319e-03
# sum_charge    5.148697e+09
# Name: 239, dtype: float64
# mi            1.248319e-03
# sum_charge    5.165297e+09
# Name: 240, dtype: float64
# mi            1.248319e-03
# sum_charge    5.317809e+09
# Name: 241, dtype: float64
# mi            1.248319e-03
# sum_charge    5.183033e+09
# Name: 242, dtype: float64
# mi            1.248319e-03
# sum_charge    4.708198e+09
# Name: 243, dtype: float64
# mi            1.248319e-03
# sum_charge    5.321465e+09
# Name: 244, dtype: float64
# mi            1.248319e-03
# sum_charge    5.526788e+09
# Name: 245, dtype: float64
# mi            1.248319e-03
# sum_charge    5.107355e+09
# Name: 246, dtype: float64
# mi            1.248319e-03
# sum_charge    5.599929e+09
# Name: 247, dtype: float64
# mi            1.248319e-03
# sum_charge    5.614589e+09
# Name: 248, dtype: float64
# mi            1.248319e-03
# sum_charge    5.510054e+09
# Name: 249, dtype: float64
# mi            1.248319e-03
# sum_charge    5.279254e+09
# Name: 250, dtype: float64
# mi            1.248319e-03
# sum_charge    4.923445e+09
# Name: 251, dtype: float64
# mi            1.248319e-03
# sum_charge    5.143937e+09
# Name: 252, dtype: float64
# mi            1.248319e-03
# sum_charge    4.839430e+09
# Name: 253, dtype: float64
# mi            1.248319e-03
# sum_charge    4.946591e+09
# Name: 254, dtype: float64
# mi            1.248319e-03
# sum_charge    4.638591e+09
# Name: 255, dtype: float64
# mi            1.248319e-03
# sum_charge    5.173685e+09
# Name: 256, dtype: float64
# mi            1.248319e-03
# sum_charge    5.636211e+09
# Name: 257, dtype: float64
# mi            1.248319e-03
# sum_charge    5.429690e+09
# Name: 258, dtype: float64
# mi            1.248319e-03
# sum_charge    5.096567e+09
# Name: 259, dtype: float64
# mi            1.248319e-03
# sum_charge    5.528025e+09
# Name: 260, dtype: float64
# mi            1.248319e-03
# sum_charge    5.375281e+09
# Name: 261, dtype: float64
# mi            1.248319e-03
# sum_charge    5.919782e+09
# Name: 262, dtype: float64
# mi            1.248319e-03
# sum_charge    4.736826e+09
# Name: 263, dtype: float64
# mi            1.248319e-03
# sum_charge    5.591099e+09
# Name: 264, dtype: float64
# mi            1.248319e-03
# sum_charge    4.843790e+09
# Name: 265, dtype: float64
# mi            1.248319e-03
# sum_charge    4.776541e+09
# Name: 266, dtype: float64
# mi            1.248319e-03
# sum_charge    5.012477e+09
# Name: 267, dtype: float64
# mi            1.248319e-03
# sum_charge    5.273341e+09
# Name: 268, dtype: float64
# mi            1.248319e-03
# sum_charge    5.368415e+09
# Name: 269, dtype: float64
# mi            1.248319e-03
# sum_charge    5.665329e+09
# Name: 270, dtype: float64
# mi            1.248319e-03
# sum_charge    4.993159e+09
# Name: 271, dtype: float64
# mi            1.248319e-03
# sum_charge    5.449516e+09
# Name: 272, dtype: float64
# mi            1.248319e-03
# sum_charge    4.986784e+09
# Name: 273, dtype: float64
# mi            1.248319e-03
# sum_charge    5.612802e+09
# Name: 274, dtype: float64
# mi            1.248319e-03
# sum_charge    5.246281e+09
# Name: 275, dtype: float64
# mi            1.248319e-03
# sum_charge    5.239421e+09
# Name: 276, dtype: float64
# mi            1.248319e-03
# sum_charge    5.383418e+09
# Name: 277, dtype: float64
# mi            1.248319e-03
# sum_charge    4.776343e+09
# Name: 278, dtype: float64
# mi            1.248319e-03
# sum_charge    5.288954e+09
# Name: 279, dtype: float64
# mi            1.248319e-03
# sum_charge    5.790578e+09
# Name: 280, dtype: float64
# mi            1.248319e-03
# sum_charge    5.509803e+09
# Name: 281, dtype: float64
# mi            1.248319e-03
# sum_charge    5.262397e+09
# Name: 282, dtype: float64
# mi            1.248319e-03
# sum_charge    4.914750e+09
# Name: 283, dtype: float64
# mi            1.248319e-03
# sum_charge    5.386946e+09
# Name: 284, dtype: float64
# mi            1.248319e-03
# sum_charge    5.280024e+09
# Name: 285, dtype: float64
# mi            1.248319e-03
# sum_charge    5.134243e+09
# Name: 286, dtype: float64
# mi            1.248319e-03
# sum_charge    5.210454e+09
# Name: 287, dtype: float64
# mi            1.248319e-03
# sum_charge    5.018565e+09
# Name: 288, dtype: float64
# mi            1.248319e-03
# sum_charge    5.125425e+09
# Name: 289, dtype: float64
# mi            1.248319e-03
# sum_charge    5.709045e+09
# Name: 290, dtype: float64
# mi            1.248319e-03
# sum_charge    5.228317e+09
# Name: 291, dtype: float64
# mi            1.248319e-03
# sum_charge    5.301908e+09
# Name: 292, dtype: float64
# mi            1.248319e-03
# sum_charge    5.258184e+09
# Name: 293, dtype: float64
# mi            1.248319e-03
# sum_charge    5.628638e+09
# Name: 294, dtype: float64
# mi            1.248319e-03
# sum_charge    5.007999e+09
# Name: 295, dtype: float64
# mi            1.248319e-03
# sum_charge    5.282551e+09
# Name: 296, dtype: float64
# mi            1.248319e-03
# sum_charge    5.374631e+09
# Name: 297, dtype: float64
# mi            1.248319e-03
# sum_charge    5.024092e+09
# Name: 298, dtype: float64
# mi            1.248319e-03
# sum_charge    4.899917e+09
# Name: 299, dtype: float64
# mi            1.248319e-03
# sum_charge    5.770363e+09
# Name: 300, dtype: float64
# mi            1.248319e-03
# sum_charge    5.082899e+09
# Name: 301, dtype: float64
# mi            1.248319e-03
# sum_charge    4.876533e+09
# Name: 302, dtype: float64
# mi            1.248319e-03
# sum_charge    5.020748e+09
# Name: 303, dtype: float64
# mi            1.248319e-03
# sum_charge    5.300858e+09
# Name: 304, dtype: float64
# mi            1.248319e-03
# sum_charge    6.038666e+09
# Name: 305, dtype: float64
# mi            1.248319e-03
# sum_charge    5.493520e+09
# Name: 306, dtype: float64
# mi            1.248319e-03
# sum_charge    5.750408e+09
# Name: 307, dtype: float64
# mi            1.248319e-03
# sum_charge    5.420364e+09
# Name: 308, dtype: float64
# mi            1.248319e-03
# sum_charge    5.083928e+09
# Name: 309, dtype: float64
# mi            1.248319e-03
# sum_charge    5.326513e+09
# Name: 310, dtype: float64
# mi            1.248319e-03
# sum_charge    5.523955e+09
# Name: 311, dtype: float64
# mi            1.248319e-03
# sum_charge    4.831009e+09
# Name: 312, dtype: float64
# mi            1.248319e-03
# sum_charge    5.357730e+09
# Name: 313, dtype: float64
# mi            1.248319e-03
# sum_charge    5.312353e+09
# Name: 314, dtype: float64
# mi            1.248319e-03
# sum_charge    4.862443e+09
# Name: 315, dtype: float64
# mi            1.248319e-03
# sum_charge    5.362977e+09
# Name: 316, dtype: float64
# mi            1.248319e-03
# sum_charge    5.462117e+09
# Name: 317, dtype: float64
# mi            1.248319e-03
# sum_charge    5.327533e+09
# Name: 318, dtype: float64
# mi            1.248319e-03
# sum_charge    4.751723e+09
# Name: 319, dtype: float64
# mi            1.248319e-03
# sum_charge    4.827620e+09
# Name: 320, dtype: float64
# mi            1.248319e-03
# sum_charge    5.171140e+09
# Name: 321, dtype: float64
# mi            1.248319e-03
# sum_charge    5.681826e+09
# Name: 322, dtype: float64
# mi            1.248319e-03
# sum_charge    5.367565e+09
# Name: 323, dtype: float64
# mi            1.248319e-03
# sum_charge    5.380585e+09
# Name: 324, dtype: float64
# mi            1.248319e-03
# sum_charge    4.984663e+09
# Name: 325, dtype: float64
# mi            1.248319e-03
# sum_charge    5.145885e+09
# Name: 326, dtype: float64
# mi            1.248319e-03
# sum_charge    5.352437e+09
# Name: 327, dtype: float64
# mi            1.248319e-03
# sum_charge    4.852884e+09
# Name: 328, dtype: float64
# mi            1.248319e-03
# sum_charge    5.348063e+09
# Name: 329, dtype: float64
# mi            1.248319e-03
# sum_charge    5.471379e+09
# Name: 330, dtype: float64
# mi            1.248319e-03
# sum_charge    5.230474e+09
# Name: 331, dtype: float64
# mi            1.248319e-03
# sum_charge    5.371846e+09
# Name: 332, dtype: float64
# mi            1.248319e-03
# sum_charge    5.254350e+09
# Name: 333, dtype: float64
# mi            1.248319e-03
# sum_charge    4.672119e+09
# Name: 334, dtype: float64
# mi            1.248319e-03
# sum_charge    5.098952e+09
# Name: 335, dtype: float64
# mi            1.248319e-03
# sum_charge    5.164246e+09
# Name: 336, dtype: float64
# mi            1.248319e-03
# sum_charge    4.851320e+09
# Name: 337, dtype: float64
# mi            1.248319e-03
# sum_charge    4.748548e+09
# Name: 338, dtype: float64
# mi            1.248319e-03
# sum_charge    5.522514e+09
# Name: 339, dtype: float64
# mi            1.248319e-03
# sum_charge    5.386998e+09
# Name: 340, dtype: float64
# mi            1.248319e-03
# sum_charge    5.470351e+09
# Name: 341, dtype: float64
# mi            1.248319e-03
# sum_charge    4.608396e+09
# Name: 342, dtype: float64
# mi            1.248319e-03
# sum_charge    5.411917e+09
# Name: 343, dtype: float64
# mi            1.248319e-03
# sum_charge    5.422046e+09
# Name: 344, dtype: float64
# mi            1.248319e-03
# sum_charge    5.342033e+09
# Name: 345, dtype: float64
# mi            1.248319e-03
# sum_charge    5.227731e+09
# Name: 346, dtype: float64
# mi            1.248319e-03
# sum_charge    5.338460e+09
# Name: 347, dtype: float64
# mi            1.248319e-03
# sum_charge    5.756836e+09
# Name: 348, dtype: float64
# mi            1.248319e-03
# sum_charge    5.477686e+09
# Name: 349, dtype: float64
# mi            1.248319e-03
# sum_charge    5.567072e+09
# Name: 350, dtype: float64
# mi            1.248319e-03
# sum_charge    5.490343e+09
# Name: 351, dtype: float64
# mi            1.248319e-03
# sum_charge    4.838907e+09
# Name: 352, dtype: float64
# mi            1.248319e-03
# sum_charge    5.216519e+09
# Name: 353, dtype: float64
# mi            1.248319e-03
# sum_charge    5.664066e+09
# Name: 354, dtype: float64
# mi            1.248319e-03
# sum_charge    5.314053e+09
# Name: 355, dtype: float64
# mi            1.248319e-03
# sum_charge    5.119684e+09
# Name: 356, dtype: float64
# mi            1.248319e-03
# sum_charge    5.661892e+09
# Name: 357, dtype: float64
# mi            1.248319e-03
# sum_charge    5.264203e+09
# Name: 358, dtype: float64
# mi            1.248319e-03
# sum_charge    5.202353e+09
# Name: 359, dtype: float64
# mi            1.248319e-03
# sum_charge    4.780700e+09
# Name: 360, dtype: float64
# mi            1.248319e-03
# sum_charge    5.523672e+09
# Name: 361, dtype: float64
# mi            1.248319e-03
# sum_charge    4.930149e+09
# Name: 362, dtype: float64
# mi            1.248319e-03
# sum_charge    5.209771e+09
# Name: 363, dtype: float64
# mi            1.248319e-03
# sum_charge    6.064157e+09
# Name: 364, dtype: float64
# mi            1.248319e-03
# sum_charge    5.234296e+09
# Name: 365, dtype: float64
# mi            1.248319e-03
# sum_charge    4.734968e+09
# Name: 366, dtype: float64
# mi            1.248319e-03
# sum_charge    4.503820e+09
# Name: 367, dtype: float64
# mi            1.248319e-03
# sum_charge    5.715625e+09
# Name: 368, dtype: float64
# mi            1.248319e-03
# sum_charge    5.613965e+09
# Name: 369, dtype: float64
# mi            1.248319e-03
# sum_charge    5.587357e+09
# Name: 370, dtype: float64
# mi            1.248319e-03
# sum_charge    4.982967e+09
# Name: 371, dtype: float64
# mi            1.248319e-03
# sum_charge    5.152819e+09
# Name: 372, dtype: float64
# mi            1.248319e-03
# sum_charge    5.619452e+09
# Name: 373, dtype: float64
# mi            1.248319e-03
# sum_charge    4.687278e+09
# Name: 374, dtype: float64
# mi            1.248319e-03
# sum_charge    5.769388e+09
# Name: 375, dtype: float64
# mi            1.248319e-03
# sum_charge    5.502395e+09
# Name: 376, dtype: float64
# mi            1.248319e-03
# sum_charge    4.601216e+09
# Name: 377, dtype: float64
# mi            1.248319e-03
# sum_charge    5.020062e+09
# Name: 378, dtype: float64
# mi            1.248319e-03
# sum_charge    5.011282e+09
# Name: 379, dtype: float64
# mi            1.248319e-03
# sum_charge    5.300598e+09
# Name: 380, dtype: float64
# mi            1.248319e-03
# sum_charge    5.506629e+09
# Name: 381, dtype: float64
# mi            1.248319e-03
# sum_charge    5.399283e+09
# Name: 382, dtype: float64
# mi            1.248319e-03
# sum_charge    5.084347e+09
# Name: 383, dtype: float64
# mi            1.248319e-03
# sum_charge    5.510896e+09
# Name: 384, dtype: float64
# mi            1.248319e-03
# sum_charge    4.870935e+09
# Name: 385, dtype: float64
# mi            1.248319e-03
# sum_charge    5.342341e+09
# Name: 386, dtype: float64
# mi            1.248319e-03
# sum_charge    4.966791e+09
# Name: 387, dtype: float64
# mi            1.248319e-03
# sum_charge    5.654286e+09
# Name: 388, dtype: float64
# mi            1.248319e-03
# sum_charge    5.661804e+09
# Name: 389, dtype: float64
# mi            1.248319e-03
# sum_charge    5.396985e+09
# Name: 390, dtype: float64
# mi            1.248319e-03
# sum_charge    5.553777e+09
# Name: 391, dtype: float64
# mi            1.248319e-03
# sum_charge    5.016245e+09
# Name: 392, dtype: float64
# mi            1.248319e-03
# sum_charge    5.446095e+09
# Name: 393, dtype: float64
# mi            1.248319e-03
# sum_charge    5.318885e+09
# Name: 394, dtype: float64
# mi            1.248319e-03
# sum_charge    4.857712e+09
# Name: 395, dtype: float64
# mi            1.248319e-03
# sum_charge    5.614792e+09
# Name: 396, dtype: float64
# mi            1.248319e-03
# sum_charge    5.129181e+09
# Name: 397, dtype: float64
# mi            1.248319e-03
# sum_charge    4.639831e+09
# Name: 398, dtype: float64
# mi            1.248319e-03
# sum_charge    5.149258e+09
# Name: 399, dtype: float64
# mi            1.248319e-03
# sum_charge    5.202650e+09
# Name: 400, dtype: float64
# mi            1.248319e-03
# sum_charge    5.386356e+09
# Name: 401, dtype: float64
# mi            1.248319e-03
# sum_charge    5.450139e+09
# Name: 402, dtype: float64
# mi            1.248319e-03
# sum_charge    5.382873e+09
# Name: 403, dtype: float64
# mi            1.248319e-03
# sum_charge    5.571886e+09
# Name: 404, dtype: float64
# mi            1.248319e-03
# sum_charge    5.278858e+09
# Name: 405, dtype: float64
# mi            1.248319e-03
# sum_charge    5.109793e+09
# Name: 406, dtype: float64
# mi            1.248319e-03
# sum_charge    5.018845e+09
# Name: 407, dtype: float64
# mi            1.248319e-03
# sum_charge    5.147027e+09
# Name: 408, dtype: float64
# mi            1.248319e-03
# sum_charge    4.689331e+09
# Name: 409, dtype: float64
# mi            1.248319e-03
# sum_charge    4.795191e+09
# Name: 410, dtype: float64
# mi            1.248319e-03
# sum_charge    5.563233e+09
# Name: 411, dtype: float64
# mi            1.248319e-03
# sum_charge    5.312304e+09
# Name: 412, dtype: float64
# mi            1.248319e-03
# sum_charge    4.681330e+09
# Name: 413, dtype: float64
# mi            1.248319e-03
# sum_charge    5.045072e+09
# Name: 414, dtype: float64
# mi            1.248319e-03
# sum_charge    4.609248e+09
# Name: 415, dtype: float64
# mi            1.248319e-03
# sum_charge    5.272616e+09
# Name: 416, dtype: float64
# mi            1.248319e-03
# sum_charge    5.602567e+09
# Name: 417, dtype: float64
# mi            1.248319e-03
# sum_charge    5.392550e+09
# Name: 418, dtype: float64
# mi            1.248319e-03
# sum_charge    5.687521e+09
# Name: 419, dtype: float64
# mi            1.248319e-03
# sum_charge    5.370934e+09
# Name: 420, dtype: float64
# mi            1.248319e-03
# sum_charge    4.862946e+09
# Name: 421, dtype: float64
# mi            1.248319e-03
# sum_charge    5.332784e+09
# Name: 422, dtype: float64
# mi            1.248319e-03
# sum_charge    5.083153e+09
# Name: 423, dtype: float64
# mi            1.248319e-03
# sum_charge    4.900755e+09
# Name: 424, dtype: float64
# mi            1.248319e-03
# sum_charge    5.425573e+09
# Name: 425, dtype: float64
# mi            1.248319e-03
# sum_charge    4.972795e+09
# Name: 426, dtype: float64
# mi            1.248319e-03
# sum_charge    5.207533e+09
# Name: 427, dtype: float64
# mi            1.248319e-03
# sum_charge    4.813464e+09
# Name: 428, dtype: float64
# mi            1.248319e-03
# sum_charge    5.155920e+09
# Name: 429, dtype: float64
# mi            1.248319e-03
# sum_charge    5.650218e+09
# Name: 430, dtype: float64
# mi            1.248319e-03
# sum_charge    5.603983e+09
# Name: 431, dtype: float64
# mi            1.248319e-03
# sum_charge    5.145155e+09
# Name: 432, dtype: float64
# mi            1.248319e-03
# sum_charge    5.483635e+09
# Name: 433, dtype: float64
# mi            1.248319e-03
# sum_charge    5.551121e+09
# Name: 434, dtype: float64
# mi            1.248319e-03
# sum_charge    4.927702e+09
# Name: 435, dtype: float64
# mi            1.248319e-03
# sum_charge    5.036027e+09
# Name: 436, dtype: float64
# mi            1.248319e-03
# sum_charge    5.619541e+09
# Name: 437, dtype: float64
# mi            1.248319e-03
# sum_charge    4.766472e+09
# Name: 438, dtype: float64
# mi            1.248319e-03
# sum_charge    5.134878e+09
# Name: 439, dtype: float64
# mi            1.248319e-03
# sum_charge    4.987323e+09
# Name: 440, dtype: float64
# mi            1.248319e-03
# sum_charge    4.887104e+09
# Name: 441, dtype: float64
# mi            1.248319e-03
# sum_charge    5.481812e+09
# Name: 442, dtype: float64
# mi            1.248319e-03
# sum_charge    5.108132e+09
# Name: 443, dtype: float64
# mi            1.248319e-03
# sum_charge    5.142459e+09
# Name: 444, dtype: float64
# mi            1.248319e-03
# sum_charge    5.367316e+09
# Name: 445, dtype: float64
# mi            1.248319e-03
# sum_charge    5.376676e+09
# Name: 446, dtype: float64
# mi            1.248319e-03
# sum_charge    5.056307e+09
# Name: 447, dtype: float64
# mi            1.248319e-03
# sum_charge    4.903649e+09
# Name: 448, dtype: float64
# mi            1.248319e-03
# sum_charge    5.252461e+09
# Name: 449, dtype: float64
# mi            1.248319e-03
# sum_charge    5.805881e+09
# Name: 450, dtype: float64
# mi            1.248319e-03
# sum_charge    5.790635e+09
# Name: 451, dtype: float64
# mi            1.248319e-03
# sum_charge    5.294311e+09
# Name: 452, dtype: float64
# mi            1.248319e-03
# sum_charge    4.801939e+09
# Name: 453, dtype: float64
# mi            1.248319e-03
# sum_charge    5.650969e+09
# Name: 454, dtype: float64
# mi            1.248319e-03
# sum_charge    5.088698e+09
# Name: 455, dtype: float64
# mi            1.248319e-03
# sum_charge    4.945494e+09
# Name: 456, dtype: float64
# mi            1.248319e-03
# sum_charge    4.817148e+09
# Name: 457, dtype: float64
# mi            1.248319e-03
# sum_charge    5.148682e+09
# Name: 458, dtype: float64
# mi            1.248319e-03
# sum_charge    5.584740e+09
# Name: 459, dtype: float64
# mi            1.248319e-03
# sum_charge    5.165150e+09
# Name: 460, dtype: float64
# mi            1.248319e-03
# sum_charge    4.399442e+09
# Name: 461, dtype: float64
# mi            1.248319e-03
# sum_charge    4.530296e+09
# Name: 462, dtype: float64
# mi            1.248319e-03
# sum_charge    5.901753e+09
# Name: 463, dtype: float64
# mi            1.248319e-03
# sum_charge    4.965350e+09
# Name: 464, dtype: float64
# mi            1.248319e-03
# sum_charge    4.777344e+09
# Name: 465, dtype: float64
# mi            1.248319e-03
# sum_charge    5.507059e+09
# Name: 466, dtype: float64
# mi            1.248319e-03
# sum_charge    4.739491e+09
# Name: 467, dtype: float64
# mi            1.248319e-03
# sum_charge    5.281748e+09
# Name: 468, dtype: float64
# mi            1.248319e-03
# sum_charge    4.385724e+09
# Name: 469, dtype: float64
# mi            1.248319e-03
# sum_charge    5.523872e+09
# Name: 470, dtype: float64
# mi            1.248319e-03
# sum_charge    5.336636e+09
# Name: 471, dtype: float64
# mi            1.248319e-03
# sum_charge    5.137103e+09
# Name: 472, dtype: float64
# mi            1.248319e-03
# sum_charge    5.545306e+09
# Name: 473, dtype: float64
# mi            1.248319e-03
# sum_charge    5.047115e+09
# Name: 474, dtype: float64
# mi            1.248319e-03
# sum_charge    5.237531e+09
# Name: 475, dtype: float64
# mi            1.248319e-03
# sum_charge    4.996125e+09
# Name: 476, dtype: float64
# mi            1.248319e-03
# sum_charge    5.403012e+09
# Name: 477, dtype: float64
# mi            1.248319e-03
# sum_charge    5.237075e+09
# Name: 478, dtype: float64
# mi            1.248319e-03
# sum_charge    4.851209e+09
# Name: 479, dtype: float64
# mi            1.248319e-03
# sum_charge    4.838428e+09
# Name: 480, dtype: float64
# mi            1.248319e-03
# sum_charge    5.171944e+09
# Name: 481, dtype: float64
# mi            1.248319e-03
# sum_charge    5.003785e+09
# Name: 482, dtype: float64
# mi            1.248319e-03
# sum_charge    5.275415e+09
# Name: 483, dtype: float64
# mi            1.248319e-03
# sum_charge    5.232312e+09
# Name: 484, dtype: float64
# mi            1.248319e-03
# sum_charge    4.924076e+09
# Name: 485, dtype: float64
# mi            1.248319e-03
# sum_charge    5.683388e+09
# Name: 486, dtype: float64
# mi            1.248319e-03
# sum_charge    5.628529e+09
# Name: 487, dtype: float64
# mi            1.248319e-03
# sum_charge    4.843179e+09
# Name: 488, dtype: float64
# mi            1.248319e-03
# sum_charge    5.351724e+09
# Name: 489, dtype: float64
# mi            1.248319e-03
# sum_charge    4.909732e+09
# Name: 490, dtype: float64
# mi            1.248319e-03
# sum_charge    5.426339e+09
# Name: 491, dtype: float64
# mi            1.248319e-03
# sum_charge    5.618018e+09
# Name: 492, dtype: float64
# mi            1.248319e-03
# sum_charge    5.210888e+09
# Name: 493, dtype: float64
# mi            1.248319e-03
# sum_charge    5.359541e+09
# Name: 494, dtype: float64
# mi            1.248319e-03
# sum_charge    5.194802e+09
# Name: 495, dtype: float64
# mi            1.248319e-03
# sum_charge    5.144122e+09
# Name: 496, dtype: float64
# mi            1.248319e-03
# sum_charge    5.470611e+09
# Name: 497, dtype: float64
# mi            1.248319e-03
# sum_charge    5.565608e+09
# Name: 498, dtype: float64
# mi            1.248319e-03
# sum_charge    4.929684e+09
# Name: 499, dtype: float64
# mi            1.248319e-03
# sum_charge    5.040199e+09
# Name: 500, dtype: float64
# mi            1.248319e-03
# sum_charge    5.402539e+09
# Name: 501, dtype: float64
# mi            1.248319e-03
# sum_charge    5.065402e+09
# Name: 502, dtype: float64
# mi            1.248319e-03
# sum_charge    5.717462e+09
# Name: 503, dtype: float64
# mi            1.248319e-03
# sum_charge    4.681583e+09
# Name: 504, dtype: float64
# mi            1.248319e-03
# sum_charge    5.261979e+09
# Name: 505, dtype: float64
# mi            1.248319e-03
# sum_charge    4.946768e+09
# Name: 506, dtype: float64
# mi            1.248319e-03
# sum_charge    5.372849e+09
# Name: 507, dtype: float64
# mi            1.248319e-03
# sum_charge    5.396381e+09
# Name: 508, dtype: float64
# mi            1.248319e-03
# sum_charge    4.834148e+09
# Name: 509, dtype: float64
# mi            1.248319e-03
# sum_charge    5.643011e+09
# Name: 510, dtype: float64
# mi            1.248319e-03
# sum_charge    5.488390e+09
# Name: 511, dtype: float64
# mi            1.248319e-03
# sum_charge    5.140787e+09
# Name: 512, dtype: float64
# mi            1.248319e-03
# sum_charge    5.526667e+09
# Name: 513, dtype: float64
# mi            1.248319e-03
# sum_charge    4.673111e+09
# Name: 514, dtype: float64
# mi            1.248319e-03
# sum_charge    5.011532e+09
# Name: 515, dtype: float64
# mi            1.248319e-03
# sum_charge    5.080643e+09
# Name: 516, dtype: float64
# mi            1.248319e-03
# sum_charge    6.010641e+09
# Name: 517, dtype: float64
# mi            1.248319e-03
# sum_charge    4.898882e+09
# Name: 518, dtype: float64
# mi            1.248319e-03
# sum_charge    5.250876e+09
# Name: 519, dtype: float64
# mi            1.248319e-03
# sum_charge    5.227023e+09
# Name: 520, dtype: float64
# mi            1.248319e-03
# sum_charge    5.359894e+09
# Name: 521, dtype: float64
# mi            1.248319e-03
# sum_charge    5.338632e+09
# Name: 522, dtype: float64
# mi            1.248319e-03
# sum_charge    5.738677e+09
# Name: 523, dtype: float64
# mi            1.248319e-03
# sum_charge    5.088787e+09
# Name: 524, dtype: float64
# mi            1.248319e-03
# sum_charge    4.831346e+09
# Name: 525, dtype: float64
# mi            1.248319e-03
# sum_charge    5.035201e+09
# Name: 526, dtype: float64
# mi            1.248319e-03
# sum_charge    6.025758e+09
# Name: 527, dtype: float64
# mi            1.248319e-03
# sum_charge    5.758369e+09
# Name: 528, dtype: float64
# mi            1.248319e-03
# sum_charge    5.200202e+09
# Name: 529, dtype: float64
# mi            1.248319e-03
# sum_charge    5.318446e+09
# Name: 530, dtype: float64
# mi            1.248319e-03
# sum_charge    4.727824e+09
# Name: 531, dtype: float64
# mi            1.248319e-03
# sum_charge    5.702171e+09
# Name: 532, dtype: float64
# mi            1.248319e-03
# sum_charge    5.361782e+09
# Name: 533, dtype: float64
# mi            1.248319e-03
# sum_charge    4.945933e+09
# Name: 534, dtype: float64
# mi            1.248319e-03
# sum_charge    5.381868e+09
# Name: 535, dtype: float64
# mi            1.248319e-03
# sum_charge    5.454794e+09
# Name: 536, dtype: float64
# mi            1.248319e-03
# sum_charge    4.578993e+09
# Name: 537, dtype: float64
# mi            1.248319e-03
# sum_charge    4.743726e+09
# Name: 538, dtype: float64
# mi            1.248319e-03
# sum_charge    5.588346e+09
# Name: 539, dtype: float64
# mi            1.248319e-03
# sum_charge    4.933494e+09
# Name: 540, dtype: float64
# mi            1.248319e-03
# sum_charge    5.077215e+09
# Name: 541, dtype: float64
# mi            1.248319e-03
# sum_charge    5.092508e+09
# Name: 542, dtype: float64
# mi            1.248319e-03
# sum_charge    5.921714e+09
# Name: 543, dtype: float64
# mi            1.248319e-03
# sum_charge    4.618345e+09
# Name: 544, dtype: float64
# mi            1.248319e-03
# sum_charge    5.381481e+09
# Name: 545, dtype: float64
# mi            1.248319e-03
# sum_charge    4.725908e+09
# Name: 546, dtype: float64
# mi            1.248319e-03
# sum_charge    5.431935e+09
# Name: 547, dtype: float64
# mi            1.248319e-03
# sum_charge    5.158639e+09
# Name: 548, dtype: float64
# mi            1.248319e-03
# sum_charge    5.771634e+09
# Name: 549, dtype: float64
# mi            1.248319e-03
# sum_charge    5.494711e+09
# Name: 550, dtype: float64
# mi            1.248319e-03
# sum_charge    5.467908e+09
# Name: 551, dtype: float64
# mi            1.248319e-03
# sum_charge    4.517662e+09
# Name: 552, dtype: float64
# mi            1.248319e-03
# sum_charge    5.291847e+09
# Name: 553, dtype: float64
# mi            1.248319e-03
# sum_charge    5.289105e+09
# Name: 554, dtype: float64
# mi            1.248319e-03
# sum_charge    4.991701e+09
# Name: 555, dtype: float64
# mi            1.248319e-03
# sum_charge    4.912966e+09
# Name: 556, dtype: float64
# mi            1.248319e-03
# sum_charge    5.221206e+09
# Name: 557, dtype: float64
# mi            1.248319e-03
# sum_charge    4.589614e+09
# Name: 558, dtype: float64
# mi            1.248319e-03
# sum_charge    5.229999e+09
# Name: 559, dtype: float64
# mi            1.248319e-03
# sum_charge    5.137010e+09
# Name: 560, dtype: float64
# mi            1.248319e-03
# sum_charge    5.254816e+09
# Name: 561, dtype: float64
# mi            1.248319e-03
# sum_charge    5.437671e+09
# Name: 562, dtype: float64
# mi            1.248319e-03
# sum_charge    4.831211e+09
# Name: 563, dtype: float64
# mi            1.248319e-03
# sum_charge    5.270515e+09
# Name: 564, dtype: float64
# mi            1.248319e-03
# sum_charge    5.129109e+09
# Name: 565, dtype: float64
# mi            1.248319e-03
# sum_charge    4.666792e+09
# Name: 566, dtype: float64
# mi            1.248319e-03
# sum_charge    4.678526e+09
# Name: 567, dtype: float64
# mi            1.248319e-03
# sum_charge    5.774878e+09
# Name: 568, dtype: float64
# mi            1.248319e-03
# sum_charge    4.947725e+09
# Name: 569, dtype: float64
# mi            1.248319e-03
# sum_charge    5.215906e+09
# Name: 570, dtype: float64
# mi            1.248319e-03
# sum_charge    5.712502e+09
# Name: 571, dtype: float64
# mi            1.248319e-03
# sum_charge    4.949239e+09
# Name: 572, dtype: float64
# mi            1.248319e-03
# sum_charge    5.029952e+09
# Name: 573, dtype: float64
# mi            1.248319e-03
# sum_charge    5.116020e+09
# Name: 574, dtype: float64
# mi            1.248319e-03
# sum_charge    5.469226e+09
# Name: 575, dtype: float64
# mi            1.248319e-03
# sum_charge    5.158459e+09
# Name: 576, dtype: float64
# mi            1.248319e-03
# sum_charge    5.092697e+09
# Name: 577, dtype: float64
# mi            1.248319e-03
# sum_charge    5.455112e+09
# Name: 578, dtype: float64
# mi            1.248319e-03
# sum_charge    5.075123e+09
# Name: 579, dtype: float64
# mi            1.248319e-03
# sum_charge    5.013629e+09
# Name: 580, dtype: float64
# mi            1.248319e-03
# sum_charge    5.404764e+09
# Name: 581, dtype: float64
# mi            1.248319e-03
# sum_charge    5.799683e+09
# Name: 582, dtype: float64
# mi            1.248319e-03
# sum_charge    5.598371e+09
# Name: 583, dtype: float64
# mi            1.248319e-03
# sum_charge    5.781894e+09
# Name: 584, dtype: float64
# mi            1.248319e-03
# sum_charge    5.206824e+09
# Name: 585, dtype: float64
# mi            1.248319e-03
# sum_charge    4.862221e+09
# Name: 586, dtype: float64
# mi            1.248319e-03
# sum_charge    5.549769e+09
# Name: 587, dtype: float64
# mi            1.248319e-03
# sum_charge    5.183801e+09
# Name: 588, dtype: float64
# mi            1.248319e-03
# sum_charge    5.203864e+09
# Name: 589, dtype: float64
# mi            1.248319e-03
# sum_charge    5.499252e+09
# Name: 590, dtype: float64
# mi            1.248319e-03
# sum_charge    5.313495e+09
# Name: 591, dtype: float64
# mi            1.248319e-03
# sum_charge    5.688073e+09
# Name: 592, dtype: float64
# mi            1.248319e-03
# sum_charge    5.014614e+09
# Name: 593, dtype: float64
# mi            1.248319e-03
# sum_charge    5.137031e+09
# Name: 594, dtype: float64
# mi            1.248319e-03
# sum_charge    5.172342e+09
# Name: 595, dtype: float64
# mi            1.248319e-03
# sum_charge    5.077426e+09
# Name: 596, dtype: float64
# mi            1.248319e-03
# sum_charge    4.743893e+09
# Name: 597, dtype: float64
# mi            1.248319e-03
# sum_charge    5.127687e+09
# Name: 598, dtype: float64
# mi            1.248319e-03
# sum_charge    5.728816e+09
# Name: 599, dtype: float64
# mi            1.248319e-03
# sum_charge    5.062020e+09
# Name: 600, dtype: float64
# mi            1.248319e-03
# ...
# sum_charge    5.255831e+09
# Name: 8813, dtype: float64
# mi            1.600000e+01
# sum_charge    5.253334e+09
# Name: 8814, dtype: float64
# mi            1.600000e+01
# sum_charge    5.284043e+09
# Name: 8815, dtype: float64
# mi            1.600000e+01
# sum_charge    5.280098e+09
# Name: 8816, dtype: float64
# mi            1.600000e+01
# sum_charge    5.267769e+09
# Name: 8817, dtype: float64
# mi            1.600000e+01
# sum_charge    5.250829e+09
# Name: 8818, dtype: float64
# mi            1.600000e+01
# sum_charge    5.246685e+09
# Name: 8819, dtype: float64
# mi            1.600000e+01
# sum_charge    5.255143e+09
# Name: 8820, dtype: float64
# mi            1.600000e+01
# sum_charge    5.272175e+09
# Name: 8821, dtype: float64
# mi            1.600000e+01
# sum_charge    5.274701e+09
# Name: 8822, dtype: float64
# mi            1.600000e+01
# sum_charge    5.237289e+09
# Name: 8823, dtype: float64
# mi            1.600000e+01
# sum_charge    5.242730e+09
# Name: 8824, dtype: float64
# mi            1.600000e+01
# sum_charge    5.265352e+09
# Name: 8825, dtype: float64
# mi            1.600000e+01
# sum_charge    5.248923e+09
# Name: 8826, dtype: float64
# mi            1.600000e+01
# sum_charge    5.256755e+09
# Name: 8827, dtype: float64
# mi            1.600000e+01
# sum_charge    5.257709e+09
# Name: 8828, dtype: float64
# mi            1.600000e+01
# sum_charge    5.268325e+09
# Name: 8829, dtype: float64
# mi            1.600000e+01
# sum_charge    5.248672e+09
# Name: 8830, dtype: float64
# mi            1.600000e+01
# sum_charge    5.223757e+09
# Name: 8831, dtype: float64
# mi            1.600000e+01
# sum_charge    5.230029e+09
# Name: 8832, dtype: float64
# mi            1.600000e+01
# sum_charge    5.235051e+09
# Name: 8833, dtype: float64
# mi            1.600000e+01
# sum_charge    5.225599e+09
# Name: 8834, dtype: float64
# mi            1.600000e+01
# sum_charge    5.244465e+09
# Name: 8835, dtype: float64
# mi            1.600000e+01
# sum_charge    5.247442e+09
# Name: 8836, dtype: float64
# mi            1.600000e+01
# sum_charge    5.255693e+09
# Name: 8837, dtype: float64
# mi            1.600000e+01
# sum_charge    5.216069e+09
# Name: 8838, dtype: float64
# mi            1.600000e+01
# sum_charge    5.251463e+09
# Name: 8839, dtype: float64
# mi            1.600000e+01
# sum_charge    5.260665e+09
# Name: 8840, dtype: float64
# mi            1.600000e+01
# sum_charge    5.260783e+09
# Name: 8841, dtype: float64
# mi            1.600000e+01
# sum_charge    5.265299e+09
# Name: 8842, dtype: float64
# mi            1.600000e+01
# sum_charge    5.231756e+09
# Name: 8843, dtype: float64
# mi            1.600000e+01
# sum_charge    5.264675e+09
# Name: 8844, dtype: float64
# mi            1.600000e+01
# sum_charge    5.248373e+09
# Name: 8845, dtype: float64
# mi            1.600000e+01
# sum_charge    5.269072e+09
# Name: 8846, dtype: float64
# mi            1.600000e+01
# sum_charge    5.262584e+09
# Name: 8847, dtype: float64
# mi            1.600000e+01
# sum_charge    5.285492e+09
# Name: 8848, dtype: float64
# mi            1.600000e+01
# sum_charge    5.287562e+09
# Name: 8849, dtype: float64
# mi            1.600000e+01
# sum_charge    5.219877e+09
# Name: 8850, dtype: float64
# mi            1.600000e+01
# sum_charge    5.261794e+09
# Name: 8851, dtype: float64
# mi            1.600000e+01
# sum_charge    5.257689e+09
# Name: 8852, dtype: float64
# mi            1.600000e+01
# sum_charge    5.249379e+09
# Name: 8853, dtype: float64
# mi            1.600000e+01
# sum_charge    5.277108e+09
# Name: 8854, dtype: float64
# mi            1.600000e+01
# sum_charge    5.259203e+09
# Name: 8855, dtype: float64
# mi            1.600000e+01
# sum_charge    5.282843e+09
# Name: 8856, dtype: float64
# mi            1.600000e+01
# sum_charge    5.261823e+09
# Name: 8857, dtype: float64
# mi            1.600000e+01
# sum_charge    5.272913e+09
# Name: 8858, dtype: float64
# mi            1.600000e+01
# sum_charge    5.234769e+09
# Name: 8859, dtype: float64
# mi            1.600000e+01
# sum_charge    5.264736e+09
# Name: 8860, dtype: float64
# mi            1.600000e+01
# sum_charge    5.256850e+09
# Name: 8861, dtype: float64
# mi            1.600000e+01
# sum_charge    5.222023e+09
# Name: 8862, dtype: float64
# mi            1.600000e+01
# sum_charge    5.267252e+09
# Name: 8863, dtype: float64
# mi            1.600000e+01
# sum_charge    5.231859e+09
# Name: 8864, dtype: float64
# mi            1.600000e+01
# sum_charge    5.222742e+09
# Name: 8865, dtype: float64
# mi            1.600000e+01
# sum_charge    5.246248e+09
# Name: 8866, dtype: float64
# mi            1.600000e+01
# sum_charge    5.249041e+09
# Name: 8867, dtype: float64
# mi            1.600000e+01
# sum_charge    5.260230e+09
# Name: 8868, dtype: float64
# mi            1.600000e+01
# sum_charge    5.272173e+09
# Name: 8869, dtype: float64
# mi            1.600000e+01
# sum_charge    5.259024e+09
# Name: 8870, dtype: float64
# mi            1.600000e+01
# sum_charge    5.255804e+09
# Name: 8871, dtype: float64
# mi            1.600000e+01
# sum_charge    5.262425e+09
# Name: 8872, dtype: float64
# mi            1.600000e+01
# sum_charge    5.216564e+09
# Name: 8873, dtype: float64
# mi            1.600000e+01
# sum_charge    5.245325e+09
# Name: 8874, dtype: float64
# mi            1.600000e+01
# sum_charge    5.254353e+09
# Name: 8875, dtype: float64
# mi            1.600000e+01
# sum_charge    5.278848e+09
# Name: 8876, dtype: float64
# mi            1.600000e+01
# sum_charge    5.305552e+09
# Name: 8877, dtype: float64
# mi            1.600000e+01
# sum_charge    5.259409e+09
# Name: 8878, dtype: float64
# mi            1.600000e+01
# sum_charge    5.263503e+09
# Name: 8879, dtype: float64
# mi            1.600000e+01
# sum_charge    5.256429e+09
# Name: 8880, dtype: float64
# mi            1.600000e+01
# sum_charge    5.238500e+09
# Name: 8881, dtype: float64
# mi            1.600000e+01
# sum_charge    5.270328e+09
# Name: 8882, dtype: float64
# mi            1.600000e+01
# sum_charge    5.248921e+09
# Name: 8883, dtype: float64
# mi            1.600000e+01
# sum_charge    5.243557e+09
# Name: 8884, dtype: float64
# mi            1.600000e+01
# sum_charge    5.252389e+09
# Name: 8885, dtype: float64
# mi            1.600000e+01
# sum_charge    5.245647e+09
# Name: 8886, dtype: float64
# mi            1.600000e+01
# sum_charge    5.247546e+09
# Name: 8887, dtype: float64
# mi            1.600000e+01
# sum_charge    5.281067e+09
# Name: 8888, dtype: float64
# mi            1.600000e+01
# sum_charge    5.249804e+09
# Name: 8889, dtype: float64
# mi            1.600000e+01
# sum_charge    5.253995e+09
# Name: 8890, dtype: float64
# mi            1.600000e+01
# sum_charge    5.252676e+09
# Name: 8891, dtype: float64
# mi            1.600000e+01
# sum_charge    5.251563e+09
# Name: 8892, dtype: float64
# mi            1.600000e+01
# sum_charge    5.234455e+09
# Name: 8893, dtype: float64
# mi            1.600000e+01
# sum_charge    5.299467e+09
# Name: 8894, dtype: float64
# mi            1.600000e+01
# sum_charge    5.238221e+09
# Name: 8895, dtype: float64
# mi            1.600000e+01
# sum_charge    5.270564e+09
# Name: 8896, dtype: float64
# mi            1.600000e+01
# sum_charge    5.269261e+09
# Name: 8897, dtype: float64
# mi            1.600000e+01
# sum_charge    5.236661e+09
# Name: 8898, dtype: float64
# mi            1.600000e+01
# sum_charge    5.262387e+09
# Name: 8899, dtype: float64
# mi            1.600000e+01
# sum_charge    5.258271e+09
# Name: 8900, dtype: float64
# mi            1.600000e+01
# sum_charge    5.261655e+09
# Name: 8901, dtype: float64
# mi            1.600000e+01
# sum_charge    5.258418e+09
# Name: 8902, dtype: float64
# mi            1.600000e+01
# sum_charge    5.297452e+09
# Name: 8903, dtype: float64
# mi            1.600000e+01
# sum_charge    5.247366e+09
# Name: 8904, dtype: float64
# mi            1.600000e+01
# sum_charge    5.250088e+09
# Name: 8905, dtype: float64
# mi            1.600000e+01
# sum_charge    5.245960e+09
# Name: 8906, dtype: float64
# mi            1.600000e+01
# sum_charge    5.267654e+09
# Name: 8907, dtype: float64
# mi            1.600000e+01
# sum_charge    5.250065e+09
# Name: 8908, dtype: float64
# mi            1.600000e+01
# sum_charge    5.287468e+09
# Name: 8909, dtype: float64
# mi            1.600000e+01
# sum_charge    5.260221e+09
# Name: 8910, dtype: float64
# mi            1.600000e+01
# sum_charge    5.274775e+09
# Name: 8911, dtype: float64
# mi            1.600000e+01
# sum_charge    5.259109e+09
# Name: 8912, dtype: float64
# mi            1.600000e+01
# sum_charge    5.290290e+09
# Name: 8913, dtype: float64
# mi            1.600000e+01
# sum_charge    5.255408e+09
# Name: 8914, dtype: float64
# mi            1.600000e+01
# sum_charge    5.263248e+09
# Name: 8915, dtype: float64
# mi            1.600000e+01
# sum_charge    5.284279e+09
# Name: 8916, dtype: float64
# mi            1.600000e+01
# sum_charge    5.268434e+09
# Name: 8917, dtype: float64
# mi            1.600000e+01
# sum_charge    5.255842e+09
# Name: 8918, dtype: float64
# mi            1.600000e+01
# sum_charge    5.216639e+09
# Name: 8919, dtype: float64
# mi            1.600000e+01
# sum_charge    5.273344e+09
# Name: 8920, dtype: float64
# mi            1.600000e+01
# sum_charge    5.222952e+09
# Name: 8921, dtype: float64
# mi            1.600000e+01
# sum_charge    5.289013e+09
# Name: 8922, dtype: float64
# mi            1.600000e+01
# sum_charge    5.237743e+09
# Name: 8923, dtype: float64
# mi            1.600000e+01
# sum_charge    5.241390e+09
# Name: 8924, dtype: float64
# mi            1.600000e+01
# sum_charge    5.263502e+09
# Name: 8925, dtype: float64
# mi            1.600000e+01
# sum_charge    5.259445e+09
# Name: 8926, dtype: float64
# mi            1.600000e+01
# sum_charge    5.265268e+09
# Name: 8927, dtype: float64
# mi            1.600000e+01
# sum_charge    5.257779e+09
# Name: 8928, dtype: float64
# mi            1.600000e+01
# sum_charge    5.268495e+09
# Name: 8929, dtype: float64
# mi            1.600000e+01
# sum_charge    5.252369e+09
# Name: 8930, dtype: float64
# mi            1.600000e+01
# sum_charge    5.272927e+09
# Name: 8931, dtype: float64
# mi            1.600000e+01
# sum_charge    5.240425e+09
# Name: 8932, dtype: float64
# mi            1.600000e+01
# sum_charge    5.235929e+09
# Name: 8933, dtype: float64
# mi            1.600000e+01
# sum_charge    5.247476e+09
# Name: 8934, dtype: float64
# mi            1.600000e+01
# sum_charge    5.262394e+09
# Name: 8935, dtype: float64
# mi            1.600000e+01
# sum_charge    5.262745e+09
# Name: 8936, dtype: float64
# mi            1.600000e+01
# sum_charge    5.270862e+09
# Name: 8937, dtype: float64
# mi            1.600000e+01
# sum_charge    5.226350e+09
# Name: 8938, dtype: float64
# mi            1.600000e+01
# sum_charge    5.271735e+09
# Name: 8939, dtype: float64
# mi            1.600000e+01
# sum_charge    5.276370e+09
# Name: 8940, dtype: float64
# mi            1.600000e+01
# sum_charge    5.281576e+09
# Name: 8941, dtype: float64
# mi            1.600000e+01
# sum_charge    5.257529e+09
# Name: 8942, dtype: float64
# mi            1.600000e+01
# sum_charge    5.241239e+09
# Name: 8943, dtype: float64
# mi            1.600000e+01
# sum_charge    5.280281e+09
# Name: 8944, dtype: float64
# mi            1.600000e+01
# sum_charge    5.273935e+09
# Name: 8945, dtype: float64
# mi            1.600000e+01
# sum_charge    5.241606e+09
# Name: 8946, dtype: float64
# mi            1.600000e+01
# sum_charge    5.272748e+09
# Name: 8947, dtype: float64
# mi            1.600000e+01
# sum_charge    5.277321e+09
# Name: 8948, dtype: float64
# mi            1.600000e+01
# sum_charge    5.285950e+09
# Name: 8949, dtype: float64
# mi            1.600000e+01
# sum_charge    5.235104e+09
# Name: 8950, dtype: float64
# mi            1.600000e+01
# sum_charge    5.274656e+09
# Name: 8951, dtype: float64
# mi            1.600000e+01
# sum_charge    5.269673e+09
# Name: 8952, dtype: float64
# mi            1.600000e+01
# sum_charge    5.234842e+09
# Name: 8953, dtype: float64
# mi            1.600000e+01
# sum_charge    5.215846e+09
# Name: 8954, dtype: float64
# mi            1.600000e+01
# sum_charge    5.281759e+09
# Name: 8955, dtype: float64
# mi            1.600000e+01
# sum_charge    5.243345e+09
# Name: 8956, dtype: float64
# mi            1.600000e+01
# sum_charge    5.234261e+09
# Name: 8957, dtype: float64
# mi            1.600000e+01
# sum_charge    5.238554e+09
# Name: 8958, dtype: float64
# mi            1.600000e+01
# sum_charge    5.272478e+09
# Name: 8959, dtype: float64
# mi            1.600000e+01
# sum_charge    5.290751e+09
# Name: 8960, dtype: float64
# mi            1.600000e+01
# sum_charge    5.255004e+09
# Name: 8961, dtype: float64
# mi            1.600000e+01
# sum_charge    5.268764e+09
# Name: 8962, dtype: float64
# mi            1.600000e+01
# sum_charge    5.240124e+09
# Name: 8963, dtype: float64
# mi            1.600000e+01
# sum_charge    5.229781e+09
# Name: 8964, dtype: float64
# mi            1.600000e+01
# sum_charge    5.277080e+09
# Name: 8965, dtype: float64
# mi            1.600000e+01
# sum_charge    5.265786e+09
# Name: 8966, dtype: float64
# mi            1.600000e+01
# sum_charge    5.264745e+09
# Name: 8967, dtype: float64
# mi            1.600000e+01
# sum_charge    5.266510e+09
# Name: 8968, dtype: float64
# mi            1.600000e+01
# sum_charge    5.251108e+09
# Name: 8969, dtype: float64
# mi            1.600000e+01
# sum_charge    5.269237e+09
# Name: 8970, dtype: float64
# mi            1.600000e+01
# sum_charge    5.255737e+09
# Name: 8971, dtype: float64
# mi            1.600000e+01
# sum_charge    5.275899e+09
# Name: 8972, dtype: float64
# mi            1.600000e+01
# sum_charge    5.263288e+09
# Name: 8973, dtype: float64
# mi            1.600000e+01
# sum_charge    5.238953e+09
# Name: 8974, dtype: float64
# mi            1.600000e+01
# sum_charge    5.229627e+09
# Name: 8975, dtype: float64
# mi            1.600000e+01
# sum_charge    5.274936e+09
# Name: 8976, dtype: float64
# mi            1.600000e+01
# sum_charge    5.261434e+09
# Name: 8977, dtype: float64
# mi            1.600000e+01
# sum_charge    5.250528e+09
# Name: 8978, dtype: float64
# mi            1.600000e+01
# sum_charge    5.244750e+09
# Name: 8979, dtype: float64
# mi            1.600000e+01
# sum_charge    5.254625e+09
# Name: 8980, dtype: float64
# mi            1.600000e+01
# sum_charge    5.264152e+09
# Name: 8981, dtype: float64
# mi            1.600000e+01
# sum_charge    5.254052e+09
# Name: 8982, dtype: float64
# mi            1.600000e+01
# sum_charge    5.261053e+09
# Name: 8983, dtype: float64
# mi            1.600000e+01
# sum_charge    5.242878e+09
# Name: 8984, dtype: float64
# mi            1.600000e+01
# sum_charge    5.273673e+09
# Name: 8985, dtype: float64
# mi            1.600000e+01
# sum_charge    5.258003e+09
# Name: 8986, dtype: float64
# mi            1.600000e+01
# sum_charge    5.220602e+09
# Name: 8987, dtype: float64
# mi            1.600000e+01
# sum_charge    5.263418e+09
# Name: 8988, dtype: float64
# mi            1.600000e+01
# sum_charge    5.252754e+09
# Name: 8989, dtype: float64
# mi            1.600000e+01
# sum_charge    5.259275e+09
# Name: 8990, dtype: float64
# mi            1.600000e+01
# sum_charge    5.236416e+09
# Name: 8991, dtype: float64
# mi            1.600000e+01
# sum_charge    5.244343e+09
# Name: 8992, dtype: float64
# mi            1.600000e+01
# sum_charge    5.265647e+09
# Name: 8993, dtype: float64
# mi            1.600000e+01
# sum_charge    5.227347e+09
# Name: 8994, dtype: float64
# mi            1.600000e+01
# sum_charge    5.271117e+09
# Name: 8995, dtype: float64
# mi            1.600000e+01
# sum_charge    5.270947e+09
# Name: 8996, dtype: float64
# mi            1.600000e+01
# sum_charge    5.251798e+09
# Name: 8997, dtype: float64
# mi            1.600000e+01
# sum_charge    5.240525e+09
# Name: 8998, dtype: float64
# mi            1.600000e+01
# sum_charge    5.273018e+09
# Name: 8999, dtype: float64
#              mi  absolute error sum_charge  relative error sum_charge
# 0      0.001248               3.417499e+07                   0.650116
# 1      0.001248               7.398911e+08                  14.075064
# 2      0.001248               4.942270e+08                   9.401757
# 3      0.001248               5.277795e+07                   1.004003
# 4      0.001248               1.161608e+08                   2.209745
# ...         ...                        ...                        ...
# 8995  16.000000               1.436571e+07                   0.273281
# 8996  16.000000               1.419526e+07                   0.270039
# 8997  16.000000               4.953011e+06                   0.094222
# 8998  16.000000               1.622668e+07                   0.308683
# 8999  16.000000               1.626686e+07                   0.309447
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 sum_charge mean  sum_charge var
# type factor
# pac  0.001248      5.249122e+09    1.137621e+17
#      0.015625      5.261007e+09    9.275009e+15
#      0.031250      5.253758e+09    4.589283e+15
#      0.062500      5.256583e+09    2.545387e+15
#      0.250000      5.256303e+09    7.958691e+14
#      1.000000      5.255661e+09    4.008372e+14
#      2.000000      5.256433e+09    3.228079e+14
#      4.000000      5.257203e+09    2.991947e+14
#      16.000000     5.256702e+09    2.774312e+14

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error sum_charge mean  absolute error sum_charge var  \
# type factor
# pac  0.001248                     2.724306e+08                   3.952767e+16
#      0.015625                     7.749919e+07                   3.281003e+15
#      0.031250                     5.433471e+07                   1.643035e+15
#      0.062500                     3.980000e+07                   9.597906e+14
#      0.250000                     2.257375e+07                   2.859861e+14
#      1.000000                     1.598218e+07                   1.463419e+14
#      2.000000                     1.437908e+07                   1.159442e+14
#      4.000000                     1.389565e+07                   1.061166e+14
#      16.000000                    1.327619e+07                   1.010001e+14
#
#                 relative error sum_charge mean  relative error sum_charge var
# type factor
# pac  0.001248                         5.182490                      14.304292
#      0.015625                         1.474279                       1.187331
#      0.031250                         1.033618                       0.594582
#      0.062500                         0.757122                       0.347329
#      0.250000                         0.429424                       0.103493
#      1.000000                         0.304031                       0.052958
#      2.000000                         0.273535                       0.041958
#      4.000000                         0.264339                       0.038402
#      16.000000                        0.252555                       0.036550

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#              sum_charge
# mi
# 0.001248   1.137621e+17
# 0.015625   9.275009e+15
# 0.031250   4.589283e+15
# 0.062500   2.545387e+15
# 0.250000   7.958691e+14
# 1.000000   4.008372e+14
# 2.000000   3.228079e+14
# 4.000000   2.991947e+14
# 16.000000  2.774312e+14

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step              scale
# query        sum_charge
# mi
# 0.001248   1.081201e+17
# 0.015625   8.637975e+15
# 0.031250   4.318988e+15
# 0.062500   2.159494e+15
# 0.250000   5.398734e+14
# 1.000000   1.349684e+14
# 2.000000   6.748418e+13
# 4.000000   3.374209e+13
# 16.000000  8.435523e+12

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# sum_charge    0.251488
# dtype: float64
#            sum_charge
# mi
# 0.001248     0.257807
# 0.015625     0.245137
# 0.031250     0.249198
# 0.062500     0.256011
# 0.250000     0.255423
# 1.000000     0.254543
# 2.000000     0.242649
# 4.000000     0.254442
# 16.000000    0.248184

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71963/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query            sum_charge
# mi
# 0.001248       2.722754e+08
# 0.015625       7.574837e+07
# 0.031250       5.178866e+07
# 0.062500       3.717851e+07
# 0.250000       1.822503e+07
# 1.000000       9.677658e+06
# 2.000000       6.406301e+06
# 4.000000       4.591776e+06
# 16.000000      2.276336e+06

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71963/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71963/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query        sum_charge
# mi
# 0.001248   5.256885e+09
# 0.015625   5.256740e+09
# 0.031250   5.256558e+09
# 0.062500   5.256451e+09
# 0.250000   5.257070e+09
# 1.000000   5.256324e+09
# 2.000000   5.256029e+09
# 4.000000   5.256827e+09
# 16.000000  5.256692e+09
# step   chosen_sample
# query     sum_charge
# all mi  5.256619e+09

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71963/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#            sum_charge
# mi
# 0.001248     5.182490
# 0.015625     1.474279
# 0.031250     1.033618
# 0.062500     0.757122
# 0.250000     0.429424
# 1.000000     0.304031
# 2.000000     0.273535
# 4.000000     0.264339
# 16.000000    0.252555

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#            sum_charge
# mi
# 0.001248     4.924683
# 0.015625     1.229142
# 0.031250     0.784419
# 0.062500     0.501110
# 0.250000     0.174001
# 1.000000     0.049488
# 2.000000     0.030887
# 4.000000     0.009897
# 16.000000    0.004371

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()
