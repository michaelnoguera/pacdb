# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   -- sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   -- sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   -- avg(l_quantity) as avg_qty,
#   -- avg(l_extendedprice) as avg_price,
#   -- avg(l_discount) as avg_disc,
#   count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'A'
#   and l_linestatus = 'F'
# ```

# %%
EXPERIMENT = 'pac-q1-count-order'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'A') &
        (lineitem_df['l_linestatus'] == 'F')
    ]
    print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        # float(discounted_price.sum()),                      # sum_disc_price
        # float(charged_price.sum()),                         # sum_charge
        # float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        # float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        # float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# (147790, 16)
# [147790.0]
# [147790.0]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['count_order']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 147790  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np
# Out:
# (147790, 16)
# [147790.0]

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
# TODO: Change it back to 1000
EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    # out_np = generate_samples() # generate samples (results of running the query)
    # print(f"Generate samples... {len(out_np)} samples generated.")

    # print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# Getting PAC Noise...
# The dimensions are - 1
# [array([[147368.]]), array([[148212.]]), array([[147636.]]), array([[147944.]]), array([[147716.]]), array([[147864.]]), array([[148014.]]), array([[147566.]]), array([[147664.]]), array([[147916.]]), array([[147898.]]), array([[147682.]]), array([[147654.]]), array([[147926.]]), array([[147752.]]), array([[147828.]]), array([[147886.]]), array([[147694.]]), array([[148288.]]), array([[147292.]]), array([[147740.]]), array([[147840.]]), array([[147362.]]), array([[148218.]]), array([[147602.]]), array([[147978.]]), array([[147546.]]), array([[148034.]]), array([[147110.]]), array([[148470.]]), array([[147924.]]), array([[147656.]]), array([[148108.]]), array([[147472.]]), array([[147408.]]), array([[148172.]]), array([[147326.]]), array([[148254.]]), array([[147618.]]), array([[147962.]]), array([[147544.]]), array([[148036.]]), array([[148014.]]), array([[147566.]]), array([[148116.]]), array([[147464.]]), array([[147512.]]), array([[148068.]]), array([[148334.]]), array([[147246.]]), array([[148218.]]), array([[147362.]]), array([[147704.]]), array([[147876.]]), array([[147948.]]), array([[147632.]]), array([[149058.]]), array([[146522.]]), array([[147390.]]), array([[148190.]]), array([[148622.]]), array([[146958.]]), array([[147736.]]), array([[147844.]]), array([[146902.]]), array([[148678.]]), array([[147698.]]), array([[147882.]]), array([[147818.]]), array([[147762.]]), array([[148066.]]), array([[147514.]]), array([[147326.]]), array([[148254.]]), array([[147326.]]), array([[148254.]]), array([[147840.]]), array([[147740.]]), array([[148222.]]), array([[147358.]]), array([[147928.]]), array([[147652.]]), array([[148398.]]), array([[147182.]]), array([[147712.]]), array([[147868.]]), array([[147826.]]), array([[147754.]]), array([[147696.]]), array([[147884.]]), array([[147956.]]), array([[147624.]]), array([[148220.]]), array([[147360.]]), array([[148256.]]), array([[147324.]]), array([[147488.]]), array([[148092.]]), array([[148156.]]), array([[147424.]]), array([[147568.]]), array([[148012.]]), array([[147128.]]), array([[148452.]]), array([[147648.]]), array([[147932.]]), array([[147818.]]), array([[147762.]]), array([[148062.]]), array([[147518.]]), array([[147936.]]), array([[147644.]]), array([[147638.]]), array([[147942.]]), array([[147530.]]), array([[148050.]]), array([[146992.]]), array([[148588.]]), array([[147248.]]), array([[148332.]]), array([[148036.]]), array([[147544.]]), array([[147808.]]), array([[147772.]]), array([[147386.]]), array([[148194.]]), array([[148078.]]), array([[147502.]]), array([[147170.]]), array([[148410.]]), array([[147734.]]), array([[147846.]]), array([[147518.]]), array([[148062.]]), array([[148336.]]), array([[147244.]]), array([[147910.]]), array([[147670.]]), array([[147780.]]), array([[147800.]]), array([[146756.]]), array([[148824.]]), array([[147656.]]), array([[147924.]]), array([[147964.]]), array([[147616.]]), array([[147668.]]), array([[147912.]]), array([[147528.]]), array([[148052.]]), array([[147718.]]), array([[147862.]]), array([[147954.]]), array([[147626.]]), array([[147922.]]), array([[147658.]]), array([[148878.]]), array([[146702.]]), array([[147846.]]), array([[147734.]]), array([[147108.]]), array([[148472.]]), array([[148320.]]), array([[147260.]]), array([[147540.]]), array([[148040.]]), array([[147962.]]), array([[147618.]]), array([[147690.]]), array([[147890.]]), array([[147774.]]), array([[147806.]]), array([[147400.]]), array([[148180.]]), array([[147884.]]), array([[147696.]]), array([[147276.]]), array([[148304.]]), array([[148658.]]), array([[146922.]]), array([[148460.]]), array([[147120.]]), array([[148134.]]), array([[147446.]]), array([[148376.]]), array([[147204.]]), array([[147990.]]), array([[147590.]]), array([[148096.]]), array([[147484.]]), array([[147900.]]), array([[147680.]]), array([[148014.]]), array([[147566.]]), array([[147744.]]), array([[147836.]]), array([[147806.]]), array([[147774.]]), array([[147622.]]), array([[147958.]]), ...
# est_y.shape: (1, 8192)
# est_y: [[147368. 148212. 147636. ... 147238. 148472. 147108.]]
# fin_var: [156150.72070312]
# sqrt_total_var: 395.15910808574944
# For mi=0.001248318631131131, we should add noise from a normal distribution with scale...
# 	400.5387627251371 * 395.15910808574944 * [395.15910809] = [62544416.46906813]
# pac_noise: [62544416.46906813]
# mi=0.001248318631131131, scale=[62544416.46906813]
# Chosen Sample [147524.]
# Chosen Sample [147672.]
# Chosen Sample [147402.]
# Chosen Sample [147980.]
# Chosen Sample [147846.]
# Chosen Sample [147580.]
# Chosen Sample [148034.]
# Chosen Sample [148130.]
# Chosen Sample [148232.]
# Chosen Sample [147388.]
# Chosen Sample [148376.]
# Chosen Sample [147570.]
# Chosen Sample [148012.]
# Chosen Sample [147506.]
# Chosen Sample [147456.]
# Chosen Sample [148206.]
# Chosen Sample [148212.]
# Chosen Sample [146948.]
# Chosen Sample [147522.]
# Chosen Sample [147696.]
# Chosen Sample [148084.]
# Chosen Sample [147424.]
# Chosen Sample [148102.]
# Chosen Sample [148312.]
# Chosen Sample [148162.]
# Chosen Sample [147508.]
# Chosen Sample [148294.]
# Chosen Sample [146930.]
# Chosen Sample [147216.]
# Chosen Sample [147952.]
# Chosen Sample [147638.]
# Chosen Sample [147990.]
# Chosen Sample [147558.]
# Chosen Sample [147648.]
# Chosen Sample [148388.]
# Chosen Sample [147704.]
# Chosen Sample [147742.]
# Chosen Sample [147410.]
# Chosen Sample [147810.]
# Chosen Sample [147768.]
# Chosen Sample [148210.]
# Chosen Sample [147962.]
# Chosen Sample [148442.]
# Chosen Sample [147606.]
# Chosen Sample [147292.]
# Chosen Sample [148086.]
# Chosen Sample [147668.]
# Chosen Sample [147888.]
# Chosen Sample [147536.]
# Chosen Sample [147650.]
# Chosen Sample [147778.]
# Chosen Sample [147564.]
# Chosen Sample [147926.]
# Chosen Sample [147660.]
# Chosen Sample [147748.]
# Chosen Sample [147642.]
# Chosen Sample [147536.]
# Chosen Sample [148310.]
# Chosen Sample [146888.]
# Chosen Sample [147550.]
# Chosen Sample [148590.]
# Chosen Sample [147298.]
# Chosen Sample [147728.]
# Chosen Sample [148980.]
# Chosen Sample [147678.]
# Chosen Sample [147814.]
# Chosen Sample [147832.]
# Chosen Sample [147544.]
# Chosen Sample [147660.]
# Chosen Sample [147130.]
# Chosen Sample [147682.]
# Chosen Sample [147320.]
# Chosen Sample [147906.]
# Chosen Sample [147582.]
# Chosen Sample [148544.]
# Chosen Sample [148048.]
# Chosen Sample [147886.]
# Chosen Sample [147420.]
# Chosen Sample [147596.]
# Chosen Sample [148126.]
# Chosen Sample [147524.]
# Chosen Sample [148026.]
# Chosen Sample [147726.]
# Chosen Sample [147812.]
# Chosen Sample [147642.]
# Chosen Sample [147892.]
# Chosen Sample [146772.]
# Chosen Sample [147670.]
# Chosen Sample [148232.]
# Chosen Sample [147596.]
# Chosen Sample [147974.]
# Chosen Sample [148602.]
# Chosen Sample [147836.]
# Chosen Sample [148368.]
# Chosen Sample [147416.]
# Chosen Sample [147628.]
# Chosen Sample [147622.]
# Chosen Sample [147798.]
# Chosen Sample [147914.]
# Chosen Sample [147656.]
# Chosen Sample [147234.]
# Chosen Sample [147674.]
# Chosen Sample [147862.]
# Chosen Sample [147840.]
# Chosen Sample [148024.]
# Chosen Sample [147746.]
# Chosen Sample [147946.]
# Chosen Sample [147152.]
# Chosen Sample [146992.]
# Chosen Sample [147796.]
# Chosen Sample [147110.]
# Chosen Sample [148096.]
# Chosen Sample [147914.]
# Chosen Sample [148400.]
# Chosen Sample [147232.]
# Chosen Sample [147464.]
# Chosen Sample [148372.]
# Chosen Sample [147326.]
# Chosen Sample [147660.]
# Chosen Sample [148180.]
# Chosen Sample [147894.]
# Chosen Sample [147692.]
# Chosen Sample [147264.]
# Chosen Sample [147650.]
# Chosen Sample [147240.]
# Chosen Sample [147734.]
# Chosen Sample [148038.]
# Chosen Sample [147932.]
# Chosen Sample [148316.]
# Chosen Sample [147484.]
# Chosen Sample [147716.]
# Chosen Sample [147844.]
# Chosen Sample [148232.]
# Chosen Sample [147596.]
# Chosen Sample [147542.]
# Chosen Sample [147782.]
# Chosen Sample [148072.]
# Chosen Sample [147092.]
# Chosen Sample [146580.]
# Chosen Sample [147844.]
# Chosen Sample [147880.]
# Chosen Sample [148436.]
# Chosen Sample [147120.]
# Chosen Sample [147796.]
# Chosen Sample [146932.]
# Chosen Sample [148112.]
# Chosen Sample [148298.]
# Chosen Sample [147742.]
# Chosen Sample [148024.]
# Chosen Sample [147306.]
# Chosen Sample [147352.]
# Chosen Sample [148262.]
# Chosen Sample [147614.]
# Chosen Sample [147958.]
# Chosen Sample [148210.]
# Chosen Sample [147412.]
# Chosen Sample [147562.]
# Chosen Sample [148014.]
# Chosen Sample [147490.]
# Chosen Sample [147442.]
# Chosen Sample [147520.]
# Chosen Sample [148194.]
# Chosen Sample [148138.]
# Chosen Sample [148212.]
# Chosen Sample [147508.]
# Chosen Sample [147408.]
# Chosen Sample [148366.]
# Chosen Sample [148184.]
# Chosen Sample [148488.]
# Chosen Sample [147334.]
# Chosen Sample [147736.]
# Chosen Sample [147872.]
# Chosen Sample [147720.]
# Chosen Sample [148284.]
# Chosen Sample [147820.]
# Chosen Sample [147818.]
# Chosen Sample [147044.]
# Chosen Sample [146996.]
# Chosen Sample [147674.]
# Chosen Sample [148336.]
# Chosen Sample [147846.]
# Chosen Sample [147228.]
# Chosen Sample [147670.]
# Chosen Sample [149046.]
# Chosen Sample [147676.]
# Chosen Sample [148094.]
# Chosen Sample [147394.]
# Chosen Sample [147800.]
# Chosen Sample [147806.]
# Chosen Sample [148046.]
# Chosen Sample [147406.]
# Chosen Sample [147924.]
# Chosen Sample [147854.]
# Chosen Sample [147502.]
# Chosen Sample [148262.]
# Chosen Sample [148046.]
# Chosen Sample [147718.]
# Chosen Sample [147442.]
# Chosen Sample [147502.]
# Chosen Sample [147934.]
# Chosen Sample [147368.]
# Chosen Sample [148266.]
# Chosen Sample [146974.]
# Chosen Sample [148136.]
# Chosen Sample [147350.]
# Chosen Sample [148164.]
# Chosen Sample [147736.]
# Chosen Sample [147492.]
# Chosen Sample [147512.]
# Chosen Sample [147562.]
# Chosen Sample [147756.]
# Chosen Sample [147632.]
# Chosen Sample [147366.]
# Chosen Sample [148248.]
# Chosen Sample [148226.]
# Chosen Sample [147858.]
# Chosen Sample [147902.]
# Chosen Sample [147290.]
# Chosen Sample [147984.]
# Chosen Sample [147630.]
# Chosen Sample [147412.]
# Chosen Sample [147646.]
# Chosen Sample [147780.]
# Chosen Sample [147666.]
# Chosen Sample [147498.]
# Chosen Sample [148272.]
# Chosen Sample [147974.]
# Chosen Sample [148308.]
# Chosen Sample [148382.]
# Chosen Sample [148060.]
# Chosen Sample [148236.]
# Chosen Sample [148126.]
# Chosen Sample [147750.]
# Chosen Sample [147014.]
# Chosen Sample [147564.]
# Chosen Sample [148234.]
# Chosen Sample [148162.]
# Chosen Sample [147780.]
# Chosen Sample [147142.]
# Chosen Sample [148500.]
# Chosen Sample [147350.]
# Chosen Sample [148114.]
# Chosen Sample [147410.]
# Chosen Sample [147902.]
# Chosen Sample [147122.]
# Chosen Sample [147514.]
# Chosen Sample [147094.]
# Chosen Sample [148700.]
# Chosen Sample [147468.]
# Chosen Sample [147660.]
# Chosen Sample [148064.]
# Chosen Sample [147860.]
# Chosen Sample [147840.]
# Chosen Sample [147004.]
# Chosen Sample [147232.]
# Chosen Sample [148304.]
# Chosen Sample [148124.]
# Chosen Sample [147496.]
# Chosen Sample [148196.]
# Chosen Sample [146990.]
# Chosen Sample [147820.]
# Chosen Sample [147896.]
# Chosen Sample [147656.]
# Chosen Sample [147890.]
# Chosen Sample [147384.]
# Chosen Sample [146818.]
# Chosen Sample [147844.]
# Chosen Sample [147374.]
# Chosen Sample [147388.]
# Chosen Sample [147406.]
# Chosen Sample [147208.]
# Chosen Sample [147250.]
# Chosen Sample [146720.]
# Chosen Sample [147894.]
# Chosen Sample [147308.]
# Chosen Sample [147848.]
# Chosen Sample [147552.]
# Chosen Sample [146898.]
# Chosen Sample [147420.]
# Chosen Sample [147916.]
# Chosen Sample [148194.]
# Chosen Sample [147666.]
# Chosen Sample [147760.]
# Chosen Sample [148418.]
# Chosen Sample [147958.]
# Chosen Sample [148716.]
# Chosen Sample [147802.]
# Chosen Sample [147916.]
# Chosen Sample [147638.]
# Chosen Sample [147620.]
# Chosen Sample [147388.]
# Chosen Sample [148198.]
# Chosen Sample [147906.]
# Chosen Sample [147772.]
# Chosen Sample [147574.]
# Chosen Sample [148102.]
# Chosen Sample [147572.]
# Chosen Sample [148692.]
# Chosen Sample [148088.]
# Chosen Sample [147774.]
# Chosen Sample [148320.]
# Chosen Sample [148366.]
# Chosen Sample [147824.]
# Chosen Sample [147748.]
# Chosen Sample [148046.]
# Chosen Sample [148732.]
# Chosen Sample [147408.]
# Chosen Sample [147712.]
# Chosen Sample [147240.]
# Chosen Sample [147632.]
# Chosen Sample [147386.]
# Chosen Sample [147610.]
# Chosen Sample [147498.]
# Chosen Sample [147872.]
# Chosen Sample [147768.]
# Chosen Sample [147438.]
# Chosen Sample [147690.]
# Chosen Sample [148350.]
# Chosen Sample [147328.]
# Chosen Sample [147980.]
# Chosen Sample [148712.]
# Chosen Sample [148196.]
# Chosen Sample [147764.]
# Chosen Sample [147304.]
# Chosen Sample [147774.]
# Chosen Sample [147916.]
# Chosen Sample [147570.]
# Chosen Sample [147402.]
# Chosen Sample [147334.]
# Chosen Sample [147268.]
# Chosen Sample [147882.]
# Chosen Sample [148116.]
# Chosen Sample [147882.]
# Chosen Sample [147814.]
# Chosen Sample [148276.]
# Chosen Sample [148014.]
# Chosen Sample [147792.]
# Chosen Sample [147428.]
# Chosen Sample [148262.]
# Chosen Sample [147494.]
# Chosen Sample [148196.]
# Chosen Sample [148658.]
# Chosen Sample [147318.]
# Chosen Sample [148204.]
# Chosen Sample [148194.]
# Chosen Sample [147810.]
# Chosen Sample [148164.]
# Chosen Sample [147874.]
# Chosen Sample [147386.]
# Chosen Sample [148074.]
# Chosen Sample [147544.]
# Chosen Sample [148380.]
# Chosen Sample [148162.]
# Chosen Sample [147764.]
# Chosen Sample [147512.]
# Chosen Sample [147364.]
# Chosen Sample [147938.]
# Chosen Sample [147598.]
# Chosen Sample [147368.]
# Chosen Sample [147148.]
# Chosen Sample [147634.]
# Chosen Sample [147870.]
# Chosen Sample [148668.]
# Chosen Sample [148884.]
# Chosen Sample [148002.]
# Chosen Sample [147902.]
# Chosen Sample [146744.]
# Chosen Sample [147270.]
# Chosen Sample [147672.]
# Chosen Sample [148094.]
# Chosen Sample [147570.]
# Chosen Sample [147888.]
# Chosen Sample [147664.]
# Chosen Sample [147342.]
# Chosen Sample [147212.]
# Chosen Sample [148106.]
# Chosen Sample [148078.]
# Chosen Sample [147314.]
# Chosen Sample [148090.]
# Chosen Sample [147760.]
# Chosen Sample [147710.]
# Chosen Sample [147402.]
# Chosen Sample [147806.]
# Chosen Sample [147750.]
# Chosen Sample [148050.]
# Chosen Sample [146978.]
# Chosen Sample [148108.]
# Chosen Sample [147952.]
# Chosen Sample [147446.]
# Chosen Sample [147994.]
# Chosen Sample [147506.]
# Chosen Sample [147734.]
# Chosen Sample [147662.]
# Chosen Sample [147186.]
# Chosen Sample [148342.]
# Chosen Sample [148232.]
# Chosen Sample [148248.]
# Chosen Sample [147590.]
# Chosen Sample [147472.]
# Chosen Sample [147438.]
# Chosen Sample [147008.]
# Chosen Sample [147128.]
# Chosen Sample [147884.]
# Chosen Sample [147766.]
# Chosen Sample [148268.]
# Chosen Sample [148124.]
# Chosen Sample [147148.]
# Chosen Sample [147322.]
# Chosen Sample [147822.]
# Chosen Sample [147470.]
# Chosen Sample [147612.]
# Chosen Sample [147916.]
# Chosen Sample [147958.]
# Chosen Sample [148082.]
# Chosen Sample [148072.]
# Chosen Sample [147348.]
# Chosen Sample [147862.]
# Chosen Sample [147526.]
# Chosen Sample [147110.]
# Chosen Sample [148342.]
# Chosen Sample [147732.]
# Chosen Sample [147860.]
# Chosen Sample [147448.]
# Chosen Sample [148898.]
# Chosen Sample [147240.]
# Chosen Sample [147360.]
# Chosen Sample [148056.]
# Chosen Sample [148302.]
# Chosen Sample [147458.]
# Chosen Sample [148430.]
# Chosen Sample [147928.]
# Chosen Sample [148036.]
# Chosen Sample [148246.]
# Chosen Sample [148156.]
# Chosen Sample [147182.]
# Chosen Sample [148404.]
# Chosen Sample [147818.]
# Chosen Sample [148232.]
# Chosen Sample [148430.]
# Chosen Sample [147608.]
# Chosen Sample [148530.]
# Chosen Sample [147810.]
# Chosen Sample [146952.]
# Chosen Sample [148084.]
# Chosen Sample [148088.]
# Chosen Sample [146858.]
# Chosen Sample [147970.]
# Chosen Sample [147792.]
# Chosen Sample [147428.]
# Chosen Sample [147782.]
# Chosen Sample [148242.]
# Chosen Sample [148270.]
# Chosen Sample [147410.]
# Chosen Sample [147610.]
# Chosen Sample [147430.]
# Chosen Sample [147298.]
# Chosen Sample [147910.]
# Chosen Sample [148158.]
# Chosen Sample [147372.]
# Chosen Sample [147314.]
# Chosen Sample [147496.]
# Chosen Sample [147620.]
# Chosen Sample [147386.]
# Chosen Sample [147604.]
# Chosen Sample [147814.]
# Chosen Sample [148006.]
# Chosen Sample [147936.]
# Chosen Sample [147448.]
# Chosen Sample [147596.]
# Chosen Sample [148094.]
# Chosen Sample [147918.]
# Chosen Sample [147114.]
# Chosen Sample [148076.]
# Chosen Sample [147742.]
# Chosen Sample [148088.]
# Chosen Sample [147992.]
# Chosen Sample [147704.]
# Chosen Sample [147632.]
# Chosen Sample [147214.]
# Chosen Sample [148028.]
# Chosen Sample [147356.]
# Chosen Sample [147340.]
# Chosen Sample [148178.]
# Chosen Sample [147762.]
# Chosen Sample [147554.]
# Chosen Sample [147996.]
# Chosen Sample [148100.]
# Chosen Sample [148136.]
# Chosen Sample [148182.]
# Chosen Sample [147828.]
# Chosen Sample [147892.]
# Chosen Sample [147262.]
# Chosen Sample [147102.]
# Chosen Sample [148084.]
# Chosen Sample [148584.]
# Chosen Sample [147346.]
# Chosen Sample [148032.]
# Chosen Sample [148052.]
# Chosen Sample [147718.]
# Chosen Sample [147804.]
# Chosen Sample [147932.]
# Chosen Sample [147882.]
# Chosen Sample [147630.]
# Chosen Sample [148080.]
# Chosen Sample [147844.]
# Chosen Sample [147890.]
# Chosen Sample [147956.]
# Chosen Sample [147620.]
# Chosen Sample [147480.]
# Chosen Sample [147570.]
# Chosen Sample [147700.]
# Chosen Sample [147408.]
# Chosen Sample [148102.]
# Chosen Sample [148070.]
# Chosen Sample [147788.]
# Chosen Sample [148260.]
# Chosen Sample [147582.]
# Chosen Sample [147428.]
# Chosen Sample [147342.]
# Chosen Sample [147648.]
# Chosen Sample [147710.]
# Chosen Sample [147654.]
# Chosen Sample [147512.]
# Chosen Sample [147358.]
# Chosen Sample [148502.]
# Chosen Sample [147686.]
# Chosen Sample [147868.]
# Chosen Sample [147568.]
# Chosen Sample [148432.]
# Chosen Sample [147208.]
# Chosen Sample [148308.]
# Chosen Sample [147568.]
# Chosen Sample [147524.]
# Chosen Sample [147090.]
# Chosen Sample [146958.]
# Chosen Sample [147686.]
# Chosen Sample [147804.]
# Chosen Sample [148034.]
# Chosen Sample [148050.]
# Chosen Sample [147996.]
# Chosen Sample [147676.]
# Chosen Sample [148602.]
# Chosen Sample [148166.]
# Chosen Sample [148146.]
# Chosen Sample [147894.]
# Chosen Sample [147762.]
# Chosen Sample [147180.]
# Chosen Sample [147570.]
# Chosen Sample [148056.]
# Chosen Sample [148342.]
# Chosen Sample [148248.]
# Chosen Sample [148090.]
# Chosen Sample [147492.]
# Chosen Sample [148362.]
# Chosen Sample [147084.]
# Chosen Sample [147370.]
# Chosen Sample [148138.]
# Chosen Sample [148062.]
# Chosen Sample [147736.]
# Chosen Sample [147466.]
# Chosen Sample [147428.]
# Chosen Sample [147340.]
# Chosen Sample [147768.]
# Chosen Sample [147612.]
# Chosen Sample [148196.]
# Chosen Sample [147736.]
# Chosen Sample [147948.]
# Chosen Sample [148488.]
# Chosen Sample [148320.]
# Chosen Sample [147694.]
# Chosen Sample [147924.]
# Chosen Sample [147244.]
# Chosen Sample [148704.]
# Chosen Sample [147978.]
# Chosen Sample [148696.]
# Chosen Sample [147778.]
# Chosen Sample [147508.]
# Chosen Sample [148010.]
# Chosen Sample [148054.]
# Chosen Sample [148632.]
# Chosen Sample [147830.]
# Chosen Sample [147460.]
# Chosen Sample [148368.]
# Chosen Sample [147902.]
# Chosen Sample [147330.]
# Chosen Sample [147682.]
# Chosen Sample [147102.]
# Chosen Sample [147760.]
# Chosen Sample [147910.]
# Chosen Sample [147358.]
# Chosen Sample [147420.]
# Chosen Sample [148152.]
# Chosen Sample [148450.]
# Chosen Sample [147344.]
# Chosen Sample [147604.]
# Chosen Sample [148072.]
# Chosen Sample [147770.]
# Chosen Sample [147238.]
# Chosen Sample [148216.]
# Chosen Sample [148110.]
# Chosen Sample [147946.]
# Chosen Sample [148172.]
# Chosen Sample [147476.]
# Chosen Sample [147932.]
# Chosen Sample [147832.]
# Chosen Sample [147740.]
# Chosen Sample [147714.]
# Chosen Sample [147548.]
# Chosen Sample [147312.]
# Chosen Sample [147604.]
# Chosen Sample [147770.]
# Chosen Sample [147540.]
# Chosen Sample [148488.]
# Chosen Sample [147978.]
# Chosen Sample [148836.]
# Chosen Sample [148224.]
# Chosen Sample [148186.]
# Chosen Sample [147910.]
# Chosen Sample [148174.]
# Chosen Sample [147808.]
# Chosen Sample [148268.]
# Chosen Sample [147690.]
# Chosen Sample [147864.]
# Chosen Sample [148668.]
# Chosen Sample [148108.]
# Chosen Sample [148096.]
# Chosen Sample [148066.]
# Chosen Sample [148260.]
# Chosen Sample [148038.]
# Chosen Sample [147842.]
# Chosen Sample [148094.]
# Chosen Sample [147530.]
# Chosen Sample [147882.]
# Chosen Sample [147936.]
# Chosen Sample [148628.]
# Chosen Sample [148028.]
# Chosen Sample [148132.]
# Chosen Sample [148162.]
# Chosen Sample [148062.]
# Chosen Sample [147540.]
# Chosen Sample [147788.]
# Chosen Sample [147772.]
# Chosen Sample [147702.]
# Chosen Sample [147730.]
# Chosen Sample [147680.]
# Chosen Sample [148236.]
# Chosen Sample [147122.]
# Chosen Sample [147778.]
# Chosen Sample [148362.]
# Chosen Sample [147330.]
# Chosen Sample [147910.]
# Chosen Sample [147640.]
# Chosen Sample [147166.]
# Chosen Sample [147806.]
# Chosen Sample [147696.]
# Chosen Sample [147754.]
# Chosen Sample [147618.]
# Chosen Sample [148160.]
# Chosen Sample [148118.]
# Chosen Sample [147466.]
# Chosen Sample [147622.]
# Chosen Sample [147706.]
# Chosen Sample [148346.]
# Chosen Sample [147412.]
# Chosen Sample [147700.]
# Chosen Sample [147840.]
# Chosen Sample [147778.]
# Chosen Sample [146962.]
# Chosen Sample [147714.]
# Chosen Sample [148062.]
# Chosen Sample [148054.]
# Chosen Sample [147548.]
# Chosen Sample [147714.]
# Chosen Sample [147732.]
# Chosen Sample [147372.]
# Chosen Sample [147126.]
# Chosen Sample [147254.]
# Chosen Sample [147866.]
# Chosen Sample [147550.]
# Chosen Sample [147830.]
# Chosen Sample [148144.]
# Chosen Sample [148032.]
# Chosen Sample [148858.]
# Chosen Sample [147746.]
# Chosen Sample [148310.]
# Chosen Sample [147454.]
# Chosen Sample [147354.]
# Chosen Sample [147496.]
# Chosen Sample [148096.]
# Chosen Sample [147788.]
# Chosen Sample [148114.]
# Chosen Sample [148650.]
# Chosen Sample [147774.]
# Chosen Sample [148056.]
# Chosen Sample [148524.]
# Chosen Sample [147320.]
# Chosen Sample [147844.]
# Chosen Sample [147626.]
# Chosen Sample [148026.]
# Chosen Sample [147002.]
# Chosen Sample [147828.]
# Chosen Sample [147480.]
# Chosen Sample [147466.]
# Chosen Sample [147732.]
# Chosen Sample [148082.]
# Chosen Sample [147848.]
# Chosen Sample [147636.]
# Chosen Sample [147546.]
# Chosen Sample [147354.]
# Chosen Sample [147720.]
# Chosen Sample [148088.]
# Chosen Sample [147474.]
# Chosen Sample [147786.]
# Chosen Sample [148474.]
# Chosen Sample [147416.]
# Chosen Sample [147780.]
# Chosen Sample [148318.]
# Chosen Sample [147596.]
# Chosen Sample [148042.]
# Chosen Sample [147968.]
# Chosen Sample [147632.]
# Chosen Sample [147484.]
# Chosen Sample [148028.]
# Chosen Sample [147880.]
# Chosen Sample [148878.]
# Chosen Sample [147902.]
# Chosen Sample [147860.]
# Chosen Sample [147434.]
# Chosen Sample [147604.]
# Chosen Sample [147938.]
# Chosen Sample [147418.]
# Chosen Sample [148056.]
# Chosen Sample [147084.]
# Chosen Sample [148430.]
# Chosen Sample [148058.]
# Chosen Sample [147644.]
# Chosen Sample [147222.]
# Chosen Sample [147516.]
# Chosen Sample [147212.]
# Chosen Sample [147524.]
# Chosen Sample [148088.]
# Chosen Sample [148394.]
# Chosen Sample [147454.]
# Chosen Sample [147740.]
# Chosen Sample [147682.]
# Chosen Sample [147984.]
# Chosen Sample [148168.]
# Chosen Sample [147406.]
# Chosen Sample [147538.]
# Chosen Sample [148034.]
# Chosen Sample [147606.]
# Chosen Sample [147746.]
# Chosen Sample [147996.]
# Chosen Sample [147402.]
# Chosen Sample [147694.]
# Chosen Sample [148262.]
# Chosen Sample [147576.]
# Chosen Sample [147496.]
# Chosen Sample [147958.]
# Chosen Sample [147828.]
# Chosen Sample [148180.]
# Chosen Sample [147776.]
# Chosen Sample [148496.]
# Chosen Sample [147178.]
# Chosen Sample [147742.]
# Chosen Sample [147056.]
# Chosen Sample [147222.]
# Chosen Sample [147948.]
# Chosen Sample [147966.]
# Chosen Sample [147818.]
# Chosen Sample [147466.]
# Chosen Sample [148704.]
# Chosen Sample [148354.]
# Chosen Sample [147768.]
# Chosen Sample [148084.]
# Chosen Sample [147220.]
# Chosen Sample [147450.]
# Chosen Sample [148096.]
# Chosen Sample [147800.]
# Chosen Sample [147932.]
# Chosen Sample [148234.]
# Chosen Sample [148226.]
# Chosen Sample [147200.]
# Chosen Sample [148972.]
# Chosen Sample [147726.]
# Chosen Sample [147874.]
# Chosen Sample [147962.]
# Chosen Sample [148092.]
# Chosen Sample [147748.]
# Chosen Sample [146582.]
# Chosen Sample [147918.]
# Chosen Sample [147484.]
# Chosen Sample [147800.]
# Chosen Sample [148250.]
# Chosen Sample [147812.]
# Chosen Sample [147692.]
# Chosen Sample [147798.]
# Chosen Sample [147222.]
# Chosen Sample [147742.]
# Chosen Sample [147886.]
# Chosen Sample [147918.]
# Chosen Sample [147930.]
# Chosen Sample [147134.]
# Chosen Sample [147868.]
# Chosen Sample [146848.]
# Chosen Sample [147948.]
# Chosen Sample [147660.]
# Chosen Sample [147518.]
# Chosen Sample [148168.]
# Chosen Sample [148612.]
# Chosen Sample [148062.]
# Chosen Sample [148594.]
# Chosen Sample [148032.]
# Chosen Sample [148140.]
# Chosen Sample [148014.]
# Chosen Sample [147066.]
# Chosen Sample [147994.]
# Chosen Sample [147630.]
# Chosen Sample [148148.]
# Chosen Sample [147454.]
# Chosen Sample [147816.]
# Chosen Sample [147870.]
# Chosen Sample [147842.]
# Chosen Sample [147582.]
# Chosen Sample [147722.]
# Chosen Sample [147632.]
# Chosen Sample [148022.]
# Chosen Sample [147994.]
# Chosen Sample [147802.]
# Chosen Sample [147364.]
# Chosen Sample [148698.]
# Chosen Sample [147914.]
# Chosen Sample [147370.]
# Chosen Sample [147476.]
# Chosen Sample [148116.]
# Chosen Sample [147760.]
# Chosen Sample [147882.]
# Chosen Sample [147556.]
# Chosen Sample [147598.]
# Chosen Sample [147484.]
# Chosen Sample [147756.]
# Chosen Sample [147640.]
# Chosen Sample [148344.]
# Chosen Sample [147986.]
# Chosen Sample [148010.]
# Chosen Sample [147442.]
# Chosen Sample [147748.]
# Chosen Sample [147734.]
# Chosen Sample [148236.]
# Chosen Sample [146860.]
# Chosen Sample [146912.]
# Chosen Sample [147730.]
# Chosen Sample [147956.]
# Chosen Sample [147344.]
# Chosen Sample [148066.]
# Chosen Sample [147780.]
# Chosen Sample [147732.]
# Chosen Sample [147876.]
# Chosen Sample [147292.]
# Chosen Sample [148216.]
# Chosen Sample [147868.]
# Chosen Sample [148026.]
# Chosen Sample [147866.]
# Chosen Sample [147866.]
# Chosen Sample [148220.]
# Chosen Sample [147920.]
# Chosen Sample [147268.]
# Chosen Sample [148466.]
# Chosen Sample [148234.]
# Chosen Sample [147890.]
# Chosen Sample [147152.]
# Chosen Sample [147902.]
# Chosen Sample [148024.]
# Chosen Sample [147728.]
# Chosen Sample [147200.]
# Chosen Sample [147796.]
# Chosen Sample [147578.]
# Chosen Sample [147398.]
# Chosen Sample [147784.]
# Chosen Sample [148044.]
# Chosen Sample [148366.]
# Chosen Sample [147520.]
# Chosen Sample [147490.]
# Chosen Sample [148186.]
# Chosen Sample [148176.]
# Chosen Sample [147710.]
# Chosen Sample [148208.]
# Chosen Sample [147610.]
# Chosen Sample [147884.]
# Chosen Sample [147754.]
# Chosen Sample [148000.]
# Chosen Sample [147616.]
# Chosen Sample [147932.]
# Chosen Sample [148204.]
# Chosen Sample [147278.]
# Chosen Sample [148320.]
# Chosen Sample [147918.]
# Chosen Sample [147806.]
# Chosen Sample [148762.]
# Chosen Sample [148234.]
# Chosen Sample [147750.]
# Chosen Sample [147504.]
# Chosen Sample [147904.]
# Chosen Sample [147658.]
# Chosen Sample [148490.]
# Chosen Sample [148472.]
# Chosen Sample [148302.]
# Chosen Sample [147280.]
# Chosen Sample [148700.]
# Chosen Sample [147222.]
# Chosen Sample [147470.]
# Chosen Sample [147298.]
# Chosen Sample [148442.]
# Chosen Sample [147786.]
# Chosen Sample [147820.]
# Chosen Sample [148318.]
# Chosen Sample [148174.]
# Chosen Sample [148156.]
# Chosen Sample [148720.]
# Chosen Sample [148136.]
# Chosen Sample [148148.]
# Chosen Sample [148008.]
# Chosen Sample [147886.]
# Chosen Sample [147402.]
# Chosen Sample [148064.]
# Chosen Sample [147648.]
# Chosen Sample [147928.]
# Chosen Sample [147930.]
# Chosen Sample [147570.]
# Chosen Sample [147638.]
# Chosen Sample [148014.]
# Chosen Sample [147770.]
# Chosen Sample [147616.]
# Chosen Sample [147878.]
# Chosen Sample [147862.]
# Chosen Sample [147206.]
# Chosen Sample [147702.]
# Chosen Sample [147202.]
# Chosen Sample [147376.]
# Chosen Sample [148114.]
# Chosen Sample [147710.]
# Chosen Sample [147390.]
# Chosen Sample [147742.]
# Chosen Sample [148034.]
# Chosen Sample [147960.]
# Chosen Sample [148200.]
# Chosen Sample [146758.]
# Chosen Sample [148770.]
# Chosen Sample [147964.]
# Chosen Sample [149046.]
# Chosen Sample [148528.]
# Chosen Sample [148528.]
# Chosen Sample [147734.]
# Chosen Sample [146494.]
# Chosen Sample [147724.]
# Chosen Sample [147464.]
# Chosen Sample [148272.]
# Chosen Sample [147770.]
# Chosen Sample [148018.]
# Chosen Sample [147698.]
# Chosen Sample [148088.]
# Chosen Sample [147598.]
# Chosen Sample [147376.]
# Chosen Sample [147346.]
# Chosen Sample [148334.]
# Chosen Sample [147508.]
# Chosen Sample [147560.]
# Chosen Sample [147800.]
# Chosen Sample [147892.]
# Chosen Sample [147376.]
# Chosen Sample [147432.]
# Chosen Sample [147592.]
# Chosen Sample [147546.]
# Chosen Sample [147564.]
# Chosen Sample [148000.]
# Chosen Sample [147806.]
# Chosen Sample [147818.]
# Chosen Sample [147954.]
# Chosen Sample [147118.]
# Chosen Sample [147744.]
# Chosen Sample [147048.]
# Chosen Sample [147874.]
# Chosen Sample [148126.]
# Chosen Sample [147270.]
# Chosen Sample [147766.]
# Chosen Sample [147504.]
# Chosen Sample [148216.]
# Chosen Sample [147886.]
# Chosen Sample [148210.]
# Chosen Sample [147752.]
# Chosen Sample [147816.]
# Chosen Sample [147326.]
# Chosen Sample [147066.]
# Chosen Sample [147044.]
# Chosen Sample [148466.]
# Chosen Sample [147408.]
# Chosen Sample [148044.]
# Chosen Sample [147606.]
# Chosen Sample [148164.]
# Chosen Sample [147878.]
# Getting PAC Noise...
# The dimensions are - 1
# [array([[147368.]]), array([[148212.]]), array([[147636.]]), array([[147944.]]), array([[147716.]]), array([[147864.]]), array([[148014.]]), array([[147566.]]), array([[147664.]]), array([[147916.]]), array([[147898.]]), array([[147682.]]), array([[147654.]]), array([[147926.]]), array([[147752.]]), array([[147828.]]), array([[147886.]]), array([[147694.]]), array([[148288.]]), array([[147292.]]), array([[147740.]]), array([[147840.]]), array([[147362.]]), array([[148218.]]), array([[147602.]]), array([[147978.]]), array([[147546.]]), array([[148034.]]), array([[147110.]]), array([[148470.]]), array([[147924.]]), array([[147656.]]), array([[148108.]]), array([[147472.]]), array([[147408.]]), array([[148172.]]), array([[147326.]]), array([[148254.]]), array([[147618.]]), array([[147962.]]), array([[147544.]]), array([[148036.]]), array([[148014.]]), array([[147566.]]), array([[148116.]]), array([[147464.]]), array([[147512.]]), array([[148068.]]), array([[148334.]]), array([[147246.]]), array([[148218.]]), array([[147362.]]), array([[147704.]]), array([[147876.]]), array([[147948.]]), array([[147632.]]), array([[149058.]]), array([[146522.]]), array([[147390.]]), array([[148190.]]), array([[148622.]]), array([[146958.]]), array([[147736.]]), array([[147844.]]), array([[146902.]]), array([[148678.]]), array([[147698.]]), array([[147882.]]), array([[147818.]]), array([[147762.]]), array([[148066.]]), array([[147514.]]), array([[147326.]]), array([[148254.]]), array([[147326.]]), array([[148254.]]), array([[147840.]]), array([[147740.]]), array([[148222.]]), array([[147358.]]), array([[147928.]]), array([[147652.]]), array([[148398.]]), array([[147182.]]), array([[147712.]]), array([[147868.]]), array([[147826.]]), array([[147754.]]), array([[147696.]]), array([[147884.]]), array([[147956.]]), array([[147624.]]), array([[148220.]]), array([[147360.]]), array([[148256.]]), array([[147324.]]), array([[147488.]]), array([[148092.]]), array([[148156.]]), array([[147424.]]), array([[147568.]]), array([[148012.]]), array([[147128.]]), array([[148452.]]), array([[147648.]]), array([[147932.]]), array([[147818.]]), array([[147762.]]), array([[148062.]]), array([[147518.]]), array([[147936.]]), array([[147644.]]), array([[147638.]]), array([[147942.]]), array([[147530.]]), array([[148050.]]), array([[146992.]]), array([[148588.]]), array([[147248.]]), array([[148332.]]), array([[148036.]]), array([[147544.]]), array([[147808.]]), array([[147772.]]), array([[147386.]]), array([[148194.]]), array([[148078.]]), array([[147502.]]), array([[147170.]]), array([[148410.]]), array([[147734.]]), array([[147846.]]), array([[147518.]]), array([[148062.]]), array([[148336.]]), array([[147244.]]), array([[147910.]]), array([[147670.]]), array([[147780.]]), array([[147800.]]), array([[146756.]]), array([[148824.]]), array([[147656.]]), array([[147924.]]), array([[147964.]]), array([[147616.]]), array([[147668.]]), array([[147912.]]), array([[147528.]]), array([[148052.]]), array([[147718.]]), array([[147862.]]), array([[147954.]]), array([[147626.]]), array([[147922.]]), array([[147658.]]), array([[148878.]]), array([[146702.]]), array([[147846.]]), array([[147734.]]), array([[147108.]]), array([[148472.]]), array([[148320.]]), array([[147260.]]), array([[147540.]]), array([[148040.]]), array([[147962.]]), array([[147618.]]), array([[147690.]]), array([[147890.]]), array([[147774.]]), array([[147806.]]), array([[147400.]]), array([[148180.]]), array([[147884.]]), array([[147696.]]), array([[147276.]]), array([[148304.]]), array([[148658.]]), array([[146922.]]), array([[148460.]]), array([[147120.]]), array([[148134.]]), array([[147446.]]), array([[148376.]]), array([[147204.]]), array([[147990.]]), array([[147590.]]), array([[148096.]]), array([[147484.]]), array([[147900.]]), array([[147680.]]), array([[148014.]]), array([[147566.]]), array([[147744.]]), array([[147836.]]), array([[147806.]]), array([[147774.]]), array([[147622.]]), array([[147958.]]), ...
# est_y.shape: (1, 8192)
# est_y: [[147368. 148212. 147636. ... 147238. 148472. 147108.]]
# fin_var: [156150.72070312]
# sqrt_total_var: 395.15910808574944
# For mi=0.015625, we should add noise from a normal distribution with scale...
# 	32.0 * 395.15910808574944 * [395.15910809] = [4996823.0625]
# pac_noise: [4996823.0625]
# mi=0.015625, scale=[4996823.0625]
# Chosen Sample [147950.]
# Chosen Sample [147512.]
# Chosen Sample [147530.]
# Chosen Sample [147740.]
# Chosen Sample [147792.]
# Chosen Sample [147722.]
# Chosen Sample [148006.]
# Chosen Sample [147660.]
# Chosen Sample [147234.]
# Chosen Sample [147938.]
# Chosen Sample [147826.]
# Chosen Sample [148004.]
# Chosen Sample [147772.]
# Chosen Sample [148036.]
# Chosen Sample [147906.]
# Chosen Sample [147734.]
# Chosen Sample [147754.]
# Chosen Sample [146896.]
# Chosen Sample [147850.]
# Chosen Sample [148166.]
# Chosen Sample [147186.]
# Chosen Sample [147664.]
# Chosen Sample [147936.]
# Chosen Sample [147552.]
# Chosen Sample [147464.]
# Chosen Sample [147398.]
# Chosen Sample [147456.]
# Chosen Sample [147512.]
# Chosen Sample [147342.]
# Chosen Sample [148310.]
# Chosen Sample [147994.]
# Chosen Sample [147718.]
# Chosen Sample [147822.]
# Chosen Sample [147788.]
# Chosen Sample [148446.]
# Chosen Sample [147910.]
# Chosen Sample [147022.]
# Chosen Sample [147802.]
# Chosen Sample [147758.]
# Chosen Sample [147786.]
# Chosen Sample [148836.]
# Chosen Sample [148076.]
# Chosen Sample [147380.]
# Chosen Sample [148034.]
# Chosen Sample [147720.]
# Chosen Sample [147814.]
# Chosen Sample [147314.]
# Chosen Sample [147842.]
# Chosen Sample [147080.]
# Chosen Sample [148076.]
# Chosen Sample [148254.]
# Chosen Sample [147682.]
# Chosen Sample [147764.]
# Chosen Sample [147484.]
# Chosen Sample [147176.]
# Chosen Sample [147298.]
# Chosen Sample [147530.]
# Chosen Sample [147650.]
# Chosen Sample [147890.]
# Chosen Sample [148292.]
# Chosen Sample [147634.]
# Chosen Sample [147814.]
# Chosen Sample [147998.]
# Chosen Sample [147942.]
# Chosen Sample [147886.]
# Chosen Sample [147948.]
# Chosen Sample [147754.]
# Chosen Sample [147760.]
# Chosen Sample [147786.]
# Chosen Sample [147912.]
# Chosen Sample [147604.]
# Chosen Sample [148374.]
# Chosen Sample [147978.]
# Chosen Sample [148038.]
# Chosen Sample [147794.]
# Chosen Sample [148328.]
# Chosen Sample [148222.]
# Chosen Sample [148138.]
# Chosen Sample [147792.]
# Chosen Sample [147962.]
# Chosen Sample [147818.]
# Chosen Sample [147792.]
# Chosen Sample [147432.]
# Chosen Sample [147634.]
# Chosen Sample [148198.]
# Chosen Sample [147728.]
# Chosen Sample [147558.]
# Chosen Sample [148156.]
# Chosen Sample [147760.]
# Chosen Sample [147538.]
# Chosen Sample [148494.]
# Chosen Sample [148192.]
# Chosen Sample [147984.]
# Chosen Sample [148108.]
# Chosen Sample [147288.]
# Chosen Sample [147684.]
# Chosen Sample [147930.]
# Chosen Sample [147962.]
# Chosen Sample [148034.]
# Chosen Sample [148088.]
# Chosen Sample [147892.]
# Chosen Sample [147596.]
# Chosen Sample [147622.]
# Chosen Sample [147718.]
# Chosen Sample [148042.]
# Chosen Sample [147796.]
# Chosen Sample [147948.]
# Chosen Sample [147830.]
# Chosen Sample [147636.]
# Chosen Sample [147548.]
# Chosen Sample [148200.]
# Chosen Sample [147506.]
# Chosen Sample [147936.]
# Chosen Sample [147384.]
# Chosen Sample [147714.]
# Chosen Sample [147978.]
# Chosen Sample [147814.]
# Chosen Sample [148044.]
# Chosen Sample [147728.]
# Chosen Sample [147932.]
# Chosen Sample [148066.]
# Chosen Sample [147212.]
# Chosen Sample [148208.]
# Chosen Sample [148324.]
# Chosen Sample [148526.]
# Chosen Sample [148262.]
# Chosen Sample [148260.]
# Chosen Sample [147300.]
# Chosen Sample [147958.]
# Chosen Sample [147420.]
# Chosen Sample [147948.]
# Chosen Sample [147918.]
# Chosen Sample [148262.]
# Chosen Sample [147660.]
# Chosen Sample [148502.]
# Chosen Sample [147116.]
# Chosen Sample [148658.]
# Chosen Sample [148104.]
# Chosen Sample [147696.]
# Chosen Sample [148010.]
# Chosen Sample [147982.]
# Chosen Sample [147086.]
# Chosen Sample [147948.]
# Chosen Sample [147458.]
# Chosen Sample [148442.]
# Chosen Sample [147918.]
# Chosen Sample [148176.]
# Chosen Sample [147408.]
# Chosen Sample [147936.]
# Chosen Sample [147770.]
# Chosen Sample [147408.]
# Chosen Sample [147720.]
# Chosen Sample [147766.]
# Chosen Sample [148028.]
# Chosen Sample [147664.]
# Chosen Sample [148466.]
# Chosen Sample [147708.]
# Chosen Sample [147712.]
# Chosen Sample [148364.]
# Chosen Sample [148028.]
# Chosen Sample [147022.]
# Chosen Sample [147594.]
# Chosen Sample [147902.]
# Chosen Sample [147410.]
# Chosen Sample [148494.]
# Chosen Sample [147920.]
# Chosen Sample [147936.]
# Chosen Sample [147992.]
# Chosen Sample [148340.]
# Chosen Sample [148192.]
# Chosen Sample [147620.]
# Chosen Sample [147790.]
# Chosen Sample [147820.]
# Chosen Sample [148134.]
# Chosen Sample [147878.]
# Chosen Sample [148488.]
# Chosen Sample [147118.]
# Chosen Sample [147324.]
# Chosen Sample [147320.]
# Chosen Sample [147670.]
# Chosen Sample [146922.]
# Chosen Sample [147466.]
# Chosen Sample [147522.]
# Chosen Sample [147358.]
# Chosen Sample [148116.]
# Chosen Sample [147576.]
# Chosen Sample [147358.]
# Chosen Sample [148346.]
# Chosen Sample [148562.]
# Chosen Sample [147810.]
# Chosen Sample [147782.]
# Chosen Sample [148062.]
# Chosen Sample [147880.]
# Chosen Sample [148022.]
# Chosen Sample [148282.]
# Chosen Sample [148076.]
# Chosen Sample [148014.]
# Chosen Sample [147818.]
# Chosen Sample [147372.]
# Chosen Sample [147916.]
# Chosen Sample [148200.]
# Chosen Sample [148234.]
# Chosen Sample [147526.]
# Chosen Sample [148114.]
# Chosen Sample [147792.]
# Chosen Sample [147862.]
# Chosen Sample [148092.]
# Chosen Sample [147496.]
# Chosen Sample [147414.]
# Chosen Sample [147242.]
# Chosen Sample [148140.]
# Chosen Sample [147850.]
# Chosen Sample [147660.]
# Chosen Sample [148212.]
# Chosen Sample [147742.]
# Chosen Sample [147842.]
# Chosen Sample [148034.]
# Chosen Sample [147094.]
# Chosen Sample [148054.]
# Chosen Sample [148422.]
# Chosen Sample [147874.]
# Chosen Sample [148438.]
# Chosen Sample [148112.]
# Chosen Sample [147574.]
# Chosen Sample [147658.]
# Chosen Sample [147658.]
# Chosen Sample [148376.]
# Chosen Sample [147620.]
# Chosen Sample [147280.]
# Chosen Sample [147176.]
# Chosen Sample [147620.]
# Chosen Sample [147850.]
# Chosen Sample [147788.]
# Chosen Sample [147986.]
# Chosen Sample [147866.]
# Chosen Sample [147648.]
# Chosen Sample [148038.]
# Chosen Sample [147254.]
# Chosen Sample [147844.]
# Chosen Sample [147654.]
# Chosen Sample [147802.]
# Chosen Sample [147998.]
# Chosen Sample [148148.]
# Chosen Sample [147768.]
# Chosen Sample [148120.]
# Chosen Sample [147946.]
# Chosen Sample [147500.]
# Chosen Sample [147362.]
# Chosen Sample [147804.]
# Chosen Sample [148216.]
# Chosen Sample [147182.]
# Chosen Sample [147732.]
# Chosen Sample [147028.]
# Chosen Sample [147468.]
# Chosen Sample [148102.]
# Chosen Sample [148010.]
# Chosen Sample [148282.]
# Chosen Sample [147250.]
# Chosen Sample [147688.]
# Chosen Sample [147838.]
# Chosen Sample [148136.]
# Chosen Sample [146920.]
# Chosen Sample [147400.]
# Chosen Sample [147462.]
# Chosen Sample [148236.]
# Chosen Sample [148138.]
# Chosen Sample [147616.]
# Chosen Sample [147994.]
# Chosen Sample [147314.]
# Chosen Sample [147964.]
# Chosen Sample [147812.]
# Chosen Sample [147414.]
# Chosen Sample [147484.]
# Chosen Sample [147982.]
# Chosen Sample [147748.]
# Chosen Sample [148062.]
# Chosen Sample [147752.]
# Chosen Sample [147860.]
# Chosen Sample [148030.]
# Chosen Sample [147854.]
# Chosen Sample [147610.]
# Chosen Sample [146918.]
# Chosen Sample [148126.]
# Chosen Sample [147214.]
# Chosen Sample [148644.]
# Chosen Sample [147114.]
# Chosen Sample [147838.]
# Chosen Sample [147044.]
# Chosen Sample [147372.]
# Chosen Sample [148024.]
# Chosen Sample [147832.]
# Chosen Sample [147666.]
# Chosen Sample [147918.]
# Chosen Sample [148174.]
# Chosen Sample [147900.]
# Chosen Sample [147602.]
# Chosen Sample [147806.]
# Chosen Sample [147718.]
# Chosen Sample [147388.]
# Chosen Sample [147568.]
# Chosen Sample [147378.]
# Chosen Sample [147794.]
# Chosen Sample [147564.]
# Chosen Sample [147594.]
# Chosen Sample [148232.]
# Chosen Sample [148016.]
# Chosen Sample [147478.]
# Chosen Sample [147780.]
# Chosen Sample [147710.]
# Chosen Sample [147964.]
# Chosen Sample [148318.]
# Chosen Sample [147490.]
# Chosen Sample [148380.]
# Chosen Sample [147794.]
# Chosen Sample [148102.]
# Chosen Sample [147272.]
# Chosen Sample [148216.]
# Chosen Sample [147492.]
# Chosen Sample [147064.]
# Chosen Sample [147092.]
# Chosen Sample [148096.]
# Chosen Sample [148034.]
# Chosen Sample [147458.]
# Chosen Sample [147924.]
# Chosen Sample [148286.]
# Chosen Sample [148092.]
# Chosen Sample [148344.]
# Chosen Sample [147958.]
# Chosen Sample [147880.]
# Chosen Sample [147528.]
# Chosen Sample [148158.]
# Chosen Sample [148404.]
# Chosen Sample [147436.]
# Chosen Sample [148102.]
# Chosen Sample [147982.]
# Chosen Sample [147422.]
# Chosen Sample [147864.]
# Chosen Sample [147252.]
# Chosen Sample [147664.]
# Chosen Sample [147044.]
# Chosen Sample [147316.]
# Chosen Sample [148498.]
# Chosen Sample [147748.]
# Chosen Sample [147760.]
# Chosen Sample [147832.]
# Chosen Sample [147200.]
# Chosen Sample [147810.]
# Chosen Sample [148312.]
# Chosen Sample [147602.]
# Chosen Sample [147252.]
# Chosen Sample [147218.]
# Chosen Sample [147428.]
# Chosen Sample [148072.]
# Chosen Sample [147594.]
# Chosen Sample [148180.]
# Chosen Sample [148104.]
# Chosen Sample [148288.]
# Chosen Sample [147898.]
# Chosen Sample [147656.]
# Chosen Sample [148336.]
# Chosen Sample [147782.]
# Chosen Sample [147576.]
# Chosen Sample [148088.]
# Chosen Sample [148126.]
# Chosen Sample [147504.]
# Chosen Sample [147512.]
# Chosen Sample [147970.]
# Chosen Sample [147426.]
# Chosen Sample [147666.]
# Chosen Sample [147896.]
# Chosen Sample [148080.]
# Chosen Sample [148248.]
# Chosen Sample [146986.]
# Chosen Sample [147530.]
# Chosen Sample [147630.]
# Chosen Sample [147582.]
# Chosen Sample [147536.]
# Chosen Sample [147262.]
# Chosen Sample [147014.]
# Chosen Sample [147878.]
# Chosen Sample [147876.]
# Chosen Sample [147836.]
# Chosen Sample [147634.]
# Chosen Sample [148418.]
# Chosen Sample [147822.]
# Chosen Sample [148008.]
# Chosen Sample [147618.]
# Chosen Sample [147948.]
# Chosen Sample [148458.]
# Chosen Sample [147518.]
# Chosen Sample [147340.]
# Chosen Sample [147638.]
# Chosen Sample [147672.]
# Chosen Sample [148176.]
# Chosen Sample [147756.]
# Chosen Sample [147462.]
# Chosen Sample [147776.]
# Chosen Sample [147864.]
# Chosen Sample [147844.]
# Chosen Sample [147864.]
# Chosen Sample [148470.]
# Chosen Sample [147780.]
# Chosen Sample [147394.]
# Chosen Sample [148088.]
# Chosen Sample [147630.]
# Chosen Sample [147446.]
# Chosen Sample [147960.]
# Chosen Sample [147896.]
# Chosen Sample [147564.]
# Chosen Sample [147624.]
# Chosen Sample [147990.]
# Chosen Sample [147736.]
# Chosen Sample [147466.]
# Chosen Sample [148046.]
# Chosen Sample [147572.]
# Chosen Sample [147786.]
# Chosen Sample [147980.]
# Chosen Sample [147140.]
# Chosen Sample [148130.]
# Chosen Sample [147582.]
# Chosen Sample [148176.]
# Chosen Sample [147738.]
# Chosen Sample [147838.]
# Chosen Sample [147994.]
# Chosen Sample [147926.]
# Chosen Sample [148184.]
# Chosen Sample [147408.]
# Chosen Sample [147852.]
# Chosen Sample [148318.]
# Chosen Sample [148034.]
# Chosen Sample [147538.]
# Chosen Sample [148458.]
# Chosen Sample [147888.]
# Chosen Sample [147294.]
# Chosen Sample [147910.]
# Chosen Sample [147774.]
# Chosen Sample [147556.]
# Chosen Sample [148010.]
# Chosen Sample [147812.]
# Chosen Sample [147388.]
# Chosen Sample [147846.]
# Chosen Sample [147514.]
# Chosen Sample [147154.]
# Chosen Sample [148466.]
# Chosen Sample [147602.]
# Chosen Sample [148054.]
# Chosen Sample [148154.]
# Chosen Sample [148106.]
# Chosen Sample [147034.]
# Chosen Sample [146858.]
# Chosen Sample [147964.]
# Chosen Sample [147778.]
# Chosen Sample [148360.]
# Chosen Sample [147256.]
# Chosen Sample [147488.]
# Chosen Sample [147726.]
# Chosen Sample [147454.]
# Chosen Sample [148176.]
# Chosen Sample [147446.]
# Chosen Sample [147494.]
# Chosen Sample [148418.]
# Chosen Sample [147218.]
# Chosen Sample [147966.]
# Chosen Sample [147732.]
# Chosen Sample [147446.]
# Chosen Sample [147476.]
# Chosen Sample [148184.]
# Chosen Sample [147450.]
# Chosen Sample [147864.]
# Chosen Sample [148720.]
# Chosen Sample [148666.]
# Chosen Sample [147860.]
# Chosen Sample [148132.]
# Chosen Sample [147734.]
# Chosen Sample [148470.]
# Chosen Sample [148116.]
# Chosen Sample [147742.]
# Chosen Sample [147308.]
# Chosen Sample [148088.]
# Chosen Sample [147550.]
# Chosen Sample [147458.]
# Chosen Sample [147604.]
# Chosen Sample [147046.]
# Chosen Sample [147830.]
# Chosen Sample [148168.]
# Chosen Sample [147806.]
# Chosen Sample [146932.]
# Chosen Sample [148150.]
# Chosen Sample [147818.]
# Chosen Sample [147610.]
# Chosen Sample [148106.]
# Chosen Sample [147844.]
# Chosen Sample [147372.]
# Chosen Sample [147688.]
# Chosen Sample [147828.]
# Chosen Sample [148514.]
# Chosen Sample [147780.]
# Chosen Sample [147106.]
# Chosen Sample [148566.]
# Chosen Sample [147944.]
# Chosen Sample [147974.]
# Chosen Sample [147850.]
# Chosen Sample [147476.]
# Chosen Sample [147704.]
# Chosen Sample [147372.]
# Chosen Sample [147638.]
# Chosen Sample [148204.]
# Chosen Sample [147534.]
# Chosen Sample [147762.]
# Chosen Sample [148176.]
# Chosen Sample [147574.]
# Chosen Sample [147838.]
# Chosen Sample [148184.]
# Chosen Sample [147666.]
# Chosen Sample [147824.]
# Chosen Sample [146936.]
# Chosen Sample [148260.]
# Chosen Sample [147650.]
# Chosen Sample [148320.]
# Chosen Sample [147242.]
# Chosen Sample [148428.]
# Chosen Sample [147844.]
# Chosen Sample [147384.]
# Chosen Sample [147574.]
# Chosen Sample [147774.]
# Chosen Sample [147922.]
# Chosen Sample [147474.]
# Chosen Sample [147380.]
# Chosen Sample [148266.]
# Chosen Sample [147706.]
# Chosen Sample [148276.]
# Chosen Sample [147932.]
# Chosen Sample [147036.]
# Chosen Sample [147740.]
# Chosen Sample [148084.]
# Chosen Sample [148152.]
# Chosen Sample [147874.]
# Chosen Sample [147742.]
# Chosen Sample [147478.]
# Chosen Sample [148288.]
# Chosen Sample [147800.]
# Chosen Sample [147868.]
# Chosen Sample [147464.]
# Chosen Sample [147806.]
# Chosen Sample [147360.]
# Chosen Sample [147412.]
# Chosen Sample [148092.]
# Chosen Sample [148126.]
# Chosen Sample [147268.]
# Chosen Sample [146682.]
# Chosen Sample [147824.]
# Chosen Sample [148156.]
# Chosen Sample [147870.]
# Chosen Sample [148052.]
# Chosen Sample [147670.]
# Chosen Sample [146908.]
# Chosen Sample [147662.]
# Chosen Sample [147644.]
# Chosen Sample [148254.]
# Chosen Sample [149006.]
# Chosen Sample [147172.]
# Chosen Sample [148088.]
# Chosen Sample [148284.]
# Chosen Sample [148806.]
# Chosen Sample [147776.]
# Chosen Sample [148126.]
# Chosen Sample [147934.]
# Chosen Sample [147356.]
# Chosen Sample [147720.]
# Chosen Sample [147350.]
# Chosen Sample [147220.]
# Chosen Sample [147674.]
# Chosen Sample [147496.]
# Chosen Sample [147482.]
# Chosen Sample [147080.]
# Chosen Sample [148074.]
# Chosen Sample [147768.]
# Chosen Sample [147700.]
# Chosen Sample [147124.]
# Chosen Sample [146906.]
# Chosen Sample [147062.]
# Chosen Sample [147918.]
# Chosen Sample [148060.]
# Chosen Sample [147746.]
# Chosen Sample [148082.]
# Chosen Sample [147596.]
# Chosen Sample [148172.]
# Chosen Sample [147732.]
# Chosen Sample [147792.]
# Chosen Sample [148398.]
# Chosen Sample [147732.]
# Chosen Sample [147874.]
# Chosen Sample [147784.]
# Chosen Sample [147686.]
# Chosen Sample [147532.]
# Chosen Sample [148276.]
# Chosen Sample [147828.]
# Chosen Sample [147100.]
# Chosen Sample [147666.]
# Chosen Sample [148254.]
# Chosen Sample [147800.]
# Chosen Sample [147768.]
# Chosen Sample [147544.]
# Chosen Sample [147408.]
# Chosen Sample [147520.]
# Chosen Sample [147918.]
# Chosen Sample [147792.]
# Chosen Sample [147902.]
# Chosen Sample [147252.]
# Chosen Sample [147526.]
# Chosen Sample [147234.]
# Chosen Sample [147512.]
# Chosen Sample [148454.]
# Chosen Sample [147934.]
# Chosen Sample [148194.]
# Chosen Sample [147862.]
# Chosen Sample [148276.]
# Chosen Sample [147442.]
# Chosen Sample [147820.]
# Chosen Sample [147558.]
# Chosen Sample [147594.]
# Chosen Sample [148254.]
# Chosen Sample [147698.]
# Chosen Sample [148104.]
# Chosen Sample [148532.]
# Chosen Sample [148386.]
# Chosen Sample [147590.]
# Chosen Sample [147464.]
# Chosen Sample [148490.]
# Chosen Sample [147490.]
# Chosen Sample [148284.]
# ...
# Chosen Sample [147782.]
# Chosen Sample [148164.]
# Chosen Sample [147596.]
# Chosen Sample [147888.]
# Chosen Sample [147584.]
# Chosen Sample [147838.]
# Chosen Sample [147350.]
# Chosen Sample [147668.]
# Chosen Sample [147414.]
# Chosen Sample [148328.]
# Chosen Sample [147738.]
# Chosen Sample [147422.]
# Chosen Sample [147994.]
# Chosen Sample [146878.]
# Chosen Sample [148208.]
# Chosen Sample [147832.]
# Chosen Sample [147558.]
# Chosen Sample [147696.]
# Chosen Sample [148128.]
# Chosen Sample [146372.]
# Chosen Sample [147622.]
# Chosen Sample [148606.]
# Chosen Sample [147382.]
# Chosen Sample [147692.]
# Chosen Sample [147540.]
# Chosen Sample [147596.]
# Chosen Sample [147648.]
# Chosen Sample [148508.]
# Chosen Sample [148198.]
# Chosen Sample [148308.]
# Chosen Sample [148166.]
# Chosen Sample [147800.]
# Chosen Sample [147962.]
# Chosen Sample [147868.]
# Chosen Sample [147838.]
# Chosen Sample [147746.]
# Chosen Sample [147960.]
# Chosen Sample [148026.]
# Chosen Sample [148016.]
# Chosen Sample [148110.]
# Chosen Sample [147416.]
# Chosen Sample [148098.]
# Chosen Sample [148196.]
# Chosen Sample [148082.]
# Chosen Sample [148766.]
# Chosen Sample [147966.]
# Chosen Sample [147844.]
# Chosen Sample [147734.]
# Chosen Sample [147408.]
# Chosen Sample [148364.]
# Chosen Sample [147802.]
# Chosen Sample [147822.]
# Chosen Sample [148198.]
# Chosen Sample [148224.]
# Chosen Sample [147574.]
# Chosen Sample [148036.]
# Chosen Sample [147986.]
# Chosen Sample [148374.]
# Chosen Sample [148362.]
# Chosen Sample [147192.]
# Chosen Sample [149074.]
# Chosen Sample [148682.]
# Chosen Sample [147868.]
# Chosen Sample [147494.]
# Chosen Sample [147648.]
# Chosen Sample [147716.]
# Chosen Sample [147610.]
# Chosen Sample [147676.]
# Chosen Sample [147552.]
# Chosen Sample [148264.]
# Chosen Sample [148498.]
# Chosen Sample [147970.]
# Chosen Sample [147526.]
# Chosen Sample [148440.]
# Chosen Sample [148072.]
# Chosen Sample [147832.]
# Chosen Sample [147144.]
# Chosen Sample [147468.]
# Chosen Sample [147880.]
# Chosen Sample [148026.]
# Chosen Sample [148216.]
# Chosen Sample [148232.]
# Chosen Sample [147782.]
# Chosen Sample [148226.]
# Chosen Sample [147964.]
# Chosen Sample [147102.]
# Chosen Sample [147588.]
# Chosen Sample [147402.]
# Chosen Sample [147882.]
# Chosen Sample [147308.]
# Chosen Sample [147946.]
# Chosen Sample [147602.]
# Chosen Sample [148046.]
# Chosen Sample [147518.]
# Chosen Sample [147684.]
# Chosen Sample [147590.]
# Chosen Sample [147572.]
# Chosen Sample [147732.]
# Chosen Sample [147618.]
# Chosen Sample [147484.]
# Chosen Sample [148318.]
# Chosen Sample [147216.]
# Chosen Sample [147692.]
# Chosen Sample [147800.]
# Chosen Sample [147222.]
# Chosen Sample [147570.]
# Chosen Sample [148300.]
# Chosen Sample [147664.]
# Chosen Sample [147336.]
# Chosen Sample [146906.]
# Chosen Sample [147982.]
# Chosen Sample [148102.]
# Chosen Sample [147646.]
# Chosen Sample [147710.]
# Chosen Sample [147206.]
# Chosen Sample [147564.]
# Chosen Sample [148304.]
# Chosen Sample [148018.]
# Chosen Sample [148104.]
# Chosen Sample [147702.]
# Chosen Sample [147998.]
# Chosen Sample [146912.]
# Chosen Sample [147824.]
# Chosen Sample [147760.]
# Chosen Sample [148050.]
# Chosen Sample [147458.]
# Chosen Sample [147678.]
# Chosen Sample [147670.]
# Chosen Sample [147786.]
# Chosen Sample [147884.]
# Chosen Sample [147882.]
# Chosen Sample [147892.]
# Chosen Sample [148102.]
# Chosen Sample [147992.]
# Chosen Sample [147300.]
# Chosen Sample [147810.]
# Chosen Sample [147598.]
# Chosen Sample [147534.]
# Chosen Sample [148060.]
# Chosen Sample [147864.]
# Chosen Sample [148328.]
# Chosen Sample [147308.]
# Chosen Sample [147490.]
# Chosen Sample [148106.]
# Chosen Sample [147194.]
# Chosen Sample [147150.]
# Chosen Sample [147814.]
# Chosen Sample [147714.]
# Chosen Sample [147262.]
# Chosen Sample [147438.]
# Chosen Sample [147722.]
# Chosen Sample [148062.]
# Chosen Sample [147690.]
# Chosen Sample [147632.]
# Chosen Sample [147830.]
# Chosen Sample [147456.]
# Chosen Sample [148362.]
# Chosen Sample [147604.]
# Chosen Sample [147496.]
# Chosen Sample [147828.]
# Chosen Sample [148038.]
# Chosen Sample [147850.]
# Chosen Sample [147612.]
# Chosen Sample [147690.]
# Chosen Sample [147408.]
# Chosen Sample [147840.]
# Chosen Sample [147944.]
# Chosen Sample [147494.]
# Chosen Sample [147228.]
# Chosen Sample [147892.]
# Chosen Sample [148012.]
# Chosen Sample [147760.]
# Chosen Sample [147598.]
# Chosen Sample [147958.]
# Chosen Sample [147906.]
# Chosen Sample [147578.]
# Chosen Sample [147740.]
# Chosen Sample [148202.]
# Chosen Sample [147746.]
# Chosen Sample [147768.]
# Chosen Sample [147920.]
# Chosen Sample [147590.]
# Chosen Sample [147980.]
# Chosen Sample [148102.]
# Chosen Sample [147978.]
# Chosen Sample [147260.]
# Chosen Sample [148064.]
# Chosen Sample [147784.]
# Chosen Sample [147942.]
# Chosen Sample [147824.]
# Chosen Sample [147866.]
# Chosen Sample [147994.]
# Chosen Sample [147878.]
# Chosen Sample [147558.]
# Chosen Sample [148014.]
# Chosen Sample [147472.]
# Chosen Sample [147860.]
# Chosen Sample [147696.]
# Chosen Sample [147518.]
# Chosen Sample [147182.]
# Chosen Sample [147474.]
# Chosen Sample [147842.]
# Chosen Sample [148356.]
# Chosen Sample [148436.]
# Chosen Sample [148310.]
# Chosen Sample [147826.]
# Chosen Sample [147748.]
# Chosen Sample [148066.]
# Chosen Sample [147410.]
# Chosen Sample [147838.]
# Chosen Sample [147880.]
# Chosen Sample [147688.]
# Chosen Sample [147692.]
# Chosen Sample [147596.]
# Chosen Sample [148160.]
# Chosen Sample [147620.]
# Chosen Sample [147612.]
# Chosen Sample [147506.]
# Chosen Sample [147598.]
# Chosen Sample [147702.]
# Chosen Sample [147420.]
# Chosen Sample [147918.]
# Chosen Sample [147570.]
# Chosen Sample [148236.]
# Chosen Sample [147876.]
# Chosen Sample [148350.]
# Chosen Sample [148016.]
# Chosen Sample [148274.]
# Chosen Sample [147694.]
# Chosen Sample [147806.]
# Chosen Sample [148214.]
# Chosen Sample [147380.]
# Chosen Sample [148302.]
# Chosen Sample [147766.]
# Chosen Sample [147282.]
# Chosen Sample [148248.]
# Chosen Sample [147456.]
# Chosen Sample [146934.]
# Chosen Sample [147366.]
# Chosen Sample [147310.]
# Chosen Sample [147410.]
# Chosen Sample [147432.]
# Chosen Sample [148116.]
# Chosen Sample [147806.]
# Chosen Sample [147988.]
# Chosen Sample [148000.]
# Chosen Sample [147432.]
# Chosen Sample [147970.]
# Chosen Sample [147620.]
# Chosen Sample [147852.]
# Chosen Sample [148240.]
# Chosen Sample [147614.]
# Chosen Sample [148150.]
# Chosen Sample [147478.]
# Chosen Sample [147858.]
# Chosen Sample [147730.]
# Chosen Sample [148108.]
# Chosen Sample [147364.]
# Chosen Sample [147536.]
# Chosen Sample [147712.]
# Chosen Sample [148178.]
# Chosen Sample [148218.]
# Chosen Sample [147770.]
# Chosen Sample [147442.]
# Chosen Sample [148156.]
# Chosen Sample [147262.]
# Chosen Sample [147442.]
# Chosen Sample [147774.]
# Chosen Sample [147530.]
# Chosen Sample [147962.]
# Chosen Sample [147720.]
# Chosen Sample [147872.]
# Chosen Sample [148350.]
# Chosen Sample [147968.]
# Chosen Sample [148050.]
# Chosen Sample [148126.]
# Chosen Sample [148118.]
# Chosen Sample [147730.]
# Chosen Sample [147364.]
# Chosen Sample [147704.]
# Chosen Sample [147430.]
# Chosen Sample [148458.]
# Chosen Sample [147656.]
# Chosen Sample [147968.]
# Chosen Sample [147816.]
# Chosen Sample [147766.]
# Chosen Sample [148056.]
# Chosen Sample [147460.]
# Chosen Sample [148232.]
# Chosen Sample [148290.]
# Chosen Sample [147794.]
# Chosen Sample [147856.]
# Chosen Sample [147884.]
# Chosen Sample [147042.]
# Chosen Sample [147468.]
# Chosen Sample [148450.]
# Chosen Sample [146970.]
# Chosen Sample [148650.]
# Chosen Sample [147556.]
# Chosen Sample [148170.]
# Chosen Sample [148228.]
# Chosen Sample [148210.]
# Chosen Sample [148220.]
# Chosen Sample [147572.]
# Chosen Sample [147928.]
# Chosen Sample [147308.]
# Chosen Sample [148630.]
# Chosen Sample [147806.]
# Chosen Sample [147566.]
# Chosen Sample [147536.]
# Chosen Sample [148296.]
# Chosen Sample [147950.]
# Chosen Sample [148612.]
# Chosen Sample [148268.]
# Chosen Sample [148344.]
# Chosen Sample [147496.]
# Chosen Sample [146842.]
# Chosen Sample [148096.]
# Chosen Sample [147970.]
# Chosen Sample [147524.]
# Chosen Sample [147816.]
# Chosen Sample [147872.]
# Chosen Sample [148134.]
# Chosen Sample [147320.]
# Chosen Sample [146898.]
# Chosen Sample [147816.]
# Chosen Sample [147800.]
# Chosen Sample [147960.]
# Chosen Sample [147706.]
# Chosen Sample [147692.]
# Chosen Sample [148084.]
# Chosen Sample [147884.]
# Chosen Sample [147166.]
# Chosen Sample [148084.]
# Chosen Sample [148008.]
# Chosen Sample [147332.]
# Chosen Sample [147188.]
# Chosen Sample [148110.]
# Chosen Sample [147964.]
# Chosen Sample [147982.]
# Chosen Sample [148104.]
# Chosen Sample [147524.]
# Chosen Sample [148362.]
# Chosen Sample [148878.]
# Chosen Sample [147522.]
# Chosen Sample [147622.]
# Chosen Sample [147672.]
# Chosen Sample [148464.]
# Chosen Sample [147626.]
# Chosen Sample [148300.]
# Chosen Sample [148288.]
# Chosen Sample [147692.]
# Chosen Sample [148058.]
# Chosen Sample [147420.]
# Chosen Sample [147330.]
# Chosen Sample [147968.]
# Chosen Sample [147268.]
# Chosen Sample [147554.]
# Chosen Sample [148164.]
# Chosen Sample [147384.]
# Chosen Sample [147864.]
# Chosen Sample [147240.]
# Chosen Sample [148192.]
# Chosen Sample [147818.]
# Chosen Sample [147258.]
# Chosen Sample [148118.]
# Chosen Sample [147902.]
# Chosen Sample [147758.]
# Chosen Sample [147598.]
# Chosen Sample [148390.]
# Chosen Sample [148096.]
# Chosen Sample [146920.]
# Chosen Sample [148644.]
# Chosen Sample [148108.]
# Chosen Sample [148504.]
# Chosen Sample [147806.]
# Chosen Sample [148072.]
# Chosen Sample [147736.]
# Chosen Sample [147932.]
# Chosen Sample [147158.]
# Chosen Sample [148184.]
# Chosen Sample [147592.]
# Chosen Sample [147582.]
# Chosen Sample [147202.]
# Chosen Sample [148226.]
# Chosen Sample [147408.]
# Chosen Sample [146852.]
# Chosen Sample [147238.]
# Chosen Sample [147610.]
# Chosen Sample [147206.]
# Chosen Sample [147994.]
# Chosen Sample [147678.]
# Chosen Sample [148140.]
# Chosen Sample [147126.]
# Chosen Sample [147916.]
# Chosen Sample [147708.]
# Chosen Sample [147874.]
# Chosen Sample [148182.]
# Chosen Sample [147854.]
# Chosen Sample [147762.]
# Chosen Sample [148436.]
# Chosen Sample [147762.]
# Chosen Sample [148104.]
# Chosen Sample [147728.]
# Chosen Sample [148208.]
# Chosen Sample [147898.]
# Chosen Sample [148270.]
# Chosen Sample [147628.]
# Chosen Sample [148162.]
# Chosen Sample [147802.]
# Chosen Sample [147742.]
# Chosen Sample [148444.]
# Chosen Sample [147836.]
# Chosen Sample [148410.]
# Chosen Sample [148064.]
# Chosen Sample [148308.]
# Chosen Sample [147940.]
# Chosen Sample [147350.]
# Chosen Sample [148162.]
# Chosen Sample [147730.]
# Chosen Sample [148196.]
# Chosen Sample [147664.]
# Chosen Sample [147918.]
# Chosen Sample [147678.]
# Chosen Sample [147678.]
# Chosen Sample [147778.]
# Chosen Sample [148236.]
# Chosen Sample [147694.]
# Chosen Sample [147160.]
# Chosen Sample [148086.]
# Chosen Sample [148066.]
# Chosen Sample [147662.]
# Chosen Sample [148606.]
# Chosen Sample [147816.]
# Chosen Sample [147898.]
# Chosen Sample [147540.]
# Chosen Sample [147676.]
# Chosen Sample [147428.]
# Chosen Sample [147592.]
# Chosen Sample [147904.]
# Chosen Sample [147236.]
# Chosen Sample [147890.]
# Chosen Sample [147958.]
# Chosen Sample [148030.]
# Chosen Sample [147492.]
# Chosen Sample [148328.]
# Chosen Sample [148170.]
# Chosen Sample [148326.]
# Chosen Sample [148946.]
# Chosen Sample [147280.]
# Chosen Sample [147766.]
# Chosen Sample [147954.]
# Chosen Sample [148250.]
# Chosen Sample [147196.]
# Chosen Sample [148010.]
# Chosen Sample [147904.]
# Chosen Sample [147648.]
# Chosen Sample [147406.]
# Chosen Sample [147798.]
# Chosen Sample [146812.]
# Chosen Sample [148358.]
# Chosen Sample [148266.]
# Chosen Sample [146940.]
# Chosen Sample [147622.]
# Chosen Sample [147832.]
# Chosen Sample [147692.]
# Chosen Sample [147770.]
# Chosen Sample [147612.]
# Chosen Sample [147854.]
# Chosen Sample [148196.]
# Chosen Sample [147998.]
# Chosen Sample [148166.]
# Chosen Sample [148002.]
# Chosen Sample [147922.]
# Chosen Sample [148602.]
# Chosen Sample [147318.]
# Chosen Sample [148960.]
# Chosen Sample [147794.]
# Chosen Sample [147546.]
# Chosen Sample [148038.]
# Chosen Sample [147674.]
# Chosen Sample [148100.]
# Chosen Sample [148150.]
# Chosen Sample [147664.]
# Chosen Sample [147514.]
# Chosen Sample [147670.]
# Chosen Sample [147748.]
# Chosen Sample [148028.]
# Chosen Sample [147584.]
# Chosen Sample [147164.]
# Chosen Sample [147420.]
# Chosen Sample [148452.]
# Chosen Sample [147514.]
# Chosen Sample [147510.]
# Chosen Sample [147186.]
# Chosen Sample [148022.]
# Chosen Sample [147854.]
# Chosen Sample [147166.]
# Chosen Sample [147234.]
# Chosen Sample [147464.]
# Chosen Sample [147330.]
# Chosen Sample [147958.]
# Chosen Sample [147984.]
# Chosen Sample [147846.]
# Chosen Sample [146754.]
# Chosen Sample [147744.]
# Chosen Sample [148104.]
# Chosen Sample [147480.]
# Chosen Sample [148324.]
# Chosen Sample [147554.]
# Chosen Sample [147942.]
# Chosen Sample [147774.]
# Chosen Sample [148372.]
# Chosen Sample [147762.]
# Chosen Sample [147854.]
# Chosen Sample [148130.]
# Chosen Sample [147408.]
# Chosen Sample [147882.]
# Chosen Sample [147798.]
# Chosen Sample [147884.]
# Chosen Sample [148212.]
# Chosen Sample [148440.]
# Chosen Sample [148286.]
# Chosen Sample [147806.]
# Chosen Sample [147878.]
# Chosen Sample [147052.]
# Chosen Sample [147754.]
# Chosen Sample [148080.]
# Chosen Sample [146564.]
# Chosen Sample [147954.]
# Chosen Sample [147552.]
# Chosen Sample [146880.]
# Chosen Sample [147694.]
# Chosen Sample [147612.]
# Chosen Sample [147818.]
# Chosen Sample [148014.]
# Chosen Sample [147996.]
# Chosen Sample [147556.]
# Chosen Sample [148128.]
# Chosen Sample [146874.]
# Chosen Sample [147588.]
# Chosen Sample [147524.]
# Chosen Sample [148294.]
# Chosen Sample [149192.]
# Chosen Sample [148304.]
# Chosen Sample [147754.]
# Chosen Sample [147798.]
# Chosen Sample [147542.]
# Chosen Sample [147874.]
# Chosen Sample [148006.]
# Chosen Sample [147226.]
# Chosen Sample [147100.]
# Chosen Sample [147550.]
# Chosen Sample [147832.]
# Chosen Sample [148116.]
# Chosen Sample [147792.]
# Chosen Sample [147636.]
# Chosen Sample [147616.]
# Chosen Sample [147964.]
# Chosen Sample [146982.]
# Chosen Sample [148362.]
# Chosen Sample [147106.]
# Chosen Sample [148288.]
# Chosen Sample [147774.]
# Chosen Sample [147400.]
# Chosen Sample [148076.]
# Chosen Sample [147842.]
# Chosen Sample [148120.]
# Chosen Sample [147924.]
# Chosen Sample [148898.]
# Chosen Sample [147620.]
# Chosen Sample [147842.]
# Chosen Sample [147434.]
# Chosen Sample [148078.]
# Chosen Sample [147450.]
# Chosen Sample [148668.]
# Chosen Sample [147998.]
# Chosen Sample [148466.]
# Chosen Sample [147458.]
# Chosen Sample [148374.]
# Chosen Sample [147638.]
# Chosen Sample [147958.]
# Chosen Sample [148210.]
# Chosen Sample [148168.]
# Chosen Sample [148008.]
# Chosen Sample [146720.]
# Chosen Sample [147976.]
# Chosen Sample [147076.]
# Chosen Sample [147786.]
# Chosen Sample [147124.]
# Chosen Sample [147616.]
# Chosen Sample [147830.]
# Chosen Sample [147988.]
# Chosen Sample [147856.]
# Chosen Sample [147858.]
# Chosen Sample [148140.]
# Chosen Sample [147792.]
# Chosen Sample [147990.]
# Chosen Sample [147674.]
# Chosen Sample [147308.]
# Chosen Sample [147916.]
# Chosen Sample [148078.]
# Chosen Sample [148046.]
# Chosen Sample [147888.]
# Chosen Sample [147406.]
# Chosen Sample [148018.]
# Chosen Sample [148212.]
# Chosen Sample [148390.]
# Chosen Sample [147408.]
# Chosen Sample [147540.]
# Chosen Sample [148360.]
# Chosen Sample [148144.]
# Chosen Sample [147122.]
# Chosen Sample [148114.]
# Chosen Sample [148462.]
# Chosen Sample [147874.]
# Chosen Sample [147592.]
# Chosen Sample [148048.]
# Chosen Sample [148266.]
# Chosen Sample [147502.]
# Chosen Sample [146522.]
# Chosen Sample [148230.]
# Chosen Sample [147172.]
# Chosen Sample [147430.]
# Chosen Sample [147534.]
# Chosen Sample [148330.]
# Chosen Sample [148450.]
# Chosen Sample [147924.]
# Chosen Sample [147746.]
# Chosen Sample [147582.]
# Chosen Sample [147162.]
# Chosen Sample [147986.]
# Chosen Sample [147706.]
# Chosen Sample [147906.]
# Chosen Sample [148376.]
# Chosen Sample [147658.]
# Chosen Sample [148060.]
# Chosen Sample [147762.]
# Chosen Sample [147990.]
# Chosen Sample [147736.]
# Chosen Sample [147252.]
# Chosen Sample [146978.]
# Chosen Sample [147740.]
# Chosen Sample [147988.]
# Chosen Sample [147824.]
# Chosen Sample [147710.]
# Chosen Sample [147426.]
# Chosen Sample [148044.]
# Chosen Sample [147754.]
# Chosen Sample [148178.]
# Chosen Sample [147388.]
# Chosen Sample [148098.]
# Chosen Sample [147828.]
# Chosen Sample [147284.]
# Chosen Sample [147746.]
# Chosen Sample [147796.]
# Chosen Sample [148174.]
# Chosen Sample [147666.]
# Chosen Sample [147644.]
# Chosen Sample [147692.]
# Chosen Sample [147154.]
# Chosen Sample [148072.]
# Chosen Sample [147964.]
# Chosen Sample [147590.]
# Chosen Sample [147270.]
# Chosen Sample [147718.]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                scale chosen_sample          chosen_noise  \
# 0  0.001248  [62544416.46906813]    [147524.0]    [905.372457915215]
# 1  0.001248  [62544416.46906813]    [147672.0]  [17873.269451553577]
# 2  0.001248  [62544416.46906813]    [147402.0]  [-11870.29584514429]
# 3  0.001248  [62544416.46906813]    [147980.0]   [969.4244379355231]
# 4  0.001248  [62544416.46906813]    [147846.0]   [2963.155465140969]
#
#                 release
# 0  [148429.37245791522]
# 1  [165545.26945155358]
# 2  [135531.70415485572]
# 3  [148949.42443793552]
# 4  [150809.15546514097]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi         scale chosen_sample  chosen_noise        release
# query             count_order   count_order   count_order    count_order
# 0      0.001248  6.254442e+07      147524.0    905.372458  148429.372458
# 1      0.001248  6.254442e+07      147672.0  17873.269452  165545.269452
# 2      0.001248  6.254442e+07      147402.0 -11870.295845  135531.704155
# 3      0.001248  6.254442e+07      147980.0    969.424438  148949.424438
# 4      0.001248  6.254442e+07      147846.0   2963.155465  150809.155465

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71972/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step              scale chosen_sample chosen_noise        release
# query       count_order   count_order  count_order    count_order
# mi
# 0.001248   6.254442e+07    147791.838  -186.715616  147605.122384
# 0.015625   4.996823e+06    147789.074   102.635686  147891.709686
# 0.031250   2.498412e+06    147777.996   -67.336689  147710.659311
# 0.062500   1.249206e+06    147780.574     3.170735  147783.744735
# 0.250000   3.123014e+05    147800.190   -18.444202  147781.745798
# 1.000000   7.807536e+04    147763.246   -15.942994  147747.303006
# 2.000000   3.903768e+04    147774.596     9.727500  147784.323500
# 4.000000   1.951884e+04    147782.748     9.039296  147791.787296
# 16.000000  4.879710e+03    147793.826     0.234550  147794.060550

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['count_order'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi                  0.001248
# count_order    148429.372458
# Name: 0, dtype: float64
# mi                  0.001248
# count_order    165545.269452
# Name: 1, dtype: float64
# mi                  0.001248
# count_order    135531.704155
# Name: 2, dtype: float64
# mi                  0.001248
# count_order    148949.424438
# Name: 3, dtype: float64
# mi                  0.001248
# count_order    150809.155465
# Name: 4, dtype: float64
# mi                  0.001248
# count_order    147862.791633
# Name: 5, dtype: float64
# mi                  0.001248
# count_order    145683.288441
# Name: 6, dtype: float64
# mi                  0.001248
# count_order    152972.749052
# Name: 7, dtype: float64
# mi                  0.001248
# count_order    162555.897745
# Name: 8, dtype: float64
# mi                  0.001248
# count_order    139985.673751
# Name: 9, dtype: float64
# mi                  0.001248
# count_order    145627.265094
# Name: 10, dtype: float64
# mi                  0.001248
# count_order    136693.333097
# Name: 11, dtype: float64
# mi                  0.001248
# count_order    143799.600193
# Name: 12, dtype: float64
# mi                  0.001248
# count_order    150174.902857
# Name: 13, dtype: float64
# mi                  0.001248
# count_order    145365.739399
# Name: 14, dtype: float64
# mi                  0.001248
# count_order    150518.678542
# Name: 15, dtype: float64
# mi                  0.001248
# count_order    162814.193371
# Name: 16, dtype: float64
# mi                  0.001248
# count_order    147808.378938
# Name: 17, dtype: float64
# mi                  0.001248
# count_order    148434.938797
# Name: 18, dtype: float64
# mi                  0.001248
# count_order    147988.322409
# Name: 19, dtype: float64
# mi                  0.001248
# count_order    157498.485023
# Name: 20, dtype: float64
# mi                  0.001248
# count_order    139151.069903
# Name: 21, dtype: float64
# mi                  0.001248
# count_order    125021.769722
# Name: 22, dtype: float64
# mi                  0.001248
# count_order    156228.318669
# Name: 23, dtype: float64
# mi                  0.001248
# count_order    145829.446550
# Name: 24, dtype: float64
# mi                  0.001248
# count_order    146102.870660
# Name: 25, dtype: float64
# mi                  0.001248
# count_order    150555.109354
# Name: 26, dtype: float64
# mi                  0.001248
# count_order    134756.400049
# Name: 27, dtype: float64
# mi                  0.001248
# count_order    156522.043679
# Name: 28, dtype: float64
# mi                  0.001248
# count_order    146868.921020
# Name: 29, dtype: float64
# mi                  0.001248
# count_order    135753.233422
# Name: 30, dtype: float64
# mi                  0.001248
# count_order    142283.240202
# Name: 31, dtype: float64
# mi                  0.001248
# count_order    132386.317286
# Name: 32, dtype: float64
# mi                  0.001248
# count_order    133663.306510
# Name: 33, dtype: float64
# mi                  0.001248
# count_order    137364.964427
# Name: 34, dtype: float64
# mi                  0.001248
# count_order    142472.800090
# Name: 35, dtype: float64
# mi                  0.001248
# count_order    143459.483212
# Name: 36, dtype: float64
# mi                  0.001248
# count_order    142684.581246
# Name: 37, dtype: float64
# mi                  0.001248
# count_order    143374.230347
# Name: 38, dtype: float64
# mi                  0.001248
# count_order    146577.701222
# Name: 39, dtype: float64
# mi                  0.001248
# count_order    152015.639261
# Name: 40, dtype: float64
# mi                  0.001248
# count_order    162943.590665
# Name: 41, dtype: float64
# mi                  0.001248
# count_order    153366.199513
# Name: 42, dtype: float64
# mi                  0.001248
# count_order    139802.410473
# Name: 43, dtype: float64
# mi                  0.001248
# count_order    153932.315236
# Name: 44, dtype: float64
# mi                  0.001248
# count_order    157225.975224
# Name: 45, dtype: float64
# mi                  0.001248
# count_order    153309.465041
# Name: 46, dtype: float64
# mi                  0.001248
# count_order    155130.116944
# Name: 47, dtype: float64
# mi                  0.001248
# count_order    144814.401266
# Name: 48, dtype: float64
# mi                  0.001248
# count_order    146163.919846
# Name: 49, dtype: float64
# mi                  0.001248
# count_order    136721.869098
# Name: 50, dtype: float64
# mi                  0.001248
# count_order    142972.090896
# Name: 51, dtype: float64
# mi                  0.001248
# count_order    156781.716334
# Name: 52, dtype: float64
# mi                  0.001248
# count_order    144215.061778
# Name: 53, dtype: float64
# mi                  0.001248
# count_order    146712.437813
# Name: 54, dtype: float64
# mi                  0.001248
# count_order    137079.465641
# Name: 55, dtype: float64
# mi                  0.001248
# count_order    149216.622345
# Name: 56, dtype: float64
# mi                  0.001248
# count_order    162405.291362
# Name: 57, dtype: float64
# mi                  0.001248
# count_order    136628.136298
# Name: 58, dtype: float64
# mi                  0.001248
# count_order    150327.385971
# Name: 59, dtype: float64
# mi                  0.001248
# count_order    147125.605107
# Name: 60, dtype: float64
# mi                  0.001248
# count_order    150496.551960
# Name: 61, dtype: float64
# mi                  0.001248
# count_order    135255.832385
# Name: 62, dtype: float64
# mi                  0.001248
# count_order    142914.287336
# Name: 63, dtype: float64
# mi                  0.001248
# count_order    151023.994962
# Name: 64, dtype: float64
# mi                  0.001248
# count_order    156227.417672
# Name: 65, dtype: float64
# mi                  0.001248
# count_order    144036.006251
# Name: 66, dtype: float64
# mi                  0.001248
# count_order    157211.025056
# Name: 67, dtype: float64
# mi                  0.001248
# count_order    153177.740306
# Name: 68, dtype: float64
# mi                  0.001248
# count_order    142499.518868
# Name: 69, dtype: float64
# mi                  0.001248
# count_order    152778.426180
# Name: 70, dtype: float64
# mi                  0.001248
# count_order    154899.150821
# Name: 71, dtype: float64
# mi                  0.001248
# count_order    148517.880065
# Name: 72, dtype: float64
# mi                  0.001248
# count_order    146503.655367
# Name: 73, dtype: float64
# mi                  0.001248
# count_order    144915.309274
# Name: 74, dtype: float64
# mi                  0.001248
# count_order    139873.886685
# Name: 75, dtype: float64
# mi                  0.001248
# count_order    161226.406105
# Name: 76, dtype: float64
# mi                  0.001248
# count_order    124035.857901
# Name: 77, dtype: float64
# mi                  0.001248
# count_order    137970.925108
# Name: 78, dtype: float64
# mi                  0.001248
# count_order    141394.058256
# Name: 79, dtype: float64
# mi                  0.001248
# count_order    157117.811966
# Name: 80, dtype: float64
# mi                  0.001248
# count_order    157441.236726
# Name: 81, dtype: float64
# mi                  0.001248
# count_order    155362.194285
# Name: 82, dtype: float64
# mi                  0.001248
# count_order    159678.139362
# Name: 83, dtype: float64
# mi                  0.001248
# count_order    146499.085840
# Name: 84, dtype: float64
# mi                  0.001248
# count_order    160708.381623
# Name: 85, dtype: float64
# mi                  0.001248
# count_order    158153.422714
# Name: 86, dtype: float64
# mi                  0.001248
# count_order    149579.816251
# Name: 87, dtype: float64
# mi                  0.001248
# count_order    141540.673350
# Name: 88, dtype: float64
# mi                  0.001248
# count_order    158090.669054
# Name: 89, dtype: float64
# mi                  0.001248
# count_order    151208.294102
# Name: 90, dtype: float64
# mi                  0.001248
# count_order    166168.832215
# Name: 91, dtype: float64
# mi                  0.001248
# count_order    157424.700698
# Name: 92, dtype: float64
# mi                  0.001248
# count_order    139638.956364
# Name: 93, dtype: float64
# mi                  0.001248
# count_order    158688.498094
# Name: 94, dtype: float64
# mi                  0.001248
# count_order    128672.997564
# Name: 95, dtype: float64
# mi                  0.001248
# count_order    144731.558989
# Name: 96, dtype: float64
# mi                  0.001248
# count_order    154728.948157
# Name: 97, dtype: float64
# mi                  0.001248
# count_order    152714.346080
# Name: 98, dtype: float64
# mi                  0.001248
# count_order    149029.729441
# Name: 99, dtype: float64
# mi                  0.001248
# count_order    150643.621995
# Name: 100, dtype: float64
# mi                  0.001248
# count_order    145193.763540
# Name: 101, dtype: float64
# mi                  0.001248
# count_order    145965.457395
# Name: 102, dtype: float64
# mi                  0.001248
# count_order    159815.244575
# Name: 103, dtype: float64
# mi                  0.001248
# count_order    155279.284581
# Name: 104, dtype: float64
# mi                  0.001248
# count_order    170647.842556
# Name: 105, dtype: float64
# mi                  0.001248
# count_order    131413.406829
# Name: 106, dtype: float64
# mi                  0.001248
# count_order    146927.892426
# Name: 107, dtype: float64
# mi                  0.001248
# count_order    135154.167727
# Name: 108, dtype: float64
# mi                  0.001248
# count_order    131771.959843
# Name: 109, dtype: float64
# mi                  0.001248
# count_order    153440.338015
# Name: 110, dtype: float64
# mi                  0.001248
# count_order    147650.005495
# Name: 111, dtype: float64
# mi                  0.001248
# count_order    138064.808962
# Name: 112, dtype: float64
# mi                  0.001248
# count_order    143463.708063
# Name: 113, dtype: float64
# mi                  0.001248
# count_order    160200.710491
# Name: 114, dtype: float64
# mi                  0.001248
# count_order    134642.373128
# Name: 115, dtype: float64
# mi                  0.001248
# count_order    156025.801500
# Name: 116, dtype: float64
# mi                  0.001248
# count_order    149138.081872
# Name: 117, dtype: float64
# mi                  0.001248
# count_order    150044.760698
# Name: 118, dtype: float64
# mi                  0.001248
# count_order    158431.212941
# Name: 119, dtype: float64
# mi                  0.001248
# count_order    157691.539019
# Name: 120, dtype: float64
# mi                  0.001248
# count_order    145794.941908
# Name: 121, dtype: float64
# mi                  0.001248
# count_order    135432.591277
# Name: 122, dtype: float64
# mi                  0.001248
# count_order    148764.532278
# Name: 123, dtype: float64
# mi                  0.001248
# count_order    151292.285460
# Name: 124, dtype: float64
# mi                  0.001248
# count_order    158492.348753
# Name: 125, dtype: float64
# mi                  0.001248
# count_order    135789.103698
# Name: 126, dtype: float64
# mi                  0.001248
# count_order    158472.148739
# Name: 127, dtype: float64
# mi                  0.001248
# count_order    140609.170211
# Name: 128, dtype: float64
# mi                  0.001248
# count_order    151471.471734
# Name: 129, dtype: float64
# mi                  0.001248
# count_order    149211.831322
# Name: 130, dtype: float64
# mi                  0.001248
# count_order    152919.849840
# Name: 131, dtype: float64
# mi                  0.001248
# count_order    130840.824664
# Name: 132, dtype: float64
# mi                  0.001248
# count_order    153228.538493
# Name: 133, dtype: float64
# mi                  0.001248
# count_order    146502.483098
# Name: 134, dtype: float64
# mi                  0.001248
# count_order    144263.560439
# Name: 135, dtype: float64
# mi                  0.001248
# count_order    143294.701394
# Name: 136, dtype: float64
# mi                  0.001248
# count_order    147619.785715
# Name: 137, dtype: float64
# mi                  0.001248
# count_order    132728.940823
# Name: 138, dtype: float64
# mi                  0.001248
# count_order    138269.592823
# Name: 139, dtype: float64
# mi                  0.001248
# count_order    144501.060847
# Name: 140, dtype: float64
# mi                  0.001248
# count_order    145591.956506
# Name: 141, dtype: float64
# mi                  0.001248
# count_order    144726.586272
# Name: 142, dtype: float64
# mi                  0.001248
# count_order    134199.318068
# Name: 143, dtype: float64
# mi                  0.001248
# count_order    148802.945375
# Name: 144, dtype: float64
# mi                  0.001248
# count_order    158710.487850
# Name: 145, dtype: float64
# mi                  0.001248
# count_order    154264.416808
# Name: 146, dtype: float64
# mi                  0.001248
# count_order    142051.905268
# Name: 147, dtype: float64
# mi                  0.001248
# count_order    138832.818569
# Name: 148, dtype: float64
# mi                  0.001248
# count_order    144109.036833
# Name: 149, dtype: float64
# mi                  0.001248
# count_order    155307.436241
# Name: 150, dtype: float64
# mi                  0.001248
# count_order    150244.645062
# Name: 151, dtype: float64
# mi                  0.001248
# count_order    149367.733733
# Name: 152, dtype: float64
# mi                  0.001248
# count_order    144694.697215
# Name: 153, dtype: float64
# mi                  0.001248
# count_order    147054.271038
# Name: 154, dtype: float64
# mi                  0.001248
# count_order    158530.498791
# Name: 155, dtype: float64
# mi                  0.001248
# count_order    144661.276488
# Name: 156, dtype: float64
# mi                  0.001248
# count_order    141503.651091
# Name: 157, dtype: float64
# mi                  0.001248
# count_order    154911.774788
# Name: 158, dtype: float64
# mi                  0.001248
# count_order    145693.717992
# Name: 159, dtype: float64
# mi                  0.001248
# count_order    135748.654697
# Name: 160, dtype: float64
# mi                  0.001248
# count_order    139265.378405
# Name: 161, dtype: float64
# mi                  0.001248
# count_order    148678.627417
# Name: 162, dtype: float64
# mi                  0.001248
# count_order    134417.285164
# Name: 163, dtype: float64
# mi                  0.001248
# count_order    145569.106530
# Name: 164, dtype: float64
# mi                  0.001248
# count_order    161011.296360
# Name: 165, dtype: float64
# mi                  0.001248
# count_order    141063.354536
# Name: 166, dtype: float64
# mi                  0.001248
# count_order    175051.669735
# Name: 167, dtype: float64
# mi                  0.001248
# count_order    150491.437214
# Name: 168, dtype: float64
# mi                  0.001248
# count_order    141345.912110
# Name: 169, dtype: float64
# mi                  0.001248
# count_order    143741.304096
# Name: 170, dtype: float64
# mi                  0.001248
# count_order    151358.454394
# Name: 171, dtype: float64
# mi                  0.001248
# count_order    140719.844731
# Name: 172, dtype: float64
# mi                  0.001248
# count_order    144255.360807
# Name: 173, dtype: float64
# mi                  0.001248
# count_order    146651.327049
# Name: 174, dtype: float64
# mi                  0.001248
# count_order    147032.102080
# Name: 175, dtype: float64
# mi                  0.001248
# count_order    143806.117741
# Name: 176, dtype: float64
# mi                  0.001248
# count_order    156791.403621
# Name: 177, dtype: float64
# mi                  0.001248
# count_order    140707.038270
# Name: 178, dtype: float64
# mi                  0.001248
# count_order    149005.062545
# Name: 179, dtype: float64
# mi                  0.001248
# count_order    136002.342894
# Name: 180, dtype: float64
# mi                  0.001248
# count_order    150680.015194
# Name: 181, dtype: float64
# mi                  0.001248
# count_order    144847.577376
# Name: 182, dtype: float64
# mi                  0.001248
# count_order    163124.303363
# Name: 183, dtype: float64
# mi                  0.001248
# count_order    165280.734914
# Name: 184, dtype: float64
# mi                  0.001248
# count_order    151007.429738
# Name: 185, dtype: float64
# mi                  0.001248
# count_order    158367.456353
# Name: 186, dtype: float64
# mi                  0.001248
# count_order    135120.843208
# Name: 187, dtype: float64
# mi                  0.001248
# count_order    157529.754677
# Name: 188, dtype: float64
# mi                  0.001248
# count_order    168764.046315
# Name: 189, dtype: float64
# mi                  0.001248
# count_order    138277.203364
# Name: 190, dtype: float64
# mi                  0.001248
# count_order    144830.281303
# Name: 191, dtype: float64
# mi                  0.001248
# count_order    145897.597848
# Name: 192, dtype: float64
# mi                  0.001248
# count_order    130816.806029
# Name: 193, dtype: float64
# mi                  0.001248
# count_order    157006.403258
# Name: 194, dtype: float64
# mi                  0.001248
# count_order    145498.048490
# Name: 195, dtype: float64
# mi                  0.001248
# count_order    148333.266371
# Name: 196, dtype: float64
# mi                  0.001248
# count_order    144200.367938
# Name: 197, dtype: float64
# mi                  0.001248
# count_order    155995.593973
# Name: 198, dtype: float64
# mi                  0.001248
# count_order    137408.113236
# Name: 199, dtype: float64
# mi                  0.001248
# count_order    155905.607320
# Name: 200, dtype: float64
# mi                  0.001248
# count_order    151504.464364
# Name: 201, dtype: float64
# mi                  0.001248
# count_order    147334.111715
# Name: 202, dtype: float64
# mi                  0.001248
# count_order    155759.561696
# Name: 203, dtype: float64
# mi                  0.001248
# count_order    147012.884037
# Name: 204, dtype: float64
# mi                  0.001248
# count_order    157556.556384
# Name: 205, dtype: float64
# mi                  0.001248
# count_order    147425.700929
# Name: 206, dtype: float64
# mi                  0.001248
# count_order    150120.226756
# Name: 207, dtype: float64
# mi                  0.001248
# count_order    152671.969893
# Name: 208, dtype: float64
# mi                  0.001248
# count_order    140910.107692
# Name: 209, dtype: float64
# mi                  0.001248
# count_order    160119.758223
# Name: 210, dtype: float64
# mi                  0.001248
# count_order    146304.249613
# Name: 211, dtype: float64
# mi                  0.001248
# count_order    141111.146318
# Name: 212, dtype: float64
# mi                  0.001248
# count_order    158124.608212
# Name: 213, dtype: float64
# mi                  0.001248
# count_order    137214.387462
# Name: 214, dtype: float64
# mi                  0.001248
# count_order    148447.910606
# Name: 215, dtype: float64
# mi                  0.001248
# count_order    145629.533018
# Name: 216, dtype: float64
# mi                  0.001248
# count_order    150164.403403
# Name: 217, dtype: float64
# mi                  0.001248
# count_order    137896.760911
# Name: 218, dtype: float64
# mi                  0.001248
# count_order    136072.536582
# Name: 219, dtype: float64
# mi                  0.001248
# count_order    154440.251316
# Name: 220, dtype: float64
# mi                  0.001248
# count_order    142687.515734
# Name: 221, dtype: float64
# mi                  0.001248
# count_order    150979.996902
# Name: 222, dtype: float64
# mi                  0.001248
# count_order    137917.482807
# Name: 223, dtype: float64
# mi                  0.001248
# count_order    137998.429864
# Name: 224, dtype: float64
# mi                  0.001248
# count_order    146352.829235
# Name: 225, dtype: float64
# mi                  0.001248
# count_order    151547.161057
# Name: 226, dtype: float64
# mi                  0.001248
# count_order    148052.835650
# Name: 227, dtype: float64
# mi                  0.001248
# count_order    146976.349764
# Name: 228, dtype: float64
# mi                  0.001248
# count_order    148693.506292
# Name: 229, dtype: float64
# mi                  0.001248
# count_order    144922.066615
# Name: 230, dtype: float64
# mi                  0.001248
# count_order    145904.119191
# Name: 231, dtype: float64
# mi                  0.001248
# count_order    145667.388502
# Name: 232, dtype: float64
# mi                  0.001248
# count_order    157884.535755
# Name: 233, dtype: float64
# mi                  0.001248
# count_order    144246.922742
# Name: 234, dtype: float64
# mi                  0.001248
# count_order    166954.558492
# Name: 235, dtype: float64
# mi                  0.001248
# count_order    131163.970442
# Name: 236, dtype: float64
# mi                  0.001248
# count_order    144601.940312
# Name: 237, dtype: float64
# mi                  0.001248
# count_order    141155.151058
# Name: 238, dtype: float64
# mi                  0.001248
# count_order    145129.244239
# Name: 239, dtype: float64
# mi                  0.001248
# count_order    145455.708255
# Name: 240, dtype: float64
# mi                  0.001248
# count_order    149071.339022
# Name: 241, dtype: float64
# mi                  0.001248
# count_order    146159.997251
# Name: 242, dtype: float64
# mi                  0.001248
# count_order    134647.480598
# Name: 243, dtype: float64
# mi                  0.001248
# count_order    149099.810221
# Name: 244, dtype: float64
# mi                  0.001248
# count_order    154134.281902
# Name: 245, dtype: float64
# mi                  0.001248
# count_order    144167.484410
# Name: 246, dtype: float64
# mi                  0.001248
# count_order    156415.553319
# Name: 247, dtype: float64
# mi                  0.001248
# count_order    156073.140169
# Name: 248, dtype: float64
# mi                  0.001248
# count_order    154003.316051
# Name: 249, dtype: float64
# mi                  0.001248
# count_order    148289.744800
# Name: 250, dtype: float64
# mi                  0.001248
# count_order    139893.187582
# Name: 251, dtype: float64
# mi                  0.001248
# count_order    144802.122220
# Name: 252, dtype: float64
# mi                  0.001248
# count_order    137510.525696
# Name: 253, dtype: float64
# mi                  0.001248
# count_order    140424.526229
# Name: 254, dtype: float64
# mi                  0.001248
# count_order    133003.333634
# Name: 255, dtype: float64
# mi                  0.001248
# count_order    145672.634127
# Name: 256, dtype: float64
# mi                  0.001248
# count_order    156904.001267
# Name: 257, dtype: float64
# mi                  0.001248
# count_order    151972.917394
# Name: 258, dtype: float64
# mi                  0.001248
# count_order    144226.528812
# Name: 259, dtype: float64
# mi                  0.001248
# count_order    154504.036232
# Name: 260, dtype: float64
# mi                  0.001248
# count_order    150767.159386
# Name: 261, dtype: float64
# mi                  0.001248
# count_order    164216.871303
# Name: 262, dtype: float64
# mi                  0.001248
# count_order    135255.720132
# Name: 263, dtype: float64
# mi                  0.001248
# count_order    155553.333902
# Name: 264, dtype: float64
# mi                  0.001248
# count_order    137763.899030
# Name: 265, dtype: float64
# mi                  0.001248
# count_order    136359.284803
# Name: 266, dtype: float64
# mi                  0.001248
# count_order    142049.897386
# Name: 267, dtype: float64
# mi                  0.001248
# count_order    148230.980416
# Name: 268, dtype: float64
# mi                  0.001248
# count_order    150757.648367
# Name: 269, dtype: float64
# mi                  0.001248
# count_order    157755.596516
# Name: 270, dtype: float64
# mi                  0.001248
# count_order    141346.439498
# Name: 271, dtype: float64
# mi                  0.001248
# count_order    152116.643595
# Name: 272, dtype: float64
# mi                  0.001248
# count_order    140986.545475
# Name: 273, dtype: float64
# mi                  0.001248
# count_order    156181.544861
# Name: 274, dtype: float64
# mi                  0.001248
# count_order    147549.570254
# Name: 275, dtype: float64
# mi                  0.001248
# count_order    147321.792991
# Name: 276, dtype: float64
# mi                  0.001248
# count_order    150642.302024
# Name: 277, dtype: float64
# mi                  0.001248
# count_order    136217.183497
# Name: 278, dtype: float64
# mi                  0.001248
# count_order    148369.760237
# Name: 279, dtype: float64
# mi                  0.001248
# count_order    160699.218500
# Name: 280, dtype: float64
# mi                  0.001248
# count_order    153454.765290
# Name: 281, dtype: float64
# mi                  0.001248
# count_order    147554.622029
# Name: 282, dtype: float64
# mi                  0.001248
# count_order    139584.300418
# Name: 283, dtype: float64
# mi                  0.001248
# count_order    150949.871646
# Name: 284, dtype: float64
# mi                  0.001248
# count_order    148505.616887
# Name: 285, dtype: float64
# mi                  0.001248
# count_order    144741.239139
# Name: 286, dtype: float64
# mi                  0.001248
# count_order    146329.423910
# Name: 287, dtype: float64
# mi                  0.001248
# count_order    142167.288758
# Name: 288, dtype: float64
# mi                  0.001248
# count_order    144792.243924
# Name: 289, dtype: float64
# mi                  0.001248
# count_order    158605.439700
# Name: 290, dtype: float64
# mi                  0.001248
# count_order    146979.866058
# Name: 291, dtype: float64
# mi                  0.001248
# count_order    148939.562174
# Name: 292, dtype: float64
# mi                  0.001248
# count_order    147783.138914
# Name: 293, dtype: float64
# mi                  0.001248
# count_order    156840.685951
# Name: 294, dtype: float64
# mi                  0.001248
# count_order    141860.836953
# Name: 295, dtype: float64
# mi                  0.001248
# count_order    148690.544685
# Name: 296, dtype: float64
# mi                  0.001248
# count_order    150868.435405
# Name: 297, dtype: float64
# mi                  0.001248
# count_order    142102.758622
# Name: 298, dtype: float64
# mi                  0.001248
# count_order    138883.714694
# Name: 299, dtype: float64
# mi                  0.001248
# count_order    160285.823676
# Name: 300, dtype: float64
# mi                  0.001248
# count_order    144089.910117
# Name: 301, dtype: float64
# mi                  0.001248
# count_order    138815.371376
# Name: 302, dtype: float64
# mi                  0.001248
# count_order    141812.298305
# Name: 303, dtype: float64
# mi                  0.001248
# count_order    148731.440470
# Name: 304, dtype: float64
# mi                  0.001248
# count_order    166627.767441
# Name: 305, dtype: float64
# mi                  0.001248
# count_order    153531.798187
# Name: 306, dtype: float64
# mi                  0.001248
# count_order    159666.746863
# Name: 307, dtype: float64
# mi                  0.001248
# count_order    151874.026708
# Name: 308, dtype: float64
# mi                  0.001248
# count_order    143656.377207
# Name: 309, dtype: float64
# mi                  0.001248
# count_order    149563.674187
# Name: 310, dtype: float64
# mi                  0.001248
# count_order    154569.302564
# Name: 311, dtype: float64
# mi                  0.001248
# count_order    137396.928200
# Name: 312, dtype: float64
# mi                  0.001248
# count_order    150116.603636
# Name: 313, dtype: float64
# mi                  0.001248
# count_order    148947.640535
# Name: 314, dtype: float64
# mi                  0.001248
# count_order    138196.676126
# Name: 315, dtype: float64
# mi                  0.001248
# count_order    150428.625689
# Name: 316, dtype: float64
# mi                  0.001248
# count_order    152687.623892
# Name: 317, dtype: float64
# mi                  0.001248
# count_order    149722.553295
# Name: 318, dtype: float64
# mi                  0.001248
# count_order    135557.824354
# Name: 319, dtype: float64
# mi                  0.001248
# count_order    137369.485793
# Name: 320, dtype: float64
# mi                  0.001248
# count_order    145915.826048
# Name: 321, dtype: float64
# mi                  0.001248
# count_order    158148.377716
# Name: 322, dtype: float64
# mi                  0.001248
# count_order    150404.860841
# Name: 323, dtype: float64
# mi                  0.001248
# count_order    150801.898465
# Name: 324, dtype: float64
# mi                  0.001248
# count_order    141341.434114
# Name: 325, dtype: float64
# mi                  0.001248
# count_order    145434.359390
# Name: 326, dtype: float64
# mi                  0.001248
# count_order    150161.653499
# Name: 327, dtype: float64
# mi                  0.001248
# count_order    137764.308291
# Name: 328, dtype: float64
# mi                  0.001248
# count_order    150157.580866
# Name: 329, dtype: float64
# mi                  0.001248
# count_order    153010.538582
# Name: 330, dtype: float64
# mi                  0.001248
# count_order    147027.175740
# Name: 331, dtype: float64
# mi                  0.001248
# count_order    150611.165190
# Name: 332, dtype: float64
# mi                  0.001248
# count_order    147872.844929
# Name: 333, dtype: float64
# mi                  0.001248
# count_order    133779.111390
# Name: 334, dtype: float64
# mi                  0.001248
# count_order    144028.144683
# Name: 335, dtype: float64
# mi                  0.001248
# count_order    145374.767271
# Name: 336, dtype: float64
# mi                  0.001248
# count_order    137794.812289
# Name: 337, dtype: float64
# mi                  0.001248
# count_order    135770.856756
# Name: 338, dtype: float64
# mi                  0.001248
# count_order    154298.269257
# Name: 339, dtype: float64
# mi                  0.001248
# count_order    151000.317330
# Name: 340, dtype: float64
# mi                  0.001248
# count_order    153127.399340
# Name: 341, dtype: float64
# mi                  0.001248
# count_order    131952.906750
# Name: 342, dtype: float64
# mi                  0.001248
# count_order    151315.283057
# Name: 343, dtype: float64
# mi                  0.001248
# count_order    151835.490100
# Name: 344, dtype: float64
# mi                  0.001248
# count_order    149787.349036
# Name: 345, dtype: float64
# mi                  0.001248
# count_order    147205.300489
# Name: 346, dtype: float64
# mi                  0.001248
# count_order    149875.264347
# Name: 347, dtype: float64
# mi                  0.001248
# count_order    159096.435535
# Name: 348, dtype: float64
# mi                  0.001248
# count_order    153102.019792
# Name: 349, dtype: float64
# mi                  0.001248
# count_order    155892.655589
# Name: 350, dtype: float64
# mi                  0.001248
# count_order    153142.723225
# Name: 351, dtype: float64
# mi                  0.001248
# count_order    137997.657443
# Name: 352, dtype: float64
# mi                  0.001248
# count_order    147093.540265
# Name: 353, dtype: float64
# mi                  0.001248
# count_order    157570.368722
# Name: 354, dtype: float64
# mi                  0.001248
# count_order    149264.181706
# Name: 355, dtype: float64
# mi                  0.001248
# count_order    144847.747473
# Name: 356, dtype: float64
# mi                  0.001248
# count_order    157289.754106
# Name: 357, dtype: float64
# mi                  0.001248
# count_order    147937.103833
# Name: 358, dtype: float64
# mi                  0.001248
# count_order    146566.355908
# Name: 359, dtype: float64
# mi                  0.001248
# count_order    136528.572597
# Name: 360, dtype: float64
# mi                  0.001248
# count_order    154238.982094
# Name: 361, dtype: float64
# mi                  0.001248
# count_order    140156.040777
# Name: 362, dtype: float64
# mi                  0.001248
# count_order    147134.424757
# Name: 363, dtype: float64
# mi                  0.001248
# count_order    167449.542491
# Name: 364, dtype: float64
# mi                  0.001248
# count_order    147185.493210
# Name: 365, dtype: float64
# mi                  0.001248
# count_order    135059.948789
# Name: 366, dtype: float64
# mi                  0.001248
# count_order    129697.240336
# Name: 367, dtype: float64
# mi                  0.001248
# count_order    158568.343059
# Name: 368, dtype: float64
# mi                  0.001248
# count_order    156343.461477
# Name: 369, dtype: float64
# mi                  0.001248
# count_order    156078.174725
# Name: 370, dtype: float64
# mi                  0.001248
# count_order    141470.490048
# Name: 371, dtype: float64
# mi                  0.001248
# count_order    145024.138180
# Name: 372, dtype: float64
# mi                  0.001248
# count_order    156299.776206
# Name: 373, dtype: float64
# mi                  0.001248
# count_order    134128.683554
# Name: 374, dtype: float64
# mi                  0.001248
# count_order    160303.828367
# Name: 375, dtype: float64
# mi                  0.001248
# count_order    153493.420111
# Name: 376, dtype: float64
# mi                  0.001248
# count_order    131627.240047
# Name: 377, dtype: float64
# mi                  0.001248
# count_order    141809.916528
# Name: 378, dtype: float64
# mi                  0.001248
# count_order    142307.217521
# Name: 379, dtype: float64
# mi                  0.001248
# count_order    148736.901013
# Name: 380, dtype: float64
# mi                  0.001248
# count_order    153410.085319
# Name: 381, dtype: float64
# mi                  0.001248
# count_order    151462.461129
# Name: 382, dtype: float64
# mi                  0.001248
# count_order    143913.795599
# Name: 383, dtype: float64
# mi                  0.001248
# count_order    153598.235372
# Name: 384, dtype: float64
# mi                  0.001248
# count_order    138458.682920
# Name: 385, dtype: float64
# mi                  0.001248
# count_order    150012.151583
# Name: 386, dtype: float64
# mi                  0.001248
# count_order    140955.847218
# Name: 387, dtype: float64
# mi                  0.001248
# count_order    157258.086123
# Name: 388, dtype: float64
# mi                  0.001248
# count_order    157191.120186
# Name: 389, dtype: float64
# mi                  0.001248
# count_order    151018.136129
# Name: 390, dtype: float64
# mi                  0.001248
# count_order    154708.581743
# Name: 391, dtype: float64
# mi                  0.001248
# count_order    142253.682182
# Name: 392, dtype: float64
# mi                  0.001248
# count_order    151832.872502
# Name: 393, dtype: float64
# mi                  0.001248
# count_order    149119.672249
# Name: 394, dtype: float64
# mi                  0.001248
# count_order    138082.598984
# Name: 395, dtype: float64
# mi                  0.001248
# count_order    156336.613353
# Name: 396, dtype: float64
# mi                  0.001248
# count_order    144852.083327
# Name: 397, dtype: float64
# mi                  0.001248
# count_order    133238.079205
# Name: 398, dtype: float64
# mi                  0.001248
# count_order    145209.809736
# Name: 399, dtype: float64
# mi                  0.001248
# count_order    146442.006838
# Name: 400, dtype: float64
# mi                  0.001248
# count_order    150897.054634
# Name: 401, dtype: float64
# mi                  0.001248
# count_order    152785.514538
# Name: 402, dtype: float64
# mi                  0.001248
# count_order    150682.815960
# Name: 403, dtype: float64
# mi                  0.001248
# count_order    155266.228804
# Name: 404, dtype: float64
# mi                  0.001248
# count_order    148481.449509
# Name: 405, dtype: float64
# mi                  0.001248
# count_order    144340.169452
# Name: 406, dtype: float64
# mi                  0.001248
# count_order    141985.701557
# Name: 407, dtype: float64
# mi                  0.001248
# count_order    145116.860948
# Name: 408, dtype: float64
# mi                  0.001248
# count_order    134031.928135
# Name: 409, dtype: float64
# mi                  0.001248
# count_order    136448.059788
# Name: 410, dtype: float64
# mi                  0.001248
# count_order    155369.741853
# Name: 411, dtype: float64
# mi                  0.001248
# count_order    149263.058145
# Name: 412, dtype: float64
# mi                  0.001248
# count_order    133783.491679
# Name: 413, dtype: float64
# mi                  0.001248
# count_order    142272.793619
# Name: 414, dtype: float64
# mi                  0.001248
# count_order    132326.546321
# Name: 415, dtype: float64
# mi                  0.001248
# count_order    147872.114501
# Name: 416, dtype: float64
# mi                  0.001248
# count_order    155926.683668
# Name: 417, dtype: float64
# mi                  0.001248
# count_order    150657.855446
# Name: 418, dtype: float64
# mi                  0.001248
# count_order    158457.152794
# Name: 419, dtype: float64
# mi                  0.001248
# count_order    150543.369437
# Name: 420, dtype: float64
# mi                  0.001248
# count_order    138438.097633
# Name: 421, dtype: float64
# mi                  0.001248
# count_order    149714.023108
# Name: 422, dtype: float64
# mi                  0.001248
# count_order    143667.786652
# Name: 423, dtype: float64
# mi                  0.001248
# count_order    139280.366383
# Name: 424, dtype: float64
# mi                  0.001248
# count_order    151661.550032
# Name: 425, dtype: float64
# mi                  0.001248
# count_order    140998.189302
# Name: 426, dtype: float64
# mi                  0.001248
# count_order    146692.543572
# Name: 427, dtype: float64
# mi                  0.001248
# count_order    136855.370665
# Name: 428, dtype: float64
# mi                  0.001248
# count_order    145415.893639
# Name: 429, dtype: float64
# mi                  0.001248
# count_order    157132.028105
# Name: 430, dtype: float64
# mi                  0.001248
# count_order    155966.718809
# Name: 431, dtype: float64
# mi                  0.001248
# count_order    145526.167491
# Name: 432, dtype: float64
# mi                  0.001248
# count_order    153125.917318
# Name: 433, dtype: float64
# mi                  0.001248
# count_order    154956.818418
# Name: 434, dtype: float64
# mi                  0.001248
# count_order    140233.649630
# Name: 435, dtype: float64
# mi                  0.001248
# count_order    142605.246741
# Name: 436, dtype: float64
# mi                  0.001248
# count_order    156680.551020
# Name: 437, dtype: float64
# mi                  0.001248
# count_order    135926.614421
# Name: 438, dtype: float64
# mi                  0.001248
# count_order    144834.229502
# Name: 439, dtype: float64
# mi                  0.001248
# count_order    141415.281836
# Name: 440, dtype: float64
# mi                  0.001248
# count_order    138838.705913
# Name: 441, dtype: float64
# mi                  0.001248
# count_order    153194.340472
# Name: 442, dtype: float64
# mi                  0.001248
# count_order    144358.645163
# Name: 443, dtype: float64
# mi                  0.001248
# count_order    144703.299517
# Name: 444, dtype: float64
# mi                  0.001248
# count_order    150532.045074
# Name: 445, dtype: float64
# mi                  0.001248
# count_order    150321.689846
# Name: 446, dtype: float64
# mi                  0.001248
# count_order    142961.979136
# Name: 447, dtype: float64
# mi                  0.001248
# count_order    139385.875380
# Name: 448, dtype: float64
# mi                  0.001248
# count_order    147968.353075
# Name: 449, dtype: float64
# mi                  0.001248
# count_order    161205.020269
# Name: 450, dtype: float64
# mi                  0.001248
# count_order    160513.183058
# Name: 451, dtype: float64
# mi                  0.001248
# count_order    148769.275457
# Name: 452, dtype: float64
# mi                  0.001248
# count_order    136517.175686
# Name: 453, dtype: float64
# mi                  0.001248
# count_order    157196.308851
# Name: 454, dtype: float64
# mi                  0.001248
# count_order    143549.608399
# Name: 455, dtype: float64
# mi                  0.001248
# count_order    140261.951977
# Name: 456, dtype: float64
# mi                  0.001248
# count_order    137190.213638
# Name: 457, dtype: float64
# mi                  0.001248
# count_order    145196.200855
# Name: 458, dtype: float64
# mi                  0.001248
# count_order    155857.334726
# Name: 459, dtype: float64
# mi                  0.001248
# count_order    145532.199457
# Name: 460, dtype: float64
# mi                  0.001248
# count_order    127137.689396
# Name: 461, dtype: float64
# mi                  0.001248
# count_order    130247.781271
# Name: 462, dtype: float64
# mi                  0.001248
# count_order    163185.253063
# Name: 463, dtype: float64
# mi                  0.001248
# count_order    140633.670848
# Name: 464, dtype: float64
# mi                  0.001248
# count_order    136333.221642
# Name: 465, dtype: float64
# mi                  0.001248
# count_order    153700.091071
# Name: 466, dtype: float64
# mi                  0.001248
# count_order    135440.069021
# Name: 467, dtype: float64
# mi                  0.001248
# count_order    148659.234401
# Name: 468, dtype: float64
# mi                  0.001248
# count_order    126913.514313
# Name: 469, dtype: float64
# mi                  0.001248
# count_order    154347.363230
# Name: 470, dtype: float64
# mi                  0.001248
# count_order    149689.757498
# Name: 471, dtype: float64
# mi                  0.001248
# count_order    144734.520512
# Name: 472, dtype: float64
# mi                  0.001248
# count_order    154499.258880
# Name: 473, dtype: float64
# mi                  0.001248
# count_order    142986.846546
# Name: 474, dtype: float64
# mi                  0.001248
# count_order    147341.546862
# Name: 475, dtype: float64
# mi                  0.001248
# count_order    141713.422429
# Name: 476, dtype: float64
# mi                  0.001248
# count_order    151108.508008
# Name: 477, dtype: float64
# mi                  0.001248
# count_order    147048.251651
# Name: 478, dtype: float64
# mi                  0.001248
# count_order    138264.960471
# Name: 479, dtype: float64
# mi                  0.001248
# count_order    137737.766064
# Name: 480, dtype: float64
# mi                  0.001248
# count_order    145960.523046
# Name: 481, dtype: float64
# mi                  0.001248
# count_order    141683.015678
# Name: 482, dtype: float64
# mi                  0.001248
# count_order    148336.887723
# Name: 483, dtype: float64
# mi                  0.001248
# count_order    147208.491848
# Name: 484, dtype: float64
# mi                  0.001248
# count_order    139642.871891
# Name: 485, dtype: float64
# mi                  0.001248
# count_order    158115.900312
# Name: 486, dtype: float64
# mi                  0.001248
# count_order    156607.868300
# Name: 487, dtype: float64
# mi                  0.001248
# count_order    138199.547997
# Name: 488, dtype: float64
# mi                  0.001248
# count_order    149887.682438
# Name: 489, dtype: float64
# mi                  0.001248
# count_order    139337.451809
# Name: 490, dtype: float64
# mi                  0.001248
# count_order    151785.439178
# Name: 491, dtype: float64
# mi                  0.001248
# count_order    156188.731151
# Name: 492, dtype: float64
# mi                  0.001248
# count_order    146813.376684
# Name: 493, dtype: float64
# mi                  0.001248
# count_order    150519.535002
# Name: 494, dtype: float64
# mi                  0.001248
# count_order    146342.282096
# Name: 495, dtype: float64
# mi                  0.001248
# count_order    145047.677854
# Name: 496, dtype: float64
# mi                  0.001248
# count_order    152851.197063
# Name: 497, dtype: float64
# mi                  0.001248
# count_order    155109.505606
# Name: 498, dtype: float64
# mi                  0.001248
# count_order    139991.596847
# Name: 499, dtype: float64
# mi                  0.001248
# count_order    142850.270898
# Name: 500, dtype: float64
# mi                  0.001248
# count_order    151056.674532
# Name: 501, dtype: float64
# mi                  0.001248
# count_order    143113.884211
# Name: 502, dtype: float64
# mi                  0.001248
# count_order    159132.461927
# Name: 503, dtype: float64
# mi                  0.001248
# count_order    133653.290812
# Name: 504, dtype: float64
# mi                  0.001248
# count_order    148009.848973
# Name: 505, dtype: float64
# mi                  0.001248
# count_order    140170.064755
# Name: 506, dtype: float64
# mi                  0.001248
# count_order    150635.004661
# Name: 507, dtype: float64
# mi                  0.001248
# count_order    150993.120927
# Name: 508, dtype: float64
# mi                  0.001248
# count_order    137990.231561
# Name: 509, dtype: float64
# mi                  0.001248
# count_order    156799.319640
# Name: 510, dtype: float64
# mi                  0.001248
# count_order    153428.452712
# Name: 511, dtype: float64
# mi                  0.001248
# count_order    145028.563989
# Name: 512, dtype: float64
# mi                  0.001248
# count_order    154340.150600
# Name: 513, dtype: float64
# mi                  0.001248
# count_order    134325.019192
# Name: 514, dtype: float64
# mi                  0.001248
# count_order    141931.382874
# Name: 515, dtype: float64
# mi                  0.001248
# count_order    143815.839538
# Name: 516, dtype: float64
# mi                  0.001248
# count_order    165678.157987
# Name: 517, dtype: float64
# mi                  0.001248
# count_order    139133.619598
# Name: 518, dtype: float64
# mi                  0.001248
# count_order    147532.078784
# Name: 519, dtype: float64
# mi                  0.001248
# count_order    147522.472866
# Name: 520, dtype: float64
# mi                  0.001248
# count_order    150331.364649
# Name: 521, dtype: float64
# mi                  0.001248
# count_order    149570.374717
# Name: 522, dtype: float64
# mi                  0.001248
# count_order    159239.948759
# Name: 523, dtype: float64
# mi                  0.001248
# count_order    143853.783648
# Name: 524, dtype: float64
# mi                  0.001248
# count_order    137542.474060
# Name: 525, dtype: float64
# mi                  0.001248
# count_order    142358.906400
# Name: 526, dtype: float64
# mi                  0.001248
# count_order    166494.550795
# Name: 527, dtype: float64
# mi                  0.001248
# count_order    160184.602033
# Name: 528, dtype: float64
# mi                  0.001248
# count_order    146568.612924
# Name: 529, dtype: float64
# mi                  0.001248
# count_order    149659.584708
# Name: 530, dtype: float64
# mi                  0.001248
# count_order    135373.800903
# Name: 531, dtype: float64
# mi                  0.001248
# count_order    158574.882024
# Name: 532, dtype: float64
# mi                  0.001248
# count_order    150318.229490
# Name: 533, dtype: float64
# mi                  0.001248
# count_order    140359.372146
# Name: 534, dtype: float64
# mi                  0.001248
# count_order    151109.594190
# Name: 535, dtype: float64
# mi                  0.001248
# count_order    152689.517846
# Name: 536, dtype: float64
# mi                  0.001248
# count_order    131386.550379
# Name: 537, dtype: float64
# mi                  0.001248
# count_order    135269.036769
# Name: 538, dtype: float64
# mi                  0.001248
# count_order    155799.106083
# Name: 539, dtype: float64
# mi                  0.001248
# count_order    139523.450693
# Name: 540, dtype: float64
# mi                  0.001248
# count_order    143523.761280
# Name: 541, dtype: float64
# mi                  0.001248
# count_order    143744.220948
# Name: 542, dtype: float64
# mi                  0.001248
# count_order    163855.471874
# Name: 543, dtype: float64
# mi                  0.001248
# count_order    132331.951321
# Name: 544, dtype: float64
# mi                  0.001248
# count_order    151006.718495
# Name: 545, dtype: float64
# mi                  0.001248
# count_order    134994.443293
# Name: 546, dtype: float64
# mi                  0.001248
# count_order    151920.736461
# Name: 547, dtype: float64
# mi                  0.001248
# count_order    145197.825507
# Name: 548, dtype: float64
# mi                  0.001248
# count_order    160385.298726
# Name: 549, dtype: float64
# mi                  0.001248
# count_order    153545.709663
# Name: 550, dtype: float64
# mi                  0.001248
# count_order    153000.165331
# Name: 551, dtype: float64
# mi                  0.001248
# count_order    129774.939033
# Name: 552, dtype: float64
# mi                  0.001248
# count_order    148683.610156
# Name: 553, dtype: float64
# mi                  0.001248
# count_order    148405.059382
# Name: 554, dtype: float64
# mi                  0.001248
# count_order    141296.366833
# Name: 555, dtype: float64
# mi                  0.001248
# count_order    139125.718923
# Name: 556, dtype: float64
# mi                  0.001248
# count_order    146630.992854
# Name: 557, dtype: float64
# mi                  0.001248
# count_order    131669.829527
# Name: 558, dtype: float64
# mi                  0.001248
# count_order    146980.860961
# Name: 559, dtype: float64
# mi                  0.001248
# count_order    144795.712854
# Name: 560, dtype: float64
# mi                  0.001248
# count_order    147776.616624
# Name: 561, dtype: float64
# mi                  0.001248
# count_order    152273.544238
# Name: 562, dtype: float64
# mi                  0.001248
# count_order    137510.959731
# Name: 563, dtype: float64
# mi                  0.001248
# count_order    147994.704507
# Name: 564, dtype: float64
# mi                  0.001248
# count_order    144461.616465
# Name: 565, dtype: float64
# mi                  0.001248
# count_order    133616.947086
# Name: 566, dtype: float64
# mi                  0.001248
# count_order    134103.275250
# Name: 567, dtype: float64
# mi                  0.001248
# count_order    160253.954134
# Name: 568, dtype: float64
# mi                  0.001248
# count_order    140477.972255
# Name: 569, dtype: float64
# mi                  0.001248
# count_order    146911.200196
# Name: 570, dtype: float64
# mi                  0.001248
# count_order    158665.673591
# Name: 571, dtype: float64
# mi                  0.001248
# count_order    140464.688387
# ...
# Name: 8821, dtype: float64
# mi                 16.000000
# count_order    147574.515464
# Name: 8822, dtype: float64
# mi                 16.000000
# count_order    147183.932645
# Name: 8823, dtype: float64
# mi                 16.000000
# count_order    147434.469681
# Name: 8824, dtype: float64
# mi                 16.00000
# count_order    148536.10669
# Name: 8825, dtype: float64
# mi                 16.00000
# count_order    147451.23407
# Name: 8826, dtype: float64
# mi                 16.000000
# count_order    147486.334911
# Name: 8827, dtype: float64
# mi                 16.000000
# count_order    147301.921228
# Name: 8828, dtype: float64
# mi                 16.000000
# count_order    147985.159808
# Name: 8829, dtype: float64
# mi                 16.000000
# count_order    147777.303512
# Name: 8830, dtype: float64
# mi                 16.000000
# count_order    147254.069702
# Name: 8831, dtype: float64
# mi                 16.000000
# count_order    147234.400795
# Name: 8832, dtype: float64
# mi                 16.000000
# count_order    147440.582164
# Name: 8833, dtype: float64
# mi                 16.00000
# count_order    147278.08335
# Name: 8834, dtype: float64
# mi                 16.000000
# count_order    147826.208577
# Name: 8835, dtype: float64
# mi                 16.000000
# count_order    147847.675967
# Name: 8836, dtype: float64
# mi                 16.000000
# count_order    147897.697473
# Name: 8837, dtype: float64
# mi                 16.000000
# count_order    146782.504915
# Name: 8838, dtype: float64
# mi                 16.000000
# count_order    147880.474277
# Name: 8839, dtype: float64
# mi                 16.00000
# count_order    148040.23833
# Name: 8840, dtype: float64
# mi                 16.000000
# count_order    147547.378429
# Name: 8841, dtype: float64
# mi                 16.00000
# count_order    148273.75415
# Name: 8842, dtype: float64
# mi                 16.000000
# count_order    147519.729178
# Name: 8843, dtype: float64
# mi                 16.000000
# count_order    147939.791814
# Name: 8844, dtype: float64
# mi                 16.000000
# count_order    147852.314879
# Name: 8845, dtype: float64
# mi                 16.000000
# count_order    148254.313255
# Name: 8846, dtype: float64
# mi                 16.000000
# count_order    147820.752162
# Name: 8847, dtype: float64
# mi                 16.00000
# count_order    147954.56689
# Name: 8848, dtype: float64
# mi                 16.00000
# count_order    148066.97035
# Name: 8849, dtype: float64
# mi                 16.000000
# count_order    147310.969341
# Name: 8850, dtype: float64
# mi                 16.000000
# count_order    147775.288836
# Name: 8851, dtype: float64
# mi                 16.000000
# count_order    147896.151183
# Name: 8852, dtype: float64
# mi                 16.000000
# count_order    147850.974876
# Name: 8853, dtype: float64
# mi                 16.000000
# count_order    148242.642628
# Name: 8854, dtype: float64
# mi                 16.000000
# count_order    148448.879963
# Name: 8855, dtype: float64
# mi                 16.000000
# count_order    148313.258103
# Name: 8856, dtype: float64
# mi                 16.000000
# count_order    147786.201103
# Name: 8857, dtype: float64
# mi                 16.000000
# count_order    147956.650645
# Name: 8858, dtype: float64
# mi                 16.000000
# count_order    147062.496574
# Name: 8859, dtype: float64
# mi                 16.000000
# count_order    147734.863732
# Name: 8860, dtype: float64
# mi                 16.000000
# count_order    148089.455891
# Name: 8861, dtype: float64
# mi                 16.000000
# count_order    146629.275957
# Name: 8862, dtype: float64
# mi                 16.000000
# count_order    147880.905649
# Name: 8863, dtype: float64
# mi                 16.000000
# count_order    147523.618376
# Name: 8864, dtype: float64
# mi                 16.000000
# count_order    146918.584291
# Name: 8865, dtype: float64
# mi                 16.000000
# count_order    147667.199087
# Name: 8866, dtype: float64
# mi                 16.000000
# count_order    147609.429609
# Name: 8867, dtype: float64
# mi                 16.000000
# count_order    147829.602668
# Name: 8868, dtype: float64
# mi                 16.000000
# count_order    148017.624129
# Name: 8869, dtype: float64
# mi                 16.000000
# count_order    148066.275916
# Name: 8870, dtype: float64
# mi                 16.000000
# count_order    147611.069202
# Name: 8871, dtype: float64
# mi                 16.000000
# count_order    148042.357111
# Name: 8872, dtype: float64
# mi                 16.000000
# count_order    146814.164241
# Name: 8873, dtype: float64
# mi                 16.000000
# count_order    147501.371193
# Name: 8874, dtype: float64
# mi                 16.000000
# count_order    147536.791866
# Name: 8875, dtype: float64
# mi                 16.000000
# count_order    148282.209842
# Name: 8876, dtype: float64
# mi                 16.000000
# count_order    149301.842281
# Name: 8877, dtype: float64
# mi                 16.000000
# count_order    148191.203451
# Name: 8878, dtype: float64
# mi                 16.000000
# count_order    147705.212588
# Name: 8879, dtype: float64
# mi                 16.000000
# count_order    147805.827579
# Name: 8880, dtype: float64
# mi                 16.0000
# count_order    147546.2637
# Name: 8881, dtype: float64
# mi                 16.00000
# count_order    147810.92869
# Name: 8882, dtype: float64
# mi                 16.000000
# count_order    148030.158423
# Name: 8883, dtype: float64
# mi                 16.000000
# count_order    147298.920648
# Name: 8884, dtype: float64
# mi                 16.000000
# count_order    147072.183975
# Name: 8885, dtype: float64
# mi                 16.000000
# count_order    147515.539843
# Name: 8886, dtype: float64
# mi                 16.00000
# count_order    147871.58985
# Name: 8887, dtype: float64
# mi                 16.000000
# count_order    148142.962137
# Name: 8888, dtype: float64
# mi                 16.000000
# count_order    147760.955905
# Name: 8889, dtype: float64
# mi                 16.000000
# count_order    147595.662863
# Name: 8890, dtype: float64
# mi                 16.000000
# count_order    147644.051037
# Name: 8891, dtype: float64
# mi                 16.000000
# count_order    147926.084541
# Name: 8892, dtype: float64
# mi                 16.000000
# count_order    146904.835116
# Name: 8893, dtype: float64
# mi                 16.000000
# count_order    148483.326293
# Name: 8894, dtype: float64
# mi                 16.000000
# count_order    147129.831066
# Name: 8895, dtype: float64
# mi                 16.000000
# count_order    148302.741607
# Name: 8896, dtype: float64
# mi                 16.000000
# count_order    147846.512358
# Name: 8897, dtype: float64
# mi                 16.000000
# count_order    147363.101024
# Name: 8898, dtype: float64
# mi                 16.000000
# count_order    148061.990962
# Name: 8899, dtype: float64
# mi                 16.00000
# count_order    147848.40241
# Name: 8900, dtype: float64
# mi                 16.000000
# count_order    148066.297141
# Name: 8901, dtype: float64
# mi                 16.000000
# count_order    148046.052834
# Name: 8902, dtype: float64
# mi                 16.000000
# count_order    148821.986356
# Name: 8903, dtype: float64
# mi                 16.000000
# count_order    147738.574288
# Name: 8904, dtype: float64
# mi                 16.000000
# count_order    147756.244502
# Name: 8905, dtype: float64
# mi                 16.000000
# count_order    147458.284105
# Name: 8906, dtype: float64
# mi                 16.000000
# count_order    148051.917426
# Name: 8907, dtype: float64
# mi                 16.00000
# count_order    147424.67328
# Name: 8908, dtype: float64
# mi                 16.000000
# count_order    148657.638947
# Name: 8909, dtype: float64
# mi                 16.0000
# count_order    148037.2526
# Name: 8910, dtype: float64
# mi                 16.000000
# count_order    148426.728572
# Name: 8911, dtype: float64
# mi                 16.000000
# count_order    147483.600342
# Name: 8912, dtype: float64
# mi                 16.000000
# count_order    148376.805115
# Name: 8913, dtype: float64
# mi                 16.000000
# count_order    147714.765902
# Name: 8914, dtype: float64
# mi                 16.000000
# count_order    147909.984449
# Name: 8915, dtype: float64
# mi                 16.000000
# count_order    148298.088537
# Name: 8916, dtype: float64
# mi                 16.000000
# count_order    148232.662199
# Name: 8917, dtype: float64
# mi                 16.000000
# count_order    147974.107545
# Name: 8918, dtype: float64
# mi                 16.000000
# count_order    146733.285151
# Name: 8919, dtype: float64
# mi                 16.0000
# count_order    147989.7128
# Name: 8920, dtype: float64
# mi                 16.000000
# count_order    147038.224418
# Name: 8921, dtype: float64
# mi                 16.00000
# count_order    147949.84969
# Name: 8922, dtype: float64
# mi                 16.000000
# count_order    147141.683558
# Name: 8923, dtype: float64
# mi                 16.000000
# count_order    147598.311125
# Name: 8924, dtype: float64
# mi                 16.00000
# count_order    147874.13689
# Name: 8925, dtype: float64
# mi                 16.000000
# count_order    148036.063854
# Name: 8926, dtype: float64
# mi                 16.000000
# count_order    147925.788916
# Name: 8927, dtype: float64
# mi                 16.000000
# count_order    147831.492325
# Name: 8928, dtype: float64
# mi                 16.000000
# count_order    148053.184398
# Name: 8929, dtype: float64
# mi                 16.000000
# count_order    147702.077557
# Name: 8930, dtype: float64
# mi                 16.000000
# count_order    148037.175192
# Name: 8931, dtype: float64
# mi                 16.000000
# count_order    147671.426643
# Name: 8932, dtype: float64
# mi                 16.000000
# count_order    147253.760026
# Name: 8933, dtype: float64
# mi                 16.000000
# count_order    147952.377811
# Name: 8934, dtype: float64
# mi                 16.000000
# count_order    147963.342904
# Name: 8935, dtype: float64
# mi                 16.000000
# count_order    148113.706416
# Name: 8936, dtype: float64
# mi                 16.000000
# count_order    147992.635358
# Name: 8937, dtype: float64
# mi                 16.000000
# count_order    147340.797818
# Name: 8938, dtype: float64
# mi                 16.000000
# count_order    148029.005892
# Name: 8939, dtype: float64
# mi                 16.000000
# count_order    148091.008794
# Name: 8940, dtype: float64
# mi                 16.000000
# count_order    148397.024389
# Name: 8941, dtype: float64
# mi                 16.000000
# count_order    147503.138399
# Name: 8942, dtype: float64
# mi                 16.000000
# count_order    147566.372804
# Name: 8943, dtype: float64
# mi                 16.000000
# count_order    148353.304307
# Name: 8944, dtype: float64
# mi                 16.000000
# count_order    148245.829797
# Name: 8945, dtype: float64
# mi                 16.000000
# count_order    147135.127877
# Name: 8946, dtype: float64
# mi                 16.000000
# count_order    148241.129658
# Name: 8947, dtype: float64
# mi                 16.000000
# count_order    148520.172751
# Name: 8948, dtype: float64
# mi                 16.000000
# count_order    147924.308689
# Name: 8949, dtype: float64
# mi                 16.00000
# count_order    147449.45321
# Name: 8950, dtype: float64
# mi                 16.000000
# count_order    148182.037488
# Name: 8951, dtype: float64
# mi                 16.000000
# count_order    148372.118494
# Name: 8952, dtype: float64
# mi                 16.000000
# count_order    147467.723084
# Name: 8953, dtype: float64
# mi                 16.000000
# count_order    146497.539448
# Name: 8954, dtype: float64
# mi                 16.000000
# count_order    148247.343855
# Name: 8955, dtype: float64
# mi                 16.00000
# count_order    147241.79603
# Name: 8956, dtype: float64
# mi                 16.000000
# count_order    147332.694518
# Name: 8957, dtype: float64
# mi                 16.000000
# count_order    147424.728535
# Name: 8958, dtype: float64
# mi                 16.000000
# count_order    148164.465997
# Name: 8959, dtype: float64
# mi                 16.000000
# count_order    148487.577247
# Name: 8960, dtype: float64
# mi                 16.000000
# count_order    148014.740789
# Name: 8961, dtype: float64
# mi                 16.000000
# count_order    147818.188874
# Name: 8962, dtype: float64
# mi                 16.000000
# count_order    147583.373649
# Name: 8963, dtype: float64
# mi                 16.000000
# count_order    147137.895234
# Name: 8964, dtype: float64
# mi                 16.000000
# count_order    147990.502739
# Name: 8965, dtype: float64
# mi                 16.000000
# count_order    147679.871922
# Name: 8966, dtype: float64
# mi                 16.000000
# count_order    147960.550593
# Name: 8967, dtype: float64
# mi                 16.000000
# count_order    148258.690206
# Name: 8968, dtype: float64
# mi                 16.000000
# count_order    147554.578669
# Name: 8969, dtype: float64
# mi                 16.000000
# count_order    148017.032123
# Name: 8970, dtype: float64
# mi                 16.000000
# count_order    147727.159787
# Name: 8971, dtype: float64
# mi                 16.00000
# count_order    148120.18698
# Name: 8972, dtype: float64
# mi                 16.00000
# count_order    147783.22124
# Name: 8973, dtype: float64
# mi                 16.000000
# count_order    147222.652528
# Name: 8974, dtype: float64
# mi                 16.000000
# count_order    147085.743371
# Name: 8975, dtype: float64
# mi                 16.000000
# count_order    147883.099755
# Name: 8976, dtype: float64
# mi                 16.000000
# count_order    147927.265931
# Name: 8977, dtype: float64
# mi                 16.000000
# count_order    147810.471525
# Name: 8978, dtype: float64
# mi                 16.000000
# count_order    147719.202762
# Name: 8979, dtype: float64
# mi                 16.00000
# count_order    147378.50499
# Name: 8980, dtype: float64
# mi                 16.000000
# count_order    148068.372723
# Name: 8981, dtype: float64
# mi                 16.000000
# count_order    147725.071105
# Name: 8982, dtype: float64
# mi                 16.000000
# count_order    148252.877736
# Name: 8983, dtype: float64
# mi                 16.000000
# count_order    147336.672119
# Name: 8984, dtype: float64
# mi                 16.000000
# count_order    148241.205406
# Name: 8985, dtype: float64
# mi                 16.000000
# count_order    147746.963604
# Name: 8986, dtype: float64
# mi                 16.000000
# count_order    147269.844775
# Name: 8987, dtype: float64
# mi                 16.000000
# count_order    147749.327348
# Name: 8988, dtype: float64
# mi                 16.000000
# count_order    147823.386578
# Name: 8989, dtype: float64
# mi                 16.000000
# count_order    148174.122764
# Name: 8990, dtype: float64
# mi                 16.000000
# count_order    147639.091709
# Name: 8991, dtype: float64
# mi                 16.000000
# count_order    147619.349689
# Name: 8992, dtype: float64
# mi                 16.000000
# count_order    147750.100158
# Name: 8993, dtype: float64
# mi                 16.000000
# count_order    147250.017621
# Name: 8994, dtype: float64
# mi                 16.000000
# count_order    148081.589443
# Name: 8995, dtype: float64
# mi                 16.00000
# count_order    148001.53166
# Name: 8996, dtype: float64
# mi                 16.000000
# count_order    147498.532487
# Name: 8997, dtype: float64
# mi                 16.000000
# count_order    147168.174465
# Name: 8998, dtype: float64
# mi                 16.000000
# count_order    147740.613452
# Name: 8999, dtype: float64
#              mi  absolute error count_order  relative error count_order
# 0      0.001248                  639.372458                    0.432622
# 1      0.001248                17755.269452                   12.013850
# 2      0.001248                12258.295845                    8.294401
# 3      0.001248                 1159.424438                    0.784508
# 4      0.001248                 3019.155465                    2.042869
# ...         ...                         ...                         ...
# 8995  16.000000                  291.589443                    0.197300
# 8996  16.000000                  211.531660                    0.143130
# 8997  16.000000                  291.467513                    0.197217
# 8998  16.000000                  621.825535                    0.420749
# 8999  16.000000                   49.386548                    0.033417
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 count_order mean  count_order var
# type factor
# pac  0.001248      147605.122384     6.588342e+07
#      0.015625      147891.709686     5.351088e+06
#      0.031250      147710.659311     2.639591e+06
#      0.062500      147783.744735     1.489641e+06
#      0.250000      147781.745798     4.520012e+05
#      1.000000      147747.303006     2.314224e+05
#      2.000000      147784.323500     1.956552e+05
#      4.000000      147791.787296     1.761460e+05
#      16.000000     147794.060550     1.646672e+05

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error count_order mean  \
# type factor
# pac  0.001248                       6554.538908
#      0.015625                       1860.197023
#      0.031250                       1306.031635
#      0.062500                        961.349509
#      0.250000                        536.234530
#      1.000000                        387.324580
#      2.000000                        354.511590
#      4.000000                        331.053256
#      16.000000                       320.255898
#
#                 absolute error count_order var  \
# type factor
# pac  0.001248                     2.291265e+07
#      0.015625                     1.897646e+06
#      0.031250                     9.384657e+05
#      0.062500                     5.645618e+05
#      0.250000                     1.642341e+05
#      1.000000                     8.307674e+04
#      2.000000                     6.988319e+04
#      4.000000                     6.644323e+04
#      16.000000                    6.201717e+04
#
#                 relative error count_order mean  \
# type factor
# pac  0.001248                          4.435035
#      0.015625                          1.258676
#      0.031250                          0.883708
#      0.062500                          0.650483
#      0.250000                          0.362835
#      1.000000                          0.262078
#      2.000000                          0.239875
#      4.000000                          0.224002
#      16.000000                         0.216697
#
#                 relative error count_order var
# type factor
# pac  0.001248                        10.490235
#      0.015625                         0.868811
#      0.031250                         0.429663
#      0.062500                         0.258477
#      0.250000                         0.075192
#      1.000000                         0.038036
#      2.000000                         0.031995
#      4.000000                         0.030420
#      16.000000                        0.028394

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#             count_order
# mi
# 0.001248   6.588342e+07
# 0.015625   5.351088e+06
# 0.031250   2.639591e+06
# 0.062500   1.489641e+06
# 0.250000   4.520012e+05
# 1.000000   2.314224e+05
# 2.000000   1.956552e+05
# 4.000000   1.761460e+05
# 16.000000  1.646672e+05

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step              scale
# query       count_order
# mi
# 0.001248   6.254442e+07
# 0.015625   4.996823e+06
# 0.031250   2.498412e+06
# 0.062500   1.249206e+06
# 0.250000   3.123014e+05
# 1.000000   7.807536e+04
# 2.000000   3.903768e+04
# 4.000000   1.951884e+04
# 16.000000  4.879710e+03

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# count_order    0.212753
# dtype: float64
#            count_order
# mi
# 0.001248      0.214874
# 0.015625      0.206857
# 0.031250      0.214705
# 0.062500      0.211439
# 0.250000      0.214925
# 1.000000      0.212641
# 2.000000      0.212350
# 4.000000      0.213844
# 16.000000     0.213139

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71972/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query           count_order
# mi
# 0.001248        6548.613685
# 0.015625        1821.857099
# 0.031250        1245.591588
# 0.062500         894.196450
# 0.250000         438.338240
# 1.000000         232.761577
# 2.000000         154.080745
# 4.000000         110.438796
# 16.000000         54.749158

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71972/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71972/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query       count_order
# mi
# 0.001248     147791.838
# 0.015625     147789.074
# 0.031250     147777.996
# 0.062500     147780.574
# 0.250000     147800.190
# 1.000000     147763.246
# 2.000000     147774.596
# 4.000000     147782.748
# 16.000000    147793.826
# step    chosen_sample
# query     count_order
# all mi  147783.787556

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71972/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#            count_order
# mi
# 0.001248      4.435035
# 0.015625      1.258676
# 0.031250      0.883708
# 0.062500      0.650483
# 0.250000      0.362835
# 1.000000      0.262078
# 2.000000      0.239875
# 4.000000      0.224002
# 16.000000     0.216697

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#            count_order
# mi
# 0.001248      4.220162
# 0.015625      1.051819
# 0.031250      0.669003
# 0.062500      0.439044
# 0.250000      0.147910
# 1.000000      0.049437
# 2.000000      0.027525
# 4.000000      0.010159
# 16.000000     0.003558

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()
