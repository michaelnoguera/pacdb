# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   -- sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   -- sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   avg(l_quantity) as avg_qty,
#   -- avg(l_extendedprice) as avg_price,
#   -- avg(l_discount) as avg_disc,
#   -- count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'N'
#   and l_linestatus = 'F'
# ```

# %%
EXPERIMENT = 'pac-q1-avg-qty-N-F'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'N') &
        (lineitem_df['l_linestatus'] == 'F')
    ]
    print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        # float(discounted_price.sum()),                      # sum_disc_price
        # float(charged_price.sum()),                         # sum_charge
        float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        # float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        # float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        # float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# (3765, 16)
# [25.30066401062417]
# [25.30066401062417]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['avg_qty']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 147790  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            # out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np
# Out:
# (3765, 16)
# [25.30066401062417]

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
# TODO: Change it back to 1000
EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    out_np = generate_samples() # generate samples (results of running the query)
    # print(f"Generate samples... {len(out_np)} samples generated.")

    print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# (1880, 16)
# [25.064893617021276]
# (1885, 16)
# [25.53580901856764]
# (1925, 16)
# [25.07948051948052]
# (1840, 16)
# [25.532065217391306]
# (1858, 16)
# [25.38912809472551]
# (1907, 16)
# [25.214472994231777]
# (1902, 16)
# [25.166140904311252]
# (1863, 16)
# [25.438003220611915]
# (1913, 16)
# [25.594877156299006]
# (1852, 16)
# [24.996760259179265]
# (1854, 16)
# [25.199568500539375]
# (1911, 16)
# [25.398744113029828]
# (1831, 16)
# [25.41561987984708]
# (1934, 16)
# [25.191830403309204]
# (1894, 16)
# [24.988384371700107]
# (1871, 16)
# [25.616782469267772]
# (1885, 16)
# [25.456233421750664]
# (1880, 16)
# [25.14468085106383]
# (1878, 16)
# [25.56975505857295]
# (1887, 16)
# [25.03285638579756]
# (1850, 16)
# [25.163243243243244]
# (1915, 16)
# [25.433420365535248]
# (1888, 16)
# [25.10487288135593]
# (1877, 16)
# [25.49760255727224]
# (1894, 16)
# [25.463041182682154]
# (1871, 16)
# [25.136290753607696]
# (1895, 16)
# [24.913984168865436]
# (1870, 16)
# [25.692513368983956]
# (1920, 16)
# [25.069270833333334]
# (1845, 16)
# [25.541463414634148]
# (1859, 16)
# [24.82409897794513]
# (1906, 16)
# [25.765477439664217]
# (1878, 16)
# [25.210330138445155]
# (1887, 16)
# [25.39056703762586]
# (1859, 16)
# [25.438407746100054]
# (1906, 16)
# [25.166316894018887]
# (1867, 16)
# [25.549009105516873]
# (1898, 16)
# [25.056375131717598]
# (1851, 16)
# [25.15775256618044]
# (1914, 16)
# (1836, 16)
# [25.147058823529413]
# (1890, 16)
# [25.46931216931217]
# (1875, 16)
# [25.130666666666666]
# (1894, 16)
# [25.44456177402323]
# (1871, 16)
# [25.154997327632284]
# (1925, 16)
# [25.255584415584416]
# (1840, 16)
# [25.347826086956523]
# (1891, 16)
# [25.766261237440506]
# (1874, 16)
# [24.830843116328708]
# (1858, 16)
# [25.090419806243272]
# (1907, 16)
# [25.505506030414264]
# (1894, 16)
# [25.38014783526927]
# (1871, 16)
# [25.220203099946552]
# (1893, 16)
# ...
# Chosen Sample [25.22849604]
# Chosen Sample [25.36756187]
# Chosen Sample [25.3256181]
# Chosen Sample [25.4180151]
# Chosen Sample [25.69567539]
# Chosen Sample [25.11268372]
# Chosen Sample [24.97578041]
# Chosen Sample [25.01294498]
# Chosen Sample [25.33642818]
# Chosen Sample [25.60966341]
# Chosen Sample [25.03388036]
# Chosen Sample [25.44543081]
# Chosen Sample [25.23857068]
# Chosen Sample [25.12619808]
# Chosen Sample [25.61405349]
# Chosen Sample [25.75778008]
# Chosen Sample [25.25794492]
# Chosen Sample [24.89963216]
# Chosen Sample [25.54967603]
# Chosen Sample [25.18779841]
# Chosen Sample [25.45238095]
# Chosen Sample [25.17304582]
# Chosen Sample [25.15960912]
# Chosen Sample [24.8979376]
# Chosen Sample [25.42562202]
# Chosen Sample [25.14647281]
# Chosen Sample [24.91029724]
# Chosen Sample [25.1994709]
# Chosen Sample [25.48660011]
# Chosen Sample [25.56507592]
# Chosen Sample [25.16903633]
# Chosen Sample [25.38709677]
# Chosen Sample [25.43120717]
# Chosen Sample [25.55467091]
# Chosen Sample [25.67464862]
# Chosen Sample [25.58059299]
# Chosen Sample [25.12776025]
# Chosen Sample [25.30248546]
# Chosen Sample [25.26923077]
# Chosen Sample [25.39784946]
# Chosen Sample [25.43736952]
# Chosen Sample [25.51939655]
# Chosen Sample [25.07042254]
# Chosen Sample [25.42536116]
# Chosen Sample [25.31909283]
# Chosen Sample [25.23366013]
# Chosen Sample [25.1776]
# Chosen Sample [25.29308511]
# Chosen Sample [25.56093667]
# Chosen Sample [25.04487179]
# Chosen Sample [25.3741532]
# Chosen Sample [25.02895442]
# Chosen Sample [25.32682154]
# Chosen Sample [25.47741216]
# Chosen Sample [25.35976268]
# Chosen Sample [25.53916309]
# Chosen Sample [25.33891892]
# Chosen Sample [25.15820417]
# Chosen Sample [25.2478678]
# Chosen Sample [25.37166754]
# Chosen Sample [25.10437158]
# Chosen Sample [25.23234984]
# Chosen Sample [25.15416238]
# Chosen Sample [25.40116279]
# Chosen Sample [25.47202073]
# Chosen Sample [25.0534846]
# Chosen Sample [25.30667373]
# Chosen Sample [25.36878675]
# Chosen Sample [25.09711286]
# Chosen Sample [25.22387268]
# Chosen Sample [24.78647497]
# Chosen Sample [25.55748031]
# Chosen Sample [25.12610735]
# Chosen Sample [25.3452188]
# Chosen Sample [25.131897]
# Chosen Sample [25.58472297]
# Chosen Sample [24.91960581]
# Chosen Sample [25.41853035]
# Chosen Sample [25.30665978]
# Chosen Sample [25.30998914]
# Chosen Sample [25.50287206]
# Chosen Sample [25.41757106]
# Chosen Sample [25.08324496]
# Chosen Sample [25.00802998]
# Chosen Sample [25.09836901]
# Chosen Sample [25.60834671]
# Chosen Sample [25.43562796]
# Chosen Sample [25.37703199]
# Chosen Sample [25.4218585]
# Chosen Sample [25.69132653]
# Chosen Sample [25.2310213]
# Chosen Sample [25.18342246]
# Chosen Sample [25.46521508]
# Chosen Sample [25.15118197]
# Chosen Sample [25.49705725]
# Chosen Sample [25.70183983]
# Chosen Sample [25.05428419]
# Chosen Sample [25.19758276]
# Chosen Sample [25.3495457]
# Chosen Sample [25.75323276]
# Chosen Sample [25.16075157]
# Chosen Sample [25.69251337]
# Chosen Sample [25.16972973]
# Chosen Sample [25.43531283]
# Chosen Sample [25.46377578]
# Chosen Sample [25.56782334]
# Chosen Sample [25.50522466]
# Chosen Sample [25.69852165]
# Chosen Sample [25.32256327]
# Chosen Sample [25.30645161]
# Chosen Sample [25.12039958]
# Chosen Sample [25.4118896]
# Chosen Sample [24.68655914]
# Chosen Sample [25.1656643]
# Chosen Sample [25.42379182]
# Chosen Sample [25.13607257]
# Chosen Sample [25.22397476]
# Chosen Sample [25.42529349]
# Chosen Sample [25.15882353]
# Chosen Sample [25.23036093]
# Chosen Sample [25.53146853]
# Chosen Sample [25.06229686]
# Chosen Sample [25.16525424]
# Chosen Sample [25.54963806]
# Chosen Sample [25.30515464]
# Chosen Sample [25.70234292]
# Chosen Sample [25.56230201]
# Chosen Sample [25.22365591]
# Chosen Sample [25.57112639]
# Chosen Sample [25.05177994]
# Chosen Sample [25.32163743]
# Chosen Sample [25.23183024]
# Chosen Sample [25.50448549]
# Chosen Sample [25.01941748]
# Chosen Sample [25.89756098]
# Chosen Sample [25.04507338]
# Chosen Sample [25.43541667]
# Chosen Sample [25.48724761]
# Chosen Sample [25.32165948]
# Chosen Sample [25.16065748]
# Chosen Sample [25.50131372]
# Chosen Sample [25.54934726]
# Chosen Sample [25.11353945]
# Chosen Sample [25.31266846]
# Chosen Sample [25.28506098]
# Chosen Sample [25.70442571]
# Chosen Sample [25.17015566]
# Chosen Sample [25.23696682]
# Chosen Sample [25.43686734]
# Chosen Sample [25.28679654]
# Chosen Sample [25.39989572]
# Chosen Sample [25.15628357]
# Chosen Sample [25.08342078]
# Chosen Sample [25.30122406]
# Chosen Sample [25.27121375]
# Chosen Sample [25.53782441]
# Chosen Sample [25.63423711]
# Chosen Sample [25.23691032]
# Chosen Sample [25.17148982]
# Chosen Sample [25.33385993]
# Chosen Sample [25.27389517]
# Chosen Sample [25.19444444]
# Chosen Sample [25.57783641]
# Chosen Sample [25.33491561]
# Chosen Sample [25.05044666]
# Chosen Sample [25.26442812]
# Chosen Sample [24.89791555]
# Chosen Sample [25.43478261]
# Chosen Sample [25.64316239]
# Chosen Sample [25.3969795]
# Chosen Sample [25.10310363]
# Chosen Sample [25.28025144]
# Chosen Sample [25.12572636]
# Chosen Sample [25.66775244]
# Chosen Sample [25.61137194]
# Chosen Sample [25.70093946]
# Chosen Sample [25.38024429]
# Chosen Sample [25.16068643]
# Chosen Sample [25.33421053]
# Chosen Sample [25.25794492]
# Chosen Sample [25.24069219]
# Chosen Sample [24.90447922]
# Chosen Sample [25.35642517]
# Chosen Sample [25.35132218]
# Chosen Sample [25.11183144]
# Chosen Sample [25.5359375]
# Chosen Sample [25.59667916]
# Chosen Sample [25.35433941]
# Chosen Sample [25.04089219]
# Chosen Sample [24.90597826]
# Chosen Sample [25.55842105]
# Chosen Sample [25.16272825]
# Chosen Sample [25.35605663]
# Chosen Sample [25.13290803]
# Chosen Sample [25.47348887]
# Chosen Sample [25.1606383]
# Chosen Sample [25.52079867]
# Chosen Sample [24.93817204]
# Chosen Sample [25.3567948]
# Chosen Sample [25.29032258]
# Chosen Sample [25.38316244]
# Chosen Sample [25.49735729]
# Chosen Sample [25.24116743]
# Chosen Sample [25.08979156]
# Chosen Sample [25.09559613]
# Chosen Sample [25.36479029]
# Chosen Sample [25.39872068]
# Chosen Sample [25.23989637]
# Chosen Sample [25.34231806]
# Chosen Sample [25.30793319]
# Chosen Sample [25.22753247]
# Chosen Sample [25.15056665]
# Chosen Sample [25.46816685]
# Chosen Sample [25.18439337]
# Chosen Sample [25.78390059]
# Chosen Sample [25.07692308]
# Chosen Sample [25.4436512]
# Chosen Sample [24.99730603]
# Chosen Sample [25.40980075]
# Chosen Sample [25.27210884]
# Chosen Sample [25.86460554]
# Chosen Sample [25.23110151]
# Chosen Sample [24.9671159]
# Chosen Sample [25.2532538]
# Chosen Sample [25.28210639]
# Chosen Sample [25.69628433]
# Chosen Sample [25.07617504]
# Chosen Sample [25.02352326]
# Chosen Sample [25.30328296]
# Chosen Sample [25.28077528]
# Chosen Sample [25.43184297]
# Chosen Sample [25.20686071]
# Chosen Sample [25.22498618]
# Chosen Sample [25.75911252]
# Chosen Sample [25.50586354]
# Chosen Sample [25.26680896]
# Chosen Sample [25.30058729]
# Chosen Sample [25.09881847]
# Chosen Sample [25.03208837]
# Chosen Sample [25.26923077]
# Chosen Sample [25.28190069]
# Chosen Sample [25.02770378]
# Chosen Sample [25.41099476]
# Chosen Sample [25.21375267]
# Chosen Sample [25.20763852]
# Chosen Sample [25.19978858]
# Chosen Sample [25.0643617]
# Chosen Sample [25.48838466]
# Chosen Sample [25.31498638]
# Chosen Sample [25.05411141]
# Chosen Sample [24.86746988]
# Chosen Sample [25.37183544]
# Chosen Sample [25.46709817]
# Chosen Sample [25.48027719]
# Chosen Sample [25.48960613]
# Chosen Sample [25.1255144]
# Chosen Sample [25.71323142]
# Chosen Sample [25.43282802]
# Chosen Sample [25.29661472]
# Chosen Sample [25.22042139]
# Chosen Sample [25.59968271]
# Chosen Sample [25.55526316]
# Chosen Sample [25.45582854]
# Chosen Sample [25.3892372]
# Chosen Sample [25.10113519]
# Chosen Sample [25.44481236]
# Chosen Sample [25.13629075]
# Chosen Sample [24.78939076]
# Chosen Sample [25.30345572]
# Chosen Sample [25.66649049]
# Chosen Sample [24.9863803]
# Chosen Sample [25.0927673]
# Chosen Sample [25.76950904]
# Chosen Sample [25.30993521]
# Chosen Sample [25.35783262]
# Chosen Sample [25.39936609]
# Chosen Sample [25.00431965]
# Chosen Sample [25.50410509]
# Chosen Sample [25.34041423]
# Chosen Sample [25.51307531]
# Chosen Sample [24.891793]
# Chosen Sample [25.309844]
# Chosen Sample [25.21466525]
# Chosen Sample [25.44077568]
# Chosen Sample [25.32834225]
# Chosen Sample [25.50822281]
# Chosen Sample [25.40797872]
# Chosen Sample [25.09159079]
# Chosen Sample [25.03210273]
# Chosen Sample [25.43840775]
# Chosen Sample [25.87698834]
# Chosen Sample [25.35306667]
# Chosen Sample [25.20686071]
# Chosen Sample [24.88588426]
# Chosen Sample [25.54512259]
# Chosen Sample [25.32744283]
# Chosen Sample [25.24973822]
# Chosen Sample [25.37941953]
# Chosen Sample [25.19312602]
# Chosen Sample [25.42632407]
# Chosen Sample [24.85798817]
# Chosen Sample [25.15856237]
# Chosen Sample [25.13029316]
# Chosen Sample [25.43987507]
# Chosen Sample [25.33422175]
# Chosen Sample [25.43059937]
# Chosen Sample [25.5477707]
# Chosen Sample [25.16836461]
# Chosen Sample [25.24318658]
# Chosen Sample [25.27890098]
# Chosen Sample [25.2411953]
# Chosen Sample [25.74478331]
# Chosen Sample [25.3990333]
# Chosen Sample [25.12646745]
# Chosen Sample [25.30633047]
# Chosen Sample [25.54459834]
# Chosen Sample [24.95717345]
# Chosen Sample [25.23009815]
# Chosen Sample [25.1408]
# Chosen Sample [25.43991416]
# Chosen Sample [25.63674762]
# Chosen Sample [25.50736842]
# Chosen Sample [25.50909091]
# Chosen Sample [25.21353066]
# Chosen Sample [25.50944386]
# Chosen Sample [24.99787347]
# Chosen Sample [25.37144391]
# Chosen Sample [25.37052201]
# Chosen Sample [25.41701461]
# Chosen Sample [25.21805702]
# Chosen Sample [25.10335498]
# Chosen Sample [24.86659494]
# Chosen Sample [25.13767343]
# Chosen Sample [25.01588142]
# Chosen Sample [25.44379015]
# Chosen Sample [25.52428722]
# Chosen Sample [25.0650236]
# Chosen Sample [25.37904067]
# Chosen Sample [25.5222759]
# Chosen Sample [25.20140769]
# Chosen Sample [25.40301612]
# Chosen Sample [25.12235416]
# Chosen Sample [25.6862955]
# Chosen Sample [25.28758512]
# Chosen Sample [25.14439655]
# Chosen Sample [25.86979441]
# Chosen Sample [25.19308511]
# Chosen Sample [25.76136364]
# Chosen Sample [25.42759347]
# Chosen Sample [25.09831613]
# Chosen Sample [25.37474333]
# Chosen Sample [25.30181418]
# Chosen Sample [25.53128259]
# Chosen Sample [25.38336933]
# Chosen Sample [25.25077882]
# Chosen Sample [25.58026667]
# Chosen Sample [24.91680261]
# Chosen Sample [25.47792916]
# Chosen Sample [25.47631442]
# Chosen Sample [25.56086044]
# Chosen Sample [25.30319149]
# Chosen Sample [25.03510638]
# Chosen Sample [25.1459893]
# Chosen Sample [24.82234043]
# Chosen Sample [25.21601686]
# Chosen Sample [25.3379845]
# Chosen Sample [25.33190807]
# Chosen Sample [25.34668072]
# Chosen Sample [25.15336134]
# Chosen Sample [25.15628357]
# Chosen Sample [25.12473573]
# Chosen Sample [25.38918919]
# Chosen Sample [25.17043661]
# Chosen Sample [25.01918977]
# Chosen Sample [25.08120531]
# Chosen Sample [25.1152]
# Chosen Sample [25.21063718]
# Chosen Sample [25.52095491]
# Chosen Sample [25.27272727]
# Chosen Sample [25.15240084]
# Chosen Sample [25.12574204]
# Chosen Sample [25.26688103]
# Chosen Sample [25.30328296]
# Chosen Sample [25.30969139]
# Chosen Sample [25.15941269]
# Chosen Sample [25.42746914]
# Chosen Sample [25.41099476]
# Chosen Sample [24.77265501]
# Chosen Sample [25.54530744]
# Chosen Sample [24.81301258]
# Chosen Sample [25.0229089]
# Chosen Sample [25.40126716]
# Chosen Sample [25.57980115]
# Chosen Sample [25.16489926]
# Chosen Sample [25.30545455]
# Chosen Sample [25.33924843]
# Chosen Sample [25.05626327]
# Chosen Sample [25.45992469]
# Chosen Sample [25.48596588]
# Chosen Sample [25.32743363]
# Chosen Sample [25.69184783]
# Chosen Sample [24.99524815]
# Chosen Sample [25.08852803]
# Chosen Sample [25.04657388]
# Chosen Sample [25.30838641]
# Chosen Sample [24.87267905]
# Chosen Sample [25.1994709]
# Chosen Sample [25.41901776]
# Chosen Sample [25.59189047]
# Chosen Sample [25.66577825]
# Chosen Sample [25.59538784]
# Chosen Sample [25.37025316]
# Chosen Sample [25.66649049]
# Chosen Sample [24.961559]
# Chosen Sample [25.17986799]
# Chosen Sample [25.42435424]
# Chosen Sample [25.18773136]
# Chosen Sample [24.88395722]
# Chosen Sample [25.28014366]
# Chosen Sample [25.24947034]
# Chosen Sample [25.48840885]
# Chosen Sample [25.41617882]
# Chosen Sample [25.33981092]
# Chosen Sample [25.15900487]
# Chosen Sample [25.34714211]
# Chosen Sample [25.08275494]
# Chosen Sample [25.17822839]
# Chosen Sample [25.19287212]
# Chosen Sample [25.43]
# Chosen Sample [25.54749478]
# Chosen Sample [25.37826541]
# Chosen Sample [25.29510784]
# Chosen Sample [25.53097345]
# Chosen Sample [25.81803714]
# Chosen Sample [25.44139388]
# Chosen Sample [25.33385013]
# Chosen Sample [25.28809908]
# Chosen Sample [25.28624733]
# Chosen Sample [25.18980021]
# Chosen Sample [25.21904762]
# Chosen Sample [25.3476874]
# Chosen Sample [25.54813665]
# Chosen Sample [25.20684039]
# Chosen Sample [25.17704918]
# Chosen Sample [25.41362661]
# Chosen Sample [25.50573514]
# Chosen Sample [25.55515088]
# Chosen Sample [25.13285641]
# Chosen Sample [25.57678293]
# Chosen Sample [25.29259451]
# Chosen Sample [25.14308511]
# Chosen Sample [25.22922181]
# Chosen Sample [25.36741214]
# Chosen Sample [25.66057441]
# Chosen Sample [25.37895867]
# Chosen Sample [25.34713701]
# Chosen Sample [25.46826223]
# Chosen Sample [25.40734824]
# Chosen Sample [25.34393217]
# Chosen Sample [25.00737619]
# Chosen Sample [25.18205945]
# Chosen Sample [25.23463983]
# Chosen Sample [25.47821409]
# Chosen Sample [25.16367476]
# Chosen Sample [25.15972588]
# Chosen Sample [25.03410937]
# Chosen Sample [25.41033755]
# Chosen Sample [25.12828601]
# Chosen Sample [25.32943055]
# Chosen Sample [25.26740506]
# Chosen Sample [25.22445652]
# Chosen Sample [25.15130527]
# Chosen Sample [25.290625]
# Chosen Sample [25.20870951]
# Chosen Sample [25.25172231]
# Chosen Sample [25.4336]
# Chosen Sample [25.54530744]
# Chosen Sample [25.01705757]
# Chosen Sample [25.73670213]
# Chosen Sample [25.52139037]
# Chosen Sample [25.39684211]
# Chosen Sample [24.85798817]
# Chosen Sample [25.43872679]
# Chosen Sample [25.14907162]
# Chosen Sample [25.41532048]
# Chosen Sample [25.41618799]
# Chosen Sample [25.44681988]
# Chosen Sample [25.20318302]
# Chosen Sample [25.38868126]
# Chosen Sample [25.34051498]
# Chosen Sample [25.36277102]
# Chosen Sample [25.30170576]
# Chosen Sample [25.32247731]
# Chosen Sample [25.18520435]
# Chosen Sample [25.09261186]
# Chosen Sample [25.51926207]
# Chosen Sample [25.49062667]
# Chosen Sample [25.21390086]
# Chosen Sample [25.16366612]
# Chosen Sample [25.52592981]
# Chosen Sample [25.65260417]
# Chosen Sample [25.22866345]
# Chosen Sample [25.46866631]
# Chosen Sample [25.51309707]
# Chosen Sample [25.24161788]
# Chosen Sample [25.2793501]
# Chosen Sample [25.39449541]
# Chosen Sample [25.42529349]
# Chosen Sample [25.30530262]
# Chosen Sample [25.00885417]
# Chosen Sample [25.08887734]
# Chosen Sample [25.27086699]
# Chosen Sample [25.17389006]
# Chosen Sample [25.16719577]
# Chosen Sample [25.08744038]
# Chosen Sample [24.87007455]
# Chosen Sample [25.66992791]
# Chosen Sample [25.32835024]
# Chosen Sample [25.17722879]
# Chosen Sample [25.06819393]
# Chosen Sample [24.98411858]
# Chosen Sample [24.99630607]
# Chosen Sample [25.38633938]
# Chosen Sample [25.46836789]
# Chosen Sample [25.00476695]
# Chosen Sample [25.31014644]
# Chosen Sample [25.72300216]
# Chosen Sample [25.54146341]
# Chosen Sample [25.41176471]
# Chosen Sample [25.2411953]
# Chosen Sample [25.33507853]
# Chosen Sample [25.07421249]
# Chosen Sample [25.71771612]
# Chosen Sample [25.13958333]
# Chosen Sample [25.36457766]
# Chosen Sample [25.48036579]
# Chosen Sample [25.09706667]
# Chosen Sample [25.41827957]
# Chosen Sample [25.52095491]
# Chosen Sample [25.31538063]
# Chosen Sample [25.46085129]
# Chosen Sample [25.30172865]
# Chosen Sample [25.32140978]
# Chosen Sample [25.51607717]
# Chosen Sample [25.43980738]
# Chosen Sample [25.12422037]
# Chosen Sample [25.3144357]
# Chosen Sample [25.40394877]
# Chosen Sample [25.70364328]
# Chosen Sample [24.97088407]
# Chosen Sample [25.01294498]
# Chosen Sample [25.22464899]
# Chosen Sample [25.79561263]
# Chosen Sample [25.15146667]
# Chosen Sample [25.29171039]
# Chosen Sample [25.41050375]
# Chosen Sample [25.15178571]
# Chosen Sample [25.21033014]
# Chosen Sample [25.39309984]
# Chosen Sample [25.07327359]
# Chosen Sample [25.50910036]
# Chosen Sample [25.61137194]
# Chosen Sample [25.46531483]
# Chosen Sample [24.89711486]
# Chosen Sample [25.33642818]
# Chosen Sample [25.21529889]
# Chosen Sample [25.43037975]
# Chosen Sample [25.05956774]
# Chosen Sample [25.38370294]
# Chosen Sample [25.54876742]
# Chosen Sample [25.44403573]
# Chosen Sample [25.11023622]
# Chosen Sample [25.06448203]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                 scale         chosen_sample  \
# 0  0.001248  [21.776269678317504]  [25.350656167979004]
# 1  0.001248  [21.776269678317504]   [25.36814345991561]
# 2  0.001248  [21.776269678317504]   [25.16063829787234]
# 3  0.001248  [21.776269678317504]  [25.193565683646113]
# 4  0.001248  [21.776269678317504]  [25.145294725956568]
#
#              chosen_noise               release
# 0   [-7.5092593637305285]  [17.841396804248475]
# 1    [-4.739943316797414]  [20.628200143118196]
# 2     [6.254271888943248]  [31.414910186815586]
# 3  [-0.42310168339376064]  [24.770464000252353]
# 4    [-6.869718819995095]  [18.275575905961475]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi     scale chosen_sample chosen_noise    release
# query             avg_qty       avg_qty      avg_qty    avg_qty
# 0      0.001248  21.77627     25.350656    -7.509259  17.841397
# 1      0.001248  21.77627     25.368143    -4.739943  20.628200
# 2      0.001248  21.77627     25.160638     6.254272  31.414910
# 3      0.001248  21.77627     25.193566    -0.423102  24.770464
# 4      0.001248  21.77627     25.145295    -6.869719  18.275576

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_10546/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step           scale chosen_sample chosen_noise    release
# query        avg_qty       avg_qty      avg_qty    avg_qty
# mi
# 0.001248   21.776270     25.292500     0.030874  25.323374
# 0.015625    1.739758     25.288950    -0.018746  25.270204
# 0.031250    0.869879     25.304412     0.027127  25.331539
# 0.062500    0.434940     25.298689     0.002321  25.301011
# 0.250000    0.108735     25.279675     0.006930  25.286606
# 1.000000    0.027184     25.284984     0.000519  25.285502
# 2.000000    0.013592     25.301497    -0.001425  25.300072
# 4.000000    0.006796     25.301105     0.004681  25.305786
# 16.000000   0.001699     25.304764     0.001971  25.306735

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['avg_qty'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi          0.001248
# avg_qty    17.841397
# Name: 0, dtype: float64
# mi          0.001248
# avg_qty    20.628200
# Name: 1, dtype: float64
# mi          0.001248
# avg_qty    31.414910
# Name: 2, dtype: float64
# mi          0.001248
# avg_qty    24.770464
# Name: 3, dtype: float64
# mi          0.001248
# avg_qty    18.275576
# Name: 4, dtype: float64
# mi          0.001248
# avg_qty    18.879240
# Name: 5, dtype: float64
# mi          0.001248
# avg_qty    23.527551
# Name: 6, dtype: float64
# mi          0.001248
# avg_qty    24.153809
# Name: 7, dtype: float64
# mi          0.001248
# avg_qty    30.931046
# Name: 8, dtype: float64
# mi          0.001248
# avg_qty    33.401137
# Name: 9, dtype: float64
# mi          0.001248
# avg_qty    20.348662
# Name: 10, dtype: float64
# mi          0.001248
# avg_qty    23.354986
# Name: 11, dtype: float64
# mi          0.001248
# avg_qty    29.996189
# Name: 12, dtype: float64
# mi          0.001248
# avg_qty    17.543279
# Name: 13, dtype: float64
# mi          0.001248
# avg_qty    21.757367
# Name: 14, dtype: float64
# mi          0.001248
# avg_qty    31.621853
# Name: 15, dtype: float64
# mi          0.001248
# avg_qty    25.087285
# Name: 16, dtype: float64
# mi          0.001248
# avg_qty    25.057394
# Name: 17, dtype: float64
# mi          0.001248
# avg_qty    24.620021
# Name: 18, dtype: float64
# mi          0.001248
# avg_qty    25.450874
# Name: 19, dtype: float64
# mi          0.001248
# avg_qty    28.166523
# Name: 20, dtype: float64
# mi          0.001248
# avg_qty    32.716995
# Name: 21, dtype: float64
# mi          0.001248
# avg_qty    15.804409
# Name: 22, dtype: float64
# mi          0.001248
# avg_qty    25.994095
# Name: 23, dtype: float64
# mi          0.001248
# avg_qty    26.559601
# Name: 24, dtype: float64
# mi          0.001248
# avg_qty    31.035513
# Name: 25, dtype: float64
# mi          0.001248
# avg_qty    25.633247
# Name: 26, dtype: float64
# mi          0.001248
# avg_qty    23.399063
# Name: 27, dtype: float64
# mi          0.001248
# avg_qty    20.445508
# Name: 28, dtype: float64
# mi          0.001248
# avg_qty    22.384426
# Name: 29, dtype: float64
# mi          0.001248
# avg_qty    25.214063
# Name: 30, dtype: float64
# mi          0.001248
# avg_qty    18.382489
# Name: 31, dtype: float64
# mi          0.001248
# avg_qty    36.071529
# Name: 32, dtype: float64
# mi          0.001248
# avg_qty    23.182001
# Name: 33, dtype: float64
# mi          0.001248
# avg_qty    15.221565
# Name: 34, dtype: float64
# mi          0.001248
# avg_qty    30.638900
# Name: 35, dtype: float64
# mi          0.001248
# avg_qty    27.526555
# Name: 36, dtype: float64
# mi          0.001248
# avg_qty    17.680662
# Name: 37, dtype: float64
# mi          0.001248
# avg_qty    28.573619
# Name: 38, dtype: float64
# mi          0.001248
# avg_qty    29.967195
# Name: 39, dtype: float64
# mi          0.001248
# avg_qty    34.574542
# Name: 40, dtype: float64
# mi          0.001248
# avg_qty    32.755680
# Name: 41, dtype: float64
# mi          0.001248
# avg_qty    33.376650
# Name: 42, dtype: float64
# mi          0.001248
# avg_qty    31.556179
# Name: 43, dtype: float64
# mi          0.001248
# avg_qty    18.343070
# Name: 44, dtype: float64
# mi          0.001248
# avg_qty    28.004610
# Name: 45, dtype: float64
# mi          0.001248
# avg_qty    21.746738
# Name: 46, dtype: float64
# mi          0.001248
# avg_qty    27.735382
# Name: 47, dtype: float64
# mi          0.001248
# avg_qty    24.518337
# Name: 48, dtype: float64
# mi          0.001248
# avg_qty    27.594060
# Name: 49, dtype: float64
# mi          0.001248
# avg_qty    32.801359
# Name: 50, dtype: float64
# mi          0.001248
# avg_qty    28.783456
# Name: 51, dtype: float64
# mi          0.001248
# avg_qty    36.971525
# Name: 52, dtype: float64
# mi          0.001248
# avg_qty    11.809884
# Name: 53, dtype: float64
# mi          0.001248
# avg_qty    17.002150
# Name: 54, dtype: float64
# mi          0.001248
# avg_qty    23.475139
# Name: 55, dtype: float64
# mi          0.001248
# avg_qty    36.708660
# Name: 56, dtype: float64
# mi          0.001248
# avg_qty    27.688186
# Name: 57, dtype: float64
# mi          0.001248
# avg_qty    22.057208
# Name: 58, dtype: float64
# mi          0.001248
# avg_qty    24.749982
# Name: 59, dtype: float64
# mi          0.001248
# avg_qty    28.145954
# Name: 60, dtype: float64
# mi          0.001248
# avg_qty    24.549753
# Name: 61, dtype: float64
# mi          0.001248
# avg_qty    21.864137
# Name: 62, dtype: float64
# mi          0.001248
# avg_qty    26.798934
# Name: 63, dtype: float64
# mi          0.001248
# avg_qty    32.886264
# Name: 64, dtype: float64
# mi          0.001248
# avg_qty    25.468598
# Name: 65, dtype: float64
# mi          0.001248
# avg_qty    24.270033
# Name: 66, dtype: float64
# mi          0.001248
# avg_qty    28.825005
# Name: 67, dtype: float64
# mi          0.001248
# avg_qty    30.947312
# Name: 68, dtype: float64
# mi          0.001248
# avg_qty    28.650825
# Name: 69, dtype: float64
# mi          0.001248
# avg_qty    19.388800
# Name: 70, dtype: float64
# mi          0.001248
# avg_qty    26.915350
# Name: 71, dtype: float64
# mi          0.001248
# avg_qty    24.386192
# Name: 72, dtype: float64
# mi          0.001248
# avg_qty    22.872878
# Name: 73, dtype: float64
# mi          0.001248
# avg_qty    29.895681
# Name: 74, dtype: float64
# mi          0.001248
# avg_qty    21.466925
# Name: 75, dtype: float64
# mi          0.001248
# avg_qty    23.284551
# Name: 76, dtype: float64
# mi          0.001248
# avg_qty    22.527937
# Name: 77, dtype: float64
# mi          0.001248
# avg_qty    13.725022
# Name: 78, dtype: float64
# mi          0.001248
# avg_qty    20.064854
# Name: 79, dtype: float64
# mi          0.001248
# avg_qty    20.733995
# Name: 80, dtype: float64
# mi          0.001248
# avg_qty    16.621611
# Name: 81, dtype: float64
# mi          0.001248
# avg_qty    18.511643
# Name: 82, dtype: float64
# mi          0.001248
# avg_qty    28.081680
# Name: 83, dtype: float64
# mi          0.001248
# avg_qty    24.819006
# Name: 84, dtype: float64
# mi          0.001248
# avg_qty    23.438966
# Name: 85, dtype: float64
# mi          0.001248
# avg_qty    25.576072
# Name: 86, dtype: float64
# mi          0.001248
# avg_qty    35.534097
# Name: 87, dtype: float64
# mi          0.001248
# avg_qty    27.960313
# Name: 88, dtype: float64
# mi          0.001248
# avg_qty    18.994746
# Name: 89, dtype: float64
# mi          0.001248
# avg_qty    27.755984
# Name: 90, dtype: float64
# mi          0.001248
# avg_qty    27.570323
# Name: 91, dtype: float64
# mi          0.001248
# avg_qty    27.541454
# Name: 92, dtype: float64
# mi          0.001248
# avg_qty    26.576496
# Name: 93, dtype: float64
# mi          0.001248
# avg_qty    30.447700
# Name: 94, dtype: float64
# mi          0.001248
# avg_qty    20.972957
# Name: 95, dtype: float64
# mi          0.001248
# avg_qty    24.278334
# Name: 96, dtype: float64
# mi          0.001248
# avg_qty    24.891302
# Name: 97, dtype: float64
# mi          0.001248
# avg_qty    22.041173
# Name: 98, dtype: float64
# mi          0.001248
# avg_qty    30.050529
# Name: 99, dtype: float64
# mi          0.001248
# avg_qty    28.966240
# Name: 100, dtype: float64
# mi          0.001248
# avg_qty    23.424075
# Name: 101, dtype: float64
# mi          0.001248
# avg_qty    28.816071
# Name: 102, dtype: float64
# mi          0.001248
# avg_qty    22.693675
# Name: 103, dtype: float64
# mi          0.001248
# avg_qty    19.013437
# Name: 104, dtype: float64
# mi          0.001248
# avg_qty    21.653090
# Name: 105, dtype: float64
# mi          0.001248
# avg_qty    20.335179
# Name: 106, dtype: float64
# mi          0.001248
# avg_qty    22.153789
# Name: 107, dtype: float64
# mi          0.001248
# avg_qty    18.700678
# Name: 108, dtype: float64
# mi          0.001248
# avg_qty    24.620271
# Name: 109, dtype: float64
# mi          0.001248
# avg_qty    24.828674
# Name: 110, dtype: float64
# mi          0.001248
# avg_qty    22.464302
# Name: 111, dtype: float64
# mi          0.001248
# avg_qty    21.228885
# Name: 112, dtype: float64
# mi          0.001248
# avg_qty    16.236938
# Name: 113, dtype: float64
# mi          0.001248
# avg_qty    26.820088
# Name: 114, dtype: float64
# mi          0.001248
# avg_qty    16.901305
# Name: 115, dtype: float64
# mi          0.001248
# avg_qty    24.514409
# Name: 116, dtype: float64
# mi          0.001248
# avg_qty    28.081976
# Name: 117, dtype: float64
# mi          0.001248
# avg_qty    30.750081
# Name: 118, dtype: float64
# mi          0.001248
# avg_qty    37.005112
# Name: 119, dtype: float64
# mi          0.001248
# avg_qty    27.289296
# Name: 120, dtype: float64
# mi          0.001248
# avg_qty    22.845336
# Name: 121, dtype: float64
# mi          0.001248
# avg_qty    31.458694
# Name: 122, dtype: float64
# mi          0.001248
# avg_qty    26.370503
# Name: 123, dtype: float64
# mi          0.001248
# avg_qty    25.585043
# Name: 124, dtype: float64
# mi          0.001248
# avg_qty    24.893126
# Name: 125, dtype: float64
# mi          0.001248
# avg_qty    35.860554
# Name: 126, dtype: float64
# mi          0.001248
# avg_qty    25.714583
# Name: 127, dtype: float64
# mi          0.001248
# avg_qty    23.050101
# Name: 128, dtype: float64
# mi          0.001248
# avg_qty    25.989156
# Name: 129, dtype: float64
# mi          0.001248
# avg_qty    32.729840
# Name: 130, dtype: float64
# mi          0.001248
# avg_qty    24.057725
# Name: 131, dtype: float64
# mi          0.001248
# avg_qty    34.595482
# Name: 132, dtype: float64
# mi          0.001248
# avg_qty    30.628606
# Name: 133, dtype: float64
# mi          0.001248
# avg_qty    20.223306
# Name: 134, dtype: float64
# mi          0.001248
# avg_qty    25.108922
# Name: 135, dtype: float64
# mi          0.001248
# avg_qty    25.461845
# Name: 136, dtype: float64
# mi          0.001248
# avg_qty    28.562259
# Name: 137, dtype: float64
# mi          0.001248
# avg_qty    27.129411
# Name: 138, dtype: float64
# mi          0.001248
# avg_qty    30.522979
# Name: 139, dtype: float64
# mi          0.001248
# avg_qty    22.438511
# Name: 140, dtype: float64
# mi          0.001248
# avg_qty    22.552851
# Name: 141, dtype: float64
# mi          0.001248
# avg_qty    24.752093
# Name: 142, dtype: float64
# mi          0.001248
# avg_qty    33.338826
# Name: 143, dtype: float64
# mi          0.001248
# avg_qty    30.702819
# Name: 144, dtype: float64
# mi          0.001248
# avg_qty    31.433890
# Name: 145, dtype: float64
# mi          0.001248
# avg_qty    19.548932
# Name: 146, dtype: float64
# mi          0.001248
# avg_qty    23.008130
# Name: 147, dtype: float64
# mi          0.001248
# avg_qty    31.525798
# Name: 148, dtype: float64
# mi          0.001248
# avg_qty    23.667102
# Name: 149, dtype: float64
# mi          0.001248
# avg_qty    23.062921
# Name: 150, dtype: float64
# mi          0.001248
# avg_qty    25.902480
# Name: 151, dtype: float64
# mi          0.001248
# avg_qty    19.902012
# Name: 152, dtype: float64
# mi          0.001248
# avg_qty    20.113469
# Name: 153, dtype: float64
# mi          0.001248
# avg_qty    34.081984
# Name: 154, dtype: float64
# mi          0.001248
# avg_qty    22.140125
# Name: 155, dtype: float64
# mi          0.001248
# avg_qty    27.023974
# Name: 156, dtype: float64
# mi          0.001248
# avg_qty    19.775960
# Name: 157, dtype: float64
# mi          0.001248
# avg_qty    24.573496
# Name: 158, dtype: float64
# mi          0.001248
# avg_qty    15.969150
# Name: 159, dtype: float64
# mi          0.001248
# avg_qty    23.902364
# Name: 160, dtype: float64
# mi          0.001248
# avg_qty    16.696893
# Name: 161, dtype: float64
# mi          0.001248
# avg_qty    29.177328
# Name: 162, dtype: float64
# mi          0.001248
# avg_qty    29.423944
# Name: 163, dtype: float64
# mi          0.001248
# avg_qty    27.922234
# Name: 164, dtype: float64
# mi          0.001248
# avg_qty    23.619662
# Name: 165, dtype: float64
# mi          0.001248
# avg_qty    28.829313
# Name: 166, dtype: float64
# mi          0.001248
# avg_qty    24.329384
# Name: 167, dtype: float64
# mi          0.001248
# avg_qty    31.482677
# Name: 168, dtype: float64
# mi          0.001248
# avg_qty    18.439499
# Name: 169, dtype: float64
# mi          0.001248
# avg_qty    29.449707
# Name: 170, dtype: float64
# mi          0.001248
# avg_qty    26.643489
# Name: 171, dtype: float64
# mi          0.001248
# avg_qty    20.076542
# Name: 172, dtype: float64
# mi          0.001248
# avg_qty    22.074423
# Name: 173, dtype: float64
# mi          0.001248
# avg_qty    23.102510
# Name: 174, dtype: float64
# mi          0.001248
# avg_qty    24.437470
# Name: 175, dtype: float64
# mi          0.001248
# avg_qty    29.177876
# Name: 176, dtype: float64
# mi          0.001248
# avg_qty    21.562241
# Name: 177, dtype: float64
# mi          0.001248
# avg_qty    29.428102
# Name: 178, dtype: float64
# mi          0.001248
# avg_qty    25.873406
# Name: 179, dtype: float64
# mi          0.001248
# avg_qty    24.065642
# Name: 180, dtype: float64
# mi          0.001248
# avg_qty    26.423275
# Name: 181, dtype: float64
# mi          0.001248
# avg_qty    31.276652
# Name: 182, dtype: float64
# mi          0.001248
# avg_qty    29.756252
# Name: 183, dtype: float64
# mi          0.001248
# avg_qty    29.465530
# Name: 184, dtype: float64
# mi          0.001248
# avg_qty    25.435086
# Name: 185, dtype: float64
# mi          0.001248
# avg_qty    26.295345
# Name: 186, dtype: float64
# mi          0.001248
# avg_qty    21.506183
# Name: 187, dtype: float64
# mi          0.001248
# avg_qty    23.457183
# Name: 188, dtype: float64
# mi          0.001248
# avg_qty    27.413139
# Name: 189, dtype: float64
# mi          0.001248
# avg_qty    32.750804
# Name: 190, dtype: float64
# mi          0.001248
# avg_qty    28.750786
# Name: 191, dtype: float64
# mi          0.001248
# avg_qty    24.216751
# Name: 192, dtype: float64
# mi          0.001248
# avg_qty    28.902487
# Name: 193, dtype: float64
# mi          0.001248
# avg_qty    26.434192
# Name: 194, dtype: float64
# mi          0.001248
# avg_qty    19.832029
# Name: 195, dtype: float64
# mi          0.001248
# avg_qty    33.819140
# Name: 196, dtype: float64
# mi          0.001248
# avg_qty    25.887900
# Name: 197, dtype: float64
# mi          0.001248
# avg_qty    26.674349
# Name: 198, dtype: float64
# mi          0.001248
# avg_qty    27.322400
# Name: 199, dtype: float64
# mi          0.001248
# avg_qty    32.767521
# Name: 200, dtype: float64
# mi          0.001248
# avg_qty    26.043231
# Name: 201, dtype: float64
# mi          0.001248
# avg_qty    38.618600
# Name: 202, dtype: float64
# mi          0.001248
# avg_qty    22.786211
# Name: 203, dtype: float64
# mi          0.001248
# avg_qty    23.648115
# Name: 204, dtype: float64
# mi          0.001248
# avg_qty    28.934545
# Name: 205, dtype: float64
# mi          0.001248
# avg_qty    22.123786
# Name: 206, dtype: float64
# mi          0.001248
# avg_qty    25.435335
# Name: 207, dtype: float64
# mi          0.001248
# avg_qty    22.682879
# Name: 208, dtype: float64
# mi          0.001248
# avg_qty    20.990901
# Name: 209, dtype: float64
# mi          0.001248
# avg_qty    21.900642
# Name: 210, dtype: float64
# mi          0.001248
# avg_qty    24.214302
# Name: 211, dtype: float64
# mi          0.001248
# avg_qty    21.395673
# Name: 212, dtype: float64
# mi          0.001248
# avg_qty    20.756052
# Name: 213, dtype: float64
# mi          0.001248
# avg_qty    24.146908
# Name: 214, dtype: float64
# mi          0.001248
# avg_qty    20.791781
# Name: 215, dtype: float64
# mi          0.001248
# avg_qty    23.683686
# Name: 216, dtype: float64
# mi          0.001248
# avg_qty    24.749088
# Name: 217, dtype: float64
# mi          0.001248
# avg_qty    25.385758
# Name: 218, dtype: float64
# mi          0.001248
# avg_qty    24.984933
# Name: 219, dtype: float64
# mi          0.001248
# avg_qty    29.516743
# Name: 220, dtype: float64
# mi          0.001248
# avg_qty    31.117682
# Name: 221, dtype: float64
# mi          0.001248
# avg_qty    22.235414
# Name: 222, dtype: float64
# mi          0.001248
# avg_qty    26.058030
# Name: 223, dtype: float64
# mi          0.001248
# avg_qty    19.978662
# Name: 224, dtype: float64
# mi          0.001248
# avg_qty    28.095568
# Name: 225, dtype: float64
# mi          0.001248
# avg_qty    25.518803
# Name: 226, dtype: float64
# mi          0.001248
# avg_qty    25.636052
# Name: 227, dtype: float64
# mi          0.001248
# avg_qty    16.579343
# Name: 228, dtype: float64
# mi          0.001248
# avg_qty    30.591880
# Name: 229, dtype: float64
# mi          0.001248
# avg_qty    21.188976
# Name: 230, dtype: float64
# mi          0.001248
# avg_qty    16.834202
# Name: 231, dtype: float64
# mi          0.001248
# avg_qty    17.330458
# Name: 232, dtype: float64
# mi          0.001248
# avg_qty    28.271494
# Name: 233, dtype: float64
# mi          0.001248
# avg_qty    23.083463
# Name: 234, dtype: float64
# mi          0.001248
# avg_qty    23.844957
# Name: 235, dtype: float64
# mi          0.001248
# avg_qty    24.094976
# Name: 236, dtype: float64
# mi          0.001248
# avg_qty    31.592830
# Name: 237, dtype: float64
# mi          0.001248
# avg_qty    28.151332
# Name: 238, dtype: float64
# mi          0.001248
# avg_qty    31.211149
# Name: 239, dtype: float64
# mi          0.001248
# avg_qty    27.490258
# Name: 240, dtype: float64
# mi          0.001248
# avg_qty    33.691501
# Name: 241, dtype: float64
# mi          0.001248
# avg_qty    21.947515
# Name: 242, dtype: float64
# mi          0.001248
# avg_qty    32.305323
# Name: 243, dtype: float64
# mi          0.001248
# avg_qty    24.307709
# Name: 244, dtype: float64
# mi          0.001248
# avg_qty    27.594684
# Name: 245, dtype: float64
# mi          0.001248
# avg_qty    31.520664
# Name: 246, dtype: float64
# mi          0.001248
# avg_qty    26.168623
# Name: 247, dtype: float64
# mi          0.001248
# avg_qty    22.847835
# Name: 248, dtype: float64
# mi          0.001248
# avg_qty    28.100191
# Name: 249, dtype: float64
# mi          0.001248
# avg_qty    33.332287
# Name: 250, dtype: float64
# mi          0.001248
# avg_qty    33.394955
# Name: 251, dtype: float64
# mi          0.001248
# avg_qty    21.669947
# Name: 252, dtype: float64
# mi          0.001248
# avg_qty    24.485514
# Name: 253, dtype: float64
# mi          0.001248
# avg_qty    20.830602
# Name: 254, dtype: float64
# mi          0.001248
# avg_qty    26.685210
# Name: 255, dtype: float64
# mi          0.001248
# avg_qty    18.719544
# Name: 256, dtype: float64
# mi          0.001248
# avg_qty    26.975521
# Name: 257, dtype: float64
# mi          0.001248
# avg_qty    32.869902
# Name: 258, dtype: float64
# mi          0.001248
# avg_qty    27.566666
# Name: 259, dtype: float64
# mi          0.001248
# avg_qty    33.963053
# Name: 260, dtype: float64
# mi          0.001248
# avg_qty    17.912906
# Name: 261, dtype: float64
# mi          0.001248
# avg_qty    26.142898
# Name: 262, dtype: float64
# mi          0.001248
# avg_qty    23.341558
# Name: 263, dtype: float64
# mi          0.001248
# avg_qty    14.498557
# Name: 264, dtype: float64
# mi          0.001248
# avg_qty    25.805689
# Name: 265, dtype: float64
# mi          0.001248
# avg_qty    26.125994
# Name: 266, dtype: float64
# mi          0.001248
# avg_qty    24.969732
# Name: 267, dtype: float64
# mi          0.001248
# avg_qty    31.875589
# Name: 268, dtype: float64
# mi          0.001248
# avg_qty    25.596096
# Name: 269, dtype: float64
# mi          0.001248
# avg_qty    26.839418
# Name: 270, dtype: float64
# mi          0.001248
# avg_qty    24.316375
# Name: 271, dtype: float64
# mi          0.001248
# avg_qty    21.089732
# Name: 272, dtype: float64
# mi          0.001248
# avg_qty    20.335917
# Name: 273, dtype: float64
# mi          0.001248
# avg_qty    24.999929
# Name: 274, dtype: float64
# mi          0.001248
# avg_qty    37.043240
# Name: 275, dtype: float64
# mi          0.001248
# avg_qty    19.219815
# Name: 276, dtype: float64
# mi          0.001248
# avg_qty    22.650964
# Name: 277, dtype: float64
# mi          0.001248
# avg_qty    29.116905
# Name: 278, dtype: float64
# mi          0.001248
# avg_qty    31.414844
# Name: 279, dtype: float64
# mi          0.001248
# avg_qty    29.308174
# Name: 280, dtype: float64
# mi          0.001248
# avg_qty    26.288615
# Name: 281, dtype: float64
# mi          0.001248
# avg_qty    25.197260
# Name: 282, dtype: float64
# mi          0.001248
# avg_qty    34.992658
# Name: 283, dtype: float64
# mi          0.001248
# avg_qty    23.866935
# Name: 284, dtype: float64
# mi          0.001248
# avg_qty    27.502273
# Name: 285, dtype: float64
# mi          0.001248
# avg_qty    20.810332
# Name: 286, dtype: float64
# mi          0.001248
# avg_qty    22.336533
# Name: 287, dtype: float64
# mi          0.001248
# avg_qty    21.380455
# Name: 288, dtype: float64
# mi          0.001248
# avg_qty    29.101614
# Name: 289, dtype: float64
# mi          0.001248
# avg_qty    21.996192
# Name: 290, dtype: float64
# mi          0.001248
# avg_qty    27.627720
# Name: 291, dtype: float64
# mi          0.001248
# avg_qty    22.348929
# Name: 292, dtype: float64
# mi          0.001248
# avg_qty    24.698230
# Name: 293, dtype: float64
# mi          0.001248
# avg_qty    24.758829
# Name: 294, dtype: float64
# mi          0.001248
# avg_qty    16.850114
# Name: 295, dtype: float64
# mi          0.001248
# avg_qty    33.265492
# Name: 296, dtype: float64
# mi          0.001248
# avg_qty    20.231689
# Name: 297, dtype: float64
# mi          0.001248
# avg_qty    21.415036
# Name: 298, dtype: float64
# mi          0.001248
# avg_qty    40.091800
# Name: 299, dtype: float64
# mi          0.001248
# avg_qty    33.768319
# Name: 300, dtype: float64
# mi          0.001248
# avg_qty    25.754437
# Name: 301, dtype: float64
# mi          0.001248
# avg_qty    15.262899
# Name: 302, dtype: float64
# mi          0.001248
# avg_qty    27.322381
# Name: 303, dtype: float64
# mi          0.001248
# avg_qty    29.970904
# Name: 304, dtype: float64
# mi          0.001248
# avg_qty    29.651216
# Name: 305, dtype: float64
# mi          0.001248
# avg_qty    20.918764
# Name: 306, dtype: float64
# mi          0.001248
# avg_qty    25.696423
# Name: 307, dtype: float64
# mi          0.001248
# avg_qty    22.601797
# Name: 308, dtype: float64
# mi          0.001248
# avg_qty    27.696855
# Name: 309, dtype: float64
# mi          0.001248
# avg_qty    16.379415
# Name: 310, dtype: float64
# mi          0.001248
# avg_qty    24.847526
# Name: 311, dtype: float64
# mi          0.001248
# avg_qty    28.648384
# Name: 312, dtype: float64
# mi          0.001248
# avg_qty    34.802199
# Name: 313, dtype: float64
# mi          0.001248
# avg_qty    27.898637
# Name: 314, dtype: float64
# mi          0.001248
# avg_qty    21.215333
# Name: 315, dtype: float64
# mi          0.001248
# avg_qty    23.409054
# Name: 316, dtype: float64
# mi          0.001248
# avg_qty    26.672054
# Name: 317, dtype: float64
# mi          0.001248
# avg_qty    25.742345
# Name: 318, dtype: float64
# mi          0.001248
# avg_qty    22.378389
# Name: 319, dtype: float64
# mi          0.001248
# avg_qty    26.502888
# Name: 320, dtype: float64
# mi          0.001248
# avg_qty    28.880806
# Name: 321, dtype: float64
# mi          0.001248
# avg_qty    29.574568
# Name: 322, dtype: float64
# mi          0.001248
# avg_qty    34.016442
# Name: 323, dtype: float64
# mi          0.001248
# avg_qty    24.142655
# Name: 324, dtype: float64
# mi          0.001248
# avg_qty    27.026150
# Name: 325, dtype: float64
# mi          0.001248
# avg_qty    25.658278
# Name: 326, dtype: float64
# mi          0.001248
# avg_qty    22.698454
# Name: 327, dtype: float64
# mi          0.001248
# avg_qty    23.034270
# Name: 328, dtype: float64
# mi          0.001248
# avg_qty    29.847222
# Name: 329, dtype: float64
# mi          0.001248
# avg_qty    30.337257
# Name: 330, dtype: float64
# mi          0.001248
# avg_qty    31.950846
# Name: 331, dtype: float64
# mi          0.001248
# avg_qty    27.762406
# Name: 332, dtype: float64
# mi          0.001248
# avg_qty    26.696900
# Name: 333, dtype: float64
# mi          0.001248
# avg_qty    32.772722
# Name: 334, dtype: float64
# mi          0.001248
# avg_qty    25.744288
# Name: 335, dtype: float64
# mi          0.001248
# avg_qty    23.081598
# Name: 336, dtype: float64
# mi          0.001248
# avg_qty    24.703739
# Name: 337, dtype: float64
# mi          0.001248
# avg_qty    26.474416
# Name: 338, dtype: float64
# mi          0.001248
# avg_qty    18.946379
# Name: 339, dtype: float64
# mi          0.001248
# avg_qty    24.760602
# Name: 340, dtype: float64
# mi          0.001248
# avg_qty    29.599031
# Name: 341, dtype: float64
# mi          0.001248
# avg_qty    24.858659
# Name: 342, dtype: float64
# mi          0.001248
# avg_qty    26.458371
# Name: 343, dtype: float64
# mi          0.001248
# avg_qty    26.432203
# Name: 344, dtype: float64
# mi          0.001248
# avg_qty    26.889175
# Name: 345, dtype: float64
# mi          0.001248
# avg_qty    19.623674
# Name: 346, dtype: float64
# mi          0.001248
# avg_qty    30.042485
# Name: 347, dtype: float64
# mi          0.001248
# avg_qty    22.876359
# Name: 348, dtype: float64
# mi          0.001248
# avg_qty    25.743575
# Name: 349, dtype: float64
# mi          0.001248
# avg_qty    24.525080
# Name: 350, dtype: float64
# mi          0.001248
# avg_qty    19.468495
# Name: 351, dtype: float64
# mi          0.001248
# avg_qty    34.672116
# Name: 352, dtype: float64
# mi          0.001248
# avg_qty    26.444400
# Name: 353, dtype: float64
# mi          0.001248
# avg_qty    17.442019
# Name: 354, dtype: float64
# mi          0.001248
# avg_qty    32.910409
# Name: 355, dtype: float64
# mi          0.001248
# avg_qty    25.803910
# Name: 356, dtype: float64
# mi          0.001248
# avg_qty    23.042179
# Name: 357, dtype: float64
# mi          0.001248
# avg_qty    24.197277
# Name: 358, dtype: float64
# mi          0.001248
# avg_qty    21.267449
# Name: 359, dtype: float64
# mi          0.001248
# avg_qty    17.835106
# Name: 360, dtype: float64
# mi          0.001248
# avg_qty    27.113446
# Name: 361, dtype: float64
# mi          0.001248
# avg_qty    31.925161
# Name: 362, dtype: float64
# mi          0.001248
# avg_qty    39.429056
# Name: 363, dtype: float64
# mi          0.001248
# avg_qty    27.986012
# Name: 364, dtype: float64
# mi          0.001248
# avg_qty    26.924843
# Name: 365, dtype: float64
# mi          0.001248
# avg_qty    33.148646
# Name: 366, dtype: float64
# mi          0.001248
# avg_qty    25.006390
# Name: 367, dtype: float64
# mi          0.001248
# avg_qty    21.662286
# Name: 368, dtype: float64
# mi          0.001248
# avg_qty    22.012041
# Name: 369, dtype: float64
# mi          0.001248
# avg_qty    20.881846
# Name: 370, dtype: float64
# mi          0.001248
# avg_qty    20.064498
# Name: 371, dtype: float64
# mi          0.001248
# avg_qty    33.110291
# Name: 372, dtype: float64
# mi          0.001248
# avg_qty    27.012120
# Name: 373, dtype: float64
# mi          0.001248
# avg_qty    25.398509
# Name: 374, dtype: float64
# mi          0.001248
# avg_qty    33.444155
# Name: 375, dtype: float64
# mi          0.001248
# avg_qty    27.620988
# Name: 376, dtype: float64
# mi          0.001248
# avg_qty    29.967384
# Name: 377, dtype: float64
# mi          0.001248
# avg_qty    21.188390
# Name: 378, dtype: float64
# mi          0.001248
# avg_qty    27.840867
# Name: 379, dtype: float64
# mi          0.001248
# avg_qty    27.265667
# Name: 380, dtype: float64
# mi          0.001248
# avg_qty    21.227265
# Name: 381, dtype: float64
# mi          0.001248
# avg_qty    22.362574
# Name: 382, dtype: float64
# mi          0.001248
# avg_qty    19.111926
# Name: 383, dtype: float64
# mi          0.001248
# avg_qty    27.613770
# Name: 384, dtype: float64
# mi          0.001248
# avg_qty    33.862484
# Name: 385, dtype: float64
# mi          0.001248
# avg_qty    30.542172
# Name: 386, dtype: float64
# mi          0.001248
# avg_qty    25.211639
# Name: 387, dtype: float64
# mi          0.001248
# avg_qty    19.413823
# Name: 388, dtype: float64
# mi          0.001248
# avg_qty    35.376249
# Name: 389, dtype: float64
# mi          0.001248
# avg_qty    32.248660
# Name: 390, dtype: float64
# mi          0.001248
# avg_qty    32.555492
# Name: 391, dtype: float64
# mi          0.001248
# avg_qty    23.221776
# Name: 392, dtype: float64
# mi          0.001248
# avg_qty    29.566228
# Name: 393, dtype: float64
# mi          0.001248
# avg_qty    16.267690
# Name: 394, dtype: float64
# mi          0.001248
# avg_qty    27.131670
# Name: 395, dtype: float64
# mi          0.001248
# avg_qty    22.946283
# Name: 396, dtype: float64
# mi          0.001248
# avg_qty    37.598070
# Name: 397, dtype: float64
# mi          0.001248
# avg_qty    21.040513
# Name: 398, dtype: float64
# mi          0.001248
# avg_qty    33.752780
# Name: 399, dtype: float64
# mi          0.001248
# avg_qty    23.927987
# Name: 400, dtype: float64
# mi          0.001248
# avg_qty    29.174037
# Name: 401, dtype: float64
# mi          0.001248
# avg_qty    24.579647
# Name: 402, dtype: float64
# mi          0.001248
# avg_qty    26.969393
# Name: 403, dtype: float64
# mi          0.001248
# avg_qty    31.561306
# Name: 404, dtype: float64
# mi          0.001248
# avg_qty    25.799705
# Name: 405, dtype: float64
# mi          0.001248
# avg_qty    35.686118
# Name: 406, dtype: float64
# mi          0.001248
# avg_qty    17.727785
# Name: 407, dtype: float64
# mi          0.001248
# avg_qty    21.625323
# Name: 408, dtype: float64
# mi          0.001248
# avg_qty    30.369704
# Name: 409, dtype: float64
# mi          0.001248
# avg_qty    26.146332
# Name: 410, dtype: float64
# mi          0.001248
# avg_qty    18.979946
# Name: 411, dtype: float64
# mi          0.001248
# avg_qty    26.572855
# Name: 412, dtype: float64
# mi          0.001248
# avg_qty    29.984913
# Name: 413, dtype: float64
# mi          0.001248
# avg_qty    13.938431
# Name: 414, dtype: float64
# mi          0.001248
# avg_qty    25.832395
# Name: 415, dtype: float64
# mi          0.001248
# avg_qty    14.012154
# Name: 416, dtype: float64
# mi          0.001248
# avg_qty    29.305809
# Name: 417, dtype: float64
# mi          0.001248
# avg_qty    20.207264
# Name: 418, dtype: float64
# mi          0.001248
# avg_qty    23.431240
# Name: 419, dtype: float64
# mi          0.001248
# avg_qty    20.693378
# Name: 420, dtype: float64
# mi          0.001248
# avg_qty    24.076861
# Name: 421, dtype: float64
# mi          0.001248
# avg_qty    23.508587
# Name: 422, dtype: float64
# mi          0.001248
# avg_qty    29.323479
# Name: 423, dtype: float64
# mi          0.001248
# avg_qty    25.792937
# Name: 424, dtype: float64
# mi          0.001248
# avg_qty    17.082904
# Name: 425, dtype: float64
# mi          0.001248
# avg_qty    24.332823
# Name: 426, dtype: float64
# mi          0.001248
# avg_qty    29.948829
# Name: 427, dtype: float64
# mi          0.001248
# avg_qty    29.597476
# Name: 428, dtype: float64
# mi          0.001248
# avg_qty    15.867641
# Name: 429, dtype: float64
# mi          0.001248
# avg_qty    21.081073
# Name: 430, dtype: float64
# mi          0.001248
# avg_qty    24.838417
# Name: 431, dtype: float64
# mi          0.001248
# avg_qty    23.101898
# Name: 432, dtype: float64
# mi          0.001248
# avg_qty    31.364699
# Name: 433, dtype: float64
# mi          0.001248
# avg_qty    25.683570
# Name: 434, dtype: float64
# mi          0.001248
# avg_qty    17.217670
# Name: 435, dtype: float64
# mi          0.001248
# avg_qty    25.091281
# Name: 436, dtype: float64
# mi          0.001248
# avg_qty    25.074620
# Name: 437, dtype: float64
# mi          0.001248
# avg_qty    31.367255
# Name: 438, dtype: float64
# mi          0.001248
# avg_qty    24.852803
# Name: 439, dtype: float64
# mi          0.001248
# avg_qty    27.512045
# Name: 440, dtype: float64
# mi          0.001248
# avg_qty    26.823605
# Name: 441, dtype: float64
# mi          0.001248
# avg_qty    28.528805
# Name: 442, dtype: float64
# mi          0.001248
# avg_qty    20.463709
# Name: 443, dtype: float64
# mi          0.001248
# avg_qty    26.568322
# Name: 444, dtype: float64
# mi          0.001248
# avg_qty    25.218783
# Name: 445, dtype: float64
# mi          0.001248
# avg_qty    16.275644
# Name: 446, dtype: float64
# mi          0.001248
# avg_qty    25.673053
# Name: 447, dtype: float64
# mi          0.001248
# avg_qty    11.681993
# Name: 448, dtype: float64
# mi          0.001248
# avg_qty    17.475268
# Name: 449, dtype: float64
# mi          0.001248
# avg_qty    25.176020
# Name: 450, dtype: float64
# mi          0.001248
# avg_qty    22.138058
# Name: 451, dtype: float64
# mi          0.001248
# avg_qty    20.912378
# Name: 452, dtype: float64
# mi          0.001248
# avg_qty    28.835641
# Name: 453, dtype: float64
# mi          0.001248
# avg_qty    23.466025
# Name: 454, dtype: float64
# mi          0.001248
# avg_qty    19.110409
# Name: 455, dtype: float64
# mi          0.001248
# avg_qty    16.187217
# Name: 456, dtype: float64
# mi          0.001248
# avg_qty    29.002051
# Name: 457, dtype: float64
# mi          0.001248
# avg_qty    27.543784
# Name: 458, dtype: float64
# mi          0.001248
# avg_qty    26.624481
# Name: 459, dtype: float64
# mi          0.001248
# avg_qty    19.826747
# Name: 460, dtype: float64
# mi          0.001248
# avg_qty    29.152092
# Name: 461, dtype: float64
# mi          0.001248
# avg_qty    18.367802
# Name: 462, dtype: float64
# mi          0.001248
# avg_qty    20.972313
# Name: 463, dtype: float64
# mi          0.001248
# avg_qty    21.300177
# Name: 464, dtype: float64
# mi          0.001248
# avg_qty    28.557020
# Name: 465, dtype: float64
# mi          0.001248
# avg_qty    26.773288
# Name: 466, dtype: float64
# mi          0.001248
# avg_qty    26.539793
# Name: 467, dtype: float64
# mi          0.001248
# avg_qty    27.433224
# Name: 468, dtype: float64
# mi          0.001248
# avg_qty    24.372493
# Name: 469, dtype: float64
# mi          0.001248
# avg_qty    15.937887
# Name: 470, dtype: float64
# mi          0.001248
# avg_qty    25.180645
# Name: 471, dtype: float64
# mi          0.001248
# avg_qty    21.535295
# Name: 472, dtype: float64
# mi          0.001248
# avg_qty    30.221402
# Name: 473, dtype: float64
# mi          0.001248
# avg_qty    27.526293
# Name: 474, dtype: float64
# mi          0.001248
# avg_qty    24.506398
# Name: 475, dtype: float64
# mi          0.001248
# avg_qty    19.521798
# Name: 476, dtype: float64
# mi          0.001248
# avg_qty    29.035491
# Name: 477, dtype: float64
# mi          0.001248
# avg_qty    16.481105
# Name: 478, dtype: float64
# mi          0.001248
# avg_qty    20.936501
# Name: 479, dtype: float64
# mi          0.001248
# avg_qty    14.541038
# Name: 480, dtype: float64
# mi          0.001248
# avg_qty    23.444579
# Name: 481, dtype: float64
# mi          0.001248
# avg_qty    32.686245
# Name: 482, dtype: float64
# mi          0.001248
# avg_qty    25.045230
# Name: 483, dtype: float64
# mi          0.001248
# avg_qty    26.309246
# Name: 484, dtype: float64
# mi          0.001248
# avg_qty    26.932343
# Name: 485, dtype: float64
# mi          0.001248
# avg_qty    18.703656
# Name: 486, dtype: float64
# mi          0.001248
# avg_qty    26.471430
# Name: 487, dtype: float64
# mi          0.001248
# avg_qty    21.369371
# Name: 488, dtype: float64
# mi          0.001248
# avg_qty    28.082179
# Name: 489, dtype: float64
# mi          0.001248
# avg_qty    25.206300
# Name: 490, dtype: float64
# mi          0.001248
# avg_qty    31.282537
# Name: 491, dtype: float64
# mi          0.001248
# avg_qty    18.175885
# Name: 492, dtype: float64
# mi          0.001248
# avg_qty    21.473909
# Name: 493, dtype: float64
# mi          0.001248
# avg_qty    15.537768
# Name: 494, dtype: float64
# mi          0.001248
# avg_qty    24.510047
# Name: 495, dtype: float64
# mi          0.001248
# avg_qty    24.051920
# Name: 496, dtype: float64
# mi          0.001248
# avg_qty    27.190096
# Name: 497, dtype: float64
# mi          0.001248
# avg_qty    33.649680
# Name: 498, dtype: float64
# mi          0.001248
# avg_qty    20.643568
# Name: 499, dtype: float64
# mi          0.001248
# avg_qty    23.559194
# Name: 500, dtype: float64
# mi          0.001248
# avg_qty    25.745016
# Name: 501, dtype: float64
# mi          0.001248
# avg_qty    22.666661
# Name: 502, dtype: float64
# mi          0.001248
# avg_qty    30.491419
# Name: 503, dtype: float64
# mi          0.001248
# avg_qty    13.617877
# Name: 504, dtype: float64
# mi          0.001248
# avg_qty    19.496934
# Name: 505, dtype: float64
# mi          0.001248
# avg_qty    26.460957
# Name: 506, dtype: float64
# mi          0.001248
# avg_qty    21.962629
# Name: 507, dtype: float64
# mi          0.001248
# avg_qty    32.292547
# Name: 508, dtype: float64
# mi          0.001248
# avg_qty    25.451200
# Name: 509, dtype: float64
# mi          0.001248
# avg_qty    25.646065
# Name: 510, dtype: float64
# mi          0.001248
# avg_qty    24.587023
# Name: 511, dtype: float64
# mi          0.001248
# avg_qty    31.387315
# Name: 512, dtype: float64
# mi          0.001248
# avg_qty    29.066501
# Name: 513, dtype: float64
# mi          0.001248
# avg_qty    23.832262
# Name: 514, dtype: float64
# mi          0.001248
# avg_qty    24.827225
# Name: 515, dtype: float64
# mi          0.001248
# avg_qty    31.690678
# Name: 516, dtype: float64
# mi          0.001248
# avg_qty    27.429903
# Name: 517, dtype: float64
# mi          0.001248
# avg_qty    32.790980
# Name: 518, dtype: float64
# mi          0.001248
# avg_qty    32.688393
# Name: 519, dtype: float64
# mi          0.001248
# avg_qty    24.594355
# Name: 520, dtype: float64
# mi          0.001248
# avg_qty    24.969095
# Name: 521, dtype: float64
# mi          0.001248
# avg_qty    16.788942
# Name: 522, dtype: float64
# mi          0.001248
# avg_qty    20.157364
# Name: 523, dtype: float64
# mi          0.001248
# avg_qty    30.335604
# Name: 524, dtype: float64
# mi          0.001248
# avg_qty    24.821724
# Name: 525, dtype: float64
# mi          0.001248
# avg_qty    24.283838
# Name: 526, dtype: float64
# mi          0.001248
# avg_qty    24.350502
# Name: 527, dtype: float64
# mi          0.001248
# avg_qty    18.524103
# Name: 528, dtype: float64
# mi          0.001248
# avg_qty    23.931249
# Name: 529, dtype: float64
# mi          0.001248
# avg_qty    28.734276
# Name: 530, dtype: float64
# mi          0.001248
# avg_qty    24.486054
# Name: 531, dtype: float64
# mi          0.001248
# avg_qty    37.998680
# Name: 532, dtype: float64
# mi          0.001248
# avg_qty    20.094074
# Name: 533, dtype: float64
# mi          0.001248
# avg_qty    17.374093
# Name: 534, dtype: float64
# mi          0.001248
# avg_qty    27.808052
# Name: 535, dtype: float64
# mi          0.001248
# avg_qty    25.579609
# Name: 536, dtype: float64
# mi          0.001248
# avg_qty    15.794699
# Name: 537, dtype: float64
# mi          0.001248
# avg_qty    23.813344
# Name: 538, dtype: float64
# mi          0.001248
# avg_qty    26.394661
# Name: 539, dtype: float64
# mi          0.001248
# avg_qty    30.914736
# Name: 540, dtype: float64
# mi          0.001248
# avg_qty    22.295692
# Name: 541, dtype: float64
# mi          0.001248
# avg_qty    20.556149
# Name: 542, dtype: float64
# mi          0.001248
# avg_qty    20.607704
# Name: 543, dtype: float64
# mi          0.001248
# avg_qty    20.579024
# Name: 544, dtype: float64
# mi          0.001248
# avg_qty    22.262859
# Name: 545, dtype: float64
# mi          0.001248
# avg_qty    27.985357
# Name: 546, dtype: float64
# mi          0.001248
# avg_qty    27.109440
# Name: 547, dtype: float64
# mi          0.001248
# avg_qty    27.219274
# Name: 548, dtype: float64
# mi          0.001248
# avg_qty    22.255733
# Name: 549, dtype: float64
# mi          0.001248
# avg_qty    31.820824
# Name: 550, dtype: float64
# mi          0.001248
# avg_qty    22.949495
# Name: 551, dtype: float64
# mi          0.001248
# avg_qty    21.000758
# Name: 552, dtype: float64
# mi          0.001248
# avg_qty    21.976599
# Name: 553, dtype: float64
# mi          0.001248
# avg_qty    28.063363
# Name: 554, dtype: float64
# mi          0.001248
# avg_qty    22.401450
# Name: 555, dtype: float64
# mi          0.001248
# avg_qty    21.553034
# Name: 556, dtype: float64
# mi          0.001248
# avg_qty    20.169783
# Name: 557, dtype: float64
# mi          0.001248
# avg_qty    24.228871
# Name: 558, dtype: float64
# mi          0.001248
# avg_qty    26.460854
# Name: 559, dtype: float64
# mi          0.001248
# avg_qty    26.227687
# Name: 560, dtype: float64
# mi          0.001248
# avg_qty    26.568936
# Name: 561, dtype: float64
# mi          0.001248
# avg_qty    21.048390
# Name: 562, dtype: float64
# mi          0.001248
# avg_qty    25.076855
# Name: 563, dtype: float64
# mi          0.001248
# avg_qty    29.591078
# Name: 564, dtype: float64
# mi          0.001248
# avg_qty    31.842595
# Name: 565, dtype: float64
# mi          0.001248
# avg_qty    24.832425
# Name: 566, dtype: float64
# mi          0.001248
# avg_qty    28.357829
# Name: 567, dtype: float64
# mi          0.001248
# avg_qty    19.229148
# Name: 568, dtype: float64
# mi          0.001248
# avg_qty    23.042111
# Name: 569, dtype: float64
# mi          0.001248
# avg_qty    28.584417
# Name: 570, dtype: float64
# mi          0.001248
# avg_qty    21.409791
# Name: 571, dtype: float64
# mi          0.001248
# avg_qty    29.546522
# Name: 572, dtype: float64
# mi          0.001248
# avg_qty    16.953365
# Name: 573, dtype: float64
# mi          0.001248
# avg_qty    25.121194
# Name: 574, dtype: float64
# mi          0.001248
# avg_qty    17.475673
# Name: 575, dtype: float64
# mi          0.001248
# avg_qty    24.082044
# Name: 576, dtype: float64
# mi          0.001248
# avg_qty    24.212766
# Name: 577, dtype: float64
# mi          0.001248
# avg_qty    26.048286
# Name: 578, dtype: float64
# mi          0.001248
# avg_qty    22.706059
# Name: 579, dtype: float64
# mi          0.001248
# avg_qty    23.780286
# Name: 580, dtype: float64
# mi          0.001248
# avg_qty    30.664228
# Name: 581, dtype: float64
# mi          0.001248
# avg_qty    29.393725
# Name: 582, dtype: float64
# mi          0.001248
# avg_qty    20.140167
# Name: 583, dtype: float64
# mi          0.001248
# avg_qty    23.101564
# Name: 584, dtype: float64
# mi          0.001248
# avg_qty    28.922201
# Name: 585, dtype: float64
# mi          0.001248
# avg_qty    28.758352
# Name: 586, dtype: float64
# mi          0.001248
# avg_qty    23.654904
# Name: 587, dtype: float64
# mi          0.001248
# avg_qty    24.624396
# Name: 588, dtype: float64
# mi          0.001248
# avg_qty    23.912917
# Name: 589, dtype: float64
# mi          0.001248
# avg_qty    24.678051
# Name: 590, dtype: float64
# mi          0.001248
# avg_qty    22.752263
# Name: 591, dtype: float64
# mi          0.001248
# avg_qty    30.983478
# Name: 592, dtype: float64
# mi          0.001248
# avg_qty    23.952391
# Name: 593, dtype: float64
# mi          0.001248
# avg_qty    26.780133
# Name: 594, dtype: float64
# mi          0.001248
# avg_qty    25.367926
# Name: 595, dtype: float64
# mi          0.001248
# avg_qty    25.163568
# Name: 596, dtype: float64
# mi          0.001248
# avg_qty    23.243025
# Name: 597, dtype: float64
# mi          0.001248
# avg_qty    25.045274
# Name: 598, dtype: float64
# mi          0.001248
# avg_qty    29.367726
# Name: 599, dtype: float64
# mi          0.001248
# avg_qty    24.059636
# Name: 600, dtype: float64
# mi          0.001248
# avg_qty    29.330636
# Name: 601, dtype: float64
# mi          0.001248
# avg_qty    25.766473
# Name: 602, dtype: float64
# mi          0.001248
# avg_qty    24.830336
# Name: 603, dtype: float64
# mi          0.001248
# avg_qty    19.876443
# Name: 604, dtype: float64
# mi          0.001248
# avg_qty    26.477626
# Name: 605, dtype: float64
# mi          0.001248
# avg_qty    17.745622
# Name: 606, dtype: float64
# mi          0.001248
# avg_qty    26.756093
# Name: 607, dtype: float64
# mi          0.001248
# avg_qty    28.316044
# Name: 608, dtype: float64
# mi          0.001248
# avg_qty    30.772396
# Name: 609, dtype: float64
# mi          0.001248
# avg_qty    21.636033
# Name: 610, dtype: float64
# mi          0.001248
# avg_qty    25.663720
# Name: 611, dtype: float64
# mi          0.001248
# avg_qty    28.457004
# Name: 612, dtype: float64
# mi          0.001248
# avg_qty    26.800216
# Name: 613, dtype: float64
# mi          0.001248
# avg_qty    31.161818
# Name: 614, dtype: float64
# mi          0.001248
# avg_qty    18.969401
# Name: 615, dtype: float64
# mi          0.001248
# avg_qty    23.976960
# Name: 616, dtype: float64
# mi          0.001248
# avg_qty    23.186827
# Name: 617, dtype: float64
# mi          0.001248
# avg_qty    28.562802
# Name: 618, dtype: float64
# mi          0.001248
# avg_qty    17.766666
# Name: 619, dtype: float64
# mi          0.001248
# avg_qty    23.752921
# Name: 620, dtype: float64
# mi          0.001248
# avg_qty    24.476224
# Name: 621, dtype: float64
# mi          0.001248
# avg_qty    29.890280
# Name: 622, dtype: float64
# mi          0.001248
# avg_qty    21.720948
# Name: 623, dtype: float64
# mi          0.001248
# avg_qty    19.816419
# Name: 624, dtype: float64
# mi          0.001248
# avg_qty    30.697558
# Name: 625, dtype: float64
# mi          0.001248
# avg_qty    28.992108
# Name: 626, dtype: float64
# mi          0.001248
# avg_qty    31.371062
# Name: 627, dtype: float64
# mi          0.001248
# avg_qty    19.528431
# Name: 628, dtype: float64
# mi          0.001248
# avg_qty    28.659533
# Name: 629, dtype: float64
# mi          0.001248
# avg_qty    23.096179
# Name: 630, dtype: float64
# mi          0.001248
# avg_qty    21.596087
# Name: 631, dtype: float64
# mi          0.001248
# avg_qty    22.603261
# Name: 632, dtype: float64
# mi          0.001248
# avg_qty    29.099174
# Name: 633, dtype: float64
# mi          0.001248
# avg_qty    18.965487
# Name: 634, dtype: float64
# mi          0.001248
# avg_qty    27.003546
# Name: 635, dtype: float64
# mi          0.001248
# avg_qty    27.673719
# Name: 636, dtype: float64
# mi          0.001248
# avg_qty    30.916396
# Name: 637, dtype: float64
# mi          0.001248
# avg_qty    30.381657
# Name: 638, dtype: float64
# mi          0.001248
# avg_qty    22.649314
# Name: 639, dtype: float64
# mi          0.001248
# avg_qty    24.536752
# Name: 640, dtype: float64
# mi          0.001248
# avg_qty    23.562686
# Name: 641, dtype: float64
# mi          0.001248
# avg_qty    23.685535
# Name: 642, dtype: float64
# mi          0.001248
# avg_qty    24.614341
# Name: 643, dtype: float64
# mi          0.001248
# avg_qty    30.559547
# Name: 644, dtype: float64
# mi          0.001248
# avg_qty    22.682511
# Name: 645, dtype: float64
# mi          0.001248
# avg_qty    21.819414
# Name: 646, dtype: float64
# mi          0.001248
# avg_qty    23.701143
# Name: 647, dtype: float64
# mi          0.001248
# avg_qty    20.223804
# Name: 648, dtype: float64
# mi          0.001248
# avg_qty    31.275285
# Name: 649, dtype: float64
# mi          0.001248
# avg_qty    20.597726
# Name: 650, dtype: float64
# mi          0.001248
# avg_qty    23.595659
# Name: 651, dtype: float64
# mi          0.001248
# avg_qty    25.138659
# Name: 652, dtype: float64
# mi          0.001248
# avg_qty    23.582265
# Name: 653, dtype: float64
# mi          0.001248
# avg_qty    22.795309
# Name: 654, dtype: float64
# mi          0.001248
# avg_qty    29.628454
# Name: 655, dtype: float64
# mi          0.001248
# avg_qty    16.358752
# Name: 656, dtype: float64
# mi          0.001248
# avg_qty    25.570846
# Name: 657, dtype: float64
# mi          0.001248
# avg_qty    23.532927
# Name: 658, dtype: float64
# mi          0.001248
# avg_qty    27.008940
# Name: 659, dtype: float64
# mi          0.001248
# avg_qty    22.878001
# Name: 660, dtype: float64
# mi          0.001248
# avg_qty    19.566840
# Name: 661, dtype: float64
# mi          0.001248
# avg_qty    25.179027
# Name: 662, dtype: float64
# mi          0.001248
# avg_qty    22.176968
# Name: 663, dtype: float64
# mi          0.001248
# avg_qty    18.171127
# Name: 664, dtype: float64
# mi          0.001248
# avg_qty    25.059524
# Name: 665, dtype: float64
# mi          0.001248
# avg_qty    27.475848
# Name: 666, dtype: float64
# mi          0.001248
# avg_qty    26.705281
# Name: 667, dtype: float64
# mi          0.001248
# avg_qty    29.097844
# Name: 668, dtype: float64
# mi          0.001248
# avg_qty    26.343084
# Name: 669, dtype: float64
# mi          0.001248
# avg_qty    20.785647
# Name: 670, dtype: float64
# mi          0.001248
# avg_qty    23.483403
# Name: 671, dtype: float64
# mi          0.001248
# avg_qty    17.455023
# Name: 672, dtype: float64
# mi          0.001248
# avg_qty    26.177548
# Name: 673, dtype: float64
# mi          0.001248
# avg_qty    26.520602
# Name: 674, dtype: float64
# mi          0.001248
# avg_qty    24.674531
# Name: 675, dtype: float64
# mi          0.001248
# avg_qty    19.140958
# Name: 676, dtype: float64
# mi          0.001248
# avg_qty    27.018405
# Name: 677, dtype: float64
# mi          0.001248
# avg_qty    34.248142
# Name: 678, dtype: float64
# mi          0.001248
# avg_qty    31.677507
# Name: 679, dtype: float64
# mi          0.001248
# avg_qty    30.376676
# Name: 680, dtype: float64
# mi          0.001248
# avg_qty    25.520744
# Name: 681, dtype: float64
# mi          0.001248
# avg_qty    26.117758
# Name: 682, dtype: float64
# mi          0.001248
# avg_qty    23.082654
# Name: 683, dtype: float64
# mi          0.001248
# avg_qty    28.663086
# Name: 684, dtype: float64
# mi          0.001248
# avg_qty    23.236207
# Name: 685, dtype: float64
# mi          0.001248
# avg_qty    16.332317
# Name: 686, dtype: float64
# mi          0.001248
# avg_qty    27.411069
# Name: 687, dtype: float64
# mi          0.001248
# avg_qty    19.605176
# Name: 688, dtype: float64
# mi          0.001248
# avg_qty    27.306812
# Name: 689, dtype: float64
# mi          0.001248
# avg_qty    22.660957
# Name: 690, dtype: float64
# mi          0.001248
# avg_qty    27.564918
# Name: 691, dtype: float64
# mi          0.001248
# avg_qty    32.427920
# Name: 692, dtype: float64
# mi          0.001248
# avg_qty    25.259278
# Name: 693, dtype: float64
# mi          0.001248
# avg_qty    23.069560
# Name: 694, dtype: float64
# mi          0.001248
# avg_qty    20.914183
# Name: 695, dtype: float64
# mi          0.001248
# avg_qty    25.931103
# Name: 696, dtype: float64
# mi          0.001248
# avg_qty    27.107467
# Name: 697, dtype: float64
# mi          0.001248
# avg_qty    23.245045
# Name: 698, dtype: float64
# mi          0.001248
# avg_qty    24.336620
# Name: 699, dtype: float64
# mi          0.001248
# avg_qty    28.043630
# Name: 700, dtype: float64
# mi          0.001248
# avg_qty    22.180664
# Name: 701, dtype: float64
# mi          0.001248
# avg_qty    24.666019
# Name: 702, dtype: float64
# mi          0.001248
# avg_qty    21.393497
# Name: 703, dtype: float64
# mi          0.001248
# avg_qty    20.872363
# Name: 704, dtype: float64
# mi          0.001248
# avg_qty    28.142512
# Name: 705, dtype: float64
# mi          0.001248
# avg_qty    26.888393
# Name: 706, dtype: float64
# mi          0.001248
# ...
# mi         16.000000
# avg_qty    25.520464
# Name: 8779, dtype: float64
# mi         16.000000
# avg_qty    25.443922
# Name: 8780, dtype: float64
# mi         16.000000
# avg_qty    25.252202
# Name: 8781, dtype: float64
# mi         16.000000
# avg_qty    25.550568
# Name: 8782, dtype: float64
# mi         16.000000
# avg_qty    24.941972
# Name: 8783, dtype: float64
# mi         16.00000
# avg_qty    25.44414
# Name: 8784, dtype: float64
# mi         16.000000
# avg_qty    25.436667
# Name: 8785, dtype: float64
# mi         16.000000
# avg_qty    25.613048
# Name: 8786, dtype: float64
# mi         16.000000
# avg_qty    25.265383
# Name: 8787, dtype: float64
# mi         16.000000
# avg_qty    25.102672
# Name: 8788, dtype: float64
# mi         16.000000
# avg_qty    25.172177
# Name: 8789, dtype: float64
# mi         16.00000
# avg_qty    24.80008
# Name: 8790, dtype: float64
# mi         16.000000
# avg_qty    25.281003
# Name: 8791, dtype: float64
# mi         16.000000
# avg_qty    25.352717
# Name: 8792, dtype: float64
# mi         16.000000
# avg_qty    25.351919
# Name: 8793, dtype: float64
# mi         16.000000
# avg_qty    25.341906
# Name: 8794, dtype: float64
# mi         16.000000
# avg_qty    25.129461
# Name: 8795, dtype: float64
# mi         16.000000
# avg_qty    25.149529
# Name: 8796, dtype: float64
# mi         16.000000
# avg_qty    25.082111
# Name: 8797, dtype: float64
# mi         16.000000
# avg_qty    25.416909
# Name: 8798, dtype: float64
# mi         16.000000
# avg_qty    25.168048
# Name: 8799, dtype: float64
# mi         16.000000
# avg_qty    25.043344
# Name: 8800, dtype: float64
# mi         16.000000
# avg_qty    25.100884
# Name: 8801, dtype: float64
# mi         16.000000
# avg_qty    25.169259
# Name: 8802, dtype: float64
# mi         16.000000
# avg_qty    25.201654
# Name: 8803, dtype: float64
# mi         16.000000
# avg_qty    25.514525
# Name: 8804, dtype: float64
# mi         16.000000
# avg_qty    25.270778
# Name: 8805, dtype: float64
# mi         16.000000
# avg_qty    25.200563
# Name: 8806, dtype: float64
# mi         16.000000
# avg_qty    25.142633
# Name: 8807, dtype: float64
# mi         16.000000
# avg_qty    25.297755
# Name: 8808, dtype: float64
# mi         16.000000
# avg_qty    25.260344
# Name: 8809, dtype: float64
# mi         16.000000
# avg_qty    25.341884
# Name: 8810, dtype: float64
# mi         16.000000
# avg_qty    25.171318
# Name: 8811, dtype: float64
# mi         16.000000
# avg_qty    25.503782
# Name: 8812, dtype: float64
# mi         16.000000
# avg_qty    25.409835
# Name: 8813, dtype: float64
# mi         16.000000
# avg_qty    24.701174
# Name: 8814, dtype: float64
# mi         16.000000
# avg_qty    25.580902
# Name: 8815, dtype: float64
# mi         16.000000
# avg_qty    24.712258
# Name: 8816, dtype: float64
# mi         16.000000
# avg_qty    25.029435
# Name: 8817, dtype: float64
# mi         16.000000
# avg_qty    25.354071
# Name: 8818, dtype: float64
# mi         16.000000
# avg_qty    25.631167
# Name: 8819, dtype: float64
# mi         16.000000
# avg_qty    25.103458
# Name: 8820, dtype: float64
# mi         16.00000
# avg_qty    25.27848
# Name: 8821, dtype: float64
# mi         16.000000
# avg_qty    25.385541
# Name: 8822, dtype: float64
# mi         16.000000
# avg_qty    24.979987
# Name: 8823, dtype: float64
# mi         16.0000
# avg_qty    25.4317
# Name: 8824, dtype: float64
# mi         16.000000
# avg_qty    25.437355
# Name: 8825, dtype: float64
# mi         16.000000
# avg_qty    25.359439
# Name: 8826, dtype: float64
# mi         16.000000
# avg_qty    25.706594
# Name: 8827, dtype: float64
# mi         16.000000
# avg_qty    24.914782
# Name: 8828, dtype: float64
# mi         16.000000
# avg_qty    25.094845
# Name: 8829, dtype: float64
# mi         16.000000
# avg_qty    25.014476
# Name: 8830, dtype: float64
# mi         16.00000
# avg_qty    25.31565
# Name: 8831, dtype: float64
# mi         16.000000
# avg_qty    24.895629
# Name: 8832, dtype: float64
# mi         16.000000
# avg_qty    25.299717
# Name: 8833, dtype: float64
# mi         16.00000
# avg_qty    25.36923
# Name: 8834, dtype: float64
# mi         16.000000
# avg_qty    25.609945
# Name: 8835, dtype: float64
# mi         16.000000
# avg_qty    25.698789
# Name: 8836, dtype: float64
# mi         16.000000
# avg_qty    25.625929
# Name: 8837, dtype: float64
# mi         16.000000
# avg_qty    25.323905
# Name: 8838, dtype: float64
# mi         16.000000
# avg_qty    25.657328
# Name: 8839, dtype: float64
# mi         16.0000
# avg_qty    25.0398
# Name: 8840, dtype: float64
# mi         16.000000
# avg_qty    25.198686
# Name: 8841, dtype: float64
# mi         16.000000
# avg_qty    25.507945
# Name: 8842, dtype: float64
# mi         16.000000
# avg_qty    25.195343
# Name: 8843, dtype: float64
# mi         16.000000
# avg_qty    24.943591
# Name: 8844, dtype: float64
# mi         16.000000
# avg_qty    25.309446
# Name: 8845, dtype: float64
# mi         16.000000
# avg_qty    25.143568
# Name: 8846, dtype: float64
# mi         16.000000
# avg_qty    25.457493
# Name: 8847, dtype: float64
# mi         16.000000
# avg_qty    25.452791
# Name: 8848, dtype: float64
# mi         16.00000
# avg_qty    25.38428
# Name: 8849, dtype: float64
# mi         16.000000
# avg_qty    25.094363
# Name: 8850, dtype: float64
# mi         16.000000
# avg_qty    25.337601
# Name: 8851, dtype: float64
# mi         16.000000
# avg_qty    25.122763
# Name: 8852, dtype: float64
# mi         16.000000
# avg_qty    25.182455
# Name: 8853, dtype: float64
# mi         16.000000
# avg_qty    25.259798
# Name: 8854, dtype: float64
# mi         16.000000
# avg_qty    25.400905
# Name: 8855, dtype: float64
# mi         16.000000
# avg_qty    25.605804
# Name: 8856, dtype: float64
# mi         16.000000
# avg_qty    25.392481
# Name: 8857, dtype: float64
# mi         16.000000
# avg_qty    25.269905
# Name: 8858, dtype: float64
# mi         16.000000
# avg_qty    25.514799
# Name: 8859, dtype: float64
# mi         16.000000
# avg_qty    25.805923
# Name: 8860, dtype: float64
# mi         16.000000
# avg_qty    25.405023
# Name: 8861, dtype: float64
# mi         16.000000
# avg_qty    25.294651
# Name: 8862, dtype: float64
# mi         16.000000
# avg_qty    25.276998
# Name: 8863, dtype: float64
# mi         16.000000
# avg_qty    25.302343
# Name: 8864, dtype: float64
# mi         16.00000
# avg_qty    25.11409
# Name: 8865, dtype: float64
# mi         16.000000
# avg_qty    25.237401
# Name: 8866, dtype: float64
# mi         16.00000
# avg_qty    25.28324
# Name: 8867, dtype: float64
# mi         16.000000
# avg_qty    25.531977
# Name: 8868, dtype: float64
# mi         16.000000
# avg_qty    25.239574
# Name: 8869, dtype: float64
# mi         16.000000
# avg_qty    25.190615
# Name: 8870, dtype: float64
# mi         16.000000
# avg_qty    25.399071
# Name: 8871, dtype: float64
# mi         16.000000
# avg_qty    25.440535
# Name: 8872, dtype: float64
# mi         16.000000
# avg_qty    25.602938
# Name: 8873, dtype: float64
# mi         16.000000
# avg_qty    25.192772
# Name: 8874, dtype: float64
# mi         16.000000
# avg_qty    25.542233
# Name: 8875, dtype: float64
# mi         16.000000
# avg_qty    25.298866
# Name: 8876, dtype: float64
# mi         16.000000
# avg_qty    25.144041
# Name: 8877, dtype: float64
# mi         16.000000
# avg_qty    25.246936
# Name: 8878, dtype: float64
# mi         16.000000
# avg_qty    25.326484
# Name: 8879, dtype: float64
# mi         16.000000
# avg_qty    25.633041
# Name: 8880, dtype: float64
# mi         16.000000
# avg_qty    25.422304
# Name: 8881, dtype: float64
# mi         16.000000
# avg_qty    25.378005
# Name: 8882, dtype: float64
# mi         16.00000
# avg_qty    25.46215
# Name: 8883, dtype: float64
# mi         16.000000
# avg_qty    25.372031
# Name: 8884, dtype: float64
# mi         16.000000
# avg_qty    25.347984
# Name: 8885, dtype: float64
# mi         16.00000
# avg_qty    25.01673
# Name: 8886, dtype: float64
# mi         16.000000
# avg_qty    25.142978
# Name: 8887, dtype: float64
# mi         16.000000
# avg_qty    25.292348
# Name: 8888, dtype: float64
# mi         16.00000
# avg_qty    25.43209
# Name: 8889, dtype: float64
# mi         16.000000
# avg_qty    25.206142
# Name: 8890, dtype: float64
# mi         16.000000
# avg_qty    25.103432
# Name: 8891, dtype: float64
# mi         16.000000
# avg_qty    25.009684
# Name: 8892, dtype: float64
# mi         16.00000
# avg_qty    25.47938
# Name: 8893, dtype: float64
# mi         16.000000
# avg_qty    25.138697
# Name: 8894, dtype: float64
# mi         16.000000
# avg_qty    25.321329
# Name: 8895, dtype: float64
# mi         16.000000
# avg_qty    25.231132
# Name: 8896, dtype: float64
# mi         16.000000
# avg_qty    25.171756
# Name: 8897, dtype: float64
# mi         16.000000
# avg_qty    25.211081
# Name: 8898, dtype: float64
# mi         16.000000
# avg_qty    25.361171
# Name: 8899, dtype: float64
# mi         16.000000
# avg_qty    25.163418
# Name: 8900, dtype: float64
# mi         16.000000
# avg_qty    25.265601
# Name: 8901, dtype: float64
# mi         16.000000
# avg_qty    25.412643
# Name: 8902, dtype: float64
# mi         16.000000
# avg_qty    25.525664
# Name: 8903, dtype: float64
# mi         16.000000
# avg_qty    25.023732
# Name: 8904, dtype: float64
# mi         16.000000
# avg_qty    25.771953
# Name: 8905, dtype: float64
# mi         16.0000
# avg_qty    25.5934
# Name: 8906, dtype: float64
# mi         16.000000
# avg_qty    25.481399
# Name: 8907, dtype: float64
# mi         16.000000
# avg_qty    24.830771
# Name: 8908, dtype: float64
# mi         16.000000
# avg_qty    25.506256
# Name: 8909, dtype: float64
# mi         16.000000
# avg_qty    25.150411
# Name: 8910, dtype: float64
# mi         16.000000
# avg_qty    25.379165
# Name: 8911, dtype: float64
# mi         16.000000
# avg_qty    25.430346
# Name: 8912, dtype: float64
# mi         16.00000
# avg_qty    25.43288
# Name: 8913, dtype: float64
# mi         16.000000
# avg_qty    25.119426
# Name: 8914, dtype: float64
# mi         16.000000
# avg_qty    25.388192
# Name: 8915, dtype: float64
# mi         16.000000
# avg_qty    25.334505
# Name: 8916, dtype: float64
# mi         16.000000
# avg_qty    25.343752
# Name: 8917, dtype: float64
# mi         16.000000
# avg_qty    25.331741
# Name: 8918, dtype: float64
# mi         16.000000
# avg_qty    25.282361
# Name: 8919, dtype: float64
# mi         16.000000
# avg_qty    25.165301
# Name: 8920, dtype: float64
# mi         16.000000
# avg_qty    25.087891
# Name: 8921, dtype: float64
# mi         16.000000
# avg_qty    25.571364
# Name: 8922, dtype: float64
# mi         16.000000
# avg_qty    25.517517
# Name: 8923, dtype: float64
# mi         16.000000
# avg_qty    25.206672
# Name: 8924, dtype: float64
# mi         16.000000
# avg_qty    25.285542
# Name: 8925, dtype: float64
# mi         16.000000
# avg_qty    25.579154
# Name: 8926, dtype: float64
# mi         16.000000
# avg_qty    25.653728
# Name: 8927, dtype: float64
# mi         16.000000
# avg_qty    25.214978
# Name: 8928, dtype: float64
# mi         16.000000
# avg_qty    25.443922
# Name: 8929, dtype: float64
# mi         16.000000
# avg_qty    25.490633
# Name: 8930, dtype: float64
# mi         16.00000
# avg_qty    25.14516
# Name: 8931, dtype: float64
# mi         16.000000
# avg_qty    25.288785
# Name: 8932, dtype: float64
# mi         16.000000
# avg_qty    25.341644
# Name: 8933, dtype: float64
# mi         16.000000
# avg_qty    25.435358
# Name: 8934, dtype: float64
# mi         16.000000
# avg_qty    25.349507
# Name: 8935, dtype: float64
# mi         16.000000
# avg_qty    25.072418
# Name: 8936, dtype: float64
# mi         16.000000
# avg_qty    25.066457
# Name: 8937, dtype: float64
# mi         16.000000
# avg_qty    25.255813
# Name: 8938, dtype: float64
# mi         16.000000
# avg_qty    25.183542
# Name: 8939, dtype: float64
# mi         16.000000
# avg_qty    25.177647
# Name: 8940, dtype: float64
# mi         16.000000
# avg_qty    25.025172
# Name: 8941, dtype: float64
# mi         16.000000
# avg_qty    24.883592
# Name: 8942, dtype: float64
# mi         16.000000
# avg_qty    25.658321
# Name: 8943, dtype: float64
# mi         16.000000
# avg_qty    25.347468
# Name: 8944, dtype: float64
# mi         16.000000
# avg_qty    25.120149
# Name: 8945, dtype: float64
# mi         16.000000
# avg_qty    25.074674
# Name: 8946, dtype: float64
# mi         16.000000
# avg_qty    25.002647
# Name: 8947, dtype: float64
# mi         16.000000
# avg_qty    25.041143
# Name: 8948, dtype: float64
# mi         16.000000
# avg_qty    25.377001
# Name: 8949, dtype: float64
# mi         16.000000
# avg_qty    25.456996
# Name: 8950, dtype: float64
# mi         16.000000
# avg_qty    24.993341
# Name: 8951, dtype: float64
# mi         16.000000
# avg_qty    25.326003
# Name: 8952, dtype: float64
# mi         16.000000
# avg_qty    25.767825
# Name: 8953, dtype: float64
# mi         16.000000
# avg_qty    25.555857
# Name: 8954, dtype: float64
# mi         16.000000
# avg_qty    25.382089
# Name: 8955, dtype: float64
# mi         16.000000
# avg_qty    25.271884
# Name: 8956, dtype: float64
# mi         16.000000
# avg_qty    25.274279
# Name: 8957, dtype: float64
# mi         16.000000
# avg_qty    25.014004
# Name: 8958, dtype: float64
# mi         16.000000
# avg_qty    25.717697
# Name: 8959, dtype: float64
# mi         16.000000
# avg_qty    25.102402
# Name: 8960, dtype: float64
# mi         16.000000
# avg_qty    25.374391
# Name: 8961, dtype: float64
# mi         16.000000
# avg_qty    25.488525
# Name: 8962, dtype: float64
# mi         16.000000
# avg_qty    25.189748
# Name: 8963, dtype: float64
# mi         16.000000
# avg_qty    25.382582
# Name: 8964, dtype: float64
# mi         16.000000
# avg_qty    25.489814
# Name: 8965, dtype: float64
# mi         16.000000
# avg_qty    25.318894
# Name: 8966, dtype: float64
# mi         16.000000
# avg_qty    25.498993
# Name: 8967, dtype: float64
# mi         16.000000
# avg_qty    25.186184
# Name: 8968, dtype: float64
# mi         16.000000
# avg_qty    25.379661
# Name: 8969, dtype: float64
# mi         16.000000
# avg_qty    25.511527
# Name: 8970, dtype: float64
# mi         16.000000
# avg_qty    25.404459
# Name: 8971, dtype: float64
# mi         16.000000
# avg_qty    25.147713
# Name: 8972, dtype: float64
# mi         16.000000
# avg_qty    25.333718
# Name: 8973, dtype: float64
# mi         16.000000
# avg_qty    25.390293
# Name: 8974, dtype: float64
# mi         16.000000
# avg_qty    25.670647
# Name: 8975, dtype: float64
# mi         16.000000
# avg_qty    25.026211
# Name: 8976, dtype: float64
# mi         16.000000
# avg_qty    24.992231
# Name: 8977, dtype: float64
# mi         16.00000
# avg_qty    25.20218
# Name: 8978, dtype: float64
# mi         16.000000
# avg_qty    25.835079
# Name: 8979, dtype: float64
# mi         16.000000
# avg_qty    25.081409
# Name: 8980, dtype: float64
# mi         16.000000
# avg_qty    25.274044
# Name: 8981, dtype: float64
# mi         16.000000
# avg_qty    25.474559
# Name: 8982, dtype: float64
# mi         16.00000
# avg_qty    25.16034
# Name: 8983, dtype: float64
# mi         16.000000
# avg_qty    25.242017
# Name: 8984, dtype: float64
# mi         16.000000
# avg_qty    25.413518
# Name: 8985, dtype: float64
# mi         16.000000
# avg_qty    25.052003
# Name: 8986, dtype: float64
# mi         16.000000
# avg_qty    25.495887
# Name: 8987, dtype: float64
# mi         16.000000
# avg_qty    25.590428
# Name: 8988, dtype: float64
# mi         16.000000
# avg_qty    25.471099
# Name: 8989, dtype: float64
# mi         16.000000
# avg_qty    24.825859
# Name: 8990, dtype: float64
# mi         16.000000
# avg_qty    25.473424
# Name: 8991, dtype: float64
# mi         16.000000
# avg_qty    25.198119
# Name: 8992, dtype: float64
# mi         16.000000
# avg_qty    25.394363
# Name: 8993, dtype: float64
# mi         16.000000
# avg_qty    25.205389
# Name: 8994, dtype: float64
# mi         16.000000
# avg_qty    25.328298
# Name: 8995, dtype: float64
# mi         16.000000
# avg_qty    25.532486
# Name: 8996, dtype: float64
# mi         16.000000
# avg_qty    25.432798
# Name: 8997, dtype: float64
# mi         16.000000
# avg_qty    25.157305
# Name: 8998, dtype: float64
# mi         16.000000
# avg_qty    25.041341
# Name: 8999, dtype: float64
#              mi  absolute error avg_qty  relative error avg_qty
# 0      0.001248                7.459267               29.482496
# 1      0.001248                4.672464               18.467752
# 2      0.001248                6.114246               24.166347
# 3      0.001248                0.530200                2.095597
# 4      0.001248                7.025088               27.766418
# ...         ...                     ...                     ...
# 8995  16.000000                0.027634                0.109223
# 8996  16.000000                0.231822                0.916268
# 8997  16.000000                0.132134                0.522254
# 8998  16.000000                0.143359                0.566623
# 8999  16.000000                0.259323                1.024967
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 avg_qty mean  avg_qty var
# type factor
# pac  0.001248      25.323374    22.386313
#      0.015625      25.270204     1.838576
#      0.031250      25.331539     0.881384
#      0.062500      25.301011     0.510035
#      0.250000      25.286606     0.177720
#      1.000000      25.285502     0.076346
#      2.000000      25.300072     0.069309
#      4.000000      25.305786     0.058417
#      16.000000     25.306735     0.050511

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error avg_qty mean  absolute error avg_qty var  \
# type factor
# pac  0.001248                      3.752972                    8.287929
#      0.015625                      1.077916                    0.676438
#      0.031250                      0.749335                    0.320274
#      0.062500                      0.568158                    0.186908
#      0.250000                      0.334333                    0.066027
#      1.000000                      0.217824                    0.029081
#      2.000000                      0.205417                    0.027071
#      4.000000                      0.194780                    0.020466
#      16.000000                     0.179782                    0.018194
#
#                 relative error avg_qty mean  relative error avg_qty var
# type factor
# pac  0.001248                     14.833494                  129.473885
#      0.015625                      4.260427                   10.567297
#      0.031250                      2.961719                    5.003318
#      0.062500                      2.245627                    2.919876
#      0.250000                      1.321441                    1.031480
#      1.000000                      0.860943                    0.454298
#      2.000000                      0.811902                    0.422906
#      4.000000                      0.769863                    0.319723
#      16.000000                     0.710582                    0.284228

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#              avg_qty
# mi
# 0.001248   22.386313
# 0.015625    1.838576
# 0.031250    0.881384
# 0.062500    0.510035
# 0.250000    0.177720
# 1.000000    0.076346
# 2.000000    0.069309
# 4.000000    0.058417
# 16.000000   0.050511

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step           scale
# query        avg_qty
# mi
# 0.001248   21.776270
# 0.015625    1.739758
# 0.031250    0.869879
# 0.062500    0.434940
# 0.250000    0.108735
# 1.000000    0.027184
# 2.000000    0.013592
# 4.000000    0.006796
# 16.000000   0.001699

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# avg_qty    0.727857
# dtype: float64
#             avg_qty
# mi
# 0.001248   0.742086
# 0.015625   0.711847
# 0.031250   0.746122
# 0.062500   0.711585
# 0.250000   0.772200
# 1.000000   0.738707
# 2.000000   0.710710
# 4.000000   0.719397
# 16.000000  0.698061

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_10546/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query               avg_qty
# mi
# 0.001248           3.728029
# 0.015625           1.062250
# 0.031250           0.727845
# 0.062500           0.542151
# 0.250000           0.272307
# 1.000000           0.127174
# 2.000000           0.093702
# 4.000000           0.065619
# 16.000000          0.033663

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_10546/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_10546/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query           avg_qty
# mi
# 0.001248      25.292500
# 0.015625      25.288950
# 0.031250      25.304412
# 0.062500      25.298689
# 0.250000      25.279675
# 1.000000      25.284984
# 2.000000      25.301497
# 4.000000      25.301105
# 16.000000     25.304764
# step   chosen_sample
# query        avg_qty
# all mi     25.295175

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_10546/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#              avg_qty
# mi
# 0.001248   14.833494
# 0.015625    4.260427
# 0.031250    2.961719
# 0.062500    2.245627
# 0.250000    1.321441
# 1.000000    0.860943
# 2.000000    0.811902
# 4.000000    0.769863
# 16.000000   0.710582

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#              avg_qty
# mi
# 0.001248   14.091407
# 0.015625    3.548581
# 0.031250    2.215597
# 0.062500    1.534042
# 0.250000    0.549240
# 1.000000    0.122236
# 2.000000    0.101192
# 4.000000    0.050465
# 16.000000   0.012520

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()
