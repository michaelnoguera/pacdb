# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   -- sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   -- sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   avg(l_quantity) as avg_qty,
#   -- avg(l_extendedprice) as avg_price,
#   -- avg(l_discount) as avg_disc,
#   -- count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'A'
#   and l_linestatus = 'F'
# ```

# %%
EXPERIMENT = 'pac-q1-avg-qty'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'A') &
        (lineitem_df['l_linestatus'] == 'F')
    ]
    print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        # float(discounted_price.sum()),                      # sum_disc_price
        # float(charged_price.sum()),                         # sum_charge
        float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        # float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        # float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        # float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# (147790, 16)
# [25.537587116854997]
# [25.537587116854997]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['avg_qty']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 147790  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            # out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np
# Out:
# (147790, 16)
# [25.537587116854997]

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
# TODO: Change it back to 1000
EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    # out_np = generate_samples() # generate samples (results of running the query)
    # print(f"Generate samples... {len(out_np)} samples generated.")

    print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# [25.58132023]
# Getting PAC Noise...
# The dimensions are - 1
# [array([[25.58132023]]), array([[25.49410304]]), array([[25.57399279]]), array([[25.50125723]]), array([[25.54751009]]), array([[25.52767408]]), array([[25.53497642]]), array([[25.54020574]]), array([[25.5701051]]), array([[25.50512453]]), array([[25.52029101]]), array([[25.55490852]]), array([[25.50310862]]), array([[25.57200222]]), array([[25.48127944]]), array([[25.59386584]]), array([[25.60339721]]), array([[25.47169147]]), array([[25.56500863]]), array([[25.50998018]]), array([[25.60296467]]), array([[25.47225379]]), array([[25.4691983]]), array([[25.60558097]]), array([[25.53049417]]), array([[25.54466204]]), array([[25.59271007]]), array([[25.48264588]]), array([[25.56098158]]), array([[25.51440695]]), array([[25.52413401]]), array([[25.55106464]]), array([[25.5623464]]), array([[25.51272106]]), array([[25.53565614]]), array([[25.53950814]]), array([[25.53116218]]), array([[25.54397183]]), array([[25.54962132]]), array([[25.52558089]]), array([[25.55709483]]), array([[25.51814424]]), array([[25.49138595]]), array([[25.58392855]]), array([[25.57769586]]), array([[25.49730104]]), array([[25.52113726]]), array([[25.5539752]]), array([[25.49450564]]), array([[25.58098692]]), array([[25.55145799]]), array([[25.52363567]]), array([[25.46004171]]), array([[25.61504233]]), array([[25.52901019]]), array([[25.5461824]]), array([[25.50195226]]), array([[25.57383874]]), array([[25.50635728]]), array([[25.56864836]]), array([[25.57940278]]), array([[25.49529798]]), array([[25.53269345]]), array([[25.54247721]]), array([[25.55141523]]), array([[25.52392419]]), array([[25.55915449]]), array([[25.51604658]]), array([[25.56343612]]), array([[25.51172832]]), array([[25.51520268]]), array([[25.56005532]]), array([[25.58809715]]), array([[25.48739326]]), array([[25.51795338]]), array([[25.55709795]]), array([[25.50592532]]), array([[25.56927034]]), array([[25.54089137]]), array([[25.53426349]]), array([[25.55850143]]), array([[25.51663371]]), array([[25.56308036]]), array([[25.51188325]]), array([[25.49647964]]), array([[25.57865123]]), array([[25.56110562]]), array([[25.51405715]]), array([[25.57451793]]), array([[25.50070325]]), array([[25.57356241]]), array([[25.50153092]]), array([[25.51995682]]), array([[25.5553203]]), array([[25.58546028]]), array([[25.48941109]]), array([[25.52246962]]), array([[25.55264295]]), array([[25.54940738]]), array([[25.52570816]]), array([[25.4991326]]), array([[25.57592628]]), array([[25.51035833]]), array([[25.56457306]]), array([[25.54705787]]), array([[25.52813455]]), array([[25.53882477]]), array([[25.53634899]]), array([[25.67320447]]), array([[25.40146965]]), array([[25.53191921]]), array([[25.54326623]]), array([[25.49209553]]), array([[25.58298522]]), array([[25.51035044]]), array([[25.56472813]]), array([[25.4817405]]), array([[25.59283388]]), array([[25.48504564]]), array([[25.58974463]]), array([[25.49879759]]), array([[25.57650599]]), array([[25.49112362]]), array([[25.58406193]]), array([[25.52524663]]), array([[25.54986032]]), array([[25.53340807]]), array([[25.54178248]]), array([[25.54539648]]), array([[25.529843]]), array([[25.56249746]]), array([[25.51269564]]), array([[25.44676582]]), array([[25.62807473]]), array([[25.55281253]]), array([[25.52224878]]), array([[25.48848624]]), array([[25.58676779]]), array([[25.57282447]]), array([[25.50235453]]), array([[25.49419445]]), array([[25.58037682]]), array([[25.53525763]]), array([[25.53991239]]), array([[25.53698197]]), array([[25.53819369]]), array([[25.6060487]]), array([[25.46923847]]), array([[25.52544602]]), array([[25.54968525]]), array([[25.45542182]]), array([[25.6196724]]), array([[25.51739054]]), array([[25.55782857]]), array([[25.52775111]]), array([[25.54744071]]), array([[25.60368893]]), array([[25.47050483]]), array([[25.56848342]]), array([[25.50666739]]), array([[25.52487968]]), array([[25.55017781]]), array([[25.49633225]]), array([[25.57913894]]), array([[25.57328182]]), array([[25.50201297]]), array([[25.53923305]]), arr ...
# est_y.shape: (1, 8192)
# est_y: [[25.58132023 25.49410304 25.57399279 ... 25.59670737 25.53204645
#   25.54317916]]
# fin_var: [0.00142377]
# sqrt_total_var: 0.0377328716260475
# For mi=0.001248318631131131, we should add noise from a normal distribution with scale...
# 	400.5387627251371 * 0.0377328716260475 * [0.03773287] = [0.57027491]
# pac_noise: [0.57027491]
# mi=0.001248318631131131, scale=[0.57027491]
# Chosen Sample [25.5383802]
# Chosen Sample [25.5247982]
# Chosen Sample [25.60858062]
# Chosen Sample [25.55112853]
# Chosen Sample [25.51269564]
# Chosen Sample [25.52546416]
# Chosen Sample [25.53436373]
# Chosen Sample [25.56836562]
# Chosen Sample [25.5063549]
# Chosen Sample [25.53441257]
# Chosen Sample [25.56699197]
# Chosen Sample [25.54584265]
# Chosen Sample [25.50908034]
# Chosen Sample [25.57613928]
# Chosen Sample [25.51291233]
# Chosen Sample [25.56706206]
# Chosen Sample [25.54033412]
# Chosen Sample [25.56013011]
# Chosen Sample [25.56826778]
# Chosen Sample [25.59376016]
# Chosen Sample [25.55646795]
# Chosen Sample [25.55190471]
# Chosen Sample [25.4828159]
# Chosen Sample [25.54081935]
# Chosen Sample [25.54133988]
# Chosen Sample [25.5251105]
# Chosen Sample [25.46208208]
# Chosen Sample [25.61459198]
# Chosen Sample [25.6283692]
# Chosen Sample [25.51591057]
# Chosen Sample [25.56755036]
# Chosen Sample [25.52591391]
# Chosen Sample [25.52620664]
# Chosen Sample [25.52955678]
# Chosen Sample [25.55737661]
# Chosen Sample [25.51226778]
# Chosen Sample [25.50335044]
# Chosen Sample [25.52627366]
# Chosen Sample [25.5515865]
# Chosen Sample [25.59562287]
# Chosen Sample [25.53769651]
# Chosen Sample [25.59799138]
# Chosen Sample [25.49542582]
# Chosen Sample [25.55869003]
# Chosen Sample [25.56764794]
# Chosen Sample [25.53936226]
# Chosen Sample [25.55332232]
# Chosen Sample [25.47308774]
# Chosen Sample [25.45412645]
# Chosen Sample [25.4979343]
# Chosen Sample [25.53700822]
# Chosen Sample [25.46432734]
# Chosen Sample [25.57006882]
# Chosen Sample [25.55793038]
# Chosen Sample [25.61400493]
# Chosen Sample [25.57545956]
# Chosen Sample [25.49871218]
# Chosen Sample [25.54256625]
# Chosen Sample [25.5719732]
# Chosen Sample [25.57267367]
# Chosen Sample [25.54821993]
# Chosen Sample [25.56960719]
# Chosen Sample [25.49631756]
# Chosen Sample [25.47104309]
# Chosen Sample [25.58521919]
# Chosen Sample [25.51539096]
# Chosen Sample [25.50362574]
# Chosen Sample [25.51104755]
# Chosen Sample [25.51923337]
# Chosen Sample [25.56562224]
# Chosen Sample [25.55639821]
# Chosen Sample [25.50699158]
# Chosen Sample [25.61549903]
# Chosen Sample [25.5972273]
# Chosen Sample [25.54565651]
# Chosen Sample [25.4785475]
# Chosen Sample [25.49074287]
# Chosen Sample [25.497965]
# Chosen Sample [25.48311607]
# Chosen Sample [25.55976669]
# Chosen Sample [25.66321412]
# Chosen Sample [25.54834961]
# Chosen Sample [25.44223766]
# Chosen Sample [25.54845344]
# Chosen Sample [25.59580607]
# Chosen Sample [25.5581235]
# Chosen Sample [25.54079797]
# Chosen Sample [25.52251642]
# Chosen Sample [25.4867505]
# Chosen Sample [25.60265861]
# Chosen Sample [25.59219863]
# Chosen Sample [25.50692454]
# Chosen Sample [25.57325685]
# Chosen Sample [25.48273213]
# Chosen Sample [25.5592473]
# Chosen Sample [25.54329802]
# Chosen Sample [25.53455447]
# Chosen Sample [25.47927577]
# Chosen Sample [25.59911841]
# Chosen Sample [25.5661944]
# Chosen Sample [25.57224554]
# Chosen Sample [25.61325623]
# Chosen Sample [25.56152358]
# Chosen Sample [25.52984307]
# Chosen Sample [25.5836486]
# Chosen Sample [25.52299216]
# Chosen Sample [25.50485988]
# Chosen Sample [25.52234424]
# Chosen Sample [25.53328072]
# Chosen Sample [25.52209803]
# Chosen Sample [25.56129427]
# Chosen Sample [25.57427615]
# Chosen Sample [25.56288113]
# Chosen Sample [25.54943396]
# Chosen Sample [25.54277603]
# Chosen Sample [25.52564694]
# Chosen Sample [25.5008627]
# Chosen Sample [25.54928526]
# Chosen Sample [25.51441149]
# Chosen Sample [25.52893778]
# Chosen Sample [25.54702692]
# Chosen Sample [25.5939929]
# Chosen Sample [25.54278031]
# Chosen Sample [25.4979343]
# Chosen Sample [25.55563706]
# Chosen Sample [25.50837316]
# Chosen Sample [25.47435118]
# Chosen Sample [25.54994187]
# Chosen Sample [25.57676852]
# Chosen Sample [25.52447723]
# Chosen Sample [25.52751225]
# Chosen Sample [25.5901626]
# Chosen Sample [25.50148416]
# Chosen Sample [25.55891759]
# Chosen Sample [25.52463705]
# Chosen Sample [25.58350814]
# Chosen Sample [25.46534119]
# Chosen Sample [25.56892285]
# Chosen Sample [25.5632692]
# Chosen Sample [25.58579313]
# Chosen Sample [25.57468217]
# Chosen Sample [25.54780511]
# Chosen Sample [25.52154704]
# Chosen Sample [25.52209803]
# Chosen Sample [25.57335366]
# Chosen Sample [25.50268716]
# Chosen Sample [25.5146799]
# Chosen Sample [25.52729759]
# Chosen Sample [25.48359725]
# Chosen Sample [25.58411742]
# Chosen Sample [25.57423041]
# Chosen Sample [25.53938298]
# Chosen Sample [25.56712778]
# Chosen Sample [25.56272726]
# Chosen Sample [25.53769651]
# Chosen Sample [25.49385396]
# Chosen Sample [25.53859395]
# Chosen Sample [25.57770211]
# Chosen Sample [25.50955319]
# Chosen Sample [25.5502774]
# Chosen Sample [25.55573482]
# Chosen Sample [25.52189697]
# Chosen Sample [25.52495646]
# Chosen Sample [25.56513643]
# Chosen Sample [25.54173333]
# Chosen Sample [25.44898513]
# Chosen Sample [25.57530701]
# Chosen Sample [25.55999298]
# Chosen Sample [25.56706266]
# Chosen Sample [25.46639608]
# Chosen Sample [25.55022473]
# Chosen Sample [25.55172041]
# Chosen Sample [25.53345519]
# Chosen Sample [25.53154757]
# Chosen Sample [25.61658774]
# Chosen Sample [25.54433154]
# Chosen Sample [25.56913577]
# Chosen Sample [25.56643718]
# Chosen Sample [25.55683465]
# Chosen Sample [25.50320893]
# Chosen Sample [25.55760724]
# Chosen Sample [25.53011655]
# Chosen Sample [25.61114648]
# Chosen Sample [25.50371026]
# Chosen Sample [25.58442807]
# Chosen Sample [25.5710022]
# Chosen Sample [25.59892533]
# Chosen Sample [25.54474966]
# Chosen Sample [25.48447289]
# Chosen Sample [25.52193237]
# Chosen Sample [25.57106224]
# Chosen Sample [25.5253779]
# Chosen Sample [25.41206866]
# Chosen Sample [25.51574894]
# Chosen Sample [25.49417922]
# Chosen Sample [25.59567972]
# Chosen Sample [25.49834143]
# Chosen Sample [25.5502774]
# Chosen Sample [25.50545755]
# Chosen Sample [25.58267876]
# Chosen Sample [25.54242441]
# Chosen Sample [25.5409197]
# Chosen Sample [25.537442]
# Chosen Sample [25.55075066]
# Chosen Sample [25.58181201]
# Chosen Sample [25.51603628]
# Chosen Sample [25.57115395]
# Chosen Sample [25.45525181]
# Chosen Sample [25.57302457]
# Chosen Sample [25.54139955]
# Chosen Sample [25.52845231]
# Chosen Sample [25.62367237]
# Chosen Sample [25.51511203]
# Chosen Sample [25.54298203]
# Chosen Sample [25.4513783]
# Chosen Sample [25.58475023]
# Chosen Sample [25.51131154]
# Chosen Sample [25.45512934]
# Chosen Sample [25.5425992]
# Chosen Sample [25.47188241]
# Chosen Sample [25.56939734]
# Chosen Sample [25.52395595]
# Chosen Sample [25.52284477]
# Chosen Sample [25.56132082]
# Chosen Sample [25.48944392]
# Chosen Sample [25.56755153]
# Chosen Sample [25.5282009]
# Chosen Sample [25.61478814]
# Chosen Sample [25.53378442]
# Chosen Sample [25.56451439]
# Chosen Sample [25.53601015]
# Chosen Sample [25.52115091]
# Chosen Sample [25.55187817]
# Chosen Sample [25.5564232]
# Chosen Sample [25.54269334]
# Chosen Sample [25.48302009]
# Chosen Sample [25.54410713]
# Chosen Sample [25.5045879]
# Chosen Sample [25.53604002]
# Chosen Sample [25.56712458]
# Chosen Sample [25.54468951]
# Chosen Sample [25.57000689]
# Chosen Sample [25.52647717]
# Chosen Sample [25.50369839]
# Chosen Sample [25.57198787]
# Chosen Sample [25.54497878]
# Chosen Sample [25.52804329]
# Chosen Sample [25.49195696]
# Chosen Sample [25.58245857]
# Chosen Sample [25.52687255]
# Chosen Sample [25.56636319]
# Chosen Sample [25.508481]
# Chosen Sample [25.60551948]
# Chosen Sample [25.54448859]
# Chosen Sample [25.5115464]
# Chosen Sample [25.5429658]
# Chosen Sample [25.56215063]
# Chosen Sample [25.51863101]
# Chosen Sample [25.53345569]
# Chosen Sample [25.45390843]
# Chosen Sample [25.50085239]
# Chosen Sample [25.52227241]
# Chosen Sample [25.41882484]
# Chosen Sample [25.53309892]
# Chosen Sample [25.58488031]
# Chosen Sample [25.54122791]
# Chosen Sample [25.52591921]
# Chosen Sample [25.51110779]
# Chosen Sample [25.52438462]
# Chosen Sample [25.48755139]
# Chosen Sample [25.49096516]
# Chosen Sample [25.55885908]
# Chosen Sample [25.57964831]
# Chosen Sample [25.59319513]
# Chosen Sample [25.5740082]
# Chosen Sample [25.53920242]
# Chosen Sample [25.55603448]
# Chosen Sample [25.56312543]
# Chosen Sample [25.52813729]
# Chosen Sample [25.56818735]
# Chosen Sample [25.54907756]
# Chosen Sample [25.60352417]
# Chosen Sample [25.62303736]
# Chosen Sample [25.55021628]
# Chosen Sample [25.51579502]
# Chosen Sample [25.56098873]
# Chosen Sample [25.52348412]
# Chosen Sample [25.58795533]
# Chosen Sample [25.51111502]
# Chosen Sample [25.52251727]
# Chosen Sample [25.53441257]
# Chosen Sample [25.55084414]
# Chosen Sample [25.52891701]
# Chosen Sample [25.54378367]
# Chosen Sample [25.51980701]
# Chosen Sample [25.54589405]
# Chosen Sample [25.48518689]
# Chosen Sample [25.50361822]
# Chosen Sample [25.55411647]
# Chosen Sample [25.62797244]
# Chosen Sample [25.49633225]
# Chosen Sample [25.4847337]
# Chosen Sample [25.51614082]
# Chosen Sample [25.59409264]
# Chosen Sample [25.5253097]
# Chosen Sample [25.52708227]
# Chosen Sample [25.54136818]
# Chosen Sample [25.55860052]
# Chosen Sample [25.50268949]
# Chosen Sample [25.52220386]
# Chosen Sample [25.51107975]
# Chosen Sample [25.4717973]
# Chosen Sample [25.5528075]
# Chosen Sample [25.58075903]
# Chosen Sample [25.56813383]
# Chosen Sample [25.55075354]
# Chosen Sample [25.5379782]
# Chosen Sample [25.56204921]
# Chosen Sample [25.47351488]
# Chosen Sample [25.54468171]
# Chosen Sample [25.573175]
# Chosen Sample [25.52543928]
# Chosen Sample [25.52171029]
# Chosen Sample [25.54323033]
# Chosen Sample [25.52251411]
# Chosen Sample [25.53846778]
# Chosen Sample [25.48612862]
# Chosen Sample [25.51839188]
# Chosen Sample [25.60305157]
# Chosen Sample [25.53433197]
# Chosen Sample [25.52831311]
# Chosen Sample [25.57769586]
# Chosen Sample [25.54424474]
# Chosen Sample [25.51539096]
# Chosen Sample [25.5319809]
# Chosen Sample [25.55497453]
# Chosen Sample [25.56946249]
# Chosen Sample [25.56346149]
# Chosen Sample [25.5007217]
# Chosen Sample [25.53580485]
# Chosen Sample [25.55531863]
# Chosen Sample [25.52356415]
# Chosen Sample [25.58127316]
# Chosen Sample [25.58214353]
# Chosen Sample [25.54907756]
# Chosen Sample [25.54333266]
# Chosen Sample [25.55928566]
# Chosen Sample [25.53168238]
# Chosen Sample [25.64831124]
# Chosen Sample [25.54875265]
# Chosen Sample [25.40317465]
# Chosen Sample [25.60471762]
# Chosen Sample [25.51397794]
# Chosen Sample [25.48369021]
# Chosen Sample [25.52113726]
# Chosen Sample [25.51285253]
# Chosen Sample [25.47655099]
# Chosen Sample [25.57800241]
# Chosen Sample [25.51315075]
# Chosen Sample [25.48658493]
# Chosen Sample [25.52261674]
# Chosen Sample [25.54597958]
# Chosen Sample [25.51939893]
# Chosen Sample [25.47920529]
# Chosen Sample [25.4932636]
# Chosen Sample [25.55237928]
# Chosen Sample [25.53716677]
# Chosen Sample [25.52792829]
# Chosen Sample [25.56939704]
# Chosen Sample [25.5515821]
# Chosen Sample [25.45182625]
# Chosen Sample [25.49369793]
# Chosen Sample [25.5701051]
# Chosen Sample [25.54485483]
# Chosen Sample [25.50373611]
# Chosen Sample [25.51883111]
# Chosen Sample [25.58721755]
# Chosen Sample [25.57528816]
# Chosen Sample [25.62380985]
# Chosen Sample [25.46381971]
# Chosen Sample [25.54918421]
# Chosen Sample [25.59067041]
# Chosen Sample [25.48447289]
# Chosen Sample [25.51298816]
# Chosen Sample [25.59855454]
# Chosen Sample [25.52062213]
# Chosen Sample [25.51112702]
# Chosen Sample [25.53188872]
# Chosen Sample [25.55987955]
# Chosen Sample [25.58322635]
# Chosen Sample [25.56801757]
# Chosen Sample [25.56249746]
# Chosen Sample [25.49804283]
# Chosen Sample [25.62635033]
# Chosen Sample [25.58149411]
# Chosen Sample [25.57428895]
# Chosen Sample [25.55164319]
# Chosen Sample [25.52889762]
# Chosen Sample [25.4872925]
# Chosen Sample [25.51142853]
# Chosen Sample [25.51867926]
# Chosen Sample [25.51035833]
# Chosen Sample [25.48198588]
# Chosen Sample [25.55979048]
# Chosen Sample [25.55205439]
# Chosen Sample [25.53166266]
# Chosen Sample [25.48658493]
# Chosen Sample [25.5575542]
# Chosen Sample [25.53353357]
# Chosen Sample [25.53849597]
# Chosen Sample [25.57445194]
# Chosen Sample [25.49737689]
# Chosen Sample [25.52702794]
# Chosen Sample [25.54978998]
# Chosen Sample [25.60751526]
# Chosen Sample [25.50066509]
# Chosen Sample [25.59623162]
# Chosen Sample [25.5814026]
# Chosen Sample [25.59571749]
# Chosen Sample [25.47890685]
# Chosen Sample [25.5115344]
# Chosen Sample [25.508481]
# Chosen Sample [25.53407303]
# Chosen Sample [25.5500544]
# Chosen Sample [25.52563162]
# Chosen Sample [25.56606949]
# Chosen Sample [25.55446588]
# Chosen Sample [25.55513749]
# Chosen Sample [25.59047322]
# Chosen Sample [25.56099171]
# Chosen Sample [25.57238657]
# Chosen Sample [25.57367127]
# Chosen Sample [25.46696707]
# Chosen Sample [25.58006426]
# Chosen Sample [25.51182889]
# Chosen Sample [25.49016199]
# Chosen Sample [25.50582473]
# Chosen Sample [25.50997086]
# Chosen Sample [25.54487637]
# Chosen Sample [25.52360306]
# Chosen Sample [25.5176732]
# Chosen Sample [25.52804276]
# Chosen Sample [25.51201753]
# Chosen Sample [25.53457497]
# Chosen Sample [25.57194371]
# Chosen Sample [25.51752033]
# Chosen Sample [25.60321687]
# Chosen Sample [25.54278987]
# Chosen Sample [25.51031012]
# Chosen Sample [25.50820804]
# Chosen Sample [25.52644999]
# Chosen Sample [25.58745532]
# Chosen Sample [25.52627366]
# Chosen Sample [25.62026963]
# Chosen Sample [25.55710507]
# Chosen Sample [25.56095806]
# Chosen Sample [25.55059158]
# Chosen Sample [25.54301489]
# Chosen Sample [25.51092473]
# Chosen Sample [25.51442497]
# Chosen Sample [25.53172967]
# Chosen Sample [25.54038748]
# Chosen Sample [25.52603368]
# Chosen Sample [25.56113655]
# Chosen Sample [25.5552654]
# Chosen Sample [25.54161318]
# Chosen Sample [25.55618646]
# Chosen Sample [25.52369649]
# Chosen Sample [25.48311607]
# Chosen Sample [25.53174335]
# Chosen Sample [25.51624549]
# Chosen Sample [25.51621192]
# Chosen Sample [25.58041816]
# Chosen Sample [25.55649714]
# Chosen Sample [25.48652153]
# Chosen Sample [25.54684037]
# Chosen Sample [25.49967503]
# Chosen Sample [25.54748293]
# Chosen Sample [25.57873572]
# Chosen Sample [25.50205367]
# Chosen Sample [25.52476994]
# Chosen Sample [25.50054296]
# Chosen Sample [25.55461674]
# Chosen Sample [25.53498193]
# Chosen Sample [25.50921019]
# Chosen Sample [25.5544339]
# Chosen Sample [25.54067522]
# Chosen Sample [25.55211427]
# Chosen Sample [25.48081413]
# Chosen Sample [25.56663149]
# Chosen Sample [25.5883753]
# Chosen Sample [25.52123426]
# Chosen Sample [25.57572297]
# Chosen Sample [25.53200886]
# Chosen Sample [25.52184623]
# Chosen Sample [25.50023754]
# Chosen Sample [25.53912668]
# Chosen Sample [25.56599033]
# Chosen Sample [25.55681772]
# Chosen Sample [25.54938973]
# Chosen Sample [25.47269015]
# Chosen Sample [25.58245087]
# Chosen Sample [25.5702364]
# Chosen Sample [25.50490276]
# Chosen Sample [25.58579313]
# Chosen Sample [25.51371966]
# Chosen Sample [25.57649571]
# Chosen Sample [25.50142257]
# Chosen Sample [25.60452943]
# Chosen Sample [25.44486007]
# Chosen Sample [25.5881652]
# Chosen Sample [25.51720395]
# Chosen Sample [25.49756249]
# Chosen Sample [25.51467549]
# Chosen Sample [25.43925082]
# Chosen Sample [25.56073115]
# Chosen Sample [25.48565543]
# Chosen Sample [25.56346149]
# Chosen Sample [25.54689091]
# Chosen Sample [25.53454161]
# Chosen Sample [25.45734209]
# Chosen Sample [25.49746028]
# Chosen Sample [25.57302457]
# Chosen Sample [25.5660636]
# Chosen Sample [25.52454512]
# Chosen Sample [25.52813401]
# Chosen Sample [25.53202857]
# Chosen Sample [25.52560176]
# Chosen Sample [25.48335938]
# Chosen Sample [25.49096516]
# Chosen Sample [25.48972409]
# Chosen Sample [25.4991326]
# Chosen Sample [25.51443833]
# Chosen Sample [25.51326399]
# Chosen Sample [25.49529798]
# Chosen Sample [25.48190079]
# Chosen Sample [25.5353847]
# Chosen Sample [25.54838753]
# Chosen Sample [25.59085444]
# Chosen Sample [25.52164923]
# Chosen Sample [25.6117988]
# Chosen Sample [25.5543667]
# Chosen Sample [25.57058974]
# Chosen Sample [25.54578591]
# Chosen Sample [25.55814299]
# Chosen Sample [25.47645538]
# Chosen Sample [25.52465009]
# Chosen Sample [25.55036932]
# Chosen Sample [25.57352623]
# Chosen Sample [25.504011]
# Chosen Sample [25.54298203]
# Chosen Sample [25.49717064]
# Chosen Sample [25.58885906]
# Chosen Sample [25.53525835]
# Chosen Sample [25.55757254]
# Chosen Sample [25.55279908]
# Chosen Sample [25.62610539]
# Chosen Sample [25.62807473]
# Chosen Sample [25.55022473]
# Chosen Sample [25.56589316]
# Chosen Sample [25.54212226]
# Chosen Sample [25.54290756]
# Chosen Sample [25.51479346]
# Chosen Sample [25.5532477]
# Chosen Sample [25.59977327]
# Chosen Sample [25.6073672]
# Chosen Sample [25.57210642]
# Chosen Sample [25.50654598]
# Chosen Sample [25.53783711]
# Chosen Sample [25.53043455]
# Chosen Sample [25.53420675]
# Chosen Sample [25.51870365]
# Chosen Sample [25.56046912]
# Chosen Sample [25.51671194]
# Chosen Sample [25.6107091]
# Chosen Sample [25.53673754]
# Chosen Sample [25.53548282]
# Chosen Sample [25.53372069]
# Chosen Sample [25.49218528]
# Chosen Sample [25.58439636]
# Chosen Sample [25.60882094]
# Chosen Sample [25.50752747]
# Chosen Sample [25.49253208]
# Chosen Sample [25.50369839]
# Chosen Sample [25.57606733]
# Chosen Sample [25.55263336]
# Chosen Sample [25.51038055]
# Chosen Sample [25.50116405]
# Chosen Sample [25.49803259]
# Chosen Sample [25.5660636]
# Chosen Sample [25.55307285]
# Chosen Sample [25.63723743]
# Chosen Sample [25.50980128]
# Chosen Sample [25.54756217]
# Chosen Sample [25.51498604]
# Chosen Sample [25.57673294]
# Chosen Sample [25.47215267]
# Chosen Sample [25.51561418]
# Chosen Sample [25.54752523]
# Chosen Sample [25.5366822]
# Chosen Sample [25.50485988]
# Chosen Sample [25.47627082]
# Chosen Sample [25.54898424]
# Chosen Sample [25.49053619]
# Chosen Sample [25.47321284]
# Chosen Sample [25.54861243]
# Chosen Sample [25.53848653]
# Chosen Sample [25.56659528]
# Chosen Sample [25.520908]
# Chosen Sample [25.51498604]
# Chosen Sample [25.5558097]
# Chosen Sample [25.54135828]
# Chosen Sample [25.59362373]
# Chosen Sample [25.57796429]
# Chosen Sample [25.50947351]
# Chosen Sample [25.53493361]
# Chosen Sample [25.50730838]
# Chosen Sample [25.48200933]
# Chosen Sample [25.56607772]
# Chosen Sample [25.59483925]
# Chosen Sample [25.55205439]
# Chosen Sample [25.54208139]
# Chosen Sample [25.51356652]
# Chosen Sample [25.51939893]
# Chosen Sample [25.50301132]
# Chosen Sample [25.55064283]
# Chosen Sample [25.53022301]
# Chosen Sample [25.56073115]
# Chosen Sample [25.55619503]
# Chosen Sample [25.52580458]
# Chosen Sample [25.49079639]
# Chosen Sample [25.4270589]
# Chosen Sample [25.51604658]
# Chosen Sample [25.57847988]
# Chosen Sample [25.56286837]
# Chosen Sample [25.5230632]
# Chosen Sample [25.56711582]
# Chosen Sample [25.51397794]
# Chosen Sample [25.53243911]
# Chosen Sample [25.56380643]
# Chosen Sample [25.56909898]
# Chosen Sample [25.49893079]
# Chosen Sample [25.48844295]
# Chosen Sample [25.53188926]
# Chosen Sample [25.51014355]
# Chosen Sample [25.58018295]
# Chosen Sample [25.4527399]
# Chosen Sample [25.55927134]
# Chosen Sample [25.45188121]
# Chosen Sample [25.57237494]
# Chosen Sample [25.48200933]
# Chosen Sample [25.55340016]
# Chosen Sample [25.48556052]
# Chosen Sample [25.49237514]
# Chosen Sample [25.59325913]
# Chosen Sample [25.48293786]
# Chosen Sample [25.4864041]
# Chosen Sample [25.61957343]
# Chosen Sample [25.58369678]
# Chosen Sample [25.50289558]
# Chosen Sample [25.53119454]
# Chosen Sample [25.59472195]
# Chosen Sample [25.53776981]
# Chosen Sample [25.51381163]
# Chosen Sample [25.51868653]
# Chosen Sample [25.55220509]
# Chosen Sample [25.53258266]
# Chosen Sample [25.50353153]
# Chosen Sample [25.51289654]
# Chosen Sample [25.55629398]
# Chosen Sample [25.5612952]
# Chosen Sample [25.58067883]
# Chosen Sample [25.58743247]
# Chosen Sample [25.53166545]
# Chosen Sample [25.54334609]
# Chosen Sample [25.58159673]
# Chosen Sample [25.52088229]
# Chosen Sample [25.57178797]
# Chosen Sample [25.53458489]
# Chosen Sample [25.56310627]
# Chosen Sample [25.50608867]
# Chosen Sample [25.53658668]
# Chosen Sample [25.5546897]
# Chosen Sample [25.60968148]
# Chosen Sample [25.54256625]
# Chosen Sample [25.43899792]
# Chosen Sample [25.55553293]
# Chosen Sample [25.46035147]
# Chosen Sample [25.52946737]
# Chosen Sample [25.56115517]
# Chosen Sample [25.46919265]
# Chosen Sample [25.54610158]
# Chosen Sample [25.61562927]
# Chosen Sample [25.57352623]
# Chosen Sample [25.5400474]
# Chosen Sample [25.52846864]
# Chosen Sample [25.51367658]
# Chosen Sample [25.5606194]
# Chosen Sample [25.58558632]
# Chosen Sample [25.61020938]
# Chosen Sample [25.57178613]
# Chosen Sample [25.53448603]
# Chosen Sample [25.459116]
# Chosen Sample [25.54919719]
# Chosen Sample [25.5045853]
# Chosen Sample [25.49377739]
# Chosen Sample [25.6120052]
# Chosen Sample [25.50185027]
# Chosen Sample [25.55629301]
# Chosen Sample [25.54025183]
# Chosen Sample [25.50908919]
# Chosen Sample [25.52993748]
# Chosen Sample [25.58462913]
# Chosen Sample [25.46040384]
# Chosen Sample [25.52011993]
# Chosen Sample [25.52798755]
# Chosen Sample [25.50020901]
# Chosen Sample [25.58105911]
# Chosen Sample [25.54635847]
# Chosen Sample [25.43285035]
# Chosen Sample [25.58907283]
# Chosen Sample [25.54412682]
# Chosen Sample [25.50205367]
# Chosen Sample [25.44264268]
# Chosen Sample [25.60368893]
# Chosen Sample [25.56289976]
# Chosen Sample [25.57175707]
# Chosen Sample [25.54656321]
# Chosen Sample [25.45658654]
# Chosen Sample [25.58194649]
# Chosen Sample [25.56634875]
# Chosen Sample [25.57270222]
# Chosen Sample [25.55757254]
# Chosen Sample [25.48282692]
# Chosen Sample [25.55949695]
# Chosen Sample [25.51099943]
# Chosen Sample [25.57992691]
# Chosen Sample [25.51632365]
# Chosen Sample [25.51686004]
# Chosen Sample [25.43171281]
# Chosen Sample [25.47103074]
# Chosen Sample [25.60276022]
# Chosen Sample [25.52887002]
# Chosen Sample [25.55995668]
# Chosen Sample [25.54492761]
# Chosen Sample [25.55068115]
# Chosen Sample [25.47203175]
# Chosen Sample [25.48755139]
# Chosen Sample [25.51326438]
# Chosen Sample [25.45617899]
# Chosen Sample [25.5057789]
# Chosen Sample [25.60239871]
# Chosen Sample [25.44609314]
# Chosen Sample [25.6046865]
# Chosen Sample [25.56885182]
# Chosen Sample [25.54458998]
# Chosen Sample [25.51702174]
# Chosen Sample [25.54318761]
# Chosen Sample [25.49077441]
# Chosen Sample [25.59991341]
# Chosen Sample [25.4627885]
# Chosen Sample [25.53942453]
# Chosen Sample [25.51779173]
# Chosen Sample [25.51195151]
# Chosen Sample [25.50099498]
# Chosen Sample [25.52865575]
# Chosen Sample [25.55266197]
# Chosen Sample [25.53839187]
# Chosen Sample [25.5503021]
# Chosen Sample [25.58722212]
# Chosen Sample [25.459116]
# Chosen Sample [25.56046912]
# Chosen Sample [25.55927039]
# Chosen Sample [25.47413513]
# Chosen Sample [25.45445828]
# Chosen Sample [25.53928814]
# Chosen Sample [25.53109529]
# Chosen Sample [25.55699006]
# Chosen Sample [25.52046008]
# Chosen Sample [25.54994187]
# Chosen Sample [25.48302009]
# Chosen Sample [25.4943937]
# Chosen Sample [25.5466712]
# Chosen Sample [25.53913487]
# Chosen Sample [25.56204053]
# Chosen Sample [25.5908138]
# Chosen Sample [25.55516957]
# Chosen Sample [25.55264295]
# Chosen Sample [25.41922733]
# Chosen Sample [25.60585884]
# Chosen Sample [25.51624549]
# Chosen Sample [25.50074584]
# Chosen Sample [25.54687415]
# Chosen Sample [25.4993457]
# Chosen Sample [25.52879333]
# Chosen Sample [25.54968448]
# Chosen Sample [25.56696302]
# Chosen Sample [25.46954939]
# Chosen Sample [25.54623601]
# Chosen Sample [25.51565395]
# Chosen Sample [25.53251126]
# Chosen Sample [25.56114378]
# Chosen Sample [25.56865171]
# Chosen Sample [25.59749236]
# Chosen Sample [25.54822674]
# Chosen Sample [25.4974856]
# Chosen Sample [25.56462143]
# Chosen Sample [25.5427541]
# Chosen Sample [25.54507046]
# Chosen Sample [25.5402121]
# Chosen Sample [25.51948508]
# Chosen Sample [25.54574209]
# Chosen Sample [25.46920936]
# Chosen Sample [25.64640205]
# Chosen Sample [25.46813139]
# Chosen Sample [25.59124475]
# Chosen Sample [25.55753612]
# Chosen Sample [25.52964845]
# Chosen Sample [25.57398007]
# Chosen Sample [25.51782929]
# Chosen Sample [25.51155491]
# Chosen Sample [25.59565835]
# Chosen Sample [25.56303351]
# Chosen Sample [25.62007562]
# Chosen Sample [25.52602862]
# Chosen Sample [25.50571692]
# Chosen Sample [25.50356028]
# Chosen Sample [25.55868481]
# Chosen Sample [25.41406747]
# Chosen Sample [25.52630222]
# Chosen Sample [25.54429784]
# Chosen Sample [25.56288113]
# Chosen Sample [25.5374771]
# Chosen Sample [25.58317286]
# Chosen Sample [25.54314186]
# Chosen Sample [25.48385219]
# Chosen Sample [25.54424474]
# Chosen Sample [25.49137954]
# Chosen Sample [25.54915378]
# Chosen Sample [25.53965176]
# Chosen Sample [25.60953193]
# Chosen Sample [25.56339745]
# Chosen Sample [25.48893113]
# Chosen Sample [25.56113416]
# Chosen Sample [25.46315789]
# Chosen Sample [25.5509285]
# Chosen Sample [25.63290197]
# Chosen Sample [25.57114814]
# Chosen Sample [25.56613778]
# Chosen Sample [25.59874711]
# Chosen Sample [25.54462535]
# Chosen Sample [25.53628918]
# Chosen Sample [25.57323799]
# Chosen Sample [25.56147519]
# Chosen Sample [25.57997109]
# Chosen Sample [25.54208959]
# Chosen Sample [25.56506376]
# Chosen Sample [25.51190186]
# Chosen Sample [25.5202455]
# Chosen Sample [25.55408323]
# Chosen Sample [25.55832229]
# Chosen Sample [25.58172213]
# Chosen Sample [25.54201777]
# Chosen Sample [25.57677898]
# Chosen Sample [25.53458373]
# Chosen Sample [25.55358302]
# Chosen Sample [25.50821631]
# Chosen Sample [25.52160091]
# Chosen Sample [25.53705628]
# Chosen Sample [25.5665427]
# Chosen Sample [25.56349897]
# Chosen Sample [25.59527255]
# Chosen Sample [25.55923364]
# Chosen Sample [25.51559623]
# Chosen Sample [25.5466712]
# Chosen Sample [25.50368075]
# Chosen Sample [25.58203797]
# Chosen Sample [25.45643767]
# Chosen Sample [25.55307746]
# Chosen Sample [25.49625787]
# Chosen Sample [25.55999353]
# Chosen Sample [25.52750813]
# Chosen Sample [25.54173164]
# Chosen Sample [25.5933624]
# Chosen Sample [25.58001296]
# Chosen Sample [25.57291991]
# Chosen Sample [25.59421894]
# Chosen Sample [25.54574893]
# Chosen Sample [25.48148549]
# Chosen Sample [25.48293786]
# Chosen Sample [25.50114865]
# Chosen Sample [25.53819369]
# Chosen Sample [25.54062677]
# Chosen Sample [25.58214353]
# Chosen Sample [25.55489618]
# Chosen Sample [25.53607066]
# Chosen Sample [25.52295191]
# Chosen Sample [25.50815258]
# Chosen Sample [25.5339939]
# Chosen Sample [25.55641756]
# Chosen Sample [25.58600338]
# Chosen Sample [25.54539538]
# Chosen Sample [25.53917406]
# Chosen Sample [25.56485934]
# Chosen Sample [25.56168092]
# Chosen Sample [25.4871895]
# Chosen Sample [25.52581894]
# Chosen Sample [25.50524172]
# Chosen Sample [25.49195696]
# Chosen Sample [25.55266197]
# Chosen Sample [25.55371262]
# Chosen Sample [25.49778001]
# Chosen Sample [25.55818434]
# Chosen Sample [25.48489031]
# Chosen Sample [25.45217156]
# Chosen Sample [25.58328726]
# Chosen Sample [25.58736351]
# Chosen Sample [25.52334026]
# Chosen Sample [25.5447418]
# Chosen Sample [25.54320354]
# Chosen Sample [25.504887]
# Chosen Sample [25.51381006]
# Chosen Sample [25.55212799]
# Chosen Sample [25.56962592]
# Chosen Sample [25.43667603]
# Chosen Sample [25.54394235]
# Chosen Sample [25.55641934]
# Chosen Sample [25.5410532]
# Chosen Sample [25.54584265]
# Chosen Sample [25.52016419]
# Chosen Sample [25.53497642]
# Chosen Sample [25.50512283]
# Chosen Sample [25.56488457]
# Chosen Sample [25.53538728]
# Chosen Sample [25.6196724]
# Chosen Sample [25.56232762]
# Chosen Sample [25.5150912]
# Chosen Sample [25.5520713]
# Chosen Sample [25.49838508]
# Chosen Sample [25.54544473]
# Chosen Sample [25.52918557]
# Chosen Sample [25.58302463]
# Chosen Sample [25.52510457]
# Chosen Sample [25.48264588]
# Chosen Sample [25.55044607]
# Chosen Sample [25.52237517]
# Chosen Sample [25.51873152]
# Chosen Sample [25.61949318]
# Chosen Sample [25.57173366]
# Chosen Sample [25.50371026]
# Chosen Sample [25.5328019]
# Chosen Sample [25.57259237]
# Chosen Sample [25.57799829]
# Chosen Sample [25.5858943]
# Chosen Sample [25.52958219]
# Chosen Sample [25.48721044]
# Chosen Sample [25.53208967]
# Chosen Sample [25.54713406]
# Chosen Sample [25.53658339]
# Chosen Sample [25.54687267]
# Chosen Sample [25.55103722]
# Chosen Sample [25.54083389]
# Chosen Sample [25.54953317]
# Chosen Sample [25.49171338]
# Chosen Sample [25.50370111]
# Chosen Sample [25.61010928]
# Chosen Sample [25.56551911]
# Chosen Sample [25.53308525]
# Chosen Sample [25.5883753]
# Chosen Sample [25.52186245]
# Chosen Sample [25.50101742]
# Chosen Sample [25.50909263]
# Chosen Sample [25.59271007]
# Chosen Sample [25.51911035]
# Chosen Sample [25.54956757]
# Chosen Sample [25.51766505]
# Chosen Sample [25.53027371]
# Chosen Sample [25.55091447]
# Chosen Sample [25.53546133]
# Chosen Sample [25.57572558]
# Chosen Sample [25.52898373]
# Chosen Sample [25.5908138]
# Chosen Sample [25.52880656]
# Chosen Sample [25.45672574]
# Chosen Sample [25.51187689]
# Chosen Sample [25.57986224]
# Chosen Sample [25.52499055]
# Chosen Sample [25.60339721]
# Chosen Sample [25.57859794]
# Chosen Sample [25.4952894]
# Chosen Sample [25.53336581]
# Chosen Sample [25.54928526]
# Chosen Sample [25.59124475]
# Chosen Sample [25.51823944]
# Chosen Sample [25.5631323]
# Chosen Sample [25.56207261]
# Chosen Sample [25.54471644]
# Chosen Sample [25.5349918]
# Chosen Sample [25.51793958]
# Chosen Sample [25.53538728]
# Getting PAC Noise...
# The dimensions are - 1
# [array([[25.58132023]]), array([[25.49410304]]), array([[25.57399279]]), array([[25.50125723]]), array([[25.54751009]]), array([[25.52767408]]), array([[25.53497642]]), array([[25.54020574]]), array([[25.5701051]]), array([[25.50512453]]), array([[25.52029101]]), array([[25.55490852]]), array([[25.50310862]]), array([[25.57200222]]), array([[25.48127944]]), array([[25.59386584]]), array([[25.60339721]]), array([[25.47169147]]), array([[25.56500863]]), array([[25.50998018]]), array([[25.60296467]]), array([[25.47225379]]), array([[25.4691983]]), array([[25.60558097]]), array([[25.53049417]]), array([[25.54466204]]), array([[25.59271007]]), array([[25.48264588]]), array([[25.56098158]]), array([[25.51440695]]), array([[25.52413401]]), array([[25.55106464]]), array([[25.5623464]]), array([[25.51272106]]), array([[25.53565614]]), array([[25.53950814]]), array([[25.53116218]]), array([[25.54397183]]), array([[25.54962132]]), array([[25.52558089]]), array([[25.55709483]]), array([[25.51814424]]), array([[25.49138595]]), array([[25.58392855]]), array([[25.57769586]]), array([[25.49730104]]), array([[25.52113726]]), array([[25.5539752]]), array([[25.49450564]]), array([[25.58098692]]), array([[25.55145799]]), array([[25.52363567]]), array([[25.46004171]]), array([[25.61504233]]), array([[25.52901019]]), array([[25.5461824]]), array([[25.50195226]]), array([[25.57383874]]), array([[25.50635728]]), array([[25.56864836]]), array([[25.57940278]]), array([[25.49529798]]), array([[25.53269345]]), array([[25.54247721]]), array([[25.55141523]]), array([[25.52392419]]), array([[25.55915449]]), array([[25.51604658]]), array([[25.56343612]]), array([[25.51172832]]), array([[25.51520268]]), array([[25.56005532]]), array([[25.58809715]]), array([[25.48739326]]), array([[25.51795338]]), array([[25.55709795]]), array([[25.50592532]]), array([[25.56927034]]), array([[25.54089137]]), array([[25.53426349]]), array([[25.55850143]]), array([[25.51663371]]), array([[25.56308036]]), array([[25.51188325]]), array([[25.49647964]]), array([[25.57865123]]), array([[25.56110562]]), array([[25.51405715]]), array([[25.57451793]]), array([[25.50070325]]), array([[25.57356241]]), array([[25.50153092]]), array([[25.51995682]]), array([[25.5553203]]), array([[25.58546028]]), array([[25.48941109]]), array([[25.52246962]]), array([[25.55264295]]), array([[25.54940738]]), array([[25.52570816]]), array([[25.4991326]]), array([[25.57592628]]), array([[25.51035833]]), array([[25.56457306]]), array([[25.54705787]]), array([[25.52813455]]), array([[25.53882477]]), array([[25.53634899]]), array([[25.67320447]]), array([[25.40146965]]), array([[25.53191921]]), array([[25.54326623]]), array([[25.49209553]]), array([[25.58298522]]), array([[25.51035044]]), array([[25.56472813]]), array([[25.4817405]]), array([[25.59283388]]), array([[25.48504564]]), array([[25.58974463]]), array([[25.49879759]]), array([[25.57650599]]), array([[25.49112362]]), array([[25.58406193]]), array([[25.52524663]]), array([[25.54986032]]), array([[25.53340807]]), array([[25.54178248]]), array([[25.54539648]]), array([[25.529843]]), array([[25.56249746]]), array([[25.51269564]]), array([[25.44676582]]), array([[25.62807473]]), array([[25.55281253]]), array([[25.52224878]]), array([[25.48848624]]), array([[25.58676779]]), array([[25.57282447]]), array([[25.50235453]]), array([[25.49419445]]), array([[25.58037682]]), array([[25.53525763]]), array([[25.53991239]]), array([[25.53698197]]), array([[25.53819369]]), array([[25.6060487]]), array([[25.46923847]]), array([[25.52544602]]), array([[25.54968525]]), array([[25.45542182]]), array([[25.6196724]]), array([[25.51739054]]), array([[25.55782857]]), array([[25.52775111]]), array([[25.54744071]]), array([[25.60368893]]), array([[25.47050483]]), array([[25.56848342]]), array([[25.50666739]]), array([[25.52487968]]), array([[25.55017781]]), array([[25.49633225]]), array([[25.57913894]]), array([[25.57328182]]), array([[25.50201297]]), array([[25.53923305]]), arr ...
# est_y.shape: (1, 8192)
# est_y: [[25.58132023 25.49410304 25.57399279 ... 25.59670737 25.53204645
#   25.54317916]]
# fin_var: [0.00142377]
# sqrt_total_var: 0.0377328716260475
# For mi=0.015625, we should add noise from a normal distribution with scale...
# 	32.0 * 0.0377328716260475 * [0.03773287] = [0.04556063]
# pac_noise: [0.04556063]
# mi=0.015625, scale=[0.04556063]
# Chosen Sample [25.60314971]
# Chosen Sample [25.57242801]
# Chosen Sample [25.47869586]
# Chosen Sample [25.55670773]
# Chosen Sample [25.51537296]
# Chosen Sample [25.54128701]
# Chosen Sample [25.55531533]
# Chosen Sample [25.47033726]
# Chosen Sample [25.53740305]
# Chosen Sample [25.53250686]
# Chosen Sample [25.52327737]
# Chosen Sample [25.5362828]
# Chosen Sample [25.51844734]
# Chosen Sample [25.52121106]
# Chosen Sample [25.57224183]
# Chosen Sample [25.57209579]
# Chosen Sample [25.47018693]
# Chosen Sample [25.61039102]
# Chosen Sample [25.50489009]
# Chosen Sample [25.50492016]
# Chosen Sample [25.54381531]
# Chosen Sample [25.57108029]
# Chosen Sample [25.51995457]
# Chosen Sample [25.53705812]
# Chosen Sample [25.48318234]
# Chosen Sample [25.59466207]
# Chosen Sample [25.54353841]
# Chosen Sample [25.50893487]
# Chosen Sample [25.54485483]
# Chosen Sample [25.61788146]
# Chosen Sample [25.53880563]
# Chosen Sample [25.54063824]
# Chosen Sample [25.49786906]
# Chosen Sample [25.547717]
# Chosen Sample [25.61070019]
# Chosen Sample [25.46414712]
# Chosen Sample [25.48628096]
# Chosen Sample [25.60310415]
# Chosen Sample [25.52173148]
# Chosen Sample [25.51828996]
# Chosen Sample [25.50947351]
# Chosen Sample [25.53941219]
# Chosen Sample [25.51435744]
# Chosen Sample [25.45617899]
# Chosen Sample [25.50361495]
# Chosen Sample [25.51539096]
# Chosen Sample [25.51442497]
# Chosen Sample [25.54661057]
# Chosen Sample [25.49634213]
# Chosen Sample [25.52980902]
# Chosen Sample [25.57671294]
# Chosen Sample [25.57298791]
# Chosen Sample [25.48369021]
# Chosen Sample [25.51186569]
# Chosen Sample [25.58540795]
# Chosen Sample [25.59415606]
# Chosen Sample [25.55139972]
# Chosen Sample [25.4979343]
# Chosen Sample [25.5533978]
# Chosen Sample [25.57253257]
# Chosen Sample [25.47005432]
# Chosen Sample [25.49711123]
# Chosen Sample [25.47811457]
# Chosen Sample [25.58298522]
# Chosen Sample [25.49566558]
# Chosen Sample [25.56938924]
# Chosen Sample [25.5612843]
# Chosen Sample [25.57962913]
# Chosen Sample [25.52963068]
# Chosen Sample [25.58219752]
# Chosen Sample [25.48993252]
# Chosen Sample [25.59867632]
# Chosen Sample [25.51434673]
# Chosen Sample [25.55619503]
# Chosen Sample [25.6090369]
# Chosen Sample [25.54345774]
# Chosen Sample [25.53631715]
# Chosen Sample [25.54265617]
# Chosen Sample [25.54278987]
# Chosen Sample [25.53923305]
# Chosen Sample [25.56343612]
# Chosen Sample [25.54929901]
# Chosen Sample [25.5186391]
# Chosen Sample [25.52676213]
# Chosen Sample [25.55933278]
# Chosen Sample [25.57735839]
# Chosen Sample [25.52096125]
# Chosen Sample [25.52334026]
# Chosen Sample [25.55142122]
# Chosen Sample [25.52166899]
# Chosen Sample [25.51985939]
# Chosen Sample [25.5418781]
# Chosen Sample [25.5425992]
# Chosen Sample [25.59360737]
# Chosen Sample [25.50240345]
# Chosen Sample [25.54173776]
# Chosen Sample [25.57716488]
# Chosen Sample [25.53516443]
# Chosen Sample [25.60218598]
# Chosen Sample [25.61959105]
# Chosen Sample [25.58074811]
# Chosen Sample [25.48311607]
# Chosen Sample [25.53455447]
# Chosen Sample [25.60671008]
# Chosen Sample [25.5751611]
# Chosen Sample [25.51730764]
# Chosen Sample [25.55550599]
# Chosen Sample [25.53543936]
# Chosen Sample [25.57399279]
# Chosen Sample [25.56659528]
# Chosen Sample [25.54383266]
# Chosen Sample [25.57613928]
# Chosen Sample [25.54438406]
# Chosen Sample [25.5160533]
# Chosen Sample [25.57150981]
# Chosen Sample [25.57796429]
# Chosen Sample [25.51869241]
# Chosen Sample [25.6207614]
# Chosen Sample [25.57276887]
# Chosen Sample [25.51330341]
# Chosen Sample [25.49115935]
# Chosen Sample [25.55449284]
# Chosen Sample [25.48275397]
# Chosen Sample [25.48149996]
# Chosen Sample [25.60040666]
# Chosen Sample [25.50308238]
# Chosen Sample [25.56279509]
# Chosen Sample [25.5045757]
# Chosen Sample [25.54396518]
# Chosen Sample [25.50880478]
# Chosen Sample [25.53839187]
# Chosen Sample [25.52450682]
# Chosen Sample [25.50533515]
# Chosen Sample [25.56462143]
# Chosen Sample [25.52454512]
# Chosen Sample [25.53461214]
# Chosen Sample [25.52356415]
# Chosen Sample [25.56787123]
# Chosen Sample [25.53029195]
# Chosen Sample [25.54373353]
# Chosen Sample [25.45770432]
# Chosen Sample [25.51266606]
# Chosen Sample [25.51696542]
# Chosen Sample [25.49987115]
# Chosen Sample [25.55818434]
# Chosen Sample [25.51624549]
# Chosen Sample [25.5085304]
# Chosen Sample [25.50542711]
# Chosen Sample [25.54438406]
# Chosen Sample [25.48372471]
# Chosen Sample [25.51474818]
# Chosen Sample [25.59360953]
# Chosen Sample [25.55973634]
# Chosen Sample [25.46137217]
# Chosen Sample [25.50693466]
# Chosen Sample [25.51462288]
# Chosen Sample [25.49436727]
# Chosen Sample [25.55860052]
# Chosen Sample [25.51197056]
# Chosen Sample [25.52915665]
# Chosen Sample [25.48628096]
# Chosen Sample [25.51397753]
# Chosen Sample [25.5144758]
# Chosen Sample [25.60221152]
# Chosen Sample [25.56227188]
# Chosen Sample [25.50489454]
# Chosen Sample [25.56287854]
# Chosen Sample [25.50194605]
# Chosen Sample [25.55909397]
# Chosen Sample [25.49862341]
# Chosen Sample [25.51383281]
# Chosen Sample [25.47514717]
# Chosen Sample [25.5739954]
# Chosen Sample [25.53847192]
# Chosen Sample [25.57178214]
# Chosen Sample [25.59362373]
# Chosen Sample [25.54974918]
# Chosen Sample [25.48941109]
# Chosen Sample [25.49585935]
# Chosen Sample [25.52456152]
# Chosen Sample [25.55177577]
# Chosen Sample [25.50956831]
# Chosen Sample [25.53257141]
# Chosen Sample [25.5660636]
# Chosen Sample [25.54314186]
# Chosen Sample [25.57308776]
# Chosen Sample [25.55452707]
# Chosen Sample [25.58199075]
# Chosen Sample [25.53854956]
# Chosen Sample [25.60300386]
# Chosen Sample [25.47625557]
# Chosen Sample [25.50817901]
# Chosen Sample [25.5564647]
# Chosen Sample [25.55416087]
# Chosen Sample [25.51437127]
# Chosen Sample [25.5655069]
# Chosen Sample [25.55893361]
# Chosen Sample [25.53325035]
# Chosen Sample [25.52419727]
# Chosen Sample [25.53614213]
# Chosen Sample [25.54383266]
# Chosen Sample [25.55641756]
# Chosen Sample [25.53853558]
# Chosen Sample [25.54544473]
# Chosen Sample [25.58101927]
# Chosen Sample [25.53490417]
# Chosen Sample [25.57372444]
# Chosen Sample [25.51407496]
# Chosen Sample [25.52284044]
# Chosen Sample [25.5381345]
# Chosen Sample [25.52632645]
# Chosen Sample [25.52247548]
# Chosen Sample [25.51441149]
# Chosen Sample [25.52368229]
# Chosen Sample [25.57474516]
# Chosen Sample [25.50168423]
# Chosen Sample [25.53436373]
# Chosen Sample [25.53862156]
# Chosen Sample [25.57570886]
# Chosen Sample [25.53252213]
# Chosen Sample [25.4805172]
# Chosen Sample [25.51486816]
# Chosen Sample [25.5192557]
# Chosen Sample [25.54490628]
# Chosen Sample [25.53152555]
# Chosen Sample [25.56485934]
# Chosen Sample [25.51501591]
# Chosen Sample [25.48971684]
# Chosen Sample [25.52851711]
# Chosen Sample [25.5865902]
# Chosen Sample [25.51146186]
# Chosen Sample [25.50562056]
# Chosen Sample [25.57755704]
# Chosen Sample [25.51345398]
# Chosen Sample [25.55849215]
# Chosen Sample [25.58472854]
# Chosen Sample [25.47435118]
# Chosen Sample [25.59543374]
# Chosen Sample [25.5198723]
# Chosen Sample [25.49746028]
# Chosen Sample [25.53816592]
# Chosen Sample [25.54829119]
# Chosen Sample [25.50961201]
# Chosen Sample [25.51479346]
# Chosen Sample [25.56281393]
# Chosen Sample [25.57276304]
# Chosen Sample [25.62305085]
# Chosen Sample [25.52363567]
# Chosen Sample [25.53430218]
# Chosen Sample [25.54752523]
# Chosen Sample [25.51182889]
# Chosen Sample [25.56506376]
# Chosen Sample [25.56130805]
# Chosen Sample [25.55599859]
# Chosen Sample [25.50006077]
# Chosen Sample [25.53372069]
# Chosen Sample [25.52177608]
# Chosen Sample [25.4953073]
# Chosen Sample [25.48672878]
# Chosen Sample [25.5381431]
# Chosen Sample [25.55515202]
# Chosen Sample [25.53547509]
# Chosen Sample [25.4943962]
# Chosen Sample [25.55541089]
# Chosen Sample [25.55137753]
# Chosen Sample [25.52784566]
# Chosen Sample [25.50345491]
# Chosen Sample [25.5525224]
# Chosen Sample [25.58031144]
# Chosen Sample [25.48882161]
# Chosen Sample [25.54814223]
# Chosen Sample [25.57042072]
# Chosen Sample [25.54574055]
# Chosen Sample [25.49265451]
# Chosen Sample [25.51494436]
# Chosen Sample [25.557172]
# Chosen Sample [25.60606963]
# Chosen Sample [25.52268362]
# Chosen Sample [25.55167196]
# Chosen Sample [25.47509029]
# Chosen Sample [25.57153309]
# Chosen Sample [25.56254509]
# Chosen Sample [25.52994073]
# Chosen Sample [25.51500537]
# Chosen Sample [25.54235623]
# Chosen Sample [25.5607624]
# Chosen Sample [25.57656354]
# Chosen Sample [25.5536166]
# Chosen Sample [25.54768884]
# Chosen Sample [25.53491326]
# Chosen Sample [25.63664159]
# Chosen Sample [25.60352417]
# Chosen Sample [25.52205952]
# Chosen Sample [25.58736351]
# Chosen Sample [25.4919405]
# Chosen Sample [25.51362448]
# Chosen Sample [25.56038321]
# Chosen Sample [25.54027268]
# Chosen Sample [25.54195728]
# Chosen Sample [25.54120134]
# Chosen Sample [25.53611801]
# Chosen Sample [25.55688323]
# Chosen Sample [25.51217099]
# Chosen Sample [25.51397753]
# Chosen Sample [25.50213179]
# Chosen Sample [25.50671549]
# Chosen Sample [25.56793556]
# Chosen Sample [25.47967249]
# Chosen Sample [25.45734209]
# Chosen Sample [25.5783569]
# Chosen Sample [25.53125042]
# Chosen Sample [25.57696115]
# Chosen Sample [25.60471762]
# Chosen Sample [25.51337673]
# Chosen Sample [25.55428016]
# Chosen Sample [25.58578684]
# Chosen Sample [25.50707076]
# Chosen Sample [25.52099097]
# Chosen Sample [25.53092531]
# Chosen Sample [25.58118728]
# Chosen Sample [25.47539434]
# Chosen Sample [25.52048854]
# Chosen Sample [25.61098075]
# Chosen Sample [25.45097482]
# Chosen Sample [25.58665012]
# Chosen Sample [25.53262837]
# Chosen Sample [25.56826026]
# Chosen Sample [25.52702794]
# Chosen Sample [25.57468217]
# Chosen Sample [25.52239575]
# Chosen Sample [25.50307105]
# Chosen Sample [25.48898952]
# Chosen Sample [25.61432757]
# Chosen Sample [25.50531391]
# Chosen Sample [25.45770432]
# Chosen Sample [25.5386713]
# Chosen Sample [25.53845426]
# Chosen Sample [25.48374216]
# Chosen Sample [25.51663235]
# Chosen Sample [25.55107315]
# Chosen Sample [25.52339189]
# Chosen Sample [25.46203989]
# Chosen Sample [25.59498606]
# Chosen Sample [25.5182458]
# Chosen Sample [25.53440392]
# Chosen Sample [25.5466712]
# Chosen Sample [25.61554699]
# Chosen Sample [25.52935703]
# Chosen Sample [25.56088671]
# Chosen Sample [25.52203026]
# Chosen Sample [25.59602766]
# Chosen Sample [25.51031012]
# Chosen Sample [25.55071857]
# Chosen Sample [25.56082226]
# Chosen Sample [25.47033338]
# Chosen Sample [25.53199103]
# Chosen Sample [25.51642749]
# Chosen Sample [25.52256285]
# Chosen Sample [25.54074335]
# Chosen Sample [25.55281253]
# Chosen Sample [25.56422298]
# Chosen Sample [25.54422128]
# Chosen Sample [25.53487116]
# Chosen Sample [25.5317905]
# Chosen Sample [25.49458998]
# Chosen Sample [25.53914258]
# Chosen Sample [25.49676286]
# Chosen Sample [25.59917518]
# Chosen Sample [25.56132082]
# Chosen Sample [25.65110618]
# Chosen Sample [25.58946515]
# Chosen Sample [25.54298203]
# Chosen Sample [25.49249588]
# Chosen Sample [25.55953365]
# Chosen Sample [25.54823545]
# Chosen Sample [25.57726552]
# Chosen Sample [25.53149062]
# Chosen Sample [25.49155926]
# Chosen Sample [25.5879168]
# Chosen Sample [25.5866728]
# Chosen Sample [25.5111039]
# Chosen Sample [25.55035309]
# Chosen Sample [25.5631765]
# Chosen Sample [25.55203547]
# Chosen Sample [25.55343589]
# Chosen Sample [25.51824226]
# Chosen Sample [25.4770421]
# Chosen Sample [25.49026685]
# Chosen Sample [25.62167078]
# Chosen Sample [25.51793002]
# Chosen Sample [25.5519343]
# Chosen Sample [25.58001328]
# Chosen Sample [25.54160572]
# Chosen Sample [25.54209859]
# Chosen Sample [25.5095969]
# Chosen Sample [25.51514288]
# Chosen Sample [25.58451981]
# Chosen Sample [25.50196126]
# Chosen Sample [25.51408241]
# Chosen Sample [25.54395931]
# Chosen Sample [25.51440695]
# Chosen Sample [25.52816349]
# Chosen Sample [25.48151214]
# ...
# Chosen Sample [25.54276766]
# Chosen Sample [25.56871428]
# Chosen Sample [25.568548]
# Chosen Sample [25.5681159]
# Chosen Sample [25.56101589]
# Chosen Sample [25.52668374]
# Chosen Sample [25.60003797]
# Chosen Sample [25.52995591]
# Chosen Sample [25.56340343]
# Chosen Sample [25.46752702]
# Chosen Sample [25.52046008]
# Chosen Sample [25.54616837]
# Chosen Sample [25.51472522]
# Chosen Sample [25.56114633]
# Chosen Sample [25.49567938]
# Chosen Sample [25.5301895]
# Chosen Sample [25.58101099]
# Chosen Sample [25.52605047]
# Chosen Sample [25.50531391]
# Chosen Sample [25.54794576]
# Chosen Sample [25.55571051]
# Chosen Sample [25.46525278]
# Chosen Sample [25.53671627]
# Chosen Sample [25.62684756]
# Chosen Sample [25.61427664]
# Chosen Sample [25.58125371]
# Chosen Sample [25.51900448]
# Chosen Sample [25.60318383]
# Chosen Sample [25.54462535]
# Chosen Sample [25.508226]
# Chosen Sample [25.62786952]
# Chosen Sample [25.57079365]
# Chosen Sample [25.59047322]
# Chosen Sample [25.54352036]
# Chosen Sample [25.5714634]
# Chosen Sample [25.51828996]
# Chosen Sample [25.54095102]
# Chosen Sample [25.47416183]
# Chosen Sample [25.52349011]
# Chosen Sample [25.54598858]
# Chosen Sample [25.50194605]
# Chosen Sample [25.55933469]
# Chosen Sample [25.51144036]
# Chosen Sample [25.54083389]
# Chosen Sample [25.53228408]
# Chosen Sample [25.54762934]
# Chosen Sample [25.55787751]
# Chosen Sample [25.54345774]
# Chosen Sample [25.54312054]
# Chosen Sample [25.55662079]
# Chosen Sample [25.54142303]
# Chosen Sample [25.59628789]
# Chosen Sample [25.53023445]
# Chosen Sample [25.5552654]
# Chosen Sample [25.50037234]
# Chosen Sample [25.57439122]
# Chosen Sample [25.53391934]
# Chosen Sample [25.48136364]
# Chosen Sample [25.51948508]
# Chosen Sample [25.53973864]
# Chosen Sample [25.58907283]
# Chosen Sample [25.56259217]
# Chosen Sample [25.62959798]
# Chosen Sample [25.53334412]
# Chosen Sample [25.55900924]
# Chosen Sample [25.46035147]
# Chosen Sample [25.57986308]
# Chosen Sample [25.51727259]
# Chosen Sample [25.52247548]
# Chosen Sample [25.50504024]
# Chosen Sample [25.5614869]
# Chosen Sample [25.53565614]
# Chosen Sample [25.52656926]
# Chosen Sample [25.63041421]
# Chosen Sample [25.48823681]
# Chosen Sample [25.50220067]
# Chosen Sample [25.51095394]
# Chosen Sample [25.50908034]
# Chosen Sample [25.57962913]
# Chosen Sample [25.54083389]
# Chosen Sample [25.57398721]
# Chosen Sample [25.55693481]
# Chosen Sample [25.57247015]
# Chosen Sample [25.60296467]
# Chosen Sample [25.54761744]
# Chosen Sample [25.46129168]
# Chosen Sample [25.50320773]
# Chosen Sample [25.60471877]
# Chosen Sample [25.52212209]
# Chosen Sample [25.54468171]
# Chosen Sample [25.57877679]
# Chosen Sample [25.53298463]
# Chosen Sample [25.58516909]
# Chosen Sample [25.55877188]
# Chosen Sample [25.46917122]
# Chosen Sample [25.47087372]
# Chosen Sample [25.56556446]
# Chosen Sample [25.57476364]
# Chosen Sample [25.5525224]
# Chosen Sample [25.54005329]
# Chosen Sample [25.51905014]
# Chosen Sample [25.57770211]
# Chosen Sample [25.52203808]
# Chosen Sample [25.49799811]
# Chosen Sample [25.58169483]
# Chosen Sample [25.51881126]
# Chosen Sample [25.49741137]
# Chosen Sample [25.52993748]
# Chosen Sample [25.57263836]
# Chosen Sample [25.48436194]
# Chosen Sample [25.53294349]
# Chosen Sample [25.54256625]
# Chosen Sample [25.53987796]
# Chosen Sample [25.53289385]
# Chosen Sample [25.50253265]
# Chosen Sample [25.57879384]
# Chosen Sample [25.54786997]
# Chosen Sample [25.5564647]
# Chosen Sample [25.53316451]
# Chosen Sample [25.50751564]
# Chosen Sample [25.60872923]
# Chosen Sample [25.52217873]
# Chosen Sample [25.54038748]
# Chosen Sample [25.5532477]
# Chosen Sample [25.56801757]
# Chosen Sample [25.58263662]
# Chosen Sample [25.50925512]
# Chosen Sample [25.48220052]
# Chosen Sample [25.52205952]
# Chosen Sample [25.56024937]
# Chosen Sample [25.53601015]
# Chosen Sample [25.51190186]
# Chosen Sample [25.54716549]
# Chosen Sample [25.55811534]
# Chosen Sample [25.50807289]
# Chosen Sample [25.52302734]
# Chosen Sample [25.51766505]
# Chosen Sample [25.53911236]
# Chosen Sample [25.53130683]
# Chosen Sample [25.53943979]
# Chosen Sample [25.5399889]
# Chosen Sample [25.59658342]
# Chosen Sample [25.54802763]
# Chosen Sample [25.54353841]
# Chosen Sample [25.553963]
# Chosen Sample [25.53605309]
# Chosen Sample [25.48739393]
# Chosen Sample [25.58564548]
# Chosen Sample [25.50101742]
# Chosen Sample [25.53794323]
# Chosen Sample [25.53057386]
# Chosen Sample [25.53586777]
# Chosen Sample [25.60381081]
# Chosen Sample [25.50101742]
# Chosen Sample [25.51928094]
# Chosen Sample [25.54038748]
# Chosen Sample [25.51087574]
# Chosen Sample [25.58711549]
# Chosen Sample [25.58074437]
# Chosen Sample [25.49283834]
# Chosen Sample [25.52915011]
# Chosen Sample [25.53389062]
# Chosen Sample [25.56505788]
# Chosen Sample [25.5623464]
# Chosen Sample [25.55025651]
# Chosen Sample [25.49871218]
# Chosen Sample [25.49647964]
# Chosen Sample [25.48478182]
# Chosen Sample [25.53440203]
# Chosen Sample [25.56374095]
# Chosen Sample [25.5509285]
# Chosen Sample [25.58006426]
# Chosen Sample [25.60019557]
# Chosen Sample [25.44865099]
# Chosen Sample [25.61562927]
# Chosen Sample [25.56286857]
# Chosen Sample [25.58865114]
# Chosen Sample [25.58548605]
# Chosen Sample [25.56438]
# Chosen Sample [25.54716549]
# Chosen Sample [25.52196421]
# Chosen Sample [25.59085444]
# Chosen Sample [25.49360679]
# Chosen Sample [25.43427538]
# Chosen Sample [25.56505788]
# Chosen Sample [25.51182107]
# Chosen Sample [25.49725126]
# Chosen Sample [25.58255443]
# Chosen Sample [25.52649234]
# Chosen Sample [25.53525763]
# Chosen Sample [25.43285035]
# Chosen Sample [25.51879364]
# Chosen Sample [25.55979048]
# Chosen Sample [25.53679689]
# Chosen Sample [25.51433609]
# Chosen Sample [25.53790005]
# Chosen Sample [25.48214984]
# Chosen Sample [25.57069976]
# Chosen Sample [25.52346878]
# Chosen Sample [25.56280598]
# Chosen Sample [25.56609676]
# Chosen Sample [25.58036998]
# Chosen Sample [25.50980128]
# Chosen Sample [25.55637205]
# Chosen Sample [25.51420114]
# Chosen Sample [25.55770013]
# Chosen Sample [25.54864008]
# Chosen Sample [25.50116037]
# Chosen Sample [25.53769651]
# Chosen Sample [25.51218459]
# Chosen Sample [25.50756241]
# Chosen Sample [25.499324]
# Chosen Sample [25.56518315]
# Chosen Sample [25.59611115]
# Chosen Sample [25.56180399]
# Chosen Sample [25.51617581]
# Chosen Sample [25.50955699]
# Chosen Sample [25.49028969]
# Chosen Sample [25.47344373]
# Chosen Sample [25.55908002]
# Chosen Sample [25.54261203]
# Chosen Sample [25.54741681]
# Chosen Sample [25.51407496]
# Chosen Sample [25.50678961]
# Chosen Sample [25.53107444]
# Chosen Sample [25.49676286]
# Chosen Sample [25.51443833]
# Chosen Sample [25.53336581]
# Chosen Sample [25.53715375]
# Chosen Sample [25.49695546]
# Chosen Sample [25.50699158]
# Chosen Sample [25.51999346]
# Chosen Sample [25.51879364]
# Chosen Sample [25.54700947]
# Chosen Sample [25.53803731]
# Chosen Sample [25.51062245]
# Chosen Sample [25.55194594]
# Chosen Sample [25.61451609]
# Chosen Sample [25.55469151]
# Chosen Sample [25.49235557]
# Chosen Sample [25.53425083]
# Chosen Sample [25.56752338]
# Chosen Sample [25.51501371]
# Chosen Sample [25.53782917]
# Chosen Sample [25.53780298]
# Chosen Sample [25.57173366]
# Chosen Sample [25.60420862]
# Chosen Sample [25.49219467]
# Chosen Sample [25.5383802]
# Chosen Sample [25.53525835]
# Chosen Sample [25.60368893]
# Chosen Sample [25.58701753]
# Chosen Sample [25.53119454]
# Chosen Sample [25.4574056]
# Chosen Sample [25.49729227]
# Chosen Sample [25.55117662]
# Chosen Sample [25.5108294]
# Chosen Sample [25.51642749]
# Chosen Sample [25.53332611]
# Chosen Sample [25.52618568]
# Chosen Sample [25.57236467]
# Chosen Sample [25.57237494]
# Chosen Sample [25.51332721]
# Chosen Sample [25.53433197]
# Chosen Sample [25.55965951]
# Chosen Sample [25.55928566]
# Chosen Sample [25.51472344]
# Chosen Sample [25.50196126]
# Chosen Sample [25.55207824]
# Chosen Sample [25.59240715]
# Chosen Sample [25.53272267]
# Chosen Sample [25.55982018]
# Chosen Sample [25.55993195]
# Chosen Sample [25.5339752]
# Chosen Sample [25.57714642]
# Chosen Sample [25.54853047]
# Chosen Sample [25.51365995]
# Chosen Sample [25.56320225]
# Chosen Sample [25.59711408]
# Chosen Sample [25.54235623]
# Chosen Sample [25.48248575]
# Chosen Sample [25.49845122]
# Chosen Sample [25.58438764]
# Chosen Sample [25.5396834]
# Chosen Sample [25.5882114]
# Chosen Sample [25.63174972]
# Chosen Sample [25.48742168]
# Chosen Sample [25.53313448]
# Chosen Sample [25.52383598]
# Chosen Sample [25.55533873]
# Chosen Sample [25.564707]
# Chosen Sample [25.4513783]
# Chosen Sample [25.51720395]
# Chosen Sample [25.53978155]
# Chosen Sample [25.56841305]
# Chosen Sample [25.56246867]
# Chosen Sample [25.56232762]
# Chosen Sample [25.53880563]
# Chosen Sample [25.56073349]
# Chosen Sample [25.56267045]
# Chosen Sample [25.54999116]
# Chosen Sample [25.56365775]
# Chosen Sample [25.49436727]
# Chosen Sample [25.52667812]
# Chosen Sample [25.52855273]
# Chosen Sample [25.55687367]
# Chosen Sample [25.50298453]
# Chosen Sample [25.56285537]
# Chosen Sample [25.5424534]
# Chosen Sample [25.54550856]
# Chosen Sample [25.57276887]
# Chosen Sample [25.51321116]
# Chosen Sample [25.61192173]
# Chosen Sample [25.49034869]
# Chosen Sample [25.54329802]
# Chosen Sample [25.57654459]
# Chosen Sample [25.53514837]
# Chosen Sample [25.53703077]
# Chosen Sample [25.52728302]
# Chosen Sample [25.59656647]
# Chosen Sample [25.50078836]
# Chosen Sample [25.58181597]
# Chosen Sample [25.56238369]
# Chosen Sample [25.53135055]
# Chosen Sample [25.48325755]
# Chosen Sample [25.51544931]
# Chosen Sample [25.52399648]
# Chosen Sample [25.49055305]
# Chosen Sample [25.57108029]
# Chosen Sample [25.46951689]
# Chosen Sample [25.49250396]
# Chosen Sample [25.5966901]
# Chosen Sample [25.53700822]
# Chosen Sample [25.53601015]
# Chosen Sample [25.51394099]
# Chosen Sample [25.56772221]
# Chosen Sample [25.55128777]
# Chosen Sample [25.50253265]
# Chosen Sample [25.49804283]
# Chosen Sample [25.46248469]
# Chosen Sample [25.50282784]
# Chosen Sample [25.52256285]
# Chosen Sample [25.54135828]
# Chosen Sample [25.55804599]
# Chosen Sample [25.54212226]
# Chosen Sample [25.47518836]
# Chosen Sample [25.58757032]
# Chosen Sample [25.52768345]
# Chosen Sample [25.53309892]
# Chosen Sample [25.54119412]
# Chosen Sample [25.57901777]
# Chosen Sample [25.5662002]
# Chosen Sample [25.56101343]
# Chosen Sample [25.54864008]
# Chosen Sample [25.56495827]
# Chosen Sample [25.52073906]
# Chosen Sample [25.5898968]
# Chosen Sample [25.50326868]
# Chosen Sample [25.58350568]
# Chosen Sample [25.537457]
# Chosen Sample [25.50513601]
# Chosen Sample [25.51714073]
# Chosen Sample [25.55307497]
# Chosen Sample [25.53454161]
# Chosen Sample [25.57106224]
# Chosen Sample [25.55910094]
# Chosen Sample [25.52772253]
# Chosen Sample [25.52907157]
# Chosen Sample [25.50012815]
# Chosen Sample [25.52618756]
# Chosen Sample [25.61368902]
# Chosen Sample [25.48022079]
# Chosen Sample [25.49060206]
# Chosen Sample [25.50512283]
# Chosen Sample [25.5007181]
# Chosen Sample [25.52543726]
# Chosen Sample [25.55531863]
# Chosen Sample [25.55110204]
# Chosen Sample [25.50585154]
# Chosen Sample [25.58254618]
# Chosen Sample [25.52775111]
# Chosen Sample [25.55338421]
# Chosen Sample [25.50807098]
# Chosen Sample [25.52808808]
# Chosen Sample [25.57069976]
# Chosen Sample [25.49167039]
# Chosen Sample [25.51346276]
# Chosen Sample [25.54627084]
# Chosen Sample [25.5735314]
# Chosen Sample [25.57397233]
# Chosen Sample [25.59494528]
# Chosen Sample [25.57002047]
# Chosen Sample [25.51062504]
# Chosen Sample [25.54077213]
# Chosen Sample [25.55934012]
# Chosen Sample [25.62933651]
# Chosen Sample [25.52951809]
# Chosen Sample [25.52813729]
# Chosen Sample [25.45563549]
# Chosen Sample [25.54497878]
# Chosen Sample [25.56888347]
# Chosen Sample [25.62635033]
# Chosen Sample [25.55606599]
# Chosen Sample [25.49532647]
# Chosen Sample [25.49235557]
# Chosen Sample [25.5178831]
# Chosen Sample [25.48318234]
# Chosen Sample [25.47808321]
# Chosen Sample [25.46165804]
# Chosen Sample [25.46663153]
# Chosen Sample [25.48110872]
# Chosen Sample [25.52039467]
# Chosen Sample [25.4863277]
# Chosen Sample [25.52623832]
# Chosen Sample [25.58147545]
# Chosen Sample [25.48149996]
# Chosen Sample [25.49331092]
# Chosen Sample [25.55497425]
# Chosen Sample [25.49077646]
# Chosen Sample [25.53155582]
# Chosen Sample [25.56431288]
# Chosen Sample [25.63285403]
# Chosen Sample [25.6236954]
# Chosen Sample [25.4963367]
# Chosen Sample [25.58556146]
# Chosen Sample [25.53352549]
# Chosen Sample [25.52216602]
# Chosen Sample [25.53277737]
# Chosen Sample [25.46211264]
# Chosen Sample [25.56624361]
# Chosen Sample [25.54827274]
# Chosen Sample [25.5866728]
# Chosen Sample [25.54242037]
# Chosen Sample [25.58240048]
# Chosen Sample [25.45245813]
# Chosen Sample [25.56806583]
# Chosen Sample [25.56866323]
# Chosen Sample [25.44965843]
# Chosen Sample [25.52569444]
# Chosen Sample [25.50462443]
# Chosen Sample [25.55229927]
# Chosen Sample [25.54433154]
# Chosen Sample [25.56062264]
# Chosen Sample [25.47937782]
# Chosen Sample [25.55770013]
# Chosen Sample [25.54223374]
# Chosen Sample [25.54179773]
# Chosen Sample [25.52830853]
# Chosen Sample [25.57004962]
# Chosen Sample [25.55969898]
# Chosen Sample [25.52002788]
# Chosen Sample [25.48875283]
# Chosen Sample [25.58240048]
# Chosen Sample [25.51315985]
# Chosen Sample [25.51323691]
# Chosen Sample [25.57879005]
# Chosen Sample [25.44092807]
# Chosen Sample [25.55661364]
# Chosen Sample [25.62934058]
# Chosen Sample [25.5190105]
# Chosen Sample [25.48022079]
# Chosen Sample [25.58774204]
# Chosen Sample [25.51537296]
# Chosen Sample [25.57210978]
# Chosen Sample [25.56488457]
# Chosen Sample [25.53695493]
# Chosen Sample [25.54359037]
# Chosen Sample [25.63204864]
# Chosen Sample [25.54211249]
# Chosen Sample [25.52091875]
# Chosen Sample [25.59071285]
# Chosen Sample [25.4943962]
# Chosen Sample [25.54501742]
# Chosen Sample [25.52580458]
# Chosen Sample [25.52296786]
# Chosen Sample [25.50765258]
# Chosen Sample [25.5500544]
# Chosen Sample [25.48971684]
# Chosen Sample [25.50168423]
# Chosen Sample [25.52934873]
# Chosen Sample [25.54132282]
# Chosen Sample [25.55129196]
# Chosen Sample [25.53063201]
# Chosen Sample [25.52352059]
# Chosen Sample [25.51462288]
# Chosen Sample [25.59231781]
# Chosen Sample [25.59867632]
# Chosen Sample [25.53861472]
# Chosen Sample [25.54119412]
# Chosen Sample [25.57859794]
# Chosen Sample [25.54239782]
# Chosen Sample [25.51824226]
# Chosen Sample [25.53808615]
# Chosen Sample [25.56013137]
# Chosen Sample [25.51891539]
# Chosen Sample [25.63893738]
# Chosen Sample [25.58671597]
# Chosen Sample [25.49853674]
# Chosen Sample [25.5295001]
# Chosen Sample [25.54413871]
# Chosen Sample [25.53201764]
# Chosen Sample [25.51905206]
# Chosen Sample [25.52632645]
# Chosen Sample [25.5140197]
# Chosen Sample [25.58798567]
# Chosen Sample [25.46106965]
# Chosen Sample [25.50742662]
# Chosen Sample [25.45638065]
# Chosen Sample [25.53340807]
# Chosen Sample [25.52193237]
# Chosen Sample [25.5845099]
# Chosen Sample [25.48755139]
# Chosen Sample [25.54852788]
# Chosen Sample [25.56513643]
# Chosen Sample [25.5566952]
# Chosen Sample [25.59300716]
# Chosen Sample [25.50386336]
# Chosen Sample [25.53589916]
# Chosen Sample [25.53593801]
# Chosen Sample [25.57711287]
# Chosen Sample [25.53674872]
# Chosen Sample [25.52553515]
# Chosen Sample [25.64293926]
# Chosen Sample [25.50822538]
# Chosen Sample [25.5668567]
# Chosen Sample [25.49513712]
# Chosen Sample [25.48776288]
# Chosen Sample [25.57383874]
# Chosen Sample [25.59159414]
# Chosen Sample [25.60372897]
# Chosen Sample [25.48706505]
# Chosen Sample [25.51913457]
# Chosen Sample [25.57955909]
# Chosen Sample [25.58457393]
# Chosen Sample [25.4632514]
# Chosen Sample [25.56939613]
# Chosen Sample [25.4721714]
# Chosen Sample [25.52301545]
# Chosen Sample [25.60908464]
# Chosen Sample [25.59472195]
# Chosen Sample [25.54254729]
# Chosen Sample [25.51501591]
# Chosen Sample [25.54744071]
# Chosen Sample [25.58580305]
# Chosen Sample [25.55140022]
# Chosen Sample [25.54625313]
# Chosen Sample [25.54299561]
# Chosen Sample [25.5395105]
# Chosen Sample [25.52062213]
# Chosen Sample [25.61785569]
# Chosen Sample [25.56600535]
# Chosen Sample [25.51614082]
# Chosen Sample [25.49762372]
# Chosen Sample [25.57703526]
# Chosen Sample [25.54471644]
# Chosen Sample [25.55040134]
# Chosen Sample [25.45893452]
# Chosen Sample [25.54393845]
# Chosen Sample [25.54670556]
# Chosen Sample [25.57067673]
# Chosen Sample [25.45579968]
# Chosen Sample [25.5795893]
# Chosen Sample [25.52035238]
# Chosen Sample [25.5042855]
# Chosen Sample [25.47595249]
# Chosen Sample [25.51099943]
# Chosen Sample [25.58443247]
# Chosen Sample [25.47745899]
# Chosen Sample [25.55367659]
# Chosen Sample [25.57173366]
# Chosen Sample [25.56230097]
# Chosen Sample [25.53257283]
# Chosen Sample [25.60671008]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                 scale         chosen_sample  \
# 0  0.001248  [0.5702749144493938]  [25.538380195764756]
# 1  0.001248  [0.5702749144493938]   [25.52479820141936]
# 2  0.001248  [0.5702749144493938]  [25.608580616273862]
# 3  0.001248  [0.5702749144493938]   [25.55112853088255]
# 4  0.001248  [0.5702749144493938]  [25.512695642763415]
#
#             chosen_noise               release
# 0  [0.08645201902029975]  [25.624832214785055]
# 1    [1.706679076740098]   [27.23147727815946]
# 2  [-1.1334683678626996]   [24.47511224841116]
# 3   [0.0925682013125626]  [25.643696732195114]
# 4   [0.2829451795146851]    [25.7956408222781]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi     scale chosen_sample chosen_noise    release
# query             avg_qty       avg_qty      avg_qty    avg_qty
# 0      0.001248  0.570275     25.538380     0.086452  25.624832
# 1      0.001248  0.570275     25.524798     1.706679  27.231477
# 2      0.001248  0.570275     25.608581    -1.133468  24.475112
# 3      0.001248  0.570275     25.551129     0.092568  25.643697
# 4      0.001248  0.570275     25.512696     0.282945  25.795641

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71998/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step          scale chosen_sample chosen_noise    release
# query       avg_qty       avg_qty      avg_qty    avg_qty
# mi
# 0.001248   0.570275     25.538142    -0.017829  25.520313
# 0.015625   0.045561     25.537356     0.009800  25.547156
# 0.031250   0.022780     25.539039    -0.006430  25.532609
# 0.062500   0.011390     25.537363     0.000303  25.537665
# 0.250000   0.002848     25.537718    -0.001761  25.535957
# 1.000000   0.000712     25.539808    -0.001522  25.538286
# 2.000000   0.000356     25.537326     0.000929  25.538254
# 4.000000   0.000178     25.538803     0.000863  25.539666
# 16.000000  0.000044     25.537056     0.000022  25.537078

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['avg_qty'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi          0.001248
# avg_qty    25.624832
# Name: 0, dtype: float64
# mi          0.001248
# avg_qty    27.231477
# Name: 1, dtype: float64
# mi          0.001248
# avg_qty    24.475112
# Name: 2, dtype: float64
# mi          0.001248
# avg_qty    25.643697
# Name: 3, dtype: float64
# mi          0.001248
# avg_qty    25.795641
# Name: 4, dtype: float64
# mi          0.001248
# avg_qty    25.552467
# Name: 5, dtype: float64
# mi          0.001248
# avg_qty    25.309899
# Name: 6, dtype: float64
# mi          0.001248
# avg_qty    26.030789
# Name: 7, dtype: float64
# mi          0.001248
# avg_qty    26.874112
# Name: 8, dtype: float64
# mi          0.001248
# avg_qty    24.827581
# Name: 9, dtype: float64
# mi          0.001248
# avg_qty    25.304521
# Name: 10, dtype: float64
# mi          0.001248
# avg_qty    24.507254
# Name: 11, dtype: float64
# mi          0.001248
# avg_qty    25.106848
# Name: 12, dtype: float64
# mi          0.001248
# avg_qty    25.830987
# Name: 13, dtype: float64
# mi          0.001248
# avg_qty    25.313318
# Name: 14, dtype: float64
# mi          0.001248
# avg_qty    25.787895
# Name: 15, dtype: float64
# mi          0.001248
# avg_qty    26.934665
# Name: 16, dtype: float64
# mi          0.001248
# avg_qty    25.642286
# Name: 17, dtype: float64
# mi          0.001248
# avg_qty    25.655442
# Name: 18, dtype: float64
# mi          0.001248
# avg_qty    25.621673
# Name: 19, dtype: float64
# mi          0.001248
# avg_qty    26.455436
# Name: 20, dtype: float64
# mi          0.001248
# avg_qty    24.761941
# Name: 21, dtype: float64
# mi          0.001248
# avg_qty    23.278936
# Name: 22, dtype: float64
# mi          0.001248
# avg_qty    26.296731
# Name: 23, dtype: float64
# mi          0.001248
# avg_qty    25.318610
# Name: 24, dtype: float64
# mi          0.001248
# avg_qty    25.390938
# Name: 25, dtype: float64
# mi          0.001248
# avg_qty    25.677990
# Name: 26, dtype: float64
# mi          0.001248
# avg_qty    24.452162
# Name: 27, dtype: float64
# mi          0.001248
# avg_qty    26.516983
# Name: 28, dtype: float64
# mi          0.001248
# avg_qty    25.412490
# Name: 29, dtype: float64
# mi          0.001248
# avg_qty    24.432700
# Name: 30, dtype: float64
# mi          0.001248
# avg_qty    24.980988
# Name: 31, dtype: float64
# mi          0.001248
# avg_qty    24.077496
# Name: 32, dtype: float64
# mi          0.001248
# avg_qty    24.194189
# Name: 33, dtype: float64
# mi          0.001248
# avg_qty    24.504811
# Name: 34, dtype: float64
# mi          0.001248
# avg_qty    25.012752
# Name: 35, dtype: float64
# mi          0.001248
# avg_qty    25.094422
# Name: 36, dtype: float64
# mi          0.001248
# avg_qty    25.075054
# Name: 37, dtype: float64
# mi          0.001248
# avg_qty    25.128025
# Name: 38, dtype: float64
# mi          0.001248
# avg_qty    25.481964
# Name: 39, dtype: float64
# mi          0.001248
# avg_qty    25.901089
# Name: 40, dtype: float64
# mi          0.001248
# avg_qty    27.028550
# Name: 41, dtype: float64
# mi          0.001248
# avg_qty    25.965627
# Name: 42, dtype: float64
# mi          0.001248
# avg_qty    24.813542
# Name: 43, dtype: float64
# mi          0.001248
# avg_qty    26.201717
# Name: 44, dtype: float64
# mi          0.001248
# avg_qty    26.412118
# Name: 45, dtype: float64
# mi          0.001248
# avg_qty    26.092013
# Name: 46, dtype: float64
# mi          0.001248
# avg_qty    26.164622
# Name: 47, dtype: float64
# mi          0.001248
# avg_qty    25.194247
# Name: 48, dtype: float64
# mi          0.001248
# avg_qty    25.356032
# Name: 49, dtype: float64
# mi          0.001248
# avg_qty    24.481283
# Name: 50, dtype: float64
# mi          0.001248
# avg_qty    25.025856
# Name: 51, dtype: float64
# mi          0.001248
# avg_qty    26.415682
# Name: 52, dtype: float64
# mi          0.001248
# avg_qty    25.228981
# Name: 53, dtype: float64
# mi          0.001248
# avg_qty    25.515121
# Name: 54, dtype: float64
# mi          0.001248
# avg_qty    24.566866
# Name: 55, dtype: float64
# mi          0.001248
# avg_qty    25.659191
# Name: 56, dtype: float64
# mi          0.001248
# avg_qty    26.888495
# Name: 57, dtype: float64
# mi          0.001248
# avg_qty    24.592281
# Name: 58, dtype: float64
# mi          0.001248
# avg_qty    25.837880
# Name: 59, dtype: float64
# mi          0.001248
# avg_qty    25.408388
# Name: 60, dtype: float64
# mi          0.001248
# avg_qty    25.875030
# Name: 61, dtype: float64
# mi          0.001248
# avg_qty    24.305378
# Name: 62, dtype: float64
# mi          0.001248
# avg_qty    24.891842
# Name: 63, dtype: float64
# mi          0.001248
# avg_qty    25.904721
# Name: 64, dtype: float64
# mi          0.001248
# avg_qty    26.318770
# Name: 65, dtype: float64
# mi          0.001248
# avg_qty    25.141155
# Name: 66, dtype: float64
# mi          0.001248
# avg_qty    26.434130
# Name: 67, dtype: float64
# mi          0.001248
# avg_qty    26.046110
# Name: 68, dtype: float64
# mi          0.001248
# avg_qty    25.123468
# Name: 69, dtype: float64
# mi          0.001248
# avg_qty    26.043045
# Name: 70, dtype: float64
# mi          0.001248
# avg_qty    26.230708
# Name: 71, dtype: float64
# mi          0.001248
# avg_qty    25.673926
# Name: 72, dtype: float64
# mi          0.001248
# avg_qty    25.494259
# Name: 73, dtype: float64
# mi          0.001248
# avg_qty    25.199161
# Name: 74, dtype: float64
# mi          0.001248
# avg_qty    24.698019
# Name: 75, dtype: float64
# mi          0.001248
# avg_qty    26.764589
# Name: 76, dtype: float64
# mi          0.001248
# avg_qty    23.265065
# Name: 77, dtype: float64
# mi          0.001248
# avg_qty    24.564039
# Name: 78, dtype: float64
# mi          0.001248
# avg_qty    24.916948
# Name: 79, dtype: float64
# mi          0.001248
# avg_qty    26.579306
# Name: 80, dtype: float64
# mi          0.001248
# avg_qty    26.447390
# Name: 81, dtype: float64
# mi          0.001248
# avg_qty    26.171401
# Name: 82, dtype: float64
# mi          0.001248
# avg_qty    26.681525
# Name: 83, dtype: float64
# mi          0.001248
# avg_qty    25.486672
# Name: 84, dtype: float64
# mi          0.001248
# avg_qty    26.781932
# Name: 85, dtype: float64
# mi          0.001248
# avg_qty    26.627585
# Name: 86, dtype: float64
# mi          0.001248
# avg_qty    25.704881
# Name: 87, dtype: float64
# mi          0.001248
# avg_qty    24.847810
# Name: 88, dtype: float64
# mi          0.001248
# avg_qty    26.604771
# Name: 89, dtype: float64
# mi          0.001248
# avg_qty    25.901034
# Name: 90, dtype: float64
# mi          0.001248
# avg_qty    27.184343
# Name: 91, dtype: float64
# mi          0.001248
# avg_qty    26.488861
# Name: 92, dtype: float64
# mi          0.001248
# avg_qty    24.649215
# Name: 93, dtype: float64
# mi          0.001248
# avg_qty    26.635633
# Name: 94, dtype: float64
# mi          0.001248
# avg_qty    23.733327
# Name: 95, dtype: float64
# mi          0.001248
# avg_qty    25.258553
# Name: 96, dtype: float64
# mi          0.001248
# avg_qty    26.141097
# Name: 97, dtype: float64
# mi          0.001248
# avg_qty    26.057493
# Name: 98, dtype: float64
# mi          0.001248
# avg_qty    25.697369
# Name: 99, dtype: float64
# mi          0.001248
# avg_qty    25.897823
# Name: 100, dtype: float64
# mi          0.001248
# avg_qty    25.376424
# Name: 101, dtype: float64
# mi          0.001248
# avg_qty    25.380427
# Name: 102, dtype: float64
# mi          0.001248
# avg_qty    26.673333
# Name: 103, dtype: float64
# mi          0.001248
# avg_qty    26.276440
# Name: 104, dtype: float64
# mi          0.001248
# avg_qty    27.709839
# Name: 105, dtype: float64
# mi          0.001248
# avg_qty    23.926199
# Name: 106, dtype: float64
# mi          0.001248
# avg_qty    25.500945
# Name: 107, dtype: float64
# mi          0.001248
# avg_qty    24.402912
# Name: 108, dtype: float64
# mi          0.001248
# avg_qty    23.991998
# Name: 109, dtype: float64
# mi          0.001248
# avg_qty    26.165764
# Name: 110, dtype: float64
# mi          0.001248
# avg_qty    25.531689
# Name: 111, dtype: float64
# mi          0.001248
# avg_qty    24.622404
# Name: 112, dtype: float64
# mi          0.001248
# avg_qty    25.078078
# Name: 113, dtype: float64
# mi          0.001248
# avg_qty    26.781130
# Name: 114, dtype: float64
# mi          0.001248
# avg_qty    24.301338
# Name: 115, dtype: float64
# mi          0.001248
# avg_qty    26.231707
# Name: 116, dtype: float64
# mi          0.001248
# avg_qty    25.722317
# Name: 117, dtype: float64
# mi          0.001248
# avg_qty    25.742127
# Name: 118, dtype: float64
# mi          0.001248
# avg_qty    26.507803
# Name: 119, dtype: float64
# mi          0.001248
# avg_qty    26.482572
# Name: 120, dtype: float64
# mi          0.001248
# avg_qty    25.412847
# Name: 121, dtype: float64
# mi          0.001248
# avg_qty    24.413025
# Name: 122, dtype: float64
# mi          0.001248
# avg_qty    25.604359
# Name: 123, dtype: float64
# mi          0.001248
# avg_qty    25.942581
# Name: 124, dtype: float64
# mi          0.001248
# avg_qty    26.535664
# Name: 125, dtype: float64
# mi          0.001248
# avg_qty    24.304731
# Name: 126, dtype: float64
# mi          0.001248
# avg_qty    26.556397
# Name: 127, dtype: float64
# mi          0.001248
# avg_qty    24.840860
# Name: 128, dtype: float64
# mi          0.001248
# avg_qty    25.905232
# Name: 129, dtype: float64
# mi          0.001248
# avg_qty    25.670346
# Name: 130, dtype: float64
# mi          0.001248
# avg_qty    26.074844
# Name: 131, dtype: float64
# mi          0.001248
# avg_qty    23.840839
# Name: 132, dtype: float64
# mi          0.001248
# avg_qty    26.096756
# Name: 133, dtype: float64
# mi          0.001248
# avg_qty    25.425376
# Name: 134, dtype: float64
# mi          0.001248
# avg_qty    25.247540
# Name: 135, dtype: float64
# mi          0.001248
# avg_qty    25.009167
# Name: 136, dtype: float64
# mi          0.001248
# avg_qty    25.619320
# Name: 137, dtype: float64
# mi          0.001248
# avg_qty    24.240662
# Name: 138, dtype: float64
# mi          0.001248
# avg_qty    24.671554
# Name: 139, dtype: float64
# mi          0.001248
# avg_qty    25.252035
# Name: 140, dtype: float64
# mi          0.001248
# avg_qty    25.276234
# Name: 141, dtype: float64
# mi          0.001248
# avg_qty    25.293005
# Name: 142, dtype: float64
# mi          0.001248
# avg_qty    24.223781
# Name: 143, dtype: float64
# mi          0.001248
# avg_qty    25.752006
# Name: 144, dtype: float64
# mi          0.001248
# avg_qty    26.514713
# Name: 145, dtype: float64
# mi          0.001248
# avg_qty    26.084400
# Name: 146, dtype: float64
# mi          0.001248
# avg_qty    24.983963
# Name: 147, dtype: float64
# mi          0.001248
# avg_qty    24.605952
# Name: 148, dtype: float64
# mi          0.001248
# avg_qty    25.278846
# Name: 149, dtype: float64
# mi          0.001248
# avg_qty    26.333877
# Name: 150, dtype: float64
# mi          0.001248
# avg_qty    25.728701
# Name: 151, dtype: float64
# mi          0.001248
# avg_qty    25.734588
# Name: 152, dtype: float64
# mi          0.001248
# avg_qty    25.251122
# Name: 153, dtype: float64
# mi          0.001248
# avg_qty    25.427339
# Name: 154, dtype: float64
# mi          0.001248
# avg_qty    26.555535
# Name: 155, dtype: float64
# mi          0.001248
# avg_qty    25.261610
# Name: 156, dtype: float64
# mi          0.001248
# avg_qty    24.956043
# Name: 157, dtype: float64
# mi          0.001248
# avg_qty    26.218242
# Name: 158, dtype: float64
# mi          0.001248
# avg_qty    25.383338
# Name: 159, dtype: float64
# mi          0.001248
# avg_qty    24.431715
# Name: 160, dtype: float64
# mi          0.001248
# avg_qty    24.669323
# Name: 161, dtype: float64
# mi          0.001248
# avg_qty    25.576580
# Name: 162, dtype: float64
# mi          0.001248
# avg_qty    24.247910
# Name: 163, dtype: float64
# mi          0.001248
# avg_qty    25.356593
# Name: 164, dtype: float64
# mi          0.001248
# avg_qty    26.747934
# Name: 165, dtype: float64
# mi          0.001248
# avg_qty    24.877994
# Name: 166, dtype: float64
# mi          0.001248
# avg_qty    28.125528
# Name: 167, dtype: float64
# mi          0.001248
# avg_qty    25.758366
# Name: 168, dtype: float64
# mi          0.001248
# avg_qty    24.894607
# Name: 169, dtype: float64
# mi          0.001248
# avg_qty    25.168780
# Name: 170, dtype: float64
# mi          0.001248
# avg_qty    25.884634
# Name: 171, dtype: float64
# mi          0.001248
# avg_qty    24.865026
# Name: 172, dtype: float64
# mi          0.001248
# avg_qty    25.146862
# Name: 173, dtype: float64
# mi          0.001248
# avg_qty    25.504994
# Name: 174, dtype: float64
# mi          0.001248
# avg_qty    25.469288
# Name: 175, dtype: float64
# mi          0.001248
# avg_qty    25.259958
# Name: 176, dtype: float64
# mi          0.001248
# avg_qty    26.501779
# Name: 177, dtype: float64
# mi          0.001248
# avg_qty    24.891575
# Name: 178, dtype: float64
# mi          0.001248
# avg_qty    25.567096
# Name: 179, dtype: float64
# mi          0.001248
# avg_qty    24.426683
# Name: 180, dtype: float64
# mi          0.001248
# avg_qty    25.859742
# Name: 181, dtype: float64
# mi          0.001248
# avg_qty    25.341640
# Name: 182, dtype: float64
# mi          0.001248
# avg_qty    26.848016
# Name: 183, dtype: float64
# mi          0.001248
# avg_qty    27.265465
# Name: 184, dtype: float64
# mi          0.001248
# avg_qty    25.849199
# Name: 185, dtype: float64
# mi          0.001248
# avg_qty    26.646756
# Name: 186, dtype: float64
# mi          0.001248
# avg_qty    24.334045
# Name: 187, dtype: float64
# mi          0.001248
# avg_qty    26.412973
# Name: 188, dtype: float64
# mi          0.001248
# avg_qty    27.500253
# Name: 189, dtype: float64
# mi          0.001248
# avg_qty    24.699374
# Name: 190, dtype: float64
# mi          0.001248
# avg_qty    25.229966
# Name: 191, dtype: float64
# mi          0.001248
# avg_qty    25.225256
# Name: 192, dtype: float64
# mi          0.001248
# avg_qty    23.922517
# Name: 193, dtype: float64
# mi          0.001248
# avg_qty    26.329163
# Name: 194, dtype: float64
# mi          0.001248
# avg_qty    25.352381
# Name: 195, dtype: float64
# mi          0.001248
# avg_qty    25.557092
# Name: 196, dtype: float64
# mi          0.001248
# avg_qty    25.240741
# Name: 197, dtype: float64
# mi          0.001248
# avg_qty    26.316492
# Name: 198, dtype: float64
# mi          0.001248
# avg_qty    24.577585
# Name: 199, dtype: float64
# mi          0.001248
# avg_qty    26.357662
# Name: 200, dtype: float64
# mi          0.001248
# avg_qty    25.850154
# Name: 201, dtype: float64
# mi          0.001248
# avg_qty    25.571828
# Name: 202, dtype: float64
# mi          0.001248
# avg_qty    26.278708
# Name: 203, dtype: float64
# mi          0.001248
# avg_qty    25.549622
# Name: 204, dtype: float64
# mi          0.001248
# avg_qty    26.412911
# Name: 205, dtype: float64
# mi          0.001248
# avg_qty    25.541524
# Name: 206, dtype: float64
# mi          0.001248
# avg_qty    25.706215
# Name: 207, dtype: float64
# mi          0.001248
# avg_qty    26.065739
# Name: 208, dtype: float64
# mi          0.001248
# avg_qty    24.906225
# Name: 209, dtype: float64
# mi          0.001248
# avg_qty    26.709040
# Name: 210, dtype: float64
# mi          0.001248
# avg_qty    25.496888
# Name: 211, dtype: float64
# mi          0.001248
# avg_qty    24.917850
# Name: 212, dtype: float64
# mi          0.001248
# avg_qty    26.486078
# Name: 213, dtype: float64
# mi          0.001248
# avg_qty    24.399904
# Name: 214, dtype: float64
# mi          0.001248
# avg_qty    25.641079
# Name: 215, dtype: float64
# mi          0.001248
# avg_qty    25.294319
# Name: 216, dtype: float64
# mi          0.001248
# avg_qty    25.729600
# Name: 217, dtype: float64
# mi          0.001248
# avg_qty    24.579391
# Name: 218, dtype: float64
# mi          0.001248
# avg_qty    24.368286
# Name: 219, dtype: float64
# mi          0.001248
# avg_qty    26.240510
# Name: 220, dtype: float64
# mi          0.001248
# avg_qty    25.050481
# Name: 221, dtype: float64
# mi          0.001248
# avg_qty    25.828405
# Name: 222, dtype: float64
# mi          0.001248
# avg_qty    24.630456
# Name: 223, dtype: float64
# mi          0.001248
# avg_qty    24.582351
# Name: 224, dtype: float64
# mi          0.001248
# avg_qty    25.384294
# Name: 225, dtype: float64
# mi          0.001248
# avg_qty    25.869394
# Name: 226, dtype: float64
# mi          0.001248
# avg_qty    25.590423
# Name: 227, dtype: float64
# mi          0.001248
# avg_qty    25.399562
# Name: 228, dtype: float64
# mi          0.001248
# avg_qty    25.625007
# Name: 229, dtype: float64
# mi          0.001248
# avg_qty    25.219570
# Name: 230, dtype: float64
# mi          0.001248
# avg_qty    25.308988
# Name: 231, dtype: float64
# mi          0.001248
# avg_qty    25.353014
# Name: 232, dtype: float64
# mi          0.001248
# avg_qty    26.594427
# Name: 233, dtype: float64
# mi          0.001248
# avg_qty    25.225953
# Name: 234, dtype: float64
# mi          0.001248
# avg_qty    27.270605
# Name: 235, dtype: float64
# mi          0.001248
# avg_qty    23.921003
# Name: 236, dtype: float64
# mi          0.001248
# avg_qty    25.201122
# Name: 237, dtype: float64
# mi          0.001248
# avg_qty    24.964369
# Name: 238, dtype: float64
# mi          0.001248
# avg_qty    25.245259
# Name: 239, dtype: float64
# mi          0.001248
# avg_qty    25.363808
# Name: 240, dtype: float64
# mi          0.001248
# avg_qty    25.661421
# Name: 241, dtype: float64
# mi          0.001248
# avg_qty    25.407117
# Name: 242, dtype: float64
# mi          0.001248
# avg_qty    24.238054
# Name: 243, dtype: float64
# mi          0.001248
# avg_qty    25.760845
# Name: 244, dtype: float64
# mi          0.001248
# avg_qty    26.177135
# Name: 245, dtype: float64
# mi          0.001248
# avg_qty    25.248597
# Name: 246, dtype: float64
# mi          0.001248
# avg_qty    26.228698
# Name: 247, dtype: float64
# mi          0.001248
# avg_qty    26.404144
# Name: 248, dtype: float64
# mi          0.001248
# avg_qty    26.132582
# Name: 249, dtype: float64
# mi          0.001248
# avg_qty    25.587919
# Name: 250, dtype: float64
# mi          0.001248
# avg_qty    24.747748
# Name: 251, dtype: float64
# mi          0.001248
# avg_qty    25.315439
# Name: 252, dtype: float64
# mi          0.001248
# avg_qty    24.637978
# Name: 253, dtype: float64
# mi          0.001248
# avg_qty    24.861516
# Name: 254, dtype: float64
# mi          0.001248
# avg_qty    24.081939
# Name: 255, dtype: float64
# mi          0.001248
# avg_qty    25.328075
# Name: 256, dtype: float64
# mi          0.001248
# avg_qty    26.416980
# Name: 257, dtype: float64
# mi          0.001248
# avg_qty    25.894105
# Name: 258, dtype: float64
# mi          0.001248
# avg_qty    25.190031
# Name: 259, dtype: float64
# mi          0.001248
# avg_qty    26.139096
# Name: 260, dtype: float64
# mi          0.001248
# avg_qty    25.796433
# Name: 261, dtype: float64
# mi          0.001248
# avg_qty    27.000186
# Name: 262, dtype: float64
# mi          0.001248
# avg_qty    24.326679
# Name: 263, dtype: float64
# mi          0.001248
# avg_qty    26.364952
# Name: 264, dtype: float64
# mi          0.001248
# avg_qty    24.676672
# Name: 265, dtype: float64
# mi          0.001248
# avg_qty    24.429269
# Name: 266, dtype: float64
# mi          0.001248
# avg_qty    25.002721
# Name: 267, dtype: float64
# mi          0.001248
# avg_qty    25.604879
# Name: 268, dtype: float64
# mi          0.001248
# avg_qty    25.807593
# Name: 269, dtype: float64
# mi          0.001248
# avg_qty    26.498132
# Name: 270, dtype: float64
# mi          0.001248
# avg_qty    24.995141
# Name: 271, dtype: float64
# mi          0.001248
# avg_qty    26.094962
# Name: 272, dtype: float64
# mi          0.001248
# avg_qty    24.933618
# Name: 273, dtype: float64
# mi          0.001248
# avg_qty    26.421323
# Name: 274, dtype: float64
# mi          0.001248
# avg_qty    25.510706
# Name: 275, dtype: float64
# mi          0.001248
# avg_qty    25.534053
# Name: 276, dtype: float64
# mi          0.001248
# avg_qty    25.920661
# Name: 277, dtype: float64
# mi          0.001248
# avg_qty    24.458405
# Name: 278, dtype: float64
# mi          0.001248
# avg_qty    25.611516
# Name: 279, dtype: float64
# mi          0.001248
# avg_qty    26.743173
# Name: 280, dtype: float64
# mi          0.001248
# avg_qty    26.156281
# Name: 281, dtype: float64
# mi          0.001248
# avg_qty    25.603426
# Name: 282, dtype: float64
# mi          0.001248
# avg_qty    24.706706
# Name: 283, dtype: float64
# mi          0.001248
# avg_qty    25.801482
# Name: 284, dtype: float64
# mi          0.001248
# avg_qty    25.540900
# Name: 285, dtype: float64
# mi          0.001248
# avg_qty    25.231219
# Name: 286, dtype: float64
# mi          0.001248
# avg_qty    25.436457
# Name: 287, dtype: float64
# mi          0.001248
# avg_qty    24.988729
# Name: 288, dtype: float64
# mi          0.001248
# avg_qty    25.252501
# Name: 289, dtype: float64
# mi          0.001248
# avg_qty    26.605541
# Name: 290, dtype: float64
# mi          0.001248
# avg_qty    25.434527
# Name: 291, dtype: float64
# mi          0.001248
# avg_qty    25.627610
# Name: 292, dtype: float64
# mi          0.001248
# avg_qty    25.544847
# Name: 293, dtype: float64
# mi          0.001248
# avg_qty    26.404662
# Name: 294, dtype: float64
# mi          0.001248
# avg_qty    24.949939
# Name: 295, dtype: float64
# mi          0.001248
# avg_qty    25.591994
# Name: 296, dtype: float64
# mi          0.001248
# avg_qty    25.711441
# Name: 297, dtype: float64
# mi          0.001248
# avg_qty    24.982599
# Name: 298, dtype: float64
# mi          0.001248
# avg_qty    24.779059
# Name: 299, dtype: float64
# mi          0.001248
# avg_qty    26.638922
# Name: 300, dtype: float64
# mi          0.001248
# avg_qty    25.076419
# Name: 301, dtype: float64
# mi          0.001248
# avg_qty    24.655927
# Name: 302, dtype: float64
# mi          0.001248
# avg_qty    25.027306
# Name: 303, dtype: float64
# mi          0.001248
# avg_qty    25.590761
# Name: 304, dtype: float64
# mi          0.001248
# avg_qty    27.235910
# Name: 305, dtype: float64
# mi          0.001248
# avg_qty    26.126116
# Name: 306, dtype: float64
# mi          0.001248
# avg_qty    26.700133
# Name: 307, dtype: float64
# mi          0.001248
# avg_qty    25.945182
# Name: 308, dtype: float64
# mi          0.001248
# avg_qty    25.142580
# Name: 309, dtype: float64
# mi          0.001248
# avg_qty    25.719021
# Name: 310, dtype: float64
# mi          0.001248
# avg_qty    26.136326
# Name: 311, dtype: float64
# mi          0.001248
# avg_qty    24.588278
# Name: 312, dtype: float64
# mi          0.001248
# avg_qty    25.795091
# Name: 313, dtype: float64
# mi          0.001248
# avg_qty    25.680775
# Name: 314, dtype: float64
# mi          0.001248
# avg_qty    24.668320
# Name: 315, dtype: float64
# mi          0.001248
# avg_qty    25.799484
# Name: 316, dtype: float64
# mi          0.001248
# avg_qty    25.976239
# Name: 317, dtype: float64
# mi          0.001248
# avg_qty    25.702165
# Name: 318, dtype: float64
# mi          0.001248
# avg_qty    24.358516
# Name: 319, dtype: float64
# mi          0.001248
# avg_qty    24.490103
# Name: 320, dtype: float64
# mi          0.001248
# avg_qty    25.307711
# Name: 321, dtype: float64
# mi          0.001248
# avg_qty    26.513292
# Name: 322, dtype: float64
# mi          0.001248
# avg_qty    25.839325
# Name: 323, dtype: float64
# mi          0.001248
# avg_qty    25.811641
# Name: 324, dtype: float64
# mi          0.001248
# avg_qty    24.910677
# Name: 325, dtype: float64
# mi          0.001248
# avg_qty    25.282201
# Name: 326, dtype: float64
# mi          0.001248
# avg_qty    25.781905
# Name: 327, dtype: float64
# mi          0.001248
# avg_qty    24.689263
# Name: 328, dtype: float64
# mi          0.001248
# avg_qty    25.810252
# Name: 329, dtype: float64
# mi          0.001248
# avg_qty    26.018026
# Name: 330, dtype: float64
# mi          0.001248
# avg_qty    25.473726
# Name: 331, dtype: float64
# mi          0.001248
# avg_qty    25.804847
# Name: 332, dtype: float64
# mi          0.001248
# avg_qty    25.521010
# Name: 333, dtype: float64
# mi          0.001248
# avg_qty    24.147705
# Name: 334, dtype: float64
# mi          0.001248
# avg_qty    25.174374
# Name: 335, dtype: float64
# mi          0.001248
# avg_qty    25.338646
# Name: 336, dtype: float64
# mi          0.001248
# avg_qty    24.643610
# Name: 337, dtype: float64
# mi          0.001248
# avg_qty    24.307970
# Name: 338, dtype: float64
# mi          0.001248
# avg_qty    26.185530
# Name: 339, dtype: float64
# mi          0.001248
# avg_qty    25.823097
# Name: 340, dtype: float64
# mi          0.001248
# avg_qty    25.950337
# Name: 341, dtype: float64
# mi          0.001248
# avg_qty    24.114094
# Name: 342, dtype: float64
# mi          0.001248
# avg_qty    25.879233
# Name: 343, dtype: float64
# mi          0.001248
# avg_qty    25.896795
# Name: 344, dtype: float64
# mi          0.001248
# avg_qty    25.732145
# Name: 345, dtype: float64
# mi          0.001248
# avg_qty    25.467742
# Name: 346, dtype: float64
# mi          0.001248
# avg_qty    25.722779
# Name: 347, dtype: float64
# mi          0.001248
# avg_qty    26.766515
# Name: 348, dtype: float64
# mi          0.001248
# avg_qty    26.028867
# Name: 349, dtype: float64
# mi          0.001248
# avg_qty    26.200369
# Name: 350, dtype: float64
# mi          0.001248
# avg_qty    26.059500
# Name: 351, dtype: float64
# mi          0.001248
# avg_qty    24.543407
# Name: 352, dtype: float64
# mi          0.001248
# avg_qty    25.419669
# Name: 353, dtype: float64
# mi          0.001248
# avg_qty    26.481589
# Name: 354, dtype: float64
# mi          0.001248
# avg_qty    25.694297
# Name: 355, dtype: float64
# mi          0.001248
# avg_qty    25.181470
# Name: 356, dtype: float64
# mi          0.001248
# avg_qty    26.503447
# Name: 357, dtype: float64
# mi          0.001248
# avg_qty    25.567493
# Name: 358, dtype: float64
# mi          0.001248
# avg_qty    25.431045
# Name: 359, dtype: float64
# mi          0.001248
# avg_qty    24.462184
# Name: 360, dtype: float64
# mi          0.001248
# avg_qty    26.154140
# Name: 361, dtype: float64
# mi          0.001248
# avg_qty    24.706611
# Name: 362, dtype: float64
# mi          0.001248
# avg_qty    25.312142
# Name: 363, dtype: float64
# mi          0.001248
# avg_qty    27.350267
# Name: 364, dtype: float64
# mi          0.001248
# avg_qty    25.483962
# Name: 365, dtype: float64
# mi          0.001248
# avg_qty    24.421482
# Name: 366, dtype: float64
# mi          0.001248
# avg_qty    23.849944
# Name: 367, dtype: float64
# mi          0.001248
# avg_qty    26.609865
# Name: 368, dtype: float64
# mi          0.001248
# avg_qty    26.339305
# Name: 369, dtype: float64
# mi          0.001248
# avg_qty    26.264253
# Name: 370, dtype: float64
# mi          0.001248
# avg_qty    24.880904
# Name: 371, dtype: float64
# mi          0.001248
# avg_qty    25.318031
# Name: 372, dtype: float64
# mi          0.001248
# avg_qty    26.400213
# Name: 373, dtype: float64
# mi          0.001248
# avg_qty    24.254439
# Name: 374, dtype: float64
# mi          0.001248
# avg_qty    26.683575
# Name: 375, dtype: float64
# mi          0.001248
# avg_qty    26.104324
# Name: 376, dtype: float64
# mi          0.001248
# avg_qty    24.077394
# Name: 377, dtype: float64
# mi          0.001248
# avg_qty    25.024139
# Name: 378, dtype: float64
# mi          0.001248
# avg_qty    24.943146
# Name: 379, dtype: float64
# mi          0.001248
# avg_qty    25.647241
# Name: 380, dtype: float64
# mi          0.001248
# avg_qty    26.164369
# Name: 381, dtype: float64
# mi          0.001248
# avg_qty    25.833620
# Name: 382, dtype: float64
# mi          0.001248
# avg_qty    25.146677
# Name: 383, dtype: float64
# mi          0.001248
# avg_qty    26.128343
# Name: 384, dtype: float64
# mi          0.001248
# avg_qty    24.707131
# Name: 385, dtype: float64
# mi          0.001248
# avg_qty    25.692950
# Name: 386, dtype: float64
# mi          0.001248
# avg_qty    24.863842
# Name: 387, dtype: float64
# mi          0.001248
# avg_qty    26.496814
# Name: 388, dtype: float64
# mi          0.001248
# avg_qty    26.461439
# Name: 389, dtype: float64
# mi          0.001248
# avg_qty    25.903384
# Name: 390, dtype: float64
# mi          0.001248
# avg_qty    26.228485
# Name: 391, dtype: float64
# mi          0.001248
# avg_qty    24.981614
# Name: 392, dtype: float64
# mi          0.001248
# avg_qty    26.070070
# Name: 393, dtype: float64
# mi          0.001248
# avg_qty    25.655752
# Name: 394, dtype: float64
# mi          0.001248
# avg_qty    24.605145
# Name: 395, dtype: float64
# mi          0.001248
# avg_qty    26.324007
# Name: 396, dtype: float64
# mi          0.001248
# avg_qty    25.267460
# Name: 397, dtype: float64
# mi          0.001248
# avg_qty    24.128127
# Name: 398, dtype: float64
# mi          0.001248
# avg_qty    25.298664
# Name: 399, dtype: float64
# mi          0.001248
# avg_qty    25.464634
# Name: 400, dtype: float64
# mi          0.001248
# avg_qty    25.870257
# Name: 401, dtype: float64
# mi          0.001248
# avg_qty    25.950021
# Name: 402, dtype: float64
# mi          0.001248
# avg_qty    25.838311
# Name: 403, dtype: float64
# mi          0.001248
# avg_qty    26.220300
# Name: 404, dtype: float64
# mi          0.001248
# avg_qty    25.565795
# Name: 405, dtype: float64
# mi          0.001248
# avg_qty    25.218471
# Name: 406, dtype: float64
# mi          0.001248
# avg_qty    25.048003
# Name: 407, dtype: float64
# mi          0.001248
# avg_qty    25.275226
# Name: 408, dtype: float64
# mi          0.001248
# avg_qty    24.255324
# Name: 409, dtype: float64
# mi          0.001248
# avg_qty    24.508432
# Name: 410, dtype: float64
# mi          0.001248
# avg_qty    26.209118
# Name: 411, dtype: float64
# mi          0.001248
# avg_qty    25.651645
# Name: 412, dtype: float64
# mi          0.001248
# avg_qty    24.184457
# Name: 413, dtype: float64
# mi          0.001248
# avg_qty    25.053762
# Name: 414, dtype: float64
# mi          0.001248
# avg_qty    24.066300
# Name: 415, dtype: float64
# mi          0.001248
# avg_qty    25.597197
# Name: 416, dtype: float64
# mi          0.001248
# avg_qty    26.383565
# Name: 417, dtype: float64
# mi          0.001248
# avg_qty    25.934494
# Name: 418, dtype: float64
# mi          0.001248
# avg_qty    26.444780
# Name: 419, dtype: float64
# mi          0.001248
# avg_qty    25.779986
# Name: 420, dtype: float64
# mi          0.001248
# avg_qty    24.608804
# Name: 421, dtype: float64
# mi          0.001248
# avg_qty    25.750451
# Name: 422, dtype: float64
# mi          0.001248
# avg_qty    25.050633
# Name: 423, dtype: float64
# mi          0.001248
# avg_qty    24.765584
# Name: 424, dtype: float64
# mi          0.001248
# avg_qty    25.976815
# Name: 425, dtype: float64
# mi          0.001248
# avg_qty    24.880531
# Name: 426, dtype: float64
# mi          0.001248
# avg_qty    25.401454
# Name: 427, dtype: float64
# mi          0.001248
# avg_qty    24.578052
# Name: 428, dtype: float64
# mi          0.001248
# avg_qty    25.273181
# Name: 429, dtype: float64
# mi          0.001248
# avg_qty    26.451259
# Name: 430, dtype: float64
# mi          0.001248
# avg_qty    26.330958
# Name: 431, dtype: float64
# mi          0.001248
# avg_qty    25.207256
# Name: 432, dtype: float64
# mi          0.001248
# avg_qty    26.054631
# Name: 433, dtype: float64
# mi          0.001248
# avg_qty    26.254229
# Name: 434, dtype: float64
# mi          0.001248
# avg_qty    24.709993
# Name: 435, dtype: float64
# mi          0.001248
# avg_qty    25.008070
# Name: 436, dtype: float64
# mi          0.001248
# avg_qty    26.316704
# Name: 437, dtype: float64
# mi          0.001248
# avg_qty    24.350956
# Name: 438, dtype: float64
# mi          0.001248
# avg_qty    25.258742
# Name: 439, dtype: float64
# mi          0.001248
# avg_qty    24.838304
# Name: 440, dtype: float64
# mi          0.001248
# avg_qty    24.671394
# Name: 441, dtype: float64
# mi          0.001248
# avg_qty    26.108085
# Name: 442, dtype: float64
# mi          0.001248
# avg_qty    25.178849
# Name: 443, dtype: float64
# mi          0.001248
# avg_qty    25.248746
# Name: 444, dtype: float64
# mi          0.001248
# avg_qty    25.868347
# Name: 445, dtype: float64
# mi          0.001248
# avg_qty    25.827775
# Name: 446, dtype: float64
# mi          0.001248
# avg_qty    25.081582
# Name: 447, dtype: float64
# mi          0.001248
# avg_qty    24.742385
# Name: 448, dtype: float64
# mi          0.001248
# avg_qty    25.526002
# Name: 449, dtype: float64
# mi          0.001248
# avg_qty    26.764260
# Name: 450, dtype: float64
# mi          0.001248
# avg_qty    26.756530
# Name: 451, dtype: float64
# mi          0.001248
# avg_qty    25.656068
# Name: 452, dtype: float64
# mi          0.001248
# avg_qty    24.561040
# Name: 453, dtype: float64
# mi          0.001248
# avg_qty    26.489668
# Name: 454, dtype: float64
# mi          0.001248
# avg_qty    25.203032
# Name: 455, dtype: float64
# mi          0.001248
# avg_qty    24.820296
# Name: 456, dtype: float64
# mi          0.001248
# avg_qty    24.495725
# Name: 457, dtype: float64
# mi          0.001248
# avg_qty    25.303162
# Name: 458, dtype: float64
# mi          0.001248
# avg_qty    26.330209
# Name: 459, dtype: float64
# mi          0.001248
# avg_qty    25.344211
# Name: 460, dtype: float64
# mi          0.001248
# avg_qty    23.584577
# Name: 461, dtype: float64
# mi          0.001248
# avg_qty    23.889543
# Name: 462, dtype: float64
# mi          0.001248
# avg_qty    27.048956
# Name: 463, dtype: float64
# mi          0.001248
# avg_qty    24.869632
# Name: 464, dtype: float64
# mi          0.001248
# avg_qty    24.427005
# Name: 465, dtype: float64
# mi          0.001248
# avg_qty    26.106587
# Name: 466, dtype: float64
# mi          0.001248
# avg_qty    24.377086
# Name: 467, dtype: float64
# mi          0.001248
# avg_qty    25.584642
# Name: 468, dtype: float64
# mi          0.001248
# avg_qty    23.509265
# Name: 469, dtype: float64
# mi          0.001248
# avg_qty    26.130171
# Name: 470, dtype: float64
# mi          0.001248
# avg_qty    25.762165
# Name: 471, dtype: float64
# mi          0.001248
# avg_qty    25.261348
# Name: 472, dtype: float64
# mi          0.001248
# avg_qty    26.201733
# Name: 473, dtype: float64
# mi          0.001248
# avg_qty    24.999424
# Name: 474, dtype: float64
# mi          0.001248
# avg_qty    25.484730
# Name: 475, dtype: float64
# mi          0.001248
# avg_qty    24.927648
# Name: 476, dtype: float64
# mi          0.001248
# avg_qty    25.879447
# Name: 477, dtype: float64
# mi          0.001248
# avg_qty    25.562909
# Name: 478, dtype: float64
# mi          0.001248
# avg_qty    24.569803
# Name: 479, dtype: float64
# mi          0.001248
# avg_qty    24.606346
# Name: 480, dtype: float64
# mi          0.001248
# avg_qty    25.368820
# Name: 481, dtype: float64
# mi          0.001248
# avg_qty    24.934425
# Name: 482, dtype: float64
# mi          0.001248
# avg_qty    25.589877
# Name: 483, dtype: float64
# mi          0.001248
# avg_qty    25.476218
# Name: 484, dtype: float64
# mi          0.001248
# avg_qty    24.756812
# Name: 485, dtype: float64
# mi          0.001248
# avg_qty    26.497071
# Name: 486, dtype: float64
# mi          0.001248
# avg_qty    26.361074
# Name: 487, dtype: float64
# mi          0.001248
# avg_qty    24.527612
# Name: 488, dtype: float64
# mi          0.001248
# avg_qty    25.763306
# Name: 489, dtype: float64
# mi          0.001248
# avg_qty    24.771520
# Name: 490, dtype: float64
# mi          0.001248
# avg_qty    25.953167
# Name: 491, dtype: float64
# mi          0.001248
# avg_qty    26.443395
# Name: 492, dtype: float64
# mi          0.001248
# avg_qty    25.410680
# Name: 493, dtype: float64
# mi          0.001248
# avg_qty    25.706666
# Name: 494, dtype: float64
# mi          0.001248
# avg_qty    25.404395
# Name: 495, dtype: float64
# mi          0.001248
# avg_qty    25.254160
# Name: 496, dtype: float64
# mi          0.001248
# avg_qty    26.024255
# Name: 497, dtype: float64
# mi          0.001248
# avg_qty    26.262616
# Name: 498, dtype: float64
# mi          0.001248
# avg_qty    24.803401
# Name: 499, dtype: float64
# mi          0.001248
# avg_qty    24.987447
# Name: 500, dtype: float64
# mi          0.001248
# avg_qty    25.885594
# Name: 501, dtype: float64
# mi          0.001248
# avg_qty    25.139002
# Name: 502, dtype: float64
# mi          0.001248
# avg_qty    26.560278
# Name: 503, dtype: float64
# mi          0.001248
# avg_qty    24.230754
# Name: 504, dtype: float64
# mi          0.001248
# avg_qty    25.525164
# Name: 505, dtype: float64
# mi          0.001248
# avg_qty    24.833034
# Name: 506, dtype: float64
# mi          0.001248
# avg_qty    25.789319
# Name: 507, dtype: float64
# mi          0.001248
# avg_qty    25.939990
# Name: 508, dtype: float64
# mi          0.001248
# avg_qty    24.530109
# Name: 509, dtype: float64
# mi          0.001248
# avg_qty    26.457039
# Name: 510, dtype: float64
# mi          0.001248
# avg_qty    26.092084
# Name: 511, dtype: float64
# mi          0.001248
# avg_qty    25.204087
# Name: 512, dtype: float64
# mi          0.001248
# avg_qty    26.113398
# Name: 513, dtype: float64
# mi          0.001248
# avg_qty    24.153700
# Name: 514, dtype: float64
# mi          0.001248
# avg_qty    24.956425
# Name: 515, dtype: float64
# mi          0.001248
# avg_qty    25.126033
# Name: 516, dtype: float64
# mi          0.001248
# avg_qty    27.306129
# Name: 517, dtype: float64
# mi          0.001248
# avg_qty    24.763091
# Name: 518, dtype: float64
# mi          0.001248
# avg_qty    25.523473
# Name: 519, dtype: float64
# mi          0.001248
# avg_qty    25.439436
# Name: 520, dtype: float64
# mi          0.001248
# avg_qty    25.753116
# Name: 521, dtype: float64
# mi          0.001248
# avg_qty    25.769574
# Name: 522, dtype: float64
# mi          0.001248
# avg_qty    26.700645
# Name: 523, dtype: float64
# mi          0.001248
# avg_qty    25.080697
# Name: 524, dtype: float64
# mi          0.001248
# avg_qty    24.559551
# Name: 525, dtype: float64
# mi          0.001248
# avg_qty    25.005977
# Name: 526, dtype: float64
# mi          0.001248
# avg_qty    27.332856
# Name: 527, dtype: float64
# mi          0.001248
# avg_qty    26.605589
# Name: 528, dtype: float64
# mi          0.001248
# avg_qty    25.429912
# Name: 529, dtype: float64
# mi          0.001248
# avg_qty    25.618784
# Name: 530, dtype: float64
# mi          0.001248
# avg_qty    24.334735
# Name: 531, dtype: float64
# mi          0.001248
# avg_qty    26.569663
# Name: 532, dtype: float64
# mi          0.001248
# avg_qty    25.821521
# Name: 533, dtype: float64
# mi          0.001248
# avg_qty    24.865210
# Name: 534, dtype: float64
# mi          0.001248
# avg_qty    25.808812
# Name: 535, dtype: float64
# mi          0.001248
# avg_qty    26.001892
# Name: 536, dtype: float64
# mi          0.001248
# avg_qty    23.958759
# Name: 537, dtype: float64
# mi          0.001248
# avg_qty    24.370428
# Name: 538, dtype: float64
# mi          0.001248
# avg_qty    26.266751
# Name: 539, dtype: float64
# mi          0.001248
# avg_qty    24.833330
# Name: 540, dtype: float64
# mi          0.001248
# avg_qty    25.069457
# Name: 541, dtype: float64
# mi          0.001248
# avg_qty    25.148364
# Name: 542, dtype: float64
# mi          0.001248
# avg_qty    27.045849
# Name: 543, dtype: float64
# mi          0.001248
# avg_qty    24.072157
# Name: 544, dtype: float64
# mi          0.001248
# avg_qty    25.786286
# Name: 545, dtype: float64
# mi          0.001248
# avg_qty    24.361078
# Name: 546, dtype: float64
# mi          0.001248
# avg_qty    25.965812
# Name: 547, dtype: float64
# mi          0.001248
# avg_qty    25.300605
# Name: 548, dtype: float64
# mi          0.001248
# avg_qty    26.653999
# Name: 549, dtype: float64
# mi          0.001248
# avg_qty    26.048849
# Name: 550, dtype: float64
# mi          0.001248
# avg_qty    25.966031
# Name: 551, dtype: float64
# mi          0.001248
# avg_qty    23.897096
# Name: 552, dtype: float64
# mi          0.001248
# avg_qty    25.565968
# Name: 553, dtype: float64
# mi          0.001248
# avg_qty    25.683718
# Name: 554, dtype: float64
# mi          0.001248
# avg_qty    24.972841
# Name: 555, dtype: float64
# mi          0.001248
# avg_qty    24.765543
# Name: 556, dtype: float64
# mi          0.001248
# avg_qty    25.491431
# Name: 557, dtype: float64
# mi          0.001248
# avg_qty    24.016102
# Name: 558, dtype: float64
# mi          0.001248
# avg_qty    25.519568
# Name: 559, dtype: float64
# mi          0.001248
# avg_qty    25.290771
# Name: 560, dtype: float64
# mi          0.001248
# avg_qty    25.584599
# Name: 561, dtype: float64
# mi          0.001248
# avg_qty    25.945018
# Name: 562, dtype: float64
# mi          0.001248
# avg_qty    24.588722
# Name: 563, dtype: float64
# mi          0.001248
# avg_qty    25.580552
# Name: 564, dtype: float64
# mi          0.001248
# avg_qty    25.294704
# Name: 565, dtype: float64
# mi          0.001248
# avg_qty    24.203666
# Name: 566, dtype: float64
# mi          0.001248
# avg_qty    24.132980
# Name: 567, dtype: float64
# mi          0.001248
# avg_qty    26.677384
# Name: 568, dtype: float64
# mi          0.001248
# avg_qty    24.841392
# Name: 569, dtype: float64
# mi          0.001248
# avg_qty    25.437497
# Name: 570, dtype: float64
# mi          0.001248
# avg_qty    26.609334
# Name: 571, dtype: float64
# mi          0.001248
# avg_qty    24.773715
# Name: 572, dtype: float64
# mi          0.001248
# avg_qty    25.004964
# Name: 573, dtype: float64
# mi          0.001248
# avg_qty    25.182480
# Name: 574, dtype: float64
# mi          0.001248
# avg_qty    26.017072
# Name: 575, dtype: float64
# mi          0.001248
# avg_qty    25.336865
# Name: 576, dtype: float64
# mi          0.001248
# avg_qty    25.129606
# Name: 577, dtype: float64
# mi          0.001248
# avg_qty    25.942399
# Name: 578, dtype: float64
# mi          0.001248
# avg_qty    25.077254
# Name: 579, dtype: float64
# mi          0.001248
# avg_qty    25.018403
# Name: 580, dtype: float64
# mi          0.001248
# avg_qty    25.892811
# Name: 581, dtype: float64
# mi          0.001248
# avg_qty    26.714429
# Name: 582, dtype: float64
# mi          0.001248
# avg_qty    26.282443
# Name: 583, dtype: float64
# mi          0.001248
# avg_qty    26.800315
# Name: 584, dtype: float64
# mi          0.001248
# avg_qty    25.429185
# Name: 585, dtype: float64
# mi          0.001248
# avg_qty    24.673969
# Name: 586, dtype: float64
# mi          0.001248
# avg_qty    26.200279
# Name: 587, dtype: float64
# mi          0.001248
# avg_qty    25.330892
# Name: 588, dtype: float64
# mi          0.001248
# avg_qty    25.472383
# Name: 589, dtype: float64
# mi          0.001248
# avg_qty    26.130787
# Name: 590, dtype: float64
# mi          0.001248
# avg_qty    25.707712
# Name: 591, dtype: float64
# mi          0.001248
# avg_qty    26.466139
# Name: 592, dtype: float64
# mi          0.001248
# avg_qty    25.026643
# Name: 593, dtype: float64
# mi          0.001248
# avg_qty    25.276832
# Name: 594, dtype: float64
# mi          0.001248
# avg_qty    25.340894
# Name: 595, dtype: float64
# mi          0.001248
# avg_qty    25.106434
# Name: 596, dtype: float64
# mi          0.001248
# avg_qty    24.396882
# Name: 597, dtype: float64
# mi          0.001248
# avg_qty    25.207882
# Name: 598, dtype: float64
# mi          0.001248
# avg_qty    26.600859
# Name: 599, dtype: float64
# mi          0.001248
# avg_qty    25.062115
# Name: 600, dtype: float64
# mi          0.001248
# avg_qty    24.846556
# Name: 601, dtype: float64
# mi          0.001248
# avg_qty    25.570312
# Name: 602, dtype: float64
# mi          0.001248
# avg_qty    24.485136
# Name: 603, dtype: float64
# mi          0.001248
# avg_qty    26.760228
# Name: 604, dtype: float64
# mi          0.001248
# avg_qty    24.733440
# Name: 605, dtype: float64
# mi          0.001248
# avg_qty    24.287917
# Name: 606, dtype: float64
# mi          0.001248
# avg_qty    26.950173
# Name: 607, dtype: float64
# mi          0.001248
# avg_qty    25.391946
# Name: 608, dtype: float64
# mi          0.001248
# avg_qty    25.179003
# Name: 609, dtype: float64
# mi          0.001248
# avg_qty    25.405060
# Name: 610, dtype: float64
# mi          0.001248
# avg_qty    25.842370
# Name: 611, dtype: float64
# mi          0.001248
# avg_qty    25.688426
# Name: 612, dtype: float64
# mi          0.001248
# avg_qty    25.672736
# Name: 613, dtype: float64
# mi          0.001248
# avg_qty    26.432560
# Name: 614, dtype: float64
# mi          0.001248
# avg_qty    25.738334
# Name: 615, dtype: float64
# mi          0.001248
# avg_qty    26.575588
# Name: 616, dtype: float64
# mi          0.001248
# avg_qty    25.414176
# Name: 617, dtype: float64
# mi          0.001248
# avg_qty    24.774914
# Name: 618, dtype: float64
# mi          0.001248
# avg_qty    26.728973
# Name: 619, dtype: float64
# mi          0.001248
# avg_qty    25.888641
# Name: 620, dtype: float64
# mi          0.001248
# avg_qty    25.439396
# Name: 621, dtype: float64
# mi          0.001248
# avg_qty    25.343583
# Name: 622, dtype: float64
# mi          0.001248
# avg_qty    25.359745
# Name: 623, dtype: float64
# mi          0.001248
# avg_qty    24.604131
# Name: 624, dtype: float64
# mi          0.001248
# avg_qty    26.259679
# Name: 625, dtype: float64
# mi          0.001248
# avg_qty    25.159150
# Name: 626, dtype: float64
# mi          0.001248
# avg_qty    25.313612
# Name: 627, dtype: float64
# mi          0.001248
# avg_qty    26.437638
# Name: 628, dtype: float64
# mi          0.001248
# avg_qty    24.931199
# Name: 629, dtype: float64
# mi          0.001248
# avg_qty    26.034750
# Name: 630, dtype: float64
# mi          0.001248
# avg_qty    26.121170
# Name: 631, dtype: float64
# mi          0.001248
# avg_qty    26.299085
# Name: 632, dtype: float64
# mi          0.001248
# avg_qty    25.576026
# Name: 633, dtype: float64
# mi          0.001248
# avg_qty    24.733212
# Name: 634, dtype: float64
# mi          0.001248
# avg_qty    25.978080
# Name: 635, dtype: float64
# mi          0.001248
# avg_qty    26.773575
# Name: 636, dtype: float64
# mi          0.001248
# avg_qty    24.825559
# Name: 637, dtype: float64
# mi          0.001248
# avg_qty    26.110347
# Name: 638, dtype: float64
# mi          0.001248
# avg_qty    26.046966
# Name: 639, dtype: float64
# mi          0.001248
# avg_qty    24.001493
# Name: 640, dtype: float64
# mi          0.001248
# avg_qty    25.397547
# Name: 641, dtype: float64
# mi          0.001248
# avg_qty    25.303247
# Name: 642, dtype: float64
# mi          0.001248
# avg_qty    26.058447
# Name: 643, dtype: float64
# mi          0.001248
# avg_qty    25.103066
# Name: 644, dtype: float64
# mi          0.001248
# avg_qty    23.611910
# Name: 645, dtype: float64
# mi          0.001248
# avg_qty    26.322403
# Name: 646, dtype: float64
# mi          0.001248
# avg_qty    26.016774
# Name: 647, dtype: float64
# mi          0.001248
# avg_qty    26.279531
# Name: 648, dtype: float64
# mi          0.001248
# avg_qty    26.119664
# Name: 649, dtype: float64
# mi          0.001248
# avg_qty    25.950143
# Name: 650, dtype: float64
# mi          0.001248
# avg_qty    24.601715
# Name: 651, dtype: float64
# mi          0.001248
# avg_qty    26.250270
# Name: 652, dtype: float64
# mi          0.001248
# avg_qty    25.925845
# Name: 653, dtype: float64
# mi          0.001248
# avg_qty    26.371770
# Name: 654, dtype: float64
# mi          0.001248
# avg_qty    26.338724
# Name: 655, dtype: float64
# mi          0.001248
# avg_qty    26.152267
# Name: 656, dtype: float64
# mi          0.001248
# avg_qty    25.707661
# Name: 657, dtype: float64
# mi          0.001248
# avg_qty    25.386574
# Name: 658, dtype: float64
# mi          0.001248
# avg_qty    25.832808
# Name: 659, dtype: float64
# mi          0.001248
# avg_qty    26.087048
# Name: 660, dtype: float64
# mi          0.001248
# avg_qty    27.392474
# Name: 661, dtype: float64
# mi          0.001248
# avg_qty    25.893024
# Name: 662, dtype: float64
# mi          0.001248
# avg_qty    24.718724
# Name: 663, dtype: float64
# mi          0.001248
# avg_qty    25.963501
# Name: 664, dtype: float64
# mi          0.001248
# avg_qty    25.564823
# Name: 665, dtype: float64
# mi          0.001248
# avg_qty    25.031865
# Name: 666, dtype: float64
# mi          0.001248
# avg_qty    24.222901
# Name: 667, dtype: float64
# mi          0.001248
# avg_qty    26.547912
# Name: 668, dtype: float64
# mi          0.001248
# avg_qty    24.451878
# Name: 669, dtype: float64
# mi          0.001248
# avg_qty    24.810563
# Name: 670, dtype: float64
# mi          0.001248
# avg_qty    24.486153
# Name: 671, dtype: float64
# mi          0.001248
# avg_qty    25.318076
# Name: 672, dtype: float64
# mi          0.001248
# avg_qty    25.149226
# Name: 673, dtype: float64
# mi          0.001248
# avg_qty    25.178843
# Name: 674, dtype: float64
# mi          0.001248
# avg_qty    25.870203
# Name: 675, dtype: float64
# mi          0.001248
# avg_qty    25.353999
# Name: 676, dtype: float64
# mi          0.001248
# avg_qty    26.249946
# Name: 677, dtype: float64
# mi          0.001248
# avg_qty    25.423238
# Name: 678, dtype: float64
# mi          0.001248
# avg_qty    26.301183
# Name: 679, dtype: float64
# mi          0.001248
# avg_qty    25.745194
# Name: 680, dtype: float64
# mi          0.001248
# avg_qty    26.214474
# Name: 681, dtype: float64
# mi          0.001248
# avg_qty    26.083997
# Name: 682, dtype: float64
# mi          0.001248
# avg_qty    25.512835
# Name: 683, dtype: float64
# mi          0.001248
# avg_qty    26.228711
# Name: 684, dtype: float64
# mi          0.001248
# avg_qty    26.403904
# Name: 685, dtype: float64
# mi          0.001248
# avg_qty    26.768807
# Name: 686, dtype: float64
# mi          0.001248
# avg_qty    25.138478
# Name: 687, dtype: float64
# mi          0.001248
# avg_qty    25.884189
# Name: 688, dtype: float64
# mi          0.001248
# avg_qty    25.613762
# Name: 689, dtype: float64
# mi          0.001248
# avg_qty    24.091813
# Name: 690, dtype: float64
# mi          0.001248
# avg_qty    25.849500
# Name: 691, dtype: float64
# mi          0.001248
# avg_qty    24.767771
# Name: 692, dtype: float64
# mi          0.001248
# avg_qty    25.657301
# Name: 693, dtype: float64
# mi          0.001248
# avg_qty    26.638794
# Name: 694, dtype: float64
# mi          0.001248
# avg_qty    26.165089
# Name: 695, dtype: float64
# mi          0.001248
# avg_qty    26.655633
# Name: 696, dtype: float64
# mi          0.001248
# avg_qty    24.599429
# Name: 697, dtype: float64
# mi          0.001248
# avg_qty    26.375368
# Name: 698, dtype: float64
# mi          0.001248
# avg_qty    26.097004
# Name: 699, dtype: float64
# mi          0.001248
# avg_qty    25.742107
# Name: 700, dtype: float64
# mi          0.001248
# avg_qty    26.464835
# Name: 701, dtype: float64
# mi          0.001248
# avg_qty    25.390444
# Name: 702, dtype: float64
# mi          0.001248
# avg_qty    25.154719
# Name: 703, dtype: float64
# mi          0.001248
# avg_qty    25.547811
# Name: 704, dtype: float64
# mi          0.001248
# avg_qty    26.919369
# Name: 705, dtype: float64
# mi          0.001248
# avg_qty    26.263970
# Name: 706, dtype: float64
# mi          0.001248
# ...
# mi         16.000000
# avg_qty    25.544487
# Name: 8779, dtype: float64
# mi         16.000000
# avg_qty    25.546335
# Name: 8780, dtype: float64
# mi         16.000000
# avg_qty    25.561998
# Name: 8781, dtype: float64
# mi         16.000000
# avg_qty    25.518132
# Name: 8782, dtype: float64
# mi         16.000000
# avg_qty    25.602395
# Name: 8783, dtype: float64
# mi         16.000000
# avg_qty    25.503642
# Name: 8784, dtype: float64
# mi         16.00000
# avg_qty    25.58363
# Name: 8785, dtype: float64
# mi         16.000000
# avg_qty    25.527857
# Name: 8786, dtype: float64
# mi         16.000000
# avg_qty    25.509932
# Name: 8787, dtype: float64
# mi         16.000000
# avg_qty    25.519337
# Name: 8788, dtype: float64
# mi         16.000000
# avg_qty    25.556393
# Name: 8789, dtype: float64
# mi         16.000000
# avg_qty    25.541851
# Name: 8790, dtype: float64
# mi         16.000000
# avg_qty    25.575074
# Name: 8791, dtype: float64
# mi         16.000000
# avg_qty    25.566408
# Name: 8792, dtype: float64
# mi         16.00000
# avg_qty    25.52786
# Name: 8793, dtype: float64
# mi         16.000000
# avg_qty    25.526204
# Name: 8794, dtype: float64
# mi         16.000000
# avg_qty    25.489863
# Name: 8795, dtype: float64
# mi         16.000000
# avg_qty    25.526497
# Name: 8796, dtype: float64
# mi         16.000000
# avg_qty    25.609271
# Name: 8797, dtype: float64
# mi         16.000000
# avg_qty    25.494727
# Name: 8798, dtype: float64
# mi         16.000000
# avg_qty    25.485393
# Name: 8799, dtype: float64
# mi         16.000000
# avg_qty    25.520014
# Name: 8800, dtype: float64
# mi         16.000000
# avg_qty    25.497858
# Name: 8801, dtype: float64
# mi         16.000000
# avg_qty    25.541667
# Name: 8802, dtype: float64
# mi         16.000000
# avg_qty    25.554161
# Name: 8803, dtype: float64
# mi         16.000000
# avg_qty    25.542432
# Name: 8804, dtype: float64
# mi         16.000
# avg_qty    25.496
# Name: 8805, dtype: float64
# mi         16.000000
# avg_qty    25.580703
# Name: 8806, dtype: float64
# mi         16.00000
# avg_qty    25.52475
# Name: 8807, dtype: float64
# mi         16.000000
# avg_qty    25.552373
# Name: 8808, dtype: float64
# mi         16.000000
# avg_qty    25.503521
# Name: 8809, dtype: float64
# mi         16.000000
# avg_qty    25.530675
# Name: 8810, dtype: float64
# mi         16.000000
# avg_qty    25.570754
# Name: 8811, dtype: float64
# mi         16.000000
# avg_qty    25.494983
# Name: 8812, dtype: float64
# mi         16.000000
# avg_qty    25.513405
# Name: 8813, dtype: float64
# mi         16.000000
# avg_qty    25.543438
# Name: 8814, dtype: float64
# mi         16.000000
# avg_qty    25.574967
# Name: 8815, dtype: float64
# mi         16.000000
# avg_qty    25.574089
# Name: 8816, dtype: float64
# mi         16.000000
# avg_qty    25.595161
# Name: 8817, dtype: float64
# mi         16.000000
# avg_qty    25.579513
# Name: 8818, dtype: float64
# mi         16.000000
# avg_qty    25.507114
# Name: 8819, dtype: float64
# mi         16.000000
# avg_qty    25.548845
# Name: 8820, dtype: float64
# mi         16.000000
# avg_qty    25.566308
# Name: 8821, dtype: float64
# mi         16.000000
# avg_qty    25.628431
# Name: 8822, dtype: float64
# mi         16.000000
# avg_qty    25.531421
# Name: 8823, dtype: float64
# mi         16.000000
# avg_qty    25.529519
# Name: 8824, dtype: float64
# mi         16.000000
# avg_qty    25.463667
# Name: 8825, dtype: float64
# mi         16.000000
# avg_qty    25.538985
# Name: 8826, dtype: float64
# mi         16.000000
# avg_qty    25.566624
# Name: 8827, dtype: float64
# mi         16.000000
# avg_qty    25.637419
# Name: 8828, dtype: float64
# mi         16.000000
# avg_qty    25.552548
# Name: 8829, dtype: float64
# mi         16.000000
# avg_qty    25.488003
# Name: 8830, dtype: float64
# mi         16.000000
# avg_qty    25.500765
# Name: 8831, dtype: float64
# mi         16.000000
# avg_qty    25.517921
# Name: 8832, dtype: float64
# mi         16.000000
# avg_qty    25.480946
# Name: 8833, dtype: float64
# mi         16.000000
# avg_qty    25.473126
# Name: 8834, dtype: float64
# mi         16.000000
# avg_qty    25.449074
# Name: 8835, dtype: float64
# mi         16.000000
# avg_qty    25.453614
# Name: 8836, dtype: float64
# mi         16.000000
# avg_qty    25.486045
# Name: 8837, dtype: float64
# mi         16.000000
# avg_qty    25.523117
# Name: 8838, dtype: float64
# mi         16.000000
# avg_qty    25.499359
# Name: 8839, dtype: float64
# mi         16.00000
# avg_qty    25.52015
# Name: 8840, dtype: float64
# mi         16.000000
# avg_qty    25.587909
# Name: 8841, dtype: float64
# mi         16.000000
# avg_qty    25.476702
# Name: 8842, dtype: float64
# mi         16.000000
# avg_qty    25.490038
# Name: 8843, dtype: float64
# mi         16.000000
# avg_qty    25.554763
# Name: 8844, dtype: float64
# mi         16.000000
# avg_qty    25.498255
# Name: 8845, dtype: float64
# mi         16.000000
# avg_qty    25.520318
# Name: 8846, dtype: float64
# mi         16.000000
# avg_qty    25.569923
# Name: 8847, dtype: float64
# mi         16.000000
# avg_qty    25.642457
# Name: 8848, dtype: float64
# mi         16.000000
# avg_qty    25.617677
# Name: 8849, dtype: float64
# mi         16.000000
# avg_qty    25.487071
# Name: 8850, dtype: float64
# mi         16.000000
# avg_qty    25.575372
# Name: 8851, dtype: float64
# mi         16.000000
# avg_qty    25.542898
# Name: 8852, dtype: float64
# mi         16.000000
# avg_qty    25.519013
# Name: 8853, dtype: float64
# mi         16.000000
# avg_qty    25.535703
# Name: 8854, dtype: float64
# mi         16.000000
# avg_qty    25.462961
# Name: 8855, dtype: float64
# mi         16.000000
# avg_qty    25.568846
# Name: 8856, dtype: float64
# mi         16.000000
# avg_qty    25.546382
# Name: 8857, dtype: float64
# mi         16.000000
# avg_qty    25.594183
# Name: 8858, dtype: float64
# mi         16.000000
# avg_qty    25.543423
# Name: 8859, dtype: float64
# mi         16.000000
# avg_qty    25.580573
# Name: 8860, dtype: float64
# mi         16.000000
# avg_qty    25.453361
# Name: 8861, dtype: float64
# mi         16.000000
# avg_qty    25.574299
# Name: 8862, dtype: float64
# mi         16.000000
# avg_qty    25.561684
# Name: 8863, dtype: float64
# mi         16.000000
# avg_qty    25.446948
# Name: 8864, dtype: float64
# mi         16.000000
# avg_qty    25.529379
# Name: 8865, dtype: float64
# mi         16.000000
# avg_qty    25.502065
# Name: 8866, dtype: float64
# mi         16.000000
# avg_qty    25.552054
# Name: 8867, dtype: float64
# mi         16.000000
# avg_qty    25.545439
# Name: 8868, dtype: float64
# mi         16.000000
# avg_qty    25.560969
# Name: 8869, dtype: float64
# mi         16.000000
# avg_qty    25.486088
# Name: 8870, dtype: float64
# mi         16.000000
# avg_qty    25.562959
# Name: 8871, dtype: float64
# mi         16.000000
# avg_qty    25.534056
# Name: 8872, dtype: float64
# mi         16.000000
# avg_qty    25.536084
# Name: 8873, dtype: float64
# mi         16.000000
# avg_qty    25.520037
# Name: 8874, dtype: float64
# mi         16.000000
# avg_qty    25.571271
# Name: 8875, dtype: float64
# mi         16.000000
# avg_qty    25.558573
# Name: 8876, dtype: float64
# mi         16.000000
# avg_qty    25.530516
# Name: 8877, dtype: float64
# mi         16.000000
# avg_qty    25.477982
# Name: 8878, dtype: float64
# mi         16.000000
# avg_qty    25.577742
# Name: 8879, dtype: float64
# mi         16.000000
# avg_qty    25.513907
# Name: 8880, dtype: float64
# mi         16.000000
# avg_qty    25.513644
# Name: 8881, dtype: float64
# mi         16.000000
# avg_qty    25.572768
# Name: 8882, dtype: float64
# mi         16.000000
# avg_qty    25.443235
# Name: 8883, dtype: float64
# mi         16.000000
# avg_qty    25.563577
# Name: 8884, dtype: float64
# mi         16.000000
# avg_qty    25.626684
# Name: 8885, dtype: float64
# mi         16.00000
# avg_qty    25.51572
# Name: 8886, dtype: float64
# mi         16.000000
# avg_qty    25.484001
# Name: 8887, dtype: float64
# mi         16.000000
# avg_qty    25.590317
# Name: 8888, dtype: float64
# mi         16.000000
# avg_qty    25.512409
# Name: 8889, dtype: float64
# mi         16.000000
# avg_qty    25.568258
# Name: 8890, dtype: float64
# mi         16.000000
# avg_qty    25.567563
# Name: 8891, dtype: float64
# mi         16.000000
# avg_qty    25.533334
# Name: 8892, dtype: float64
# mi         16.000000
# avg_qty    25.536222
# Name: 8893, dtype: float64
# mi         16.000000
# avg_qty    25.643634
# Name: 8894, dtype: float64
# mi         16.000000
# avg_qty    25.544388
# Name: 8895, dtype: float64
# mi         16.000000
# avg_qty    25.522326
# Name: 8896, dtype: float64
# mi         16.000000
# avg_qty    25.597637
# Name: 8897, dtype: float64
# mi         16.000000
# avg_qty    25.490873
# Name: 8898, dtype: float64
# mi         16.00000
# avg_qty    25.54368
# Name: 8899, dtype: float64
# mi         16.000000
# avg_qty    25.526416
# Name: 8900, dtype: float64
# mi         16.00000
# avg_qty    25.51784
# Name: 8901, dtype: float64
# mi         16.000000
# avg_qty    25.519307
# Name: 8902, dtype: float64
# mi         16.000000
# avg_qty    25.542796
# Name: 8903, dtype: float64
# mi         16.000000
# avg_qty    25.501039
# Name: 8904, dtype: float64
# mi         16.000000
# avg_qty    25.493496
# Name: 8905, dtype: float64
# mi         16.000000
# avg_qty    25.531668
# Name: 8906, dtype: float64
# mi         16.000000
# avg_qty    25.538832
# Name: 8907, dtype: float64
# mi         16.000000
# avg_qty    25.548874
# Name: 8908, dtype: float64
# mi         16.000000
# avg_qty    25.529643
# Name: 8909, dtype: float64
# mi         16.000000
# avg_qty    25.527269
# Name: 8910, dtype: float64
# mi         16.000000
# avg_qty    25.510873
# Name: 8911, dtype: float64
# mi         16.000000
# avg_qty    25.594762
# Name: 8912, dtype: float64
# mi         16.000000
# avg_qty    25.598944
# Name: 8913, dtype: float64
# mi         16.000000
# avg_qty    25.545945
# Name: 8914, dtype: float64
# mi         16.000000
# avg_qty    25.536609
# Name: 8915, dtype: float64
# mi         16.000000
# avg_qty    25.587009
# Name: 8916, dtype: float64
# mi         16.000000
# avg_qty    25.548572
# Name: 8917, dtype: float64
# mi         16.000000
# avg_qty    25.515006
# Name: 8918, dtype: float64
# mi         16.000000
# avg_qty    25.539355
# Name: 8919, dtype: float64
# mi         16.000000
# avg_qty    25.561441
# Name: 8920, dtype: float64
# mi         16.000000
# avg_qty    25.515308
# Name: 8921, dtype: float64
# mi         16.000000
# avg_qty    25.654583
# Name: 8922, dtype: float64
# mi         16.000000
# avg_qty    25.588405
# Name: 8923, dtype: float64
# mi         16.000000
# avg_qty    25.496848
# Name: 8924, dtype: float64
# mi         16.000000
# avg_qty    25.533715
# Name: 8925, dtype: float64
# mi         16.000000
# avg_qty    25.548728
# Name: 8926, dtype: float64
# mi         16.000000
# avg_qty    25.538682
# Name: 8927, dtype: float64
# mi         16.000000
# avg_qty    25.516521
# Name: 8928, dtype: float64
# mi         16.000000
# avg_qty    25.518037
# Name: 8929, dtype: float64
# mi         16.000000
# avg_qty    25.505433
# Name: 8930, dtype: float64
# mi         16.00000
# avg_qty    25.59249
# Name: 8931, dtype: float64
# mi         16.000000
# avg_qty    25.460824
# Name: 8932, dtype: float64
# mi         16.000000
# avg_qty    25.502247
# Name: 8933, dtype: float64
# mi         16.000000
# avg_qty    25.459854
# Name: 8934, dtype: float64
# mi         16.00000
# avg_qty    25.52246
# Name: 8935, dtype: float64
# mi         16.000000
# avg_qty    25.528398
# Name: 8936, dtype: float64
# mi         16.000000
# avg_qty    25.594501
# Name: 8937, dtype: float64
# mi         16.000000
# avg_qty    25.481325
# Name: 8938, dtype: float64
# mi         16.000000
# avg_qty    25.549579
# Name: 8939, dtype: float64
# mi         16.000000
# avg_qty    25.553583
# Name: 8940, dtype: float64
# mi         16.000000
# avg_qty    25.557366
# Name: 8941, dtype: float64
# mi         16.000000
# avg_qty    25.602092
# Name: 8942, dtype: float64
# mi         16.000000
# avg_qty    25.506382
# Name: 8943, dtype: float64
# mi         16.00000
# avg_qty    25.53526
# Name: 8944, dtype: float64
# mi         16.000000
# avg_qty    25.545662
# Name: 8945, dtype: float64
# mi         16.000000
# avg_qty    25.578366
# Name: 8946, dtype: float64
# mi         16.000000
# avg_qty    25.548888
# Name: 8947, dtype: float64
# mi         16.00000
# avg_qty    25.53109
# Name: 8948, dtype: float64
# mi         16.000000
# avg_qty    25.647743
# Name: 8949, dtype: float64
# mi         16.000000
# avg_qty    25.494614
# Name: 8950, dtype: float64
# mi         16.000000
# avg_qty    25.579656
# Name: 8951, dtype: float64
# mi         16.00000
# avg_qty    25.50527
# Name: 8952, dtype: float64
# mi         16.00000
# avg_qty    25.48449
# Name: 8953, dtype: float64
# mi         16.000000
# avg_qty    25.571503
# Name: 8954, dtype: float64
# mi         16.00000
# avg_qty    25.59325
# Name: 8955, dtype: float64
# mi         16.000000
# avg_qty    25.610394
# Name: 8956, dtype: float64
# mi         16.000000
# avg_qty    25.477774
# Name: 8957, dtype: float64
# mi         16.0000
# avg_qty    25.5087
# Name: 8958, dtype: float64
# mi         16.000000
# avg_qty    25.563753
# Name: 8959, dtype: float64
# mi         16.000000
# avg_qty    25.588162
# Name: 8960, dtype: float64
# mi         16.000000
# avg_qty    25.471916
# Name: 8961, dtype: float64
# mi         16.000000
# avg_qty    25.576289
# Name: 8962, dtype: float64
# mi         16.000000
# avg_qty    25.472303
# Name: 8963, dtype: float64
# mi         16.000000
# avg_qty    25.520714
# Name: 8964, dtype: float64
# mi         16.000000
# avg_qty    25.609515
# Name: 8965, dtype: float64
# mi         16.000000
# avg_qty    25.592227
# Name: 8966, dtype: float64
# mi         16.000000
# avg_qty    25.547756
# Name: 8967, dtype: float64
# mi         16.000000
# avg_qty    25.503814
# Name: 8968, dtype: float64
# mi         16.000000
# avg_qty    25.537565
# Name: 8969, dtype: float64
# mi         16.0000
# avg_qty    25.5817
# Name: 8970, dtype: float64
# mi         16.000000
# avg_qty    25.548073
# Name: 8971, dtype: float64
# mi         16.000000
# avg_qty    25.558684
# Name: 8972, dtype: float64
# mi         16.000000
# avg_qty    25.547505
# Name: 8973, dtype: float64
# mi         16.000000
# avg_qty    25.536708
# Name: 8974, dtype: float64
# mi         16.00000
# avg_qty    25.53091
# Name: 8975, dtype: float64
# mi         16.00000
# avg_qty    25.63152
# Name: 8976, dtype: float64
# mi         16.000000
# avg_qty    25.560206
# Name: 8977, dtype: float64
# mi         16.000000
# avg_qty    25.514849
# Name: 8978, dtype: float64
# mi         16.000000
# avg_qty    25.498502
# Name: 8979, dtype: float64
# mi         16.0000
# avg_qty    25.5725
# Name: 8980, dtype: float64
# mi         16.000000
# avg_qty    25.547044
# Name: 8981, dtype: float64
# mi         16.000000
# avg_qty    25.547639
# Name: 8982, dtype: float64
# mi         16.000000
# avg_qty    25.466084
# Name: 8983, dtype: float64
# mi         16.000000
# avg_qty    25.539037
# Name: 8984, dtype: float64
# mi         16.00000
# avg_qty    25.56038
# Name: 8985, dtype: float64
# mi         16.000000
# avg_qty    25.562939
# Name: 8986, dtype: float64
# mi         16.000000
# avg_qty    25.454448
# Name: 8987, dtype: float64
# mi         16.000000
# avg_qty    25.579907
# Name: 8988, dtype: float64
# mi         16.000000
# avg_qty    25.522967
# Name: 8989, dtype: float64
# mi         16.000000
# avg_qty    25.504297
# Name: 8990, dtype: float64
# mi         16.000000
# avg_qty    25.473383
# Name: 8991, dtype: float64
# mi         16.000000
# avg_qty    25.508646
# Name: 8992, dtype: float64
# mi         16.00000
# avg_qty    25.58998
# Name: 8993, dtype: float64
# mi         16.000000
# avg_qty    25.486627
# Name: 8994, dtype: float64
# mi         16.000000
# avg_qty    25.554592
# Name: 8995, dtype: float64
# mi         16.000000
# avg_qty    25.575317
# Name: 8996, dtype: float64
# mi         16.000000
# avg_qty    25.553567
# Name: 8997, dtype: float64
# mi         16.00000
# avg_qty    25.52285
# Name: 8998, dtype: float64
# mi         16.000000
# avg_qty    25.608869
# Name: 8999, dtype: float64
#              mi  absolute error avg_qty  relative error avg_qty
# 0      0.001248                0.087245                0.341634
# 1      0.001248                1.693890                6.632930
# 2      0.001248                1.062475                4.160436
# 3      0.001248                0.106110                0.415504
# 4      0.001248                0.258054                1.010486
# ...         ...                     ...                     ...
# 8995  16.000000                0.017005                0.066589
# 8996  16.000000                0.037730                0.147744
# 8997  16.000000                0.015980                0.062574
# 8998  16.000000                0.014737                0.057709
# 8999  16.000000                0.071282                0.279127
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 avg_qty mean  avg_qty var
# type factor
# pac  0.001248      25.520313     0.598462
#      0.015625      25.547156     0.048400
#      0.031250      25.532609     0.024234
#      0.062500      25.537665     0.013080
#      0.250000      25.535957     0.004383
#      1.000000      25.538286     0.002040
#      2.000000      25.538254     0.001725
#      4.000000      25.539666     0.001604
#      16.000000     25.537078     0.001508

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error avg_qty mean  absolute error avg_qty var  \
# type factor
# pac  0.001248                      0.625139                    0.207570
#      0.015625                      0.177041                    0.017117
#      0.031250                      0.124244                    0.008806
#      0.062500                      0.090314                    0.004915
#      0.250000                      0.053695                    0.001500
#      1.000000                      0.035734                    0.000762
#      2.000000                      0.033115                    0.000628
#      4.000000                      0.032145                    0.000574
#      16.000000                     0.030651                    0.000568
#
#                 relative error avg_qty mean  relative error avg_qty var
# type factor
# pac  0.001248                      2.447918                    3.182765
#      0.015625                      0.693255                    0.262462
#      0.031250                      0.486513                    0.135032
#      0.062500                      0.353650                    0.075361
#      0.250000                      0.210259                    0.022997
#      1.000000                      0.139929                    0.011690
#      2.000000                      0.129672                    0.009622
#      4.000000                      0.125872                    0.008802
#      16.000000                     0.120025                    0.008707

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#             avg_qty
# mi
# 0.001248   0.598462
# 0.015625   0.048400
# 0.031250   0.024234
# 0.062500   0.013080
# 0.250000   0.004383
# 1.000000   0.002040
# 2.000000   0.001725
# 4.000000   0.001604
# 16.000000  0.001508

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step          scale
# query       avg_qty
# mi
# 0.001248   0.570275
# 0.015625   0.045561
# 0.031250   0.022780
# 0.062500   0.011390
# 0.250000   0.002848
# 1.000000   0.000712
# 2.000000   0.000356
# 4.000000   0.000178
# 16.000000  0.000044

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# avg_qty    0.117329
# dtype: float64
#             avg_qty
# mi
# 0.001248   0.120344
# 0.015625   0.113145
# 0.031250   0.112985
# 0.062500   0.119483
# 0.250000   0.121656
# 1.000000   0.115930
# 2.000000   0.113932
# 4.000000   0.120324
# 16.000000  0.118167

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71998/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query               avg_qty
# mi
# 0.001248           0.625313
# 0.015625           0.173965
# 0.031250           0.118939
# 0.062500           0.085385
# 0.250000           0.041856
# 1.000000           0.022226
# 2.000000           0.014713
# 4.000000           0.010546
# 16.000000          0.005228

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71998/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71998/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query           avg_qty
# mi
# 0.001248      25.538142
# 0.015625      25.537356
# 0.031250      25.539039
# 0.062500      25.537363
# 0.250000      25.537718
# 1.000000      25.539808
# 2.000000      25.537326
# 4.000000      25.538803
# 16.000000     25.537056
# step   chosen_sample
# query        avg_qty
# all mi     25.538068

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_71998/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#             avg_qty
# mi
# 0.001248   2.447918
# 0.015625   0.693255
# 0.031250   0.486513
# 0.062500   0.353650
# 0.250000   0.210259
# 1.000000   0.139929
# 2.000000   0.129672
# 4.000000   0.125872
# 16.000000  0.120025

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#             avg_qty
# mi
# 0.001248   2.327574
# 0.015625   0.580111
# 0.031250   0.373528
# 0.062500   0.234167
# 0.250000   0.088603
# 1.000000   0.023999
# 2.000000   0.015740
# 4.000000   0.005549
# 16.000000  0.001857

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()
