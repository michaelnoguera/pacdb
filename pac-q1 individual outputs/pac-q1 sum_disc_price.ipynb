# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   -- sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   -- avg(l_quantity) as avg_qty,
#   -- avg(l_extendedprice) as avg_price,
#   -- avg(l_discount) as avg_disc,
#   -- count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'N'
#   and l_linestatus = 'F'
# ```

# %%
EXPERIMENT = 'pac-q1-sum-disc-price-N-F'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'N') &
        (lineitem_df['l_linestatus'] == 'F')
    ]
    # print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    # charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        float(discounted_price.sum()),                      # sum_disc_price
        # float(charged_price.sum()),                         # sum_charge
        # float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        # float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        # float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        # float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    # print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# [127132372.6512]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['sum_disc_price']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 3765  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        print(f'iteration : {i}')
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    out_np = generate_samples() # generate samples (results of running the query)
    print(f"Generate samples... {len(out_np)} samples generated.")

    print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# iteration : 0
# iteration : 1
# iteration : 2
# iteration : 3
# iteration : 4
# iteration : 5
# iteration : 6
# iteration : 7
# iteration : 8
# iteration : 9
# iteration : 10
# iteration : 11
# iteration : 12
# iteration : 13
# iteration : 14
# iteration : 15
# iteration : 16
# iteration : 17
# iteration : 18
# iteration : 19
# iteration : 20
# iteration : 21
# iteration : 22
# iteration : 23
# iteration : 24
# iteration : 25
# iteration : 26
# iteration : 27
# iteration : 28
# iteration : 29
# iteration : 30
# iteration : 31
# iteration : 32
# iteration : 33
# iteration : 34
# iteration : 35
# iteration : 36
# iteration : 37
# iteration : 38
# iteration : 39
# iteration : 40
# iteration : 41
# iteration : 42
# iteration : 43
# iteration : 44
# iteration : 45
# iteration : 46
# iteration : 47
# iteration : 48
# iteration : 49
# iteration : 50
# iteration : 51
# iteration : 52
# iteration : 53
# iteration : 54
# iteration : 55
# iteration : 56
# iteration : 57
# iteration : 58
# iteration : 59
# iteration : 60
# iteration : 61
# iteration : 62
# iteration : 63
# iteration : 64
# iteration : 65
# iteration : 66
# iteration : 67
# iteration : 68
# iteration : 69
# iteration : 70
# iteration : 71
# iteration : 72
# iteration : 73
# iteration : 74
# iteration : 75
# iteration : 76
# iteration : 77
# iteration : 78
# iteration : 79
# iteration : 80
# iteration : 81
# iteration : 82
# iteration : 83
# iteration : 84
# iteration : 85
# iteration : 86
# iteration : 87
# iteration : 88
# iteration : 89
# iteration : 90
# iteration : 91
# iteration : 92
# iteration : 93
# iteration : 94
# iteration : 95
# iteration : 96
# iteration : 97
# iteration : 98
# iteration : 99
# iteration : 100
# iteration : 101
# iteration : 102
# iteration : 103
# iteration : 104
# iteration : 105
# iteration : 106
# iteration : 107
# iteration : 108
# iteration : 109
# iteration : 110
# iteration : 111
# iteration : 112
# iteration : 113
# iteration : 114
# iteration : 115
# iteration : 116
# iteration : 117
# iteration : 118
# iteration : 119
# iteration : 120
# iteration : 121
# iteration : 122
# iteration : 123
# iteration : 124
# iteration : 125
# iteration : 126
# iteration : 127
# iteration : 128
# iteration : 129
# iteration : 130
# iteration : 131
# iteration : 132
# iteration : 133
# iteration : 134
# iteration : 135
# iteration : 136
# iteration : 137
# iteration : 138
# iteration : 139
# iteration : 140
# iteration : 141
# iteration : 142
# iteration : 143
# iteration : 144
# iteration : 145
# iteration : 146
# iteration : 147
# iteration : 148
# iteration : 149
# iteration : 150
# iteration : 151
# iteration : 152
# iteration : 153
# iteration : 154
# iteration : 155
# iteration : 156
# iteration : 157
# iteration : 158
# iteration : 159
# iteration : 160
# iteration : 161
# iteration : 162
# iteration : 163
# iteration : 164
# iteration : 165
# iteration : 166
# iteration : 167
# iteration : 168
# iteration : 169
# iteration : 170
# iteration : 171
# iteration : 172
# iteration : 173
# iteration : 174
# iteration : 175
# iteration : 176
# iteration : 177
# iteration : 178
# iteration : 179
# iteration : 180
# iteration : 181
# iteration : 182
# iteration : 183
# iteration : 184
# iteration : 185
# iteration : 186
# iteration : 187
# iteration : 188
# iteration : 189
# iteration : 190
# iteration : 191
# iteration : 192
# iteration : 193
# iteration : 194
# iteration : 195
# iteration : 196
# iteration : 197
# iteration : 198
# iteration : 199
# iteration : 200
# iteration : 201
# iteration : 202
# iteration : 203
# iteration : 204
# iteration : 205
# iteration : 206
# iteration : 207
# iteration : 208
# iteration : 209
# iteration : 210
# iteration : 211
# iteration : 212
# iteration : 213
# iteration : 214
# iteration : 215
# iteration : 216
# iteration : 217
# iteration : 218
# iteration : 219
# iteration : 220
# iteration : 221
# iteration : 222
# iteration : 223
# iteration : 224
# iteration : 225
# iteration : 226
# iteration : 227
# iteration : 228
# iteration : 229
# iteration : 230
# iteration : 231
# iteration : 232
# iteration : 233
# iteration : 234
# iteration : 235
# iteration : 236
# iteration : 237
# iteration : 238
# iteration : 239
# iteration : 240
# iteration : 241
# iteration : 242
# iteration : 243
# iteration : 244
# iteration : 245
# iteration : 246
# iteration : 247
# iteration : 248
# iteration : 249
# iteration : 250
# iteration : 251
# iteration : 252
# iteration : 253
# iteration : 254
# iteration : 255
# iteration : 256
# iteration : 257
# iteration : 258
# iteration : 259
# iteration : 260
# iteration : 261
# iteration : 262
# iteration : 263
# iteration : 264
# iteration : 265
# iteration : 266
# iteration : 267
# iteration : 268
# iteration : 269
# iteration : 270
# iteration : 271
# iteration : 272
# iteration : 273
# iteration : 274
# iteration : 275
# iteration : 276
# iteration : 277
# iteration : 278
# iteration : 279
# iteration : 280
# iteration : 281
# iteration : 282
# iteration : 283
# iteration : 284
# iteration : 285
# iteration : 286
# iteration : 287
# iteration : 288
# iteration : 289
# iteration : 290
# iteration : 291
# iteration : 292
# iteration : 293
# iteration : 294
# iteration : 295
# iteration : 296
# iteration : 297
# iteration : 298
# iteration : 299
# iteration : 300
# iteration : 301
# iteration : 302
# iteration : 303
# iteration : 304
# iteration : 305
# iteration : 306
# iteration : 307
# iteration : 308
# iteration : 309
# iteration : 310
# iteration : 311
# iteration : 312
# iteration : 313
# iteration : 314
# iteration : 315
# iteration : 316
# iteration : 317
# iteration : 318
# iteration : 319
# iteration : 320
# iteration : 321
# iteration : 322
# iteration : 323
# iteration : 324
# iteration : 325
# iteration : 326
# iteration : 327
# iteration : 328
# iteration : 329
# iteration : 330
# iteration : 331
# iteration : 332
# iteration : 333
# iteration : 334
# iteration : 335
# iteration : 336
# iteration : 337
# iteration : 338
# iteration : 339
# iteration : 340
# iteration : 341
# iteration : 342
# iteration : 343
# iteration : 344
# iteration : 345
# iteration : 346
# iteration : 347
# iteration : 348
# iteration : 349
# iteration : 350
# iteration : 351
# iteration : 352
# iteration : 353
# iteration : 354
# iteration : 355
# iteration : 356
# iteration : 357
# iteration : 358
# iteration : 359
# iteration : 360
# iteration : 361
# iteration : 362
# iteration : 363
# iteration : 364
# iteration : 365
# iteration : 366
# iteration : 367
# iteration : 368
# iteration : 369
# iteration : 370
# iteration : 371
# iteration : 372
# iteration : 373
# iteration : 374
# iteration : 375
# iteration : 376
# iteration : 377
# iteration : 378
# iteration : 379
# iteration : 380
# iteration : 381
# iteration : 382
# iteration : 383
# iteration : 384
# iteration : 385
# iteration : 386
# iteration : 387
# iteration : 388
# iteration : 389
# iteration : 390
# iteration : 391
# iteration : 392
# iteration : 393
# iteration : 394
# iteration : 395
# iteration : 396
# iteration : 397
# iteration : 398
# iteration : 399
# iteration : 400
# iteration : 401
# iteration : 402
# iteration : 403
# iteration : 404
# iteration : 405
# iteration : 406
# iteration : 407
# iteration : 408
# iteration : 409
# iteration : 410
# iteration : 411
# iteration : 412
# iteration : 413
# iteration : 414
# iteration : 415
# iteration : 416
# iteration : 417
# iteration : 418
# iteration : 419
# iteration : 420
# iteration : 421
# iteration : 422
# iteration : 423
# iteration : 424
# iteration : 425
# iteration : 426
# iteration : 427
# iteration : 428
# iteration : 429
# iteration : 430
# iteration : 431
# iteration : 432
# iteration : 433
# iteration : 434
# iteration : 435
# iteration : 436
# iteration : 437
# iteration : 438
# iteration : 439
# iteration : 440
# iteration : 441
# iteration : 442
# iteration : 443
# iteration : 444
# iteration : 445
# iteration : 446
# iteration : 447
# iteration : 448
# iteration : 449
# iteration : 450
# iteration : 451
# iteration : 452
# iteration : 453
# iteration : 454
# iteration : 455
# iteration : 456
# iteration : 457
# iteration : 458
# iteration : 459
# iteration : 460
# iteration : 461
# iteration : 462
# iteration : 463
# iteration : 464
# iteration : 465
# iteration : 466
# iteration : 467
# iteration : 468
# iteration : 469
# iteration : 470
# iteration : 471
# iteration : 472
# iteration : 473
# iteration : 474
# iteration : 475
# iteration : 476
# iteration : 477
# iteration : 478
# iteration : 479
# iteration : 480
# iteration : 481
# iteration : 482
# iteration : 483
# iteration : 484
# iteration : 485
# iteration : 486
# iteration : 487
# iteration : 488
# iteration : 489
# iteration : 490
# iteration : 491
# iteration : 492
# iteration : 493
# iteration : 494
# iteration : 495
# iteration : 496
# iteration : 497
# iteration : 498
# iteration : 499
# iteration : 500
# iteration : 501
# iteration : 502
# iteration : 503
# iteration : 504
# iteration : 505
# iteration : 506
# iteration : 507
# iteration : 508
# iteration : 509
# iteration : 510
# iteration : 511
# iteration : 512
# iteration : 513
# iteration : 514
# iteration : 515
# iteration : 516
# iteration : 517
# iteration : 518
# iteration : 519
# iteration : 520
# iteration : 521
# iteration : 522
# iteration : 523
# iteration : 524
# iteration : 525
# iteration : 526
# iteration : 527
# iteration : 528
# iteration : 529
# iteration : 530
# iteration : 531
# iteration : 532
# iteration : 533
# iteration : 534
# iteration : 535
# iteration : 536
# iteration : 537
# iteration : 538
# iteration : 539
# iteration : 540
# iteration : 541
# iteration : 542
# iteration : 543
# iteration : 544
# iteration : 545
# iteration : 546
# iteration : 547
# iteration : 548
# iteration : 549
# iteration : 550
# iteration : 551
# iteration : 552
# iteration : 553
# iteration : 554
# iteration : 555
# iteration : 556
# iteration : 557
# iteration : 558
# iteration : 559
# iteration : 560
# iteration : 561
# iteration : 562
# iteration : 563
# iteration : 564
# iteration : 565
# iteration : 566
# iteration : 567
# iteration : 568
# iteration : 569
# iteration : 570
# iteration : 571
# iteration : 572
# iteration : 573
# iteration : 574
# iteration : 575
# iteration : 576
# iteration : 577
# iteration : 578
# iteration : 579
# iteration : 580
# iteration : 581
# iteration : 582
# iteration : 583
# iteration : 584
# iteration : 585
# iteration : 586
# iteration : 587
# iteration : 588
# iteration : 589
# iteration : 590
# iteration : 591
# iteration : 592
# iteration : 593
# iteration : 594
# iteration : 595
# iteration : 596
# iteration : 597
# iteration : 598
# iteration : 599
# iteration : 600
# iteration : 601
# iteration : 602
# iteration : 603
# iteration : 604
# iteration : 605
# iteration : 606
# iteration : 607
# iteration : 608
# iteration : 609
# iteration : 610
# iteration : 611
# iteration : 612
# iteration : 613
# iteration : 614
# iteration : 615
# iteration : 616
# iteration : 617
# iteration : 618
# iteration : 619
# iteration : 620
# iteration : 621
# iteration : 622
# iteration : 623
# iteration : 624
# iteration : 625
# iteration : 626
# iteration : 627
# iteration : 628
# iteration : 629
# iteration : 630
# iteration : 631
# iteration : 632
# iteration : 633
# iteration : 634
# iteration : 635
# iteration : 636
# iteration : 637
# iteration : 638
# iteration : 639
# iteration : 640
# iteration : 641
# iteration : 642
# iteration : 643
# iteration : 644
# iteration : 645
# iteration : 646
# iteration : 647
# iteration : 648
# iteration : 649
# iteration : 650
# iteration : 651
# iteration : 652
# iteration : 653
# iteration : 654
# iteration : 655
# iteration : 656
# iteration : 657
# iteration : 658
# iteration : 659
# iteration : 660
# iteration : 661
# iteration : 662
# iteration : 663
# iteration : 664
# iteration : 665
# iteration : 666
# iteration : 667
# iteration : 668
# iteration : 669
# iteration : 670
# iteration : 671
# iteration : 672
# iteration : 673
# iteration : 674
# iteration : 675
# iteration : 676
# iteration : 677
# iteration : 678
# iteration : 679
# iteration : 680
# iteration : 681
# iteration : 682
# iteration : 683
# iteration : 684
# iteration : 685
# iteration : 686
# iteration : 687
# iteration : 688
# iteration : 689
# iteration : 690
# iteration : 691
# iteration : 692
# iteration : 693
# iteration : 694
# iteration : 695
# iteration : 696
# iteration : 697
# iteration : 698
# iteration : 699
# iteration : 700
# iteration : 701
# iteration : 702
# iteration : 703
# iteration : 704
# iteration : 705
# iteration : 706
# iteration : 707
# iteration : 708
# iteration : 709
# iteration : 710
# iteration : 711
# iteration : 712
# iteration : 713
# iteration : 714
# iteration : 715
# iteration : 716
# iteration : 717
# iteration : 718
# iteration : 719
# iteration : 720
# iteration : 721
# iteration : 722
# iteration : 723
# iteration : 724
# iteration : 725
# iteration : 726
# iteration : 727
# iteration : 728
# iteration : 729
# iteration : 730
# iteration : 731
# iteration : 732
# iteration : 733
# iteration : 734
# iteration : 735
# iteration : 736
# iteration : 737
# iteration : 738
# iteration : 739
# iteration : 740
# iteration : 741
# iteration : 742
# iteration : 743
# iteration : 744
# iteration : 745
# iteration : 746
# iteration : 747
# iteration : 748
# iteration : 749
# iteration : 750
# iteration : 751
# iteration : 752
# iteration : 753
# iteration : 754
# iteration : 755
# iteration : 756
# iteration : 757
# iteration : 758
# iteration : 759
# iteration : 760
# iteration : 761
# iteration : 762
# iteration : 763
# iteration : 764
# iteration : 765
# iteration : 766
# iteration : 767
# iteration : 768
# iteration : 769
# iteration : 770
# iteration : 771
# iteration : 772
# iteration : 773
# iteration : 774
# iteration : 775
# iteration : 776
# iteration : 777
# iteration : 778
# iteration : 779
# iteration : 780
# iteration : 781
# iteration : 782
# iteration : 783
# iteration : 784
# iteration : 785
# iteration : 786
# iteration : 787
# iteration : 788
# iteration : 789
# iteration : 790
# iteration : 791
# iteration : 792
# iteration : 793
# iteration : 794
# iteration : 795
# iteration : 796
# iteration : 797
# iteration : 798
# iteration : 799
# iteration : 800
# iteration : 801
# iteration : 802
# iteration : 803
# iteration : 804
# iteration : 805
# iteration : 806
# iteration : 807
# iteration : 808
# iteration : 809
# iteration : 810
# iteration : 811
# iteration : 812
# iteration : 813
# iteration : 814
# iteration : 815
# iteration : 816
# iteration : 817
# iteration : 818
# iteration : 819
# iteration : 820
# iteration : 821
# iteration : 822
# iteration : 823
# iteration : 824
# iteration : 825
# iteration : 826
# iteration : 827
# iteration : 828
# iteration : 829
# iteration : 830
# iteration : 831
# iteration : 832
# iteration : 833
# iteration : 834
# iteration : 835
# iteration : 836
# iteration : 837
# iteration : 838
# iteration : 839
# iteration : 840
# iteration : 841
# iteration : 842
# iteration : 843
# iteration : 844
# iteration : 845
# iteration : 846
# iteration : 847
# iteration : 848
# iteration : 849
# iteration : 850
# iteration : 851
# iteration : 852
# iteration : 853
# iteration : 854
# iteration : 855
# iteration : 856
# iteration : 857
# iteration : 858
# iteration : 859
# iteration : 860
# iteration : 861
# iteration : 862
# iteration : 863
# iteration : 864
# iteration : 865
# iteration : 866
# iteration : 867
# iteration : 868
# iteration : 869
# iteration : 870
# iteration : 871
# iteration : 872
# iteration : 873
# iteration : 874
# iteration : 875
# iteration : 876
# iteration : 877
# iteration : 878
# iteration : 879
# iteration : 880
# iteration : 881
# iteration : 882
# iteration : 883
# iteration : 884
# iteration : 885
# iteration : 886
# iteration : 887
# iteration : 888
# iteration : 889
# iteration : 890
# iteration : 891
# iteration : 892
# iteration : 893
# iteration : 894
# iteration : 895
# iteration : 896
# iteration : 897
# iteration : 898
# iteration : 899
# iteration : 900
# iteration : 901
# iteration : 902
# iteration : 903
# iteration : 904
# iteration : 905
# iteration : 906
# iteration : 907
# iteration : 908
# iteration : 909
# iteration : 910
# iteration : 911
# iteration : 912
# iteration : 913
# iteration : 914
# iteration : 915
# iteration : 916
# iteration : 917
# iteration : 918
# iteration : 919
# iteration : 920
# iteration : 921
# iteration : 922
# iteration : 923
# iteration : 924
# iteration : 925
# iteration : 926
# iteration : 927
# iteration : 928
# iteration : 929
# iteration : 930
# iteration : 931
# iteration : 932
# iteration : 933
# iteration : 934
# iteration : 935
# iteration : 936
# iteration : 937
# iteration : 938
# iteration : 939
# iteration : 940
# iteration : 941
# iteration : 942
# iteration : 943
# iteration : 944
# iteration : 945
# iteration : 946
# iteration : 947
# iteration : 948
# iteration : 949
# iteration : 950
# iteration : 951
# iteration : 952
# iteration : 953
# iteration : 954
# iteration : 955
# iteration : 956
# iteration : 957
# iteration : 958
# iteration : 959
# iteration : 960
# iteration : 961
# iteration : 962
# iteration : 963
# iteration : 964
# iteration : 965
# iteration : 966
# iteration : 967
# iteration : 968
# iteration : 969
# iteration : 970
# iteration : 971
# iteration : 972
# iteration : 973
# iteration : 974
# iteration : 975
# iteration : 976
# iteration : 977
# iteration : 978
# iteration : 979
# iteration : 980
# iteration : 981
# iteration : 982
# iteration : 983
# iteration : 984
# iteration : 985
# iteration : 986
# iteration : 987
# iteration : 988
# iteration : 989
# iteration : 990
# iteration : 991
# iteration : 992
# iteration : 993
# iteration : 994
# iteration : 995
# iteration : 996
# iteration : 997
# iteration : 998
# iteration : 999
# iteration : 1000
# iteration : 1001
# iteration : 1002
# iteration : 1003
# iteration : 1004
# iteration : 1005
# iteration : 1006
# iteration : 1007
# iteration : 1008
# iteration : 1009
# iteration : 1010
# iteration : 1011
# iteration : 1012
# iteration : 1013
# iteration : 1014
# iteration : 1015
# iteration : 1016
# iteration : 1017
# iteration : 1018
# iteration : 1019
# iteration : 1020
# iteration : 1021
# iteration : 1022
# iteration : 1023
# iteration : 1024
# iteration : 1025
# iteration : 1026
# iteration : 1027
# iteration : 1028
# iteration : 1029
# iteration : 1030
# iteration : 1031
# iteration : 1032
# iteration : 1033
# iteration : 1034
# iteration : 1035
# iteration : 1036
# iteration : 1037
# iteration : 1038
# iteration : 1039
# iteration : 1040
# iteration : 1041
# iteration : 1042
# iteration : 1043
# iteration : 1044
# iteration : 1045
# iteration : 1046
# iteration : 1047
# iteration : 1048
# iteration : 1049
# iteration : 1050
# iteration : 1051
# iteration : 1052
# iteration : 1053
# iteration : 1054
# iteration : 1055
# iteration : 1056
# iteration : 1057
# iteration : 1058
# iteration : 1059
# iteration : 1060
# iteration : 1061
# iteration : 1062
# iteration : 1063
# iteration : 1064
# iteration : 1065
# iteration : 1066
# iteration : 1067
# iteration : 1068
# iteration : 1069
# iteration : 1070
# iteration : 1071
# iteration : 1072
# iteration : 1073
# iteration : 1074
# iteration : 1075
# iteration : 1076
# iteration : 1077
# iteration : 1078
# iteration : 1079
# iteration : 1080
# iteration : 1081
# iteration : 1082
# iteration : 1083
# iteration : 1084
# iteration : 1085
# iteration : 1086
# iteration : 1087
# iteration : 1088
# iteration : 1089
# iteration : 1090
# iteration : 1091
# iteration : 1092
# iteration : 1093
# iteration : 1094
# iteration : 1095
# iteration : 1096
# iteration : 1097
# iteration : 1098
# iteration : 1099
# iteration : 1100
# iteration : 1101
# iteration : 1102
# iteration : 1103
# iteration : 1104
# iteration : 1105
# iteration : 1106
# iteration : 1107
# iteration : 1108
# iteration : 1109
# iteration : 1110
# iteration : 1111
# iteration : 1112
# iteration : 1113
# iteration : 1114
# iteration : 1115
# iteration : 1116
# iteration : 1117
# iteration : 1118
# iteration : 1119
# iteration : 1120
# iteration : 1121
# iteration : 1122
# iteration : 1123
# iteration : 1124
# iteration : 1125
# iteration : 1126
# iteration : 1127
# iteration : 1128
# iteration : 1129
# iteration : 1130
# iteration : 1131
# iteration : 1132
# iteration : 1133
# iteration : 1134
# iteration : 1135
# iteration : 1136
# iteration : 1137
# iteration : 1138
# iteration : 1139
# iteration : 1140
# iteration : 1141
# iteration : 1142
# iteration : 1143
# iteration : 1144
# iteration : 1145
# iteration : 1146
# iteration : 1147
# iteration : 1148
# iteration : 1149
# iteration : 1150
# iteration : 1151
# iteration : 1152
# iteration : 1153
# iteration : 1154
# iteration : 1155
# iteration : 1156
# iteration : 1157
# iteration : 1158
# iteration : 1159
# iteration : 1160
# iteration : 1161
# iteration : 1162
# iteration : 1163
# iteration : 1164
# iteration : 1165
# iteration : 1166
# iteration : 1167
# iteration : 1168
# iteration : 1169
# iteration : 1170
# iteration : 1171
# iteration : 1172
# iteration : 1173
# iteration : 1174
# iteration : 1175
# iteration : 1176
# iteration : 1177
# iteration : 1178
# iteration : 1179
# iteration : 1180
# iteration : 1181
# iteration : 1182
# iteration : 1183
# iteration : 1184
# iteration : 1185
# iteration : 1186
# iteration : 1187
# iteration : 1188
# iteration : 1189
# iteration : 1190
# iteration : 1191
# iteration : 1192
# iteration : 1193
# iteration : 1194
# iteration : 1195
# iteration : 1196
# iteration : 1197
# iteration : 1198
# iteration : 1199
# iteration : 1200
# iteration : 1201
# iteration : 1202
# iteration : 1203
# iteration : 1204
# iteration : 1205
# iteration : 1206
# iteration : 1207
# iteration : 1208
# iteration : 1209
# iteration : 1210
# iteration : 1211
# iteration : 1212
# iteration : 1213
# iteration : 1214
# iteration : 1215
# iteration : 1216
# iteration : 1217
# iteration : 1218
# iteration : 1219
# iteration : 1220
# iteration : 1221
# iteration : 1222
# iteration : 1223
# iteration : 1224
# iteration : 1225
# iteration : 1226
# iteration : 1227
# iteration : 1228
# iteration : 1229
# iteration : 1230
# iteration : 1231
# iteration : 1232
# iteration : 1233
# iteration : 1234
# iteration : 1235
# iteration : 1236
# iteration : 1237
# iteration : 1238
# iteration : 1239
# iteration : 1240
# iteration : 1241
# iteration : 1242
# iteration : 1243
# iteration : 1244
# iteration : 1245
# iteration : 1246
# iteration : 1247
# iteration : 1248
# iteration : 1249
# iteration : 1250
# iteration : 1251
# iteration : 1252
# iteration : 1253
# iteration : 1254
# iteration : 1255
# iteration : 1256
# iteration : 1257
# iteration : 1258
# iteration : 1259
# iteration : 1260
# iteration : 1261
# iteration : 1262
# iteration : 1263
# iteration : 1264
# iteration : 1265
# iteration : 1266
# iteration : 1267
# iteration : 1268
# iteration : 1269
# iteration : 1270
# iteration : 1271
# iteration : 1272
# iteration : 1273
# iteration : 1274
# iteration : 1275
# iteration : 1276
# iteration : 1277
# iteration : 1278
# iteration : 1279
# iteration : 1280
# iteration : 1281
# iteration : 1282
# iteration : 1283
# iteration : 1284
# iteration : 1285
# iteration : 1286
# iteration : 1287
# iteration : 1288
# iteration : 1289
# iteration : 1290
# iteration : 1291
# iteration : 1292
# iteration : 1293
# iteration : 1294
# iteration : 1295
# iteration : 1296
# iteration : 1297
# iteration : 1298
# iteration : 1299
# iteration : 1300
# iteration : 1301
# iteration : 1302
# iteration : 1303
# iteration : 1304
# iteration : 1305
# iteration : 1306
# iteration : 1307
# iteration : 1308
# iteration : 1309
# iteration : 1310
# iteration : 1311
# iteration : 1312
# iteration : 1313
# iteration : 1314
# iteration : 1315
# iteration : 1316
# iteration : 1317
# iteration : 1318
# iteration : 1319
# iteration : 1320
# iteration : 1321
# iteration : 1322
# iteration : 1323
# iteration : 1324
# iteration : 1325
# iteration : 1326
# iteration : 1327
# iteration : 1328
# iteration : 1329
# iteration : 1330
# iteration : 1331
# iteration : 1332
# iteration : 1333
# iteration : 1334
# iteration : 1335
# iteration : 1336
# iteration : 1337
# iteration : 1338
# iteration : 1339
# iteration : 1340
# iteration : 1341
# iteration : 1342
# iteration : 1343
# iteration : 1344
# iteration : 1345
# iteration : 1346
# iteration : 1347
# iteration : 1348
# iteration : 1349
# iteration : 1350
# iteration : 1351
# iteration : 1352
# iteration : 1353
# iteration : 1354
# iteration : 1355
# iteration : 1356
# iteration : 1357
# iteration : 1358
# iteration : 1359
# iteration : 1360
# iteration : 1361
# iteration : 1362
# iteration : 1363
# iteration : 1364
# iteration : 1365
# iteration : 1366
# iteration : 1367
# iteration : 1368
# iteration : 1369
# iteration : 1370
# iteration : 1371
# iteration : 1372
# iteration : 1373
# iteration : 1374
# iteration : 1375
# iteration : 1376
# iteration : 1377
# iteration : 1378
# iteration : 1379
# iteration : 1380
# iteration : 1381
# iteration : 1382
# iteration : 1383
# iteration : 1384
# iteration : 1385
# iteration : 1386
# iteration : 1387
# iteration : 1388
# iteration : 1389
# iteration : 1390
# iteration : 1391
# iteration : 1392
# iteration : 1393
# iteration : 1394
# iteration : 1395
# iteration : 1396
# iteration : 1397
# iteration : 1398
# iteration : 1399
# iteration : 1400
# iteration : 1401
# iteration : 1402
# iteration : 1403
# iteration : 1404
# iteration : 1405
# iteration : 1406
# iteration : 1407
# iteration : 1408
# iteration : 1409
# iteration : 1410
# iteration : 1411
# iteration : 1412
# iteration : 1413
# iteration : 1414
# iteration : 1415
# iteration : 1416
# iteration : 1417
# iteration : 1418
# iteration : 1419
# iteration : 1420
# iteration : 1421
# iteration : 1422
# iteration : 1423
# iteration : 1424
# iteration : 1425
# iteration : 1426
# iteration : 1427
# iteration : 1428
# iteration : 1429
# iteration : 1430
# iteration : 1431
# iteration : 1432
# iteration : 1433
# iteration : 1434
# iteration : 1435
# iteration : 1436
# iteration : 1437
# iteration : 1438
# iteration : 1439
# iteration : 1440
# iteration : 1441
# iteration : 1442
# iteration : 1443
# iteration : 1444
# iteration : 1445
# iteration : 1446
# iteration : 1447
# iteration : 1448
# iteration : 1449
# iteration : 1450
# iteration : 1451
# iteration : 1452
# iteration : 1453
# iteration : 1454
# iteration : 1455
# iteration : 1456
# iteration : 1457
# iteration : 1458
# iteration : 1459
# iteration : 1460
# iteration : 1461
# iteration : 1462
# iteration : 1463
# iteration : 1464
# iteration : 1465
# iteration : 1466
# iteration : 1467
# iteration : 1468
# iteration : 1469
# iteration : 1470
# iteration : 1471
# iteration : 1472
# iteration : 1473
# iteration : 1474
# iteration : 1475
# iteration : 1476
# iteration : 1477
# iteration : 1478
# iteration : 1479
# iteration : 1480
# iteration : 1481
# iteration : 1482
# iteration : 1483
# iteration : 1484
# iteration : 1485
# iteration : 1486
# iteration : 1487
# iteration : 1488
# iteration : 1489
# iteration : 1490
# iteration : 1491
# iteration : 1492
# iteration : 1493
# iteration : 1494
# iteration : 1495
# iteration : 1496
# iteration : 1497
# iteration : 1498
# iteration : 1499
# iteration : 1500
# iteration : 1501
# iteration : 1502
# iteration : 1503
# iteration : 1504
# iteration : 1505
# iteration : 1506
# iteration : 1507
# iteration : 1508
# iteration : 1509
# iteration : 1510
# iteration : 1511
# iteration : 1512
# iteration : 1513
# iteration : 1514
# iteration : 1515
# iteration : 1516
# iteration : 1517
# iteration : 1518
# iteration : 1519
# iteration : 1520
# iteration : 1521
# iteration : 1522
# iteration : 1523
# iteration : 1524
# iteration : 1525
# iteration : 1526
# iteration : 1527
# iteration : 1528
# iteration : 1529
# iteration : 1530
# iteration : 1531
# iteration : 1532
# iteration : 1533
# iteration : 1534
# iteration : 1535
# iteration : 1536
# iteration : 1537
# iteration : 1538
# iteration : 1539
# iteration : 1540
# iteration : 1541
# iteration : 1542
# iteration : 1543
# iteration : 1544
# iteration : 1545
# iteration : 1546
# iteration : 1547
# iteration : 1548
# iteration : 1549
# iteration : 1550
# iteration : 1551
# iteration : 1552
# iteration : 1553
# iteration : 1554
# iteration : 1555
# iteration : 1556
# iteration : 1557
# iteration : 1558
# iteration : 1559
# iteration : 1560
# iteration : 1561
# iteration : 1562
# iteration : 1563
# iteration : 1564
# iteration : 1565
# iteration : 1566
# iteration : 1567
# iteration : 1568
# iteration : 1569
# iteration : 1570
# iteration : 1571
# iteration : 1572
# iteration : 1573
# iteration : 1574
# iteration : 1575
# iteration : 1576
# iteration : 1577
# iteration : 1578
# iteration : 1579
# iteration : 1580
# iteration : 1581
# iteration : 1582
# iteration : 1583
# iteration : 1584
# iteration : 1585
# iteration : 1586
# iteration : 1587
# iteration : 1588
# iteration : 1589
# iteration : 1590
# iteration : 1591
# iteration : 1592
# iteration : 1593
# iteration : 1594
# iteration : 1595
# iteration : 1596
# iteration : 1597
# iteration : 1598
# iteration : 1599
# iteration : 1600
# iteration : 1601
# iteration : 1602
# iteration : 1603
# iteration : 1604
# iteration : 1605
# iteration : 1606
# iteration : 1607
# iteration : 1608
# iteration : 1609
# iteration : 1610
# iteration : 1611
# iteration : 1612
# iteration : 1613
# iteration : 1614
# iteration : 1615
# iteration : 1616
# iteration : 1617
# iteration : 1618
# iteration : 1619
# iteration : 1620
# iteration : 1621
# iteration : 1622
# iteration : 1623
# iteration : 1624
# iteration : 1625
# iteration : 1626
# iteration : 1627
# iteration : 1628
# iteration : 1629
# iteration : 1630
# iteration : 1631
# iteration : 1632
# iteration : 1633
# iteration : 1634
# iteration : 1635
# iteration : 1636
# iteration : 1637
# iteration : 1638
# iteration : 1639
# iteration : 1640
# iteration : 1641
# iteration : 1642
# iteration : 1643
# iteration : 1644
# iteration : 1645
# iteration : 1646
# iteration : 1647
# iteration : 1648
# iteration : 1649
# iteration : 1650
# iteration : 1651
# iteration : 1652
# iteration : 1653
# iteration : 1654
# iteration : 1655
# iteration : 1656
# iteration : 1657
# iteration : 1658
# iteration : 1659
# iteration : 1660
# iteration : 1661
# iteration : 1662
# iteration : 1663
# iteration : 1664
# iteration : 1665
# iteration : 1666
# iteration : 1667
# iteration : 1668
# iteration : 1669
# iteration : 1670
# iteration : 1671
# iteration : 1672
# iteration : 1673
# iteration : 1674
# iteration : 1675
# iteration : 1676
# iteration : 1677
# iteration : 1678
# iteration : 1679
# iteration : 1680
# iteration : 1681
# iteration : 1682
# iteration : 1683
# iteration : 1684
# iteration : 1685
# iteration : 1686
# iteration : 1687
# iteration : 1688
# iteration : 1689
# iteration : 1690
# iteration : 1691
# iteration : 1692
# iteration : 1693
# iteration : 1694
# iteration : 1695
# iteration : 1696
# iteration : 1697
# iteration : 1698
# iteration : 1699
# iteration : 1700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/chaitanyasuma/pac/pacdb/pac-q1 individual outputs/pac-q1 sum_disc_price.ipynb Cell 14 line 1
#       <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> experiment_results = []
#       <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> saved_steps = []
# ---> <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a> out_np = generate_samples() # generate samples (results of running the query)
#      <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a> print(f"Generate samples... {len(out_np)} samples generated.")
#      <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=12'>13</a> print(out_np[0])
#
# /Users/chaitanyasuma/pac/pacdb/pac-q1 individual outputs/pac-q1 sum_disc_price.ipynb Cell 14 line 5
#      <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=55'>56</a> for i in range(number_of_pairs):
#      <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=56'>57</a>     print(f'iteration : {i}')
# ---> <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=57'>58</a>     for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
#      <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=58'>59</a>         out = runquery(temp_df)
#      <a href='vscode-notebook-cell:/Users/chaitanyasuma/pac/pacdb/pac-q1%20individual%20outputs/pac-q1%20sum_disc_price.ipynb#X16sZmlsZQ%3D%3D?line=59'>60</a>         # double the sums and counts, avg stays the same
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:6404, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6402     new_obj = self
#    6403 else:
# -> 6404     new_obj = self.copy(deep=None)
#    6405 if allow_duplicates is not lib.no_default:
#    6406     allow_duplicates = validate_bool_kwarg(allow_duplicates, "allow_duplicates")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:6808, in NDFrame.copy(self, deep)
#    6659 @final
#    6660 def copy(self, deep: bool_t | None = True) -> Self:
#    6661     """
#    6662     Make a copy of this object's indices and data.
#    6663
#    (...)
#    6806     dtype: int64
#    6807     """
# -> 6808     data = self._mgr.copy(deep=deep)
#    6809     self._clear_item_cache()
#    6810     return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#    6811         self, method="copy"
#    6812     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/managers.py:593, in BaseBlockManager.copy(self, deep)
#     590     else:
#     591         new_axes = list(self.axes)
# --> 593 res = self.apply("copy", deep=deep)
#     594 res.axes = new_axes
#     596 if self.ndim > 1:
#     597     # Avoid needing to re-compute these
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/blocks.py:796, in Block.copy(self, deep)
#     794 refs: BlockValuesRefs | None
#     795 if deep:
# --> 796     values = values.copy()
#     797     refs = None
#     798 else:
#
# KeyboardInterrupt:

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                    scale      chosen_sample  \
# 0  0.001248  [9.972871206732286e+16]  [5047459456.6414]
# 1  0.001248  [9.972871206732286e+16]  [5064221434.2172]
# 2  0.001248  [9.972871206732286e+16]  [5052737617.4446]
# 3  0.001248  [9.972871206732286e+16]  [5065522581.9294]
# 4  0.001248  [9.972871206732286e+16]  [5057572831.9406]
#
#             chosen_noise               release
# 0   [-508177540.3739331]  [4539281916.2674675]
# 1    [-320768350.055409]   [4743453084.161791]
# 2     [423248199.510061]   [5475985816.954661]
# 3   [-28632753.56203658]   [5036889828.367364]
# 4  [-464897620.91148645]   [4592675211.029114]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi          scale  chosen_sample   chosen_noise        release
# query           sum_disc_price sum_disc_price sum_disc_price sum_disc_price
# 0      0.001248   9.972871e+16   5.047459e+09  -5.081775e+08   4.539282e+09
# 1      0.001248   9.972871e+16   5.064221e+09  -3.207684e+08   4.743453e+09
# 2      0.001248   9.972871e+16   5.052738e+09   4.232482e+08   5.475986e+09
# 3      0.001248   9.972871e+16   5.065523e+09  -2.863275e+07   5.036890e+09
# 4      0.001248   9.972871e+16   5.057573e+09  -4.648976e+08   4.592675e+09

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_78615/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step               scale  chosen_sample   chosen_noise        release
# query     sum_disc_price sum_disc_price sum_disc_price sum_disc_price
# mi
# 0.001248    9.972871e+16   5.054302e+09   2.089340e+06   5.056392e+09
# 0.015625    7.967565e+15   5.053608e+09  -1.268601e+06   5.052339e+09
# 0.031250    3.983783e+15   5.053959e+09   1.835782e+06   5.055794e+09
# 0.062500    1.991891e+15   5.054040e+09   1.570846e+05   5.054197e+09
# 0.250000    4.979728e+14   5.054037e+09   4.690057e+05   5.054506e+09
# 1.000000    1.244932e+14   5.053354e+09   3.511071e+04   5.053390e+09
# 2.000000    6.224660e+13   5.053173e+09  -9.642707e+04   5.053076e+09
# 4.000000    3.112330e+13   5.054071e+09   3.167892e+05   5.054388e+09
# 16.000000   7.780826e+12   5.054566e+09   1.333936e+05   5.054700e+09

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['sum_disc_price'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi                1.248319e-03
# sum_disc_price    4.539282e+09
# Name: 0, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.743453e+09
# Name: 1, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.475986e+09
# Name: 2, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.036890e+09
# Name: 3, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.592675e+09
# Name: 4, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.617062e+09
# Name: 5, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.956426e+09
# Name: 6, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.984028e+09
# Name: 7, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.417037e+09
# Name: 8, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.596693e+09
# Name: 9, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.684064e+09
# Name: 10, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.939160e+09
# Name: 11, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.385831e+09
# Name: 12, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.532411e+09
# Name: 13, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.806824e+09
# Name: 14, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.475090e+09
# Name: 15, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.046122e+09
# Name: 16, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.036043e+09
# Name: 17, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.981721e+09
# Name: 18, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.038501e+09
# Name: 19, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.220645e+09
# Name: 20, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.541088e+09
# Name: 21, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.432814e+09
# Name: 22, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.072376e+09
# Name: 23, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.178594e+09
# Name: 24, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.399183e+09
# Name: 25, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.096671e+09
# Name: 26, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.916349e+09
# Name: 27, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.753828e+09
# Name: 28, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.826024e+09
# Name: 29, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.064686e+09
# Name: 30, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.617289e+09
# Name: 31, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.771412e+09
# Name: 32, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.884471e+09
# Name: 33, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.383292e+09
# Name: 34, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.454303e+09
# Name: 35, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.232639e+09
# Name: 36, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.555164e+09
# Name: 37, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.276011e+09
# Name: 38, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.376619e+09
# Name: 39, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.675526e+09
# Name: 40, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.537135e+09
# Name: 41, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.618508e+09
# Name: 42, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.452317e+09
# Name: 43, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.584905e+09
# Name: 44, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.220752e+09
# Name: 45, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.834952e+09
# Name: 46, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.223967e+09
# Name: 47, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.976335e+09
# Name: 48, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.215496e+09
# Name: 49, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.551067e+09
# Name: 50, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.289903e+09
# Name: 51, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.830498e+09
# Name: 52, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.172601e+09
# Name: 53, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.510842e+09
# Name: 54, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.928724e+09
# Name: 55, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.791309e+09
# Name: 56, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.190518e+09
# Name: 57, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.852585e+09
# Name: 58, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.005412e+09
# Name: 59, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.232081e+09
# Name: 60, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.027363e+09
# Name: 61, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.807799e+09
# Name: 62, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.155500e+09
# Name: 63, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.548328e+09
# Name: 64, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.043531e+09
# Name: 65, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.955788e+09
# Name: 66, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.307402e+09
# Name: 67, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.463661e+09
# Name: 68, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.253151e+09
# Name: 69, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.695244e+09
# Name: 70, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.116858e+09
# Name: 71, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.998971e+09
# Name: 72, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.889659e+09
# Name: 73, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.375070e+09
# Name: 74, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.788168e+09
# Name: 75, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.920203e+09
# Name: 76, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.864399e+09
# Name: 77, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.289482e+09
# Name: 78, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.711173e+09
# Name: 79, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.744970e+09
# Name: 80, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.469639e+09
# Name: 81, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.600468e+09
# Name: 82, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.234238e+09
# Name: 83, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.014497e+09
# Name: 84, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.897629e+09
# Name: 85, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.086941e+09
# Name: 86, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.765018e+09
# Name: 87, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.209192e+09
# Name: 88, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.579514e+09
# Name: 89, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.234366e+09
# Name: 90, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.206501e+09
# Name: 91, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.222145e+09
# Name: 92, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.133627e+09
# Name: 93, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.400041e+09
# Name: 94, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.771801e+09
# Name: 95, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.967126e+09
# Name: 96, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.024536e+09
# Name: 97, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.834109e+09
# Name: 98, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.329934e+09
# Name: 99, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.267360e+09
# Name: 100, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.957464e+09
# Name: 101, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.308834e+09
# Name: 102, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.894849e+09
# Name: 103, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.630191e+09
# Name: 104, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.831432e+09
# Name: 105, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.713131e+09
# Name: 106, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.847606e+09
# Name: 107, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.608034e+09
# Name: 108, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.003571e+09
# Name: 109, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.016452e+09
# Name: 110, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.879406e+09
# Name: 111, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.781650e+09
# Name: 112, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.407726e+09
# Name: 113, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.173783e+09
# Name: 114, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.487275e+09
# Name: 115, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.991104e+09
# Name: 116, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.259950e+09
# Name: 117, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.453622e+09
# Name: 118, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.859092e+09
# Name: 119, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.161598e+09
# Name: 120, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.875504e+09
# Name: 121, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.471003e+09
# Name: 122, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.112699e+09
# Name: 123, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.081830e+09
# Name: 124, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.019866e+09
# Name: 125, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.764459e+09
# Name: 126, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.062515e+09
# Name: 127, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.908219e+09
# Name: 128, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.125374e+09
# Name: 129, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.545931e+09
# Name: 130, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.940193e+09
# Name: 131, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.666976e+09
# Name: 132, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.408113e+09
# Name: 133, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.713958e+09
# Name: 134, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.033470e+09
# Name: 135, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.097343e+09
# Name: 136, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.287813e+09
# Name: 137, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.173568e+09
# Name: 138, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.388107e+09
# Name: 139, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.875513e+09
# Name: 140, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.866085e+09
# Name: 141, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.022853e+09
# Name: 142, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.613294e+09
# Name: 143, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.426455e+09
# Name: 144, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.488843e+09
# Name: 145, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.701418e+09
# Name: 146, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.916747e+09
# Name: 147, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.470973e+09
# Name: 148, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.968084e+09
# Name: 149, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.896690e+09
# Name: 150, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.078165e+09
# Name: 151, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.679433e+09
# Name: 152, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.675532e+09
# Name: 153, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.618305e+09
# Name: 154, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.830021e+09
# Name: 155, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.172462e+09
# Name: 156, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.699069e+09
# Name: 157, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.984858e+09
# Name: 158, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.432909e+09
# Name: 159, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.986156e+09
# Name: 160, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.439969e+09
# Name: 161, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.316727e+09
# Name: 162, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.307175e+09
# Name: 163, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.210142e+09
# Name: 164, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.916682e+09
# Name: 165, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.295037e+09
# Name: 166, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.002355e+09
# Name: 167, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.449157e+09
# Name: 168, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.614499e+09
# Name: 169, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.324751e+09
# Name: 170, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.123370e+09
# Name: 171, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.696578e+09
# Name: 172, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.832014e+09
# Name: 173, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.894194e+09
# Name: 174, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.011259e+09
# Name: 175, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.267637e+09
# Name: 176, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.817169e+09
# Name: 177, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.310479e+09
# Name: 178, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.107960e+09
# Name: 179, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.984174e+09
# Name: 180, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.146401e+09
# Name: 181, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.495875e+09
# Name: 182, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.355968e+09
# Name: 183, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.321284e+09
# Name: 184, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.055642e+09
# Name: 185, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.114581e+09
# Name: 186, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.843156e+09
# Name: 187, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.888965e+09
# Name: 188, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.189820e+09
# Name: 189, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.593436e+09
# Name: 190, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.307257e+09
# Name: 191, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.979097e+09
# Name: 192, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.282578e+09
# Name: 193, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.112192e+09
# Name: 194, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.709504e+09
# Name: 195, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.624992e+09
# Name: 196, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.086557e+09
# Name: 197, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.100946e+09
# Name: 198, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.189283e+09
# Name: 199, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.570005e+09
# Name: 200, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.091259e+09
# Name: 201, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.922995e+09
# Name: 202, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.928305e+09
# Name: 203, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.966641e+09
# Name: 204, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.293847e+09
# Name: 205, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.829584e+09
# Name: 206, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.060830e+09
# Name: 207, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.858295e+09
# Name: 208, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.739878e+09
# Name: 209, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.851334e+09
# Name: 210, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.015412e+09
# Name: 211, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.748501e+09
# Name: 212, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.741537e+09
# Name: 213, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.977155e+09
# Name: 214, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.747845e+09
# Name: 215, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.935342e+09
# Name: 216, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.002640e+09
# Name: 217, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.010946e+09
# Name: 218, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.066303e+09
# Name: 219, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.340478e+09
# Name: 220, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.454360e+09
# Name: 221, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.870566e+09
# Name: 222, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.112760e+09
# Name: 223, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.707145e+09
# Name: 224, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.238551e+09
# Name: 225, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.046171e+09
# Name: 226, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.082813e+09
# Name: 227, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.456196e+09
# Name: 228, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.371193e+09
# Name: 229, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.783922e+09
# Name: 230, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.484407e+09
# Name: 231, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.502729e+09
# Name: 232, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.231817e+09
# Name: 233, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.890885e+09
# Name: 234, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.972791e+09
# Name: 235, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.962734e+09
# Name: 236, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.502942e+09
# Name: 237, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.265017e+09
# Name: 238, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.454608e+09
# Name: 239, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.198043e+09
# Name: 240, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.583972e+09
# Name: 241, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.828452e+09
# Name: 242, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.531138e+09
# Name: 243, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.016679e+09
# Name: 244, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.205723e+09
# Name: 245, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.469947e+09
# Name: 246, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.118990e+09
# Name: 247, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.947837e+09
# Name: 248, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.261582e+09
# Name: 249, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.591653e+09
# Name: 250, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.612493e+09
# Name: 251, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.809795e+09
# Name: 252, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.024762e+09
# Name: 253, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.772555e+09
# Name: 254, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.158341e+09
# Name: 255, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.636483e+09
# Name: 256, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.156420e+09
# Name: 257, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.587779e+09
# Name: 258, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.227129e+09
# Name: 259, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.666014e+09
# Name: 260, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.537077e+09
# Name: 261, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.132946e+09
# Name: 262, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.917831e+09
# Name: 263, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.278672e+09
# Name: 264, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.116854e+09
# Name: 265, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.117014e+09
# Name: 266, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.029536e+09
# Name: 267, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.525794e+09
# Name: 268, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.050825e+09
# Name: 269, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.152945e+09
# Name: 270, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.958151e+09
# Name: 271, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.791545e+09
# Name: 272, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.734671e+09
# Name: 273, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.067609e+09
# Name: 274, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.837297e+09
# Name: 275, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.659276e+09
# Name: 276, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.889797e+09
# Name: 277, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.283540e+09
# Name: 278, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.449029e+09
# Name: 279, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.325077e+09
# Name: 280, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.111738e+09
# Name: 281, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.016490e+09
# Name: 282, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.686466e+09
# Name: 283, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.945808e+09
# Name: 284, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.223574e+09
# Name: 285, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.711892e+09
# Name: 286, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.878165e+09
# Name: 287, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.752378e+09
# Name: 288, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.308476e+09
# Name: 289, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.811211e+09
# Name: 290, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.215975e+09
# Name: 291, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.808578e+09
# Name: 292, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.003500e+09
# Name: 293, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.014506e+09
# Name: 294, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.468759e+09
# Name: 295, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.554558e+09
# Name: 296, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.726903e+09
# Name: 297, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.788273e+09
# Name: 298, dtype: float64
# mi                1.248319e-03
# sum_disc_price    6.063458e+09
# Name: 299, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.645087e+09
# Name: 300, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.096848e+09
# Name: 301, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.360677e+09
# Name: 302, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.181888e+09
# Name: 303, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.354635e+09
# Name: 304, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.347113e+09
# Name: 305, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.721271e+09
# Name: 306, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.038173e+09
# Name: 307, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.884957e+09
# Name: 308, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.233301e+09
# Name: 309, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.435146e+09
# Name: 310, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.032266e+09
# Name: 311, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.273031e+09
# Name: 312, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.703147e+09
# Name: 313, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.183277e+09
# Name: 314, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.780958e+09
# Name: 315, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.909134e+09
# Name: 316, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.152418e+09
# Name: 317, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.038385e+09
# Name: 318, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.849526e+09
# Name: 319, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.149174e+09
# Name: 320, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.315007e+09
# Name: 321, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.329920e+09
# Name: 322, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.627325e+09
# Name: 323, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.989310e+09
# Name: 324, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.169976e+09
# Name: 325, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.046774e+09
# Name: 326, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.923516e+09
# Name: 327, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.893912e+09
# Name: 328, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.327058e+09
# Name: 329, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.366439e+09
# Name: 330, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.491568e+09
# Name: 331, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.231538e+09
# Name: 332, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.186599e+09
# Name: 333, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.563320e+09
# Name: 334, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.101617e+09
# Name: 335, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.907316e+09
# Name: 336, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.990079e+09
# Name: 337, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.089120e+09
# Name: 338, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.590958e+09
# Name: 339, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.021840e+09
# Name: 340, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.328374e+09
# Name: 341, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.034626e+09
# Name: 342, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.132155e+09
# Name: 343, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.149160e+09
# Name: 344, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.128400e+09
# Name: 345, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.687004e+09
# Name: 346, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.374660e+09
# Name: 347, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.878049e+09
# Name: 348, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.071394e+09
# Name: 349, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.017498e+09
# Name: 350, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.651411e+09
# Name: 351, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.699377e+09
# Name: 352, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.152679e+09
# Name: 353, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.569304e+09
# Name: 354, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.587924e+09
# Name: 355, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.099903e+09
# Name: 356, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.923174e+09
# Name: 357, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.988451e+09
# Name: 358, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.787088e+09
# Name: 359, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.552262e+09
# Name: 360, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.178759e+09
# Name: 361, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.507790e+09
# Name: 362, dtype: float64
# mi                1.248319e-03
# sum_disc_price    6.017064e+09
# Name: 363, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.279240e+09
# Name: 364, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.155634e+09
# Name: 365, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.569359e+09
# Name: 366, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.049010e+09
# Name: 367, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.829273e+09
# Name: 368, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.835633e+09
# Name: 369, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.753164e+09
# Name: 370, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.701116e+09
# Name: 371, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.593623e+09
# Name: 372, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.199387e+09
# Name: 373, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.095984e+09
# Name: 374, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.591281e+09
# Name: 375, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.238324e+09
# Name: 376, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.356896e+09
# Name: 377, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.801300e+09
# Name: 378, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.213342e+09
# Name: 379, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.176140e+09
# Name: 380, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.742964e+09
# Name: 381, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.898119e+09
# Name: 382, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.598966e+09
# Name: 383, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.175990e+09
# Name: 384, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.651453e+09
# Name: 385, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.397161e+09
# Name: 386, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.054428e+09
# Name: 387, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.662825e+09
# Name: 388, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.716265e+09
# Name: 389, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.545775e+09
# Name: 390, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.560968e+09
# Name: 391, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.881433e+09
# Name: 392, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.372390e+09
# Name: 393, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.483743e+09
# Name: 394, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.175584e+09
# Name: 395, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.884317e+09
# Name: 396, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.864131e+09
# Name: 397, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.764011e+09
# Name: 398, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.608124e+09
# Name: 399, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.999731e+09
# Name: 400, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.306125e+09
# Name: 401, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.015232e+09
# Name: 402, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.209588e+09
# Name: 403, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.476095e+09
# Name: 404, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.101406e+09
# Name: 405, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.756481e+09
# Name: 406, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.528742e+09
# Name: 407, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.826814e+09
# Name: 408, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.364612e+09
# Name: 409, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.111772e+09
# Name: 410, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.625356e+09
# Name: 411, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.113950e+09
# Name: 412, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.367818e+09
# Name: 413, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.307482e+09
# Name: 414, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.098598e+09
# Name: 415, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.302364e+09
# Name: 416, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.367610e+09
# Name: 417, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.716403e+09
# Name: 418, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.930096e+09
# Name: 419, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.787043e+09
# Name: 420, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.959787e+09
# Name: 421, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.950736e+09
# Name: 422, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.327406e+09
# Name: 423, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.073900e+09
# Name: 424, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.492120e+09
# Name: 425, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.019342e+09
# Name: 426, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.401179e+09
# Name: 427, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.285223e+09
# Name: 428, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.391205e+09
# Name: 429, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.779480e+09
# Name: 430, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.035919e+09
# Name: 431, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.953841e+09
# Name: 432, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.503415e+09
# Name: 433, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.098314e+09
# Name: 434, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.530904e+09
# Name: 435, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.018289e+09
# Name: 436, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.045134e+09
# Name: 437, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.435935e+09
# Name: 438, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.003276e+09
# Name: 439, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.223245e+09
# Name: 440, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.192637e+09
# Name: 441, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.247847e+09
# Name: 442, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.681849e+09
# Name: 443, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.120255e+09
# Name: 444, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.027199e+09
# Name: 445, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.463908e+09
# Name: 446, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.070863e+09
# Name: 447, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.165881e+09
# Name: 448, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.505716e+09
# Name: 449, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.996743e+09
# Name: 450, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.832959e+09
# Name: 451, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.764744e+09
# Name: 452, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.256707e+09
# Name: 453, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.938694e+09
# Name: 454, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.670218e+09
# Name: 455, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.432480e+09
# Name: 456, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.276184e+09
# Name: 457, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.182080e+09
# Name: 458, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.170659e+09
# Name: 459, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.678859e+09
# Name: 460, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.318356e+09
# Name: 461, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.606986e+09
# Name: 462, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.761648e+09
# Name: 463, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.801643e+09
# Name: 464, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.247173e+09
# Name: 465, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.164279e+09
# Name: 466, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.137959e+09
# Name: 467, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.194206e+09
# Name: 468, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.985826e+09
# Name: 469, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.434724e+09
# Name: 470, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.088283e+09
# Name: 471, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.828536e+09
# Name: 472, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.395307e+09
# Name: 473, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.206285e+09
# Name: 474, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.003394e+09
# Name: 475, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.673619e+09
# Name: 476, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.290034e+09
# Name: 477, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.409849e+09
# Name: 478, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.779047e+09
# Name: 479, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.345645e+09
# Name: 480, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.953592e+09
# Name: 481, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.543880e+09
# Name: 482, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.028273e+09
# Name: 483, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.118757e+09
# Name: 484, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.183173e+09
# Name: 485, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.622762e+09
# Name: 486, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.109686e+09
# Name: 487, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.802748e+09
# Name: 488, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.224998e+09
# Name: 489, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.058439e+09
# Name: 490, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.452706e+09
# Name: 491, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.548293e+09
# Name: 492, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.809823e+09
# Name: 493, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.412165e+09
# Name: 494, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.974489e+09
# Name: 495, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.951998e+09
# Name: 496, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.188298e+09
# Name: 497, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.567991e+09
# Name: 498, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.728137e+09
# Name: 499, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.931072e+09
# Name: 500, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.066983e+09
# Name: 501, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.898249e+09
# Name: 502, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.470890e+09
# Name: 503, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.259962e+09
# Name: 504, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.661345e+09
# Name: 505, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.129672e+09
# Name: 506, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.824502e+09
# Name: 507, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.558932e+09
# Name: 508, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.019682e+09
# Name: 509, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.049704e+09
# Name: 510, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.038285e+09
# Name: 511, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.462458e+09
# Name: 512, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.295750e+09
# Name: 513, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.972757e+09
# Name: 514, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.030652e+09
# Name: 515, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.487506e+09
# Name: 516, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.234155e+09
# Name: 517, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.524362e+09
# Name: 518, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.598851e+09
# Name: 519, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.013665e+09
# Name: 520, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.083269e+09
# Name: 521, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.498242e+09
# Name: 522, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.687765e+09
# Name: 523, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.403868e+09
# Name: 524, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.007548e+09
# Name: 525, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.954018e+09
# Name: 526, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.998662e+09
# Name: 527, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.606318e+09
# Name: 528, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.960177e+09
# Name: 529, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.298974e+09
# Name: 530, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.982692e+09
# Name: 531, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.917671e+09
# Name: 532, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.737689e+09
# Name: 533, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.493140e+09
# Name: 534, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.249276e+09
# Name: 535, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.037930e+09
# Name: 536, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.441254e+09
# Name: 537, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.974806e+09
# Name: 538, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.110478e+09
# Name: 539, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.430817e+09
# Name: 540, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.850936e+09
# Name: 541, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.747466e+09
# Name: 542, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.729927e+09
# Name: 543, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.745616e+09
# Name: 544, dtype: float64
# mi                1.248319e-03
# sum_disc_price    4.863485e+09
# Name: 545, dtype: float64
# mi                1.248319e-03
# sum_disc_price    5.252031e+09
# ...
# sum_disc_price    5.055736e+09
# Name: 8831, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.026455e+09
# Name: 8832, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.076090e+09
# Name: 8833, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.074283e+09
# Name: 8834, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.051729e+09
# Name: 8835, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.078080e+09
# Name: 8836, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.058092e+09
# Name: 8837, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.019932e+09
# Name: 8838, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.050754e+09
# Name: 8839, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.075219e+09
# Name: 8840, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.048240e+09
# Name: 8841, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.069320e+09
# Name: 8842, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.073976e+09
# Name: 8843, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.078815e+09
# Name: 8844, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052863e+09
# Name: 8845, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.065082e+09
# Name: 8846, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.055555e+09
# Name: 8847, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.069034e+09
# Name: 8848, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.051219e+09
# Name: 8849, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.056607e+09
# Name: 8850, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.022886e+09
# Name: 8851, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.034544e+09
# Name: 8852, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.065799e+09
# Name: 8853, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.047250e+09
# Name: 8854, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.011458e+09
# Name: 8855, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.045874e+09
# Name: 8856, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.059448e+09
# Name: 8857, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.083985e+09
# Name: 8858, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.070692e+09
# Name: 8859, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.040731e+09
# Name: 8860, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.063255e+09
# Name: 8861, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.058333e+09
# Name: 8862, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.072303e+09
# Name: 8863, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.047043e+09
# Name: 8864, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.058479e+09
# Name: 8865, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.044207e+09
# Name: 8866, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.064078e+09
# Name: 8867, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.034584e+09
# Name: 8868, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.073053e+09
# Name: 8869, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.059679e+09
# Name: 8870, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052380e+09
# Name: 8871, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.031612e+09
# Name: 8872, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.068113e+09
# Name: 8873, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.070925e+09
# Name: 8874, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.082392e+09
# Name: 8875, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.071761e+09
# Name: 8876, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.073497e+09
# Name: 8877, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.074028e+09
# Name: 8878, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.083287e+09
# Name: 8879, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.046837e+09
# Name: 8880, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.078251e+09
# Name: 8881, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.040325e+09
# Name: 8882, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.062967e+09
# Name: 8883, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.057019e+09
# Name: 8884, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.035758e+09
# Name: 8885, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.029693e+09
# Name: 8886, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.047136e+09
# Name: 8887, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.063136e+09
# Name: 8888, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.047464e+09
# Name: 8889, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.081961e+09
# Name: 8890, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.046571e+09
# Name: 8891, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052369e+09
# Name: 8892, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.089475e+09
# Name: 8893, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.039561e+09
# Name: 8894, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.039723e+09
# Name: 8895, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.038359e+09
# Name: 8896, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.084004e+09
# Name: 8897, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.049484e+09
# Name: 8898, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.072193e+09
# Name: 8899, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.043558e+09
# Name: 8900, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.073086e+09
# Name: 8901, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.041413e+09
# Name: 8902, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.051399e+09
# Name: 8903, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.081944e+09
# Name: 8904, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.079149e+09
# Name: 8905, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.047667e+09
# Name: 8906, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.083091e+09
# Name: 8907, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.037298e+09
# Name: 8908, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.038316e+09
# Name: 8909, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052523e+09
# Name: 8910, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.036580e+09
# Name: 8911, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.046856e+09
# Name: 8912, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.050136e+09
# Name: 8913, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.030108e+09
# Name: 8914, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.035126e+09
# Name: 8915, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.030110e+09
# Name: 8916, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.062253e+09
# Name: 8917, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052448e+09
# Name: 8918, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.061770e+09
# Name: 8919, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.090269e+09
# Name: 8920, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.056313e+09
# Name: 8921, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052566e+09
# Name: 8922, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.043692e+09
# Name: 8923, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.072319e+09
# Name: 8924, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052861e+09
# Name: 8925, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.045035e+09
# Name: 8926, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.074882e+09
# Name: 8927, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.051157e+09
# Name: 8928, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.047911e+09
# Name: 8929, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.038159e+09
# Name: 8930, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.066877e+09
# Name: 8931, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.022143e+09
# Name: 8932, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.059336e+09
# Name: 8933, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.047679e+09
# Name: 8934, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.086058e+09
# Name: 8935, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.051915e+09
# Name: 8936, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.024003e+09
# Name: 8937, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.054414e+09
# Name: 8938, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.051335e+09
# Name: 8939, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.028975e+09
# Name: 8940, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.056384e+09
# Name: 8941, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.066810e+09
# Name: 8942, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.074781e+09
# Name: 8943, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.040519e+09
# Name: 8944, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.066974e+09
# Name: 8945, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.034160e+09
# Name: 8946, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.056779e+09
# Name: 8947, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.057149e+09
# Name: 8948, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052355e+09
# Name: 8949, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.027855e+09
# Name: 8950, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.072244e+09
# Name: 8951, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.059057e+09
# Name: 8952, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.050798e+09
# Name: 8953, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.073309e+09
# Name: 8954, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.043385e+09
# Name: 8955, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.058082e+09
# Name: 8956, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.038724e+09
# Name: 8957, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.045815e+09
# Name: 8958, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.038039e+09
# Name: 8959, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.043520e+09
# Name: 8960, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.051365e+09
# Name: 8961, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.073806e+09
# Name: 8962, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.040187e+09
# Name: 8963, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.047142e+09
# Name: 8964, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.053989e+09
# Name: 8965, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052486e+09
# Name: 8966, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.053785e+09
# Name: 8967, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.053793e+09
# Name: 8968, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.054364e+09
# Name: 8969, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.036861e+09
# Name: 8970, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.046354e+09
# Name: 8971, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.066211e+09
# Name: 8972, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.072937e+09
# Name: 8973, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.068538e+09
# Name: 8974, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.050384e+09
# Name: 8975, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.055911e+09
# Name: 8976, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.030194e+09
# Name: 8977, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.064607e+09
# Name: 8978, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.069006e+09
# Name: 8979, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.035047e+09
# Name: 8980, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.067187e+09
# Name: 8981, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.050461e+09
# Name: 8982, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.076337e+09
# Name: 8983, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.074104e+09
# Name: 8984, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.051776e+09
# Name: 8985, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052843e+09
# Name: 8986, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052614e+09
# Name: 8987, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.042150e+09
# Name: 8988, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.036295e+09
# Name: 8989, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.061219e+09
# Name: 8990, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.049207e+09
# Name: 8991, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.048351e+09
# Name: 8992, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052700e+09
# Name: 8993, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.088873e+09
# Name: 8994, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.052937e+09
# Name: 8995, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.069795e+09
# Name: 8996, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.048134e+09
# Name: 8997, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.064194e+09
# Name: 8998, dtype: float64
# mi                1.600000e+01
# sum_disc_price    5.069017e+09
# Name: 8999, dtype: float64
#              mi  absolute error sum_disc_price  relative error sum_disc_price
# 0      0.001248                   5.148144e+08                      10.186081
# 1      0.001248                   3.106432e+08                       6.146365
# 2      0.001248                   4.218896e+08                       8.347478
# 3      0.001248                   1.720644e+07                       0.340445
# 4      0.001248                   4.614211e+08                       9.129645
# ...         ...                            ...                            ...
# 8995  16.000000                   1.159337e+06                       0.022939
# 8996  16.000000                   1.569845e+07                       0.310609
# 8997  16.000000                   5.962143e+06                       0.117967
# 8998  16.000000                   1.009739e+07                       0.199786
# 8999  16.000000                   1.492088e+07                       0.295224
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 sum_disc_price mean  sum_disc_price var
# type factor
# pac  0.001248          5.056392e+09        1.014069e+17
#      0.015625          5.052339e+09        8.335106e+15
#      0.031250          5.055794e+09        4.003609e+15
#      0.062500          5.054197e+09        2.438527e+15
#      0.250000          5.054506e+09        7.724709e+14
#      1.000000          5.053390e+09        3.519319e+14
#      2.000000          5.053076e+09        3.371592e+14
#      4.000000          5.054388e+09        2.787332e+14
#      16.000000         5.054700e+09        2.544327e+14

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error sum_disc_price mean  \
# type factor
# pac  0.001248                         2.524068e+08
#      0.015625                         7.248624e+07
#      0.031250                         5.045113e+07
#      0.062500                         3.907911e+07
#      0.250000                         2.250341e+07
#      1.000000                         1.508884e+07
#      2.000000                         1.452856e+07
#      4.000000                         1.333277e+07
#      16.000000                        1.267216e+07
#
#                 absolute error sum_disc_price var  \
# type factor
# pac  0.001248                        3.763916e+16
#      0.015625                        3.078681e+15
#      0.031250                        1.458631e+15
#      0.062500                        9.098319e+14
#      0.250000                        2.657284e+14
#      1.000000                        1.245309e+14
#      2.000000                        1.269099e+14
#      4.000000                        1.008774e+14
#      16.000000                       9.405291e+13
#
#                 relative error sum_disc_price mean  \
# type factor
# pac  0.001248                             4.994104
#      0.015625                             1.434208
#      0.031250                             0.998223
#      0.062500                             0.773217
#      0.250000                             0.445251
#      1.000000                             0.298547
#      2.000000                             0.287461
#      4.000000                             0.263801
#      16.000000                            0.250731
#
#                 relative error sum_disc_price var
# type factor
# pac  0.001248                           14.735096
#      0.015625                            1.205251
#      0.031250                            0.571029
#      0.062500                            0.356184
#      0.250000                            0.104028
#      1.000000                            0.048752
#      2.000000                            0.049683
#      4.000000                            0.039492
#      16.000000                           0.036820

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#            sum_disc_price
# mi
# 0.001248     1.014069e+17
# 0.015625     8.335106e+15
# 0.031250     4.003609e+15
# 0.062500     2.438527e+15
# 0.250000     7.724709e+14
# 1.000000     3.519319e+14
# 2.000000     3.371592e+14
# 4.000000     2.787332e+14
# 16.000000    2.544327e+14

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step               scale
# query     sum_disc_price
# mi
# 0.001248    9.972871e+16
# 0.015625    7.967565e+15
# 0.031250    3.983783e+15
# 0.062500    1.991891e+15
# 0.250000    4.979728e+14
# 1.000000    1.244932e+14
# 2.000000    6.224660e+13
# 4.000000    3.112330e+13
# 16.000000   7.780826e+12

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# sum_disc_price    0.249917
# dtype: float64
#            sum_disc_price
# mi
# 0.001248         0.241364
# 0.015625         0.255722
# 0.031250         0.248658
# 0.062500         0.250195
# 0.250000         0.248148
# 1.000000         0.249884
# 2.000000         0.256780
# 4.000000         0.250058
# 16.000000        0.248439

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_78615/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query        sum_disc_price
# mi
# 0.001248       2.522886e+08
# 0.015625       7.188615e+07
# 0.031250       4.925581e+07
# 0.062500       3.668925e+07
# 0.250000       1.842797e+07
# 1.000000       8.606322e+06
# 2.000000       6.341133e+06
# 4.000000       4.440645e+06
# 16.000000      2.278105e+06

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_78615/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_78615/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step       chosen_sample
# query     sum_disc_price
# mi
# 0.001248    5.054302e+09
# 0.015625    5.053608e+09
# 0.031250    5.053959e+09
# 0.062500    5.054040e+09
# 0.250000    5.054037e+09
# 1.000000    5.053354e+09
# 2.000000    5.053173e+09
# 4.000000    5.054071e+09
# 16.000000   5.054566e+09
# step    chosen_sample
# query  sum_disc_price
# all mi   5.053901e+09

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_78615/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#            sum_disc_price
# mi
# 0.001248         4.994104
# 0.015625         1.434208
# 0.031250         0.998223
# 0.062500         0.773217
# 0.250000         0.445251
# 1.000000         0.298547
# 2.000000         0.287461
# 4.000000         0.263801
# 16.000000        0.250731

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#            sum_disc_price
# mi
# 0.001248         4.752740
# 0.015625         1.178486
# 0.031250         0.749565
# 0.062500         0.523021
# 0.250000         0.197103
# 1.000000         0.048663
# 2.000000         0.030681
# 4.000000         0.013743
# 16.000000        0.002291

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()
