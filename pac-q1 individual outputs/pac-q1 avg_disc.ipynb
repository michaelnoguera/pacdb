# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   -- sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   -- sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   -- avg(l_quantity) as avg_qty,
#   -- avg(l_extendedprice) as avg_price,
#   avg(l_discount) as avg_disc,
#   -- count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'A'
#   and l_linestatus = 'F'
# ```

# %%
EXPERIMENT = 'pac-q1-avg-disc'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'A') &
        (lineitem_df['l_linestatus'] == 'F')
    ]
    print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        # float(discounted_price.sum()),                      # sum_disc_price
        # float(charged_price.sum()),                         # sum_charge
        # float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        # float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        # float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# (147790, 16)
# [0.05014459706340077]
# [0.05014459706340077]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['avg_disc']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 147790  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            # out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np
# Out:
# (147790, 16)
# [0.05014459706340077]

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
# TODO: Change it back to 1000
EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    # out_np = generate_samples() # generate samples (results of running the query)
    # print(f"Generate samples... {len(out_np)} samples generated.")

    # print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# Getting PAC Noise...
# The dimensions are - 1
# [array([[0.05000746]]), array([[0.05028095]]), array([[0.05008575]]), array([[0.05020332]]), array([[0.05011509]]), array([[0.05017408]]), array([[0.05022457]]), array([[0.05006438]]), array([[0.05015197]]), array([[0.05013724]]), array([[0.05006964]]), array([[0.05021966]]), array([[0.05005865]]), array([[0.05023039]]), array([[0.05013685]]), array([[0.05015234]]), array([[0.05027075]]), array([[0.05001828]]), array([[0.05007863]]), array([[0.05021101]]), array([[0.05013104]]), array([[0.05015814]]), array([[0.0501383]]), array([[0.05015086]]), array([[0.05005677]]), array([[0.0502322]]), array([[0.0501689]]), array([[0.05012038]]), array([[0.05029339]]), array([[0.04999717]]), array([[0.05019158]]), array([[0.05009752]]), array([[0.05005293]]), array([[0.05023666]]), array([[0.05007313]]), array([[0.0502157]]), array([[0.05018761]]), array([[0.05010185]]), array([[0.05001734]]), array([[0.05027156]]), array([[0.0501365]]), array([[0.05015267]]), array([[0.05005608]]), array([[0.05023339]]), array([[0.05013989]]), array([[0.05014932]]), array([[0.05031035]]), array([[0.04997947]]), array([[0.05014454]]), array([[0.05014466]]), array([[0.05011186]]), array([[0.05017752]]), array([[0.0501067]]), array([[0.05018245]]), array([[0.05022427]]), array([[0.05006476]]), array([[0.05023494]]), array([[0.05005269]]), array([[0.05000461]]), array([[0.05028382]]), array([[0.05020051]]), array([[0.05008805]]), array([[0.05026588]]), array([[0.0500234]]), array([[0.05032906]]), array([[0.04996233]]), array([[0.05009601]]), array([[0.05019313]]), array([[0.05015424]]), array([[0.05013495]]), array([[0.05003593]]), array([[0.05025367]]), array([[0.05027205]]), array([[0.05001794]]), array([[0.05021435]]), array([[0.05007528]]), array([[0.05018588]]), array([[0.05010329]]), array([[0.05000972]]), array([[0.05028027]]), array([[0.05024174]]), array([[0.05004727]]), array([[0.05015863]]), array([[0.05013045]]), array([[0.05010954]]), array([[0.05017962]]), array([[0.05015478]]), array([[0.05013441]]), array([[0.05009316]]), array([[0.05019596]]), array([[0.05010057]]), array([[0.05018872]]), array([[0.05028485]]), array([[0.05000353]]), array([[0.05014502]]), array([[0.05014417]]), array([[0.05015798]]), array([[0.05013127]]), array([[0.05020357]]), array([[0.05008533]]), array([[0.05010964]]), array([[0.05017944]]), array([[0.0500469]]), array([[0.05024142]]), array([[0.05006543]]), array([[0.05022362]]), array([[0.05012475]]), array([[0.05016445]]), array([[0.05007483]]), array([[0.05021462]]), array([[0.05006638]]), array([[0.05022297]]), array([[0.05009781]]), array([[0.05019129]]), array([[0.05004596]]), array([[0.05024289]]), array([[0.04992843]]), array([[0.05035844]]), array([[0.05022642]]), array([[0.05006337]]), array([[0.05015591]]), array([[0.05013325]]), array([[0.04999202]]), array([[0.05029721]]), array([[0.05024765]]), array([[0.05004211]]), array([[0.04997042]]), array([[0.05031945]]), array([[0.05014867]]), array([[0.05014056]]), array([[0.05006051]]), array([[0.05022862]]), array([[0.05020418]]), array([[0.05008523]]), array([[0.05029999]]), array([[0.04998805]]), array([[0.05024231]]), array([[0.05004673]]), array([[0.049964]]), array([[0.05032517]]), array([[0.05023018]]), array([[0.05006021]]), array([[0.05009292]]), array([[0.05019618]]), array([[0.0502483]]), array([[0.05004065]]), array([[0.05017323]]), array([[0.05011601]]), array([[0.05021311]]), array([[0.05007632]]), array([[0.0500042]]), array([[0.05028486]]), array([[0.05024318]]), array([[0.05004579]]), array([[0.05013953]]), array([[0.05014967]]), array([[0.0499906]]), array([[0.05030088]]), array([[0.05004883]]), array([[0.05024043]]), array([[0.0498374]]), array([[0.05044897]]), array([[0.05017516]]), array([[0.05011381]]), array([[0.05011943]]), array([[0.05016968]]), array([[0.05002987]]), array([[0.05025959]]), array([[0.05004442]]), array([[0.05024464]]), array([[0.04997753]]), array([[0.05031162]]), array([[0.05000909]]), array([[0.05027939]]), array([[0.0 ...
# est_y.shape: (1, 8192)
# est_y: [[0.05000746 0.05028095 0.05008575 ... 0.05004605 0.05011531 0.05017416]]
# fin_var: [6.98681163e-09]
# sqrt_total_var: 8.358714991894317e-05
# For mi=0.001248318631131131, we should add noise from a normal distribution with scale...
# 	400.5387627251371 * 8.358714991894317e-05 * [8.35871499e-05] = [2.79848889e-06]
# pac_noise: [2.79848889e-06]
# mi=0.001248318631131131, scale=[2.79848889e-06]
# Chosen Sample [0.0500911]
# Chosen Sample [0.04994352]
# Chosen Sample [0.05018277]
# Chosen Sample [0.05011826]
# Chosen Sample [0.05022862]
# Chosen Sample [0.05033514]
# Chosen Sample [0.05021792]
# Chosen Sample [0.05021036]
# Chosen Sample [0.05013654]
# Chosen Sample [0.05005034]
# Chosen Sample [0.0501511]
# Chosen Sample [0.05014759]
# Chosen Sample [0.05022268]
# Chosen Sample [0.05023063]
# Chosen Sample [0.05014228]
# Chosen Sample [0.05031686]
# Chosen Sample [0.05019459]
# Chosen Sample [0.05000177]
# Chosen Sample [0.05025257]
# Chosen Sample [0.05013948]
# Chosen Sample [0.05019529]
# Chosen Sample [0.05015656]
# Chosen Sample [0.05011978]
# Chosen Sample [0.05001807]
# Chosen Sample [0.05017197]
# Chosen Sample [0.05024311]
# Chosen Sample [0.05003358]
# Chosen Sample [0.05023154]
# Chosen Sample [0.05016235]
# Chosen Sample [0.05009638]
# Chosen Sample [0.05009252]
# Chosen Sample [0.05014393]
# Chosen Sample [0.05010396]
# Chosen Sample [0.04998645]
# Chosen Sample [0.05025312]
# Chosen Sample [0.04995247]
# Chosen Sample [0.05020279]
# Chosen Sample [0.05021111]
# Chosen Sample [0.05012949]
# Chosen Sample [0.0500827]
# Chosen Sample [0.05015519]
# Chosen Sample [0.05006502]
# Chosen Sample [0.05001684]
# Chosen Sample [0.05004255]
# Chosen Sample [0.05011202]
# Chosen Sample [0.05030428]
# Chosen Sample [0.05018189]
# Chosen Sample [0.04997944]
# Chosen Sample [0.05010547]
# Chosen Sample [0.05006231]
# Chosen Sample [0.05009135]
# Chosen Sample [0.05023149]
# Chosen Sample [0.05005057]
# Chosen Sample [0.0502006]
# Chosen Sample [0.05003316]
# Chosen Sample [0.05012598]
# Chosen Sample [0.05015332]
# Chosen Sample [0.05008051]
# Chosen Sample [0.05013412]
# Chosen Sample [0.05014734]
# Chosen Sample [0.05014173]
# Chosen Sample [0.05009586]
# Chosen Sample [0.05007311]
# Chosen Sample [0.05007907]
# Chosen Sample [0.05016739]
# Chosen Sample [0.04996469]
# Chosen Sample [0.05019955]
# Chosen Sample [0.05012539]
# Chosen Sample [0.05010307]
# Chosen Sample [0.05013294]
# Chosen Sample [0.05017592]
# Chosen Sample [0.04995724]
# Chosen Sample [0.05015686]
# Chosen Sample [0.05029746]
# Chosen Sample [0.05010919]
# Chosen Sample [0.05009227]
# Chosen Sample [0.05022626]
# Chosen Sample [0.05022114]
# Chosen Sample [0.05021965]
# Chosen Sample [0.05008979]
# Chosen Sample [0.05016933]
# Chosen Sample [0.05016267]
# Chosen Sample [0.05014202]
# Chosen Sample [0.05011542]
# Chosen Sample [0.05016526]
# Chosen Sample [0.05011143]
# Chosen Sample [0.05026817]
# Chosen Sample [0.0500604]
# Chosen Sample [0.05010268]
# Chosen Sample [0.05027223]
# Chosen Sample [0.05005609]
# Chosen Sample [0.0500646]
# Chosen Sample [0.05002138]
# Chosen Sample [0.05009773]
# Chosen Sample [0.05012319]
# Chosen Sample [0.05006367]
# Chosen Sample [0.0502795]
# Chosen Sample [0.05027294]
# Chosen Sample [0.05004408]
# Chosen Sample [0.05011703]
# Chosen Sample [0.0501539]
# Chosen Sample [0.05000217]
# Chosen Sample [0.05005153]
# Chosen Sample [0.05014232]
# Chosen Sample [0.05003999]
# Chosen Sample [0.05012941]
# Chosen Sample [0.05]
# Chosen Sample [0.05008277]
# Chosen Sample [0.05023443]
# Chosen Sample [0.05017484]
# Chosen Sample [0.05009054]
# Chosen Sample [0.0501445]
# Chosen Sample [0.05025812]
# Chosen Sample [0.05008544]
# Chosen Sample [0.05019249]
# Chosen Sample [0.05020669]
# Chosen Sample [0.05011417]
# Chosen Sample [0.05014091]
# Chosen Sample [0.05016809]
# Chosen Sample [0.05011688]
# Chosen Sample [0.05016809]
# Chosen Sample [0.05008897]
# Chosen Sample [0.05019679]
# Chosen Sample [0.05006231]
# Chosen Sample [0.0501342]
# Chosen Sample [0.05010316]
# Chosen Sample [0.05013969]
# Chosen Sample [0.05002325]
# Chosen Sample [0.05026309]
# Chosen Sample [0.05021263]
# Chosen Sample [0.0501136]
# Chosen Sample [0.05012919]
# Chosen Sample [0.05019362]
# Chosen Sample [0.04997832]
# Chosen Sample [0.05022977]
# Chosen Sample [0.05009297]
# Chosen Sample [0.05020598]
# Chosen Sample [0.0500019]
# Chosen Sample [0.05017424]
# Chosen Sample [0.0500161]
# Chosen Sample [0.05006735]
# Chosen Sample [0.05014121]
# Chosen Sample [0.05025911]
# Chosen Sample [0.05017484]
# Chosen Sample [0.05010018]
# Chosen Sample [0.05003524]
# Chosen Sample [0.05012866]
# Chosen Sample [0.05009598]
# Chosen Sample [0.05014457]
# Chosen Sample [0.05011568]
# Chosen Sample [0.0501736]
# Chosen Sample [0.05008822]
# Chosen Sample [0.05016502]
# Chosen Sample [0.05036159]
# Chosen Sample [0.05015519]
# Chosen Sample [0.05024014]
# Chosen Sample [0.05006777]
# Chosen Sample [0.05030376]
# Chosen Sample [0.05020205]
# Chosen Sample [0.05019275]
# Chosen Sample [0.05022817]
# Chosen Sample [0.05017666]
# Chosen Sample [0.05009667]
# Chosen Sample [0.05012509]
# Chosen Sample [0.05015809]
# Chosen Sample [0.05006716]
# Chosen Sample [0.05016837]
# Chosen Sample [0.05019368]
# Chosen Sample [0.05008297]
# Chosen Sample [0.05009285]
# Chosen Sample [0.0500555]
# Chosen Sample [0.05010617]
# Chosen Sample [0.05017912]
# Chosen Sample [0.05021445]
# Chosen Sample [0.05009742]
# Chosen Sample [0.05025085]
# Chosen Sample [0.05030902]
# Chosen Sample [0.05014517]
# Chosen Sample [0.050271]
# Chosen Sample [0.05025375]
# Chosen Sample [0.05028381]
# Chosen Sample [0.05034165]
# Chosen Sample [0.05029525]
# Chosen Sample [0.05027146]
# Chosen Sample [0.0501078]
# Chosen Sample [0.05023053]
# Chosen Sample [0.05027152]
# Chosen Sample [0.05010582]
# Chosen Sample [0.05007104]
# Chosen Sample [0.05012037]
# Chosen Sample [0.05008873]
# Chosen Sample [0.05014913]
# Chosen Sample [0.05023388]
# Chosen Sample [0.05007783]
# Chosen Sample [0.05016215]
# Chosen Sample [0.05024398]
# Chosen Sample [0.05022123]
# Chosen Sample [0.05019275]
# Chosen Sample [0.05022942]
# Chosen Sample [0.05016656]
# Chosen Sample [0.05003963]
# Chosen Sample [0.05001781]
# Chosen Sample [0.05012424]
# Chosen Sample [0.05015985]
# Chosen Sample [0.05012962]
# Chosen Sample [0.0501659]
# Chosen Sample [0.05007662]
# Chosen Sample [0.05018848]
# Chosen Sample [0.05021286]
# Chosen Sample [0.05009894]
# Chosen Sample [0.05016581]
# Chosen Sample [0.05011461]
# Chosen Sample [0.05025121]
# Chosen Sample [0.05022098]
# Chosen Sample [0.05002685]
# Chosen Sample [0.05014433]
# Chosen Sample [0.05002786]
# Chosen Sample [0.04996171]
# Chosen Sample [0.05020435]
# Chosen Sample [0.05022841]
# Chosen Sample [0.05011152]
# Chosen Sample [0.0500489]
# Chosen Sample [0.0500632]
# Chosen Sample [0.05018772]
# Chosen Sample [0.05025383]
# Chosen Sample [0.05020247]
# Chosen Sample [0.04998973]
# Chosen Sample [0.05000998]
# Chosen Sample [0.05004448]
# Chosen Sample [0.05026611]
# Chosen Sample [0.05009579]
# Chosen Sample [0.05016378]
# Chosen Sample [0.0501864]
# Chosen Sample [0.05026038]
# Chosen Sample [0.05012523]
# Chosen Sample [0.0502353]
# Chosen Sample [0.05002551]
# Chosen Sample [0.05007985]
# Chosen Sample [0.05014082]
# Chosen Sample [0.05013926]
# Chosen Sample [0.05000285]
# Chosen Sample [0.0502602]
# Chosen Sample [0.05011329]
# Chosen Sample [0.05016673]
# Chosen Sample [0.05021153]
# Chosen Sample [0.05022371]
# Chosen Sample [0.05015432]
# Chosen Sample [0.05011553]
# Chosen Sample [0.05028413]
# Chosen Sample [0.05028782]
# Chosen Sample [0.05022423]
# Chosen Sample [0.05022373]
# Chosen Sample [0.05023201]
# Chosen Sample [0.05026693]
# Chosen Sample [0.05017129]
# Chosen Sample [0.05026351]
# Chosen Sample [0.0501469]
# Chosen Sample [0.0500937]
# Chosen Sample [0.05002969]
# Chosen Sample [0.05011062]
# Chosen Sample [0.05019713]
# Chosen Sample [0.0501067]
# Chosen Sample [0.05015225]
# Chosen Sample [0.05019758]
# Chosen Sample [0.04999037]
# Chosen Sample [0.04996554]
# Chosen Sample [0.05021942]
# Chosen Sample [0.05009825]
# Chosen Sample [0.05008006]
# Chosen Sample [0.05015142]
# Chosen Sample [0.05011209]
# Chosen Sample [0.0502252]
# Chosen Sample [0.05003094]
# Chosen Sample [0.04997863]
# Chosen Sample [0.0502304]
# Chosen Sample [0.05010565]
# Chosen Sample [0.05020034]
# Chosen Sample [0.05011287]
# Chosen Sample [0.05011993]
# Chosen Sample [0.05006585]
# Chosen Sample [0.05023645]
# Chosen Sample [0.05014275]
# Chosen Sample [0.05024134]
# Chosen Sample [0.05009756]
# Chosen Sample [0.05004217]
# Chosen Sample [0.05029896]
# Chosen Sample [0.05030987]
# Chosen Sample [0.05009884]
# Chosen Sample [0.05016879]
# Chosen Sample [0.05022585]
# Chosen Sample [0.05005034]
# Chosen Sample [0.05024089]
# Chosen Sample [0.05022595]
# Chosen Sample [0.05012194]
# Chosen Sample [0.05024896]
# Chosen Sample [0.05027224]
# Chosen Sample [0.05011303]
# Chosen Sample [0.05015495]
# Chosen Sample [0.05010291]
# Chosen Sample [0.05013291]
# Chosen Sample [0.05017516]
# Chosen Sample [0.05011849]
# Chosen Sample [0.05010404]
# Chosen Sample [0.05012724]
# Chosen Sample [0.05004445]
# Chosen Sample [0.05017616]
# Chosen Sample [0.05023567]
# Chosen Sample [0.05018184]
# Chosen Sample [0.05015105]
# Chosen Sample [0.05008535]
# Chosen Sample [0.05012946]
# Chosen Sample [0.0502325]
# Chosen Sample [0.05026183]
# Chosen Sample [0.05015973]
# Chosen Sample [0.04997036]
# Chosen Sample [0.05010594]
# Chosen Sample [0.05009831]
# Chosen Sample [0.05028905]
# Chosen Sample [0.05011485]
# Chosen Sample [0.05007258]
# Chosen Sample [0.05002945]
# Chosen Sample [0.05020837]
# Chosen Sample [0.05007647]
# Chosen Sample [0.05018818]
# Chosen Sample [0.05012573]
# Chosen Sample [0.05007612]
# Chosen Sample [0.05013336]
# Chosen Sample [0.05013216]
# Chosen Sample [0.05016724]
# Chosen Sample [0.05027202]
# Chosen Sample [0.05004111]
# Chosen Sample [0.05013989]
# Chosen Sample [0.05006018]
# Chosen Sample [0.04996469]
# Chosen Sample [0.0501013]
# Chosen Sample [0.05022647]
# Chosen Sample [0.05009825]
# Chosen Sample [0.05017948]
# Chosen Sample [0.05019101]
# Chosen Sample [0.04998427]
# Chosen Sample [0.05012429]
# Chosen Sample [0.05006216]
# Chosen Sample [0.05012694]
# Chosen Sample [0.05010594]
# Chosen Sample [0.05023645]
# Chosen Sample [0.05009932]
# Chosen Sample [0.05019978]
# Chosen Sample [0.05017285]
# Chosen Sample [0.05018428]
# Chosen Sample [0.05018788]
# Chosen Sample [0.05016293]
# Chosen Sample [0.05004408]
# Chosen Sample [0.05005292]
# Chosen Sample [0.05008392]
# Chosen Sample [0.05031035]
# Chosen Sample [0.0501668]
# Chosen Sample [0.05005921]
# Chosen Sample [0.05018293]
# Chosen Sample [0.05013544]
# Chosen Sample [0.05013415]
# Chosen Sample [0.05026755]
# Chosen Sample [0.05020369]
# Chosen Sample [0.05017906]
# Chosen Sample [0.05021077]
# Chosen Sample [0.05016567]
# Chosen Sample [0.05013779]
# Chosen Sample [0.05009622]
# Chosen Sample [0.05017016]
# Chosen Sample [0.05029647]
# Chosen Sample [0.05017259]
# Chosen Sample [0.05018025]
# Chosen Sample [0.05029522]
# Chosen Sample [0.05015197]
# Chosen Sample [0.05010045]
# Chosen Sample [0.05002636]
# Chosen Sample [0.05005158]
# Chosen Sample [0.05010103]
# Chosen Sample [0.05009992]
# Chosen Sample [0.05003727]
# Chosen Sample [0.05005807]
# Chosen Sample [0.05006472]
# Chosen Sample [0.05018575]
# Chosen Sample [0.05007104]
# Chosen Sample [0.05011208]
# Chosen Sample [0.05011699]
# Chosen Sample [0.0501011]
# Chosen Sample [0.05011411]
# Chosen Sample [0.05022534]
# Chosen Sample [0.05001194]
# Chosen Sample [0.05011163]
# Chosen Sample [0.05013491]
# Chosen Sample [0.05006051]
# Chosen Sample [0.05016646]
# Chosen Sample [0.05014689]
# Chosen Sample [0.05017568]
# Chosen Sample [0.05011266]
# Chosen Sample [0.05012992]
# Chosen Sample [0.05014174]
# Chosen Sample [0.05027219]
# Chosen Sample [0.05029328]
# Chosen Sample [0.05009945]
# Chosen Sample [0.0500469]
# Chosen Sample [0.05006789]
# Chosen Sample [0.05032457]
# Chosen Sample [0.05021286]
# Chosen Sample [0.05009087]
# Chosen Sample [0.05013415]
# Chosen Sample [0.05005349]
# Chosen Sample [0.04997348]
# Chosen Sample [0.0499684]
# Chosen Sample [0.0501321]
# Chosen Sample [0.04994078]
# Chosen Sample [0.05019059]
# Chosen Sample [0.05009522]
# Chosen Sample [0.05011805]
# Chosen Sample [0.05017672]
# Chosen Sample [0.05003219]
# Chosen Sample [0.05013679]
# Chosen Sample [0.05022582]
# Chosen Sample [0.05024241]
# Chosen Sample [0.05026291]
# Chosen Sample [0.05022373]
# Chosen Sample [0.05016182]
# Chosen Sample [0.05014319]
# Chosen Sample [0.05023934]
# Chosen Sample [0.05012106]
# Chosen Sample [0.05016386]
# Chosen Sample [0.05011301]
# Chosen Sample [0.05018758]
# Chosen Sample [0.05024106]
# Chosen Sample [0.05014521]
# Chosen Sample [0.05010025]
# Chosen Sample [0.05008621]
# Chosen Sample [0.05026216]
# Chosen Sample [0.05011713]
# Chosen Sample [0.0501694]
# Chosen Sample [0.05017292]
# Chosen Sample [0.05015273]
# Chosen Sample [0.05014364]
# Chosen Sample [0.04992358]
# Chosen Sample [0.05037056]
# Chosen Sample [0.05035059]
# Chosen Sample [0.05005879]
# Chosen Sample [0.0500836]
# Chosen Sample [0.05019286]
# Chosen Sample [0.05014572]
# Chosen Sample [0.0500569]
# Chosen Sample [0.05016997]
# Chosen Sample [0.05013824]
# Chosen Sample [0.05010935]
# Chosen Sample [0.05011792]
# Chosen Sample [0.05014325]
# Chosen Sample [0.05021111]
# Chosen Sample [0.05019145]
# Chosen Sample [0.05022818]
# Chosen Sample [0.05003422]
# Chosen Sample [0.05009425]
# Chosen Sample [0.05016374]
# Chosen Sample [0.05001669]
# Chosen Sample [0.05001751]
# Chosen Sample [0.05015499]
# Chosen Sample [0.05031148]
# Chosen Sample [0.05005224]
# Chosen Sample [0.05011802]
# Chosen Sample [0.05014383]
# Chosen Sample [0.05027229]
# Chosen Sample [0.05013736]
# Chosen Sample [0.05011936]
# Chosen Sample [0.05021965]
# Chosen Sample [0.05001391]
# Chosen Sample [0.05002231]
# Chosen Sample [0.05006526]
# Chosen Sample [0.05001189]
# Chosen Sample [0.05022282]
# Chosen Sample [0.05004943]
# Chosen Sample [0.05000541]
# Chosen Sample [0.05020392]
# Chosen Sample [0.0501772]
# Chosen Sample [0.05014482]
# Chosen Sample [0.05016645]
# Chosen Sample [0.05000692]
# Chosen Sample [0.05009081]
# Chosen Sample [0.05023404]
# Chosen Sample [0.05007444]
# Chosen Sample [0.05013581]
# Chosen Sample [0.05013973]
# Chosen Sample [0.05000297]
# Chosen Sample [0.05019901]
# Chosen Sample [0.05014455]
# Chosen Sample [0.0502277]
# Chosen Sample [0.05000379]
# Chosen Sample [0.05018729]
# Chosen Sample [0.05001767]
# Chosen Sample [0.05006834]
# Chosen Sample [0.05003365]
# Chosen Sample [0.05022831]
# Chosen Sample [0.05006418]
# Chosen Sample [0.05000311]
# Chosen Sample [0.05000352]
# Chosen Sample [0.05023301]
# Chosen Sample [0.05026228]
# Chosen Sample [0.05030781]
# Chosen Sample [0.050055]
# Chosen Sample [0.05016761]
# Chosen Sample [0.0500161]
# Chosen Sample [0.05005328]
# Chosen Sample [0.05019006]
# Chosen Sample [0.05007926]
# Chosen Sample [0.05015175]
# Chosen Sample [0.04999377]
# Chosen Sample [0.05006391]
# Chosen Sample [0.05015739]
# Chosen Sample [0.0500578]
# Chosen Sample [0.05021328]
# Chosen Sample [0.05024928]
# Chosen Sample [0.0501871]
# Chosen Sample [0.05009147]
# Chosen Sample [0.05017948]
# Chosen Sample [0.05011836]
# Chosen Sample [0.05008344]
# Chosen Sample [0.05012362]
# Chosen Sample [0.05025289]
# Chosen Sample [0.05021286]
# Chosen Sample [0.04999715]
# Chosen Sample [0.05026707]
# Chosen Sample [0.05012107]
# Chosen Sample [0.05026429]
# Chosen Sample [0.05028773]
# Chosen Sample [0.05009674]
# Chosen Sample [0.05011209]
# Chosen Sample [0.05035089]
# Chosen Sample [0.05010964]
# Chosen Sample [0.05006467]
# Chosen Sample [0.05020885]
# Chosen Sample [0.05008805]
# Chosen Sample [0.05031079]
# Chosen Sample [0.05015101]
# Chosen Sample [0.05008728]
# Chosen Sample [0.05017643]
# Chosen Sample [0.05013406]
# Chosen Sample [0.05028955]
# Chosen Sample [0.05018762]
# Chosen Sample [0.05020248]
# Chosen Sample [0.05025421]
# Chosen Sample [0.05017242]
# Chosen Sample [0.05005739]
# Chosen Sample [0.05017394]
# Chosen Sample [0.05006302]
# Chosen Sample [0.05004647]
# Chosen Sample [0.05031212]
# Chosen Sample [0.05022098]
# Chosen Sample [0.05009373]
# Chosen Sample [0.05024015]
# Chosen Sample [0.05010124]
# Chosen Sample [0.05017623]
# Chosen Sample [0.05021782]
# Chosen Sample [0.05011395]
# Chosen Sample [0.05008523]
# Chosen Sample [0.0500555]
# Chosen Sample [0.05014458]
# Chosen Sample [0.05024039]
# Chosen Sample [0.05022587]
# Chosen Sample [0.05015998]
# Chosen Sample [0.0502493]
# Chosen Sample [0.05016829]
# Chosen Sample [0.05020645]
# Chosen Sample [0.05013153]
# Chosen Sample [0.05028595]
# Chosen Sample [0.05012716]
# Chosen Sample [0.04999445]
# Chosen Sample [0.05009248]
# Chosen Sample [0.05030466]
# Chosen Sample [0.05011109]
# Chosen Sample [0.05009961]
# Chosen Sample [0.05009563]
# Chosen Sample [0.05009433]
# Chosen Sample [0.05003756]
# Chosen Sample [0.05013094]
# Chosen Sample [0.05011145]
# Chosen Sample [0.0501495]
# Chosen Sample [0.05008848]
# Chosen Sample [0.05011732]
# Chosen Sample [0.05003599]
# Chosen Sample [0.05016673]
# Chosen Sample [0.05017552]
# Chosen Sample [0.05007787]
# Chosen Sample [0.05011448]
# Chosen Sample [0.05010165]
# Chosen Sample [0.05009276]
# Chosen Sample [0.04999715]
# Chosen Sample [0.05016117]
# Chosen Sample [0.050211]
# Chosen Sample [0.05015615]
# Chosen Sample [0.05021433]
# Chosen Sample [0.05001965]
# Chosen Sample [0.05029742]
# Chosen Sample [0.05014685]
# Chosen Sample [0.05001481]
# Chosen Sample [0.05016435]
# Chosen Sample [0.05032003]
# Chosen Sample [0.05]
# Chosen Sample [0.05017736]
# Chosen Sample [0.05021943]
# Chosen Sample [0.05023835]
# Chosen Sample [0.05008266]
# Chosen Sample [0.05015216]
# Chosen Sample [0.05003981]
# Chosen Sample [0.0500263]
# Chosen Sample [0.05017378]
# Chosen Sample [0.05001965]
# Chosen Sample [0.05009122]
# Chosen Sample [0.05006005]
# Chosen Sample [0.05006263]
# Chosen Sample [0.05007123]
# Chosen Sample [0.0501071]
# Chosen Sample [0.05015962]
# Chosen Sample [0.05016182]
# Chosen Sample [0.05005963]
# Chosen Sample [0.05006411]
# Chosen Sample [0.05013842]
# Chosen Sample [0.05021286]
# Chosen Sample [0.05009154]
# Chosen Sample [0.05005316]
# Chosen Sample [0.05017906]
# Chosen Sample [0.05007359]
# Chosen Sample [0.05007684]
# Chosen Sample [0.05006578]
# Chosen Sample [0.0501871]
# Chosen Sample [0.05011132]
# Chosen Sample [0.0499881]
# Chosen Sample [0.05014545]
# Chosen Sample [0.05013069]
# Chosen Sample [0.05019313]
# Chosen Sample [0.05021374]
# Chosen Sample [0.05022943]
# Chosen Sample [0.05014065]
# Chosen Sample [0.05009681]
# Chosen Sample [0.05005292]
# Chosen Sample [0.05026111]
# Chosen Sample [0.05008621]
# Chosen Sample [0.05015915]
# Chosen Sample [0.05008351]
# Chosen Sample [0.05020772]
# Chosen Sample [0.05021445]
# Chosen Sample [0.05018906]
# Chosen Sample [0.0501731]
# Chosen Sample [0.05024442]
# Chosen Sample [0.05022371]
# Chosen Sample [0.0501406]
# Chosen Sample [0.05023715]
# Chosen Sample [0.05005963]
# Chosen Sample [0.05016053]
# Chosen Sample [0.05010967]
# Chosen Sample [0.05026765]
# Chosen Sample [0.0502214]
# Chosen Sample [0.05028196]
# Chosen Sample [0.05007696]
# Chosen Sample [0.05015429]
# Chosen Sample [0.05003308]
# Chosen Sample [0.05017089]
# Chosen Sample [0.05005731]
# Chosen Sample [0.05013608]
# Chosen Sample [0.05019306]
# Chosen Sample [0.05012835]
# Chosen Sample [0.05014056]
# Chosen Sample [0.0501043]
# Chosen Sample [0.05020653]
# Chosen Sample [0.05011636]
# Chosen Sample [0.04994882]
# Chosen Sample [0.0501059]
# Chosen Sample [0.05015792]
# Chosen Sample [0.05018652]
# Chosen Sample [0.05022043]
# Chosen Sample [0.05008542]
# Chosen Sample [0.05016163]
# Chosen Sample [0.05012466]
# Chosen Sample [0.04993861]
# Chosen Sample [0.05018422]
# Chosen Sample [0.05004703]
# Chosen Sample [0.05010769]
# Chosen Sample [0.05031159]
# Chosen Sample [0.05024279]
# Chosen Sample [0.05025044]
# Chosen Sample [0.0501152]
# Chosen Sample [0.05008051]
# Chosen Sample [0.05024808]
# Chosen Sample [0.05006352]
# Chosen Sample [0.05028557]
# Chosen Sample [0.0501152]
# Chosen Sample [0.05018215]
# Chosen Sample [0.05017027]
# Chosen Sample [0.05008463]
# Chosen Sample [0.05027474]
# Chosen Sample [0.05004647]
# Chosen Sample [0.05030823]
# Chosen Sample [0.05010956]
# Chosen Sample [0.05019953]
# Chosen Sample [0.05002411]
# Chosen Sample [0.05032643]
# Chosen Sample [0.05018666]
# Chosen Sample [0.05029954]
# Chosen Sample [0.05028682]
# Chosen Sample [0.05018675]
# Chosen Sample [0.04993285]
# Chosen Sample [0.05010697]
# Chosen Sample [0.0501814]
# Chosen Sample [0.05004579]
# Chosen Sample [0.05011129]
# Chosen Sample [0.05004832]
# Chosen Sample [0.05015624]
# Chosen Sample [0.05005794]
# Chosen Sample [0.05009914]
# Chosen Sample [0.05010285]
# Chosen Sample [0.05013309]
# Chosen Sample [0.05015982]
# Chosen Sample [0.0500946]
# Chosen Sample [0.05014927]
# Chosen Sample [0.05022318]
# Chosen Sample [0.05011916]
# Chosen Sample [0.05024843]
# Chosen Sample [0.05011217]
# Chosen Sample [0.05019134]
# Chosen Sample [0.05016645]
# Chosen Sample [0.05006505]
# Chosen Sample [0.0499906]
# Chosen Sample [0.04988993]
# Chosen Sample [0.0501611]
# Chosen Sample [0.05018028]
# Chosen Sample [0.05033536]
# Chosen Sample [0.05016696]
# Chosen Sample [0.05009293]
# Chosen Sample [0.05026436]
# Chosen Sample [0.05017623]
# Chosen Sample [0.05025898]
# Chosen Sample [0.05020208]
# Chosen Sample [0.05017502]
# Chosen Sample [0.04995748]
# Chosen Sample [0.05013843]
# Chosen Sample [0.05000109]
# Chosen Sample [0.05014682]
# Chosen Sample [0.05000959]
# Chosen Sample [0.05013653]
# Chosen Sample [0.05016073]
# Chosen Sample [0.05022878]
# Chosen Sample [0.05010049]
# Chosen Sample [0.05006528]
# Chosen Sample [0.0501663]
# Chosen Sample [0.05015142]
# Chosen Sample [0.0502356]
# Chosen Sample [0.05016388]
# Chosen Sample [0.05006761]
# Chosen Sample [0.05011628]
# Chosen Sample [0.05005041]
# Chosen Sample [0.0501388]
# Chosen Sample [0.05014801]
# Chosen Sample [0.05008539]
# Chosen Sample [0.04997832]
# Chosen Sample [0.05022116]
# Chosen Sample [0.05027481]
# Chosen Sample [0.0502166]
# Chosen Sample [0.05027386]
# Chosen Sample [0.05020287]
# Chosen Sample [0.05011327]
# Chosen Sample [0.05024623]
# Chosen Sample [0.0501397]
# Chosen Sample [0.05011723]
# Chosen Sample [0.05006181]
# Chosen Sample [0.05004948]
# Chosen Sample [0.05002365]
# Chosen Sample [0.05020092]
# Chosen Sample [0.05018675]
# Chosen Sample [0.05011109]
# Chosen Sample [0.0501456]
# Chosen Sample [0.05015403]
# Chosen Sample [0.05034602]
# Chosen Sample [0.05021464]
# Chosen Sample [0.0500765]
# Chosen Sample [0.05008792]
# Chosen Sample [0.05015995]
# Chosen Sample [0.05002325]
# Chosen Sample [0.0502353]
# Chosen Sample [0.05005788]
# Chosen Sample [0.05019633]
# Chosen Sample [0.0501501]
# Chosen Sample [0.05024816]
# Chosen Sample [0.05019435]
# Chosen Sample [0.05011611]
# Chosen Sample [0.05013127]
# Chosen Sample [0.05013171]
# Chosen Sample [0.05018352]
# Chosen Sample [0.05002231]
# Chosen Sample [0.05014469]
# Chosen Sample [0.05027767]
# Chosen Sample [0.05011386]
# Chosen Sample [0.05030579]
# Chosen Sample [0.05024172]
# Chosen Sample [0.05017984]
# Chosen Sample [0.05007472]
# Chosen Sample [0.05007635]
# Chosen Sample [0.05013226]
# Chosen Sample [0.04999973]
# Chosen Sample [0.05009897]
# Chosen Sample [0.05010657]
# Chosen Sample [0.0503142]
# Chosen Sample [0.05011263]
# Chosen Sample [0.05016465]
# Chosen Sample [0.05000406]
# Chosen Sample [0.05002766]
# Chosen Sample [0.04997759]
# Chosen Sample [0.0502448]
# Chosen Sample [0.05002594]
# Chosen Sample [0.05001386]
# Chosen Sample [0.05009322]
# Chosen Sample [0.04995329]
# Chosen Sample [0.05000392]
# Chosen Sample [0.05002597]
# Chosen Sample [0.05012257]
# Chosen Sample [0.05012491]
# Chosen Sample [0.05017537]
# Chosen Sample [0.05005086]
# Chosen Sample [0.04995833]
# Chosen Sample [0.05013147]
# Chosen Sample [0.05033401]
# Chosen Sample [0.05023282]
# Chosen Sample [0.05022339]
# Chosen Sample [0.05009497]
# Chosen Sample [0.05019889]
# Chosen Sample [0.05018433]
# Chosen Sample [0.05007794]
# Chosen Sample [0.05014807]
# Chosen Sample [0.05019745]
# Chosen Sample [0.05025812]
# Chosen Sample [0.05013395]
# Chosen Sample [0.05012992]
# Chosen Sample [0.05009601]
# Chosen Sample [0.05018855]
# Chosen Sample [0.05006018]
# Chosen Sample [0.05024953]
# Chosen Sample [0.0501687]
# Chosen Sample [0.0500598]
# Chosen Sample [0.05021887]
# Chosen Sample [0.05016039]
# Chosen Sample [0.05021234]
# Chosen Sample [0.05015137]
# Chosen Sample [0.05016661]
# Chosen Sample [0.05014107]
# Chosen Sample [0.05016975]
# Chosen Sample [0.04997888]
# Chosen Sample [0.05017958]
# Chosen Sample [0.05005679]
# Chosen Sample [0.05017017]
# Chosen Sample [0.04996331]
# Chosen Sample [0.0501691]
# Chosen Sample [0.05001887]
# Chosen Sample [0.05012251]
# Chosen Sample [0.05016213]
# Chosen Sample [0.05014201]
# Chosen Sample [0.05013038]
# Chosen Sample [0.05012872]
# Chosen Sample [0.05014128]
# Chosen Sample [0.05017894]
# Chosen Sample [0.05010336]
# Chosen Sample [0.05021668]
# Chosen Sample [0.0501661]
# Chosen Sample [0.05008838]
# Chosen Sample [0.05016266]
# Chosen Sample [0.05017125]
# Chosen Sample [0.05000027]
# Chosen Sample [0.05016906]
# Chosen Sample [0.05007546]
# Chosen Sample [0.05028841]
# Chosen Sample [0.05005139]
# Chosen Sample [0.05004175]
# Chosen Sample [0.05011277]
# Chosen Sample [0.05019633]
# Chosen Sample [0.04993762]
# Chosen Sample [0.05012346]
# Chosen Sample [0.05015102]
# Chosen Sample [0.05011436]
# Chosen Sample [0.05008052]
# Chosen Sample [0.05006619]
# Chosen Sample [0.05030884]
# Chosen Sample [0.05016191]
# Chosen Sample [0.05006492]
# Chosen Sample [0.05003131]
# Chosen Sample [0.05012389]
# Chosen Sample [0.05014911]
# Chosen Sample [0.0500294]
# Chosen Sample [0.05014971]
# Chosen Sample [0.05028196]
# Chosen Sample [0.05027568]
# Chosen Sample [0.05004065]
# Chosen Sample [0.05020564]
# Chosen Sample [0.05010594]
# Chosen Sample [0.05018387]
# Chosen Sample [0.05025971]
# Chosen Sample [0.05019957]
# Chosen Sample [0.05011231]
# Chosen Sample [0.05032132]
# Chosen Sample [0.05007556]
# Chosen Sample [0.05012805]
# Chosen Sample [0.05009112]
# Chosen Sample [0.04991927]
# Chosen Sample [0.05010673]
# Chosen Sample [0.05008095]
# Chosen Sample [0.05014791]
# Chosen Sample [0.05004909]
# Chosen Sample [0.05021985]
# Chosen Sample [0.05011553]
# Chosen Sample [0.05006181]
# Chosen Sample [0.0501344]
# Chosen Sample [0.05002118]
# Chosen Sample [0.05020021]
# Chosen Sample [0.05018567]
# Chosen Sample [0.0500479]
# Chosen Sample [0.0501757]
# Chosen Sample [0.05013781]
# Chosen Sample [0.0501327]
# Chosen Sample [0.05012924]
# Chosen Sample [0.05015648]
# Chosen Sample [0.0502939]
# Chosen Sample [0.05014905]
# Chosen Sample [0.05017838]
# Chosen Sample [0.05024464]
# Chosen Sample [0.05010468]
# Chosen Sample [0.05010037]
# Chosen Sample [0.05023836]
# Chosen Sample [0.0502124]
# Chosen Sample [0.05014759]
# Chosen Sample [0.05022067]
# Chosen Sample [0.05022457]
# Chosen Sample [0.0500877]
# Chosen Sample [0.05018142]
# Chosen Sample [0.05020395]
# Chosen Sample [0.05028486]
# Chosen Sample [0.05016195]
# Chosen Sample [0.05020907]
# Chosen Sample [0.0501625]
# Chosen Sample [0.05005116]
# Chosen Sample [0.05014016]
# Chosen Sample [0.05008544]
# Chosen Sample [0.05006825]
# Chosen Sample [0.05021538]
# Chosen Sample [0.05012038]
# Chosen Sample [0.05002217]
# Chosen Sample [0.05013266]
# Chosen Sample [0.05002085]
# Chosen Sample [0.05003025]
# Chosen Sample [0.04997837]
# Chosen Sample [0.05027146]
# Chosen Sample [0.05013263]
# Chosen Sample [0.05017344]
# Chosen Sample [0.05011155]
# Chosen Sample [0.05013311]
# Chosen Sample [0.05016423]
# Chosen Sample [0.05019896]
# Chosen Sample [0.05016578]
# Chosen Sample [0.04993855]
# Chosen Sample [0.05022119]
# Chosen Sample [0.05024821]
# Chosen Sample [0.05003822]
# Chosen Sample [0.05020298]
# Chosen Sample [0.05015973]
# Chosen Sample [0.05029916]
# Chosen Sample [0.05005528]
# Chosen Sample [0.05008298]
# Chosen Sample [0.05014299]
# Chosen Sample [0.05012706]
# Chosen Sample [0.05000379]
# Chosen Sample [0.05017778]
# Chosen Sample [0.05011368]
# Chosen Sample [0.05004445]
# Chosen Sample [0.0501689]
# Chosen Sample [0.05019165]
# Chosen Sample [0.05008919]
# Chosen Sample [0.05019323]
# Chosen Sample [0.05019781]
# Chosen Sample [0.05017343]
# Chosen Sample [0.04996098]
# Chosen Sample [0.05006836]
# Chosen Sample [0.05012282]
# Chosen Sample [0.05019435]
# Chosen Sample [0.05021995]
# Chosen Sample [0.05027405]
# Chosen Sample [0.05027192]
# Chosen Sample [0.05001247]
# Chosen Sample [0.05005816]
# Chosen Sample [0.05027075]
# Chosen Sample [0.05020889]
# Chosen Sample [0.05008365]
# Chosen Sample [0.0501261]
# Chosen Sample [0.05014091]
# Chosen Sample [0.05002597]
# Chosen Sample [0.05007032]
# Chosen Sample [0.05012164]
# Chosen Sample [0.0500502]
# Chosen Sample [0.05009997]
# Chosen Sample [0.0500649]
# Chosen Sample [0.0501196]
# Chosen Sample [0.05020395]
# Getting PAC Noise...
# The dimensions are - 1
# [array([[0.05000746]]), array([[0.05028095]]), array([[0.05008575]]), array([[0.05020332]]), array([[0.05011509]]), array([[0.05017408]]), array([[0.05022457]]), array([[0.05006438]]), array([[0.05015197]]), array([[0.05013724]]), array([[0.05006964]]), array([[0.05021966]]), array([[0.05005865]]), array([[0.05023039]]), array([[0.05013685]]), array([[0.05015234]]), array([[0.05027075]]), array([[0.05001828]]), array([[0.05007863]]), array([[0.05021101]]), array([[0.05013104]]), array([[0.05015814]]), array([[0.0501383]]), array([[0.05015086]]), array([[0.05005677]]), array([[0.0502322]]), array([[0.0501689]]), array([[0.05012038]]), array([[0.05029339]]), array([[0.04999717]]), array([[0.05019158]]), array([[0.05009752]]), array([[0.05005293]]), array([[0.05023666]]), array([[0.05007313]]), array([[0.0502157]]), array([[0.05018761]]), array([[0.05010185]]), array([[0.05001734]]), array([[0.05027156]]), array([[0.0501365]]), array([[0.05015267]]), array([[0.05005608]]), array([[0.05023339]]), array([[0.05013989]]), array([[0.05014932]]), array([[0.05031035]]), array([[0.04997947]]), array([[0.05014454]]), array([[0.05014466]]), array([[0.05011186]]), array([[0.05017752]]), array([[0.0501067]]), array([[0.05018245]]), array([[0.05022427]]), array([[0.05006476]]), array([[0.05023494]]), array([[0.05005269]]), array([[0.05000461]]), array([[0.05028382]]), array([[0.05020051]]), array([[0.05008805]]), array([[0.05026588]]), array([[0.0500234]]), array([[0.05032906]]), array([[0.04996233]]), array([[0.05009601]]), array([[0.05019313]]), array([[0.05015424]]), array([[0.05013495]]), array([[0.05003593]]), array([[0.05025367]]), array([[0.05027205]]), array([[0.05001794]]), array([[0.05021435]]), array([[0.05007528]]), array([[0.05018588]]), array([[0.05010329]]), array([[0.05000972]]), array([[0.05028027]]), array([[0.05024174]]), array([[0.05004727]]), array([[0.05015863]]), array([[0.05013045]]), array([[0.05010954]]), array([[0.05017962]]), array([[0.05015478]]), array([[0.05013441]]), array([[0.05009316]]), array([[0.05019596]]), array([[0.05010057]]), array([[0.05018872]]), array([[0.05028485]]), array([[0.05000353]]), array([[0.05014502]]), array([[0.05014417]]), array([[0.05015798]]), array([[0.05013127]]), array([[0.05020357]]), array([[0.05008533]]), array([[0.05010964]]), array([[0.05017944]]), array([[0.0500469]]), array([[0.05024142]]), array([[0.05006543]]), array([[0.05022362]]), array([[0.05012475]]), array([[0.05016445]]), array([[0.05007483]]), array([[0.05021462]]), array([[0.05006638]]), array([[0.05022297]]), array([[0.05009781]]), array([[0.05019129]]), array([[0.05004596]]), array([[0.05024289]]), array([[0.04992843]]), array([[0.05035844]]), array([[0.05022642]]), array([[0.05006337]]), array([[0.05015591]]), array([[0.05013325]]), array([[0.04999202]]), array([[0.05029721]]), array([[0.05024765]]), array([[0.05004211]]), array([[0.04997042]]), array([[0.05031945]]), array([[0.05014867]]), array([[0.05014056]]), array([[0.05006051]]), array([[0.05022862]]), array([[0.05020418]]), array([[0.05008523]]), array([[0.05029999]]), array([[0.04998805]]), array([[0.05024231]]), array([[0.05004673]]), array([[0.049964]]), array([[0.05032517]]), array([[0.05023018]]), array([[0.05006021]]), array([[0.05009292]]), array([[0.05019618]]), array([[0.0502483]]), array([[0.05004065]]), array([[0.05017323]]), array([[0.05011601]]), array([[0.05021311]]), array([[0.05007632]]), array([[0.0500042]]), array([[0.05028486]]), array([[0.05024318]]), array([[0.05004579]]), array([[0.05013953]]), array([[0.05014967]]), array([[0.0499906]]), array([[0.05030088]]), array([[0.05004883]]), array([[0.05024043]]), array([[0.0498374]]), array([[0.05044897]]), array([[0.05017516]]), array([[0.05011381]]), array([[0.05011943]]), array([[0.05016968]]), array([[0.05002987]]), array([[0.05025959]]), array([[0.05004442]]), array([[0.05024464]]), array([[0.04997753]]), array([[0.05031162]]), array([[0.05000909]]), array([[0.05027939]]), array([[0.0 ...
# est_y.shape: (1, 8192)
# est_y: [[0.05000746 0.05028095 0.05008575 ... 0.05004605 0.05011531 0.05017416]]
# fin_var: [6.98681163e-09]
# sqrt_total_var: 8.358714991894317e-05
# For mi=0.015625, we should add noise from a normal distribution with scale...
# 	32.0 * 8.358714991894317e-05 * [8.35871499e-05] = [2.23577972e-07]
# pac_noise: [2.23577972e-07]
# mi=0.015625, scale=[2.23577972e-07]
# Chosen Sample [0.05006097]
# Chosen Sample [0.05021774]
# Chosen Sample [0.04999864]
# Chosen Sample [0.05024448]
# Chosen Sample [0.05018729]
# Chosen Sample [0.05022366]
# Chosen Sample [0.05004054]
# Chosen Sample [0.05008736]
# Chosen Sample [0.05009577]
# Chosen Sample [0.05023226]
# Chosen Sample [0.05007779]
# Chosen Sample [0.05014716]
# Chosen Sample [0.05011964]
# Chosen Sample [0.05008336]
# Chosen Sample [0.05012224]
# Chosen Sample [0.05020916]
# Chosen Sample [0.05027167]
# Chosen Sample [0.0499838]
# Chosen Sample [0.05017748]
# Chosen Sample [0.05012365]
# Chosen Sample [0.05011237]
# Chosen Sample [0.05016334]
# Chosen Sample [0.05013938]
# Chosen Sample [0.0502555]
# Chosen Sample [0.05014431]
# Chosen Sample [0.05014464]
# Chosen Sample [0.05019857]
# Chosen Sample [0.04990631]
# Chosen Sample [0.05010045]
# Chosen Sample [0.05001605]
# Chosen Sample [0.05020149]
# Chosen Sample [0.05027756]
# Chosen Sample [0.05007834]
# Chosen Sample [0.05001678]
# Chosen Sample [0.05012961]
# Chosen Sample [0.04999419]
# Chosen Sample [0.05008026]
# Chosen Sample [0.05006116]
# Chosen Sample [0.05001881]
# Chosen Sample [0.0500318]
# Chosen Sample [0.0501071]
# Chosen Sample [0.05007131]
# Chosen Sample [0.05002375]
# Chosen Sample [0.05016388]
# Chosen Sample [0.05003953]
# Chosen Sample [0.04996469]
# Chosen Sample [0.05001751]
# Chosen Sample [0.05023512]
# Chosen Sample [0.0501115]
# Chosen Sample [0.05019787]
# Chosen Sample [0.05000809]
# Chosen Sample [0.05014409]
# Chosen Sample [0.05008392]
# Chosen Sample [0.05021494]
# Chosen Sample [0.05011958]
# Chosen Sample [0.05015995]
# Chosen Sample [0.0502188]
# Chosen Sample [0.05006231]
# Chosen Sample [0.04990723]
# Chosen Sample [0.05017344]
# Chosen Sample [0.0500149]
# Chosen Sample [0.05013436]
# Chosen Sample [0.04999216]
# Chosen Sample [0.05019129]
# Chosen Sample [0.05011833]
# Chosen Sample [0.05019412]
# Chosen Sample [0.05020697]
# Chosen Sample [0.05018408]
# Chosen Sample [0.05018946]
# Chosen Sample [0.05010817]
# Chosen Sample [0.04995325]
# Chosen Sample [0.05007535]
# Chosen Sample [0.0502668]
# Chosen Sample [0.05011132]
# Chosen Sample [0.05024778]
# Chosen Sample [0.05014374]
# Chosen Sample [0.05007354]
# Chosen Sample [0.05019968]
# Chosen Sample [0.05016997]
# Chosen Sample [0.05002987]
# Chosen Sample [0.05015424]
# Chosen Sample [0.05016983]
# Chosen Sample [0.05011327]
# Chosen Sample [0.05024805]
# Chosen Sample [0.05015587]
# Chosen Sample [0.05015204]
# Chosen Sample [0.05013256]
# Chosen Sample [0.0501327]
# Chosen Sample [0.05011343]
# Chosen Sample [0.05019426]
# Chosen Sample [0.05025025]
# Chosen Sample [0.05008961]
# Chosen Sample [0.05020435]
# Chosen Sample [0.05012882]
# Chosen Sample [0.05011556]
# Chosen Sample [0.05008857]
# Chosen Sample [0.05022673]
# Chosen Sample [0.0501299]
# Chosen Sample [0.05009998]
# Chosen Sample [0.05010089]
# Chosen Sample [0.0502038]
# Chosen Sample [0.05021965]
# Chosen Sample [0.0502795]
# Chosen Sample [0.04992337]
# Chosen Sample [0.05029073]
# Chosen Sample [0.05013519]
# Chosen Sample [0.05015059]
# Chosen Sample [0.05016018]
# Chosen Sample [0.05008575]
# Chosen Sample [0.0500263]
# Chosen Sample [0.05020796]
# Chosen Sample [0.05023063]
# Chosen Sample [0.05027458]
# Chosen Sample [0.05014913]
# Chosen Sample [0.05005199]
# Chosen Sample [0.05007123]
# Chosen Sample [0.05012638]
# Chosen Sample [0.05018359]
# Chosen Sample [0.05028471]
# Chosen Sample [0.05012573]
# Chosen Sample [0.05017141]
# Chosen Sample [0.04996413]
# Chosen Sample [0.05006585]
# Chosen Sample [0.05022073]
# Chosen Sample [0.0500369]
# Chosen Sample [0.0499973]
# Chosen Sample [0.05012802]
# Chosen Sample [0.0501222]
# Chosen Sample [0.05023169]
# Chosen Sample [0.05017284]
# Chosen Sample [0.05004948]
# Chosen Sample [0.05009154]
# Chosen Sample [0.05012491]
# Chosen Sample [0.05000406]
# Chosen Sample [0.05026707]
# Chosen Sample [0.05013703]
# Chosen Sample [0.05006216]
# Chosen Sample [0.05024159]
# Chosen Sample [0.05014205]
# Chosen Sample [0.05011175]
# Chosen Sample [0.05010258]
# Chosen Sample [0.05019376]
# Chosen Sample [0.05008814]
# Chosen Sample [0.05006483]
# Chosen Sample [0.05020021]
# Chosen Sample [0.05002231]
# Chosen Sample [0.05012836]
# Chosen Sample [0.05005766]
# Chosen Sample [0.05027458]
# Chosen Sample [0.05007999]
# Chosen Sample [0.0500734]
# Chosen Sample [0.05022367]
# Chosen Sample [0.05029939]
# Chosen Sample [0.05019375]
# Chosen Sample [0.05022348]
# Chosen Sample [0.05035254]
# Chosen Sample [0.05012944]
# Chosen Sample [0.05018184]
# Chosen Sample [0.05017659]
# Chosen Sample [0.05029508]
# Chosen Sample [0.05008026]
# Chosen Sample [0.05013781]
# Chosen Sample [0.05004165]
# Chosen Sample [0.05020921]
# Chosen Sample [0.0500959]
# Chosen Sample [0.05017672]
# Chosen Sample [0.05005259]
# Chosen Sample [0.05019906]
# Chosen Sample [0.05004139]
# Chosen Sample [0.05010162]
# Chosen Sample [0.05025349]
# Chosen Sample [0.05021734]
# Chosen Sample [0.05018753]
# Chosen Sample [0.05011247]
# Chosen Sample [0.05011361]
# Chosen Sample [0.05006263]
# Chosen Sample [0.05022472]
# Chosen Sample [0.05014417]
# Chosen Sample [0.05015246]
# Chosen Sample [0.05019503]
# Chosen Sample [0.05022801]
# Chosen Sample [0.05006456]
# Chosen Sample [0.05009829]
# Chosen Sample [0.04999715]
# Chosen Sample [0.05009601]
# Chosen Sample [0.05011641]
# Chosen Sample [0.05020372]
# Chosen Sample [0.05003397]
# Chosen Sample [0.05031098]
# Chosen Sample [0.05014234]
# Chosen Sample [0.05009243]
# Chosen Sample [0.04992382]
# Chosen Sample [0.05014863]
# Chosen Sample [0.0501566]
# Chosen Sample [0.05025425]
# Chosen Sample [0.05027715]
# Chosen Sample [0.05008891]
# Chosen Sample [0.05015262]
# Chosen Sample [0.05005483]
# Chosen Sample [0.05014914]
# Chosen Sample [0.05020796]
# Chosen Sample [0.05007556]
# Chosen Sample [0.05022477]
# Chosen Sample [0.05014016]
# Chosen Sample [0.05009825]
# Chosen Sample [0.05013756]
# Chosen Sample [0.05021257]
# Chosen Sample [0.04998142]
# Chosen Sample [0.05006254]
# Chosen Sample [0.05024694]
# Chosen Sample [0.05016619]
# Chosen Sample [0.05034143]
# Chosen Sample [0.05016809]
# Chosen Sample [0.05032157]
# Chosen Sample [0.05023352]
# Chosen Sample [0.05004342]
# Chosen Sample [0.05021792]
# Chosen Sample [0.05012074]
# Chosen Sample [0.05020384]
# Chosen Sample [0.05015321]
# Chosen Sample [0.0501531]
# Chosen Sample [0.05005336]
# Chosen Sample [0.05008885]
# Chosen Sample [0.05019963]
# Chosen Sample [0.05013044]
# Chosen Sample [0.05010673]
# Chosen Sample [0.0502313]
# Chosen Sample [0.05018642]
# Chosen Sample [0.0502098]
# Chosen Sample [0.05010735]
# Chosen Sample [0.05021745]
# Chosen Sample [0.05001163]
# Chosen Sample [0.05025821]
# Chosen Sample [0.05008541]
# Chosen Sample [0.05023251]
# Chosen Sample [0.05005066]
# Chosen Sample [0.05013969]
# Chosen Sample [0.05008828]
# Chosen Sample [0.05008347]
# Chosen Sample [0.05025289]
# Chosen Sample [0.05019783]
# Chosen Sample [0.04996554]
# Chosen Sample [0.05012015]
# Chosen Sample [0.05015998]
# Chosen Sample [0.05016068]
# Chosen Sample [0.05016182]
# Chosen Sample [0.05020502]
# Chosen Sample [0.05017752]
# Chosen Sample [0.05028524]
# Chosen Sample [0.05016435]
# Chosen Sample [0.05011713]
# Chosen Sample [0.05014201]
# Chosen Sample [0.05008216]
# Chosen Sample [0.05020059]
# Chosen Sample [0.05002566]
# Chosen Sample [0.05013094]
# Chosen Sample [0.05027906]
# Chosen Sample [0.05009861]
# Chosen Sample [0.0502856]
# Chosen Sample [0.05012243]
# Chosen Sample [0.05018726]
# Chosen Sample [0.05013164]
# Chosen Sample [0.05000909]
# Chosen Sample [0.05016601]
# Chosen Sample [0.05014666]
# Chosen Sample [0.05028824]
# Chosen Sample [0.05021962]
# Chosen Sample [0.05019203]
# Chosen Sample [0.05007725]
# Chosen Sample [0.05000879]
# Chosen Sample [0.05025884]
# Chosen Sample [0.05016566]
# Chosen Sample [0.05017412]
# Chosen Sample [0.05006717]
# Chosen Sample [0.05010125]
# Chosen Sample [0.05016993]
# Chosen Sample [0.05012535]
# Chosen Sample [0.05021399]
# Chosen Sample [0.05010741]
# Chosen Sample [0.05013446]
# Chosen Sample [0.05024172]
# Chosen Sample [0.0502464]
# Chosen Sample [0.05025978]
# Chosen Sample [0.05022362]
# Chosen Sample [0.05009634]
# Chosen Sample [0.04993474]
# Chosen Sample [0.05010309]
# Chosen Sample [0.05021857]
# Chosen Sample [0.0502892]
# Chosen Sample [0.05012376]
# Chosen Sample [0.05022796]
# Chosen Sample [0.05014275]
# Chosen Sample [0.05017577]
# Chosen Sample [0.05013781]
# Chosen Sample [0.05024638]
# Chosen Sample [0.05007398]
# Chosen Sample [0.05027333]
# Chosen Sample [0.05015164]
# Chosen Sample [0.05018957]
# Chosen Sample [0.05019381]
# Chosen Sample [0.05006297]
# Chosen Sample [0.05025739]
# Chosen Sample [0.05012063]
# Chosen Sample [0.05013781]
# Chosen Sample [0.0501615]
# Chosen Sample [0.05013512]
# Chosen Sample [0.05002563]
# Chosen Sample [0.05003722]
# Chosen Sample [0.05012362]
# Chosen Sample [0.05013828]
# Chosen Sample [0.05021656]
# Chosen Sample [0.05008123]
# Chosen Sample [0.05004408]
# Chosen Sample [0.05017227]
# Chosen Sample [0.05013977]
# Chosen Sample [0.04993685]
# Chosen Sample [0.0502379]
# Chosen Sample [0.05018645]
# Chosen Sample [0.05014429]
# Chosen Sample [0.05014046]
# Chosen Sample [0.05021162]
# Chosen Sample [0.05010254]
# Chosen Sample [0.05010023]
# Chosen Sample [0.05019632]
# Chosen Sample [0.05018168]
# Chosen Sample [0.05012317]
# Chosen Sample [0.05008076]
# Chosen Sample [0.05019059]
# Chosen Sample [0.05006735]
# Chosen Sample [0.05027086]
# Chosen Sample [0.05016023]
# Chosen Sample [0.05018153]
# Chosen Sample [0.05020592]
# Chosen Sample [0.05012761]
# Chosen Sample [0.05010258]
# Chosen Sample [0.05024243]
# Chosen Sample [0.05011132]
# Chosen Sample [0.050251]
# Chosen Sample [0.05017012]
# Chosen Sample [0.05023394]
# Chosen Sample [0.05029895]
# Chosen Sample [0.05015246]
# Chosen Sample [0.05020494]
# Chosen Sample [0.05007336]
# Chosen Sample [0.05013082]
# Chosen Sample [0.05019633]
# Chosen Sample [0.05016007]
# Chosen Sample [0.05010829]
# Chosen Sample [0.05002209]
# Chosen Sample [0.05015687]
# Chosen Sample [0.05016058]
# Chosen Sample [0.05013824]
# Chosen Sample [0.05013493]
# Chosen Sample [0.05009567]
# Chosen Sample [0.05007342]
# Chosen Sample [0.05018163]
# Chosen Sample [0.05028863]
# Chosen Sample [0.05021123]
# Chosen Sample [0.05003413]
# Chosen Sample [0.05029999]
# Chosen Sample [0.05005928]
# Chosen Sample [0.05020125]
# Chosen Sample [0.05018908]
# Chosen Sample [0.05007129]
# Chosen Sample [0.05027782]
# Chosen Sample [0.05009396]
# Chosen Sample [0.05015571]
# Chosen Sample [0.05009021]
# Chosen Sample [0.05018772]
# Chosen Sample [0.05010548]
# Chosen Sample [0.05024959]
# Chosen Sample [0.05022098]
# Chosen Sample [0.05023145]
# Chosen Sample [0.04997519]
# Chosen Sample [0.0501707]
# Chosen Sample [0.05009947]
# Chosen Sample [0.05009218]
# Chosen Sample [0.05011327]
# Chosen Sample [0.05010924]
# Chosen Sample [0.05008155]
# Chosen Sample [0.05018137]
# Chosen Sample [0.0501595]
# Chosen Sample [0.05023111]
# Chosen Sample [0.05018407]
# Chosen Sample [0.05027033]
# Chosen Sample [0.05007851]
# Chosen Sample [0.05022436]
# Chosen Sample [0.05025374]
# Chosen Sample [0.05004567]
# Chosen Sample [0.05011917]
# Chosen Sample [0.05019044]
# Chosen Sample [0.05005459]
# Chosen Sample [0.05012934]
# Chosen Sample [0.0502327]
# Chosen Sample [0.05017786]
# Chosen Sample [0.0502246]
# Chosen Sample [0.05011084]
# Chosen Sample [0.05015677]
# Chosen Sample [0.05015151]
# Chosen Sample [0.05033409]
# Chosen Sample [0.04999717]
# Chosen Sample [0.05000325]
# Chosen Sample [0.0502247]
# Chosen Sample [0.05003822]
# Chosen Sample [0.050055]
# Chosen Sample [0.05017308]
# Chosen Sample [0.0499781]
# Chosen Sample [0.05021042]
# Chosen Sample [0.05015275]
# Chosen Sample [0.05005297]
# Chosen Sample [0.0500327]
# Chosen Sample [0.0500352]
# Chosen Sample [0.05014458]
# Chosen Sample [0.05018913]
# Chosen Sample [0.05024598]
# Chosen Sample [0.05018567]
# Chosen Sample [0.05015286]
# Chosen Sample [0.05024358]
# Chosen Sample [0.05013218]
# Chosen Sample [0.05009147]
# Chosen Sample [0.05018006]
# Chosen Sample [0.05015798]
# Chosen Sample [0.05015963]
# Chosen Sample [0.0501369]
# Chosen Sample [0.05030069]
# Chosen Sample [0.05011769]
# Chosen Sample [0.05015739]
# Chosen Sample [0.05013716]
# Chosen Sample [0.05012042]
# Chosen Sample [0.05013767]
# Chosen Sample [0.05017013]
# Chosen Sample [0.05009767]
# Chosen Sample [0.05016796]
# Chosen Sample [0.05032181]
# Chosen Sample [0.05006545]
# Chosen Sample [0.05020098]
# Chosen Sample [0.05014408]
# Chosen Sample [0.05014526]
# Chosen Sample [0.05012922]
# Chosen Sample [0.05015822]
# Chosen Sample [0.05003923]
# Chosen Sample [0.05022371]
# Chosen Sample [0.05010941]
# Chosen Sample [0.05035254]
# Chosen Sample [0.05011734]
# Chosen Sample [0.05015238]
# Chosen Sample [0.05006223]
# Chosen Sample [0.05019135]
# Chosen Sample [0.05013575]
# Chosen Sample [0.05014572]
# Chosen Sample [0.05010786]
# Chosen Sample [0.05018704]
# Chosen Sample [0.05016163]
# ...
# Chosen Sample [0.05015116]
# Chosen Sample [0.05004648]
# Chosen Sample [0.05029742]
# Chosen Sample [0.05011905]
# Chosen Sample [0.05014802]
# Chosen Sample [0.05017807]
# Chosen Sample [0.05010022]
# Chosen Sample [0.05010336]
# Chosen Sample [0.05012752]
# Chosen Sample [0.05016056]
# Chosen Sample [0.05010935]
# Chosen Sample [0.05025515]
# Chosen Sample [0.04997837]
# Chosen Sample [0.05001767]
# Chosen Sample [0.0501408]
# Chosen Sample [0.05024464]
# Chosen Sample [0.05030781]
# Chosen Sample [0.05014446]
# Chosen Sample [0.05033228]
# Chosen Sample [0.05020962]
# Chosen Sample [0.05012145]
# Chosen Sample [0.05008853]
# Chosen Sample [0.05008139]
# Chosen Sample [0.0500229]
# Chosen Sample [0.05024598]
# Chosen Sample [0.05004644]
# Chosen Sample [0.05018223]
# Chosen Sample [0.0500773]
# Chosen Sample [0.05001268]
# Chosen Sample [0.05011235]
# Chosen Sample [0.05013813]
# Chosen Sample [0.05015995]
# Chosen Sample [0.05004347]
# Chosen Sample [0.05005137]
# Chosen Sample [0.05021295]
# Chosen Sample [0.05017987]
# Chosen Sample [0.05014878]
# Chosen Sample [0.05002001]
# Chosen Sample [0.05012056]
# Chosen Sample [0.05012761]
# Chosen Sample [0.05019967]
# Chosen Sample [0.05002437]
# Chosen Sample [0.05010625]
# Chosen Sample [0.05024125]
# Chosen Sample [0.05013756]
# Chosen Sample [0.05010999]
# Chosen Sample [0.05020283]
# Chosen Sample [0.05012823]
# Chosen Sample [0.05004378]
# Chosen Sample [0.05017017]
# Chosen Sample [0.05010986]
# Chosen Sample [0.0501317]
# Chosen Sample [0.0500901]
# Chosen Sample [0.05018758]
# Chosen Sample [0.05015331]
# Chosen Sample [0.05024528]
# Chosen Sample [0.0500318]
# Chosen Sample [0.04998404]
# Chosen Sample [0.05000406]
# Chosen Sample [0.05034512]
# Chosen Sample [0.05011425]
# Chosen Sample [0.05019906]
# Chosen Sample [0.05024155]
# Chosen Sample [0.04990271]
# Chosen Sample [0.05020298]
# Chosen Sample [0.05020402]
# Chosen Sample [0.04998095]
# Chosen Sample [0.05006208]
# Chosen Sample [0.05014374]
# Chosen Sample [0.05012328]
# Chosen Sample [0.0500739]
# Chosen Sample [0.05018055]
# Chosen Sample [0.05017161]
# Chosen Sample [0.05014557]
# Chosen Sample [0.05014383]
# Chosen Sample [0.05006865]
# Chosen Sample [0.05011992]
# Chosen Sample [0.0500525]
# Chosen Sample [0.05028445]
# Chosen Sample [0.05002594]
# Chosen Sample [0.05004442]
# Chosen Sample [0.05011217]
# Chosen Sample [0.05022769]
# Chosen Sample [0.05018772]
# Chosen Sample [0.05018644]
# Chosen Sample [0.05036435]
# Chosen Sample [0.05028557]
# Chosen Sample [0.05020551]
# Chosen Sample [0.05036342]
# Chosen Sample [0.05034143]
# Chosen Sample [0.0502092]
# Chosen Sample [0.05023603]
# Chosen Sample [0.05007313]
# Chosen Sample [0.05013704]
# Chosen Sample [0.05020778]
# Chosen Sample [0.05014251]
# Chosen Sample [0.05006208]
# Chosen Sample [0.05000298]
# Chosen Sample [0.05022268]
# Chosen Sample [0.05018408]
# Chosen Sample [0.05020298]
# Chosen Sample [0.05009043]
# Chosen Sample [0.05007735]
# Chosen Sample [0.04998767]
# Chosen Sample [0.05013104]
# Chosen Sample [0.05010715]
# Chosen Sample [0.05024393]
# Chosen Sample [0.05013332]
# Chosen Sample [0.05020173]
# Chosen Sample [0.05016614]
# Chosen Sample [0.05007258]
# Chosen Sample [0.05006847]
# Chosen Sample [0.05017178]
# Chosen Sample [0.05016515]
# Chosen Sample [0.05015075]
# Chosen Sample [0.05003857]
# Chosen Sample [0.04999743]
# Chosen Sample [0.05011135]
# Chosen Sample [0.05022047]
# Chosen Sample [0.05019203]
# Chosen Sample [0.05009291]
# Chosen Sample [0.05012307]
# Chosen Sample [0.05030376]
# Chosen Sample [0.05007052]
# Chosen Sample [0.05009482]
# Chosen Sample [0.05016981]
# Chosen Sample [0.05018344]
# Chosen Sample [0.05008697]
# Chosen Sample [0.05009914]
# Chosen Sample [0.05013136]
# Chosen Sample [0.0502192]
# Chosen Sample [0.05020831]
# Chosen Sample [0.05008051]
# Chosen Sample [0.05014016]
# Chosen Sample [0.05010707]
# Chosen Sample [0.05006308]
# Chosen Sample [0.0500213]
# Chosen Sample [0.05019318]
# Chosen Sample [0.05014863]
# Chosen Sample [0.05005539]
# Chosen Sample [0.05016981]
# Chosen Sample [0.05006518]
# Chosen Sample [0.0501281]
# Chosen Sample [0.05031148]
# Chosen Sample [0.0502493]
# Chosen Sample [0.05013491]
# Chosen Sample [0.05022223]
# Chosen Sample [0.05017698]
# Chosen Sample [0.05013892]
# Chosen Sample [0.05017577]
# Chosen Sample [0.05011466]
# Chosen Sample [0.05009579]
# Chosen Sample [0.05013038]
# Chosen Sample [0.05012053]
# Chosen Sample [0.05014431]
# Chosen Sample [0.05006205]
# Chosen Sample [0.05011077]
# Chosen Sample [0.05019323]
# Chosen Sample [0.05005951]
# Chosen Sample [0.05008088]
# Chosen Sample [0.05027296]
# Chosen Sample [0.05019044]
# Chosen Sample [0.05010443]
# Chosen Sample [0.05012034]
# Chosen Sample [0.05019857]
# Chosen Sample [0.05013081]
# Chosen Sample [0.05023018]
# Chosen Sample [0.05014595]
# Chosen Sample [0.05028777]
# Chosen Sample [0.05011368]
# Chosen Sample [0.05009114]
# Chosen Sample [0.05015737]
# Chosen Sample [0.05024421]
# Chosen Sample [0.04994676]
# Chosen Sample [0.05011368]
# Chosen Sample [0.05021829]
# Chosen Sample [0.05031148]
# Chosen Sample [0.050191]
# Chosen Sample [0.0501588]
# Chosen Sample [0.04999011]
# Chosen Sample [0.05014904]
# Chosen Sample [0.05017508]
# Chosen Sample [0.0500656]
# Chosen Sample [0.05022812]
# Chosen Sample [0.05005293]
# Chosen Sample [0.05023154]
# Chosen Sample [0.05015332]
# Chosen Sample [0.05010954]
# Chosen Sample [0.05010366]
# Chosen Sample [0.05028674]
# Chosen Sample [0.05038655]
# Chosen Sample [0.05014107]
# Chosen Sample [0.05026216]
# Chosen Sample [0.05004346]
# Chosen Sample [0.05017539]
# Chosen Sample [0.05027474]
# Chosen Sample [0.04991663]
# Chosen Sample [0.05021208]
# Chosen Sample [0.05007785]
# Chosen Sample [0.05024115]
# Chosen Sample [0.05012053]
# Chosen Sample [0.05004014]
# Chosen Sample [0.05017643]
# Chosen Sample [0.05014123]
# Chosen Sample [0.0501808]
# Chosen Sample [0.05022812]
# Chosen Sample [0.05017996]
# Chosen Sample [0.05011889]
# Chosen Sample [0.05014013]
# Chosen Sample [0.05009767]
# Chosen Sample [0.05009292]
# Chosen Sample [0.05024843]
# Chosen Sample [0.05017184]
# Chosen Sample [0.05032457]
# Chosen Sample [0.0501979]
# Chosen Sample [0.05003676]
# Chosen Sample [0.05008837]
# Chosen Sample [0.05008079]
# Chosen Sample [0.05006455]
# Chosen Sample [0.05025592]
# Chosen Sample [0.05027833]
# Chosen Sample [0.05007032]
# Chosen Sample [0.0501938]
# Chosen Sample [0.05015615]
# Chosen Sample [0.05009635]
# Chosen Sample [0.05024258]
# Chosen Sample [0.05003023]
# Chosen Sample [0.05017574]
# Chosen Sample [0.05011577]
# Chosen Sample [0.05015519]
# Chosen Sample [0.05025192]
# Chosen Sample [0.05012889]
# Chosen Sample [0.05029677]
# Chosen Sample [0.05009938]
# Chosen Sample [0.05010455]
# Chosen Sample [0.04998769]
# Chosen Sample [0.05020045]
# Chosen Sample [0.05017745]
# Chosen Sample [0.04996467]
# Chosen Sample [0.05024522]
# Chosen Sample [0.05002853]
# Chosen Sample [0.05015337]
# Chosen Sample [0.05035188]
# Chosen Sample [0.04998142]
# Chosen Sample [0.05009112]
# Chosen Sample [0.05009804]
# Chosen Sample [0.05015571]
# Chosen Sample [0.05006467]
# Chosen Sample [0.0501261]
# Chosen Sample [0.05022425]
# Chosen Sample [0.05003132]
# Chosen Sample [0.04995724]
# Chosen Sample [0.05004507]
# Chosen Sample [0.05017184]
# Chosen Sample [0.05028593]
# Chosen Sample [0.05014193]
# Chosen Sample [0.05015517]
# Chosen Sample [0.05007624]
# Chosen Sample [0.05000419]
# Chosen Sample [0.05017595]
# Chosen Sample [0.05019271]
# Chosen Sample [0.05022082]
# Chosen Sample [0.05016026]
# Chosen Sample [0.05012421]
# Chosen Sample [0.05007242]
# Chosen Sample [0.05012936]
# Chosen Sample [0.04997837]
# Chosen Sample [0.04993161]
# Chosen Sample [0.05015921]
# Chosen Sample [0.0500911]
# Chosen Sample [0.05010124]
# Chosen Sample [0.0499906]
# Chosen Sample [0.05012581]
# Chosen Sample [0.05005731]
# Chosen Sample [0.05004212]
# Chosen Sample [0.05008851]
# Chosen Sample [0.05017422]
# Chosen Sample [0.05027943]
# Chosen Sample [0.05028863]
# Chosen Sample [0.05030428]
# Chosen Sample [0.05014589]
# Chosen Sample [0.05017854]
# Chosen Sample [0.05023715]
# Chosen Sample [0.05024154]
# Chosen Sample [0.05027202]
# Chosen Sample [0.05021484]
# Chosen Sample [0.05019978]
# Chosen Sample [0.05024317]
# Chosen Sample [0.05015677]
# Chosen Sample [0.05028484]
# Chosen Sample [0.05007031]
# Chosen Sample [0.05014207]
# Chosen Sample [0.05005596]
# Chosen Sample [0.05006495]
# Chosen Sample [0.04997958]
# Chosen Sample [0.05011519]
# Chosen Sample [0.05006152]
# Chosen Sample [0.05012602]
# Chosen Sample [0.05007455]
# Chosen Sample [0.05012551]
# Chosen Sample [0.05009634]
# Chosen Sample [0.05008264]
# Chosen Sample [0.05023703]
# Chosen Sample [0.05014898]
# Chosen Sample [0.05025123]
# Chosen Sample [0.05017734]
# Chosen Sample [0.05015047]
# Chosen Sample [0.05019489]
# Chosen Sample [0.05004332]
# Chosen Sample [0.05004933]
# Chosen Sample [0.05022659]
# Chosen Sample [0.05023437]
# Chosen Sample [0.05002685]
# Chosen Sample [0.05015739]
# Chosen Sample [0.05030098]
# Chosen Sample [0.05009277]
# Chosen Sample [0.05019701]
# Chosen Sample [0.05016195]
# Chosen Sample [0.05020149]
# Chosen Sample [0.0502477]
# Chosen Sample [0.05009559]
# Chosen Sample [0.0500106]
# Chosen Sample [0.05025163]
# Chosen Sample [0.05012944]
# Chosen Sample [0.05022965]
# Chosen Sample [0.05010433]
# Chosen Sample [0.050163]
# Chosen Sample [0.05021602]
# Chosen Sample [0.05016303]
# Chosen Sample [0.05014713]
# Chosen Sample [0.05005766]
# Chosen Sample [0.05028471]
# Chosen Sample [0.05016193]
# Chosen Sample [0.05016471]
# Chosen Sample [0.05003129]
# Chosen Sample [0.05006367]
# Chosen Sample [0.05003591]
# Chosen Sample [0.0502272]
# Chosen Sample [0.05016678]
# Chosen Sample [0.05022945]
# Chosen Sample [0.05019021]
# Chosen Sample [0.05005296]
# Chosen Sample [0.05019302]
# Chosen Sample [0.05031273]
# Chosen Sample [0.05019941]
# Chosen Sample [0.05009325]
# Chosen Sample [0.05006223]
# Chosen Sample [0.05011683]
# Chosen Sample [0.05029798]
# Chosen Sample [0.05016334]
# Chosen Sample [0.05023892]
# Chosen Sample [0.05028115]
# Chosen Sample [0.05013868]
# Chosen Sample [0.05009135]
# Chosen Sample [0.05009579]
# Chosen Sample [0.049987]
# Chosen Sample [0.05011253]
# Chosen Sample [0.05020934]
# Chosen Sample [0.05006308]
# Chosen Sample [0.05016646]
# Chosen Sample [0.05008089]
# Chosen Sample [0.05016331]
# Chosen Sample [0.05021123]
# Chosen Sample [0.05006005]
# Chosen Sample [0.05019326]
# Chosen Sample [0.05024039]
# Chosen Sample [0.0499729]
# Chosen Sample [0.05009249]
# Chosen Sample [0.04993575]
# Chosen Sample [0.05019758]
# Chosen Sample [0.05009692]
# Chosen Sample [0.05009255]
# Chosen Sample [0.05023161]
# Chosen Sample [0.05003614]
# Chosen Sample [0.05017574]
# Chosen Sample [0.05014212]
# Chosen Sample [0.05031971]
# Chosen Sample [0.05030364]
# Chosen Sample [0.05026055]
# Chosen Sample [0.05017343]
# Chosen Sample [0.05022368]
# Chosen Sample [0.05014049]
# Chosen Sample [0.05001973]
# Chosen Sample [0.05016064]
# Chosen Sample [0.05008344]
# Chosen Sample [0.05008873]
# Chosen Sample [0.05024845]
# Chosen Sample [0.05015993]
# Chosen Sample [0.05024495]
# Chosen Sample [0.05018898]
# Chosen Sample [0.05010304]
# Chosen Sample [0.05011855]
# Chosen Sample [0.05008428]
# Chosen Sample [0.05000135]
# Chosen Sample [0.0500877]
# Chosen Sample [0.05012817]
# Chosen Sample [0.0502309]
# Chosen Sample [0.05012429]
# Chosen Sample [0.05015122]
# Chosen Sample [0.05018425]
# Chosen Sample [0.05012108]
# Chosen Sample [0.05013953]
# Chosen Sample [0.05023714]
# Chosen Sample [0.05014201]
# Chosen Sample [0.05013829]
# Chosen Sample [0.05006455]
# Chosen Sample [0.05015155]
# Chosen Sample [0.05006228]
# Chosen Sample [0.05006311]
# Chosen Sample [0.05016246]
# Chosen Sample [0.05016105]
# Chosen Sample [0.05012894]
# Chosen Sample [0.0500766]
# Chosen Sample [0.05019327]
# Chosen Sample [0.05015838]
# Chosen Sample [0.0499673]
# Chosen Sample [0.05023905]
# Chosen Sample [0.05003207]
# Chosen Sample [0.05011993]
# Chosen Sample [0.05030798]
# Chosen Sample [0.05022371]
# Chosen Sample [0.05007606]
# Chosen Sample [0.05014689]
# Chosen Sample [0.05016606]
# Chosen Sample [0.05010862]
# Chosen Sample [0.05019271]
# Chosen Sample [0.05005529]
# Chosen Sample [0.05014431]
# Chosen Sample [0.05025467]
# Chosen Sample [0.05017059]
# Chosen Sample [0.05022381]
# Chosen Sample [0.05012364]
# Chosen Sample [0.05016845]
# Chosen Sample [0.05007499]
# Chosen Sample [0.05007009]
# Chosen Sample [0.05011758]
# Chosen Sample [0.05022073]
# Chosen Sample [0.05018597]
# Chosen Sample [0.05006868]
# Chosen Sample [0.05014021]
# Chosen Sample [0.05004974]
# Chosen Sample [0.05005387]
# Chosen Sample [0.05014717]
# Chosen Sample [0.05013218]
# Chosen Sample [0.05027828]
# Chosen Sample [0.05024019]
# Chosen Sample [0.05030636]
# Chosen Sample [0.05019285]
# Chosen Sample [0.05024897]
# Chosen Sample [0.05014659]
# Chosen Sample [0.04996857]
# Chosen Sample [0.05018335]
# Chosen Sample [0.05008155]
# Chosen Sample [0.05015668]
# Chosen Sample [0.05016054]
# Chosen Sample [0.05008441]
# Chosen Sample [0.05018326]
# Chosen Sample [0.05022385]
# Chosen Sample [0.05010288]
# Chosen Sample [0.05028077]
# Chosen Sample [0.05011998]
# Chosen Sample [0.05011232]
# Chosen Sample [0.05025085]
# Chosen Sample [0.05013634]
# Chosen Sample [0.05011]
# Chosen Sample [0.05003023]
# Chosen Sample [0.05002174]
# Chosen Sample [0.05017716]
# Chosen Sample [0.05028417]
# Chosen Sample [0.05006413]
# Chosen Sample [0.05014067]
# Chosen Sample [0.05008204]
# Chosen Sample [0.05008833]
# Chosen Sample [0.05016054]
# Chosen Sample [0.05012815]
# Chosen Sample [0.05018476]
# Chosen Sample [0.05018151]
# Chosen Sample [0.05014878]
# Chosen Sample [0.05026259]
# Chosen Sample [0.05018532]
# Chosen Sample [0.0502345]
# Chosen Sample [0.05008428]
# Chosen Sample [0.05009047]
# Chosen Sample [0.05018729]
# Chosen Sample [0.05008873]
# Chosen Sample [0.05018142]
# Chosen Sample [0.05032684]
# Chosen Sample [0.05024615]
# Chosen Sample [0.05022135]
# Chosen Sample [0.050076]
# Chosen Sample [0.05015254]
# Chosen Sample [0.05021817]
# Chosen Sample [0.05000909]
# Chosen Sample [0.05018909]
# Chosen Sample [0.0499881]
# Chosen Sample [0.05026695]
# Chosen Sample [0.05016819]
# Chosen Sample [0.05014319]
# Chosen Sample [0.05018642]
# Chosen Sample [0.05004342]
# Chosen Sample [0.05003446]
# Chosen Sample [0.05018922]
# Chosen Sample [0.04999295]
# Chosen Sample [0.05011933]
# Chosen Sample [0.05019325]
# Chosen Sample [0.05035254]
# Chosen Sample [0.05011203]
# Chosen Sample [0.05007535]
# Chosen Sample [0.05000745]
# Chosen Sample [0.05009692]
# Chosen Sample [0.05020889]
# Chosen Sample [0.05019626]
# Chosen Sample [0.05007851]
# Chosen Sample [0.0501081]
# Chosen Sample [0.05026923]
# Chosen Sample [0.05016304]
# Chosen Sample [0.05005521]
# Chosen Sample [0.05016653]
# Chosen Sample [0.05008915]
# Chosen Sample [0.0500855]
# Chosen Sample [0.05013015]
# Chosen Sample [0.05020006]
# Chosen Sample [0.05022549]
# Chosen Sample [0.05016619]
# Chosen Sample [0.05010704]
# Chosen Sample [0.05010203]
# Chosen Sample [0.05001706]
# Chosen Sample [0.05008635]
# Chosen Sample [0.05016766]
# Chosen Sample [0.04997042]
# Chosen Sample [0.05012037]
# Chosen Sample [0.05028765]
# Chosen Sample [0.05015142]
# Chosen Sample [0.05002675]
# Chosen Sample [0.05012509]
# Chosen Sample [0.05039558]
# Chosen Sample [0.0501795]
# Chosen Sample [0.05017094]
# Chosen Sample [0.05007509]
# Chosen Sample [0.05019238]
# Chosen Sample [0.05020174]
# Chosen Sample [0.05003902]
# Chosen Sample [0.0500652]
# Chosen Sample [0.05024561]
# Chosen Sample [0.05014594]
# Chosen Sample [0.05022385]
# Chosen Sample [0.05021151]
# Chosen Sample [0.05018834]
# Chosen Sample [0.05005269]
# Chosen Sample [0.05019564]
# Chosen Sample [0.05005517]
# Chosen Sample [0.05006159]
# Chosen Sample [0.05008893]
# Chosen Sample [0.05019025]
# Chosen Sample [0.05009525]
# Chosen Sample [0.04990684]
# Chosen Sample [0.050142]
# Chosen Sample [0.04998496]
# Chosen Sample [0.05010478]
# Chosen Sample [0.05011325]
# Chosen Sample [0.05013608]
# Chosen Sample [0.05001677]
# Chosen Sample [0.0502313]
# Chosen Sample [0.05014967]
# Chosen Sample [0.0502137]
# Chosen Sample [0.05021792]
# Chosen Sample [0.05014744]
# Chosen Sample [0.05013375]
# Chosen Sample [0.05003178]
# Chosen Sample [0.0501011]
# Chosen Sample [0.05041045]
# Chosen Sample [0.05024448]
# Chosen Sample [0.05010404]
# Chosen Sample [0.05006689]
# Chosen Sample [0.05003893]
# Chosen Sample [0.05009997]
# Chosen Sample [0.05024987]
# Chosen Sample [0.05017277]
# Chosen Sample [0.0499749]
# Chosen Sample [0.05013545]
# Chosen Sample [0.05021999]
# Chosen Sample [0.05014475]
# Chosen Sample [0.05032542]
# Chosen Sample [0.05010555]
# Chosen Sample [0.05020017]
# Chosen Sample [0.05024528]
# Chosen Sample [0.05017502]
# Chosen Sample [0.05006473]
# Chosen Sample [0.04999266]
# Chosen Sample [0.05025028]
# Chosen Sample [0.04997837]
# Chosen Sample [0.05025679]
# Chosen Sample [0.05020914]
# Chosen Sample [0.04992337]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                     scale           chosen_sample  \
# 0  0.001248  [2.7984888863033976e-06]  [0.050091103820395326]
# 1  0.001248  [2.7984888863033976e-06]   [0.04994352348447912]
# 2  0.001248  [2.7984888863033976e-06]  [0.050182765498432855]
# 3  0.001248  [2.7984888863033976e-06]   [0.05011825922421949]
# 4  0.001248  [2.7984888863033976e-06]   [0.05022861626286812]
#
#                chosen_noise                release
# 0  [0.00019151147429915532]  [0.05028261529469448]
# 1    [0.003780693960025043]  [0.05372421744450416]
# 2  [-0.0025108979600565753]  [0.04767186753837628]
# 3   [0.0002050602508476661]  [0.05032331947506716]
# 4    [0.000626789855098385]   [0.0508554061179665]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi     scale chosen_sample chosen_noise   release
# query            avg_disc      avg_disc     avg_disc  avg_disc
# 0      0.001248  0.000003      0.050091     0.000192  0.050283
# 1      0.001248  0.000003      0.049944     0.003781  0.053724
# 2      0.001248  0.000003      0.050183    -0.002511  0.047672
# 3      0.001248  0.000003      0.050118     0.000205  0.050323
# 4      0.001248  0.000003      0.050229     0.000627  0.050855

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step              scale chosen_sample  chosen_noise   release
# query          avg_disc      avg_disc      avg_disc  avg_disc
# mi
# 0.001248   2.798489e-06      0.050140 -3.949555e-05  0.050101
# 0.015625   2.235780e-07      0.050146  2.171030e-05  0.050167
# 0.031250   1.117890e-07      0.050142 -1.424358e-05  0.050128
# 0.062500   5.589449e-08      0.050141  6.706987e-07  0.050142
# 0.250000   1.397362e-08      0.050148 -3.901462e-06  0.050144
# 1.000000   3.493406e-09      0.050146 -3.372387e-06  0.050143
# 2.000000   1.746703e-09      0.050149  2.057637e-06  0.050151
# 4.000000   8.733515e-10      0.050148  1.912063e-06  0.050150
# 16.000000  2.183379e-10      0.050142  4.961377e-08  0.050142

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['avg_disc'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi          0.001248
# avg_disc    0.050283
# Name: 0, dtype: float64
# mi          0.001248
# avg_disc    0.053724
# Name: 1, dtype: float64
# mi          0.001248
# avg_disc    0.047672
# Name: 2, dtype: float64
# mi          0.001248
# avg_disc    0.050323
# Name: 3, dtype: float64
# mi          0.001248
# avg_disc    0.050855
# Name: 4, dtype: float64
# mi          0.001248
# avg_disc    0.050395
# Name: 5, dtype: float64
# mi          0.001248
# avg_disc    0.049721
# Name: 6, dtype: float64
# mi          0.001248
# avg_disc    0.051235
# Name: 7, dtype: float64
# mi          0.001248
# avg_disc    0.053166
# Name: 8, dtype: float64
# mi          0.001248
# avg_disc    0.048485
# Name: 9, dtype: float64
# mi          0.001248
# avg_disc    0.049570
# Name: 10, dtype: float64
# mi          0.001248
# avg_disc    0.047847
# Name: 11, dtype: float64
# mi          0.001248
# avg_disc    0.049332
# Name: 12, dtype: float64
# mi          0.001248
# avg_disc    0.050795
# Name: 13, dtype: float64
# mi          0.001248
# avg_disc    0.049700
# Name: 14, dtype: float64
# mi          0.001248
# avg_disc    0.050806
# Name: 15, dtype: float64
# mi          0.001248
# avg_disc    0.053283
# Name: 16, dtype: float64
# mi          0.001248
# avg_disc    0.050184
# Name: 17, dtype: float64
# mi          0.001248
# avg_disc    0.050446
# Name: 18, dtype: float64
# mi          0.001248
# avg_disc    0.050201
# Name: 19, dtype: float64
# mi          0.001248
# avg_disc    0.052187
# Name: 20, dtype: float64
# mi          0.001248
# avg_disc    0.048407
# Name: 21, dtype: float64
# mi          0.001248
# avg_disc    0.045238
# Name: 22, dtype: float64
# mi          0.001248
# avg_disc    0.051693
# Name: 23, dtype: float64
# mi          0.001248
# avg_disc    0.049679
# Name: 24, dtype: float64
# mi          0.001248
# avg_disc    0.049946
# Name: 25, dtype: float64
# mi          0.001248
# avg_disc    0.050512
# Name: 26, dtype: float64
# mi          0.001248
# avg_disc    0.047656
# Name: 27, dtype: float64
# mi          0.001248
# avg_disc    0.052131
# Name: 28, dtype: float64
# mi          0.001248
# avg_disc    0.049867
# Name: 29, dtype: float64
# mi          0.001248
# avg_disc    0.047579
# Name: 30, dtype: float64
# mi          0.001248
# avg_disc    0.048937
# Name: 31, dtype: float64
# mi          0.001248
# avg_disc    0.046895
# Name: 32, dtype: float64
# mi          0.001248
# avg_disc    0.047028
# Name: 33, dtype: float64
# mi          0.001248
# avg_disc    0.047921
# Name: 34, dtype: float64
# mi          0.001248
# avg_disc    0.048846
# Name: 35, dtype: float64
# mi          0.001248
# avg_disc    0.049297
# Name: 36, dtype: float64
# mi          0.001248
# avg_disc    0.049212
# Name: 37, dtype: float64
# mi          0.001248
# avg_disc    0.049191
# Name: 38, dtype: float64
# mi          0.001248
# avg_disc    0.049831
# Name: 39, dtype: float64
# mi          0.001248
# avg_disc    0.050960
# Name: 40, dtype: float64
# mi          0.001248
# avg_disc    0.053234
# Name: 41, dtype: float64
# mi          0.001248
# avg_disc    0.051058
# Name: 42, dtype: float64
# mi          0.001248
# avg_disc    0.048392
# Name: 43, dtype: float64
# mi          0.001248
# avg_disc    0.051517
# Name: 44, dtype: float64
# mi          0.001248
# avg_disc    0.052238
# Name: 45, dtype: float64
# mi          0.001248
# avg_disc    0.051375
# Name: 46, dtype: float64
# mi          0.001248
# avg_disc    0.051511
# Name: 47, dtype: float64
# mi          0.001248
# avg_disc    0.049530
# Name: 48, dtype: float64
# mi          0.001248
# avg_disc    0.049748
# Name: 49, dtype: float64
# mi          0.001248
# avg_disc    0.047753
# Name: 50, dtype: float64
# mi          0.001248
# avg_disc    0.049260
# Name: 51, dtype: float64
# mi          0.001248
# avg_disc    0.051924
# Name: 52, dtype: float64
# mi          0.001248
# avg_disc    0.049472
# Name: 53, dtype: float64
# mi          0.001248
# avg_disc    0.049814
# Name: 54, dtype: float64
# mi          0.001248
# avg_disc    0.047892
# Name: 55, dtype: float64
# mi          0.001248
# avg_disc    0.050509
# Name: 56, dtype: float64
# mi          0.001248
# avg_disc    0.053062
# Name: 57, dtype: float64
# mi          0.001248
# avg_disc    0.047964
# Name: 58, dtype: float64
# mi          0.001248
# avg_disc    0.050735
# Name: 59, dtype: float64
# mi          0.001248
# avg_disc    0.049832
# Name: 60, dtype: float64
# mi          0.001248
# avg_disc    0.050772
# Name: 61, dtype: float64
# mi          0.001248
# avg_disc    0.047435
# Name: 62, dtype: float64
# mi          0.001248
# avg_disc    0.048796
# Name: 63, dtype: float64
# mi          0.001248
# avg_disc    0.050875
# Name: 64, dtype: float64
# mi          0.001248
# avg_disc    0.051744
# Name: 65, dtype: float64
# mi          0.001248
# avg_disc    0.049397
# Name: 66, dtype: float64
# mi          0.001248
# avg_disc    0.052170
# Name: 67, dtype: float64
# mi          0.001248
# avg_disc    0.051270
# Name: 68, dtype: float64
# mi          0.001248
# avg_disc    0.049153
# Name: 69, dtype: float64
# mi          0.001248
# avg_disc    0.051254
# Name: 70, dtype: float64
# mi          0.001248
# avg_disc    0.051560
# Name: 71, dtype: float64
# mi          0.001248
# avg_disc    0.050286
# Name: 72, dtype: float64
# mi          0.001248
# avg_disc    0.050069
# Name: 73, dtype: float64
# mi          0.001248
# avg_disc    0.049342
# Name: 74, dtype: float64
# mi          0.001248
# avg_disc    0.048363
# Name: 75, dtype: float64
# mi          0.001248
# avg_disc    0.053048
# Name: 76, dtype: float64
# mi          0.001248
# avg_disc    0.045275
# Name: 77, dtype: float64
# mi          0.001248
# avg_disc    0.048184
# Name: 78, dtype: float64
# mi          0.001248
# avg_disc    0.048666
# Name: 79, dtype: float64
# mi          0.001248
# avg_disc    0.052199
# Name: 80, dtype: float64
# mi          0.001248
# avg_disc    0.052154
# Name: 81, dtype: float64
# mi          0.001248
# avg_disc    0.051757
# Name: 82, dtype: float64
# mi          0.001248
# avg_disc    0.052625
# Name: 83, dtype: float64
# mi          0.001248
# avg_disc    0.049924
# Name: 84, dtype: float64
# mi          0.001248
# avg_disc    0.052822
# Name: 85, dtype: float64
# mi          0.001248
# avg_disc    0.052676
# Name: 86, dtype: float64
# mi          0.001248
# avg_disc    0.050464
# Name: 87, dtype: float64
# mi          0.001248
# avg_disc    0.048687
# Name: 88, dtype: float64
# mi          0.001248
# avg_disc    0.052492
# Name: 89, dtype: float64
# mi          0.001248
# avg_disc    0.050740
# Name: 90, dtype: float64
# mi          0.001248
# avg_disc    0.053780
# Name: 91, dtype: float64
# mi          0.001248
# avg_disc    0.052050
# Name: 92, dtype: float64
# mi          0.001248
# avg_disc    0.048251
# Name: 93, dtype: float64
# mi          0.001248
# avg_disc    0.052508
# Name: 94, dtype: float64
# mi          0.001248
# avg_disc    0.046054
# Name: 95, dtype: float64
# mi          0.001248
# avg_disc    0.049668
# Name: 96, dtype: float64
# mi          0.001248
# avg_disc    0.051739
# Name: 97, dtype: float64
# mi          0.001248
# avg_disc    0.051059
# Name: 98, dtype: float64
# mi          0.001248
# avg_disc    0.050408
# Name: 99, dtype: float64
# mi          0.001248
# avg_disc    0.050875
# Name: 100, dtype: float64
# mi          0.001248
# avg_disc    0.049478
# Name: 101, dtype: float64
# mi          0.001248
# avg_disc    0.049650
# Name: 102, dtype: float64
# mi          0.001248
# avg_disc    0.052675
# Name: 103, dtype: float64
# mi          0.001248
# avg_disc    0.051575
# Name: 104, dtype: float64
# mi          0.001248
# avg_disc    0.054974
# Name: 105, dtype: float64
# mi          0.001248
# avg_disc    0.046503
# Name: 106, dtype: float64
# mi          0.001248
# avg_disc    0.050035
# Name: 107, dtype: float64
# mi          0.001248
# avg_disc    0.047730
# Name: 108, dtype: float64
# mi          0.001248
# avg_disc    0.046785
# Name: 109, dtype: float64
# mi          0.001248
# avg_disc    0.051430
# Name: 110, dtype: float64
# mi          0.001248
# avg_disc    0.050050
# Name: 111, dtype: float64
# mi          0.001248
# avg_disc    0.048175
# Name: 112, dtype: float64
# mi          0.001248
# avg_disc    0.049041
# Name: 113, dtype: float64
# mi          0.001248
# avg_disc    0.052936
# Name: 114, dtype: float64
# mi          0.001248
# avg_disc    0.047495
# Name: 115, dtype: float64
# mi          0.001248
# avg_disc    0.051733
# Name: 116, dtype: float64
# mi          0.001248
# avg_disc    0.050524
# Name: 117, dtype: float64
# mi          0.001248
# avg_disc    0.050673
# Name: 118, dtype: float64
# mi          0.001248
# avg_disc    0.052285
# Name: 119, dtype: float64
# mi          0.001248
# avg_disc    0.052241
# Name: 120, dtype: float64
# mi          0.001248
# avg_disc    0.049688
# Name: 121, dtype: float64
# mi          0.001248
# avg_disc    0.047694
# Name: 122, dtype: float64
# mi          0.001248
# avg_disc    0.050298
# Name: 123, dtype: float64
# mi          0.001248
# avg_disc    0.050991
# Name: 124, dtype: float64
# mi          0.001248
# avg_disc    0.052379
# Name: 125, dtype: float64
# mi          0.001248
# avg_disc    0.047549
# Name: 126, dtype: float64
# mi          0.001248
# avg_disc    0.052253
# Name: 127, dtype: float64
# mi          0.001248
# avg_disc    0.048633
# Name: 128, dtype: float64
# mi          0.001248
# avg_disc    0.051056
# Name: 129, dtype: float64
# mi          0.001248
# avg_disc    0.050430
# Name: 130, dtype: float64
# mi          0.001248
# avg_disc    0.051203
# Name: 131, dtype: float64
# mi          0.001248
# avg_disc    0.046515
# Name: 132, dtype: float64
# mi          0.001248
# avg_disc    0.051170
# Name: 133, dtype: float64
# mi          0.001248
# avg_disc    0.050010
# Name: 134, dtype: float64
# mi          0.001248
# avg_disc    0.049349
# Name: 135, dtype: float64
# mi          0.001248
# avg_disc    0.049195
# Name: 136, dtype: float64
# mi          0.001248
# avg_disc    0.050114
# Name: 137, dtype: float64
# mi          0.001248
# avg_disc    0.047244
# Name: 138, dtype: float64
# mi          0.001248
# avg_disc    0.047991
# Name: 139, dtype: float64
# mi          0.001248
# avg_disc    0.049353
# Name: 140, dtype: float64
# mi          0.001248
# avg_disc    0.049540
# Name: 141, dtype: float64
# mi          0.001248
# avg_disc    0.049753
# Name: 142, dtype: float64
# mi          0.001248
# avg_disc    0.047299
# Name: 143, dtype: float64
# mi          0.001248
# avg_disc    0.050496
# Name: 144, dtype: float64
# mi          0.001248
# avg_disc    0.052277
# Name: 145, dtype: float64
# mi          0.001248
# avg_disc    0.051391
# Name: 146, dtype: float64
# mi          0.001248
# avg_disc    0.048892
# Name: 147, dtype: float64
# mi          0.001248
# avg_disc    0.048200
# Name: 148, dtype: float64
# mi          0.001248
# avg_disc    0.049439
# Name: 149, dtype: float64
# mi          0.001248
# avg_disc    0.051856
# Name: 150, dtype: float64
# mi          0.001248
# avg_disc    0.050508
# Name: 151, dtype: float64
# mi          0.001248
# avg_disc    0.050536
# Name: 152, dtype: float64
# mi          0.001248
# avg_disc    0.049671
# Name: 153, dtype: float64
# mi          0.001248
# avg_disc    0.049911
# Name: 154, dtype: float64
# mi          0.001248
# avg_disc    0.052592
# Name: 155, dtype: float64
# mi          0.001248
# avg_disc    0.049454
# Name: 156, dtype: float64
# mi          0.001248
# avg_disc    0.048927
# Name: 157, dtype: float64
# mi          0.001248
# avg_disc    0.051772
# Name: 158, dtype: float64
# mi          0.001248
# avg_disc    0.049823
# Name: 159, dtype: float64
# mi          0.001248
# avg_disc    0.047738
# Name: 160, dtype: float64
# mi          0.001248
# avg_disc    0.048288
# Name: 161, dtype: float64
# mi          0.001248
# avg_disc    0.050211
# Name: 162, dtype: float64
# mi          0.001248
# avg_disc    0.047207
# Name: 163, dtype: float64
# mi          0.001248
# avg_disc    0.049748
# Name: 164, dtype: float64
# mi          0.001248
# avg_disc    0.052945
# Name: 165, dtype: float64
# mi          0.001248
# avg_disc    0.048624
# Name: 166, dtype: float64
# mi          0.001248
# avg_disc    0.055877
# Name: 167, dtype: float64
# mi          0.001248
# avg_disc    0.050507
# Name: 168, dtype: float64
# mi          0.001248
# avg_disc    0.048826
# Name: 169, dtype: float64
# mi          0.001248
# avg_disc    0.049211
# Name: 170, dtype: float64
# mi          0.001248
# avg_disc    0.050844
# Name: 171, dtype: float64
# mi          0.001248
# avg_disc    0.048698
# Name: 172, dtype: float64
# mi          0.001248
# avg_disc    0.049362
# Name: 173, dtype: float64
# mi          0.001248
# avg_disc    0.049850
# Name: 174, dtype: float64
# mi          0.001248
# avg_disc    0.050085
# Name: 175, dtype: float64
# mi          0.001248
# avg_disc    0.049624
# Name: 176, dtype: float64
# mi          0.001248
# avg_disc    0.052217
# Name: 177, dtype: float64
# mi          0.001248
# avg_disc    0.048797
# Name: 178, dtype: float64
# mi          0.001248
# avg_disc    0.050395
# Name: 179, dtype: float64
# mi          0.001248
# avg_disc    0.047779
# Name: 180, dtype: float64
# mi          0.001248
# avg_disc    0.051072
# Name: 181, dtype: float64
# mi          0.001248
# avg_disc    0.049698
# Name: 182, dtype: float64
# mi          0.001248
# avg_disc    0.053249
# Name: 183, dtype: float64
# mi          0.001248
# avg_disc    0.053832
# Name: 184, dtype: float64
# mi          0.001248
# avg_disc    0.050847
# Name: 185, dtype: float64
# mi          0.001248
# avg_disc    0.052593
# Name: 186, dtype: float64
# mi          0.001248
# avg_disc    0.047424
# Name: 187, dtype: float64
# mi          0.001248
# avg_disc    0.052128
# Name: 188, dtype: float64
# mi          0.001248
# avg_disc    0.054503
# Name: 189, dtype: float64
# mi          0.001248
# avg_disc    0.048158
# Name: 190, dtype: float64
# mi          0.001248
# avg_disc    0.049495
# Name: 191, dtype: float64
# mi          0.001248
# avg_disc    0.049820
# Name: 192, dtype: float64
# mi          0.001248
# avg_disc    0.046548
# Name: 193, dtype: float64
# mi          0.001248
# avg_disc    0.052012
# Name: 194, dtype: float64
# mi          0.001248
# avg_disc    0.049705
# Name: 195, dtype: float64
# mi          0.001248
# avg_disc    0.050351
# Name: 196, dtype: float64
# mi          0.001248
# avg_disc    0.049507
# Name: 197, dtype: float64
# mi          0.001248
# avg_disc    0.052026
# Name: 198, dtype: float64
# mi          0.001248
# avg_disc    0.047940
# Name: 199, dtype: float64
# mi          0.001248
# avg_disc    0.051846
# Name: 200, dtype: float64
# mi          0.001248
# avg_disc    0.050703
# Name: 201, dtype: float64
# mi          0.001248
# avg_disc    0.050200
# Name: 202, dtype: float64
# mi          0.001248
# avg_disc    0.051772
# Name: 203, dtype: float64
# mi          0.001248
# avg_disc    0.050058
# Name: 204, dtype: float64
# mi          0.001248
# avg_disc    0.052153
# Name: 205, dtype: float64
# mi          0.001248
# avg_disc    0.050011
# Name: 206, dtype: float64
# mi          0.001248
# avg_disc    0.050744
# Name: 207, dtype: float64
# mi          0.001248
# avg_disc    0.051304
# Name: 208, dtype: float64
# mi          0.001248
# avg_disc    0.048692
# Name: 209, dtype: float64
# mi          0.001248
# avg_disc    0.052781
# Name: 210, dtype: float64
# mi          0.001248
# avg_disc    0.049834
# Name: 211, dtype: float64
# mi          0.001248
# avg_disc    0.048928
# Name: 212, dtype: float64
# mi          0.001248
# avg_disc    0.052310
# Name: 213, dtype: float64
# mi          0.001248
# avg_disc    0.047698
# Name: 214, dtype: float64
# mi          0.001248
# avg_disc    0.050269
# Name: 215, dtype: float64
# mi          0.001248
# avg_disc    0.049547
# Name: 216, dtype: float64
# mi          0.001248
# avg_disc    0.050570
# Name: 217, dtype: float64
# mi          0.001248
# avg_disc    0.048071
# Name: 218, dtype: float64
# mi          0.001248
# avg_disc    0.047784
# Name: 219, dtype: float64
# mi          0.001248
# avg_disc    0.051598
# Name: 220, dtype: float64
# mi          0.001248
# avg_disc    0.049000
# Name: 221, dtype: float64
# mi          0.001248
# avg_disc    0.050740
# Name: 222, dtype: float64
# mi          0.001248
# avg_disc    0.048126
# Name: 223, dtype: float64
# mi          0.001248
# avg_disc    0.048244
# Name: 224, dtype: float64
# mi          0.001248
# avg_disc    0.049797
# Name: 225, dtype: float64
# mi          0.001248
# avg_disc    0.050746
# Name: 226, dtype: float64
# mi          0.001248
# avg_disc    0.049956
# Name: 227, dtype: float64
# mi          0.001248
# avg_disc    0.049747
# Name: 228, dtype: float64
# mi          0.001248
# avg_disc    0.050400
# Name: 229, dtype: float64
# mi          0.001248
# avg_disc    0.049395
# Name: 230, dtype: float64
# mi          0.001248
# avg_disc    0.049694
# Name: 231, dtype: float64
# mi          0.001248
# avg_disc    0.049746
# Name: 232, dtype: float64
# mi          0.001248
# avg_disc    0.052560
# Name: 233, dtype: float64
# mi          0.001248
# avg_disc    0.049424
# Name: 234, dtype: float64
# mi          0.001248
# avg_disc    0.054195
# Name: 235, dtype: float64
# mi          0.001248
# avg_disc    0.046430
# Name: 236, dtype: float64
# mi          0.001248
# avg_disc    0.049408
# Name: 237, dtype: float64
# mi          0.001248
# avg_disc    0.048874
# Name: 238, dtype: float64
# mi          0.001248
# avg_disc    0.049426
# Name: 239, dtype: float64
# mi          0.001248
# avg_disc    0.049602
# Name: 240, dtype: float64
# mi          0.001248
# avg_disc    0.050463
# Name: 241, dtype: float64
# mi          0.001248
# avg_disc    0.049849
# Name: 242, dtype: float64
# mi          0.001248
# avg_disc    0.047363
# Name: 243, dtype: float64
# mi          0.001248
# avg_disc    0.050630
# Name: 244, dtype: float64
# mi          0.001248
# avg_disc    0.051624
# Name: 245, dtype: float64
# mi          0.001248
# avg_disc    0.049535
# Name: 246, dtype: float64
# mi          0.001248
# avg_disc    0.051748
# Name: 247, dtype: float64
# mi          0.001248
# avg_disc    0.052104
# Name: 248, dtype: float64
# mi          0.001248
# avg_disc    0.051630
# Name: 249, dtype: float64
# mi          0.001248
# avg_disc    0.050272
# Name: 250, dtype: float64
# mi          0.001248
# avg_disc    0.048539
# Name: 251, dtype: float64
# mi          0.001248
# avg_disc    0.049589
# Name: 252, dtype: float64
# mi          0.001248
# avg_disc    0.048259
# Name: 253, dtype: float64
# mi          0.001248
# avg_disc    0.048731
# Name: 254, dtype: float64
# mi          0.001248
# avg_disc    0.047027
# Name: 255, dtype: float64
# mi          0.001248
# avg_disc    0.049628
# Name: 256, dtype: float64
# mi          0.001248
# avg_disc    0.052084
# Name: 257, dtype: float64
# mi          0.001248
# avg_disc    0.050829
# Name: 258, dtype: float64
# mi          0.001248
# avg_disc    0.049526
# Name: 259, dtype: float64
# mi          0.001248
# avg_disc    0.051611
# Name: 260, dtype: float64
# mi          0.001248
# avg_disc    0.050714
# Name: 261, dtype: float64
# mi          0.001248
# avg_disc    0.053655
# Name: 262, dtype: float64
# mi          0.001248
# avg_disc    0.047525
# Name: 263, dtype: float64
# mi          0.001248
# avg_disc    0.051718
# Name: 264, dtype: float64
# mi          0.001248
# avg_disc    0.048050
# Name: 265, dtype: float64
# mi          0.001248
# avg_disc    0.047790
# Name: 266, dtype: float64
# mi          0.001248
# avg_disc    0.048972
# Name: 267, dtype: float64
# mi          0.001248
# avg_disc    0.050258
# Name: 268, dtype: float64
# mi          0.001248
# avg_disc    0.050860
# Name: 269, dtype: float64
# mi          0.001248
# avg_disc    0.052343
# Name: 270, dtype: float64
# mi          0.001248
# avg_disc    0.048976
# Name: 271, dtype: float64
# mi          0.001248
# avg_disc    0.051172
# Name: 272, dtype: float64
# mi          0.001248
# avg_disc    0.048518
# Name: 273, dtype: float64
# mi          0.001248
# avg_disc    0.052107
# Name: 274, dtype: float64
# mi          0.001248
# avg_disc    0.050043
# Name: 275, dtype: float64
# mi          0.001248
# avg_disc    0.050152
# Name: 276, dtype: float64
# mi          0.001248
# avg_disc    0.050905
# Name: 277, dtype: float64
# mi          0.001248
# avg_disc    0.047750
# Name: 278, dtype: float64
# mi          0.001248
# avg_disc    0.050162
# Name: 279, dtype: float64
# mi          0.001248
# avg_disc    0.052882
# Name: 280, dtype: float64
# mi          0.001248
# avg_disc    0.051367
# Name: 281, dtype: float64
# mi          0.001248
# avg_disc    0.050198
# Name: 282, dtype: float64
# mi          0.001248
# avg_disc    0.048229
# Name: 283, dtype: float64
# mi          0.001248
# avg_disc    0.050675
# Name: 284, dtype: float64
# mi          0.001248
# avg_disc    0.050254
# Name: 285, dtype: float64
# mi          0.001248
# avg_disc    0.049662
# Name: 286, dtype: float64
# mi          0.001248
# avg_disc    0.049763
# Name: 287, dtype: float64
# mi          0.001248
# avg_disc    0.049012
# Name: 288, dtype: float64
# mi          0.001248
# avg_disc    0.049628
# Name: 289, dtype: float64
# mi          0.001248
# avg_disc    0.052423
# Name: 290, dtype: float64
# mi          0.001248
# avg_disc    0.049983
# Name: 291, dtype: float64
# mi          0.001248
# avg_disc    0.050445
# Name: 292, dtype: float64
# mi          0.001248
# avg_disc    0.050124
# Name: 293, dtype: float64
# mi          0.001248
# avg_disc    0.052209
# Name: 294, dtype: float64
# mi          0.001248
# avg_disc    0.048952
# Name: 295, dtype: float64
# mi          0.001248
# avg_disc    0.050350
# Name: 296, dtype: float64
# mi          0.001248
# avg_disc    0.050615
# Name: 297, dtype: float64
# mi          0.001248
# avg_disc    0.048837
# Name: 298, dtype: float64
# mi          0.001248
# avg_disc    0.048252
# Name: 299, dtype: float64
# mi          0.001248
# avg_disc    0.052706
# Name: 300, dtype: float64
# mi          0.001248
# avg_disc    0.049214
# Name: 301, dtype: float64
# mi          0.001248
# avg_disc    0.048198
# Name: 302, dtype: float64
# mi          0.001248
# avg_disc    0.048872
# Name: 303, dtype: float64
# mi          0.001248
# avg_disc    0.050189
# Name: 304, dtype: float64
# mi          0.001248
# avg_disc    0.053962
# Name: 305, dtype: float64
# mi          0.001248
# avg_disc    0.051531
# Name: 306, dtype: float64
# mi          0.001248
# avg_disc    0.052711
# Name: 307, dtype: float64
# mi          0.001248
# avg_disc    0.051131
# Name: 308, dtype: float64
# mi          0.001248
# avg_disc    0.049244
# Name: 309, dtype: float64
# mi          0.001248
# avg_disc    0.050590
# Name: 310, dtype: float64
# mi          0.001248
# avg_disc    0.051705
# Name: 311, dtype: float64
# mi          0.001248
# avg_disc    0.048125
# Name: 312, dtype: float64
# mi          0.001248
# avg_disc    0.050635
# Name: 313, dtype: float64
# mi          0.001248
# avg_disc    0.050220
# Name: 314, dtype: float64
# mi          0.001248
# avg_disc    0.048151
# Name: 315, dtype: float64
# mi          0.001248
# avg_disc    0.050678
# Name: 316, dtype: float64
# mi          0.001248
# avg_disc    0.051207
# Name: 317, dtype: float64
# mi          0.001248
# avg_disc    0.050621
# Name: 318, dtype: float64
# mi          0.001248
# avg_disc    0.047445
# Name: 319, dtype: float64
# mi          0.001248
# avg_disc    0.047630
# Name: 320, dtype: float64
# mi          0.001248
# avg_disc    0.049726
# Name: 321, dtype: float64
# mi          0.001248
# avg_disc    0.052273
# Name: 322, dtype: float64
# mi          0.001248
# avg_disc    0.050844
# Name: 323, dtype: float64
# mi          0.001248
# avg_disc    0.050766
# Name: 324, dtype: float64
# mi          0.001248
# avg_disc    0.048685
# Name: 325, dtype: float64
# mi          0.001248
# avg_disc    0.049682
# Name: 326, dtype: float64
# mi          0.001248
# avg_disc    0.050716
# Name: 327, dtype: float64
# mi          0.001248
# avg_disc    0.048143
# Name: 328, dtype: float64
# mi          0.001248
# avg_disc    0.050883
# Name: 329, dtype: float64
# mi          0.001248
# avg_disc    0.051126
# Name: 330, dtype: float64
# mi          0.001248
# avg_disc    0.049910
# Name: 331, dtype: float64
# mi          0.001248
# avg_disc    0.050637
# Name: 332, dtype: float64
# mi          0.001248
# avg_disc    0.049977
# Name: 333, dtype: float64
# mi          0.001248
# avg_disc    0.047035
# Name: 334, dtype: float64
# mi          0.001248
# avg_disc    0.049383
# Name: 335, dtype: float64
# mi          0.001248
# avg_disc    0.049587
# Name: 336, dtype: float64
# mi          0.001248
# avg_disc    0.048142
# Name: 337, dtype: float64
# mi          0.001248
# avg_disc    0.047549
# Name: 338, dtype: float64
# mi          0.001248
# avg_disc    0.051424
# Name: 339, dtype: float64
# mi          0.001248
# avg_disc    0.050717
# Name: 340, dtype: float64
# mi          0.001248
# avg_disc    0.051008
# Name: 341, dtype: float64
# mi          0.001248
# avg_disc    0.046877
# Name: 342, dtype: float64
# mi          0.001248
# avg_disc    0.050764
# Name: 343, dtype: float64
# mi          0.001248
# avg_disc    0.051007
# Name: 344, dtype: float64
# mi          0.001248
# avg_disc    0.050518
# Name: 345, dtype: float64
# mi          0.001248
# avg_disc    0.049997
# Name: 346, dtype: float64
# mi          0.001248
# avg_disc    0.050596
# Name: 347, dtype: float64
# mi          0.001248
# avg_disc    0.052661
# Name: 348, dtype: float64
# mi          0.001248
# avg_disc    0.051251
# Name: 349, dtype: float64
# mi          0.001248
# avg_disc    0.051929
# Name: 350, dtype: float64
# mi          0.001248
# avg_disc    0.051052
# Name: 351, dtype: float64
# mi          0.001248
# avg_disc    0.047903
# Name: 352, dtype: float64
# mi          0.001248
# avg_disc    0.049942
# Name: 353, dtype: float64
# mi          0.001248
# avg_disc    0.052438
# Name: 354, dtype: float64
# mi          0.001248
# avg_disc    0.050569
# Name: 355, dtype: float64
# mi          0.001248
# avg_disc    0.049406
# Name: 356, dtype: float64
# mi          0.001248
# avg_disc    0.052233
# Name: 357, dtype: float64
# mi          0.001248
# avg_disc    0.050256
# Name: 358, dtype: float64
# mi          0.001248
# avg_disc    0.050011
# Name: 359, dtype: float64
# mi          0.001248
# avg_disc    0.047918
# Name: 360, dtype: float64
# mi          0.001248
# avg_disc    0.051551
# Name: 361, dtype: float64
# mi          0.001248
# avg_disc    0.048379
# Name: 362, dtype: float64
# mi          0.001248
# avg_disc    0.049841
# Name: 363, dtype: float64
# mi          0.001248
# avg_disc    0.054279
# Name: 364, dtype: float64
# mi          0.001248
# avg_disc    0.049986
# Name: 365, dtype: float64
# mi          0.001248
# avg_disc    0.047625
# Name: 366, dtype: float64
# mi          0.001248
# avg_disc    0.046453
# Name: 367, dtype: float64
# mi          0.001248
# avg_disc    0.052601
# Name: 368, dtype: float64
# mi          0.001248
# avg_disc    0.051918
# Name: 369, dtype: float64
# mi          0.001248
# avg_disc    0.051980
# Name: 370, dtype: float64
# mi          0.001248
# avg_disc    0.048938
# Name: 371, dtype: float64
# mi          0.001248
# avg_disc    0.049594
# Name: 372, dtype: float64
# mi          0.001248
# avg_disc    0.051995
# Name: 373, dtype: float64
# mi          0.001248
# avg_disc    0.047259
# Name: 374, dtype: float64
# mi          0.001248
# avg_disc    0.052632
# Name: 375, dtype: float64
# mi          0.001248
# avg_disc    0.051247
# Name: 376, dtype: float64
# mi          0.001248
# avg_disc    0.046782
# Name: 377, dtype: float64
# mi          0.001248
# avg_disc    0.048709
# Name: 378, dtype: float64
# mi          0.001248
# avg_disc    0.048905
# Name: 379, dtype: float64
# mi          0.001248
# avg_disc    0.050282
# Name: 380, dtype: float64
# mi          0.001248
# avg_disc    0.051457
# Name: 381, dtype: float64
# mi          0.001248
# avg_disc    0.050844
# Name: 382, dtype: float64
# mi          0.001248
# avg_disc    0.049301
# Name: 383, dtype: float64
# mi          0.001248
# avg_disc    0.051291
# Name: 384, dtype: float64
# mi          0.001248
# avg_disc    0.048299
# Name: 385, dtype: float64
# mi          0.001248
# avg_disc    0.050517
# Name: 386, dtype: float64
# mi          0.001248
# avg_disc    0.048745
# Name: 387, dtype: float64
# mi          0.001248
# avg_disc    0.052087
# Name: 388, dtype: float64
# mi          0.001248
# avg_disc    0.052057
# Name: 389, dtype: float64
# mi          0.001248
# avg_disc    0.050878
# Name: 390, dtype: float64
# mi          0.001248
# avg_disc    0.051536
# Name: 391, dtype: float64
# mi          0.001248
# avg_disc    0.049022
# Name: 392, dtype: float64
# mi          0.001248
# avg_disc    0.051130
# Name: 393, dtype: float64
# mi          0.001248
# avg_disc    0.050340
# Name: 394, dtype: float64
# mi          0.001248
# avg_disc    0.047966
# Name: 395, dtype: float64
# mi          0.001248
# avg_disc    0.051841
# Name: 396, dtype: float64
# mi          0.001248
# avg_disc    0.049563
# Name: 397, dtype: float64
# mi          0.001248
# avg_disc    0.047261
# Name: 398, dtype: float64
# mi          0.001248
# avg_disc    0.049822
# Name: 399, dtype: float64
# mi          0.001248
# avg_disc    0.049980
# Name: 400, dtype: float64
# mi          0.001248
# avg_disc    0.050844
# Name: 401, dtype: float64
# mi          0.001248
# avg_disc    0.051105
# Name: 402, dtype: float64
# mi          0.001248
# avg_disc    0.050942
# Name: 403, dtype: float64
# mi          0.001248
# avg_disc    0.051693
# Name: 404, dtype: float64
# mi          0.001248
# avg_disc    0.050166
# Name: 405, dtype: float64
# mi          0.001248
# avg_disc    0.049540
# Name: 406, dtype: float64
# mi          0.001248
# avg_disc    0.048925
# Name: 407, dtype: float64
# mi          0.001248
# avg_disc    0.049401
# Name: 408, dtype: float64
# mi          0.001248
# avg_disc    0.047126
# Name: 409, dtype: float64
# mi          0.001248
# avg_disc    0.047771
# Name: 410, dtype: float64
# mi          0.001248
# avg_disc    0.051517
# Name: 411, dtype: float64
# mi          0.001248
# avg_disc    0.050467
# Name: 412, dtype: float64
# mi          0.001248
# avg_disc    0.047071
# Name: 413, dtype: float64
# mi          0.001248
# avg_disc    0.048891
# Name: 414, dtype: float64
# mi          0.001248
# avg_disc    0.046999
# Name: 415, dtype: float64
# mi          0.001248
# avg_disc    0.050034
# Name: 416, dtype: float64
# mi          0.001248
# avg_disc    0.051914
# Name: 417, dtype: float64
# mi          0.001248
# avg_disc    0.050976
# Name: 418, dtype: float64
# mi          0.001248
# avg_disc    0.052382
# Name: 419, dtype: float64
# mi          0.001248
# avg_disc    0.050858
# Name: 420, dtype: float64
# mi          0.001248
# avg_disc    0.048231
# Name: 421, dtype: float64
# mi          0.001248
# avg_disc    0.050641
# Name: 422, dtype: float64
# mi          0.001248
# avg_disc    0.049037
# Name: 423, dtype: float64
# mi          0.001248
# avg_disc    0.048556
# Name: 424, dtype: float64
# mi          0.001248
# avg_disc    0.051031
# Name: 425, dtype: float64
# mi          0.001248
# avg_disc    0.048671
# Name: 426, dtype: float64
# mi          0.001248
# avg_disc    0.049773
# Name: 427, dtype: float64
# mi          0.001248
# avg_disc    0.047945
# Name: 428, dtype: float64
# mi          0.001248
# avg_disc    0.049603
# Name: 429, dtype: float64
# mi          0.001248
# avg_disc    0.052092
# Name: 430, dtype: float64
# mi          0.001248
# avg_disc    0.051778
# Name: 431, dtype: float64
# mi          0.001248
# avg_disc    0.049511
# Name: 432, dtype: float64
# mi          0.001248
# avg_disc    0.051313
# Name: 433, dtype: float64
# mi          0.001248
# avg_disc    0.051762
# Name: 434, dtype: float64
# mi          0.001248
# avg_disc    0.048441
# Name: 435, dtype: float64
# mi          0.001248
# avg_disc    0.049070
# Name: 436, dtype: float64
# mi          0.001248
# avg_disc    0.051940
# Name: 437, dtype: float64
# mi          0.001248
# avg_disc    0.047499
# Name: 438, dtype: float64
# mi          0.001248
# avg_disc    0.049337
# Name: 439, dtype: float64
# mi          0.001248
# avg_disc    0.048866
# Name: 440, dtype: float64
# mi          0.001248
# avg_disc    0.048453
# Name: 441, dtype: float64
# mi          0.001248
# avg_disc    0.051379
# Name: 442, dtype: float64
# mi          0.001248
# avg_disc    0.049296
# Name: 443, dtype: float64
# mi          0.001248
# avg_disc    0.049477
# Name: 444, dtype: float64
# mi          0.001248
# avg_disc    0.050923
# Name: 445, dtype: float64
# mi          0.001248
# avg_disc    0.050554
# Name: 446, dtype: float64
# mi          0.001248
# avg_disc    0.049148
# Name: 447, dtype: float64
# mi          0.001248
# avg_disc    0.048437
# Name: 448, dtype: float64
# mi          0.001248
# avg_disc    0.050149
# Name: 449, dtype: float64
# mi          0.001248
# avg_disc    0.052860
# Name: 450, dtype: float64
# mi          0.001248
# avg_disc    0.052733
# Name: 451, dtype: float64
# mi          0.001248
# avg_disc    0.050499
# Name: 452, dtype: float64
# mi          0.001248
# avg_disc    0.047845
# Name: 453, dtype: float64
# mi          0.001248
# avg_disc    0.052294
# Name: 454, dtype: float64
# mi          0.001248
# avg_disc    0.049241
# Name: 455, dtype: float64
# mi          0.001248
# avg_disc    0.048476
# Name: 456, dtype: float64
# mi          0.001248
# avg_disc    0.047844
# Name: 457, dtype: float64
# mi          0.001248
# avg_disc    0.049556
# Name: 458, dtype: float64
# mi          0.001248
# avg_disc    0.051825
# Name: 459, dtype: float64
# mi          0.001248
# avg_disc    0.049740
# Name: 460, dtype: float64
# mi          0.001248
# avg_disc    0.045979
# Name: 461, dtype: float64
# mi          0.001248
# avg_disc    0.046427
# Name: 462, dtype: float64
# mi          0.001248
# avg_disc    0.053414
# Name: 463, dtype: float64
# mi          0.001248
# avg_disc    0.048625
# Name: 464, dtype: float64
# mi          0.001248
# avg_disc    0.047803
# Name: 465, dtype: float64
# mi          0.001248
# avg_disc    0.051357
# Name: 466, dtype: float64
# mi          0.001248
# avg_disc    0.047579
# Name: 467, dtype: float64
# mi          0.001248
# avg_disc    0.050445
# Name: 468, dtype: float64
# mi          0.001248
# avg_disc    0.045534
# Name: 469, dtype: float64
# mi          0.001248
# avg_disc    0.051382
# Name: 470, dtype: float64
# mi          0.001248
# avg_disc    0.050610
# Name: 471, dtype: float64
# mi          0.001248
# avg_disc    0.049305
# Name: 472, dtype: float64
# mi          0.001248
# avg_disc    0.051652
# Name: 473, dtype: float64
# mi          0.001248
# avg_disc    0.048970
# Name: 474, dtype: float64
# mi          0.001248
# avg_disc    0.049868
# Name: 475, dtype: float64
# mi          0.001248
# avg_disc    0.048937
# Name: 476, dtype: float64
# mi          0.001248
# avg_disc    0.050913
# Name: 477, dtype: float64
# mi          0.001248
# avg_disc    0.050110
# Name: 478, dtype: float64
# mi          0.001248
# avg_disc    0.048101
# Name: 479, dtype: float64
# mi          0.001248
# avg_disc    0.047972
# Name: 480, dtype: float64
# mi          0.001248
# avg_disc    0.049799
# Name: 481, dtype: float64
# mi          0.001248
# avg_disc    0.048860
# Name: 482, dtype: float64
# mi          0.001248
# avg_disc    0.050196
# Name: 483, dtype: float64
# mi          0.001248
# avg_disc    0.050063
# Name: 484, dtype: float64
# mi          0.001248
# avg_disc    0.048373
# Name: 485, dtype: float64
# mi          0.001248
# avg_disc    0.052122
# Name: 486, dtype: float64
# mi          0.001248
# avg_disc    0.051991
# Name: 487, dtype: float64
# mi          0.001248
# avg_disc    0.048033
# Name: 488, dtype: float64
# mi          0.001248
# avg_disc    0.050663
# Name: 489, dtype: float64
# mi          0.001248
# avg_disc    0.048194
# Name: 490, dtype: float64
# mi          0.001248
# avg_disc    0.051144
# Name: 491, dtype: float64
# mi          0.001248
# avg_disc    0.051940
# Name: 492, dtype: float64
# mi          0.001248
# avg_disc    0.049800
# Name: 493, dtype: float64
# mi          0.001248
# avg_disc    0.050443
# Name: 494, dtype: float64
# mi          0.001248
# avg_disc    0.050016
# Name: 495, dtype: float64
# mi          0.001248
# avg_disc    0.049433
# Name: 496, dtype: float64
# mi          0.001248
# avg_disc    0.051018
# Name: 497, dtype: float64
# mi          0.001248
# avg_disc    0.051567
# Name: 498, dtype: float64
# mi          0.001248
# avg_disc    0.048580
# Name: 499, dtype: float64
# mi          0.001248
# avg_disc    0.049187
# Name: 500, dtype: float64
# mi          0.001248
# avg_disc    0.050979
# Name: 501, dtype: float64
# mi          0.001248
# avg_disc    0.049100
# Name: 502, dtype: float64
# mi          0.001248
# avg_disc    0.052506
# Name: 503, dtype: float64
# mi          0.001248
# avg_disc    0.047014
# Name: 504, dtype: float64
# mi          0.001248
# avg_disc    0.050079
# Name: 505, dtype: float64
# mi          0.001248
# avg_disc    0.048543
# Name: 506, dtype: float64
# mi          0.001248
# avg_disc    0.050717
# Name: 507, dtype: float64
# mi          0.001248
# avg_disc    0.050895
# Name: 508, dtype: float64
# mi          0.001248
# avg_disc    0.047967
# Name: 509, dtype: float64
# mi          0.001248
# avg_disc    0.051989
# Name: 510, dtype: float64
# mi          0.001248
# avg_disc    0.051431
# Name: 511, dtype: float64
# mi          0.001248
# avg_disc    0.049408
# Name: 512, dtype: float64
# mi          0.001248
# avg_disc    0.051540
# Name: 513, dtype: float64
# mi          0.001248
# avg_disc    0.047401
# Name: 514, dtype: float64
# mi          0.001248
# avg_disc    0.048848
# Name: 515, dtype: float64
# mi          0.001248
# avg_disc    0.049295
# Name: 516, dtype: float64
# mi          0.001248
# avg_disc    0.054040
# Name: 517, dtype: float64
# mi          0.001248
# avg_disc    0.048382
# Name: 518, dtype: float64
# mi          0.001248
# avg_disc    0.050059
# Name: 519, dtype: float64
# mi          0.001248
# avg_disc    0.050084
# Name: 520, dtype: float64
# mi          0.001248
# avg_disc    0.050819
# Name: 521, dtype: float64
# mi          0.001248
# avg_disc    0.050648
# Name: 522, dtype: float64
# mi          0.001248
# avg_disc    0.052511
# Name: 523, dtype: float64
# mi          0.001248
# avg_disc    0.049284
# Name: 524, dtype: float64
# mi          0.001248
# avg_disc    0.047975
# Name: 525, dtype: float64
# mi          0.001248
# avg_disc    0.049099
# Name: 526, dtype: float64
# mi          0.001248
# avg_disc    0.054291
# Name: 527, dtype: float64
# mi          0.001248
# avg_disc    0.052583
# Name: 528, dtype: float64
# mi          0.001248
# avg_disc    0.049977
# Name: 529, dtype: float64
# mi          0.001248
# avg_disc    0.050637
# Name: 530, dtype: float64
# mi          0.001248
# avg_disc    0.047530
# Name: 531, dtype: float64
# mi          0.001248
# avg_disc    0.052402
# Name: 532, dtype: float64
# mi          0.001248
# avg_disc    0.050892
# Name: 533, dtype: float64
# mi          0.001248
# avg_disc    0.048692
# Name: 534, dtype: float64
# mi          0.001248
# avg_disc    0.051035
# Name: 535, dtype: float64
# mi          0.001248
# avg_disc    0.051184
# Name: 536, dtype: float64
# mi          0.001248
# avg_disc    0.046566
# Name: 537, dtype: float64
# mi          0.001248
# avg_disc    0.047473
# Name: 538, dtype: float64
# mi          0.001248
# avg_disc    0.051785
# Name: 539, dtype: float64
# mi          0.001248
# avg_disc    0.048565
# Name: 540, dtype: float64
# mi          0.001248
# avg_disc    0.049113
# Name: 541, dtype: float64
# mi          0.001248
# avg_disc    0.049267
# Name: 542, dtype: float64
# mi          0.001248
# avg_disc    0.053577
# Name: 543, dtype: float64
# mi          0.001248
# avg_disc    0.046881
# Name: 544, dtype: float64
# mi          0.001248
# avg_disc    0.050744
# Name: 545, dtype: float64
# mi          0.001248
# avg_disc    0.047596
# Name: 546, dtype: float64
# mi          0.001248
# avg_disc    0.050983
# Name: 547, dtype: float64
# mi          0.001248
# avg_disc    0.049442
# Name: 548, dtype: float64
# mi          0.001248
# avg_disc    0.052860
# Name: 549, dtype: float64
# mi          0.001248
# avg_disc    0.051342
# Name: 550, dtype: float64
# mi          0.001248
# avg_disc    0.051132
# Name: 551, dtype: float64
# mi          0.001248
# avg_disc    0.046492
# Name: 552, dtype: float64
# mi          0.001248
# avg_disc    0.050169
# Name: 553, dtype: float64
# mi          0.001248
# avg_disc    0.050456
# Name: 554, dtype: float64
# mi          0.001248
# avg_disc    0.048933
# Name: 555, dtype: float64
# mi          0.001248
# avg_disc    0.048208
# Name: 556, dtype: float64
# mi          0.001248
# avg_disc    0.049783
# Name: 557, dtype: float64
# mi          0.001248
# avg_disc    0.046657
# Name: 558, dtype: float64
# mi          0.001248
# avg_disc    0.050042
# Name: 559, dtype: float64
# mi          0.001248
# avg_disc    0.049684
# Name: 560, dtype: float64
# mi          0.001248
# avg_disc    0.050318
# Name: 561, dtype: float64
# mi          0.001248
# avg_disc    0.051113
# Name: 562, dtype: float64
# mi          0.001248
# avg_disc    0.048113
# Name: 563, dtype: float64
# mi          0.001248
# avg_disc    0.050126
# Name: 564, dtype: float64
# mi          0.001248
# avg_disc    0.049514
# Name: 565, dtype: float64
# mi          0.001248
# avg_disc    0.047100
# Name: 566, dtype: float64
# mi          0.001248
# avg_disc    0.047243
# Name: 567, dtype: float64
# mi          0.001248
# avg_disc    0.052652
# Name: 568, dtype: float64
# mi          0.001248
# avg_disc    0.048468
# Name: 569, dtype: float64
# mi          0.001248
# avg_disc    0.049878
# Name: 570, dtype: float64
# mi          0.001248
# avg_disc    0.052721
# Name: 571, dtype: float64
# mi          0.001248
# avg_disc    0.048368
# Name: 572, dtype: float64
# mi          0.001248
# avg_disc    0.048966
# Name: 573, dtype: float64
# mi          0.001248
# avg_disc    0.049147
# Name: 574, dtype: float64
# mi          0.001248
# avg_disc    0.051158
# Name: 575, dtype: float64
# mi          0.001248
# avg_disc    0.049598
# Name: 576, dtype: float64
# mi          0.001248
# avg_disc    0.049236
# Name: 577, dtype: float64
# mi          0.001248
# avg_disc    0.051109
# Name: 578, dtype: float64
# mi          0.001248
# avg_disc    0.049026
# Name: 579, dtype: float64
# mi          0.001248
# avg_disc    0.048781
# Name: 580, dtype: float64
# mi          0.001248
# avg_disc    0.050971
# Name: 581, dtype: float64
# mi          0.001248
# avg_disc    0.052743
# Name: 582, dtype: float64
# mi          0.001248
# avg_disc    0.051892
# Name: 583, dtype: float64
# mi          0.001248
# avg_disc    0.052888
# Name: 584, dtype: float64
# mi          0.001248
# avg_disc    0.049804
# Name: 585, dtype: float64
# mi          0.001248
# avg_disc    0.048262
# Name: 586, dtype: float64
# mi          0.001248
# avg_disc    0.051650
# Name: 587, dtype: float64
# mi          0.001248
# avg_disc    0.049723
# Name: 588, dtype: float64
# mi          0.001248
# avg_disc    0.049790
# Name: 589, dtype: float64
# mi          0.001248
# avg_disc    0.051441
# Name: 590, dtype: float64
# mi          0.001248
# avg_disc    0.050367
# Name: 591, dtype: float64
# mi          0.001248
# avg_disc    0.052275
# Name: 592, dtype: float64
# mi          0.001248
# avg_disc    0.049060
# Name: 593, dtype: float64
# mi          0.001248
# avg_disc    0.049492
# Name: 594, dtype: float64
# mi          0.001248
# avg_disc    0.049775
# Name: 595, dtype: float64
# mi          0.001248
# avg_disc    0.049337
# Name: 596, dtype: float64
# mi          0.001248
# avg_disc    0.047537
# Name: 597, dtype: float64
# mi          0.001248
# avg_disc    0.049412
# Name: 598, dtype: float64
# mi          0.001248
# avg_disc    0.052677
# Name: 599, dtype: float64
# mi          0.001248
# avg_disc    0.049019
# Name: 600, dtype: float64
# mi          0.001248
# avg_disc    0.048782
# Name: 601, dtype: float64
# mi          0.001248
# avg_disc    0.050267
# Name: 602, dtype: float64
# mi          0.001248
# avg_disc    0.048011
# Name: 603, dtype: float64
# mi          0.001248
# avg_disc    0.052934
# Name: 604, dtype: float64
# mi          0.001248
# avg_disc    0.048346
# Name: 605, dtype: float64
# mi          0.001248
# avg_disc    0.047270
# Name: 606, dtype: float64
# mi          0.001248
# avg_disc    0.053091
# Name: 607, dtype: float64
# mi          0.001248
# avg_disc    0.049888
# Name: 608, dtype: float64
# mi          0.001248
# avg_disc    0.049275
# Name: 609, dtype: float64
# mi          0.001248
# avg_disc    0.049757
# Name: 610, dtype: float64
# mi          0.001248
# avg_disc    0.050727
# Name: 611, dtype: float64
# mi          0.001248
# avg_disc    0.050273
# Name: 612, dtype: float64
# mi          0.001248
# avg_disc    0.050281
# Name: 613, dtype: float64
# mi          0.001248
# avg_disc    0.052152
# Name: 614, dtype: float64
# mi          0.001248
# avg_disc    0.050610
# Name: 615, dtype: float64
# mi          0.001248
# avg_disc    0.052528
# Name: 616, dtype: float64
# mi          0.001248
# avg_disc    0.049909
# Name: 617, dtype: float64
# mi          0.001248
# avg_disc    0.048312
# Name: 618, dtype: float64
# mi          0.001248
# avg_disc    0.052651
# Name: 619, dtype: float64
# mi          0.001248
# avg_disc    0.050958
# Name: 620, dtype: float64
# mi          0.001248
# avg_disc    0.049864
# Name: 621, dtype: float64
# mi          0.001248
# avg_disc    0.049677
# Name: 622, dtype: float64
# mi          0.001248
# avg_disc    0.049825
# Name: 623, dtype: float64
# mi          0.001248
# avg_disc    0.048082
# Name: 624, dtype: float64
# mi          0.001248
# avg_disc    0.051648
# Name: 625, dtype: float64
# mi          0.001248
# avg_disc    0.049244
# Name: 626, dtype: float64
# mi          0.001248
# avg_disc    0.049640
# Name: 627, dtype: float64
# mi          0.001248
# avg_disc    0.052064
# Name: 628, dtype: float64
# mi          0.001248
# avg_disc    0.048671
# Name: 629, dtype: float64
# mi          0.001248
# avg_disc    0.051350
# Name: 630, dtype: float64
# mi          0.001248
# avg_disc    0.051668
# Name: 631, dtype: float64
# mi          0.001248
# avg_disc    0.051928
# Name: 632, dtype: float64
# mi          0.001248
# avg_disc    0.050208
# Name: 633, dtype: float64
# mi          0.001248
# avg_disc    0.048392
# Name: 634, dtype: float64
# mi          0.001248
# avg_disc    0.051149
# Name: 635, dtype: float64
# mi          0.001248
# avg_disc    0.052769
# Name: 636, dtype: float64
# mi          0.001248
# avg_disc    0.048528
# Name: 637, dtype: float64
# mi          0.001248
# avg_disc    0.051541
# Name: 638, dtype: float64
# mi          0.001248
# avg_disc    0.051157
# Name: 639, dtype: float64
# mi          0.001248
# avg_disc    0.046687
# Name: 640, dtype: float64
# mi          0.001248
# avg_disc    0.049859
# Name: 641, dtype: float64
# mi          0.001248
# avg_disc    0.049797
# Name: 642, dtype: float64
# mi          0.001248
# avg_disc    0.051381
# Name: 643, dtype: float64
# mi          0.001248
# avg_disc    0.049287
# Name: 644, dtype: float64
# mi          0.001248
# avg_disc    0.045813
# Name: 645, dtype: float64
# mi          0.001248
# avg_disc    0.052171
# Name: 646, dtype: float64
# mi          0.001248
# avg_disc    0.051237
# Name: 647, dtype: float64
# mi          0.001248
# avg_disc    0.051974
# Name: 648, dtype: float64
# mi          0.001248
# avg_disc    0.051450
# Name: 649, dtype: float64
# mi          0.001248
# avg_disc    0.051097
# Name: 650, dtype: float64
# mi          0.001248
# avg_disc    0.048052
# Name: 651, dtype: float64
# mi          0.001248
# avg_disc    0.051804
# Name: 652, dtype: float64
# mi          0.001248
# avg_disc    0.051228
# Name: 653, dtype: float64
# mi          0.001248
# avg_disc    0.051946
# Name: 654, dtype: float64
# mi          0.001248
# avg_disc    0.052178
# Name: 655, dtype: float64
# mi          0.001248
# avg_disc    0.051552
# Name: 656, dtype: float64
# mi          0.001248
# avg_disc    0.050349
# Name: 657, dtype: float64
# mi          0.001248
# avg_disc    0.049596
# Name: 658, dtype: float64
# mi          0.001248
# avg_disc    0.050902
# Name: 659, dtype: float64
# mi          0.001248
# avg_disc    0.051289
# Name: 660, dtype: float64
# mi          0.001248
# avg_disc    0.054119
# Name: 661, dtype: float64
# mi          0.001248
# avg_disc    0.050980
# Name: 662, dtype: float64
# mi          0.001248
# avg_disc    0.048367
# Name: 663, dtype: float64
# mi          0.001248
# avg_disc    0.051126
# Name: 664, dtype: float64
# mi          0.001248
# avg_disc    0.050132
# Name: 665, dtype: float64
# mi          0.001248
# avg_disc    0.049097
# Name: 666, dtype: float64
# mi          0.001248
# avg_disc    0.047279
# Name: 667, dtype: float64
# mi          0.001248
# avg_disc    0.052242
# Name: 668, dtype: float64
# mi          0.001248
# avg_disc    0.047659
# Name: 669, dtype: float64
# mi          0.001248
# avg_disc    0.048495
# Name: 670, dtype: float64
# mi          0.001248
# avg_disc    0.047762
# Name: 671, dtype: float64
# mi          0.001248
# avg_disc    0.049624
# Name: 672, dtype: float64
# mi          0.001248
# avg_disc    0.049238
# Name: 673, dtype: float64
# mi          0.001248
# avg_disc    0.049354
# Name: 674, dtype: float64
# mi          0.001248
# avg_disc    0.050764
# Name: 675, dtype: float64
# mi          0.001248
# avg_disc    0.049569
# Name: 676, dtype: float64
# mi          0.001248
# avg_disc    0.051687
# Name: 677, dtype: float64
# mi          0.001248
# avg_disc    0.049800
# Name: 678, dtype: float64
# mi          0.001248
# avg_disc    0.051743
# Name: 679, dtype: float64
# mi          0.001248
# avg_disc    0.050841
# Name: 680, dtype: float64
# mi          0.001248
# avg_disc    0.051744
# Name: 681, dtype: float64
# mi          0.001248
# avg_disc    0.051423
# Name: 682, dtype: float64
# mi          0.001248
# avg_disc    0.049901
# Name: 683, dtype: float64
# mi          0.001248
# avg_disc    0.051600
# Name: 684, dtype: float64
# mi          0.001248
# avg_disc    0.052386
# Name: 685, dtype: float64
# mi          0.001248
# avg_disc    0.052751
# Name: 686, dtype: float64
# mi          0.001248
# avg_disc    0.049573
# Name: 687, dtype: float64
# mi          0.001248
# avg_disc    0.050901
# Name: 688, dtype: float64
# mi          0.001248
# avg_disc    0.050299
# Name: 689, dtype: float64
# mi          0.001248
# avg_disc    0.047119
# Name: 690, dtype: float64
# mi          0.001248
# avg_disc    0.050757
# Name: 691, dtype: float64
# mi          0.001248
# avg_disc    0.048397
# Name: 692, dtype: float64
# mi          0.001248
# avg_disc    0.050232
# Name: 693, dtype: float64
# mi          0.001248
# avg_disc    0.052742
# Name: 694, dtype: float64
# mi          0.001248
# avg_disc    0.051520
# Name: 695, dtype: float64
# mi          0.001248
# avg_disc    0.052729
# Name: 696, dtype: float64
# mi          0.001248
# avg_disc    0.047895
# Name: 697, dtype: float64
# mi          0.001248
# avg_disc    0.052076
# Name: 698, dtype: float64
# mi          0.001248
# avg_disc    0.051265
# Name: 699, dtype: float64
# mi          0.001248
# avg_disc    0.050677
# Name: 700, dtype: float64
# mi          0.001248
# avg_disc    0.052348
# Name: 701, dtype: float64
# mi          0.001248
# avg_disc    0.050035
# Name: 702, dtype: float64
# mi          0.001248
# avg_disc    0.049059
# Name: 703, dtype: float64
# mi          0.001248
# avg_disc    0.050203
# Name: 704, dtype: float64
# mi          0.001248
# avg_disc    0.053339
# Name: 705, dtype: float64
# mi          0.001248
# avg_disc    0.051490
# Name: 706, dtype: float64
# mi          0.001248
# ...
# Name: 8785, dtype: float64
# mi          16.000000
# avg_disc     0.050202
# Name: 8786, dtype: float64
# mi          16.000000
# avg_disc     0.050151
# Name: 8787, dtype: float64
# mi          16.000000
# avg_disc     0.050025
# Name: 8788, dtype: float64
# mi          16.000000
# avg_disc     0.050168
# Name: 8789, dtype: float64
# mi          16.0000
# avg_disc     0.0501
# Name: 8790, dtype: float64
# mi          16.000000
# avg_disc     0.050098
# Name: 8791, dtype: float64
# mi          16.000000
# avg_disc     0.050265
# Name: 8792, dtype: float64
# mi          16.00000
# avg_disc     0.05016
# Name: 8793, dtype: float64
# mi          16.000000
# avg_disc     0.050239
# Name: 8794, dtype: float64
# mi          16.000000
# avg_disc     0.050166
# Name: 8795, dtype: float64
# mi          16.000000
# avg_disc     0.050104
# Name: 8796, dtype: float64
# mi          16.000000
# avg_disc     0.050109
# Name: 8797, dtype: float64
# mi          16.000000
# avg_disc     0.050116
# Name: 8798, dtype: float64
# mi          16.00000
# avg_disc     0.04999
# Name: 8799, dtype: float64
# mi          16.000000
# avg_disc     0.050121
# Name: 8800, dtype: float64
# mi          16.000000
# avg_disc     0.050122
# Name: 8801, dtype: float64
# mi          16.000000
# avg_disc     0.050267
# Name: 8802, dtype: float64
# mi          16.000000
# avg_disc     0.050122
# Name: 8803, dtype: float64
# mi          16.000000
# avg_disc     0.050132
# Name: 8804, dtype: float64
# mi          16.000000
# avg_disc     0.050162
# Name: 8805, dtype: float64
# mi          16.000000
# avg_disc     0.050117
# Name: 8806, dtype: float64
# mi          16.000000
# avg_disc     0.050133
# Name: 8807, dtype: float64
# mi          16.000000
# avg_disc     0.050235
# Name: 8808, dtype: float64
# mi          16.000000
# avg_disc     0.050132
# Name: 8809, dtype: float64
# mi          16.000000
# avg_disc     0.050144
# Name: 8810, dtype: float64
# mi          16.000000
# avg_disc     0.050065
# Name: 8811, dtype: float64
# mi          16.000000
# avg_disc     0.050159
# Name: 8812, dtype: float64
# mi          16.000000
# avg_disc     0.050062
# Name: 8813, dtype: float64
# mi          16.000000
# avg_disc     0.050057
# Name: 8814, dtype: float64
# mi          16.000000
# avg_disc     0.050166
# Name: 8815, dtype: float64
# mi          16.000000
# avg_disc     0.050161
# Name: 8816, dtype: float64
# mi          16.000000
# avg_disc     0.050129
# Name: 8817, dtype: float64
# mi          16.000000
# avg_disc     0.050098
# Name: 8818, dtype: float64
# mi          16.000000
# avg_disc     0.050185
# Name: 8819, dtype: float64
# mi          16.000000
# avg_disc     0.050176
# Name: 8820, dtype: float64
# mi          16.000000
# avg_disc     0.049983
# Name: 8821, dtype: float64
# mi          16.000000
# avg_disc     0.050237
# Name: 8822, dtype: float64
# mi          16.000000
# avg_disc     0.050036
# Name: 8823, dtype: float64
# mi          16.000000
# avg_disc     0.050123
# Name: 8824, dtype: float64
# mi          16.000000
# avg_disc     0.050326
# Name: 8825, dtype: float64
# mi          16.00000
# avg_disc     0.05021
# Name: 8826, dtype: float64
# mi          16.000000
# avg_disc     0.050071
# Name: 8827, dtype: float64
# mi          16.000000
# avg_disc     0.050171
# Name: 8828, dtype: float64
# mi          16.000000
# avg_disc     0.050158
# Name: 8829, dtype: float64
# mi          16.000000
# avg_disc     0.050092
# Name: 8830, dtype: float64
# mi          16.000000
# avg_disc     0.050211
# Name: 8831, dtype: float64
# mi          16.000000
# avg_disc     0.050055
# Name: 8832, dtype: float64
# mi          16.000000
# avg_disc     0.050139
# Name: 8833, dtype: float64
# mi          16.000000
# avg_disc     0.050244
# Name: 8834, dtype: float64
# mi          16.000000
# avg_disc     0.050143
# Name: 8835, dtype: float64
# mi          16.000000
# avg_disc     0.050195
# Name: 8836, dtype: float64
# mi          16.000000
# avg_disc     0.050135
# Name: 8837, dtype: float64
# mi          16.000000
# avg_disc     0.050174
# Name: 8838, dtype: float64
# mi          16.000000
# avg_disc     0.050104
# Name: 8839, dtype: float64
# mi          16.000000
# avg_disc     0.050057
# Name: 8840, dtype: float64
# mi          16.000000
# avg_disc     0.050132
# Name: 8841, dtype: float64
# mi          16.00000
# avg_disc     0.05021
# Name: 8842, dtype: float64
# mi          16.000000
# avg_disc     0.050179
# Name: 8843, dtype: float64
# mi          16.000000
# avg_disc     0.050068
# Name: 8844, dtype: float64
# mi          16.000000
# avg_disc     0.050157
# Name: 8845, dtype: float64
# mi          16.000000
# avg_disc     0.050025
# Name: 8846, dtype: float64
# mi          16.000000
# avg_disc     0.050066
# Name: 8847, dtype: float64
# mi          16.000000
# avg_disc     0.050168
# Name: 8848, dtype: float64
# mi          16.000000
# avg_disc     0.050119
# Name: 8849, dtype: float64
# mi          16.000000
# avg_disc     0.050258
# Name: 8850, dtype: float64
# mi          16.000000
# avg_disc     0.050218
# Name: 8851, dtype: float64
# mi          16.000000
# avg_disc     0.050327
# Name: 8852, dtype: float64
# mi          16.000000
# avg_disc     0.050186
# Name: 8853, dtype: float64
# mi          16.000000
# avg_disc     0.050255
# Name: 8854, dtype: float64
# mi          16.000000
# avg_disc     0.050148
# Name: 8855, dtype: float64
# mi          16.000000
# avg_disc     0.049974
# Name: 8856, dtype: float64
# mi          16.000000
# avg_disc     0.050179
# Name: 8857, dtype: float64
# mi          16.000000
# avg_disc     0.050098
# Name: 8858, dtype: float64
# mi          16.000000
# avg_disc     0.050159
# Name: 8859, dtype: float64
# mi          16.000000
# avg_disc     0.050156
# Name: 8860, dtype: float64
# mi          16.000000
# avg_disc     0.050086
# Name: 8861, dtype: float64
# mi          16.000000
# avg_disc     0.050197
# Name: 8862, dtype: float64
# mi          16.000000
# avg_disc     0.050208
# Name: 8863, dtype: float64
# mi          16.000000
# avg_disc     0.050097
# Name: 8864, dtype: float64
# mi          16.000000
# avg_disc     0.050289
# Name: 8865, dtype: float64
# mi          16.000000
# avg_disc     0.050114
# Name: 8866, dtype: float64
# mi          16.000000
# avg_disc     0.050112
# Name: 8867, dtype: float64
# mi          16.000000
# avg_disc     0.050253
# Name: 8868, dtype: float64
# mi          16.000000
# avg_disc     0.050137
# Name: 8869, dtype: float64
# mi          16.000000
# avg_disc     0.050125
# Name: 8870, dtype: float64
# mi          16.000000
# avg_disc     0.050042
# Name: 8871, dtype: float64
# mi          16.000000
# avg_disc     0.050004
# Name: 8872, dtype: float64
# mi          16.000000
# avg_disc     0.050165
# Name: 8873, dtype: float64
# mi          16.000000
# avg_disc     0.050266
# Name: 8874, dtype: float64
# mi          16.000000
# avg_disc     0.050067
# Name: 8875, dtype: float64
# mi          16.000000
# avg_disc     0.050138
# Name: 8876, dtype: float64
# mi          16.000000
# avg_disc     0.050105
# Name: 8877, dtype: float64
# mi          16.000000
# avg_disc     0.050064
# Name: 8878, dtype: float64
# mi          16.00000
# avg_disc     0.05015
# Name: 8879, dtype: float64
# mi          16.00000
# avg_disc     0.05013
# Name: 8880, dtype: float64
# mi          16.000000
# avg_disc     0.050186
# Name: 8881, dtype: float64
# mi          16.000000
# avg_disc     0.050168
# Name: 8882, dtype: float64
# mi          16.000000
# avg_disc     0.050154
# Name: 8883, dtype: float64
# mi          16.000000
# avg_disc     0.050278
# Name: 8884, dtype: float64
# mi          16.000000
# avg_disc     0.050179
# Name: 8885, dtype: float64
# mi          16.000000
# avg_disc     0.050227
# Name: 8886, dtype: float64
# mi          16.000000
# avg_disc     0.050093
# Name: 8887, dtype: float64
# mi          16.000000
# avg_disc     0.050096
# Name: 8888, dtype: float64
# mi          16.000000
# avg_disc     0.050181
# Name: 8889, dtype: float64
# mi          16.00000
# avg_disc     0.05008
# Name: 8890, dtype: float64
# mi          16.000000
# avg_disc     0.050187
# Name: 8891, dtype: float64
# mi          16.000000
# avg_disc     0.050319
# Name: 8892, dtype: float64
# mi          16.00000
# avg_disc     0.05023
# Name: 8893, dtype: float64
# mi          16.000000
# avg_disc     0.050247
# Name: 8894, dtype: float64
# mi          16.000000
# avg_disc     0.050081
# Name: 8895, dtype: float64
# mi          16.000000
# avg_disc     0.050156
# Name: 8896, dtype: float64
# mi          16.000000
# avg_disc     0.050234
# Name: 8897, dtype: float64
# mi          16.000000
# avg_disc     0.050001
# Name: 8898, dtype: float64
# mi          16.000000
# avg_disc     0.050186
# Name: 8899, dtype: float64
# mi          16.000000
# avg_disc     0.049989
# Name: 8900, dtype: float64
# mi          16.000000
# avg_disc     0.050256
# Name: 8901, dtype: float64
# mi          16.000000
# avg_disc     0.050194
# Name: 8902, dtype: float64
# mi          16.000000
# avg_disc     0.050127
# Name: 8903, dtype: float64
# mi          16.000000
# avg_disc     0.050212
# Name: 8904, dtype: float64
# mi          16.000000
# avg_disc     0.050025
# Name: 8905, dtype: float64
# mi          16.00000
# avg_disc     0.05004
# Name: 8906, dtype: float64
# mi          16.000000
# avg_disc     0.050184
# Name: 8907, dtype: float64
# mi          16.000000
# avg_disc     0.049988
# Name: 8908, dtype: float64
# mi          16.000000
# avg_disc     0.050117
# Name: 8909, dtype: float64
# mi          16.000000
# avg_disc     0.050202
# Name: 8910, dtype: float64
# mi          16.000000
# avg_disc     0.050344
# Name: 8911, dtype: float64
# mi          16.000000
# avg_disc     0.050117
# Name: 8912, dtype: float64
# mi          16.000000
# avg_disc     0.050076
# Name: 8913, dtype: float64
# mi          16.000000
# avg_disc     0.050024
# Name: 8914, dtype: float64
# mi          16.000000
# avg_disc     0.050087
# Name: 8915, dtype: float64
# mi          16.000000
# avg_disc     0.050228
# Name: 8916, dtype: float64
# mi          16.00000
# avg_disc     0.05021
# Name: 8917, dtype: float64
# mi          16.000000
# avg_disc     0.050071
# Name: 8918, dtype: float64
# mi          16.000000
# avg_disc     0.050111
# Name: 8919, dtype: float64
# mi          16.000000
# avg_disc     0.050272
# Name: 8920, dtype: float64
# mi          16.000000
# avg_disc     0.050155
# Name: 8921, dtype: float64
# mi          16.00000
# avg_disc     0.05009
# Name: 8922, dtype: float64
# mi          16.00000
# avg_disc     0.05017
# Name: 8923, dtype: float64
# mi          16.000000
# avg_disc     0.050085
# Name: 8924, dtype: float64
# mi          16.000000
# avg_disc     0.050095
# Name: 8925, dtype: float64
# mi          16.00000
# avg_disc     0.05014
# Name: 8926, dtype: float64
# mi          16.000000
# avg_disc     0.050215
# Name: 8927, dtype: float64
# mi          16.00000
# avg_disc     0.05022
# Name: 8928, dtype: float64
# mi          16.000000
# avg_disc     0.050148
# Name: 8929, dtype: float64
# mi          16.000000
# avg_disc     0.050088
# Name: 8930, dtype: float64
# mi          16.000000
# avg_disc     0.050112
# Name: 8931, dtype: float64
# mi          16.000000
# avg_disc     0.050017
# Name: 8932, dtype: float64
# mi          16.000000
# avg_disc     0.050075
# Name: 8933, dtype: float64
# mi          16.000000
# avg_disc     0.050175
# Name: 8934, dtype: float64
# mi          16.000000
# avg_disc     0.049946
# Name: 8935, dtype: float64
# mi          16.000000
# avg_disc     0.050135
# Name: 8936, dtype: float64
# mi          16.00000
# avg_disc     0.05031
# Name: 8937, dtype: float64
# mi          16.000000
# avg_disc     0.050138
# Name: 8938, dtype: float64
# mi          16.000000
# avg_disc     0.050029
# Name: 8939, dtype: float64
# mi          16.000000
# avg_disc     0.050099
# Name: 8940, dtype: float64
# mi          16.000000
# avg_disc     0.050397
# Name: 8941, dtype: float64
# mi          16.0000
# avg_disc     0.0502
# Name: 8942, dtype: float64
# mi          16.000000
# avg_disc     0.050177
# Name: 8943, dtype: float64
# mi          16.000000
# avg_disc     0.050074
# Name: 8944, dtype: float64
# mi          16.000000
# avg_disc     0.050214
# Name: 8945, dtype: float64
# mi          16.000000
# avg_disc     0.050205
# Name: 8946, dtype: float64
# mi          16.000000
# avg_disc     0.050066
# Name: 8947, dtype: float64
# mi          16.000000
# avg_disc     0.050078
# Name: 8948, dtype: float64
# mi          16.000000
# avg_disc     0.050256
# Name: 8949, dtype: float64
# mi          16.000000
# avg_disc     0.050116
# Name: 8950, dtype: float64
# mi          16.000000
# avg_disc     0.050252
# Name: 8951, dtype: float64
# mi          16.000000
# avg_disc     0.050234
# Name: 8952, dtype: float64
# mi          16.000000
# avg_disc     0.050181
# Name: 8953, dtype: float64
# mi          16.000000
# avg_disc     0.050048
# Name: 8954, dtype: float64
# mi          16.000000
# avg_disc     0.050199
# Name: 8955, dtype: float64
# mi          16.00000
# avg_disc     0.05007
# Name: 8956, dtype: float64
# mi          16.000000
# avg_disc     0.050041
# Name: 8957, dtype: float64
# mi          16.000000
# avg_disc     0.050066
# Name: 8958, dtype: float64
# mi          16.000000
# avg_disc     0.050155
# Name: 8959, dtype: float64
# mi          16.000000
# avg_disc     0.050103
# Name: 8960, dtype: float64
# mi          16.000000
# avg_disc     0.049926
# Name: 8961, dtype: float64
# mi          16.000000
# avg_disc     0.050157
# Name: 8962, dtype: float64
# mi          16.000000
# avg_disc     0.049985
# Name: 8963, dtype: float64
# mi          16.0000
# avg_disc     0.0501
# Name: 8964, dtype: float64
# mi          16.000000
# avg_disc     0.050114
# Name: 8965, dtype: float64
# mi          16.000000
# avg_disc     0.050131
# Name: 8966, dtype: float64
# mi          16.000000
# avg_disc     0.050028
# Name: 8967, dtype: float64
# mi          16.000000
# avg_disc     0.050206
# Name: 8968, dtype: float64
# mi          16.000000
# avg_disc     0.050128
# Name: 8969, dtype: float64
# mi          16.000000
# avg_disc     0.050205
# Name: 8970, dtype: float64
# mi          16.000000
# avg_disc     0.050211
# Name: 8971, dtype: float64
# mi          16.000000
# avg_disc     0.050175
# Name: 8972, dtype: float64
# mi          16.000000
# avg_disc     0.050144
# Name: 8973, dtype: float64
# mi          16.000000
# avg_disc     0.050026
# Name: 8974, dtype: float64
# mi          16.000000
# avg_disc     0.050124
# Name: 8975, dtype: float64
# mi          16.000000
# avg_disc     0.050441
# Name: 8976, dtype: float64
# mi          16.000000
# avg_disc     0.050232
# Name: 8977, dtype: float64
# mi          16.000000
# avg_disc     0.050101
# Name: 8978, dtype: float64
# mi          16.000000
# avg_disc     0.050069
# Name: 8979, dtype: float64
# mi          16.000000
# avg_disc     0.050029
# Name: 8980, dtype: float64
# mi          16.000000
# avg_disc     0.050105
# Name: 8981, dtype: float64
# mi          16.000000
# avg_disc     0.050244
# Name: 8982, dtype: float64
# mi          16.000000
# avg_disc     0.050189
# Name: 8983, dtype: float64
# mi          16.000000
# avg_disc     0.049964
# Name: 8984, dtype: float64
# mi          16.000000
# avg_disc     0.050166
# Name: 8985, dtype: float64
# mi          16.000000
# avg_disc     0.050203
# Name: 8986, dtype: float64
# mi          16.000000
# avg_disc     0.050142
# Name: 8987, dtype: float64
# mi          16.000000
# avg_disc     0.050326
# Name: 8988, dtype: float64
# mi          16.000000
# avg_disc     0.050111
# Name: 8989, dtype: float64
# mi          16.0000
# avg_disc     0.0502
# Name: 8990, dtype: float64
# mi          16.00000
# avg_disc     0.05024
# Name: 8991, dtype: float64
# mi          16.00000
# avg_disc     0.05017
# Name: 8992, dtype: float64
# mi          16.000000
# avg_disc     0.050077
# Name: 8993, dtype: float64
# mi          16.000000
# avg_disc     0.050013
# Name: 8994, dtype: float64
# mi          16.000000
# avg_disc     0.050252
# Name: 8995, dtype: float64
# mi          16.000000
# avg_disc     0.049986
# Name: 8996, dtype: float64
# mi          16.000000
# avg_disc     0.050237
# Name: 8997, dtype: float64
# mi          16.000000
# avg_disc     0.050188
# Name: 8998, dtype: float64
# mi          16.000000
# avg_disc     0.049928
# Name: 8999, dtype: float64
#              mi  absolute error avg_disc  relative error avg_disc
# 0      0.001248                 0.000138                 0.275240
# 1      0.001248                 0.003580                 7.138596
# 2      0.001248                 0.002473                 4.931198
# 3      0.001248                 0.000179                 0.356414
# 4      0.001248                 0.000711                 1.417519
# ...         ...                      ...                      ...
# 8995  16.000000                 0.000108                 0.214809
# 8996  16.000000                 0.000158                 0.315657
# 8997  16.000000                 0.000093                 0.185159
# 8998  16.000000                 0.000043                 0.085759
# 8999  16.000000                 0.000216                 0.431644
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 avg_disc mean  avg_disc var
# type factor
# pac  0.001248        0.050101  2.935569e-06
#      0.015625        0.050167  2.348160e-07
#      0.031250        0.050128  1.156286e-07
#      0.062500        0.050142  6.619654e-08
#      0.250000        0.050144  1.993478e-08
#      1.000000        0.050143  9.774616e-09
#      2.000000        0.050151  8.785649e-09
#      4.000000        0.050150  7.568721e-09
#      16.000000       0.050142  7.066317e-09

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error avg_disc mean  absolute error avg_disc var  \
# type factor
# pac  0.001248                       0.001386                 1.013771e-06
#      0.015625                       0.000389                 8.390384e-08
#      0.031250                       0.000271                 4.251313e-08
#      0.062500                       0.000203                 2.514547e-08
#      0.250000                       0.000114                 6.952774e-09
#      1.000000                       0.000079                 3.564722e-09
#      2.000000                       0.000076                 2.991499e-09
#      4.000000                       0.000069                 2.830414e-09
#      16.000000                      0.000067                 2.525434e-09
#
#                 relative error avg_disc mean  relative error avg_disc var
# type factor
# pac  0.001248                       2.764589                     4.031730
#      0.015625                       0.775650                     0.333683
#      0.031250                       0.539979                     0.169073
#      0.062500                       0.403893                     0.100003
#      0.250000                       0.227108                     0.027651
#      1.000000                       0.157123                     0.014177
#      2.000000                       0.152322                     0.011897
#      4.000000                       0.137676                     0.011256
#      16.000000                      0.134443                     0.010044

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#                avg_disc
# mi
# 0.001248   2.935569e-06
# 0.015625   2.348160e-07
# 0.031250   1.156286e-07
# 0.062500   6.619654e-08
# 0.250000   1.993478e-08
# 1.000000   9.774616e-09
# 2.000000   8.785649e-09
# 4.000000   7.568721e-09
# 16.000000  7.066317e-09

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step              scale
# query          avg_disc
# mi
# 0.001248   2.798489e-06
# 0.015625   2.235780e-07
# 0.031250   1.117890e-07
# 0.062500   5.589449e-08
# 0.250000   1.397362e-08
# 1.000000   3.493406e-09
# 2.000000   1.746703e-09
# 4.000000   8.733515e-10
# 16.000000  2.183379e-10

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# avg_disc    0.132998
# dtype: float64
#            avg_disc
# mi
# 0.001248   0.134522
# 0.015625   0.128350
# 0.031250   0.136229
# 0.062500   0.137989
# 0.250000   0.133241
# 1.000000   0.129348
# 2.000000   0.134598
# 4.000000   0.129041
# 16.000000  0.133664

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query              avg_disc
# mi
# 0.001248           0.001385
# 0.015625           0.000385
# 0.031250           0.000263
# 0.062500           0.000189
# 0.250000           0.000093
# 1.000000           0.000049
# 2.000000           0.000033
# 4.000000           0.000023
# 16.000000          0.000012

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query          avg_disc
# mi
# 0.001248       0.050140
# 0.015625       0.050146
# 0.031250       0.050142
# 0.062500       0.050141
# 0.250000       0.050148
# 1.000000       0.050146
# 2.000000       0.050149
# 4.000000       0.050148
# 16.000000      0.050142
# step   chosen_sample
# query       avg_disc
# all mi      0.050145

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#            avg_disc
# mi
# 0.001248   2.764589
# 0.015625   0.775650
# 0.031250   0.539979
# 0.062500   0.403893
# 0.250000   0.227108
# 1.000000   0.157123
# 2.000000   0.152322
# 4.000000   0.137676
# 16.000000  0.134443

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#            avg_disc
# mi
# 0.001248   2.630068
# 0.015625   0.647300
# 0.031250   0.403750
# 0.062500   0.265904
# 0.250000   0.093867
# 1.000000   0.027775
# 2.000000   0.017724
# 4.000000   0.008635
# 16.000000  0.000779

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()
