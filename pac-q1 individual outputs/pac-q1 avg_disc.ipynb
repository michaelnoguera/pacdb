# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   -- sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   -- sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   -- avg(l_quantity) as avg_qty,
#   -- avg(l_extendedprice) as avg_price,
#   avg(l_discount) as avg_disc,
#   -- count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'A'
#   and l_linestatus = 'F'
# ```

# %%
EXPERIMENT = 'pac-q1-avg-disc-N-F'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'N') &
        (lineitem_df['l_linestatus'] == 'F')
    ]
    print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        # float(discounted_price.sum()),                      # sum_disc_price
        # float(charged_price.sum()),                         # sum_charge
        # float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        # float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        # float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# (3765, 16)
# [0.04939442231075697]
# [0.04939442231075697]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['avg_disc']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 147790  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            # out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np
# Out:
# (3765, 16)
# [0.04939442231075697]

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
# TODO: Change it back to 1000
EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    out_np = generate_samples() # generate samples (results of running the query)
    # print(f"Generate samples... {len(out_np)} samples generated.")

    # print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# (1880, 16)
# [0.04971276595744681]
# (1885, 16)
# [0.04907692307692308]
# (1925, 16)
# [0.04956883116883117]
# (1840, 16)
# [0.04921195652173913]
# (1858, 16)
# [0.049628632938643696]
# (1907, 16)
# [0.04916622968012586]
# (1902, 16)
# [0.049269190325972656]
# (1863, 16)
# [0.049522275899087496]
# (1913, 16)
# [0.0498588604286461]
# (1852, 16)
# [0.048914686825053996]
# (1854, 16)
# [0.049293419633225456]
# (1911, 16)
# [0.049492412349555204]
# (1831, 16)
# [0.04920808301474604]
# (1934, 16)
# [0.04957083764219235]
# (1894, 16)
# [0.04969904963041182]
# (1871, 16)
# [0.049086050240513095]
# (1885, 16)
# [0.0483395225464191]
# (1880, 16)
# [0.050452127659574464]
# (1878, 16)
# [0.04917465388711395]
# (1887, 16)
# [0.04961314255431903]
# (1850, 16)
# [0.0496054054054054]
# (1915, 16)
# [0.04919060052219321]
# (1888, 16)
# [0.048824152542372885]
# (1877, 16)
# [0.049968034096963244]
# (1894, 16)
# [0.04876979936642028]
# (1871, 16)
# [0.050026723677177976]
# (1895, 16)
# [0.049889182058047495]
# (1870, 16)
# [0.04889304812834225]
# (1920, 16)
# [0.049229166666666664]
# (1845, 16)
# [0.04956639566395664]
# (1859, 16)
# [0.04933835395373857]
# (1906, 16)
# [0.049449108079748165]
# (1878, 16)
# [0.049100106496272625]
# (1887, 16)
# [0.04968733439321675]
# (1859, 16)
# [0.04944593867670791]
# (1906, 16)
# [0.04934417628541448]
# (1867, 16)
# [0.04967862881628281]
# (1898, 16)
# [0.04911485774499473]
# (1851, 16)
# [0.04804430037817396]
# (1914, 16)
# [0.05070010449320794]
# (1887, 16)
# [0.048441971383147854]
# (1878, 16)
# [0.050351437699680514]
# (1903, 16)
# [0.04944823962165002]
# (1862, 16)
# [0.04933941997851773]
# (1842, 16)
# [0.049712269272529856]
# (1923, 16)
# [0.049089963598543944]
# (1857, 16)
# [0.04927840603123317]
# (1908, 16)
# [0.049507337526205446]
# (1906, 16)
# [0.049464847848898215]
# (1859, 16)
# [0.04932221624529317]
# (1917, 16)
# [0.050198226395409495]
# (1848, 16)
# [0.04856060606060606]
# (1831, 16)
# [0.04944838885854724]
# (1934, 16)
# [0.04934332988624612]
# (1850, 16)
# [0.04923243243243243]
# (1915, 16)
# (1912, 16)
# [0.05007845188284519]
# (1864, 16)
# [0.04958690987124464]
# (1901, 16)
# [0.049205681220410316]
# (1846, 16)
# [0.05039003250270856]
# (1919, 16)
# [0.04843668577384054]
# (1941, 16)
# [0.05044822256568779]
# (1824, 16)
# [0.048273026315789475]
# (1910, 16)
# [0.049172774869109946]
# (1855, 16)
# [0.04962264150943396]
# (1946, 16)
# [0.04889003083247687]
# (1819, 16)
# [0.04993402968664101]
# (1833, 16)
# [0.04924168030551009]
# (1932, 16)
# [0.04953933747412008]
# (1844, 16)
# [0.04964750542299349]
# (1921, 16)
# [0.04915148360229048]
# (1894, 16)
# [0.049097148891235474]
# (1871, 16)
# [0.049695350080171036]
# (1852, 16)
# [0.0491036717062635]
# (1913, 16)
# [0.049675901725039204]
# (1845, 16)
# [0.0503739837398374]
# (1920, 16)
# [0.048453125]
# (1841, 16)
# [0.04999456816947312]
# (1924, 16)
# [0.04882016632016632]
# (1849, 16)
# [0.04990265008112493]
# (1916, 16)
# [0.04890396659707725]
# (1902, 16)
# [0.048606729758149315]
# (1863, 16)
# [0.05019860440150295]
# (1994, 16)
# [0.049112337011033104]
# (1771, 16)
# [0.04971202710333145]
# (1941, 16)
# [0.04999484801648635]
# (1824, 16)
# [0.04875548245614036]
# (1865, 16)
# [0.0493941018766756]
# (1900, 16)
# [0.04939473684210526]
# (1927, 16)
# [0.04901920083030617]
# (1838, 16)
# [0.04978781284004353]
# (1957, 16)
# [0.048758303525804805]
# (1808, 16)
# [0.05008296460176991]
# (1916, 16)
# [0.04936847599164927]
# (1849, 16)
# [0.049421308815575986]
# (1854, 16)
# [0.049633225458468176]
# (1911, 16)
# [0.04916274201988488]
# (1887, 16)
# [0.04998410174880763]
# (1878, 16)
# [0.04880191693290735]
# (1898, 16)
# [0.04920969441517387]
# (1867, 16)
# [0.049582217461167644]
# (1854, 16)
# [0.050458468176914774]
# (1911, 16)
# [0.048362114076399794]
# (1809, 16)
# [0.04897180762852405]
# (1956, 16)
# [0.04978527607361963]
# (1852, 16)
# [0.04959503239740821]
# (1913, 16)
# [0.049200209095661265]
# (1858, 16)
# [0.049693218514531755]
# (1907, 16)
# [0.04910330361824856]
# (1873, 16)
# [0.04917245061398825]
# (1892, 16)
# [0.04961416490486258]
# (1898, 16)
# [0.04854583772391992]
# (1867, 16)
# [0.05025709694697375]
# (1858, 16)
# [0.0486221743810549]
# (1907, 16)
# [0.050146827477713686]
# (1875, 16)
# [0.04953066666666667]
# (1890, 16)
# [0.04925925925925926]
# (1856, 16)
# [0.0496875]
# (1909, 16)
# [0.04910948140387637]
# (1880, 16)
# [0.04927127659574468]
# (1885, 16)
# [0.049517241379310344]
# (1920, 16)
# [0.049442708333333335]
# (1845, 16)
# [0.04934417344173442]
# (1934, 16)
# [0.04904343329886246]
# (1831, 16)
# [0.04976515565264883]
# (1909, 16)
# [0.0491828182294395]
# (1856, 16)
# [0.04961206896551724]
# (1821, 16)
# [0.04931905546403075]
# (1944, 16)
# [0.04946502057613168]
# (1894, 16)
# [0.04958839050131926]
# (1870, 16)
# [0.04919786096256684]
# (1904, 16)
# [0.04888655462184874]
# (1861, 16)
# [0.04991402471789361]
# (1863, 16)
# [0.05024691358024691]
# (1902, 16)
# [0.048559411146161933]
# (1873, 16)
# [0.0491137213027229]
# (1892, 16)
# [0.0496723044397463]
# (1905, 16)
# [0.04861942257217848]
# (1860, 16)
# [0.05018817204301075]
# (1932, 16)
# [0.04965320910973085]
# (1833, 16)
# [0.049121658483360614]
# (1880, 16)
# [0.04826063829787234]
# (1885, 16)
# [0.05052519893899204]
# (1885, 16)
# [0.04986206896551724]
# (1880, 16)
# [0.04892553191489362]
# (1915, 16)
# [0.05029242819843342]
# (1850, 16)
# [0.048464864864864864]
# (1856, 16)
# [0.0497521551724138]
# (1909, 16)
# [0.04904662126767941]
# (1836, 16)
# [0.049226579520697165]
# (1929, 16)
# [0.04955417314670814]
# (1854, 16)
# [0.048371089536138084]
# (1911, 16)
# [0.05038723181580325]
# (1879, 16)
# [0.048078765300691856]
# (1886, 16)
# [0.050705196182396606]
# (1855, 16)
# [0.04987601078167116]
# (1910, 16)
# [0.04892670157068063]
# (1842, 16)
# [0.04891965255157438]
# (1923, 16)
# [0.04984919396775871]
# (1867, 16)
# [0.049287627209426886]
# (1898, 16)
# [0.049499473129610116]
# (1892, 16)
# [0.050258985200845666]
# (1873, 16)
# [0.04852108916177256]
# (1896, 16)
# [0.04971518987341773]
# (1869, 16)
# [0.04906902086677367]
# (1909, 16)
# [0.04894709271870089]
# (1856, 16)
# [0.04985452586206897]
# (1900, 16)
# [0.04892105263157895]
# (1865, 16)
# [0.04987667560321716]
# (1902, 16)
# [0.04956887486855941]
# (1863, 16)
# [0.049216317767042404]
# (1853, 16)
# [0.04880194279546681]
# (1912, 16)
# [0.049968619246861926]
# (1920, 16)
# [0.04878645833333333]
# (1845, 16)
# [0.05002710027100271]
# (1867, 16)
# [0.04919121585431173]
# (1898, 16)
# [0.04959430979978925]
# (1858, 16)
# [0.049122712594187296]
# (1907, 16)
# [0.04965915049816466]
# (1922, 16)
# [0.049885535900104055]
# (1843, 16)
# [0.04888225718936517]
# (1928, 16)
# [0.04896784232365145]
# (1837, 16)
# [0.0498421339139902]
# (1873, 16)
# [0.050112119594233846]
# (1892, 16)
# [0.048683932346723045]
# (1941, 16)
# [0.04892323544564657]
# (1824, 16)
# [0.049895833333333334]
# (1893, 16)
# [0.05011093502377179]
# (1872, 16)
# [0.0486698717948718]
# (1900, 16)
# [0.049300000000000004]
# (1865, 16)
# [0.04949061662198391]
# (1867, 16)
# [0.04953401178361007]
# (1898, 16)
# [0.04925711275026343]
# (1887, 16)
# [0.04951775304716481]
# (1878, 16)
# [0.049270500532481366]
# (1825, 16)
# [0.0492]
# (1940, 16)
# [0.04957731958762887]
# (1854, 16)
# [0.04939050701186623]
# (1911, 16)
# [0.04939822082679226]
# (1853, 16)
# [0.04919050188882893]
# (1912, 16)
# [0.04959205020920502]
# (1891, 16)
# [0.05005817028027498]
# (1874, 16)
# [0.04872465314834579]
# (1860, 16)
# [0.04931182795698925]
# (1903, 16)
# [0.04886495007882291]
# (1862, 16)
# [0.04993555316863588]
# (1847, 16)
# [0.04993502977801841]
# (1918, 16)
# [0.04887382690302398]
# (1913, 16)
# [0.049069524307370625]
# (1852, 16)
# [0.04973002159827213]
# (1843, 16)
# [0.04961475854584916]
# (1922, 16)
# [0.049183142559833505]
# (1924, 16)
# [0.04951663201663201]
# (1841, 16)
# [0.04926670287887018]
# (1835, 16)
# [0.04922615803814714]
# (1930, 16)
# [0.049554404145077724]
# (1891, 16)
# [0.050195663670015864]
# (1874, 16)
# [0.04858591248665955]
# (1904, 16)
# [0.04884453781512605]
# (1861, 16)
# [0.049957012358946805]
# (1858, 16)
# [0.049504843918191606]
# (1907, 16)
# [0.04928683796539066]
# (1893, 16)
# [0.048943475964078186]
# (1872, 16)
# [0.04985042735042735]
# (1894, 16)
# [0.04952481520591341]
# (1871, 16)
# [0.04926242650988776]
# (1821, 16)
# [0.04907742998352554]
# (1944, 16)
# [0.04969135802469136]
# (1857, 16)
# [0.04979536887452881]
# (1908, 16)
# [0.0490041928721174]
# (1918, 16)
# [0.04936392075078207]
# (1847, 16)
# [0.04942609637249594]
# (1875, 16)
# [0.04880533333333334]
# (1890, 16)
# [0.04997883597883598]
# (1850, 16)
# [0.049151351351351354]
# (1915, 16)
# [0.04962924281984334]
# (1862, 16)
# [0.0489795918367347]
# (1903, 16)
# [0.04980031529164477]
# (1854, 16)
# [0.049417475728155344]
# (1911, 16)
# [0.04937205651491366]
# (1883, 16)
# [0.0506372809346787]
# (1882, 16)
# [0.0481509032943677]
# (1875, 16)
# [0.048981333333333335]
# (1890, 16)
# [0.0498042328042328]
# (1889, 16)
# [0.049650608787718375]
# (1876, 16)
# [0.04913646055437101]
# (1836, 16)
# [0.04927559912854031]
# (1929, 16)
# [0.04950751684810783]
# (1908, 16)
# [0.049732704402515725]
# (1857, 16)
# [0.04904684975767366]
# (1894, 16)
# [0.04855860612460401]
# (1871, 16)
# [0.05024051309460182]
# (1892, 16)
# [0.05017441860465117]
# (1873, 16)
# [0.04860651361452216]
# (1871, 16)
# [0.04940673436664885]
# (1894, 16)
# [0.04938225976768743]
# (1914, 16)
# [0.04969174503657262]
# (1851, 16)
# [0.04908698001080497]
# (1870, 16)
# [0.05018181818181818]
# (1895, 16)
# [0.04861741424802111]
# (1855, 16)
# [0.04853908355795149]
# (1910, 16)
# [0.05022513089005236]
# (1934, 16)
# [0.04981385729058945]
# (1831, 16)
# [0.048951392681594756]
# (1837, 16)
# [0.04909635274904736]
# (1928, 16)
# [0.04967842323651452]
# (1874, 16)
# [0.049300960512273215]
# (1891, 16)
# [0.04948704389212057]
# (1905, 16)
# [0.04813648293963255]
# (1860, 16)
# [0.050682795698924726]
# (1892, 16)
# [0.050047568710359404]
# (1873, 16)
# [0.048734650293646556]
# ...
# Chosen Sample [0.05007523]
# Chosen Sample [0.04957663]
# Chosen Sample [0.04950321]
# Chosen Sample [0.04907216]
# Chosen Sample [0.04978992]
# Chosen Sample [0.04863589]
# Chosen Sample [0.04852011]
# Chosen Sample [0.049931]
# Chosen Sample [0.04901568]
# Chosen Sample [0.04910263]
# Chosen Sample [0.04996815]
# Chosen Sample [0.04929788]
# Chosen Sample [0.04864894]
# Chosen Sample [0.04950396]
# Chosen Sample [0.05008104]
# Chosen Sample [0.0489008]
# Chosen Sample [0.04917071]
# Chosen Sample [0.04865608]
# Chosen Sample [0.04934771]
# Chosen Sample [0.0487114]
# Chosen Sample [0.04892259]
# Chosen Sample [0.04953093]
# Chosen Sample [0.04962005]
# Chosen Sample [0.04929437]
# Chosen Sample [0.04913204]
# Chosen Sample [0.04837109]
# Chosen Sample [0.04925254]
# Chosen Sample [0.04964072]
# Chosen Sample [0.04928956]
# Chosen Sample [0.04860302]
# Chosen Sample [0.05022392]
# Chosen Sample [0.04966341]
# Chosen Sample [0.04941768]
# Chosen Sample [0.04937859]
# Chosen Sample [0.0496269]
# Chosen Sample [0.0498722]
# Chosen Sample [0.04941793]
# Chosen Sample [0.0492168]
# Chosen Sample [0.04924258]
# Chosen Sample [0.04962165]
# Chosen Sample [0.0486987]
# Chosen Sample [0.04986207]
# Chosen Sample [0.04854497]
# Chosen Sample [0.04945013]
# Chosen Sample [0.04919653]
# Chosen Sample [0.0486991]
# Chosen Sample [0.05052938]
# Chosen Sample [0.04933226]
# Chosen Sample [0.04973992]
# Chosen Sample [0.05051323]
# Chosen Sample [0.04916973]
# Chosen Sample [0.04847614]
# Chosen Sample [0.0490574]
# Chosen Sample [0.04997952]
# Chosen Sample [0.04935688]
# Chosen Sample [0.04970276]
# Chosen Sample [0.04956793]
# Chosen Sample [0.04991914]
# Chosen Sample [0.04855941]
# Chosen Sample [0.04898466]
# Chosen Sample [0.04945513]
# Chosen Sample [0.04902151]
# Chosen Sample [0.0494833]
# Chosen Sample [0.04872845]
# Chosen Sample [0.04961538]
# Chosen Sample [0.05014981]
# Chosen Sample [0.04959388]
# Chosen Sample [0.04955882]
# Chosen Sample [0.04936]
# Chosen Sample [0.04963298]
# Chosen Sample [0.04909526]
# Chosen Sample [0.04920406]
# Chosen Sample [0.04989057]
# Chosen Sample [0.04883646]
# Chosen Sample [0.04940338]
# Chosen Sample [0.04901283]
# Chosen Sample [0.04950917]
# Chosen Sample [0.04927039]
# Chosen Sample [0.04928108]
# Chosen Sample [0.04910208]
# Chosen Sample [0.04946162]
# Chosen Sample [0.04975954]
# Chosen Sample [0.04931694]
# Chosen Sample [0.04948894]
# Chosen Sample [0.04905447]
# Chosen Sample [0.04946089]
# Chosen Sample [0.04920207]
# Chosen Sample [0.04976229]
# Chosen Sample [0.05018008]
# Chosen Sample [0.04950828]
# Chosen Sample [0.04930184]
# Chosen Sample [0.04924138]
# Chosen Sample [0.04984558]
# Chosen Sample [0.04862992]
# Chosen Sample [0.04923398]
# Chosen Sample [0.04888709]
# Chosen Sample [0.04959012]
# Chosen Sample [0.04933835]
# Chosen Sample [0.04885892]
# Chosen Sample [0.04901491]
# Chosen Sample [0.04950439]
# Chosen Sample [0.05034202]
# Chosen Sample [0.04927937]
# Chosen Sample [0.04966925]
# Chosen Sample [0.04994168]
# Chosen Sample [0.049197]
# Chosen Sample [0.04981142]
# Chosen Sample [0.04901552]
# Chosen Sample [0.04960063]
# Chosen Sample [0.0502989]
# Chosen Sample [0.04973073]
# Chosen Sample [0.04815306]
# Chosen Sample [0.04968323]
# Chosen Sample [0.04920856]
# Chosen Sample [0.0495539]
# Chosen Sample [0.04947774]
# Chosen Sample [0.04925629]
# Chosen Sample [0.0490855]
# Chosen Sample [0.04917509]
# Chosen Sample [0.04944298]
# Chosen Sample [0.05027258]
# Chosen Sample [0.04942349]
# Chosen Sample [0.04982777]
# Chosen Sample [0.04889305]
# Chosen Sample [0.05015135]
# Chosen Sample [0.04934252]
# Chosen Sample [0.04995769]
# Chosen Sample [0.04924816]
# Chosen Sample [0.0499582]
# Chosen Sample [0.05006336]
# Chosen Sample [0.04903069]
# Chosen Sample [0.04983871]
# Chosen Sample [0.04926919]
# Chosen Sample [0.04908174]
# Chosen Sample [0.04888172]
# Chosen Sample [0.04916894]
# Chosen Sample [0.04925119]
# Chosen Sample [0.04882604]
# Chosen Sample [0.04945846]
# Chosen Sample [0.04934365]
# Chosen Sample [0.04857219]
# Chosen Sample [0.04915605]
# Chosen Sample [0.04909091]
# Chosen Sample [0.04934995]
# Chosen Sample [0.04946504]
# Chosen Sample [0.04904343]
# Chosen Sample [0.04962371]
# Chosen Sample [0.0492705]
# Chosen Sample [0.04919747]
# Chosen Sample [0.04972043]
# Chosen Sample [0.0497303]
# Chosen Sample [0.04902373]
# Chosen Sample [0.04988304]
# Chosen Sample [0.0505252]
# Chosen Sample [0.04876517]
# Chosen Sample [0.04895361]
# Chosen Sample [0.04854201]
# Chosen Sample [0.04967505]
# Chosen Sample [0.04966667]
# Chosen Sample [0.0483847]
# Chosen Sample [0.0491056]
# Chosen Sample [0.04971368]
# Chosen Sample [0.04943248]
# Chosen Sample [0.05000522]
# Chosen Sample [0.04925373]
# Chosen Sample [0.04832345]
# Chosen Sample [0.04922764]
# Chosen Sample [0.04963646]
# Chosen Sample [0.0491358]
# Chosen Sample [0.04963138]
# Chosen Sample [0.04932339]
# Chosen Sample [0.04946429]
# Chosen Sample [0.04936392]
# Chosen Sample [0.04836735]
# Chosen Sample [0.04947009]
# Chosen Sample [0.0500958]
# Chosen Sample [0.05013963]
# Chosen Sample [0.05008835]
# Chosen Sample [0.04939394]
# Chosen Sample [0.04874546]
# Chosen Sample [0.0493194]
# Chosen Sample [0.04922591]
# Chosen Sample [0.04917266]
# Chosen Sample [0.04897275]
# Chosen Sample [0.05055937]
# Chosen Sample [0.04899262]
# Chosen Sample [0.04947977]
# Chosen Sample [0.04863589]
# Chosen Sample [0.04871726]
# Chosen Sample [0.04960279]
# Chosen Sample [0.04954594]
# Chosen Sample [0.05015642]
# Chosen Sample [0.04972646]
# Chosen Sample [0.04967522]
# Chosen Sample [0.04959324]
# Chosen Sample [0.04861021]
# Chosen Sample [0.04983307]
# Chosen Sample [0.04951983]
# Chosen Sample [0.04939989]
# Chosen Sample [0.04925117]
# Chosen Sample [0.04954211]
# Chosen Sample [0.04924258]
# Chosen Sample [0.05031987]
# Chosen Sample [0.04948192]
# Chosen Sample [0.04893178]
# Chosen Sample [0.04856449]
# Chosen Sample [0.05068071]
# Chosen Sample [0.04896354]
# Chosen Sample [0.04957151]
# Chosen Sample [0.04927584]
# Chosen Sample [0.04853425]
# Chosen Sample [0.0496413]
# Chosen Sample [0.04917895]
# Chosen Sample [0.04918367]
# Chosen Sample [0.04892501]
# Chosen Sample [0.05036683]
# Chosen Sample [0.04867444]
# Chosen Sample [0.04982447]
# Chosen Sample [0.04894065]
# Chosen Sample [0.04998387]
# Chosen Sample [0.04923119]
# Chosen Sample [0.04938172]
# Chosen Sample [0.04942256]
# Chosen Sample [0.04943975]
# Chosen Sample [0.05031234]
# Chosen Sample [0.04883485]
# Chosen Sample [0.04935553]
# Chosen Sample [0.04840508]
# Chosen Sample [0.04884861]
# Chosen Sample [0.04858031]
# Chosen Sample [0.04993531]
# Chosen Sample [0.04997912]
# Chosen Sample [0.04950649]
# Chosen Sample [0.04938478]
# Chosen Sample [0.05007684]
# Chosen Sample [0.04928915]
# Chosen Sample [0.05008104]
# Chosen Sample [0.04939637]
# Chosen Sample [0.04866905]
# Chosen Sample [0.04961746]
# Chosen Sample [0.04982768]
# Chosen Sample [0.04927263]
# Chosen Sample [0.05011727]
# Chosen Sample [0.04943305]
# Chosen Sample [0.04901887]
# Chosen Sample [0.04849783]
# Chosen Sample [0.04951639]
# Chosen Sample [0.05001616]
# Chosen Sample [0.04991896]
# Chosen Sample [0.04789859]
# Chosen Sample [0.0490099]
# Chosen Sample [0.05013096]
# Chosen Sample [0.04922028]
# Chosen Sample [0.04926715]
# Chosen Sample [0.04961857]
# Chosen Sample [0.05007396]
# Chosen Sample [0.04984009]
# Chosen Sample [0.04952508]
# Chosen Sample [0.04957288]
# Chosen Sample [0.04899033]
# Chosen Sample [0.04853235]
# Chosen Sample [0.04945513]
# Chosen Sample [0.04893753]
# Chosen Sample [0.05011188]
# Chosen Sample [0.0489267]
# Chosen Sample [0.04937633]
# Chosen Sample [0.04989779]
# Chosen Sample [0.04955603]
# Chosen Sample [0.04905851]
# Chosen Sample [0.04982712]
# Chosen Sample [0.04908992]
# Chosen Sample [0.05061538]
# Chosen Sample [0.04860136]
# Chosen Sample [0.0491192]
# Chosen Sample [0.04844121]
# Chosen Sample [0.0499307]
# Chosen Sample [0.04888403]
# Chosen Sample [0.04947016]
# Chosen Sample [0.04966263]
# Chosen Sample [0.04961317]
# Chosen Sample [0.05012359]
# Chosen Sample [0.05019989]
# Chosen Sample [0.04948176]
# Chosen Sample [0.05021053]
# Chosen Sample [0.04991636]
# Chosen Sample [0.04956635]
# Chosen Sample [0.04882869]
# Chosen Sample [0.04939845]
# Chosen Sample [0.05002672]
# Chosen Sample [0.0498687]
# Chosen Sample [0.04901188]
# Chosen Sample [0.04942918]
# Chosen Sample [0.04963855]
# Chosen Sample [0.04868449]
# Chosen Sample [0.04978295]
# Chosen Sample [0.04910367]
# Chosen Sample [0.0495279]
# Chosen Sample [0.04989435]
# Chosen Sample [0.04928186]
# Chosen Sample [0.04864258]
# Chosen Sample [0.04956452]
# Chosen Sample [0.04941423]
# Chosen Sample [0.04911134]
# Chosen Sample [0.04987628]
# Chosen Sample [0.04935707]
# Chosen Sample [0.05001048]
# Chosen Sample [0.04913904]
# Chosen Sample [0.04932095]
# Chosen Sample [0.04929787]
# Chosen Sample [0.04859668]
# Chosen Sample [0.04920813]
# Chosen Sample [0.04944594]
# Chosen Sample [0.04906151]
# Chosen Sample [0.049792]
# Chosen Sample [0.04926715]
# Chosen Sample [0.04926447]
# Chosen Sample [0.0495566]
# Chosen Sample [0.05046258]
# Chosen Sample [0.05014136]
# Chosen Sample [0.04879683]
# Chosen Sample [0.0488707]
# Chosen Sample [0.05050341]
# Chosen Sample [0.04851533]
# Chosen Sample [0.04867336]
# Chosen Sample [0.04935396]
# Chosen Sample [0.04781364]
# Chosen Sample [0.04942964]
# Chosen Sample [0.04974238]
# Chosen Sample [0.04956476]
# Chosen Sample [0.04983914]
# Chosen Sample [0.04896226]
# Chosen Sample [0.04920166]
# Chosen Sample [0.04953575]
# Chosen Sample [0.0494382]
# Chosen Sample [0.04889366]
# Chosen Sample [0.04971185]
# Chosen Sample [0.04937768]
# Chosen Sample [0.05016066]
# Chosen Sample [0.04876338]
# Chosen Sample [0.04971101]
# Chosen Sample [0.04982933]
# Chosen Sample [0.04890021]
# Chosen Sample [0.04943506]
# Chosen Sample [0.05031579]
# Chosen Sample [0.04963131]
# Chosen Sample [0.04968288]
# Chosen Sample [0.04927072]
# Chosen Sample [0.04878788]
# Chosen Sample [0.05044015]
# Chosen Sample [0.04888946]
# Chosen Sample [0.04931628]
# Chosen Sample [0.04949314]
# Chosen Sample [0.04973485]
# Chosen Sample [0.04937601]
# Chosen Sample [0.0496318]
# Chosen Sample [0.04917946]
# Chosen Sample [0.04966809]
# Chosen Sample [0.04866948]
# Chosen Sample [0.04945464]
# Chosen Sample [0.04890511]
# Chosen Sample [0.04917874]
# Chosen Sample [0.04961018]
# Chosen Sample [0.04915757]
# Chosen Sample [0.0498761]
# Chosen Sample [0.04889186]
# Chosen Sample [0.04869565]
# Chosen Sample [0.04837823]
# Chosen Sample [0.04969953]
# Chosen Sample [0.05028191]
# Chosen Sample [0.04953512]
# Chosen Sample [0.04917852]
# Chosen Sample [0.04947311]
# Chosen Sample [0.04946612]
# Chosen Sample [0.04992303]
# Chosen Sample [0.0501877]
# Chosen Sample [0.04949244]
# Chosen Sample [0.04966251]
# Chosen Sample [0.04858133]
# Chosen Sample [0.04998912]
# Chosen Sample [0.0493733]
# Chosen Sample [0.04931286]
# Chosen Sample [0.04932844]
# Chosen Sample [0.04848404]
# Chosen Sample [0.04908511]
# Chosen Sample [0.0501016]
# Chosen Sample [0.04929255]
# Chosen Sample [0.04959958]
# Chosen Sample [0.04924031]
# Chosen Sample [0.05019776]
# Chosen Sample [0.05075869]
# Chosen Sample [0.04892857]
# Chosen Sample [0.04836735]
# Chosen Sample [0.04875264]
# Chosen Sample [0.0491027]
# Chosen Sample [0.04930037]
# Chosen Sample [0.04977079]
# Chosen Sample [0.0495046]
# Chosen Sample [0.04918933]
# Chosen Sample [0.0495524]
# Chosen Sample [0.04845093]
# Chosen Sample [0.04987772]
# Chosen Sample [0.04927975]
# Chosen Sample [0.05023745]
# Chosen Sample [0.04956592]
# Chosen Sample [0.0490099]
# Chosen Sample [0.04898755]
# Chosen Sample [0.04985317]
# Chosen Sample [0.04946502]
# Chosen Sample [0.0489267]
# Chosen Sample [0.04844727]
# Chosen Sample [0.04895901]
# Chosen Sample [0.04924549]
# Chosen Sample [0.04987214]
# Chosen Sample [0.04892291]
# Chosen Sample [0.05016222]
# Chosen Sample [0.04879639]
# Chosen Sample [0.04960519]
# Chosen Sample [0.05026096]
# Chosen Sample [0.05010085]
# Chosen Sample [0.04902636]
# Chosen Sample [0.049235]
# Chosen Sample [0.05006767]
# Chosen Sample [0.04847283]
# Chosen Sample [0.0494509]
# Chosen Sample [0.04995285]
# Chosen Sample [0.04961991]
# Chosen Sample [0.04994161]
# Chosen Sample [0.05022281]
# Chosen Sample [0.05051323]
# Chosen Sample [0.04948798]
# Chosen Sample [0.04912059]
# Chosen Sample [0.04869403]
# Chosen Sample [0.04930818]
# Chosen Sample [0.04941456]
# Chosen Sample [0.04942918]
# Chosen Sample [0.04827549]
# Chosen Sample [0.05012101]
# Chosen Sample [0.04849236]
# Chosen Sample [0.049688]
# Chosen Sample [0.04987701]
# Chosen Sample [0.04874295]
# Chosen Sample [0.04864407]
# Chosen Sample [0.04926238]
# Chosen Sample [0.04916977]
# Chosen Sample [0.05056197]
# Chosen Sample [0.04930233]
# Chosen Sample [0.04926586]
# Chosen Sample [0.04966898]
# Chosen Sample [0.04937567]
# Chosen Sample [0.04881551]
# Chosen Sample [0.05010526]
# Chosen Sample [0.04932672]
# Chosen Sample [0.04861546]
# Chosen Sample [0.04941084]
# Chosen Sample [0.04978136]
# Chosen Sample [0.04890186]
# Chosen Sample [0.04968321]
# Chosen Sample [0.04997416]
# Chosen Sample [0.04904146]
# Chosen Sample [0.04928038]
# Chosen Sample [0.04862776]
# Chosen Sample [0.04852381]
# Chosen Sample [0.04934078]
# Chosen Sample [0.05074017]
# Chosen Sample [0.04880022]
# Chosen Sample [0.04910383]
# Chosen Sample [0.04957082]
# Chosen Sample [0.05007299]
# Chosen Sample [0.04930801]
# Chosen Sample [0.04990802]
# Chosen Sample [0.04955232]
# Chosen Sample [0.04919731]
# Chosen Sample [0.0487766]
# Chosen Sample [0.04915828]
# Chosen Sample [0.04956337]
# Chosen Sample [0.04994778]
# Chosen Sample [0.04953301]
# Chosen Sample [0.05010225]
# Chosen Sample [0.04929761]
# Chosen Sample [0.0498722]
# Chosen Sample [0.04983042]
# Chosen Sample [0.04995258]
# Chosen Sample [0.04921975]
# Chosen Sample [0.04979343]
# Chosen Sample [0.04930608]
# Chosen Sample [0.05052798]
# Chosen Sample [0.04912493]
# Chosen Sample [0.04972929]
# Chosen Sample [0.04972574]
# Chosen Sample [0.05038381]
# Chosen Sample [0.0491272]
# Chosen Sample [0.04896624]
# Chosen Sample [0.04913587]
# Chosen Sample [0.0489398]
# Chosen Sample [0.04916146]
# Chosen Sample [0.04968667]
# Chosen Sample [0.04862215]
# Chosen Sample [0.049584]
# Chosen Sample [0.04895901]
# Chosen Sample [0.04971215]
# Chosen Sample [0.05097872]
# Chosen Sample [0.04886631]
# Chosen Sample [0.05014211]
# Chosen Sample [0.04851533]
# Chosen Sample [0.04918302]
# Chosen Sample [0.04844032]
# Chosen Sample [0.05022408]
# Chosen Sample [0.04852742]
# Chosen Sample [0.04908605]
# Chosen Sample [0.04962865]
# Chosen Sample [0.04910304]
# Chosen Sample [0.04881766]
# Chosen Sample [0.04948704]
# Chosen Sample [0.04955757]
# Chosen Sample [0.04911372]
# Chosen Sample [0.04977237]
# Chosen Sample [0.04973985]
# Chosen Sample [0.04945741]
# Chosen Sample [0.04883235]
# Chosen Sample [0.05023707]
# Chosen Sample [0.04974359]
# Chosen Sample [0.05042431]
# Chosen Sample [0.04989583]
# Chosen Sample [0.04949007]
# Chosen Sample [0.04929298]
# Chosen Sample [0.04992809]
# Chosen Sample [0.05006386]
# Chosen Sample [0.04898323]
# Chosen Sample [0.04988127]
# Chosen Sample [0.04934365]
# Chosen Sample [0.04884842]
# Chosen Sample [0.04965104]
# Chosen Sample [0.04993243]
# Chosen Sample [0.04940226]
# Chosen Sample [0.04888478]
# Chosen Sample [0.05028571]
# Chosen Sample [0.04974033]
# Chosen Sample [0.04925985]
# Chosen Sample [0.04964985]
# Chosen Sample [0.04957822]
# Chosen Sample [0.04980129]
# Chosen Sample [0.04914225]
# Chosen Sample [0.04939121]
# Chosen Sample [0.04930343]
# Chosen Sample [0.04921025]
# Chosen Sample [0.04903775]
# Chosen Sample [0.04995233]
# Chosen Sample [0.04980649]
# Chosen Sample [0.04968683]
# Chosen Sample [0.0495664]
# Chosen Sample [0.04946476]
# Chosen Sample [0.04953575]
# Chosen Sample [0.04966492]
# Chosen Sample [0.04966898]
# Chosen Sample [0.04940235]
# Chosen Sample [0.04944271]
# Chosen Sample [0.05025068]
# Chosen Sample [0.04887574]
# Chosen Sample [0.05016]
# Chosen Sample [0.04948925]
# Chosen Sample [0.04845093]
# Chosen Sample [0.04958053]
# Chosen Sample [0.04944824]
# Chosen Sample [0.0496176]
# Chosen Sample [0.04839558]
# Chosen Sample [0.04933012]
# Chosen Sample [0.04857678]
# Chosen Sample [0.04882017]
# Chosen Sample [0.04976903]
# Chosen Sample [0.04997866]
# Chosen Sample [0.04945079]
# Chosen Sample [0.04904711]
# Chosen Sample [0.04860302]
# Chosen Sample [0.04861154]
# Chosen Sample [0.04965222]
# Chosen Sample [0.04976]
# Chosen Sample [0.04892445]
# Chosen Sample [0.05021972]
# Chosen Sample [0.04965861]
# Chosen Sample [0.04910011]
# Chosen Sample [0.04881861]
# Chosen Sample [0.04973115]
# Chosen Sample [0.04797192]
# Chosen Sample [0.04983307]
# Chosen Sample [0.04945571]
# Chosen Sample [0.04909635]
# Chosen Sample [0.05022392]
# Chosen Sample [0.04958967]
# Chosen Sample [0.04986814]
# Chosen Sample [0.049631]
# Chosen Sample [0.04907169]
# Chosen Sample [0.04957663]
# Chosen Sample [0.04936942]
# Chosen Sample [0.04924409]
# Chosen Sample [0.04935518]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                     scale           chosen_sample  \
# 0  0.001248  [2.7984888863033976e-06]  [0.050091103820395326]
# 1  0.001248  [2.7984888863033976e-06]   [0.04994352348447912]
# 2  0.001248  [2.7984888863033976e-06]  [0.050182765498432855]
# 3  0.001248  [2.7984888863033976e-06]   [0.05011825922421949]
# 4  0.001248  [2.7984888863033976e-06]   [0.05022861626286812]
#
#                chosen_noise                release
# 0  [0.00019151147429915532]  [0.05028261529469448]
# 1    [0.003780693960025043]  [0.05372421744450416]
# 2  [-0.0025108979600565753]  [0.04767186753837628]
# 3   [0.0002050602508476661]  [0.05032331947506716]
# 4    [0.000626789855098385]   [0.0508554061179665]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi     scale chosen_sample chosen_noise   release
# query            avg_disc      avg_disc     avg_disc  avg_disc
# 0      0.001248  0.000003      0.050091     0.000192  0.050283
# 1      0.001248  0.000003      0.049944     0.003781  0.053724
# 2      0.001248  0.000003      0.050183    -0.002511  0.047672
# 3      0.001248  0.000003      0.050118     0.000205  0.050323
# 4      0.001248  0.000003      0.050229     0.000627  0.050855

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step              scale chosen_sample  chosen_noise   release
# query          avg_disc      avg_disc      avg_disc  avg_disc
# mi
# 0.001248   2.798489e-06      0.050140 -3.949555e-05  0.050101
# 0.015625   2.235780e-07      0.050146  2.171030e-05  0.050167
# 0.031250   1.117890e-07      0.050142 -1.424358e-05  0.050128
# 0.062500   5.589449e-08      0.050141  6.706987e-07  0.050142
# 0.250000   1.397362e-08      0.050148 -3.901462e-06  0.050144
# 1.000000   3.493406e-09      0.050146 -3.372387e-06  0.050143
# 2.000000   1.746703e-09      0.050149  2.057637e-06  0.050151
# 4.000000   8.733515e-10      0.050148  1.912063e-06  0.050150
# 16.000000  2.183379e-10      0.050142  4.961377e-08  0.050142

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['avg_disc'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi          0.001248
# avg_disc    0.050283
# Name: 0, dtype: float64
# mi          0.001248
# avg_disc    0.053724
# Name: 1, dtype: float64
# mi          0.001248
# avg_disc    0.047672
# Name: 2, dtype: float64
# mi          0.001248
# avg_disc    0.050323
# Name: 3, dtype: float64
# mi          0.001248
# avg_disc    0.050855
# Name: 4, dtype: float64
# mi          0.001248
# avg_disc    0.050395
# Name: 5, dtype: float64
# mi          0.001248
# avg_disc    0.049721
# Name: 6, dtype: float64
# mi          0.001248
# avg_disc    0.051235
# Name: 7, dtype: float64
# mi          0.001248
# avg_disc    0.053166
# Name: 8, dtype: float64
# mi          0.001248
# avg_disc    0.048485
# Name: 9, dtype: float64
# mi          0.001248
# avg_disc    0.049570
# Name: 10, dtype: float64
# mi          0.001248
# avg_disc    0.047847
# Name: 11, dtype: float64
# mi          0.001248
# avg_disc    0.049332
# Name: 12, dtype: float64
# mi          0.001248
# avg_disc    0.050795
# Name: 13, dtype: float64
# mi          0.001248
# avg_disc    0.049700
# Name: 14, dtype: float64
# mi          0.001248
# avg_disc    0.050806
# Name: 15, dtype: float64
# mi          0.001248
# avg_disc    0.053283
# Name: 16, dtype: float64
# mi          0.001248
# avg_disc    0.050184
# Name: 17, dtype: float64
# mi          0.001248
# avg_disc    0.050446
# Name: 18, dtype: float64
# mi          0.001248
# avg_disc    0.050201
# Name: 19, dtype: float64
# mi          0.001248
# avg_disc    0.052187
# Name: 20, dtype: float64
# mi          0.001248
# avg_disc    0.048407
# Name: 21, dtype: float64
# mi          0.001248
# avg_disc    0.045238
# Name: 22, dtype: float64
# mi          0.001248
# avg_disc    0.051693
# Name: 23, dtype: float64
# mi          0.001248
# avg_disc    0.049679
# Name: 24, dtype: float64
# mi          0.001248
# avg_disc    0.049946
# Name: 25, dtype: float64
# mi          0.001248
# avg_disc    0.050512
# Name: 26, dtype: float64
# mi          0.001248
# avg_disc    0.047656
# Name: 27, dtype: float64
# mi          0.001248
# avg_disc    0.052131
# Name: 28, dtype: float64
# mi          0.001248
# avg_disc    0.049867
# Name: 29, dtype: float64
# mi          0.001248
# avg_disc    0.047579
# Name: 30, dtype: float64
# mi          0.001248
# avg_disc    0.048937
# Name: 31, dtype: float64
# mi          0.001248
# avg_disc    0.046895
# Name: 32, dtype: float64
# mi          0.001248
# avg_disc    0.047028
# Name: 33, dtype: float64
# mi          0.001248
# avg_disc    0.047921
# Name: 34, dtype: float64
# mi          0.001248
# avg_disc    0.048846
# Name: 35, dtype: float64
# mi          0.001248
# avg_disc    0.049297
# Name: 36, dtype: float64
# mi          0.001248
# avg_disc    0.049212
# Name: 37, dtype: float64
# mi          0.001248
# avg_disc    0.049191
# Name: 38, dtype: float64
# mi          0.001248
# avg_disc    0.049831
# Name: 39, dtype: float64
# mi          0.001248
# avg_disc    0.050960
# Name: 40, dtype: float64
# mi          0.001248
# avg_disc    0.053234
# Name: 41, dtype: float64
# mi          0.001248
# avg_disc    0.051058
# Name: 42, dtype: float64
# mi          0.001248
# avg_disc    0.048392
# Name: 43, dtype: float64
# mi          0.001248
# avg_disc    0.051517
# Name: 44, dtype: float64
# mi          0.001248
# avg_disc    0.052238
# Name: 45, dtype: float64
# mi          0.001248
# avg_disc    0.051375
# Name: 46, dtype: float64
# mi          0.001248
# avg_disc    0.051511
# Name: 47, dtype: float64
# mi          0.001248
# avg_disc    0.049530
# Name: 48, dtype: float64
# mi          0.001248
# avg_disc    0.049748
# Name: 49, dtype: float64
# mi          0.001248
# avg_disc    0.047753
# Name: 50, dtype: float64
# mi          0.001248
# avg_disc    0.049260
# Name: 51, dtype: float64
# mi          0.001248
# avg_disc    0.051924
# Name: 52, dtype: float64
# mi          0.001248
# avg_disc    0.049472
# Name: 53, dtype: float64
# mi          0.001248
# avg_disc    0.049814
# Name: 54, dtype: float64
# mi          0.001248
# avg_disc    0.047892
# Name: 55, dtype: float64
# mi          0.001248
# avg_disc    0.050509
# Name: 56, dtype: float64
# mi          0.001248
# avg_disc    0.053062
# Name: 57, dtype: float64
# mi          0.001248
# avg_disc    0.047964
# Name: 58, dtype: float64
# mi          0.001248
# avg_disc    0.050735
# Name: 59, dtype: float64
# mi          0.001248
# avg_disc    0.049832
# Name: 60, dtype: float64
# mi          0.001248
# avg_disc    0.050772
# Name: 61, dtype: float64
# mi          0.001248
# avg_disc    0.047435
# Name: 62, dtype: float64
# mi          0.001248
# avg_disc    0.048796
# Name: 63, dtype: float64
# mi          0.001248
# avg_disc    0.050875
# Name: 64, dtype: float64
# mi          0.001248
# avg_disc    0.051744
# Name: 65, dtype: float64
# mi          0.001248
# avg_disc    0.049397
# Name: 66, dtype: float64
# mi          0.001248
# avg_disc    0.052170
# Name: 67, dtype: float64
# mi          0.001248
# avg_disc    0.051270
# Name: 68, dtype: float64
# mi          0.001248
# avg_disc    0.049153
# Name: 69, dtype: float64
# mi          0.001248
# avg_disc    0.051254
# Name: 70, dtype: float64
# mi          0.001248
# avg_disc    0.051560
# Name: 71, dtype: float64
# mi          0.001248
# avg_disc    0.050286
# Name: 72, dtype: float64
# mi          0.001248
# avg_disc    0.050069
# Name: 73, dtype: float64
# mi          0.001248
# avg_disc    0.049342
# Name: 74, dtype: float64
# mi          0.001248
# avg_disc    0.048363
# Name: 75, dtype: float64
# mi          0.001248
# avg_disc    0.053048
# Name: 76, dtype: float64
# mi          0.001248
# avg_disc    0.045275
# Name: 77, dtype: float64
# mi          0.001248
# avg_disc    0.048184
# Name: 78, dtype: float64
# mi          0.001248
# avg_disc    0.048666
# Name: 79, dtype: float64
# mi          0.001248
# avg_disc    0.052199
# Name: 80, dtype: float64
# mi          0.001248
# avg_disc    0.052154
# Name: 81, dtype: float64
# mi          0.001248
# avg_disc    0.051757
# Name: 82, dtype: float64
# mi          0.001248
# avg_disc    0.052625
# Name: 83, dtype: float64
# mi          0.001248
# avg_disc    0.049924
# Name: 84, dtype: float64
# mi          0.001248
# avg_disc    0.052822
# Name: 85, dtype: float64
# mi          0.001248
# avg_disc    0.052676
# Name: 86, dtype: float64
# mi          0.001248
# avg_disc    0.050464
# Name: 87, dtype: float64
# mi          0.001248
# avg_disc    0.048687
# Name: 88, dtype: float64
# mi          0.001248
# avg_disc    0.052492
# Name: 89, dtype: float64
# mi          0.001248
# avg_disc    0.050740
# Name: 90, dtype: float64
# mi          0.001248
# avg_disc    0.053780
# Name: 91, dtype: float64
# mi          0.001248
# avg_disc    0.052050
# Name: 92, dtype: float64
# mi          0.001248
# avg_disc    0.048251
# Name: 93, dtype: float64
# mi          0.001248
# avg_disc    0.052508
# Name: 94, dtype: float64
# mi          0.001248
# avg_disc    0.046054
# Name: 95, dtype: float64
# mi          0.001248
# avg_disc    0.049668
# Name: 96, dtype: float64
# mi          0.001248
# avg_disc    0.051739
# Name: 97, dtype: float64
# mi          0.001248
# avg_disc    0.051059
# Name: 98, dtype: float64
# mi          0.001248
# avg_disc    0.050408
# Name: 99, dtype: float64
# mi          0.001248
# avg_disc    0.050875
# Name: 100, dtype: float64
# mi          0.001248
# avg_disc    0.049478
# Name: 101, dtype: float64
# mi          0.001248
# avg_disc    0.049650
# Name: 102, dtype: float64
# mi          0.001248
# avg_disc    0.052675
# Name: 103, dtype: float64
# mi          0.001248
# avg_disc    0.051575
# Name: 104, dtype: float64
# mi          0.001248
# avg_disc    0.054974
# Name: 105, dtype: float64
# mi          0.001248
# avg_disc    0.046503
# Name: 106, dtype: float64
# mi          0.001248
# avg_disc    0.050035
# Name: 107, dtype: float64
# mi          0.001248
# avg_disc    0.047730
# Name: 108, dtype: float64
# mi          0.001248
# avg_disc    0.046785
# Name: 109, dtype: float64
# mi          0.001248
# avg_disc    0.051430
# Name: 110, dtype: float64
# mi          0.001248
# avg_disc    0.050050
# Name: 111, dtype: float64
# mi          0.001248
# avg_disc    0.048175
# Name: 112, dtype: float64
# mi          0.001248
# avg_disc    0.049041
# Name: 113, dtype: float64
# mi          0.001248
# avg_disc    0.052936
# Name: 114, dtype: float64
# mi          0.001248
# avg_disc    0.047495
# Name: 115, dtype: float64
# mi          0.001248
# avg_disc    0.051733
# Name: 116, dtype: float64
# mi          0.001248
# avg_disc    0.050524
# Name: 117, dtype: float64
# mi          0.001248
# avg_disc    0.050673
# Name: 118, dtype: float64
# mi          0.001248
# avg_disc    0.052285
# Name: 119, dtype: float64
# mi          0.001248
# avg_disc    0.052241
# Name: 120, dtype: float64
# mi          0.001248
# avg_disc    0.049688
# Name: 121, dtype: float64
# mi          0.001248
# avg_disc    0.047694
# Name: 122, dtype: float64
# mi          0.001248
# avg_disc    0.050298
# Name: 123, dtype: float64
# mi          0.001248
# avg_disc    0.050991
# Name: 124, dtype: float64
# mi          0.001248
# avg_disc    0.052379
# Name: 125, dtype: float64
# mi          0.001248
# avg_disc    0.047549
# Name: 126, dtype: float64
# mi          0.001248
# avg_disc    0.052253
# Name: 127, dtype: float64
# mi          0.001248
# avg_disc    0.048633
# Name: 128, dtype: float64
# mi          0.001248
# avg_disc    0.051056
# Name: 129, dtype: float64
# mi          0.001248
# avg_disc    0.050430
# Name: 130, dtype: float64
# mi          0.001248
# avg_disc    0.051203
# Name: 131, dtype: float64
# mi          0.001248
# avg_disc    0.046515
# Name: 132, dtype: float64
# mi          0.001248
# avg_disc    0.051170
# Name: 133, dtype: float64
# mi          0.001248
# avg_disc    0.050010
# Name: 134, dtype: float64
# mi          0.001248
# avg_disc    0.049349
# Name: 135, dtype: float64
# mi          0.001248
# avg_disc    0.049195
# Name: 136, dtype: float64
# mi          0.001248
# avg_disc    0.050114
# Name: 137, dtype: float64
# mi          0.001248
# avg_disc    0.047244
# Name: 138, dtype: float64
# mi          0.001248
# avg_disc    0.047991
# Name: 139, dtype: float64
# mi          0.001248
# avg_disc    0.049353
# Name: 140, dtype: float64
# mi          0.001248
# avg_disc    0.049540
# Name: 141, dtype: float64
# mi          0.001248
# avg_disc    0.049753
# Name: 142, dtype: float64
# mi          0.001248
# avg_disc    0.047299
# Name: 143, dtype: float64
# mi          0.001248
# avg_disc    0.050496
# Name: 144, dtype: float64
# mi          0.001248
# avg_disc    0.052277
# Name: 145, dtype: float64
# mi          0.001248
# avg_disc    0.051391
# Name: 146, dtype: float64
# mi          0.001248
# avg_disc    0.048892
# Name: 147, dtype: float64
# mi          0.001248
# avg_disc    0.048200
# Name: 148, dtype: float64
# mi          0.001248
# avg_disc    0.049439
# Name: 149, dtype: float64
# mi          0.001248
# avg_disc    0.051856
# Name: 150, dtype: float64
# mi          0.001248
# avg_disc    0.050508
# Name: 151, dtype: float64
# mi          0.001248
# avg_disc    0.050536
# Name: 152, dtype: float64
# mi          0.001248
# avg_disc    0.049671
# Name: 153, dtype: float64
# mi          0.001248
# avg_disc    0.049911
# Name: 154, dtype: float64
# mi          0.001248
# avg_disc    0.052592
# Name: 155, dtype: float64
# mi          0.001248
# avg_disc    0.049454
# Name: 156, dtype: float64
# mi          0.001248
# avg_disc    0.048927
# Name: 157, dtype: float64
# mi          0.001248
# avg_disc    0.051772
# Name: 158, dtype: float64
# mi          0.001248
# avg_disc    0.049823
# Name: 159, dtype: float64
# mi          0.001248
# avg_disc    0.047738
# Name: 160, dtype: float64
# mi          0.001248
# avg_disc    0.048288
# Name: 161, dtype: float64
# mi          0.001248
# avg_disc    0.050211
# Name: 162, dtype: float64
# mi          0.001248
# avg_disc    0.047207
# Name: 163, dtype: float64
# mi          0.001248
# avg_disc    0.049748
# Name: 164, dtype: float64
# mi          0.001248
# avg_disc    0.052945
# Name: 165, dtype: float64
# mi          0.001248
# avg_disc    0.048624
# Name: 166, dtype: float64
# mi          0.001248
# avg_disc    0.055877
# Name: 167, dtype: float64
# mi          0.001248
# avg_disc    0.050507
# Name: 168, dtype: float64
# mi          0.001248
# avg_disc    0.048826
# Name: 169, dtype: float64
# mi          0.001248
# avg_disc    0.049211
# Name: 170, dtype: float64
# mi          0.001248
# avg_disc    0.050844
# Name: 171, dtype: float64
# mi          0.001248
# avg_disc    0.048698
# Name: 172, dtype: float64
# mi          0.001248
# avg_disc    0.049362
# Name: 173, dtype: float64
# mi          0.001248
# avg_disc    0.049850
# Name: 174, dtype: float64
# mi          0.001248
# avg_disc    0.050085
# Name: 175, dtype: float64
# mi          0.001248
# avg_disc    0.049624
# Name: 176, dtype: float64
# mi          0.001248
# avg_disc    0.052217
# Name: 177, dtype: float64
# mi          0.001248
# avg_disc    0.048797
# Name: 178, dtype: float64
# mi          0.001248
# avg_disc    0.050395
# Name: 179, dtype: float64
# mi          0.001248
# avg_disc    0.047779
# Name: 180, dtype: float64
# mi          0.001248
# avg_disc    0.051072
# Name: 181, dtype: float64
# mi          0.001248
# avg_disc    0.049698
# Name: 182, dtype: float64
# mi          0.001248
# avg_disc    0.053249
# Name: 183, dtype: float64
# mi          0.001248
# avg_disc    0.053832
# Name: 184, dtype: float64
# mi          0.001248
# avg_disc    0.050847
# Name: 185, dtype: float64
# mi          0.001248
# avg_disc    0.052593
# Name: 186, dtype: float64
# mi          0.001248
# avg_disc    0.047424
# Name: 187, dtype: float64
# mi          0.001248
# avg_disc    0.052128
# Name: 188, dtype: float64
# mi          0.001248
# avg_disc    0.054503
# Name: 189, dtype: float64
# mi          0.001248
# avg_disc    0.048158
# Name: 190, dtype: float64
# mi          0.001248
# avg_disc    0.049495
# Name: 191, dtype: float64
# mi          0.001248
# avg_disc    0.049820
# Name: 192, dtype: float64
# mi          0.001248
# avg_disc    0.046548
# Name: 193, dtype: float64
# mi          0.001248
# avg_disc    0.052012
# Name: 194, dtype: float64
# mi          0.001248
# avg_disc    0.049705
# Name: 195, dtype: float64
# mi          0.001248
# avg_disc    0.050351
# Name: 196, dtype: float64
# mi          0.001248
# avg_disc    0.049507
# Name: 197, dtype: float64
# mi          0.001248
# avg_disc    0.052026
# Name: 198, dtype: float64
# mi          0.001248
# avg_disc    0.047940
# Name: 199, dtype: float64
# mi          0.001248
# avg_disc    0.051846
# Name: 200, dtype: float64
# mi          0.001248
# avg_disc    0.050703
# Name: 201, dtype: float64
# mi          0.001248
# avg_disc    0.050200
# Name: 202, dtype: float64
# mi          0.001248
# avg_disc    0.051772
# Name: 203, dtype: float64
# mi          0.001248
# avg_disc    0.050058
# Name: 204, dtype: float64
# mi          0.001248
# avg_disc    0.052153
# Name: 205, dtype: float64
# mi          0.001248
# avg_disc    0.050011
# Name: 206, dtype: float64
# mi          0.001248
# avg_disc    0.050744
# Name: 207, dtype: float64
# mi          0.001248
# avg_disc    0.051304
# Name: 208, dtype: float64
# mi          0.001248
# avg_disc    0.048692
# Name: 209, dtype: float64
# mi          0.001248
# avg_disc    0.052781
# Name: 210, dtype: float64
# mi          0.001248
# avg_disc    0.049834
# Name: 211, dtype: float64
# mi          0.001248
# avg_disc    0.048928
# Name: 212, dtype: float64
# mi          0.001248
# avg_disc    0.052310
# Name: 213, dtype: float64
# mi          0.001248
# avg_disc    0.047698
# Name: 214, dtype: float64
# mi          0.001248
# avg_disc    0.050269
# Name: 215, dtype: float64
# mi          0.001248
# avg_disc    0.049547
# Name: 216, dtype: float64
# mi          0.001248
# avg_disc    0.050570
# Name: 217, dtype: float64
# mi          0.001248
# avg_disc    0.048071
# Name: 218, dtype: float64
# mi          0.001248
# avg_disc    0.047784
# Name: 219, dtype: float64
# mi          0.001248
# avg_disc    0.051598
# Name: 220, dtype: float64
# mi          0.001248
# avg_disc    0.049000
# Name: 221, dtype: float64
# mi          0.001248
# avg_disc    0.050740
# Name: 222, dtype: float64
# mi          0.001248
# avg_disc    0.048126
# Name: 223, dtype: float64
# mi          0.001248
# avg_disc    0.048244
# Name: 224, dtype: float64
# mi          0.001248
# avg_disc    0.049797
# Name: 225, dtype: float64
# mi          0.001248
# avg_disc    0.050746
# Name: 226, dtype: float64
# mi          0.001248
# avg_disc    0.049956
# Name: 227, dtype: float64
# mi          0.001248
# avg_disc    0.049747
# Name: 228, dtype: float64
# mi          0.001248
# avg_disc    0.050400
# Name: 229, dtype: float64
# mi          0.001248
# avg_disc    0.049395
# Name: 230, dtype: float64
# mi          0.001248
# avg_disc    0.049694
# Name: 231, dtype: float64
# mi          0.001248
# avg_disc    0.049746
# Name: 232, dtype: float64
# mi          0.001248
# avg_disc    0.052560
# Name: 233, dtype: float64
# mi          0.001248
# avg_disc    0.049424
# Name: 234, dtype: float64
# mi          0.001248
# avg_disc    0.054195
# Name: 235, dtype: float64
# mi          0.001248
# avg_disc    0.046430
# Name: 236, dtype: float64
# mi          0.001248
# avg_disc    0.049408
# Name: 237, dtype: float64
# mi          0.001248
# avg_disc    0.048874
# Name: 238, dtype: float64
# mi          0.001248
# avg_disc    0.049426
# Name: 239, dtype: float64
# mi          0.001248
# avg_disc    0.049602
# Name: 240, dtype: float64
# mi          0.001248
# avg_disc    0.050463
# Name: 241, dtype: float64
# mi          0.001248
# avg_disc    0.049849
# Name: 242, dtype: float64
# mi          0.001248
# avg_disc    0.047363
# Name: 243, dtype: float64
# mi          0.001248
# avg_disc    0.050630
# Name: 244, dtype: float64
# mi          0.001248
# avg_disc    0.051624
# Name: 245, dtype: float64
# mi          0.001248
# avg_disc    0.049535
# Name: 246, dtype: float64
# mi          0.001248
# avg_disc    0.051748
# Name: 247, dtype: float64
# mi          0.001248
# avg_disc    0.052104
# Name: 248, dtype: float64
# mi          0.001248
# avg_disc    0.051630
# Name: 249, dtype: float64
# mi          0.001248
# avg_disc    0.050272
# Name: 250, dtype: float64
# mi          0.001248
# avg_disc    0.048539
# Name: 251, dtype: float64
# mi          0.001248
# avg_disc    0.049589
# Name: 252, dtype: float64
# mi          0.001248
# avg_disc    0.048259
# Name: 253, dtype: float64
# mi          0.001248
# avg_disc    0.048731
# Name: 254, dtype: float64
# mi          0.001248
# avg_disc    0.047027
# Name: 255, dtype: float64
# mi          0.001248
# avg_disc    0.049628
# Name: 256, dtype: float64
# mi          0.001248
# avg_disc    0.052084
# Name: 257, dtype: float64
# mi          0.001248
# avg_disc    0.050829
# Name: 258, dtype: float64
# mi          0.001248
# avg_disc    0.049526
# Name: 259, dtype: float64
# mi          0.001248
# avg_disc    0.051611
# Name: 260, dtype: float64
# mi          0.001248
# avg_disc    0.050714
# Name: 261, dtype: float64
# mi          0.001248
# avg_disc    0.053655
# Name: 262, dtype: float64
# mi          0.001248
# avg_disc    0.047525
# Name: 263, dtype: float64
# mi          0.001248
# avg_disc    0.051718
# Name: 264, dtype: float64
# mi          0.001248
# avg_disc    0.048050
# Name: 265, dtype: float64
# mi          0.001248
# avg_disc    0.047790
# Name: 266, dtype: float64
# mi          0.001248
# avg_disc    0.048972
# Name: 267, dtype: float64
# mi          0.001248
# avg_disc    0.050258
# Name: 268, dtype: float64
# mi          0.001248
# avg_disc    0.050860
# Name: 269, dtype: float64
# mi          0.001248
# avg_disc    0.052343
# Name: 270, dtype: float64
# mi          0.001248
# avg_disc    0.048976
# Name: 271, dtype: float64
# mi          0.001248
# avg_disc    0.051172
# Name: 272, dtype: float64
# mi          0.001248
# avg_disc    0.048518
# Name: 273, dtype: float64
# mi          0.001248
# avg_disc    0.052107
# Name: 274, dtype: float64
# mi          0.001248
# avg_disc    0.050043
# Name: 275, dtype: float64
# mi          0.001248
# avg_disc    0.050152
# Name: 276, dtype: float64
# mi          0.001248
# avg_disc    0.050905
# Name: 277, dtype: float64
# mi          0.001248
# avg_disc    0.047750
# Name: 278, dtype: float64
# mi          0.001248
# avg_disc    0.050162
# Name: 279, dtype: float64
# mi          0.001248
# avg_disc    0.052882
# Name: 280, dtype: float64
# mi          0.001248
# avg_disc    0.051367
# Name: 281, dtype: float64
# mi          0.001248
# avg_disc    0.050198
# Name: 282, dtype: float64
# mi          0.001248
# avg_disc    0.048229
# Name: 283, dtype: float64
# mi          0.001248
# avg_disc    0.050675
# Name: 284, dtype: float64
# mi          0.001248
# avg_disc    0.050254
# Name: 285, dtype: float64
# mi          0.001248
# avg_disc    0.049662
# Name: 286, dtype: float64
# mi          0.001248
# avg_disc    0.049763
# Name: 287, dtype: float64
# mi          0.001248
# avg_disc    0.049012
# Name: 288, dtype: float64
# mi          0.001248
# avg_disc    0.049628
# Name: 289, dtype: float64
# mi          0.001248
# avg_disc    0.052423
# Name: 290, dtype: float64
# mi          0.001248
# avg_disc    0.049983
# Name: 291, dtype: float64
# mi          0.001248
# avg_disc    0.050445
# Name: 292, dtype: float64
# mi          0.001248
# avg_disc    0.050124
# Name: 293, dtype: float64
# mi          0.001248
# avg_disc    0.052209
# Name: 294, dtype: float64
# mi          0.001248
# avg_disc    0.048952
# Name: 295, dtype: float64
# mi          0.001248
# avg_disc    0.050350
# Name: 296, dtype: float64
# mi          0.001248
# avg_disc    0.050615
# Name: 297, dtype: float64
# mi          0.001248
# avg_disc    0.048837
# Name: 298, dtype: float64
# mi          0.001248
# avg_disc    0.048252
# Name: 299, dtype: float64
# mi          0.001248
# avg_disc    0.052706
# Name: 300, dtype: float64
# mi          0.001248
# avg_disc    0.049214
# Name: 301, dtype: float64
# mi          0.001248
# avg_disc    0.048198
# Name: 302, dtype: float64
# mi          0.001248
# avg_disc    0.048872
# Name: 303, dtype: float64
# mi          0.001248
# avg_disc    0.050189
# Name: 304, dtype: float64
# mi          0.001248
# avg_disc    0.053962
# Name: 305, dtype: float64
# mi          0.001248
# avg_disc    0.051531
# Name: 306, dtype: float64
# mi          0.001248
# avg_disc    0.052711
# Name: 307, dtype: float64
# mi          0.001248
# avg_disc    0.051131
# Name: 308, dtype: float64
# mi          0.001248
# avg_disc    0.049244
# Name: 309, dtype: float64
# mi          0.001248
# avg_disc    0.050590
# Name: 310, dtype: float64
# mi          0.001248
# avg_disc    0.051705
# Name: 311, dtype: float64
# mi          0.001248
# avg_disc    0.048125
# Name: 312, dtype: float64
# mi          0.001248
# avg_disc    0.050635
# Name: 313, dtype: float64
# mi          0.001248
# avg_disc    0.050220
# Name: 314, dtype: float64
# mi          0.001248
# avg_disc    0.048151
# Name: 315, dtype: float64
# mi          0.001248
# avg_disc    0.050678
# Name: 316, dtype: float64
# mi          0.001248
# avg_disc    0.051207
# Name: 317, dtype: float64
# mi          0.001248
# avg_disc    0.050621
# Name: 318, dtype: float64
# mi          0.001248
# avg_disc    0.047445
# Name: 319, dtype: float64
# mi          0.001248
# avg_disc    0.047630
# Name: 320, dtype: float64
# mi          0.001248
# avg_disc    0.049726
# Name: 321, dtype: float64
# mi          0.001248
# avg_disc    0.052273
# Name: 322, dtype: float64
# mi          0.001248
# avg_disc    0.050844
# Name: 323, dtype: float64
# mi          0.001248
# avg_disc    0.050766
# Name: 324, dtype: float64
# mi          0.001248
# avg_disc    0.048685
# Name: 325, dtype: float64
# mi          0.001248
# avg_disc    0.049682
# Name: 326, dtype: float64
# mi          0.001248
# avg_disc    0.050716
# Name: 327, dtype: float64
# mi          0.001248
# avg_disc    0.048143
# Name: 328, dtype: float64
# mi          0.001248
# avg_disc    0.050883
# Name: 329, dtype: float64
# mi          0.001248
# avg_disc    0.051126
# Name: 330, dtype: float64
# mi          0.001248
# avg_disc    0.049910
# Name: 331, dtype: float64
# mi          0.001248
# avg_disc    0.050637
# Name: 332, dtype: float64
# mi          0.001248
# avg_disc    0.049977
# Name: 333, dtype: float64
# mi          0.001248
# avg_disc    0.047035
# Name: 334, dtype: float64
# mi          0.001248
# avg_disc    0.049383
# Name: 335, dtype: float64
# mi          0.001248
# avg_disc    0.049587
# Name: 336, dtype: float64
# mi          0.001248
# avg_disc    0.048142
# Name: 337, dtype: float64
# mi          0.001248
# avg_disc    0.047549
# Name: 338, dtype: float64
# mi          0.001248
# avg_disc    0.051424
# Name: 339, dtype: float64
# mi          0.001248
# avg_disc    0.050717
# Name: 340, dtype: float64
# mi          0.001248
# avg_disc    0.051008
# Name: 341, dtype: float64
# mi          0.001248
# avg_disc    0.046877
# Name: 342, dtype: float64
# mi          0.001248
# avg_disc    0.050764
# Name: 343, dtype: float64
# mi          0.001248
# avg_disc    0.051007
# Name: 344, dtype: float64
# mi          0.001248
# avg_disc    0.050518
# Name: 345, dtype: float64
# mi          0.001248
# avg_disc    0.049997
# Name: 346, dtype: float64
# mi          0.001248
# avg_disc    0.050596
# Name: 347, dtype: float64
# mi          0.001248
# avg_disc    0.052661
# Name: 348, dtype: float64
# mi          0.001248
# avg_disc    0.051251
# Name: 349, dtype: float64
# mi          0.001248
# avg_disc    0.051929
# Name: 350, dtype: float64
# mi          0.001248
# avg_disc    0.051052
# Name: 351, dtype: float64
# mi          0.001248
# avg_disc    0.047903
# Name: 352, dtype: float64
# mi          0.001248
# avg_disc    0.049942
# Name: 353, dtype: float64
# mi          0.001248
# avg_disc    0.052438
# Name: 354, dtype: float64
# mi          0.001248
# avg_disc    0.050569
# Name: 355, dtype: float64
# mi          0.001248
# avg_disc    0.049406
# Name: 356, dtype: float64
# mi          0.001248
# avg_disc    0.052233
# Name: 357, dtype: float64
# mi          0.001248
# avg_disc    0.050256
# Name: 358, dtype: float64
# mi          0.001248
# avg_disc    0.050011
# Name: 359, dtype: float64
# mi          0.001248
# avg_disc    0.047918
# Name: 360, dtype: float64
# mi          0.001248
# avg_disc    0.051551
# Name: 361, dtype: float64
# mi          0.001248
# avg_disc    0.048379
# Name: 362, dtype: float64
# mi          0.001248
# avg_disc    0.049841
# Name: 363, dtype: float64
# mi          0.001248
# avg_disc    0.054279
# Name: 364, dtype: float64
# mi          0.001248
# avg_disc    0.049986
# Name: 365, dtype: float64
# mi          0.001248
# avg_disc    0.047625
# Name: 366, dtype: float64
# mi          0.001248
# avg_disc    0.046453
# Name: 367, dtype: float64
# mi          0.001248
# avg_disc    0.052601
# Name: 368, dtype: float64
# mi          0.001248
# avg_disc    0.051918
# Name: 369, dtype: float64
# mi          0.001248
# avg_disc    0.051980
# Name: 370, dtype: float64
# mi          0.001248
# avg_disc    0.048938
# Name: 371, dtype: float64
# mi          0.001248
# avg_disc    0.049594
# Name: 372, dtype: float64
# mi          0.001248
# avg_disc    0.051995
# Name: 373, dtype: float64
# mi          0.001248
# avg_disc    0.047259
# Name: 374, dtype: float64
# mi          0.001248
# avg_disc    0.052632
# Name: 375, dtype: float64
# mi          0.001248
# avg_disc    0.051247
# Name: 376, dtype: float64
# mi          0.001248
# avg_disc    0.046782
# Name: 377, dtype: float64
# mi          0.001248
# avg_disc    0.048709
# Name: 378, dtype: float64
# mi          0.001248
# avg_disc    0.048905
# Name: 379, dtype: float64
# mi          0.001248
# avg_disc    0.050282
# Name: 380, dtype: float64
# mi          0.001248
# avg_disc    0.051457
# Name: 381, dtype: float64
# mi          0.001248
# avg_disc    0.050844
# Name: 382, dtype: float64
# mi          0.001248
# avg_disc    0.049301
# Name: 383, dtype: float64
# mi          0.001248
# avg_disc    0.051291
# Name: 384, dtype: float64
# mi          0.001248
# avg_disc    0.048299
# Name: 385, dtype: float64
# mi          0.001248
# avg_disc    0.050517
# Name: 386, dtype: float64
# mi          0.001248
# avg_disc    0.048745
# Name: 387, dtype: float64
# mi          0.001248
# avg_disc    0.052087
# Name: 388, dtype: float64
# mi          0.001248
# avg_disc    0.052057
# Name: 389, dtype: float64
# mi          0.001248
# avg_disc    0.050878
# Name: 390, dtype: float64
# mi          0.001248
# avg_disc    0.051536
# Name: 391, dtype: float64
# mi          0.001248
# avg_disc    0.049022
# Name: 392, dtype: float64
# mi          0.001248
# avg_disc    0.051130
# Name: 393, dtype: float64
# mi          0.001248
# avg_disc    0.050340
# Name: 394, dtype: float64
# mi          0.001248
# avg_disc    0.047966
# Name: 395, dtype: float64
# mi          0.001248
# avg_disc    0.051841
# Name: 396, dtype: float64
# mi          0.001248
# avg_disc    0.049563
# Name: 397, dtype: float64
# mi          0.001248
# avg_disc    0.047261
# Name: 398, dtype: float64
# mi          0.001248
# avg_disc    0.049822
# Name: 399, dtype: float64
# mi          0.001248
# avg_disc    0.049980
# Name: 400, dtype: float64
# mi          0.001248
# avg_disc    0.050844
# Name: 401, dtype: float64
# mi          0.001248
# avg_disc    0.051105
# Name: 402, dtype: float64
# mi          0.001248
# avg_disc    0.050942
# Name: 403, dtype: float64
# mi          0.001248
# avg_disc    0.051693
# Name: 404, dtype: float64
# mi          0.001248
# avg_disc    0.050166
# Name: 405, dtype: float64
# mi          0.001248
# avg_disc    0.049540
# Name: 406, dtype: float64
# mi          0.001248
# avg_disc    0.048925
# Name: 407, dtype: float64
# mi          0.001248
# avg_disc    0.049401
# Name: 408, dtype: float64
# mi          0.001248
# avg_disc    0.047126
# Name: 409, dtype: float64
# mi          0.001248
# avg_disc    0.047771
# Name: 410, dtype: float64
# mi          0.001248
# avg_disc    0.051517
# Name: 411, dtype: float64
# mi          0.001248
# avg_disc    0.050467
# Name: 412, dtype: float64
# mi          0.001248
# avg_disc    0.047071
# Name: 413, dtype: float64
# mi          0.001248
# avg_disc    0.048891
# Name: 414, dtype: float64
# mi          0.001248
# avg_disc    0.046999
# Name: 415, dtype: float64
# mi          0.001248
# avg_disc    0.050034
# Name: 416, dtype: float64
# mi          0.001248
# avg_disc    0.051914
# Name: 417, dtype: float64
# mi          0.001248
# avg_disc    0.050976
# Name: 418, dtype: float64
# mi          0.001248
# avg_disc    0.052382
# Name: 419, dtype: float64
# mi          0.001248
# avg_disc    0.050858
# Name: 420, dtype: float64
# mi          0.001248
# avg_disc    0.048231
# Name: 421, dtype: float64
# mi          0.001248
# avg_disc    0.050641
# Name: 422, dtype: float64
# mi          0.001248
# avg_disc    0.049037
# Name: 423, dtype: float64
# mi          0.001248
# avg_disc    0.048556
# Name: 424, dtype: float64
# mi          0.001248
# avg_disc    0.051031
# Name: 425, dtype: float64
# mi          0.001248
# avg_disc    0.048671
# Name: 426, dtype: float64
# mi          0.001248
# avg_disc    0.049773
# Name: 427, dtype: float64
# mi          0.001248
# avg_disc    0.047945
# Name: 428, dtype: float64
# mi          0.001248
# avg_disc    0.049603
# Name: 429, dtype: float64
# mi          0.001248
# avg_disc    0.052092
# Name: 430, dtype: float64
# mi          0.001248
# avg_disc    0.051778
# Name: 431, dtype: float64
# mi          0.001248
# avg_disc    0.049511
# Name: 432, dtype: float64
# mi          0.001248
# avg_disc    0.051313
# Name: 433, dtype: float64
# mi          0.001248
# avg_disc    0.051762
# Name: 434, dtype: float64
# mi          0.001248
# avg_disc    0.048441
# Name: 435, dtype: float64
# mi          0.001248
# avg_disc    0.049070
# Name: 436, dtype: float64
# mi          0.001248
# avg_disc    0.051940
# Name: 437, dtype: float64
# mi          0.001248
# avg_disc    0.047499
# Name: 438, dtype: float64
# mi          0.001248
# avg_disc    0.049337
# Name: 439, dtype: float64
# mi          0.001248
# avg_disc    0.048866
# Name: 440, dtype: float64
# mi          0.001248
# avg_disc    0.048453
# Name: 441, dtype: float64
# mi          0.001248
# avg_disc    0.051379
# Name: 442, dtype: float64
# mi          0.001248
# avg_disc    0.049296
# Name: 443, dtype: float64
# mi          0.001248
# avg_disc    0.049477
# Name: 444, dtype: float64
# mi          0.001248
# avg_disc    0.050923
# Name: 445, dtype: float64
# mi          0.001248
# avg_disc    0.050554
# Name: 446, dtype: float64
# mi          0.001248
# avg_disc    0.049148
# Name: 447, dtype: float64
# mi          0.001248
# avg_disc    0.048437
# Name: 448, dtype: float64
# mi          0.001248
# avg_disc    0.050149
# Name: 449, dtype: float64
# mi          0.001248
# avg_disc    0.052860
# Name: 450, dtype: float64
# mi          0.001248
# avg_disc    0.052733
# Name: 451, dtype: float64
# mi          0.001248
# avg_disc    0.050499
# Name: 452, dtype: float64
# mi          0.001248
# avg_disc    0.047845
# Name: 453, dtype: float64
# mi          0.001248
# avg_disc    0.052294
# Name: 454, dtype: float64
# mi          0.001248
# avg_disc    0.049241
# Name: 455, dtype: float64
# mi          0.001248
# avg_disc    0.048476
# Name: 456, dtype: float64
# mi          0.001248
# avg_disc    0.047844
# Name: 457, dtype: float64
# mi          0.001248
# avg_disc    0.049556
# Name: 458, dtype: float64
# mi          0.001248
# avg_disc    0.051825
# Name: 459, dtype: float64
# mi          0.001248
# avg_disc    0.049740
# Name: 460, dtype: float64
# mi          0.001248
# avg_disc    0.045979
# Name: 461, dtype: float64
# mi          0.001248
# avg_disc    0.046427
# Name: 462, dtype: float64
# mi          0.001248
# avg_disc    0.053414
# Name: 463, dtype: float64
# mi          0.001248
# avg_disc    0.048625
# Name: 464, dtype: float64
# mi          0.001248
# avg_disc    0.047803
# Name: 465, dtype: float64
# mi          0.001248
# avg_disc    0.051357
# Name: 466, dtype: float64
# mi          0.001248
# avg_disc    0.047579
# Name: 467, dtype: float64
# mi          0.001248
# avg_disc    0.050445
# Name: 468, dtype: float64
# mi          0.001248
# avg_disc    0.045534
# Name: 469, dtype: float64
# mi          0.001248
# avg_disc    0.051382
# Name: 470, dtype: float64
# mi          0.001248
# avg_disc    0.050610
# Name: 471, dtype: float64
# mi          0.001248
# avg_disc    0.049305
# Name: 472, dtype: float64
# mi          0.001248
# avg_disc    0.051652
# Name: 473, dtype: float64
# mi          0.001248
# avg_disc    0.048970
# Name: 474, dtype: float64
# mi          0.001248
# avg_disc    0.049868
# Name: 475, dtype: float64
# mi          0.001248
# avg_disc    0.048937
# Name: 476, dtype: float64
# mi          0.001248
# avg_disc    0.050913
# Name: 477, dtype: float64
# mi          0.001248
# avg_disc    0.050110
# Name: 478, dtype: float64
# mi          0.001248
# avg_disc    0.048101
# Name: 479, dtype: float64
# mi          0.001248
# avg_disc    0.047972
# Name: 480, dtype: float64
# mi          0.001248
# avg_disc    0.049799
# Name: 481, dtype: float64
# mi          0.001248
# avg_disc    0.048860
# Name: 482, dtype: float64
# mi          0.001248
# avg_disc    0.050196
# Name: 483, dtype: float64
# mi          0.001248
# avg_disc    0.050063
# Name: 484, dtype: float64
# mi          0.001248
# avg_disc    0.048373
# Name: 485, dtype: float64
# mi          0.001248
# avg_disc    0.052122
# Name: 486, dtype: float64
# mi          0.001248
# avg_disc    0.051991
# Name: 487, dtype: float64
# mi          0.001248
# avg_disc    0.048033
# Name: 488, dtype: float64
# mi          0.001248
# avg_disc    0.050663
# Name: 489, dtype: float64
# mi          0.001248
# avg_disc    0.048194
# Name: 490, dtype: float64
# mi          0.001248
# avg_disc    0.051144
# Name: 491, dtype: float64
# mi          0.001248
# avg_disc    0.051940
# Name: 492, dtype: float64
# mi          0.001248
# avg_disc    0.049800
# Name: 493, dtype: float64
# mi          0.001248
# avg_disc    0.050443
# Name: 494, dtype: float64
# mi          0.001248
# avg_disc    0.050016
# Name: 495, dtype: float64
# mi          0.001248
# avg_disc    0.049433
# Name: 496, dtype: float64
# mi          0.001248
# avg_disc    0.051018
# Name: 497, dtype: float64
# mi          0.001248
# avg_disc    0.051567
# Name: 498, dtype: float64
# mi          0.001248
# avg_disc    0.048580
# Name: 499, dtype: float64
# mi          0.001248
# avg_disc    0.049187
# Name: 500, dtype: float64
# mi          0.001248
# avg_disc    0.050979
# Name: 501, dtype: float64
# mi          0.001248
# avg_disc    0.049100
# Name: 502, dtype: float64
# mi          0.001248
# avg_disc    0.052506
# Name: 503, dtype: float64
# mi          0.001248
# avg_disc    0.047014
# Name: 504, dtype: float64
# mi          0.001248
# avg_disc    0.050079
# Name: 505, dtype: float64
# mi          0.001248
# avg_disc    0.048543
# Name: 506, dtype: float64
# mi          0.001248
# avg_disc    0.050717
# Name: 507, dtype: float64
# mi          0.001248
# avg_disc    0.050895
# Name: 508, dtype: float64
# mi          0.001248
# avg_disc    0.047967
# Name: 509, dtype: float64
# mi          0.001248
# avg_disc    0.051989
# Name: 510, dtype: float64
# mi          0.001248
# avg_disc    0.051431
# Name: 511, dtype: float64
# mi          0.001248
# avg_disc    0.049408
# Name: 512, dtype: float64
# mi          0.001248
# avg_disc    0.051540
# Name: 513, dtype: float64
# mi          0.001248
# avg_disc    0.047401
# Name: 514, dtype: float64
# mi          0.001248
# avg_disc    0.048848
# Name: 515, dtype: float64
# mi          0.001248
# avg_disc    0.049295
# Name: 516, dtype: float64
# mi          0.001248
# avg_disc    0.054040
# Name: 517, dtype: float64
# mi          0.001248
# avg_disc    0.048382
# Name: 518, dtype: float64
# mi          0.001248
# avg_disc    0.050059
# Name: 519, dtype: float64
# mi          0.001248
# avg_disc    0.050084
# Name: 520, dtype: float64
# mi          0.001248
# avg_disc    0.050819
# Name: 521, dtype: float64
# mi          0.001248
# avg_disc    0.050648
# Name: 522, dtype: float64
# mi          0.001248
# avg_disc    0.052511
# Name: 523, dtype: float64
# mi          0.001248
# avg_disc    0.049284
# Name: 524, dtype: float64
# mi          0.001248
# avg_disc    0.047975
# Name: 525, dtype: float64
# mi          0.001248
# avg_disc    0.049099
# Name: 526, dtype: float64
# mi          0.001248
# avg_disc    0.054291
# Name: 527, dtype: float64
# mi          0.001248
# avg_disc    0.052583
# Name: 528, dtype: float64
# mi          0.001248
# avg_disc    0.049977
# Name: 529, dtype: float64
# mi          0.001248
# avg_disc    0.050637
# Name: 530, dtype: float64
# mi          0.001248
# avg_disc    0.047530
# Name: 531, dtype: float64
# mi          0.001248
# avg_disc    0.052402
# Name: 532, dtype: float64
# mi          0.001248
# avg_disc    0.050892
# Name: 533, dtype: float64
# mi          0.001248
# avg_disc    0.048692
# Name: 534, dtype: float64
# mi          0.001248
# avg_disc    0.051035
# Name: 535, dtype: float64
# mi          0.001248
# avg_disc    0.051184
# Name: 536, dtype: float64
# mi          0.001248
# avg_disc    0.046566
# Name: 537, dtype: float64
# mi          0.001248
# avg_disc    0.047473
# Name: 538, dtype: float64
# mi          0.001248
# avg_disc    0.051785
# Name: 539, dtype: float64
# mi          0.001248
# avg_disc    0.048565
# Name: 540, dtype: float64
# mi          0.001248
# avg_disc    0.049113
# Name: 541, dtype: float64
# mi          0.001248
# avg_disc    0.049267
# Name: 542, dtype: float64
# mi          0.001248
# avg_disc    0.053577
# Name: 543, dtype: float64
# mi          0.001248
# avg_disc    0.046881
# Name: 544, dtype: float64
# mi          0.001248
# avg_disc    0.050744
# Name: 545, dtype: float64
# mi          0.001248
# avg_disc    0.047596
# Name: 546, dtype: float64
# mi          0.001248
# avg_disc    0.050983
# Name: 547, dtype: float64
# mi          0.001248
# avg_disc    0.049442
# Name: 548, dtype: float64
# mi          0.001248
# avg_disc    0.052860
# Name: 549, dtype: float64
# mi          0.001248
# avg_disc    0.051342
# Name: 550, dtype: float64
# mi          0.001248
# avg_disc    0.051132
# Name: 551, dtype: float64
# mi          0.001248
# avg_disc    0.046492
# Name: 552, dtype: float64
# mi          0.001248
# avg_disc    0.050169
# Name: 553, dtype: float64
# mi          0.001248
# avg_disc    0.050456
# Name: 554, dtype: float64
# mi          0.001248
# avg_disc    0.048933
# Name: 555, dtype: float64
# mi          0.001248
# avg_disc    0.048208
# Name: 556, dtype: float64
# mi          0.001248
# avg_disc    0.049783
# Name: 557, dtype: float64
# mi          0.001248
# avg_disc    0.046657
# Name: 558, dtype: float64
# mi          0.001248
# avg_disc    0.050042
# Name: 559, dtype: float64
# mi          0.001248
# avg_disc    0.049684
# Name: 560, dtype: float64
# mi          0.001248
# avg_disc    0.050318
# Name: 561, dtype: float64
# mi          0.001248
# avg_disc    0.051113
# Name: 562, dtype: float64
# mi          0.001248
# avg_disc    0.048113
# Name: 563, dtype: float64
# mi          0.001248
# avg_disc    0.050126
# Name: 564, dtype: float64
# mi          0.001248
# avg_disc    0.049514
# Name: 565, dtype: float64
# mi          0.001248
# avg_disc    0.047100
# Name: 566, dtype: float64
# mi          0.001248
# avg_disc    0.047243
# Name: 567, dtype: float64
# mi          0.001248
# avg_disc    0.052652
# Name: 568, dtype: float64
# mi          0.001248
# avg_disc    0.048468
# Name: 569, dtype: float64
# mi          0.001248
# avg_disc    0.049878
# Name: 570, dtype: float64
# mi          0.001248
# avg_disc    0.052721
# Name: 571, dtype: float64
# mi          0.001248
# avg_disc    0.048368
# Name: 572, dtype: float64
# mi          0.001248
# avg_disc    0.048966
# Name: 573, dtype: float64
# mi          0.001248
# avg_disc    0.049147
# Name: 574, dtype: float64
# mi          0.001248
# avg_disc    0.051158
# Name: 575, dtype: float64
# mi          0.001248
# avg_disc    0.049598
# Name: 576, dtype: float64
# mi          0.001248
# avg_disc    0.049236
# Name: 577, dtype: float64
# mi          0.001248
# avg_disc    0.051109
# Name: 578, dtype: float64
# mi          0.001248
# avg_disc    0.049026
# Name: 579, dtype: float64
# mi          0.001248
# avg_disc    0.048781
# Name: 580, dtype: float64
# mi          0.001248
# avg_disc    0.050971
# Name: 581, dtype: float64
# mi          0.001248
# avg_disc    0.052743
# Name: 582, dtype: float64
# mi          0.001248
# avg_disc    0.051892
# Name: 583, dtype: float64
# mi          0.001248
# avg_disc    0.052888
# Name: 584, dtype: float64
# mi          0.001248
# avg_disc    0.049804
# Name: 585, dtype: float64
# mi          0.001248
# avg_disc    0.048262
# Name: 586, dtype: float64
# mi          0.001248
# avg_disc    0.051650
# Name: 587, dtype: float64
# mi          0.001248
# avg_disc    0.049723
# Name: 588, dtype: float64
# mi          0.001248
# avg_disc    0.049790
# Name: 589, dtype: float64
# mi          0.001248
# avg_disc    0.051441
# Name: 590, dtype: float64
# mi          0.001248
# avg_disc    0.050367
# Name: 591, dtype: float64
# mi          0.001248
# avg_disc    0.052275
# Name: 592, dtype: float64
# mi          0.001248
# avg_disc    0.049060
# Name: 593, dtype: float64
# mi          0.001248
# avg_disc    0.049492
# Name: 594, dtype: float64
# mi          0.001248
# avg_disc    0.049775
# Name: 595, dtype: float64
# mi          0.001248
# avg_disc    0.049337
# Name: 596, dtype: float64
# mi          0.001248
# avg_disc    0.047537
# Name: 597, dtype: float64
# mi          0.001248
# avg_disc    0.049412
# Name: 598, dtype: float64
# mi          0.001248
# avg_disc    0.052677
# Name: 599, dtype: float64
# mi          0.001248
# avg_disc    0.049019
# Name: 600, dtype: float64
# mi          0.001248
# avg_disc    0.048782
# Name: 601, dtype: float64
# mi          0.001248
# avg_disc    0.050267
# Name: 602, dtype: float64
# mi          0.001248
# avg_disc    0.048011
# Name: 603, dtype: float64
# mi          0.001248
# avg_disc    0.052934
# Name: 604, dtype: float64
# mi          0.001248
# avg_disc    0.048346
# Name: 605, dtype: float64
# mi          0.001248
# avg_disc    0.047270
# Name: 606, dtype: float64
# mi          0.001248
# avg_disc    0.053091
# Name: 607, dtype: float64
# mi          0.001248
# avg_disc    0.049888
# Name: 608, dtype: float64
# mi          0.001248
# avg_disc    0.049275
# Name: 609, dtype: float64
# mi          0.001248
# avg_disc    0.049757
# Name: 610, dtype: float64
# mi          0.001248
# avg_disc    0.050727
# Name: 611, dtype: float64
# mi          0.001248
# avg_disc    0.050273
# Name: 612, dtype: float64
# mi          0.001248
# avg_disc    0.050281
# Name: 613, dtype: float64
# mi          0.001248
# avg_disc    0.052152
# Name: 614, dtype: float64
# mi          0.001248
# avg_disc    0.050610
# Name: 615, dtype: float64
# mi          0.001248
# avg_disc    0.052528
# Name: 616, dtype: float64
# mi          0.001248
# avg_disc    0.049909
# Name: 617, dtype: float64
# mi          0.001248
# avg_disc    0.048312
# Name: 618, dtype: float64
# mi          0.001248
# avg_disc    0.052651
# Name: 619, dtype: float64
# mi          0.001248
# avg_disc    0.050958
# Name: 620, dtype: float64
# mi          0.001248
# avg_disc    0.049864
# Name: 621, dtype: float64
# mi          0.001248
# avg_disc    0.049677
# Name: 622, dtype: float64
# mi          0.001248
# avg_disc    0.049825
# Name: 623, dtype: float64
# mi          0.001248
# avg_disc    0.048082
# Name: 624, dtype: float64
# mi          0.001248
# avg_disc    0.051648
# Name: 625, dtype: float64
# mi          0.001248
# avg_disc    0.049244
# Name: 626, dtype: float64
# mi          0.001248
# avg_disc    0.049640
# Name: 627, dtype: float64
# mi          0.001248
# avg_disc    0.052064
# Name: 628, dtype: float64
# mi          0.001248
# avg_disc    0.048671
# Name: 629, dtype: float64
# mi          0.001248
# avg_disc    0.051350
# Name: 630, dtype: float64
# mi          0.001248
# avg_disc    0.051668
# Name: 631, dtype: float64
# mi          0.001248
# avg_disc    0.051928
# Name: 632, dtype: float64
# mi          0.001248
# avg_disc    0.050208
# Name: 633, dtype: float64
# mi          0.001248
# avg_disc    0.048392
# Name: 634, dtype: float64
# mi          0.001248
# avg_disc    0.051149
# Name: 635, dtype: float64
# mi          0.001248
# avg_disc    0.052769
# Name: 636, dtype: float64
# mi          0.001248
# avg_disc    0.048528
# Name: 637, dtype: float64
# mi          0.001248
# avg_disc    0.051541
# Name: 638, dtype: float64
# mi          0.001248
# avg_disc    0.051157
# Name: 639, dtype: float64
# mi          0.001248
# avg_disc    0.046687
# Name: 640, dtype: float64
# mi          0.001248
# avg_disc    0.049859
# Name: 641, dtype: float64
# mi          0.001248
# avg_disc    0.049797
# Name: 642, dtype: float64
# mi          0.001248
# avg_disc    0.051381
# Name: 643, dtype: float64
# mi          0.001248
# avg_disc    0.049287
# Name: 644, dtype: float64
# mi          0.001248
# avg_disc    0.045813
# Name: 645, dtype: float64
# mi          0.001248
# avg_disc    0.052171
# Name: 646, dtype: float64
# mi          0.001248
# avg_disc    0.051237
# Name: 647, dtype: float64
# mi          0.001248
# avg_disc    0.051974
# Name: 648, dtype: float64
# mi          0.001248
# avg_disc    0.051450
# Name: 649, dtype: float64
# mi          0.001248
# avg_disc    0.051097
# Name: 650, dtype: float64
# mi          0.001248
# avg_disc    0.048052
# Name: 651, dtype: float64
# mi          0.001248
# avg_disc    0.051804
# Name: 652, dtype: float64
# mi          0.001248
# avg_disc    0.051228
# Name: 653, dtype: float64
# mi          0.001248
# avg_disc    0.051946
# Name: 654, dtype: float64
# mi          0.001248
# avg_disc    0.052178
# Name: 655, dtype: float64
# mi          0.001248
# avg_disc    0.051552
# Name: 656, dtype: float64
# mi          0.001248
# avg_disc    0.050349
# Name: 657, dtype: float64
# mi          0.001248
# avg_disc    0.049596
# Name: 658, dtype: float64
# mi          0.001248
# avg_disc    0.050902
# Name: 659, dtype: float64
# mi          0.001248
# avg_disc    0.051289
# Name: 660, dtype: float64
# mi          0.001248
# avg_disc    0.054119
# Name: 661, dtype: float64
# mi          0.001248
# avg_disc    0.050980
# Name: 662, dtype: float64
# mi          0.001248
# avg_disc    0.048367
# Name: 663, dtype: float64
# mi          0.001248
# avg_disc    0.051126
# Name: 664, dtype: float64
# mi          0.001248
# avg_disc    0.050132
# Name: 665, dtype: float64
# mi          0.001248
# avg_disc    0.049097
# Name: 666, dtype: float64
# mi          0.001248
# avg_disc    0.047279
# Name: 667, dtype: float64
# mi          0.001248
# avg_disc    0.052242
# Name: 668, dtype: float64
# mi          0.001248
# avg_disc    0.047659
# Name: 669, dtype: float64
# mi          0.001248
# avg_disc    0.048495
# Name: 670, dtype: float64
# mi          0.001248
# avg_disc    0.047762
# Name: 671, dtype: float64
# mi          0.001248
# avg_disc    0.049624
# Name: 672, dtype: float64
# mi          0.001248
# avg_disc    0.049238
# Name: 673, dtype: float64
# mi          0.001248
# avg_disc    0.049354
# Name: 674, dtype: float64
# mi          0.001248
# avg_disc    0.050764
# Name: 675, dtype: float64
# mi          0.001248
# avg_disc    0.049569
# Name: 676, dtype: float64
# mi          0.001248
# avg_disc    0.051687
# Name: 677, dtype: float64
# mi          0.001248
# avg_disc    0.049800
# Name: 678, dtype: float64
# mi          0.001248
# avg_disc    0.051743
# Name: 679, dtype: float64
# mi          0.001248
# avg_disc    0.050841
# Name: 680, dtype: float64
# mi          0.001248
# avg_disc    0.051744
# Name: 681, dtype: float64
# mi          0.001248
# avg_disc    0.051423
# Name: 682, dtype: float64
# mi          0.001248
# avg_disc    0.049901
# Name: 683, dtype: float64
# mi          0.001248
# avg_disc    0.051600
# Name: 684, dtype: float64
# mi          0.001248
# avg_disc    0.052386
# Name: 685, dtype: float64
# mi          0.001248
# avg_disc    0.052751
# Name: 686, dtype: float64
# mi          0.001248
# avg_disc    0.049573
# Name: 687, dtype: float64
# mi          0.001248
# avg_disc    0.050901
# Name: 688, dtype: float64
# mi          0.001248
# avg_disc    0.050299
# Name: 689, dtype: float64
# mi          0.001248
# avg_disc    0.047119
# Name: 690, dtype: float64
# mi          0.001248
# avg_disc    0.050757
# Name: 691, dtype: float64
# mi          0.001248
# avg_disc    0.048397
# Name: 692, dtype: float64
# mi          0.001248
# avg_disc    0.050232
# Name: 693, dtype: float64
# mi          0.001248
# avg_disc    0.052742
# Name: 694, dtype: float64
# mi          0.001248
# avg_disc    0.051520
# Name: 695, dtype: float64
# mi          0.001248
# avg_disc    0.052729
# Name: 696, dtype: float64
# mi          0.001248
# avg_disc    0.047895
# Name: 697, dtype: float64
# mi          0.001248
# avg_disc    0.052076
# Name: 698, dtype: float64
# mi          0.001248
# avg_disc    0.051265
# Name: 699, dtype: float64
# mi          0.001248
# avg_disc    0.050677
# Name: 700, dtype: float64
# mi          0.001248
# avg_disc    0.052348
# Name: 701, dtype: float64
# mi          0.001248
# avg_disc    0.050035
# Name: 702, dtype: float64
# mi          0.001248
# avg_disc    0.049059
# Name: 703, dtype: float64
# mi          0.001248
# avg_disc    0.050203
# Name: 704, dtype: float64
# mi          0.001248
# avg_disc    0.053339
# Name: 705, dtype: float64
# mi          0.001248
# avg_disc    0.051490
# Name: 706, dtype: float64
# mi          0.001248
# ...
# Name: 8785, dtype: float64
# mi          16.000000
# avg_disc     0.050202
# Name: 8786, dtype: float64
# mi          16.000000
# avg_disc     0.050151
# Name: 8787, dtype: float64
# mi          16.000000
# avg_disc     0.050025
# Name: 8788, dtype: float64
# mi          16.000000
# avg_disc     0.050168
# Name: 8789, dtype: float64
# mi          16.0000
# avg_disc     0.0501
# Name: 8790, dtype: float64
# mi          16.000000
# avg_disc     0.050098
# Name: 8791, dtype: float64
# mi          16.000000
# avg_disc     0.050265
# Name: 8792, dtype: float64
# mi          16.00000
# avg_disc     0.05016
# Name: 8793, dtype: float64
# mi          16.000000
# avg_disc     0.050239
# Name: 8794, dtype: float64
# mi          16.000000
# avg_disc     0.050166
# Name: 8795, dtype: float64
# mi          16.000000
# avg_disc     0.050104
# Name: 8796, dtype: float64
# mi          16.000000
# avg_disc     0.050109
# Name: 8797, dtype: float64
# mi          16.000000
# avg_disc     0.050116
# Name: 8798, dtype: float64
# mi          16.00000
# avg_disc     0.04999
# Name: 8799, dtype: float64
# mi          16.000000
# avg_disc     0.050121
# Name: 8800, dtype: float64
# mi          16.000000
# avg_disc     0.050122
# Name: 8801, dtype: float64
# mi          16.000000
# avg_disc     0.050267
# Name: 8802, dtype: float64
# mi          16.000000
# avg_disc     0.050122
# Name: 8803, dtype: float64
# mi          16.000000
# avg_disc     0.050132
# Name: 8804, dtype: float64
# mi          16.000000
# avg_disc     0.050162
# Name: 8805, dtype: float64
# mi          16.000000
# avg_disc     0.050117
# Name: 8806, dtype: float64
# mi          16.000000
# avg_disc     0.050133
# Name: 8807, dtype: float64
# mi          16.000000
# avg_disc     0.050235
# Name: 8808, dtype: float64
# mi          16.000000
# avg_disc     0.050132
# Name: 8809, dtype: float64
# mi          16.000000
# avg_disc     0.050144
# Name: 8810, dtype: float64
# mi          16.000000
# avg_disc     0.050065
# Name: 8811, dtype: float64
# mi          16.000000
# avg_disc     0.050159
# Name: 8812, dtype: float64
# mi          16.000000
# avg_disc     0.050062
# Name: 8813, dtype: float64
# mi          16.000000
# avg_disc     0.050057
# Name: 8814, dtype: float64
# mi          16.000000
# avg_disc     0.050166
# Name: 8815, dtype: float64
# mi          16.000000
# avg_disc     0.050161
# Name: 8816, dtype: float64
# mi          16.000000
# avg_disc     0.050129
# Name: 8817, dtype: float64
# mi          16.000000
# avg_disc     0.050098
# Name: 8818, dtype: float64
# mi          16.000000
# avg_disc     0.050185
# Name: 8819, dtype: float64
# mi          16.000000
# avg_disc     0.050176
# Name: 8820, dtype: float64
# mi          16.000000
# avg_disc     0.049983
# Name: 8821, dtype: float64
# mi          16.000000
# avg_disc     0.050237
# Name: 8822, dtype: float64
# mi          16.000000
# avg_disc     0.050036
# Name: 8823, dtype: float64
# mi          16.000000
# avg_disc     0.050123
# Name: 8824, dtype: float64
# mi          16.000000
# avg_disc     0.050326
# Name: 8825, dtype: float64
# mi          16.00000
# avg_disc     0.05021
# Name: 8826, dtype: float64
# mi          16.000000
# avg_disc     0.050071
# Name: 8827, dtype: float64
# mi          16.000000
# avg_disc     0.050171
# Name: 8828, dtype: float64
# mi          16.000000
# avg_disc     0.050158
# Name: 8829, dtype: float64
# mi          16.000000
# avg_disc     0.050092
# Name: 8830, dtype: float64
# mi          16.000000
# avg_disc     0.050211
# Name: 8831, dtype: float64
# mi          16.000000
# avg_disc     0.050055
# Name: 8832, dtype: float64
# mi          16.000000
# avg_disc     0.050139
# Name: 8833, dtype: float64
# mi          16.000000
# avg_disc     0.050244
# Name: 8834, dtype: float64
# mi          16.000000
# avg_disc     0.050143
# Name: 8835, dtype: float64
# mi          16.000000
# avg_disc     0.050195
# Name: 8836, dtype: float64
# mi          16.000000
# avg_disc     0.050135
# Name: 8837, dtype: float64
# mi          16.000000
# avg_disc     0.050174
# Name: 8838, dtype: float64
# mi          16.000000
# avg_disc     0.050104
# Name: 8839, dtype: float64
# mi          16.000000
# avg_disc     0.050057
# Name: 8840, dtype: float64
# mi          16.000000
# avg_disc     0.050132
# Name: 8841, dtype: float64
# mi          16.00000
# avg_disc     0.05021
# Name: 8842, dtype: float64
# mi          16.000000
# avg_disc     0.050179
# Name: 8843, dtype: float64
# mi          16.000000
# avg_disc     0.050068
# Name: 8844, dtype: float64
# mi          16.000000
# avg_disc     0.050157
# Name: 8845, dtype: float64
# mi          16.000000
# avg_disc     0.050025
# Name: 8846, dtype: float64
# mi          16.000000
# avg_disc     0.050066
# Name: 8847, dtype: float64
# mi          16.000000
# avg_disc     0.050168
# Name: 8848, dtype: float64
# mi          16.000000
# avg_disc     0.050119
# Name: 8849, dtype: float64
# mi          16.000000
# avg_disc     0.050258
# Name: 8850, dtype: float64
# mi          16.000000
# avg_disc     0.050218
# Name: 8851, dtype: float64
# mi          16.000000
# avg_disc     0.050327
# Name: 8852, dtype: float64
# mi          16.000000
# avg_disc     0.050186
# Name: 8853, dtype: float64
# mi          16.000000
# avg_disc     0.050255
# Name: 8854, dtype: float64
# mi          16.000000
# avg_disc     0.050148
# Name: 8855, dtype: float64
# mi          16.000000
# avg_disc     0.049974
# Name: 8856, dtype: float64
# mi          16.000000
# avg_disc     0.050179
# Name: 8857, dtype: float64
# mi          16.000000
# avg_disc     0.050098
# Name: 8858, dtype: float64
# mi          16.000000
# avg_disc     0.050159
# Name: 8859, dtype: float64
# mi          16.000000
# avg_disc     0.050156
# Name: 8860, dtype: float64
# mi          16.000000
# avg_disc     0.050086
# Name: 8861, dtype: float64
# mi          16.000000
# avg_disc     0.050197
# Name: 8862, dtype: float64
# mi          16.000000
# avg_disc     0.050208
# Name: 8863, dtype: float64
# mi          16.000000
# avg_disc     0.050097
# Name: 8864, dtype: float64
# mi          16.000000
# avg_disc     0.050289
# Name: 8865, dtype: float64
# mi          16.000000
# avg_disc     0.050114
# Name: 8866, dtype: float64
# mi          16.000000
# avg_disc     0.050112
# Name: 8867, dtype: float64
# mi          16.000000
# avg_disc     0.050253
# Name: 8868, dtype: float64
# mi          16.000000
# avg_disc     0.050137
# Name: 8869, dtype: float64
# mi          16.000000
# avg_disc     0.050125
# Name: 8870, dtype: float64
# mi          16.000000
# avg_disc     0.050042
# Name: 8871, dtype: float64
# mi          16.000000
# avg_disc     0.050004
# Name: 8872, dtype: float64
# mi          16.000000
# avg_disc     0.050165
# Name: 8873, dtype: float64
# mi          16.000000
# avg_disc     0.050266
# Name: 8874, dtype: float64
# mi          16.000000
# avg_disc     0.050067
# Name: 8875, dtype: float64
# mi          16.000000
# avg_disc     0.050138
# Name: 8876, dtype: float64
# mi          16.000000
# avg_disc     0.050105
# Name: 8877, dtype: float64
# mi          16.000000
# avg_disc     0.050064
# Name: 8878, dtype: float64
# mi          16.00000
# avg_disc     0.05015
# Name: 8879, dtype: float64
# mi          16.00000
# avg_disc     0.05013
# Name: 8880, dtype: float64
# mi          16.000000
# avg_disc     0.050186
# Name: 8881, dtype: float64
# mi          16.000000
# avg_disc     0.050168
# Name: 8882, dtype: float64
# mi          16.000000
# avg_disc     0.050154
# Name: 8883, dtype: float64
# mi          16.000000
# avg_disc     0.050278
# Name: 8884, dtype: float64
# mi          16.000000
# avg_disc     0.050179
# Name: 8885, dtype: float64
# mi          16.000000
# avg_disc     0.050227
# Name: 8886, dtype: float64
# mi          16.000000
# avg_disc     0.050093
# Name: 8887, dtype: float64
# mi          16.000000
# avg_disc     0.050096
# Name: 8888, dtype: float64
# mi          16.000000
# avg_disc     0.050181
# Name: 8889, dtype: float64
# mi          16.00000
# avg_disc     0.05008
# Name: 8890, dtype: float64
# mi          16.000000
# avg_disc     0.050187
# Name: 8891, dtype: float64
# mi          16.000000
# avg_disc     0.050319
# Name: 8892, dtype: float64
# mi          16.00000
# avg_disc     0.05023
# Name: 8893, dtype: float64
# mi          16.000000
# avg_disc     0.050247
# Name: 8894, dtype: float64
# mi          16.000000
# avg_disc     0.050081
# Name: 8895, dtype: float64
# mi          16.000000
# avg_disc     0.050156
# Name: 8896, dtype: float64
# mi          16.000000
# avg_disc     0.050234
# Name: 8897, dtype: float64
# mi          16.000000
# avg_disc     0.050001
# Name: 8898, dtype: float64
# mi          16.000000
# avg_disc     0.050186
# Name: 8899, dtype: float64
# mi          16.000000
# avg_disc     0.049989
# Name: 8900, dtype: float64
# mi          16.000000
# avg_disc     0.050256
# Name: 8901, dtype: float64
# mi          16.000000
# avg_disc     0.050194
# Name: 8902, dtype: float64
# mi          16.000000
# avg_disc     0.050127
# Name: 8903, dtype: float64
# mi          16.000000
# avg_disc     0.050212
# Name: 8904, dtype: float64
# mi          16.000000
# avg_disc     0.050025
# Name: 8905, dtype: float64
# mi          16.00000
# avg_disc     0.05004
# Name: 8906, dtype: float64
# mi          16.000000
# avg_disc     0.050184
# Name: 8907, dtype: float64
# mi          16.000000
# avg_disc     0.049988
# Name: 8908, dtype: float64
# mi          16.000000
# avg_disc     0.050117
# Name: 8909, dtype: float64
# mi          16.000000
# avg_disc     0.050202
# Name: 8910, dtype: float64
# mi          16.000000
# avg_disc     0.050344
# Name: 8911, dtype: float64
# mi          16.000000
# avg_disc     0.050117
# Name: 8912, dtype: float64
# mi          16.000000
# avg_disc     0.050076
# Name: 8913, dtype: float64
# mi          16.000000
# avg_disc     0.050024
# Name: 8914, dtype: float64
# mi          16.000000
# avg_disc     0.050087
# Name: 8915, dtype: float64
# mi          16.000000
# avg_disc     0.050228
# Name: 8916, dtype: float64
# mi          16.00000
# avg_disc     0.05021
# Name: 8917, dtype: float64
# mi          16.000000
# avg_disc     0.050071
# Name: 8918, dtype: float64
# mi          16.000000
# avg_disc     0.050111
# Name: 8919, dtype: float64
# mi          16.000000
# avg_disc     0.050272
# Name: 8920, dtype: float64
# mi          16.000000
# avg_disc     0.050155
# Name: 8921, dtype: float64
# mi          16.00000
# avg_disc     0.05009
# Name: 8922, dtype: float64
# mi          16.00000
# avg_disc     0.05017
# Name: 8923, dtype: float64
# mi          16.000000
# avg_disc     0.050085
# Name: 8924, dtype: float64
# mi          16.000000
# avg_disc     0.050095
# Name: 8925, dtype: float64
# mi          16.00000
# avg_disc     0.05014
# Name: 8926, dtype: float64
# mi          16.000000
# avg_disc     0.050215
# Name: 8927, dtype: float64
# mi          16.00000
# avg_disc     0.05022
# Name: 8928, dtype: float64
# mi          16.000000
# avg_disc     0.050148
# Name: 8929, dtype: float64
# mi          16.000000
# avg_disc     0.050088
# Name: 8930, dtype: float64
# mi          16.000000
# avg_disc     0.050112
# Name: 8931, dtype: float64
# mi          16.000000
# avg_disc     0.050017
# Name: 8932, dtype: float64
# mi          16.000000
# avg_disc     0.050075
# Name: 8933, dtype: float64
# mi          16.000000
# avg_disc     0.050175
# Name: 8934, dtype: float64
# mi          16.000000
# avg_disc     0.049946
# Name: 8935, dtype: float64
# mi          16.000000
# avg_disc     0.050135
# Name: 8936, dtype: float64
# mi          16.00000
# avg_disc     0.05031
# Name: 8937, dtype: float64
# mi          16.000000
# avg_disc     0.050138
# Name: 8938, dtype: float64
# mi          16.000000
# avg_disc     0.050029
# Name: 8939, dtype: float64
# mi          16.000000
# avg_disc     0.050099
# Name: 8940, dtype: float64
# mi          16.000000
# avg_disc     0.050397
# Name: 8941, dtype: float64
# mi          16.0000
# avg_disc     0.0502
# Name: 8942, dtype: float64
# mi          16.000000
# avg_disc     0.050177
# Name: 8943, dtype: float64
# mi          16.000000
# avg_disc     0.050074
# Name: 8944, dtype: float64
# mi          16.000000
# avg_disc     0.050214
# Name: 8945, dtype: float64
# mi          16.000000
# avg_disc     0.050205
# Name: 8946, dtype: float64
# mi          16.000000
# avg_disc     0.050066
# Name: 8947, dtype: float64
# mi          16.000000
# avg_disc     0.050078
# Name: 8948, dtype: float64
# mi          16.000000
# avg_disc     0.050256
# Name: 8949, dtype: float64
# mi          16.000000
# avg_disc     0.050116
# Name: 8950, dtype: float64
# mi          16.000000
# avg_disc     0.050252
# Name: 8951, dtype: float64
# mi          16.000000
# avg_disc     0.050234
# Name: 8952, dtype: float64
# mi          16.000000
# avg_disc     0.050181
# Name: 8953, dtype: float64
# mi          16.000000
# avg_disc     0.050048
# Name: 8954, dtype: float64
# mi          16.000000
# avg_disc     0.050199
# Name: 8955, dtype: float64
# mi          16.00000
# avg_disc     0.05007
# Name: 8956, dtype: float64
# mi          16.000000
# avg_disc     0.050041
# Name: 8957, dtype: float64
# mi          16.000000
# avg_disc     0.050066
# Name: 8958, dtype: float64
# mi          16.000000
# avg_disc     0.050155
# Name: 8959, dtype: float64
# mi          16.000000
# avg_disc     0.050103
# Name: 8960, dtype: float64
# mi          16.000000
# avg_disc     0.049926
# Name: 8961, dtype: float64
# mi          16.000000
# avg_disc     0.050157
# Name: 8962, dtype: float64
# mi          16.000000
# avg_disc     0.049985
# Name: 8963, dtype: float64
# mi          16.0000
# avg_disc     0.0501
# Name: 8964, dtype: float64
# mi          16.000000
# avg_disc     0.050114
# Name: 8965, dtype: float64
# mi          16.000000
# avg_disc     0.050131
# Name: 8966, dtype: float64
# mi          16.000000
# avg_disc     0.050028
# Name: 8967, dtype: float64
# mi          16.000000
# avg_disc     0.050206
# Name: 8968, dtype: float64
# mi          16.000000
# avg_disc     0.050128
# Name: 8969, dtype: float64
# mi          16.000000
# avg_disc     0.050205
# Name: 8970, dtype: float64
# mi          16.000000
# avg_disc     0.050211
# Name: 8971, dtype: float64
# mi          16.000000
# avg_disc     0.050175
# Name: 8972, dtype: float64
# mi          16.000000
# avg_disc     0.050144
# Name: 8973, dtype: float64
# mi          16.000000
# avg_disc     0.050026
# Name: 8974, dtype: float64
# mi          16.000000
# avg_disc     0.050124
# Name: 8975, dtype: float64
# mi          16.000000
# avg_disc     0.050441
# Name: 8976, dtype: float64
# mi          16.000000
# avg_disc     0.050232
# Name: 8977, dtype: float64
# mi          16.000000
# avg_disc     0.050101
# Name: 8978, dtype: float64
# mi          16.000000
# avg_disc     0.050069
# Name: 8979, dtype: float64
# mi          16.000000
# avg_disc     0.050029
# Name: 8980, dtype: float64
# mi          16.000000
# avg_disc     0.050105
# Name: 8981, dtype: float64
# mi          16.000000
# avg_disc     0.050244
# Name: 8982, dtype: float64
# mi          16.000000
# avg_disc     0.050189
# Name: 8983, dtype: float64
# mi          16.000000
# avg_disc     0.049964
# Name: 8984, dtype: float64
# mi          16.000000
# avg_disc     0.050166
# Name: 8985, dtype: float64
# mi          16.000000
# avg_disc     0.050203
# Name: 8986, dtype: float64
# mi          16.000000
# avg_disc     0.050142
# Name: 8987, dtype: float64
# mi          16.000000
# avg_disc     0.050326
# Name: 8988, dtype: float64
# mi          16.000000
# avg_disc     0.050111
# Name: 8989, dtype: float64
# mi          16.0000
# avg_disc     0.0502
# Name: 8990, dtype: float64
# mi          16.00000
# avg_disc     0.05024
# Name: 8991, dtype: float64
# mi          16.00000
# avg_disc     0.05017
# Name: 8992, dtype: float64
# mi          16.000000
# avg_disc     0.050077
# Name: 8993, dtype: float64
# mi          16.000000
# avg_disc     0.050013
# Name: 8994, dtype: float64
# mi          16.000000
# avg_disc     0.050252
# Name: 8995, dtype: float64
# mi          16.000000
# avg_disc     0.049986
# Name: 8996, dtype: float64
# mi          16.000000
# avg_disc     0.050237
# Name: 8997, dtype: float64
# mi          16.000000
# avg_disc     0.050188
# Name: 8998, dtype: float64
# mi          16.000000
# avg_disc     0.049928
# Name: 8999, dtype: float64
#              mi  absolute error avg_disc  relative error avg_disc
# 0      0.001248                 0.000138                 0.275240
# 1      0.001248                 0.003580                 7.138596
# 2      0.001248                 0.002473                 4.931198
# 3      0.001248                 0.000179                 0.356414
# 4      0.001248                 0.000711                 1.417519
# ...         ...                      ...                      ...
# 8995  16.000000                 0.000108                 0.214809
# 8996  16.000000                 0.000158                 0.315657
# 8997  16.000000                 0.000093                 0.185159
# 8998  16.000000                 0.000043                 0.085759
# 8999  16.000000                 0.000216                 0.431644
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 avg_disc mean  avg_disc var
# type factor
# pac  0.001248        0.050101  2.935569e-06
#      0.015625        0.050167  2.348160e-07
#      0.031250        0.050128  1.156286e-07
#      0.062500        0.050142  6.619654e-08
#      0.250000        0.050144  1.993478e-08
#      1.000000        0.050143  9.774616e-09
#      2.000000        0.050151  8.785649e-09
#      4.000000        0.050150  7.568721e-09
#      16.000000       0.050142  7.066317e-09

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error avg_disc mean  absolute error avg_disc var  \
# type factor
# pac  0.001248                       0.001386                 1.013771e-06
#      0.015625                       0.000389                 8.390384e-08
#      0.031250                       0.000271                 4.251313e-08
#      0.062500                       0.000203                 2.514547e-08
#      0.250000                       0.000114                 6.952774e-09
#      1.000000                       0.000079                 3.564722e-09
#      2.000000                       0.000076                 2.991499e-09
#      4.000000                       0.000069                 2.830414e-09
#      16.000000                      0.000067                 2.525434e-09
#
#                 relative error avg_disc mean  relative error avg_disc var
# type factor
# pac  0.001248                       2.764589                     4.031730
#      0.015625                       0.775650                     0.333683
#      0.031250                       0.539979                     0.169073
#      0.062500                       0.403893                     0.100003
#      0.250000                       0.227108                     0.027651
#      1.000000                       0.157123                     0.014177
#      2.000000                       0.152322                     0.011897
#      4.000000                       0.137676                     0.011256
#      16.000000                      0.134443                     0.010044

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#                avg_disc
# mi
# 0.001248   2.935569e-06
# 0.015625   2.348160e-07
# 0.031250   1.156286e-07
# 0.062500   6.619654e-08
# 0.250000   1.993478e-08
# 1.000000   9.774616e-09
# 2.000000   8.785649e-09
# 4.000000   7.568721e-09
# 16.000000  7.066317e-09

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step              scale
# query          avg_disc
# mi
# 0.001248   2.798489e-06
# 0.015625   2.235780e-07
# 0.031250   1.117890e-07
# 0.062500   5.589449e-08
# 0.250000   1.397362e-08
# 1.000000   3.493406e-09
# 2.000000   1.746703e-09
# 4.000000   8.733515e-10
# 16.000000  2.183379e-10

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# avg_disc    0.132998
# dtype: float64
#            avg_disc
# mi
# 0.001248   0.134522
# 0.015625   0.128350
# 0.031250   0.136229
# 0.062500   0.137989
# 0.250000   0.133241
# 1.000000   0.129348
# 2.000000   0.134598
# 4.000000   0.129041
# 16.000000  0.133664

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query              avg_disc
# mi
# 0.001248           0.001385
# 0.015625           0.000385
# 0.031250           0.000263
# 0.062500           0.000189
# 0.250000           0.000093
# 1.000000           0.000049
# 2.000000           0.000033
# 4.000000           0.000023
# 16.000000          0.000012

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query          avg_disc
# mi
# 0.001248       0.050140
# 0.015625       0.050146
# 0.031250       0.050142
# 0.062500       0.050141
# 0.250000       0.050148
# 1.000000       0.050146
# 2.000000       0.050149
# 4.000000       0.050148
# 16.000000      0.050142
# step   chosen_sample
# query       avg_disc
# all mi      0.050145

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72018/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#            avg_disc
# mi
# 0.001248   2.764589
# 0.015625   0.775650
# 0.031250   0.539979
# 0.062500   0.403893
# 0.250000   0.227108
# 1.000000   0.157123
# 2.000000   0.152322
# 4.000000   0.137676
# 16.000000  0.134443

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#            avg_disc
# mi
# 0.001248   2.630068
# 0.015625   0.647300
# 0.031250   0.403750
# 0.062500   0.265904
# 0.250000   0.093867
# 1.000000   0.027775
# 2.000000   0.017724
# 4.000000   0.008635
# 16.000000  0.000779

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()
