# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   -- sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   -- sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   -- avg(l_quantity) as avg_qty,
#   -- avg(l_extendedprice) as avg_price,
#   -- avg(l_discount) as avg_disc,
#   count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'N'
#   and l_linestatus = 'F'
# ```

# %%
EXPERIMENT = 'pac-q1-count-order-N-F'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'N') &
        (lineitem_df['l_linestatus'] == 'F')
    ]
    print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        # float(discounted_price.sum()),                      # sum_disc_price
        # float(charged_price.sum()),                         # sum_charge
        # float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        # float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        # float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# (3765, 16)
# [3765.0]
# [3765.0]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['count_order']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 147790  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        print(f'iteration : {i}')
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np
# Out:
# (3765, 16)
# [3765.0]

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
# TODO: Change it back to 1000
EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    out_np = generate_samples() # generate samples (results of running the query)
    print(f"Generate samples... {len(out_np)} samples generated.")

    # print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# iteration : 0
# (1880, 16)
# [1880.0]
# (1885, 16)
# [1885.0]
# iteration : 1
# (1925, 16)
# [1925.0]
# (1840, 16)
# [1840.0]
# iteration : 2
# (1858, 16)
# [1858.0]
# (1907, 16)
# [1907.0]
# iteration : 3
# (1902, 16)
# [1902.0]
# (1863, 16)
# [1863.0]
# iteration : 4
# (1913, 16)
# [1913.0]
# (1852, 16)
# [1852.0]
# iteration : 5
# (1854, 16)
# [1854.0]
# (1911, 16)
# [1911.0]
# iteration : 6
# (1831, 16)
# [1831.0]
# (1934, 16)
# [1934.0]
# iteration : 7
# (1894, 16)
# [1894.0]
# (1871, 16)
# [1871.0]
# iteration : 8
# (1885, 16)
# [1885.0]
# (1880, 16)
# [1880.0]
# iteration : 9
# (1878, 16)
# [1878.0]
# (1887, 16)
# [1887.0]
# iteration : 10
# (1850, 16)
# [1850.0]
# (1915, 16)
# [1915.0]
# iteration : 11
# (1888, 16)
# [1888.0]
# (1877, 16)
# [1877.0]
# iteration : 12
# (1894, 16)
# [1894.0]
# (1871, 16)
# [1871.0]
# iteration : 13
# (1895, 16)
# [1895.0]
# (1870, 16)
# [1870.0]
# iteration : 14
# (1920, 16)
# [1920.0]
# (1845, 16)
# [1845.0]
# iteration : 15
# (1859, 16)
# [1859.0]
# (1906, 16)
# [1906.0]
# iteration : 16
# (1878, 16)
# [1878.0]
# (1887, 16)
# [1887.0]
# iteration : 17
# (1859, 16)
# [1859.0]
# (1906, 16)
# [1906.0]
# iteration : 18
# (1867, 16)
# Chosen Sample [3734.]
# Chosen Sample [3788.]
# Chosen Sample [3690.]
# Chosen Sample [3772.]
# Chosen Sample [3794.]
# Chosen Sample [3860.]
# Chosen Sample [3726.]
# Chosen Sample [3776.]
# Chosen Sample [3770.]
# Chosen Sample [3750.]
# Chosen Sample [3748.]
# Chosen Sample [3802.]
# Chosen Sample [3674.]
# Chosen Sample [3848.]
# Chosen Sample [3776.]
# Chosen Sample [3762.]
# Chosen Sample [3876.]
# Chosen Sample [3786.]
# Chosen Sample [3976.]
# Chosen Sample [3834.]
# Chosen Sample [3780.]
# Chosen Sample [3864.]
# Chosen Sample [3684.]
# Chosen Sample [3806.]
# Chosen Sample [3698.]
# Chosen Sample [3720.]
# Chosen Sample [3928.]
# Chosen Sample [3820.]
# Chosen Sample [3812.]
# Chosen Sample [3836.]
# Chosen Sample [3822.]
# Chosen Sample [3818.]
# Chosen Sample [3772.]
# Chosen Sample [3776.]
# Chosen Sample [3694.]
# Chosen Sample [3854.]
# Chosen Sample [3684.]
# Chosen Sample [3830.]
# Chosen Sample [3758.]
# Chosen Sample [3666.]
# Chosen Sample [3718.]
# Chosen Sample [3734.]
# Chosen Sample [3796.]
# Chosen Sample [3822.]
# Chosen Sample [3726.]
# Chosen Sample [3790.]
# Chosen Sample [3750.]
# Chosen Sample [3758.]
# Chosen Sample [3718.]
# Chosen Sample [3884.]
# Chosen Sample [3710.]
# Chosen Sample [3792.]
# Chosen Sample [3762.]
# Chosen Sample [3768.]
# Chosen Sample [3786.]
# Chosen Sample [3768.]
# Chosen Sample [3728.]
# Chosen Sample [3638.]
# Chosen Sample [3814.]
# Chosen Sample [3694.]
# Chosen Sample [3740.]
# Chosen Sample [3836.]
# Chosen Sample [3724.]
# Chosen Sample [3792.]
# Chosen Sample [3722.]
# Chosen Sample [3788.]
# Chosen Sample [3672.]
# Chosen Sample [3792.]
# Chosen Sample [3780.]
# Chosen Sample [3782.]
# Chosen Sample [3626.]
# Chosen Sample [3816.]
# Chosen Sample [3790.]
# Chosen Sample [3822.]
# Chosen Sample [3878.]
# Chosen Sample [3740.]
# Chosen Sample [3742.]
# Chosen Sample [3826.]
# Chosen Sample [3798.]
# Chosen Sample [3784.]
# Chosen Sample [3614.]
# Chosen Sample [3716.]
# Chosen Sample [3782.]
# Chosen Sample [3792.]
# Chosen Sample [3854.]
# Chosen Sample [3774.]
# Chosen Sample [3870.]
# Chosen Sample [3790.]
# Chosen Sample [3846.]
# Chosen Sample [3786.]
# Chosen Sample [3760.]
# Chosen Sample [3740.]
# Chosen Sample [3792.]
# Chosen Sample [3668.]
# Chosen Sample [3786.]
# Chosen Sample [3756.]
# Chosen Sample [3652.]
# Chosen Sample [3744.]
# Chosen Sample [3700.]
# Chosen Sample [3808.]
# Chosen Sample [3788.]
# Chosen Sample [3766.]
# Chosen Sample [3816.]
# Chosen Sample [3806.]
# Chosen Sample [3724.]
# Chosen Sample [3748.]
# Chosen Sample [3712.]
# Chosen Sample [3794.]
# Chosen Sample [3770.]
# Chosen Sample [3726.]
# Chosen Sample [3770.]
# Chosen Sample [3752.]
# Chosen Sample [3810.]
# Chosen Sample [3704.]
# Chosen Sample [3774.]
# Chosen Sample [3776.]
# Chosen Sample [3824.]
# Chosen Sample [3830.]
# Chosen Sample [3892.]
# Chosen Sample [3740.]
# Chosen Sample [3738.]
# Chosen Sample [3764.]
# Chosen Sample [3734.]
# Chosen Sample [3722.]
# Chosen Sample [3732.]
# Chosen Sample [3744.]
# Chosen Sample [3686.]
# Chosen Sample [3808.]
# Chosen Sample [3812.]
# Chosen Sample [3730.]
# Chosen Sample [3768.]
# Chosen Sample [3698.]
# Chosen Sample [3722.]
# Chosen Sample [3768.]
# Chosen Sample [3874.]
# Chosen Sample [3760.]
# Chosen Sample [3790.]
# Chosen Sample [3702.]
# Chosen Sample [3730.]
# Chosen Sample [3714.]
# Chosen Sample [3780.]
# Chosen Sample [3802.]
# Chosen Sample [3756.]
# Chosen Sample [3824.]
# Chosen Sample [3880.]
# Chosen Sample [3790.]
# Chosen Sample [3798.]
# Chosen Sample [3802.]
# Chosen Sample [3708.]
# Chosen Sample [3746.]
# Chosen Sample [3674.]
# Chosen Sample [3716.]
# Chosen Sample [3708.]
# Chosen Sample [3662.]
# Chosen Sample [3684.]
# Chosen Sample [3778.]
# Chosen Sample [3830.]
# Chosen Sample [3806.]
# Chosen Sample [3756.]
# Chosen Sample [3814.]
# Chosen Sample [3856.]
# Chosen Sample [3776.]
# Chosen Sample [3806.]
# Chosen Sample [3704.]
# Chosen Sample [3770.]
# Chosen Sample [3780.]
# Chosen Sample [3710.]
# Chosen Sample [3684.]
# Chosen Sample [3782.]
# Chosen Sample [3778.]
# Chosen Sample [3714.]
# Chosen Sample [3768.]
# Chosen Sample [3780.]
# Chosen Sample [3806.]
# Chosen Sample [3688.]
# Chosen Sample [3798.]
# Chosen Sample [3906.]
# Chosen Sample [3794.]
# Chosen Sample [3768.]
# Chosen Sample [3842.]
# Chosen Sample [3710.]
# Chosen Sample [3804.]
# Chosen Sample [3782.]
# Chosen Sample [3744.]
# Chosen Sample [3720.]
# Chosen Sample [3832.]
# Chosen Sample [3712.]
# Chosen Sample [3692.]
# Chosen Sample [3738.]
# Chosen Sample [3792.]
# Chosen Sample [3672.]
# Chosen Sample [3750.]
# Chosen Sample [3760.]
# Chosen Sample [3758.]
# Chosen Sample [3744.]
# Chosen Sample [3838.]
# Chosen Sample [3730.]
# Chosen Sample [3788.]
# Chosen Sample [3586.]
# Chosen Sample [3708.]
# Chosen Sample [3728.]
# Chosen Sample [3700.]
# Chosen Sample [3742.]
# Chosen Sample [3752.]
# Chosen Sample [3826.]
# Chosen Sample [3660.]
# Chosen Sample [3796.]
# Chosen Sample [3892.]
# Chosen Sample [3784.]
# Chosen Sample [3860.]
# Chosen Sample [3702.]
# Chosen Sample [3776.]
# Chosen Sample [3742.]
# Chosen Sample [3810.]
# Chosen Sample [3770.]
# Chosen Sample [3756.]
# Chosen Sample [3810.]
# Chosen Sample [3838.]
# Chosen Sample [3702.]
# Chosen Sample [3806.]
# Chosen Sample [3718.]
# Chosen Sample [3856.]
# Chosen Sample [3756.]
# Chosen Sample [3874.]
# Chosen Sample [3684.]
# Chosen Sample [3830.]
# Chosen Sample [3870.]
# Chosen Sample [3772.]
# Chosen Sample [3736.]
# Chosen Sample [3924.]
# Chosen Sample [3738.]
# Chosen Sample [3806.]
# Chosen Sample [3814.]
# Chosen Sample [3788.]
# Chosen Sample [3920.]
# Chosen Sample [3662.]
# Chosen Sample [3740.]
# Chosen Sample [3766.]
# Chosen Sample [3638.]
# Chosen Sample [3738.]
# Chosen Sample [3696.]
# Chosen Sample [3758.]
# Chosen Sample [3806.]
# Chosen Sample [3742.]
# Chosen Sample [3712.]
# Chosen Sample [3832.]
# Chosen Sample [3740.]
# Chosen Sample [3700.]
# Chosen Sample [3772.]
# Chosen Sample [3782.]
# Chosen Sample [3804.]
# Chosen Sample [3828.]
# Chosen Sample [3788.]
# Chosen Sample [3714.]
# Chosen Sample [3720.]
# Chosen Sample [3804.]
# Chosen Sample [3768.]
# Chosen Sample [3720.]
# Chosen Sample [3658.]
# Chosen Sample [3766.]
# Chosen Sample [3748.]
# Chosen Sample [3804.]
# Chosen Sample [3748.]
# Chosen Sample [3740.]
# Chosen Sample [3768.]
# Chosen Sample [3718.]
# Chosen Sample [3692.]
# Chosen Sample [3776.]
# Chosen Sample [3868.]
# Chosen Sample [3880.]
# Chosen Sample [3756.]
# Chosen Sample [3788.]
# Chosen Sample [3720.]
# Chosen Sample [3782.]
# Chosen Sample [3708.]
# Chosen Sample [3762.]
# Chosen Sample [3770.]
# Chosen Sample [3790.]
# Chosen Sample [3708.]
# Chosen Sample [3690.]
# Chosen Sample [3816.]
# Chosen Sample [3840.]
# Chosen Sample [3764.]
# Chosen Sample [3712.]
# Chosen Sample [3772.]
# Chosen Sample [3806.]
# Chosen Sample [3830.]
# Chosen Sample [3752.]
# Chosen Sample [3710.]
# Chosen Sample [3936.]
# Chosen Sample [3796.]
# Chosen Sample [3726.]
# Chosen Sample [3798.]
# Chosen Sample [3754.]
# Chosen Sample [3696.]
# Chosen Sample [3836.]
# Chosen Sample [3724.]
# Chosen Sample [3812.]
# Chosen Sample [3758.]
# Chosen Sample [3724.]
# Chosen Sample [3622.]
# Chosen Sample [3762.]
# Chosen Sample [3858.]
# Chosen Sample [3732.]
# Chosen Sample [3798.]
# Chosen Sample [3892.]
# Chosen Sample [3816.]
# Chosen Sample [3790.]
# Chosen Sample [3792.]
# Chosen Sample [3806.]
# Chosen Sample [3812.]
# Chosen Sample [3742.]
# Chosen Sample [3726.]
# Chosen Sample [3744.]
# Chosen Sample [3708.]
# Chosen Sample [3802.]
# Chosen Sample [3818.]
# Chosen Sample [3786.]
# Chosen Sample [3684.]
# Chosen Sample [3834.]
# Chosen Sample [3832.]
# Chosen Sample [3766.]
# Chosen Sample [3846.]
# Chosen Sample [3800.]
# Chosen Sample [3776.]
# Chosen Sample [3814.]
# Chosen Sample [3706.]
# Chosen Sample [3782.]
# Chosen Sample [3706.]
# Chosen Sample [3702.]
# Chosen Sample [3840.]
# Chosen Sample [3734.]
# Chosen Sample [3618.]
# Chosen Sample [3766.]
# Chosen Sample [3680.]
# Chosen Sample [3800.]
# Chosen Sample [3724.]
# Chosen Sample [3814.]
# Chosen Sample [3762.]
# Chosen Sample [3772.]
# Chosen Sample [3760.]
# Chosen Sample [3606.]
# Chosen Sample [3720.]
# Chosen Sample [3694.]
# Chosen Sample [3720.]
# Chosen Sample [3706.]
# Chosen Sample [3784.]
# Chosen Sample [3906.]
# Chosen Sample [3742.]
# Chosen Sample [3724.]
# Chosen Sample [3624.]
# Chosen Sample [3752.]
# Chosen Sample [3860.]
# Chosen Sample [3710.]
# Chosen Sample [3832.]
# Chosen Sample [3850.]
# Chosen Sample [3706.]
# Chosen Sample [3644.]
# Chosen Sample [3742.]
# Chosen Sample [3702.]
# Chosen Sample [3744.]
# Chosen Sample [3922.]
# Chosen Sample [3712.]
# Chosen Sample [3714.]
# Chosen Sample [3822.]
# Chosen Sample [3752.]
# Chosen Sample [3704.]
# Chosen Sample [3710.]
# Chosen Sample [3688.]
# Chosen Sample [3722.]
# Chosen Sample [3714.]
# Chosen Sample [3702.]
# Chosen Sample [3826.]
# Chosen Sample [3838.]
# Chosen Sample [3818.]
# Chosen Sample [3668.]
# Chosen Sample [3848.]
# Chosen Sample [3618.]
# Chosen Sample [3786.]
# Chosen Sample [3752.]
# Chosen Sample [3748.]
# Chosen Sample [3746.]
# Chosen Sample [3724.]
# Chosen Sample [3802.]
# Chosen Sample [3744.]
# Chosen Sample [3746.]
# Chosen Sample [3754.]
# Chosen Sample [3820.]
# Chosen Sample [3752.]
# Chosen Sample [3718.]
# Chosen Sample [3784.]
# Chosen Sample [3760.]
# Chosen Sample [3702.]
# Chosen Sample [3670.]
# Chosen Sample [3770.]
# Chosen Sample [3818.]
# Chosen Sample [3792.]
# Chosen Sample [3708.]
# Chosen Sample [3752.]
# Chosen Sample [3656.]
# Chosen Sample [3888.]
# Chosen Sample [3794.]
# Chosen Sample [3826.]
# Chosen Sample [3722.]
# Chosen Sample [3702.]
# Chosen Sample [3782.]
# Chosen Sample [3800.]
# Chosen Sample [3826.]
# Chosen Sample [3828.]
# Chosen Sample [3876.]
# Chosen Sample [3624.]
# Chosen Sample [3742.]
# Chosen Sample [3808.]
# Chosen Sample [3704.]
# Chosen Sample [3784.]
# Chosen Sample [3818.]
# Chosen Sample [3816.]
# Chosen Sample [3870.]
# Chosen Sample [3704.]
# Chosen Sample [3728.]
# Chosen Sample [3786.]
# Chosen Sample [3704.]
# Chosen Sample [3654.]
# Chosen Sample [3766.]
# Chosen Sample [3824.]
# Chosen Sample [3826.]
# Chosen Sample [3718.]
# Chosen Sample [3764.]
# Chosen Sample [3816.]
# Chosen Sample [3740.]
# Chosen Sample [3770.]
# Chosen Sample [3760.]
# Chosen Sample [3734.]
# Chosen Sample [3738.]
# Chosen Sample [3718.]
# Chosen Sample [3772.]
# Chosen Sample [3750.]
# Chosen Sample [3848.]
# Chosen Sample [3698.]
# Chosen Sample [3834.]
# Chosen Sample [3848.]
# Chosen Sample [3820.]
# Chosen Sample [3790.]
# Chosen Sample [3666.]
# Chosen Sample [3814.]
# Chosen Sample [3718.]
# Chosen Sample [3784.]
# Chosen Sample [3684.]
# Chosen Sample [3842.]
# Chosen Sample [3752.]
# Chosen Sample [3804.]
# Chosen Sample [3768.]
# Chosen Sample [3730.]
# Chosen Sample [3816.]
# Chosen Sample [3858.]
# Chosen Sample [3748.]
# Chosen Sample [3738.]
# Chosen Sample [3724.]
# Chosen Sample [3748.]
# Chosen Sample [3728.]
# Chosen Sample [3610.]
# Chosen Sample [3736.]
# Chosen Sample [3668.]
# Chosen Sample [3750.]
# Chosen Sample [3728.]
# Chosen Sample [3788.]
# Chosen Sample [3800.]
# Chosen Sample [3960.]
# Chosen Sample [3784.]
# Chosen Sample [3812.]
# Chosen Sample [3762.]
# Chosen Sample [3726.]
# Chosen Sample [3908.]
# Chosen Sample [3832.]
# Chosen Sample [3788.]
# Chosen Sample [3696.]
# Chosen Sample [3718.]
# Chosen Sample [3748.]
# Chosen Sample [3778.]
# Chosen Sample [3736.]
# Chosen Sample [3788.]
# Chosen Sample [3814.]
# Chosen Sample [3836.]
# Chosen Sample [3726.]
# Chosen Sample [3694.]
# Chosen Sample [3846.]
# Chosen Sample [3874.]
# Chosen Sample [3736.]
# Chosen Sample [3818.]
# Chosen Sample [3712.]
# Chosen Sample [3794.]
# Chosen Sample [3760.]
# Chosen Sample [3872.]
# Chosen Sample [3798.]
# Chosen Sample [3682.]
# Chosen Sample [3896.]
# Chosen Sample [3638.]
# Chosen Sample [3836.]
# Chosen Sample [3704.]
# Chosen Sample [3852.]
# Chosen Sample [3750.]
# Chosen Sample [3678.]
# Chosen Sample [3670.]
# Chosen Sample [3842.]
# Chosen Sample [3812.]
# Chosen Sample [3760.]
# Chosen Sample [3760.]
# Chosen Sample [3740.]
# Chosen Sample [3760.]
# Chosen Sample [3796.]
# Chosen Sample [3870.]
# Chosen Sample [3742.]
# Chosen Sample [3796.]
# Chosen Sample [3808.]
# Chosen Sample [3724.]
# Chosen Sample [3784.]
# Chosen Sample [3700.]
# Chosen Sample [3802.]
# Chosen Sample [3752.]
# Chosen Sample [3916.]
# Chosen Sample [3750.]
# Chosen Sample [3798.]
# Chosen Sample [3770.]
# Chosen Sample [3762.]
# Chosen Sample [3832.]
# Chosen Sample [3706.]
# Chosen Sample [3732.]
# Chosen Sample [3838.]
# Chosen Sample [3694.]
# Chosen Sample [3814.]
# Chosen Sample [3888.]
# Chosen Sample [3820.]
# Chosen Sample [3774.]
# Chosen Sample [3708.]
# Chosen Sample [3658.]
# Chosen Sample [3754.]
# Chosen Sample [3788.]
# Chosen Sample [3822.]
# Chosen Sample [3772.]
# Chosen Sample [3850.]
# Chosen Sample [3832.]
# Chosen Sample [3768.]
# Chosen Sample [3718.]
# Chosen Sample [3634.]
# Chosen Sample [3842.]
# Chosen Sample [3680.]
# Chosen Sample [3788.]
# Chosen Sample [3818.]
# Chosen Sample [3736.]
# Chosen Sample [3768.]
# Chosen Sample [3770.]
# Chosen Sample [3780.]
# Chosen Sample [3828.]
# Chosen Sample [3798.]
# Chosen Sample [3752.]
# Chosen Sample [3816.]
# Chosen Sample [3792.]
# Chosen Sample [3784.]
# Chosen Sample [3746.]
# Chosen Sample [3636.]
# Chosen Sample [3794.]
# Chosen Sample [3782.]
# Chosen Sample [3740.]
# Chosen Sample [3898.]
# Chosen Sample [3776.]
# Chosen Sample [3796.]
# Chosen Sample [3758.]
# Chosen Sample [3808.]
# Chosen Sample [3698.]
# Chosen Sample [3814.]
# Chosen Sample [3746.]
# Chosen Sample [3748.]
# Chosen Sample [3816.]
# Chosen Sample [3800.]
# Chosen Sample [3832.]
# Chosen Sample [3828.]
# Chosen Sample [3802.]
# Chosen Sample [3842.]
# Chosen Sample [3770.]
# Chosen Sample [3788.]
# Chosen Sample [3870.]
# Chosen Sample [3714.]
# Chosen Sample [3752.]
# Chosen Sample [3804.]
# Chosen Sample [3780.]
# Chosen Sample [3762.]
# Chosen Sample [3864.]
# Chosen Sample [3684.]
# Chosen Sample [3660.]
# Chosen Sample [3728.]
# Chosen Sample [3836.]
# Chosen Sample [3844.]
# Chosen Sample [3914.]
# Chosen Sample [3842.]
# Chosen Sample [3862.]
# Chosen Sample [3760.]
# Chosen Sample [3778.]
# Chosen Sample [3756.]
# Chosen Sample [3830.]
# Chosen Sample [3726.]
# Chosen Sample [3912.]
# Chosen Sample [3844.]
# Chosen Sample [3756.]
# Chosen Sample [3774.]
# Chosen Sample [3796.]
# Chosen Sample [3768.]
# Chosen Sample [3776.]
# Chosen Sample [3718.]
# Chosen Sample [3788.]
# Chosen Sample [3794.]
# Chosen Sample [3694.]
# Chosen Sample [3792.]
# Chosen Sample [3804.]
# Chosen Sample [3758.]
# Chosen Sample [3792.]
# Chosen Sample [3680.]
# Chosen Sample [3754.]
# Chosen Sample [3840.]
# Chosen Sample [3766.]
# Chosen Sample [3774.]
# Chosen Sample [3750.]
# Chosen Sample [3708.]
# Chosen Sample [3752.]
# Chosen Sample [3760.]
# Chosen Sample [3740.]
# Chosen Sample [3800.]
# Chosen Sample [3718.]
# Chosen Sample [3770.]
# Chosen Sample [3770.]
# Chosen Sample [3838.]
# Chosen Sample [3830.]
# Chosen Sample [3742.]
# Chosen Sample [3770.]
# Chosen Sample [3746.]
# Chosen Sample [3806.]
# Chosen Sample [3782.]
# Chosen Sample [3752.]
# Chosen Sample [3746.]
# Chosen Sample [3866.]
# Chosen Sample [3844.]
# Chosen Sample [3686.]
# Chosen Sample [3734.]
# Chosen Sample [3712.]
# Chosen Sample [3666.]
# Chosen Sample [3818.]
# Chosen Sample [3840.]
# Chosen Sample [3726.]
# Chosen Sample [3734.]
# Chosen Sample [3894.]
# Chosen Sample [3758.]
# Chosen Sample [3816.]
# Chosen Sample [3706.]
# Chosen Sample [3748.]
# Chosen Sample [3734.]
# Chosen Sample [3840.]
# Chosen Sample [3848.]
# Chosen Sample [3714.]
# Chosen Sample [3784.]
# Chosen Sample [3780.]
# Chosen Sample [3774.]
# Chosen Sample [3756.]
# Chosen Sample [3884.]
# Chosen Sample [3746.]
# Chosen Sample [3724.]
# Chosen Sample [3754.]
# Chosen Sample [3778.]
# Chosen Sample [3790.]
# Chosen Sample [3748.]
# Chosen Sample [3762.]
# Chosen Sample [3776.]
# Chosen Sample [3824.]
# Chosen Sample [3704.]
# Chosen Sample [3690.]
# Chosen Sample [3774.]
# Chosen Sample [3748.]
# Chosen Sample [3820.]
# Chosen Sample [3746.]
# Chosen Sample [3748.]
# Chosen Sample [3840.]
# Chosen Sample [3670.]
# Chosen Sample [3718.]
# Chosen Sample [3750.]
# Chosen Sample [3720.]
# Chosen Sample [3770.]
# Chosen Sample [3862.]
# Chosen Sample [3806.]
# Chosen Sample [3818.]
# Chosen Sample [3802.]
# Chosen Sample [3732.]
# Chosen Sample [3738.]
# Chosen Sample [3848.]
# Chosen Sample [3810.]
# Chosen Sample [3748.]
# Chosen Sample [3678.]
# Chosen Sample [3778.]
# Chosen Sample [3708.]
# Chosen Sample [3846.]
# Chosen Sample [3738.]
# Chosen Sample [3750.]
# Chosen Sample [3812.]
# Chosen Sample [3732.]
# Chosen Sample [3808.]
# Chosen Sample [3756.]
# Chosen Sample [3826.]
# Chosen Sample [3794.]
# Chosen Sample [3846.]
# Chosen Sample [3834.]
# Chosen Sample [3748.]
# Chosen Sample [3674.]
# Chosen Sample [3662.]
# Chosen Sample [3948.]
# Chosen Sample [3792.]
# Chosen Sample [3794.]
# Chosen Sample [3878.]
# Chosen Sample [3732.]
# Chosen Sample [3806.]
# Chosen Sample [3810.]
# Chosen Sample [3784.]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                 scale chosen_sample           chosen_noise  \
# 0  0.001248  [1487633.0391542679]      [3810.0]  [-1962.6970477883895]
# 1  0.001248  [1487633.0391542679]      [3792.0]  [-1238.8802016209643]
# 2  0.001248  [1487633.0391542679]      [3760.0]   [1634.6806493039555]
# 3  0.001248  [1487633.0391542679]      [3730.0]  [-110.58619561366261]
# 4  0.001248  [1487633.0391542679]      [3868.0]  [-1795.5401716797803]
#
#                 release
# 0  [1847.3029522116105]
# 1  [2553.1197983790357]
# 2   [5394.680649303956]
# 3  [3619.4138043863372]
# 4  [2072.4598283202195]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi         scale chosen_sample chosen_noise      release
# query             count_order   count_order  count_order  count_order
# 0      0.001248  1.487633e+06        3810.0 -1962.697048  1847.302952
# 1      0.001248  1.487633e+06        3792.0 -1238.880202  2553.119798
# 2      0.001248  1.487633e+06        3760.0  1634.680649  5394.680649
# 3      0.001248  1.487633e+06        3730.0  -110.586196  3619.413804
# 4      0.001248  1.487633e+06        3868.0 -1795.540172  2072.459828

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33281/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step              scale chosen_sample chosen_noise      release
# query       count_order   count_order  count_order  count_order
# mi
# 0.001248   1.487633e+06      3766.264     8.069506  3774.333506
# 0.015625   1.188506e+05      3760.206    -4.899625  3755.306375
# 0.031250   5.942528e+04      3764.540     7.090205  3771.630205
# 0.062500   2.971264e+04      3762.640     0.606696  3763.246696
# 0.250000   7.428160e+03      3761.668     1.811407  3763.479407
# 1.000000   1.857040e+03      3763.360     0.135606  3763.495606
# 2.000000   9.285200e+02      3764.238    -0.372423  3763.865577
# 4.000000   4.642600e+02      3766.452     1.223512  3767.675512
# 16.000000  1.160650e+02      3769.520     0.515197  3770.035197

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['count_order'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi                0.001248
# count_order    1847.302952
# Name: 0, dtype: float64
# mi                0.001248
# count_order    2553.119798
# Name: 1, dtype: float64
# mi                0.001248
# count_order    5394.680649
# Name: 2, dtype: float64
# mi                0.001248
# count_order    3619.413804
# Name: 3, dtype: float64
# mi                0.001248
# count_order    2072.459828
# Name: 4, dtype: float64
# mi                0.001248
# count_order    2099.358863
# Name: 5, dtype: float64
# mi                0.001248
# count_order    3398.953175
# Name: 6, dtype: float64
# mi                0.001248
# count_order    3412.472412
# Name: 7, dtype: float64
# mi                0.001248
# count_order    5256.266499
# Name: 8, dtype: float64
# mi                0.001248
# count_order    5692.727636
# Name: 9, dtype: float64
# mi                0.001248
# count_order    2299.307211
# Name: 10, dtype: float64
# mi                0.001248
# count_order    3142.562141
# Name: 11, dtype: float64
# mi                0.001248
# count_order    4994.060571
# Name: 12, dtype: float64
# mi                0.001248
# count_order    1958.453761
# Name: 13, dtype: float64
# mi                0.001248
# count_order    2733.671089
# Name: 14, dtype: float64
# mi                0.001248
# count_order    5391.344688
# Name: 15, dtype: float64
# mi                0.001248
# count_order    3535.040179
# Name: 16, dtype: float64
# mi                0.001248
# count_order    3553.953455
# Name: 17, dtype: float64
# mi                0.001248
# count_order    3581.704584
# Name: 18, dtype: float64
# mi                0.001248
# count_order    3840.073906
# Name: 19, dtype: float64
# mi                0.001248
# count_order    4440.802864
# Name: 20, dtype: float64
# mi                0.001248
# count_order    5590.736235
# Name: 21, dtype: float64
# mi                0.001248
# count_order    1336.799742
# Name: 22, dtype: float64
# mi                0.001248
# count_order    3979.023807
# Name: 23, dtype: float64
# mi                0.001248
# count_order    4110.251852
# Name: 24, dtype: float64
# mi                0.001248
# count_order    5172.981555
# Name: 25, dtype: float64
# mi                0.001248
# count_order    3815.375003
# Name: 26, dtype: float64
# mi                0.001248
# count_order    3283.390485
# Name: 27, dtype: float64
# mi                0.001248
# count_order    2576.942809
# Name: 28, dtype: float64
# mi                0.001248
# count_order    2826.996561
# Name: 29, dtype: float64
# mi                0.001248
# count_order    3900.726502
# Name: 30, dtype: float64
# mi                0.001248
# count_order    2070.262326
# Name: 31, dtype: float64
# mi                0.001248
# count_order    6602.374669
# Name: 32, dtype: float64
# mi                0.001248
# count_order    3192.017162
# Name: 33, dtype: float64
# mi                0.001248
# count_order    1100.532901
# Name: 34, dtype: float64
# mi                0.001248
# count_order    5288.862325
# Name: 35, dtype: float64
# mi                0.001248
# count_order    4249.312903
# Name: 36, dtype: float64
# mi                0.001248
# count_order    1784.691479
# Name: 37, dtype: float64
# mi                0.001248
# count_order    4661.042133
# Name: 38, dtype: float64
# mi                0.001248
# count_order    4956.544383
# Name: 39, dtype: float64
# mi                0.001248
# count_order    6093.719803
# Name: 40, dtype: float64
# mi                0.001248
# count_order    5617.919024
# Name: 41, dtype: float64
# mi                0.001248
# count_order    5966.600731
# Name: 42, dtype: float64
# mi                0.001248
# count_order    5419.525915
# Name: 43, dtype: float64
# mi                0.001248
# count_order    1983.927199
# Name: 44, dtype: float64
# mi                0.001248
# count_order    4351.065859
# Name: 45, dtype: float64
# mi                0.001248
# count_order    2857.901274
# Name: 46, dtype: float64
# mi                0.001248
# count_order    4415.196324
# Name: 47, dtype: float64
# mi                0.001248
# count_order    3533.302289
# Name: 48, dtype: float64
# mi                0.001248
# count_order    4334.453049
# Name: 49, dtype: float64
# mi                0.001248
# count_order    5699.500105
# Name: 50, dtype: float64
# mi                0.001248
# count_order    4732.344323
# Name: 51, dtype: float64
# mi                0.001248
# count_order    6773.968769
# Name: 52, dtype: float64
# mi               0.001248
# count_order    304.571404
# Name: 53, dtype: float64
# mi                0.001248
# count_order    1583.338595
# Name: 54, dtype: float64
# mi                0.001248
# count_order    3382.477843
# Name: 55, dtype: float64
# mi                0.001248
# count_order    6594.253606
# Name: 56, dtype: float64
# mi                0.001248
# count_order    4192.073402
# Name: 57, dtype: float64
# mi                0.001248
# count_order    2953.165575
# Name: 58, dtype: float64
# mi                0.001248
# count_order    3597.194850
# Name: 59, dtype: float64
# mi                0.001248
# count_order    4485.921219
# Name: 60, dtype: float64
# mi                0.001248
# count_order    3569.632668
# Name: 61, dtype: float64
# mi                0.001248
# count_order    2817.987672
# Name: 62, dtype: float64
# mi                0.001248
# count_order    4094.166359
# Name: 63, dtype: float64
# mi                0.001248
# count_order    5590.734000
# Name: 64, dtype: float64
# mi                0.001248
# count_order    3813.294098
# Name: 65, dtype: float64
# mi                0.001248
# count_order    3416.562451
# Name: 66, dtype: float64
# mi                0.001248
# count_order    4655.709031
# Name: 67, dtype: float64
# mi                0.001248
# count_order    5295.952639
# Name: 68, dtype: float64
# mi                0.001248
# count_order    4600.185519
# Name: 69, dtype: float64
# mi                0.001248
# count_order    2311.829995
# Name: 70, dtype: float64
# mi                0.001248
# count_order    4044.585933
# Name: 71, dtype: float64
# mi                0.001248
# count_order    3592.707654
# Name: 72, dtype: float64
# mi                0.001248
# count_order    3171.084268
# Name: 73, dtype: float64
# mi                0.001248
# count_order    5050.582333
# Name: 74, dtype: float64
# mi                0.001248
# count_order    2803.676964
# Name: 75, dtype: float64
# mi                0.001248
# count_order    3204.730852
# Name: 76, dtype: float64
# mi                0.001248
# count_order    3075.486424
# Name: 77, dtype: float64
# mi               0.001248
# count_order    699.822326
# Name: 78, dtype: float64
# mi                0.001248
# count_order    2459.861060
# Name: 79, dtype: float64
# mi                0.001248
# count_order    2641.088338
# Name: 80, dtype: float64
# mi                0.001248
# count_order    1639.836902
# Name: 81, dtype: float64
# mi                0.001248
# count_order    1925.495137
# Name: 82, dtype: float64
# mi                0.001248
# count_order    4488.118791
# Name: 83, dtype: float64
# mi                0.001248
# count_order    3595.835208
# Name: 84, dtype: float64
# mi                0.001248
# count_order    3193.098855
# Name: 85, dtype: float64
# mi                0.001248
# count_order    3833.690476
# Name: 86, dtype: float64
# mi                0.001248
# count_order    6419.047529
# Name: 87, dtype: float64
# mi                0.001248
# count_order    4506.227165
# Name: 88, dtype: float64
# mi                0.001248
# count_order    2009.797191
# Name: 89, dtype: float64
# mi                0.001248
# count_order    4453.711310
# Name: 90, dtype: float64
# mi                0.001248
# count_order    4431.046341
# Name: 91, dtype: float64
# mi                0.001248
# count_order    4416.541468
# Name: 92, dtype: float64
# mi                0.001248
# count_order    4102.328372
# Name: 93, dtype: float64
# mi                0.001248
# count_order    5196.087171
# Name: 94, dtype: float64
# mi                0.001248
# count_order    2611.417200
# Name: 95, dtype: float64
# mi                0.001248
# count_order    3543.721381
# Name: 96, dtype: float64
# mi                0.001248
# count_order    3742.113778
# Name: 97, dtype: float64
# mi                0.001248
# count_order    2816.987624
# Name: 98, dtype: float64
# mi                0.001248
# count_order    4747.195718
# Name: 99, dtype: float64
# mi                0.001248
# count_order    4712.599362
# Name: 100, dtype: float64
# mi                0.001248
# count_order    3343.412165
# Name: 101, dtype: float64
# mi                0.001248
# count_order    4584.911008
# Name: 102, dtype: float64
# mi                0.001248
# count_order    3215.056580
# Name: 103, dtype: float64
# mi                0.001248
# count_order    1943.029825
# Name: 104, dtype: float64
# mi                0.001248
# count_order    2812.475015
# Name: 105, dtype: float64
# mi                0.001248
# count_order    2378.827674
# Name: 106, dtype: float64
# mi                0.001248
# count_order    2982.566501
# Name: 107, dtype: float64
# mi                0.001248
# count_order    2032.645409
# Name: 108, dtype: float64
# mi                0.001248
# count_order    3560.251595
# Name: 109, dtype: float64
# mi                0.001248
# count_order    3789.753487
# Name: 110, dtype: float64
# mi                0.001248
# count_order    3155.275207
# Name: 111, dtype: float64
# mi                0.001248
# count_order    2616.430884
# Name: 112, dtype: float64
# mi                0.001248
# count_order    1195.185608
# Name: 113, dtype: float64
# mi                0.001248
# count_order    4118.007929
# Name: 114, dtype: float64
# mi                0.001248
# count_order    1726.055749
# Name: 115, dtype: float64
# mi                0.001248
# count_order    3633.996189
# Name: 116, dtype: float64
# mi                0.001248
# count_order    4551.851345
# Name: 117, dtype: float64
# mi                0.001248
# count_order    5212.735166
# Name: 118, dtype: float64
# mi                0.001248
# count_order    6934.371112
# Name: 119, dtype: float64
# mi                0.001248
# count_order    4249.320793
# Name: 120, dtype: float64
# mi                0.001248
# count_order    3266.337302
# Name: 121, dtype: float64
# mi                0.001248
# count_order    5334.011602
# Name: 122, dtype: float64
# mi                0.001248
# count_order    3982.966739
# Name: 123, dtype: float64
# mi                0.001248
# count_order    3903.704604
# Name: 124, dtype: float64
# mi                0.001248
# count_order    3756.531226
# Name: 125, dtype: float64
# mi                0.001248
# count_order    6511.328603
# Name: 126, dtype: float64
# mi                0.001248
# count_order    3827.172987
# Name: 127, dtype: float64
# mi                0.001248
# count_order    3123.931108
# Name: 128, dtype: float64
# mi                0.001248
# count_order    3943.878599
# Name: 129, dtype: float64
# mi                0.001248
# count_order    5552.010002
# Name: 130, dtype: float64
# mi                0.001248
# count_order    3233.714531
# Name: 131, dtype: float64
# mi                0.001248
# count_order    6223.862594
# Name: 132, dtype: float64
# mi                0.001248
# count_order    5027.556909
# Name: 133, dtype: float64
# mi                0.001248
# count_order    2360.234258
# Name: 134, dtype: float64
# mi                0.001248
# count_order    3740.143934
# Name: 135, dtype: float64
# mi                0.001248
# count_order    3804.407761
# Name: 136, dtype: float64
# mi                0.001248
# count_order    4667.835993
# Name: 137, dtype: float64
# mi                0.001248
# count_order    4308.043715
# Name: 138, dtype: float64
# mi                0.001248
# count_order    5188.237563
# Name: 139, dtype: float64
# mi                0.001248
# count_order    2960.709716
# Name: 140, dtype: float64
# mi                0.001248
# count_order    3081.998300
# Name: 141, dtype: float64
# mi                0.001248
# count_order    3604.805694
# Name: 142, dtype: float64
# mi                0.001248
# count_order    5842.901410
# Name: 143, dtype: float64
# mi                0.001248
# count_order    5137.772111
# Name: 144, dtype: float64
# mi                0.001248
# count_order    5473.794403
# Name: 145, dtype: float64
# mi                0.001248
# count_order    2287.288644
# Name: 146, dtype: float64
# mi                0.001248
# count_order    3308.610660
# Name: 147, dtype: float64
# mi                0.001248
# count_order    5527.108966
# Name: 148, dtype: float64
# mi                0.001248
# count_order    3337.153955
# Name: 149, dtype: float64
# mi                0.001248
# count_order    3113.711526
# Name: 150, dtype: float64
# mi                0.001248
# count_order    3778.041895
# Name: 151, dtype: float64
# mi                0.001248
# count_order    2325.298841
# Name: 152, dtype: float64
# mi                0.001248
# count_order    2426.438901
# Name: 153, dtype: float64
# mi                0.001248
# count_order    5992.787352
# Name: 154, dtype: float64
# mi                0.001248
# count_order    2892.620748
# Name: 155, dtype: float64
# mi                0.001248
# count_order    4168.838227
# Name: 156, dtype: float64
# mi                0.001248
# count_order    2499.737456
# Name: 157, dtype: float64
# mi                0.001248
# count_order    3435.898601
# Name: 158, dtype: float64
# mi                0.001248
# count_order    1439.851939
# Name: 159, dtype: float64
# mi                0.001248
# count_order    3525.592624
# Name: 160, dtype: float64
# mi                0.001248
# count_order    1351.728041
# Name: 161, dtype: float64
# mi                0.001248
# count_order    4757.496266
# Name: 162, dtype: float64
# mi                0.001248
# count_order    4762.244988
# Name: 163, dtype: float64
# mi                0.001248
# count_order    4435.099080
# Name: 164, dtype: float64
# mi                0.001248
# count_order    3248.818534
# Name: 165, dtype: float64
# mi                0.001248
# count_order    4608.682349
# Name: 166, dtype: float64
# mi                0.001248
# count_order    3564.221131
# Name: 167, dtype: float64
# mi                0.001248
# count_order    5337.676258
# Name: 168, dtype: float64
# mi                0.001248
# count_order    2046.128635
# Name: 169, dtype: float64
# mi                0.001248
# count_order    4817.223184
# Name: 170, dtype: float64
# mi                0.001248
# count_order    4049.880278
# Name: 171, dtype: float64
# mi                0.001248
# count_order    2337.670517
# Name: 172, dtype: float64
# mi                0.001248
# count_order    2908.484255
# Name: 173, dtype: float64
# mi                0.001248
# count_order    3133.779407
# Name: 174, dtype: float64
# mi                0.001248
# count_order    3537.012930
# Name: 175, dtype: float64
# mi                0.001248
# count_order    4670.549320
# Name: 176, dtype: float64
# mi                0.001248
# count_order    2716.505199
# Name: 177, dtype: float64
# mi                0.001248
# count_order    4887.609014
# Name: 178, dtype: float64
# mi                0.001248
# count_order    3983.161654
# Name: 179, dtype: float64
# mi                0.001248
# count_order    3396.463738
# Name: 180, dtype: float64
# mi                0.001248
# count_order    4034.305031
# Name: 181, dtype: float64
# mi                0.001248
# count_order    5289.121585
# Name: 182, dtype: float64
# mi                0.001248
# count_order    4991.694438
# Name: 183, dtype: float64
# mi                0.001248
# count_order    4819.380182
# Name: 184, dtype: float64
# mi                0.001248
# count_order    3816.310014
# Name: 185, dtype: float64
# mi                0.001248
# count_order    4118.000548
# Name: 186, dtype: float64
# mi                0.001248
# count_order    2934.363451
# Name: 187, dtype: float64
# mi                0.001248
# count_order    3223.763059
# Name: 188, dtype: float64
# mi                0.001248
# count_order    4283.178029
# Name: 189, dtype: float64
# mi                0.001248
# count_order    5824.277596
# Name: 190, dtype: float64
# mi                0.001248
# count_order    4678.234977
# Name: 191, dtype: float64
# mi                0.001248
# count_order    3424.591445
# Name: 192, dtype: float64
# mi                0.001248
# count_order    4637.317491
# Name: 193, dtype: float64
# mi                0.001248
# count_order    4121.444035
# Name: 194, dtype: float64
# mi                0.001248
# count_order    2381.134121
# Name: 195, dtype: float64
# mi                0.001248
# count_order    5931.120901
# Name: 196, dtype: float64
# mi                0.001248
# count_order    3873.364557
# Name: 197, dtype: float64
# mi                0.001248
# count_order    4134.393556
# Name: 198, dtype: float64
# mi                0.001248
# count_order    4259.561042
# Name: 199, dtype: float64
# mi                0.001248
# count_order    5630.531366
# Name: 200, dtype: float64
# mi                0.001248
# count_order    3864.825268
# Name: 201, dtype: float64
# mi                0.001248
# count_order    7218.882000
# Name: 202, dtype: float64
# mi                0.001248
# count_order    3231.833213
# Name: 203, dtype: float64
# mi                0.001248
# count_order    3420.291452
# Name: 204, dtype: float64
# mi                0.001248
# count_order    4718.373413
# Name: 205, dtype: float64
# mi                0.001248
# count_order    2898.022205
# Name: 206, dtype: float64
# mi                0.001248
# count_order    3741.265408
# Name: 207, dtype: float64
# mi                0.001248
# count_order    2855.560716
# Name: 208, dtype: float64
# mi                0.001248
# count_order    2565.177644
# Name: 209, dtype: float64
# mi                0.001248
# count_order    2851.605045
# Name: 210, dtype: float64
# mi                0.001248
# count_order    3601.076880
# Name: 211, dtype: float64
# mi                0.001248
# count_order    2594.120075
# Name: 212, dtype: float64
# mi                0.001248
# count_order    2552.692829
# Name: 213, dtype: float64
# mi                0.001248
# count_order    3412.024193
# Name: 214, dtype: float64
# mi                0.001248
# count_order    2592.663041
# Name: 215, dtype: float64
# mi                0.001248
# count_order    3338.496048
# Name: 216, dtype: float64
# mi                0.001248
# count_order    3586.834927
# Name: 217, dtype: float64
# mi                0.001248
# count_order    3750.152312
# Name: 218, dtype: float64
# mi                0.001248
# count_order    3861.966211
# Name: 219, dtype: float64
# mi                0.001248
# count_order    4816.287841
# Name: 220, dtype: float64
# mi                0.001248
# count_order    5303.244062
# Name: 221, dtype: float64
# mi                0.001248
# count_order    3114.517261
# Name: 222, dtype: float64
# mi                0.001248
# count_order    3884.102880
# Name: 223, dtype: float64
# mi                0.001248
# count_order    2289.021292
# Name: 224, dtype: float64
# mi                0.001248
# count_order    4523.725583
# Name: 225, dtype: float64
# mi                0.001248
# count_order    3727.343227
# Name: 226, dtype: float64
# mi                0.001248
# count_order    3847.358207
# Name: 227, dtype: float64
# mi                0.001248
# count_order    1522.544093
# Name: 228, dtype: float64
# mi                0.001248
# count_order    5190.818228
# Name: 229, dtype: float64
# mi                0.001248
# count_order    2781.593602
# Name: 230, dtype: float64
# mi                0.001248
# count_order    1623.558004
# Name: 231, dtype: float64
# mi                0.001248
# count_order    1685.747438
# Name: 232, dtype: float64
# mi                0.001248
# count_order    4421.827558
# Name: 233, dtype: float64
# mi                0.001248
# count_order    3228.764332
# Name: 234, dtype: float64
# mi                0.001248
# count_order    3450.435548
# Name: 235, dtype: float64
# mi                0.001248
# count_order    3392.084059
# Name: 236, dtype: float64
# mi                0.001248
# count_order    5528.568770
# Name: 237, dtype: float64
# mi                0.001248
# count_order    4603.941012
# Name: 238, dtype: float64
# mi                0.001248
# count_order    5297.936884
# Name: 239, dtype: float64
# mi                0.001248
# count_order    4376.871134
# Name: 240, dtype: float64
# mi                0.001248
# count_order    5904.424311
# Name: 241, dtype: float64
# mi                0.001248
# count_order    2976.744234
# Name: 242, dtype: float64
# mi                0.001248
# count_order    5508.585398
# Name: 243, dtype: float64
# mi                0.001248
# count_order    3751.286529
# Name: 244, dtype: float64
# mi                0.001248
# count_order    4365.472941
# Name: 245, dtype: float64
# mi                0.001248
# count_order    5443.511363
# Name: 246, dtype: float64
# mi                0.001248
# count_order    3871.732126
# Name: 247, dtype: float64
# mi                0.001248
# count_order    3303.603768
# Name: 248, dtype: float64
# mi                0.001248
# count_order    4577.372124
# Name: 249, dtype: float64
# mi                0.001248
# count_order    5797.818489
# Name: 250, dtype: float64
# mi                0.001248
# count_order    5753.306196
# Name: 251, dtype: float64
# mi                0.001248
# count_order    2670.433832
# Name: 252, dtype: float64
# mi                0.001248
# count_order    3601.822374
# Name: 253, dtype: float64
# mi                0.001248
# count_order    2535.631664
# Name: 254, dtype: float64
# mi                0.001248
# count_order    4265.555888
# Name: 255, dtype: float64
# mi                0.001248
# count_order    2169.180934
# Name: 256, dtype: float64
# mi                0.001248
# count_order    4277.275083
# Name: 257, dtype: float64
# mi                0.001248
# count_order    5703.689481
# Name: 258, dtype: float64
# mi                0.001248
# count_order    4320.940878
# Name: 259, dtype: float64
# mi                0.001248
# count_order    5978.373970
# Name: 260, dtype: float64
# mi                0.001248
# count_order    1732.619942
# Name: 261, dtype: float64
# mi                0.001248
# count_order    4071.518413
# Name: 262, dtype: float64
# mi                0.001248
# count_order    3161.058865
# Name: 263, dtype: float64
# mi               0.001248
# count_order    910.204092
# Name: 264, dtype: float64
# mi                0.001248
# count_order    3832.296321
# Name: 265, dtype: float64
# mi                0.001248
# count_order    4056.966627
# Name: 266, dtype: float64
# mi                0.001248
# count_order    3732.095158
# Name: 267, dtype: float64
# mi                0.001248
# count_order    5483.068328
# Name: 268, dtype: float64
# mi                0.001248
# count_order    3692.030356
# Name: 269, dtype: float64
# mi                0.001248
# count_order    4116.571911
# Name: 270, dtype: float64
# mi                0.001248
# count_order    3447.701242
# Name: 271, dtype: float64
# mi                0.001248
# count_order    2646.510522
# Name: 272, dtype: float64
# mi                0.001248
# count_order    2580.255577
# Name: 273, dtype: float64
# mi                0.001248
# count_order    3723.061557
# Name: 274, dtype: float64
# mi                0.001248
# count_order    7067.519338
# Name: 275, dtype: float64
# mi                0.001248
# count_order    2223.722710
# Name: 276, dtype: float64
# mi                0.001248
# count_order    3198.906051
# Name: 277, dtype: float64
# mi                0.001248
# count_order    4654.446158
# Name: 278, dtype: float64
# mi                0.001248
# count_order    5305.060498
# Name: 279, dtype: float64
# mi                0.001248
# count_order    4754.983984
# Name: 280, dtype: float64
# mi                0.001248
# count_order    3949.149837
# Name: 281, dtype: float64
# mi                0.001248
# count_order    3856.382367
# Name: 282, dtype: float64
# mi                0.001248
# count_order    6177.331505
# Name: 283, dtype: float64
# mi                0.001248
# count_order    3363.314310
# Name: 284, dtype: float64
# mi                0.001248
# count_order    4554.150337
# Name: 285, dtype: float64
# mi                0.001248
# count_order    2417.607874
# Name: 286, dtype: float64
# mi                0.001248
# count_order    3093.833395
# Name: 287, dtype: float64
# mi                0.001248
# count_order    2589.548059
# Name: 288, dtype: float64
# mi                0.001248
# count_order    4851.608825
# Name: 289, dtype: float64
# mi                0.001248
# count_order    2800.953342
# Name: 290, dtype: float64
# mi                0.001248
# count_order    4521.611460
# Name: 291, dtype: float64
# mi                0.001248
# count_order    2860.662720
# Name: 292, dtype: float64
# mi                0.001248
# count_order    3568.197691
# Name: 293, dtype: float64
# mi                0.001248
# count_order    3543.903819
# Name: 294, dtype: float64
# mi                0.001248
# count_order    1589.732231
# Name: 295, dtype: float64
# mi                0.001248
# count_order    5778.027179
# Name: 296, dtype: float64
# mi                0.001248
# count_order    2382.238810
# Name: 297, dtype: float64
# mi                0.001248
# count_order    2769.644366
# Name: 298, dtype: float64
# mi                0.001248
# count_order    7655.395729
# Name: 299, dtype: float64
# mi                0.001248
# count_order    6094.637920
# Name: 300, dtype: float64
# mi                0.001248
# count_order    3848.339627
# Name: 301, dtype: float64
# mi                0.001248
# count_order    1107.427313
# Name: 302, dtype: float64
# mi                0.001248
# count_order    4261.161821
# Name: 303, dtype: float64
# mi                0.001248
# count_order    5065.304088
# Name: 304, dtype: float64
# mi                0.001248
# count_order    4879.991187
# Name: 305, dtype: float64
# mi                0.001248
# count_order    2493.462491
# Name: 306, dtype: float64
# mi                0.001248
# count_order    3811.162047
# Name: 307, dtype: float64
# mi                0.001248
# count_order    3288.116040
# Name: 308, dtype: float64
# mi                0.001248
# count_order    4405.465764
# Name: 309, dtype: float64
# mi                0.001248
# count_order    1446.937803
# Name: 310, dtype: float64
# mi                0.001248
# count_order    3653.431952
# Name: 311, dtype: float64
# mi                0.001248
# count_order    4646.757290
# Name: 312, dtype: float64
# mi                0.001248
# count_order    6343.164574
# Name: 313, dtype: float64
# mi                0.001248
# count_order    4279.859307
# Name: 314, dtype: float64
# mi                0.001248
# count_order    2612.218434
# Name: 315, dtype: float64
# mi                0.001248
# count_order    3206.687426
# Name: 316, dtype: float64
# mi                0.001248
# count_order    4130.157066
# Name: 317, dtype: float64
# mi                0.001248
# count_order    3621.164433
# Name: 318, dtype: float64
# mi                0.001248
# count_order    3038.352618
# Name: 319, dtype: float64
# mi                0.001248
# count_order    4057.666408
# Name: 320, dtype: float64
# mi                0.001248
# count_order    4845.654467
# Name: 321, dtype: float64
# mi                0.001248
# count_order    4840.624224
# Name: 322, dtype: float64
# mi                0.001248
# count_order    6009.955047
# Name: 323, dtype: float64
# mi                0.001248
# count_order    3570.488850
# Name: 324, dtype: float64
# mi                0.001248
# count_order    4310.924902
# Name: 325, dtype: float64
# mi                0.001248
# count_order    3826.057484
# Name: 326, dtype: float64
# mi                0.001248
# count_order    3101.764464
# Name: 327, dtype: float64
# mi                0.001248
# count_order    3209.780540
# Name: 328, dtype: float64
# mi                0.001248
# count_order    4875.844132
# Name: 329, dtype: float64
# mi                0.001248
# count_order    4826.987645
# Name: 330, dtype: float64
# mi                0.001248
# count_order    5374.571920
# Name: 331, dtype: float64
# mi                0.001248
# count_order    4511.252777
# Name: 332, dtype: float64
# mi                0.001248
# count_order    4143.050327
# Name: 333, dtype: float64
# mi                0.001248
# count_order    5701.401620
# Name: 334, dtype: float64
# mi                0.001248
# count_order    3963.064490
# Name: 335, dtype: float64
# mi                0.001248
# count_order    3197.427971
# Name: 336, dtype: float64
# mi                0.001248
# count_order    3547.395251
# Name: 337, dtype: float64
# mi                0.001248
# count_order    4040.337258
# Name: 338, dtype: float64
# mi                0.001248
# count_order    2055.651637
# Name: 339, dtype: float64
# mi                0.001248
# count_order    3577.244351
# Name: 340, dtype: float64
# mi                0.001248
# count_order    4918.339330
# Name: 341, dtype: float64
# mi                0.001248
# count_order    3635.390526
# Name: 342, dtype: float64
# mi                0.001248
# count_order    4117.563645
# Name: 343, dtype: float64
# mi                0.001248
# count_order    4128.555594
# Name: 344, dtype: float64
# mi                0.001248
# count_order    4056.693313
# Name: 345, dtype: float64
# mi                0.001248
# count_order    2398.367045
# Name: 346, dtype: float64
# mi                0.001248
# count_order    4904.766192
# Name: 347, dtype: float64
# mi                0.001248
# count_order    3196.308586
# Name: 348, dtype: float64
# mi                0.001248
# count_order    3884.432751
# Name: 349, dtype: float64
# mi                0.001248
# count_order    3613.936815
# Name: 350, dtype: float64
# mi                0.001248
# count_order    2153.489183
# Name: 351, dtype: float64
# mi                0.001248
# count_order    6334.132300
# Name: 352, dtype: float64
# mi                0.001248
# count_order    4158.435690
# Name: 353, dtype: float64
# mi                0.001248
# count_order    1860.199089
# Name: 354, dtype: float64
# mi                0.001248
# count_order    5930.592734
# Name: 355, dtype: float64
# mi                0.001248
# count_order    3878.716502
# Name: 356, dtype: float64
# mi                0.001248
# count_order    3318.894498
# Name: 357, dtype: float64
# mi                0.001248
# count_order    3573.996377
# Name: 358, dtype: float64
# mi                0.001248
# count_order    2709.380989
# Name: 359, dtype: float64
# mi                0.001248
# count_order    1918.035585
# Name: 360, dtype: float64
# mi                0.001248
# count_order    4237.635383
# Name: 361, dtype: float64
# mi                0.001248
# count_order    5391.374766
# Name: 362, dtype: float64
# mi                0.001248
# count_order    7464.293076
# Name: 363, dtype: float64
# mi                0.001248
# count_order    4717.709834
# Name: 364, dtype: float64
# mi                0.001248
# count_order    4122.987115
# Name: 365, dtype: float64
# mi                0.001248
# count_order    5758.989479
# Name: 366, dtype: float64
# mi                0.001248
# count_order    3745.696188
# Name: 367, dtype: float64
# mi                0.001248
# count_order    2952.652185
# Name: 368, dtype: float64
# mi                0.001248
# count_order    2983.421372
# Name: 369, dtype: float64
# mi                0.001248
# count_order    2619.586202
# Name: 370, dtype: float64
# mi                0.001248
# count_order    2459.915181
# Name: 371, dtype: float64
# mi                0.001248
# count_order    5869.699920
# Name: 372, dtype: float64
# mi                0.001248
# count_order    4166.907826
# Name: 373, dtype: float64
# mi                0.001248
# count_order    3870.175516
# Name: 374, dtype: float64
# mi                0.001248
# count_order    5747.305605
# Name: 375, dtype: float64
# mi                0.001248
# count_order    4446.687258
# Name: 376, dtype: float64
# mi                0.001248
# count_order    5047.546590
# Name: 377, dtype: float64
# mi                0.001248
# count_order    2689.722964
# Name: 378, dtype: float64
# mi                0.001248
# count_order    4584.926399
# Name: 379, dtype: float64
# mi                0.001248
# count_order    4189.406046
# Name: 380, dtype: float64
# mi                0.001248
# count_order    2528.279836
# Name: 381, dtype: float64
# mi                0.001248
# count_order    3081.280793
# Name: 382, dtype: float64
# mi                0.001248
# count_order    2163.611149
# Name: 383, dtype: float64
# mi                0.001248
# count_order    4185.962715
# Name: 384, dtype: float64
# mi                0.001248
# count_order    6017.753573
# Name: 385, dtype: float64
# mi                0.001248
# count_order    5120.001710
# Name: 386, dtype: float64
# mi                0.001248
# count_order    3719.500583
# Name: 387, dtype: float64
# mi                0.001248
# count_order    2134.426703
# Name: 388, dtype: float64
# mi                0.001248
# count_order    6326.983915
# Name: 389, dtype: float64
# mi                0.001248
# count_order    5678.595836
# Name: 390, dtype: float64
# mi                0.001248
# count_order    5694.170723
# Name: 391, dtype: float64
# mi                0.001248
# count_order    3183.159499
# Name: 392, dtype: float64
# mi                0.001248
# count_order    4834.138178
# Name: 393, dtype: float64
# mi                0.001248
# count_order    1507.592541
# Name: 394, dtype: float64
# mi                0.001248
# count_order    4329.056123
# Name: 395, dtype: float64
# mi                0.001248
# count_order    3080.243657
# Name: 396, dtype: float64
# mi                0.001248
# count_order    7002.775358
# Name: 397, dtype: float64
# mi                0.001248
# count_order    2510.965203
# Name: 398, dtype: float64
# mi                0.001248
# count_order    5938.331758
# Name: 399, dtype: float64
# mi                0.001248
# count_order    3448.207967
# Name: 400, dtype: float64
# mi                0.001248
# count_order    4781.800157
# Name: 401, dtype: float64
# mi                0.001248
# count_order    3552.736250
# Name: 402, dtype: float64
# mi                0.001248
# count_order    4277.687069
# Name: 403, dtype: float64
# mi                0.001248
# count_order    5448.171686
# Name: 404, dtype: float64
# mi                0.001248
# count_order    3846.733423
# Name: 405, dtype: float64
# mi                0.001248
# count_order    6416.456898
# Name: 406, dtype: float64
# mi                0.001248
# count_order    1813.568133
# Name: 407, dtype: float64
# mi                0.001248
# count_order    2795.280821
# Name: 408, dtype: float64
# mi                0.001248
# count_order    5005.320024
# Name: 409, dtype: float64
# mi                0.001248
# count_order    3905.314514
# Name: 410, dtype: float64
# mi                0.001248
# count_order    2294.614493
# Name: 411, dtype: float64
# mi                0.001248
# count_order    4014.821482
# Name: 412, dtype: float64
# mi                0.001248
# count_order    5007.001886
# Name: 413, dtype: float64
# mi               0.001248
# count_order    933.170632
# Name: 414, dtype: float64
# mi                0.001248
# count_order    4011.887389
# Name: 415, dtype: float64
# mi               0.001248
# count_order    836.592367
# Name: 416, dtype: float64
# mi                0.001248
# count_order    4926.850570
# Name: 417, dtype: float64
# mi                0.001248
# count_order    2332.156529
# Name: 418, dtype: float64
# mi                0.001248
# count_order    3306.104269
# Name: 419, dtype: float64
# mi                0.001248
# count_order    2535.568802
# Name: 420, dtype: float64
# mi                0.001248
# count_order    3276.936909
# Name: 421, dtype: float64
# mi                0.001248
# count_order    3324.192531
# Name: 422, dtype: float64
# mi                0.001248
# count_order    4943.290031
# Name: 423, dtype: float64
# mi                0.001248
# count_order    3922.846318
# Name: 424, dtype: float64
# mi                0.001248
# count_order    1659.545225
# Name: 425, dtype: float64
# mi                0.001248
# count_order    3680.609072
# Name: 426, dtype: float64
# mi                0.001248
# count_order    5083.135433
# Name: 427, dtype: float64
# mi                0.001248
# count_order    4669.368881
# Name: 428, dtype: float64
# mi                0.001248
# count_order    1181.024850
# Name: 429, dtype: float64
# mi                0.001248
# count_order    2711.841139
# Name: 430, dtype: float64
# mi                0.001248
# count_order    3600.672337
# Name: 431, dtype: float64
# mi                0.001248
# count_order    3215.224012
# Name: 432, dtype: float64
# mi                0.001248
# count_order    5438.297016
# Name: 433, dtype: float64
# mi                0.001248
# count_order    3786.239651
# Name: 434, dtype: float64
# mi                0.001248
# count_order    1636.208201
# Name: 435, dtype: float64
# mi                0.001248
# count_order    3685.814603
# Name: 436, dtype: float64
# mi                0.001248
# count_order    3606.648847
# Name: 437, dtype: float64
# mi                0.001248
# count_order    5334.716729
# Name: 438, dtype: float64
# mi                0.001248
# count_order    3579.819768
# Name: 439, dtype: float64
# mi                0.001248
# count_order    4417.764137
# Name: 440, dtype: float64
# mi                0.001248
# count_order    4236.968960
# Name: 441, dtype: float64
# mi                0.001248
# count_order    4554.459109
# Name: 442, dtype: float64
# mi                0.001248
# count_order    2486.201390
# Name: 443, dtype: float64
# mi                0.001248
# count_order    4081.614649
# Name: 444, dtype: float64
# mi                0.001248
# count_order    3679.154849
# Name: 445, dtype: float64
# mi                0.001248
# count_order    1444.434596
# Name: 446, dtype: float64
# mi                0.001248
# count_order    3889.620106
# Name: 447, dtype: float64
# mi               0.001248
# count_order    198.055921
# Name: 448, dtype: float64
# mi                0.001248
# count_order    1692.090255
# Name: 449, dtype: float64
# mi                0.001248
# count_order    3632.213098
# Name: 450, dtype: float64
# mi                0.001248
# count_order    2993.235076
# Name: 451, dtype: float64
# mi                0.001248
# count_order    2568.880869
# Name: 452, dtype: float64
# mi                0.001248
# count_order    4508.240020
# Name: 453, dtype: float64
# mi                0.001248
# count_order    3296.772448
# Name: 454, dtype: float64
# mi                0.001248
# count_order    2365.481580
# Name: 455, dtype: float64
# mi                0.001248
# count_order    1440.091752
# Name: 456, dtype: float64
# mi                0.001248
# count_order    4749.958377
# Name: 457, dtype: float64
# mi                0.001248
# count_order    4173.760433
# Name: 458, dtype: float64
# mi                0.001248
# count_order    4238.946127
# Name: 459, dtype: float64
# mi                0.001248
# count_order    2339.523713
# Name: 460, dtype: float64
# mi                0.001248
# count_order    4840.901311
# Name: 461, dtype: float64
# mi                0.001248
# count_order    2136.924476
# Name: 462, dtype: float64
# mi                0.001248
# count_order    2621.696511
# Name: 463, dtype: float64
# mi                0.001248
# count_order    2742.415228
# Name: 464, dtype: float64
# mi                0.001248
# count_order    4640.988724
# Name: 465, dtype: float64
# mi                0.001248
# count_order    4146.881524
# Name: 466, dtype: float64
# mi                0.001248
# count_order    4068.601327
# Name: 467, dtype: float64
# mi                0.001248
# count_order    4333.755216
# Name: 468, dtype: float64
# mi                0.001248
# count_order    3582.009018
# Name: 469, dtype: float64
# mi                0.001248
# count_order    1338.828091
# Name: 470, dtype: float64
# mi                0.001248
# count_order    3918.160871
# Name: 471, dtype: float64
# mi                0.001248
# count_order    2842.867371
# Name: 472, dtype: float64
# mi                0.001248
# count_order    5057.552363
# Name: 473, dtype: float64
# mi                0.001248
# count_order    4168.037008
# Name: 474, dtype: float64
# mi                0.001248
# count_order    3621.680647
# Name: 475, dtype: float64
# mi                0.001248
# count_order    2332.111951
# Name: 476, dtype: float64
# mi                0.001248
# count_order    4727.378445
# Name: 477, dtype: float64
# mi                0.001248
# count_order    1317.020312
# Name: 478, dtype: float64
# mi                0.001248
# count_order    2623.654533
# Name: 479, dtype: float64
# mi                0.001248
# count_order    1058.505282
# Name: 480, dtype: float64
# mi                0.001248
# count_order    3298.873634
# Name: 481, dtype: float64
# mi                0.001248
# count_order    5610.745116
# Name: 482, dtype: float64
# mi                0.001248
# count_order    3760.785781
# Name: 483, dtype: float64
# mi                0.001248
# count_order    4021.905405
# Name: 484, dtype: float64
# mi                0.001248
# count_order    4196.918656
# Name: 485, dtype: float64
# mi                0.001248
# count_order    1984.529612
# Name: 486, dtype: float64
# mi                0.001248
# count_order    4076.591796
# Name: 487, dtype: float64
# mi                0.001248
# count_order    2723.920262
# Name: 488, dtype: float64
# mi                0.001248
# count_order    4659.007042
# Name: 489, dtype: float64
# mi                0.001248
# count_order    3772.239361
# Name: 490, dtype: float64
# mi                0.001248
# count_order    5302.784899
# Name: 491, dtype: float64
# mi                0.001248
# count_order    1919.399978
# Name: 492, dtype: float64
# mi                0.001248
# count_order    2751.243208
# Name: 493, dtype: float64
# mi                0.001248
# count_order    1233.307744
# Name: 494, dtype: float64
# mi                0.001248
# count_order    3604.977216
# Name: 495, dtype: float64
# mi                0.001248
# count_order    3415.875733
# Name: 496, dtype: float64
# mi                0.001248
# count_order    4167.255179
# Name: 497, dtype: float64
# mi                0.001248
# count_order    5689.761957
# Name: 498, dtype: float64
# mi                0.001248
# count_order    2633.096709
# Name: 499, dtype: float64
# mi                0.001248
# count_order    3139.437148
# Name: 500, dtype: float64
# mi                0.001248
# count_order    3897.369570
# Name: 501, dtype: float64
# mi                0.001248
# count_order    3199.239173
# Name: 502, dtype: float64
# mi                0.001248
# count_order    5280.222038
# Name: 503, dtype: float64
# mi               0.001248
# count_order    733.952390
# Name: 504, dtype: float64
# mi                0.001248
# count_order    2346.429403
# Name: 505, dtype: float64
# mi                0.001248
# count_order    4078.599289
# Name: 506, dtype: float64
# mi                0.001248
# count_order    2784.980939
# Name: 507, dtype: float64
# mi                0.001248
# count_order    5662.956437
# Name: 508, dtype: float64
# mi                0.001248
# count_order    3706.078507
# Name: 509, dtype: float64
# mi                0.001248
# count_order    3909.190925
# Name: 510, dtype: float64
# mi                0.001248
# count_order    3563.135414
# Name: 511, dtype: float64
# mi                0.001248
# count_order    5291.969852
# Name: 512, dtype: float64
# mi                0.001248
# count_order    4783.514637
# Name: 513, dtype: float64
# mi                0.001248
# count_order    3461.862456
# Name: 514, dtype: float64
# mi                0.001248
# count_order    3685.878925
# Name: 515, dtype: float64
# mi                0.001248
# count_order    5457.553951
# Name: 516, dtype: float64
# mi                0.001248
# count_order    4480.867847
# Name: 517, dtype: float64
# mi                0.001248
# count_order    5554.622810
# Name: 518, dtype: float64
# mi                0.001248
# count_order    5772.903217
# Name: 519, dtype: float64
# mi                0.001248
# count_order    3580.768752
# Name: 520, dtype: float64
# mi                0.001248
# count_order    3804.250494
# Name: 521, dtype: float64
# mi                0.001248
# count_order    1618.532309
# Name: 522, dtype: float64
# mi                0.001248
# count_order    2348.943980
# Name: 523, dtype: float64
# mi                0.001248
# count_order    5170.840549
# Name: 524, dtype: float64
# mi                0.001248
# count_order    3656.538744
# Name: 525, dtype: float64
# mi                0.001248
# count_order    3288.934077
# Name: 526, dtype: float64
# mi                0.001248
# count_order    3727.850500
# Name: 527, dtype: float64
# mi                0.001248
# count_order    2051.475267
# Name: 528, dtype: float64
# mi                0.001248
# count_order    3425.550717
# Name: 529, dtype: float64
# mi                0.001248
# count_order    4585.472433
# Name: 530, dtype: float64
# mi                0.001248
# count_order    3418.396948
# Name: 531, dtype: float64
# mi                0.001248
# count_order    7078.994691
# Name: 532, dtype: float64
# mi                0.001248
# count_order    2505.190294
# Name: 533, dtype: float64
# mi                0.001248
# count_order    1798.886974
# Name: 534, dtype: float64
# mi                0.001248
# count_order    4419.905913
# Name: 535, dtype: float64
# mi                0.001248
# count_order    3796.939435
# Name: 536, dtype: float64
# mi                0.001248
# count_order    1370.135907
# Name: 537, dtype: float64
# mi                0.001248
# count_order    3398.050684
# Name: 538, dtype: float64
# mi                0.001248
# count_order    3980.761342
# Name: 539, dtype: float64
# mi                0.001248
# count_order    5185.962971
# Name: 540, dtype: float64
# mi                0.001248
# count_order    3025.602628
# Name: 541, dtype: float64
# mi                0.001248
# count_order    2635.307238
# Name: 542, dtype: float64
# mi                0.001248
# count_order    2455.783204
# Name: 543, dtype: float64
# mi                0.001248
# count_order    2458.838312
# Name: 544, dtype: float64
# mi                0.001248
# count_order    3002.119826
# Name: 545, dtype: float64
# mi                0.001248
# count_order    4388.142675
# Name: 546, dtype: float64
# mi                0.001248
# count_order    4288.282903
# Name: 547, dtype: float64
# mi                0.001248
# count_order    4265.794976
# Name: 548, dtype: float64
# mi                0.001248
# count_order    3047.308866
# Name: 549, dtype: float64
# mi                0.001248
# count_order    5616.580462
# Name: 550, dtype: float64
# mi                0.001248
# count_order    3252.149256
# Name: 551, dtype: float64
# mi                0.001248
# count_order    2778.859080
# Name: 552, dtype: float64
# mi                0.001248
# count_order    2958.079165
# Name: 553, dtype: float64
# mi                0.001248
# count_order    4429.702368
# Name: 554, dtype: float64
# mi                0.001248
# count_order    2925.734038
# Name: 555, dtype: float64
# mi                0.001248
# count_order    2895.302163
# Name: 556, dtype: float64
# mi                0.001248
# count_order    2508.607785
# Name: 557, dtype: float64
# mi                0.001248
# count_order    3387.442553
# Name: 558, dtype: float64
# mi                0.001248
# count_order    4112.425830
# Name: 559, dtype: float64
# mi                0.001248
# count_order    3967.988159
# Name: 560, dtype: float64
# mi                0.001248
# count_order    4151.514909
# Name: 561, dtype: float64
# mi                0.001248
# count_order    2657.673161
# Name: 562, dtype: float64
# mi                0.001248
# count_order    3649.225506
# Name: 563, dtype: float64
# mi                0.001248
# count_order    4788.987123
# Name: 564, dtype: float64
# mi                0.001248
# count_order    5568.709452
# Name: 565, dtype: float64
# mi                0.001248
# count_order    3604.824305
# Name: 566, dtype: float64
# mi                0.001248
# count_order    4440.752531
# Name: 567, dtype: float64
# mi                0.001248
# count_order    2270.011380
# Name: 568, dtype: float64
# mi                0.001248
# count_order    3090.766677
# Name: 569, dtype: float64
# mi                0.001248
# count_order    4531.609388
# Name: 570, dtype: float64
# mi                0.001248
# count_order    3046.634927
# Name: 571, dtype: float64
# mi                0.001248
# count_order    4755.731089
# Name: 572, dtype: float64
# mi                0.001248
# count_order    1621.705339
# Name: 573, dtype: float64
# mi                0.001248
# count_order    3670.432338
# Name: 574, dtype: float64
# mi                0.001248
# count_order    1817.441818
# Name: 575, dtype: float64
# mi                0.001248
# count_order    3514.293935
# Name: 576, dtype: float64
# mi                0.001248
# count_order    3436.925835
# Name: 577, dtype: float64
# mi                0.001248
# count_order    4035.421205
# Name: 578, dtype: float64
# mi                0.001248
# count_order    3177.836750
# Name: 579, dtype: float64
# mi                0.001248
# count_order    3370.189363
# Name: 580, dtype: float64
# mi                0.001248
# count_order    5236.140840
# Name: 581, dtype: float64
# mi                0.001248
# count_order    4924.610359
# Name: 582, dtype: float64
# mi                0.001248
# count_order    2472.618118
# Name: 583, dtype: float64
# mi                0.001248
# count_order    3211.698293
# Name: 584, dtype: float64
# mi                0.001248
# count_order    4597.261825
# Name: 585, dtype: float64
# mi                0.001248
# count_order    4663.679777
# Name: 586, dtype: float64
# mi                0.001248
# count_order    3441.423962
# Name: 587, dtype: float64
# mi                0.001248
# count_order    3629.565491
# Name: 588, dtype: float64
# mi                0.001248
# count_order    3420.759115
# Name: 589, dtype: float64
# mi                0.001248
# count_order    3603.247968
# Name: 590, dtype: float64
# mi                0.001248
# count_order    3324.239736
# Name: 591, dtype: float64
# mi                0.001248
# count_order    5227.258173
# Name: 592, dtype: float64
# mi                0.001248
# count_order    3341.227825
# Name: 593, dtype: float64
# mi                0.001248
# count_order    4212.733474
# Name: 594, dtype: float64
# mi                0.001248
# count_order    3834.734279
# Name: 595, dtype: float64
# mi                0.001248
# count_order    3779.472601
# Name: 596, dtype: float64
# mi                0.001248
# count_order    3189.343042
# Name: 597, dtype: float64
# mi                0.001248
# count_order    3564.297220
# Name: 598, dtype: float64
# mi                0.001248
# count_order    4939.047956
# Name: 599, dtype: float64
# mi                0.001248
# count_order    3511.118391
# Name: 600, dtype: float64
# mi                0.001248
# ...
# mi               16.00000
# count_order    3819.69696
# Name: 8813, dtype: float64
# mi               16.000000
# count_order    3755.316978
# Name: 8814, dtype: float64
# mi               16.000000
# count_order    3717.303327
# Name: 8815, dtype: float64
# mi               16.000000
# count_order    3631.665764
# Name: 8816, dtype: float64
# mi               16.000000
# count_order    3755.705737
# Name: 8817, dtype: float64
# mi               16.000000
# count_order    3775.664364
# Name: 8818, dtype: float64
# mi               16.000000
# count_order    3835.425424
# Name: 8819, dtype: float64
# mi               16.000000
# count_order    3755.941006
# Name: 8820, dtype: float64
# mi               16.00000
# count_order    3842.94964
# Name: 8821, dtype: float64
# mi               16.000000
# count_order    3844.099385
# Name: 8822, dtype: float64
# mi               16.000000
# count_order    3748.063576
# Name: 8823, dtype: float64
# mi               16.000000
# count_order    3710.623009
# Name: 8824, dtype: float64
# mi               16.000000
# count_order    3621.294598
# Name: 8825, dtype: float64
# mi               16.00000
# count_order    3850.36514
# Name: 8826, dtype: float64
# mi               16.000000
# count_order    3683.854133
# Name: 8827, dtype: float64
# mi               16.000000
# count_order    3766.968483
# Name: 8828, dtype: float64
# mi               16.000000
# count_order    3819.650997
# Name: 8829, dtype: float64
# mi               16.000000
# count_order    3727.610509
# Name: 8830, dtype: float64
# mi               16.000000
# count_order    3769.898506
# Name: 8831, dtype: float64
# mi               16.000000
# count_order    3775.998551
# Name: 8832, dtype: float64
# mi               16.000000
# count_order    3806.201333
# Name: 8833, dtype: float64
# mi               16.000000
# count_order    3814.986909
# Name: 8834, dtype: float64
# mi               16.00000
# count_order    3802.71887
# Name: 8835, dtype: float64
# mi               16.000000
# count_order    3760.627965
# Name: 8836, dtype: float64
# mi               16.000000
# count_order    3823.982472
# Name: 8837, dtype: float64
# mi               16.000000
# count_order    3779.885989
# Name: 8838, dtype: float64
# mi               16.000000
# count_order    3781.605236
# Name: 8839, dtype: float64
# mi               16.000000
# count_order    3766.449972
# Name: 8840, dtype: float64
# mi               16.000000
# count_order    3640.918427
# Name: 8841, dtype: float64
# mi               16.000000
# count_order    3815.848127
# Name: 8842, dtype: float64
# mi               16.000000
# count_order    3783.989447
# Name: 8843, dtype: float64
# mi               16.000000
# count_order    3755.586412
# Name: 8844, dtype: float64
# mi               16.000000
# count_order    3905.658642
# Name: 8845, dtype: float64
# mi               16.000000
# count_order    3748.320237
# Name: 8846, dtype: float64
# mi               16.000000
# count_order    3787.919538
# Name: 8847, dtype: float64
# mi               16.000000
# count_order    3767.569324
# Name: 8848, dtype: float64
# mi               16.000000
# count_order    3819.622799
# Name: 8849, dtype: float64
# mi               16.000000
# count_order    3681.104509
# Name: 8850, dtype: float64
# mi               16.000000
# count_order    3811.506291
# Name: 8851, dtype: float64
# mi               16.000000
# count_order    3756.456816
# Name: 8852, dtype: float64
# mi               16.000000
# count_order    3749.104637
# Name: 8853, dtype: float64
# mi               16.000000
# count_order    3833.492499
# Name: 8854, dtype: float64
# mi               16.000000
# count_order    3792.395462
# Name: 8855, dtype: float64
# mi               16.000000
# count_order    3847.240203
# Name: 8856, dtype: float64
# mi               16.000000
# count_order    3831.715611
# Name: 8857, dtype: float64
# mi               16.00000
# count_order    3795.41261
# Name: 8858, dtype: float64
# mi               16.0000
# count_order    3837.7724
# Name: 8859, dtype: float64
# mi               16.000000
# count_order    3766.833795
# Name: 8860, dtype: float64
# mi               16.000000
# count_order    3778.493863
# Name: 8861, dtype: float64
# mi               16.000000
# count_order    3859.754542
# Name: 8862, dtype: float64
# mi               16.000000
# count_order    3711.098466
# Name: 8863, dtype: float64
# mi               16.000000
# count_order    3756.206882
# Name: 8864, dtype: float64
# mi               16.000000
# count_order    3784.211686
# Name: 8865, dtype: float64
# mi               16.000000
# count_order    3784.797113
# Name: 8866, dtype: float64
# mi               16.000000
# count_order    3745.155456
# Name: 8867, dtype: float64
# mi               16.00000
# count_order    3859.77641
# Name: 8868, dtype: float64
# mi               16.000000
# count_order    3692.555524
# Name: 8869, dtype: float64
# mi               16.000000
# count_order    3663.545705
# Name: 8870, dtype: float64
# mi               16.000000
# count_order    3724.195602
# Name: 8871, dtype: float64
# mi               16.000000
# count_order    3818.958519
# Name: 8872, dtype: float64
# mi               16.000000
# count_order    3856.490254
# Name: 8873, dtype: float64
# mi               16.000000
# count_order    3929.660263
# Name: 8874, dtype: float64
# mi               16.000000
# count_order    3832.969584
# Name: 8875, dtype: float64
# mi               16.000000
# count_order    3863.639187
# Name: 8876, dtype: float64
# mi               16.000000
# count_order    3760.249928
# Name: 8877, dtype: float64
# mi               16.000000
# count_order    3782.629996
# Name: 8878, dtype: float64
# mi               16.000000
# count_order    3745.302646
# Name: 8879, dtype: float64
# mi               16.000000
# count_order    3822.803608
# Name: 8880, dtype: float64
# mi               16.000000
# count_order    3737.329161
# Name: 8881, dtype: float64
# mi               16.000000
# count_order    3920.068032
# Name: 8882, dtype: float64
# mi               16.000000
# count_order    3842.402531
# Name: 8883, dtype: float64
# mi               16.000000
# count_order    3746.769046
# Name: 8884, dtype: float64
# mi               16.000000
# count_order    3775.059058
# Name: 8885, dtype: float64
# mi               16.000000
# count_order    3798.444913
# Name: 8886, dtype: float64
# mi               16.00000
# count_order    3757.78521
# Name: 8887, dtype: float64
# mi               16.000000
# count_order    3791.083178
# Name: 8888, dtype: float64
# mi               16.000000
# count_order    3705.944635
# Name: 8889, dtype: float64
# mi               16.000000
# count_order    3799.099683
# Name: 8890, dtype: float64
# mi               16.000000
# count_order    3779.286443
# Name: 8891, dtype: float64
# mi               16.00000
# count_order    3687.61594
# Name: 8892, dtype: float64
# mi               16.000000
# count_order    3810.045582
# Name: 8893, dtype: float64
# mi               16.000000
# count_order    3806.721138
# Name: 8894, dtype: float64
# mi               16.000000
# count_order    3755.882411
# Name: 8895, dtype: float64
# mi               16.000000
# count_order    3782.519415
# Name: 8896, dtype: float64
# mi               16.000000
# count_order    3666.225651
# Name: 8897, dtype: float64
# mi               16.00000
# count_order    3769.62365
# Name: 8898, dtype: float64
# mi               16.000000
# count_order    3858.438548
# Name: 8899, dtype: float64
# mi               16.000000
# count_order    3754.162032
# Name: 8900, dtype: float64
# mi               16.000000
# count_order    3777.627388
# Name: 8901, dtype: float64
# mi               16.000000
# count_order    3744.522396
# Name: 8902, dtype: float64
# mi               16.000000
# count_order    3702.865765
# Name: 8903, dtype: float64
# mi               16.000000
# count_order    3753.744474
# Name: 8904, dtype: float64
# mi               16.000000
# count_order    3769.213535
# Name: 8905, dtype: float64
# mi               16.000000
# count_order    3758.821052
# Name: 8906, dtype: float64
# mi               16.000000
# count_order    3822.100657
# Name: 8907, dtype: float64
# mi               16.000000
# count_order    3710.886262
# Name: 8908, dtype: float64
# mi               16.00000
# count_order    3787.65007
# Name: 8909, dtype: float64
# mi               16.000000
# count_order    3770.350027
# Name: 8910, dtype: float64
# mi               16.000000
# count_order    3828.550121
# Name: 8911, dtype: float64
# mi               16.000000
# count_order    3833.700424
# Name: 8912, dtype: float64
# mi               16.000000
# count_order    3738.356652
# Name: 8913, dtype: float64
# mi               16.000000
# count_order    3748.108334
# Name: 8914, dtype: float64
# mi               16.000000
# count_order    3745.872024
# Name: 8915, dtype: float64
# mi               16.000000
# count_order    3804.429296
# Name: 8916, dtype: float64
# mi               16.000000
# count_order    3777.028877
# Name: 8917, dtype: float64
# mi               16.000000
# count_order    3759.850443
# Name: 8918, dtype: float64
# mi               16.000000
# count_order    3735.514786
# Name: 8919, dtype: float64
# mi               16.000000
# count_order    3860.797846
# Name: 8920, dtype: float64
# mi               16.00000
# count_order    3842.76619
# Name: 8921, dtype: float64
# mi               16.000000
# count_order    3699.617989
# Name: 8922, dtype: float64
# mi               16.000000
# count_order    3741.028395
# Name: 8923, dtype: float64
# mi               16.000000
# count_order    3710.110547
# Name: 8924, dtype: float64
# mi               16.000000
# count_order    3697.854733
# Name: 8925, dtype: float64
# mi               16.000000
# count_order    3831.911346
# Name: 8926, dtype: float64
# mi               16.000000
# count_order    3840.293684
# Name: 8927, dtype: float64
# mi               16.000000
# count_order    3722.423063
# Name: 8928, dtype: float64
# mi               16.0000
# count_order    3727.5327
# Name: 8929, dtype: float64
# mi               16.000000
# count_order    3888.128669
# Name: 8930, dtype: float64
# mi               16.000000
# count_order    3732.788849
# Name: 8931, dtype: float64
# mi               16.000000
# count_order    3818.465952
# Name: 8932, dtype: float64
# mi               16.000000
# count_order    3692.186162
# Name: 8933, dtype: float64
# mi               16.000000
# count_order    3750.630442
# Name: 8934, dtype: float64
# mi               16.000000
# count_order    3745.553715
# Name: 8935, dtype: float64
# mi               16.000000
# count_order    3856.613793
# Name: 8936, dtype: float64
# mi               16.000000
# count_order    3842.139902
# Name: 8937, dtype: float64
# mi               16.000000
# count_order    3710.065441
# Name: 8938, dtype: float64
# mi               16.000000
# count_order    3786.522685
# Name: 8939, dtype: float64
# mi               16.000000
# count_order    3782.731528
# Name: 8940, dtype: float64
# mi               16.000000
# count_order    3757.724859
# Name: 8941, dtype: float64
# mi               16.000000
# count_order    3759.533112
# Name: 8942, dtype: float64
# mi               16.000000
# count_order    3880.966397
# Name: 8943, dtype: float64
# mi               16.000000
# count_order    3750.996728
# Name: 8944, dtype: float64
# mi               16.000000
# count_order    3709.081048
# Name: 8945, dtype: float64
# mi               16.000000
# count_order    3755.693573
# Name: 8946, dtype: float64
# mi               16.000000
# count_order    3782.842803
# Name: 8947, dtype: float64
# mi               16.00000
# count_order    3801.71906
# Name: 8948, dtype: float64
# mi               16.000000
# count_order    3745.559287
# Name: 8949, dtype: float64
# mi               16.000000
# count_order    3759.027697
# Name: 8950, dtype: float64
# mi               16.000000
# count_order    3773.013501
# Name: 8951, dtype: float64
# mi               16.000000
# count_order    3828.144517
# Name: 8952, dtype: float64
# mi               16.000000
# count_order    3715.715259
# Name: 8953, dtype: float64
# mi               16.000000
# count_order    3693.761974
# Name: 8954, dtype: float64
# mi               16.000000
# count_order    3766.243543
# Name: 8955, dtype: float64
# mi               16.000000
# count_order    3756.021133
# Name: 8956, dtype: float64
# mi               16.000000
# count_order    3804.108805
# Name: 8957, dtype: float64
# mi               16.000000
# count_order    3730.263324
# Name: 8958, dtype: float64
# mi               16.000000
# count_order    3747.994929
# Name: 8959, dtype: float64
# mi               16.000000
# count_order    3830.282021
# Name: 8960, dtype: float64
# mi               16.000000
# count_order    3672.564786
# Name: 8961, dtype: float64
# mi               16.000000
# count_order    3720.132476
# Name: 8962, dtype: float64
# mi               16.000000
# count_order    3774.224161
# Name: 8963, dtype: float64
# mi               16.000000
# count_order    3710.669823
# Name: 8964, dtype: float64
# mi               16.000000
# count_order    3761.860822
# Name: 8965, dtype: float64
# mi               16.000000
# count_order    3862.918167
# Name: 8966, dtype: float64
# mi               16.000000
# count_order    3815.969181
# Name: 8967, dtype: float64
# mi               16.000000
# count_order    3787.800006
# Name: 8968, dtype: float64
# mi               16.00000
# count_order    3817.22526
# Name: 8969, dtype: float64
# mi               16.00000
# count_order    3730.81079
# Name: 8970, dtype: float64
# mi               16.000000
# count_order    3728.761065
# Name: 8971, dtype: float64
# mi               16.000000
# count_order    3854.140283
# Name: 8972, dtype: float64
# mi               16.000000
# count_order    3815.039857
# Name: 8973, dtype: float64
# mi               16.000000
# count_order    3744.430745
# Name: 8974, dtype: float64
# mi               16.000000
# count_order    3669.375851
# Name: 8975, dtype: float64
# mi               16.000000
# count_order    3792.460779
# Name: 8976, dtype: float64
# mi               16.000000
# count_order    3702.585908
# Name: 8977, dtype: float64
# mi               16.000000
# count_order    3840.127271
# Name: 8978, dtype: float64
# mi               16.000000
# count_order    3748.315402
# Name: 8979, dtype: float64
# mi               16.00000
# count_order    3731.68907
# Name: 8980, dtype: float64
# mi               16.000000
# count_order    3807.382487
# Name: 8981, dtype: float64
# mi               16.000000
# count_order    3748.742243
# Name: 8982, dtype: float64
# mi               16.000000
# count_order    3810.235882
# Name: 8983, dtype: float64
# mi               16.000000
# count_order    3764.282054
# Name: 8984, dtype: float64
# mi               16.000000
# count_order    3831.336576
# Name: 8985, dtype: float64
# mi               16.000000
# count_order    3788.440518
# Name: 8986, dtype: float64
# mi               16.000000
# count_order    3842.546446
# Name: 8987, dtype: float64
# mi               16.000000
# count_order    3828.525847
# Name: 8988, dtype: float64
# mi               16.000000
# count_order    3749.511835
# Name: 8989, dtype: float64
# mi               16.000000
# count_order    3655.375904
# Name: 8990, dtype: float64
# mi               16.000000
# count_order    3697.806653
# Name: 8991, dtype: float64
# mi               16.000000
# count_order    3943.509729
# Name: 8992, dtype: float64
# mi               16.000000
# count_order    3782.586366
# Name: 8993, dtype: float64
# mi               16.000000
# count_order    3832.113445
# Name: 8994, dtype: float64
# mi               16.000000
# count_order    3863.518818
# Name: 8995, dtype: float64
# mi               16.000000
# count_order    3727.744504
# Name: 8996, dtype: float64
# mi               16.000000
# count_order    3803.062707
# Name: 8997, dtype: float64
# mi               16.00000
# count_order    3822.30229
# Name: 8998, dtype: float64
# mi               16.000000
# count_order    3777.951513
# Name: 8999, dtype: float64
#              mi  absolute error count_order  relative error count_order
# 0      0.001248                 1917.697048                   50.934849
# 1      0.001248                 1211.880202                   32.188053
# 2      0.001248                 1629.680649                   43.285011
# 3      0.001248                  145.586196                    3.866831
# 4      0.001248                 1692.540172                   44.954586
# ...         ...                         ...                         ...
# 8995  16.000000                   98.518818                    2.616702
# 8996  16.000000                   37.255496                    0.989522
# 8997  16.000000                   38.062707                    1.010962
# 8998  16.000000                   57.302290                    1.521973
# 8999  16.000000                   12.951513                    0.343998
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 count_order mean  count_order var
# type factor
# pac  0.001248        3774.333506     1.514854e+06
#      0.015625        3755.306375     1.258772e+05
#      0.031250        3771.630205     5.921528e+04
#      0.062500        3763.246696     3.527436e+04
#      0.250000        3763.479407     1.174634e+04
#      1.000000        3763.495606     5.178557e+03
#      2.000000        3763.865577     4.743795e+03
#      4.000000        3767.675512     3.873352e+03
#      16.000000       3770.035197     3.739951e+03

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error count_order mean  \
# type factor
# pac  0.001248                        974.981693
#      0.015625                        283.058223
#      0.031250                        194.139677
#      0.062500                        150.607304
#      0.250000                         85.884212
#      1.000000                         58.232319
#      2.000000                         54.828961
#      4.000000                         49.679967
#      16.000000                        48.087117
#
#                 absolute error count_order var  \
# type factor
# pac  0.001248                    563399.982011
#      0.015625                     45769.140091
#      0.031250                     21531.338249
#      0.062500                     12572.171503
#      0.250000                      4365.173223
#      1.000000                      1786.425282
#      2.000000                      1735.859100
#      4.000000                      1409.947900
#      16.000000                     1450.644142
#
#                 relative error count_order mean  \
# type factor
# pac  0.001248                         25.895928
#      0.015625                          7.518147
#      0.031250                          5.156432
#      0.062500                          4.000194
#      0.250000                          2.281121
#      1.000000                          1.546675
#      2.000000                          1.456281
#      4.000000                          1.319521
#      16.000000                         1.277214
#
#                 relative error count_order var
# type factor
# pac  0.001248                       397.453996
#      0.015625                        32.288122
#      0.031250                        15.189416
#      0.062500                         8.869116
#      0.250000                         3.079438
#      1.000000                         1.260245
#      2.000000                         1.224573
#      4.000000                         0.994656
#      16.000000                        1.023366

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#             count_order
# mi
# 0.001248   1.514854e+06
# 0.015625   1.258772e+05
# 0.031250   5.921528e+04
# 0.062500   3.527436e+04
# 0.250000   1.174634e+04
# 1.000000   5.178557e+03
# 2.000000   4.743795e+03
# 4.000000   3.873352e+03
# 16.000000  3.739951e+03

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step              scale
# query       count_order
# mi
# 0.001248   1.487633e+06
# 0.015625   1.188506e+05
# 0.031250   5.942528e+04
# 0.062500   2.971264e+04
# 0.250000   7.428160e+03
# 1.000000   1.857040e+03
# 2.000000   9.285200e+02
# 4.000000   4.642600e+02
# 16.000000  1.160650e+02

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# count_order    1.285082
# dtype: float64
#            count_order
# mi
# 0.001248      1.302895
# 0.015625      1.327278
# 0.031250      1.284090
# 0.062500      1.306773
# 0.250000      1.300558
# 1.000000      1.262629
# 2.000000      1.301514
# 4.000000      1.229163
# 16.000000     1.250837

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33281/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query           count_order
# mi
# 0.001248         974.395810
# 0.015625         277.640634
# 0.031250         190.237106
# 0.062500         141.702211
# 0.250000          71.173023
# 1.000000          33.239568
# 2.000000          24.490896
# 4.000000          17.150781
# 16.000000          8.798557

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33281/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33281/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query       count_order
# mi
# 0.001248       3766.264
# 0.015625       3760.206
# 0.031250       3764.540
# 0.062500       3762.640
# 0.250000       3761.668
# 1.000000       3763.360
# 2.000000       3764.238
# 4.000000       3766.452
# 16.000000      3769.520
# step   chosen_sample
# query    count_order
# all mi   3764.320889

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33281/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#            count_order
# mi
# 0.001248     25.895928
# 0.015625      7.518147
# 0.031250      5.156432
# 0.062500      4.000194
# 0.250000      2.281121
# 1.000000      1.546675
# 2.000000      1.456281
# 4.000000      1.319521
# 16.000000     1.277214

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#            count_order
# mi
# 0.001248     24.593033
# 0.015625      6.190869
# 0.031250      3.872342
# 0.062500      2.693421
# 0.250000      0.980563
# 1.000000      0.284046
# 2.000000      0.154767
# 4.000000      0.090358
# 16.000000     0.026378

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
relative_error_percent(38854, 3765)
# Out:
# 931.9787516600267
