# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   -- sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   -- sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   -- avg(l_quantity) as avg_qty,
#   avg(l_extendedprice) as avg_price,
#   -- avg(l_discount) as avg_disc,
#   -- count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'A'
#   and l_linestatus = 'F'
# ```

# %%
EXPERIMENT = 'pac-q1-avg-price'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'A') &
        (lineitem_df['l_linestatus'] == 'F')
    ]
    print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        # float(discounted_price.sum()),                      # sum_disc_price
        # float(charged_price.sum()),                         # sum_charge
        # float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        # float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        # float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# (147790, 16)
# [36002.12382901414]
# [36002.12382901414]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['avg_price']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 147790  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            # out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np
# Out:
# (147790, 16)
# [36002.12382901414]

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
# TODO: Change it back to 1000
EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    # out_np = generate_samples() # generate samples (results of running the query)
    # print(f"Generate samples... {len(out_np)} samples generated.")

    print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# [36088.2901843]
# Getting PAC Noise...
# The dimensions are - 1
# [array([[36088.2901843]]), array([[35916.44815197]]), array([[36057.29799019]]), array([[35947.0645332]]), array([[36012.49425479]]), array([[35991.76378321]]), array([[35969.09714541]]), array([[36035.25077931]]), array([[36076.40134955]]), array([[35927.97285284]]), array([[35916.1254516]]), array([[36088.24798784]]), array([[35962.85560567]]), array([[36041.31984763]]), array([[35914.52971263]]), array([[36089.6729123]]), array([[36096.35053203]]), array([[35907.77463269]]), array([[36092.88629073]]), array([[35910.74762445]]), array([[36045.49575484]]), array([[35958.78124026]]), array([[35920.12800084]]), array([[36083.64610857]]), array([[36009.82755342]]), array([[35994.43967914]]), array([[36066.5792828]]), array([[35937.88085521]]), array([[36040.30867256]]), array([[35964.28876244]]), array([[35978.48258024]]), array([[36025.80798735]]), array([[36046.07800254]]), array([[35957.98009507]]), array([[36032.25247517]]), array([[35972.15053127]]), array([[36017.20346212]]), array([[35987.13858729]]), array([[36044.48776071]]), array([[35959.85839013]]), array([[36023.51001613]]), array([[35980.80871923]]), array([[35923.899426]]), array([[36080.58571582]]), array([[36053.10672284]]), array([[35950.9155185]]), array([[36001.34837681]]), array([[36002.89636937]]), array([[35940.79490919]]), array([[36063.90590794]]), array([[36063.10085793]]), array([[35940.79259524]]), array([[35858.55407789]]), array([[36145.5265889]]), array([[36015.42834077]]), array([[35988.79083952]]), array([[35964.74250466]]), array([[36040.15214862]]), array([[35970.33650885]]), array([[36033.73954612]]), array([[36051.32881969]]), array([[35952.36169205]]), array([[36004.84616437]]), array([[35999.40348232]]), array([[36034.69023349]]), array([[35969.94643928]]), array([[35984.81407196]]), array([[36019.41204866]]), array([[36074.24765617]]), array([[35929.9726678]]), array([[35953.30027353]]), array([[36051.13008311]]), array([[36051.54345112]]), array([[35953.01355039]]), array([[35955.50327057]]), array([[36048.45256479]]), array([[35978.12981886]]), array([[36026.13407987]]), array([[36030.89895549]]), array([[35973.17998616]]), array([[36042.17321021]]), array([[35961.99958511]]), array([[36078.45584038]]), array([[35925.16117175]]), array([[35937.53364994]]), array([[36066.64586577]]), array([[36065.84786979]]), array([[35938.36873574]]), array([[36120.54214197]]), array([[35883.85605732]]), array([[36077.7690727]]), array([[35926.30846245]]), array([[35957.70848239]]), array([[36046.79838572]]), array([[36058.73380288]]), array([[35945.15572955]]), array([[35982.90074108]]), array([[36021.26851471]]), array([[36008.02439834]]), array([[35996.19396177]]), array([[35902.5114064]]), array([[36101.43743859]]), array([[35982.7296134]]), array([[36021.34507329]]), array([[36047.92594021]]), array([[35956.40964876]]), array([[36028.09518015]]), array([[35976.14263505]]), array([[36194.99992125]]), array([[35808.5364704]]), array([[36011.49247661]]), array([[35992.73665276]]), array([[35991.53677928]]), array([[36012.68912385]]), array([[35917.56725154]]), array([[36086.38341614]]), array([[35930.37884184]]), array([[36073.09819541]]), array([[35925.31873492]]), array([[36078.36763679]]), array([[35928.69881988]]), array([[36075.79368107]]), array([[35933.89119371]]), array([[36070.37308705]]), array([[35993.87731603]]), array([[36010.32537944]]), array([[35999.03687611]]), array([[36005.22283657]]), array([[36023.30225005]]), array([[35981.1223586]]), array([[36057.30910907]]), array([[35946.98035429]]), array([[35908.56383994]]), array([[36095.34006592]]), array([[36008.01707408]]), array([[35996.18687811]]), array([[35930.46398093]]), array([[36073.90014194]]), array([[36061.49320179]]), array([[35942.76248999]]), array([[35921.60984423]]), array([[36081.51902301]]), array([[35990.5662437]]), array([[36013.66047497]]), array([[36026.04193236]]), array([[35978.1493395]]), array([[36155.48708386]]), array([[35849.01356672]]), array([[35980.491923 ...
# est_y.shape: (1, 8192)
# est_y: [[36088.2901843  35916.44815197 36057.29799019 ... 36064.44031486
#   36010.36943383 35993.80177013]]
# fin_var: [3307.94855069]
# sqrt_total_var: 57.5147681094632
# For mi=0.001248318631131131, we should add noise from a normal distribution with scale...
# 	400.5387627251371 * 57.5147681094632 * [57.51476811] = [1324961.61964991]
# pac_noise: [1324961.61964991]
# mi=0.001248318631131131, scale=[1324961.61964991]
# Chosen Sample [36035.08398715]
# Chosen Sample [36001.99186251]
# Chosen Sample [36086.76985753]
# Chosen Sample [36041.47570064]
# Chosen Sample [35946.98035429]
# Chosen Sample [35946.71591977]
# Chosen Sample [36019.17285948]
# Chosen Sample [36026.30353824]
# Chosen Sample [35961.74246843]
# Chosen Sample [36000.59790851]
# Chosen Sample [36066.39179086]
# Chosen Sample [36055.123099]
# Chosen Sample [35996.99146745]
# Chosen Sample [36045.70744214]
# Chosen Sample [35956.35388862]
# Chosen Sample [36077.36073087]
# Chosen Sample [36015.14084622]
# Chosen Sample [36017.70507064]
# Chosen Sample [36036.51437291]
# Chosen Sample [36096.09130714]
# Chosen Sample [36008.55244456]
# Chosen Sample [35995.64171329]
# Chosen Sample [35916.02789456]
# Chosen Sample [36059.21998921]
# Chosen Sample [35991.04707293]
# Chosen Sample [35982.41132576]
# Chosen Sample [35926.09487599]
# Chosen Sample [36086.07788961]
# Chosen Sample [36122.86277524]
# Chosen Sample [35973.93896358]
# Chosen Sample [36013.74713448]
# Chosen Sample [35976.79240665]
# Chosen Sample [35957.16074655]
# Chosen Sample [35974.79520996]
# Chosen Sample [36067.11890126]
# Chosen Sample [35904.71130734]
# Chosen Sample [36032.07465311]
# Chosen Sample [35965.08875449]
# Chosen Sample [36031.47264678]
# Chosen Sample [36085.67087258]
# Chosen Sample [36002.36770488]
# Chosen Sample [36106.18275665]
# Chosen Sample [35942.52350413]
# Chosen Sample [36051.32475929]
# Chosen Sample [36016.54409432]
# Chosen Sample [36051.93774725]
# Chosen Sample [36019.61813785]
# Chosen Sample [35952.58847817]
# Chosen Sample [35861.36063212]
# Chosen Sample [35973.26603522]
# Chosen Sample [35990.87577109]
# Chosen Sample [35924.97789867]
# Chosen Sample [36050.18633263]
# Chosen Sample [35986.07723513]
# Chosen Sample [36100.32308742]
# Chosen Sample [36052.8801589]
# Chosen Sample [35940.7006515]
# Chosen Sample [35955.62643584]
# Chosen Sample [36034.1861873]
# Chosen Sample [36027.0352858]
# Chosen Sample [35989.64450663]
# Chosen Sample [36032.85930725]
# Chosen Sample [35942.76266233]
# Chosen Sample [35896.9749996]
# Chosen Sample [36063.3965399]
# Chosen Sample [35955.77587779]
# Chosen Sample [35963.62617079]
# Chosen Sample [35944.61201391]
# Chosen Sample [35990.85456454]
# Chosen Sample [36055.68407109]
# Chosen Sample [36039.04013177]
# Chosen Sample [35971.40722142]
# Chosen Sample [36116.81493476]
# Chosen Sample [36098.84452237]
# Chosen Sample [36003.6961781]
# Chosen Sample [35907.48888577]
# Chosen Sample [35919.27815682]
# Chosen Sample [35937.040027]
# Chosen Sample [35921.98703501]
# Chosen Sample [36023.32395542]
# Chosen Sample [36171.48470107]
# Chosen Sample [35977.82098253]
# Chosen Sample [35849.17882756]
# Chosen Sample [36006.37524491]
# Chosen Sample [36051.35278024]
# Chosen Sample [36005.13491183]
# Chosen Sample [35984.29917764]
# Chosen Sample [35993.97295578]
# Chosen Sample [35960.55257475]
# Chosen Sample [36075.99190317]
# Chosen Sample [36063.02292254]
# Chosen Sample [35990.48545121]
# Chosen Sample [36042.07415636]
# Chosen Sample [35945.32899803]
# Chosen Sample [36038.24189287]
# Chosen Sample [36029.19667434]
# Chosen Sample [35967.06308518]
# Chosen Sample [35933.91768211]
# Chosen Sample [36100.65943075]
# Chosen Sample [36072.69887956]
# Chosen Sample [36035.67088974]
# Chosen Sample [36105.51076764]
# Chosen Sample [35994.79599004]
# Chosen Sample [35999.57553301]
# Chosen Sample [36082.44889842]
# Chosen Sample [35986.19397777]
# Chosen Sample [35948.01090438]
# Chosen Sample [35959.21085843]
# Chosen Sample [35978.66845951]
# Chosen Sample [35978.9848525]
# Chosen Sample [36029.95481259]
# Chosen Sample [36074.20091508]
# Chosen Sample [36063.97079857]
# Chosen Sample [35996.35198895]
# Chosen Sample [36001.93585226]
# Chosen Sample [35981.95554115]
# Chosen Sample [35951.84705834]
# Chosen Sample [36013.05285516]
# Chosen Sample [35944.21886157]
# Chosen Sample [35994.01225402]
# Chosen Sample [36000.88103872]
# Chosen Sample [36097.94788804]
# Chosen Sample [36015.79514939]
# Chosen Sample [35973.26603522]
# Chosen Sample [36032.46853437]
# Chosen Sample [35924.92060176]
# Chosen Sample [35941.1213152]
# Chosen Sample [36057.44076779]
# Chosen Sample [36073.02944335]
# Chosen Sample [36003.93936522]
# Chosen Sample [35987.13184543]
# Chosen Sample [36101.76552894]
# Chosen Sample [35898.42915848]
# Chosen Sample [36032.81835294]
# Chosen Sample [35989.54618834]
# Chosen Sample [36059.5621077]
# Chosen Sample [35880.35702564]
# Chosen Sample [36029.17828787]
# Chosen Sample [36032.61098827]
# Chosen Sample [36080.52209437]
# Chosen Sample [36058.7509198]
# Chosen Sample [36044.63340335]
# Chosen Sample [35970.78818869]
# Chosen Sample [35978.9848525]
# Chosen Sample [36079.56336659]
# Chosen Sample [35971.29649738]
# Chosen Sample [35967.0306518]
# Chosen Sample [35998.50026276]
# Chosen Sample [35963.65392166]
# Chosen Sample [36100.17953851]
# Chosen Sample [36082.9242144]
# Chosen Sample [35993.75512593]
# Chosen Sample [36027.82475267]
# Chosen Sample [36061.84311413]
# Chosen Sample [36002.36770488]
# Chosen Sample [35909.19854652]
# Chosen Sample [36003.20238056]
# Chosen Sample [36058.80660181]
# Chosen Sample [35991.18090338]
# Chosen Sample [36003.2144861]
# Chosen Sample [36049.93629732]
# Chosen Sample [36010.04983846]
# Chosen Sample [36001.03829618]
# Chosen Sample [36071.12731628]
# Chosen Sample [36032.05672858]
# Chosen Sample [35859.05429054]
# Chosen Sample [36050.78541984]
# Chosen Sample [36045.07033148]
# Chosen Sample [36075.04752882]
# Chosen Sample [35886.26551495]
# Chosen Sample [36021.73729504]
# Chosen Sample [36017.37294917]
# Chosen Sample [35993.43860547]
# Chosen Sample [36005.8592888]
# Chosen Sample [36118.17964876]
# Chosen Sample [36021.31730209]
# Chosen Sample [36031.36019083]
# Chosen Sample [36006.98582302]
# Chosen Sample [36032.31082682]
# Chosen Sample [35969.3586629]
# Chosen Sample [36059.87212113]
# Chosen Sample [35988.42272666]
# Chosen Sample [36147.66126972]
# Chosen Sample [35988.76824443]
# Chosen Sample [36078.74412552]
# Chosen Sample [36070.06423096]
# Chosen Sample [36072.42658928]
# Chosen Sample [36032.70058512]
# Chosen Sample [35921.78585984]
# Chosen Sample [35963.44466855]
# Chosen Sample [36076.85464092]
# Chosen Sample [36000.54097631]
# Chosen Sample [35844.08680009]
# Chosen Sample [35991.96141191]
# Chosen Sample [35949.8129031]
# Chosen Sample [36124.00987504]
# Chosen Sample [35978.73519828]
# Chosen Sample [36003.2144861]
# Chosen Sample [35933.69858863]
# Chosen Sample [36051.73228845]
# Chosen Sample [35966.86450003]
# Chosen Sample [36008.33792683]
# Chosen Sample [35984.05013227]
# Chosen Sample [35991.5899225]
# Chosen Sample [36071.31481045]
# Chosen Sample [35966.18810575]
# Chosen Sample [36023.00140115]
# Chosen Sample [35883.12346459]
# Chosen Sample [36048.15885799]
# Chosen Sample [36014.30094902]
# Chosen Sample [35998.8223084]
# Chosen Sample [36119.04299149]
# Chosen Sample [35985.13677429]
# Chosen Sample [36005.21056851]
# Chosen Sample [35878.92824673]
# Chosen Sample [36098.11393391]
# Chosen Sample [35978.42722884]
# Chosen Sample [35841.2652343]
# Chosen Sample [36003.0996724]
# Chosen Sample [35921.23022055]
# Chosen Sample [36080.80977085]
# Chosen Sample [36006.35656191]
# Chosen Sample [35983.35992191]
# Chosen Sample [36065.57322227]
# Chosen Sample [35932.17644619]
# Chosen Sample [36010.13737078]
# Chosen Sample [35990.63150459]
# Chosen Sample [36100.97490264]
# Chosen Sample [35953.10843836]
# Chosen Sample [36062.4515287]
# Chosen Sample [35958.5344046]
# Chosen Sample [35994.64803505]
# Chosen Sample [36069.50657651]
# Chosen Sample [36026.07637735]
# Chosen Sample [36016.72012822]
# Chosen Sample [35956.1385106]
# Chosen Sample [35991.31016603]
# Chosen Sample [35932.2193987]
# Chosen Sample [36014.32359992]
# Chosen Sample [36053.36376956]
# Chosen Sample [36016.13467431]
# Chosen Sample [36076.33088715]
# Chosen Sample [35943.2594033]
# Chosen Sample [35997.99753634]
# Chosen Sample [36048.48272277]
# Chosen Sample [36038.02236574]
# Chosen Sample [35986.88288618]
# Chosen Sample [35930.95619314]
# Chosen Sample [36081.46565017]
# Chosen Sample [35967.77586198]
# Chosen Sample [36028.68565053]
# Chosen Sample [35973.77446517]
# Chosen Sample [36089.03910836]
# Chosen Sample [36043.0812352]
# Chosen Sample [35953.73075839]
# Chosen Sample [36006.17117623]
# Chosen Sample [36047.6873591]
# Chosen Sample [35995.66958548]
# Chosen Sample [36006.07957016]
# Chosen Sample [35883.32839091]
# Chosen Sample [35951.17753782]
# Chosen Sample [35966.88671337]
# Chosen Sample [35862.78941811]
# Chosen Sample [36013.46320765]
# Chosen Sample [36054.76742713]
# Chosen Sample [35974.54145691]
# Chosen Sample [35973.71339331]
# Chosen Sample [35945.25292277]
# Chosen Sample [35969.64596344]
# Chosen Sample [35909.25297518]
# Chosen Sample [35936.14658334]
# Chosen Sample [36014.73772686]
# Chosen Sample [36038.40583765]
# Chosen Sample [36086.09518845]
# Chosen Sample [36029.65521207]
# Chosen Sample [36003.6322929]
# Chosen Sample [36007.8517137]
# Chosen Sample [36023.00871857]
# Chosen Sample [35992.17413811]
# Chosen Sample [36057.48701939]
# Chosen Sample [35997.25953655]
# Chosen Sample [36121.35726423]
# Chosen Sample [36114.56804683]
# Chosen Sample [36016.77331348]
# Chosen Sample [35996.03673962]
# Chosen Sample [36004.80431117]
# Chosen Sample [36035.46013694]
# Chosen Sample [36099.41364991]
# Chosen Sample [35971.51856026]
# Chosen Sample [35953.59999187]
# Chosen Sample [36000.59790851]
# Chosen Sample [36063.32431585]
# Chosen Sample [35990.86909442]
# Chosen Sample [36012.61195084]
# Chosen Sample [35968.34004134]
# Chosen Sample [36008.16616724]
# Chosen Sample [35904.27124427]
# Chosen Sample [35970.45046606]
# Chosen Sample [36037.12946491]
# Chosen Sample [36091.43223246]
# Chosen Sample [35982.33427697]
# Chosen Sample [35887.13528032]
# Chosen Sample [35951.83782999]
# Chosen Sample [36083.35879579]
# Chosen Sample [36037.4256242]
# Chosen Sample [36028.25283167]
# Chosen Sample [35981.99258955]
# Chosen Sample [36001.51596607]
# Chosen Sample [35940.42720185]
# Chosen Sample [35985.93873876]
# Chosen Sample [35953.02655707]
# Chosen Sample [35897.74764542]
# Chosen Sample [36035.38750803]
# Chosen Sample [36033.87552343]
# Chosen Sample [36045.77798035]
# Chosen Sample [36015.76624045]
# Chosen Sample [35969.44579565]
# Chosen Sample [36044.29143]
# Chosen Sample [35913.93446568]
# Chosen Sample [36029.09921408]
# Chosen Sample [36066.37695492]
# Chosen Sample [35970.52128074]
# Chosen Sample [35959.81649617]
# Chosen Sample [35999.18883275]
# Chosen Sample [35994.47030953]
# Chosen Sample [35975.7752066]
# Chosen Sample [35902.11647787]
# Chosen Sample [35963.54271163]
# Chosen Sample [36075.11991842]
# Chosen Sample [35944.62290749]
# Chosen Sample [35984.15360517]
# Chosen Sample [36053.10672284]
# Chosen Sample [35988.82461151]
# Chosen Sample [35955.77587779]
# Chosen Sample [36005.03958537]
# Chosen Sample [36000.54216128]
# Chosen Sample [36053.16250217]
# Chosen Sample [36054.50294096]
# Chosen Sample [35960.72998597]
# Chosen Sample [35952.10997152]
# Chosen Sample [35999.14907865]
# Chosen Sample [35977.50822236]
# Chosen Sample [36054.76995846]
# Chosen Sample [36080.73728347]
# Chosen Sample [35997.25953655]
# Chosen Sample [36015.52043285]
# Chosen Sample [35982.53227235]
# Chosen Sample [35979.41137333]
# Chosen Sample [36193.39105003]
# Chosen Sample [36019.79099153]
# Chosen Sample [35813.18066719]
# Chosen Sample [36095.12475253]
# Chosen Sample [35942.72842699]
# Chosen Sample [35923.08062952]
# Chosen Sample [36001.34837681]
# Chosen Sample [35955.34549958]
# Chosen Sample [35901.65215225]
# Chosen Sample [36066.51326983]
# Chosen Sample [35988.95147481]
# Chosen Sample [35945.71039321]
# Chosen Sample [35939.54724291]
# Chosen Sample [36002.85002002]
# Chosen Sample [35972.24408117]
# Chosen Sample [35916.33548373]
# Chosen Sample [35939.97119336]
# Chosen Sample [36019.95111047]
# Chosen Sample [36007.83633198]
# Chosen Sample [35975.62358254]
# Chosen Sample [36077.73405033]
# Chosen Sample [36029.70475819]
# Chosen Sample [35901.54727058]
# Chosen Sample [35938.84288624]
# Chosen Sample [36076.40134955]
# Chosen Sample [36042.28609507]
# Chosen Sample [35961.52862022]
# Chosen Sample [35964.06882328]
# Chosen Sample [36071.42073097]
# Chosen Sample [36088.30442429]
# Chosen Sample [36092.26924627]
# Chosen Sample [35884.48255347]
# Chosen Sample [36028.72311665]
# Chosen Sample [36103.49254284]
# Chosen Sample [35921.78585984]
# Chosen Sample [35924.22379492]
# Chosen Sample [36096.2303592]
# Chosen Sample [35978.68103036]
# Chosen Sample [35964.95455168]
# Chosen Sample [35975.11027049]
# Chosen Sample [36007.29798923]
# Chosen Sample [36112.23007987]
# Chosen Sample [36035.89938511]
# Chosen Sample [36057.30910907]
# Chosen Sample [35928.67574677]
# Chosen Sample [36122.53790496]
# Chosen Sample [36065.09797738]
# Chosen Sample [36049.77349601]
# Chosen Sample [36037.57216516]
# Chosen Sample [35965.57117704]
# Chosen Sample [35912.59301684]
# Chosen Sample [35991.99164177]
# Chosen Sample [35985.48010353]
# Chosen Sample [35982.7296134]
# Chosen Sample [35901.92760637]
# Chosen Sample [36048.48683581]
# Chosen Sample [36045.63593452]
# Chosen Sample [35969.66199265]
# Chosen Sample [35945.71039321]
# Chosen Sample [35999.90785436]
# Chosen Sample [36009.56255334]
# Chosen Sample [36011.78175086]
# Chosen Sample [36063.0047213]
# Chosen Sample [35946.66335285]
# Chosen Sample [35974.31008151]
# Chosen Sample [36059.14998352]
# Chosen Sample [36133.90908274]
# Chosen Sample [35954.18829248]
# Chosen Sample [36084.11192653]
# Chosen Sample [36045.77299351]
# Chosen Sample [36086.5153859]
# Chosen Sample [35940.27111877]
# Chosen Sample [35994.19139618]
# Chosen Sample [35973.77446517]
# Chosen Sample [35966.54332293]
# Chosen Sample [36028.45714489]
# Chosen Sample [35967.50995653]
# Chosen Sample [36036.3680475]
# Chosen Sample [36004.78851826]
# Chosen Sample [35996.02795458]
# Chosen Sample [36070.72009345]
# Chosen Sample [36022.70476575]
# Chosen Sample [36043.83490103]
# Chosen Sample [36058.05299995]
# Chosen Sample [35900.31554349]
# Chosen Sample [36048.08919895]
# Chosen Sample [35945.09447147]
# Chosen Sample [35929.06966443]
# Chosen Sample [35964.18386015]
# Chosen Sample [35972.03769308]
# Chosen Sample [36037.14859435]
# Chosen Sample [35991.60779483]
# Chosen Sample [36011.28590628]
# Chosen Sample [36028.96676828]
# Chosen Sample [35967.77566743]
# Chosen Sample [35970.65629778]
# Chosen Sample [36110.65313273]
# Chosen Sample [35940.41355023]
# Chosen Sample [36106.24607312]
# Chosen Sample [36003.40278851]
# Chosen Sample [35964.8135422]
# Chosen Sample [35913.40284825]
# Chosen Sample [35954.87638928]
# Chosen Sample [36053.61840426]
# Chosen Sample [35965.08875449]
# Chosen Sample [36093.48956372]
# Chosen Sample [36007.28108553]
# Chosen Sample [36032.80470828]
# Chosen Sample [36013.11038469]
# Chosen Sample [36024.32259426]
# Chosen Sample [35972.43758828]
# Chosen Sample [35926.77236257]
# Chosen Sample [36006.38795194]
# Chosen Sample [36011.04074001]
# Chosen Sample [36007.01478851]
# Chosen Sample [36029.08522357]
# Chosen Sample [36048.04061943]
# Chosen Sample [35988.86983406]
# Chosen Sample [36039.96511843]
# Chosen Sample [35962.43380921]
# Chosen Sample [35921.98703501]
# Chosen Sample [35987.10791713]
# Chosen Sample [35964.46757406]
# Chosen Sample [35983.55201096]
# Chosen Sample [36053.91236743]
# Chosen Sample [36059.8702989]
# Chosen Sample [35946.77933215]
# Chosen Sample [35999.5278184]
# Chosen Sample [35948.35729648]
# Chosen Sample [36053.41635025]
# Chosen Sample [36055.78054085]
# Chosen Sample [35947.50557894]
# Chosen Sample [35978.08272415]
# Chosen Sample [35923.24973707]
# Chosen Sample [36026.22282849]
# Chosen Sample [35968.16142472]
# Chosen Sample [35990.2141437]
# Chosen Sample [36050.6833909]
# Chosen Sample [35990.38681053]
# Chosen Sample [36053.30499905]
# Chosen Sample [35915.17801919]
# Chosen Sample [36057.82731593]
# Chosen Sample [36033.21193317]
# Chosen Sample [35998.81746656]
# Chosen Sample [36053.58186782]
# Chosen Sample [35975.38525405]
# Chosen Sample [35956.96921782]
# Chosen Sample [35969.77897425]
# Chosen Sample [36020.86373689]
# Chosen Sample [36033.57574933]
# Chosen Sample [36028.57843012]
# Chosen Sample [35992.37769059]
# Chosen Sample [35932.80266095]
# Chosen Sample [36079.02955613]
# Chosen Sample [36015.07713812]
# Chosen Sample [35942.80849527]
# Chosen Sample [36080.52209437]
# Chosen Sample [35977.15552181]
# Chosen Sample [36058.72999432]
# Chosen Sample [35975.20542244]
# Chosen Sample [36035.289623]
# Chosen Sample [35882.21484082]
# Chosen Sample [36076.95594692]
# Chosen Sample [35967.38710599]
# Chosen Sample [35999.10495901]
# Chosen Sample [35997.90748187]
# Chosen Sample [35841.99482651]
# Chosen Sample [36008.53695009]
# Chosen Sample [35925.48872342]
# Chosen Sample [36054.50294096]
# Chosen Sample [35995.28711325]
# Chosen Sample [36029.11979614]
# Chosen Sample [35873.00259427]
# Chosen Sample [35979.64078223]
# Chosen Sample [36048.15885799]
# Chosen Sample [36021.05274624]
# Chosen Sample [36007.63309073]
# Chosen Sample [36003.36836965]
# Chosen Sample [36037.23636757]
# Chosen Sample [35941.06189174]
# Chosen Sample [35935.44949041]
# Chosen Sample [35936.14658334]
# Chosen Sample [35924.33551258]
# Chosen Sample [35902.5114064]
# Chosen Sample [35960.79982322]
# Chosen Sample [35978.03168088]
# Chosen Sample [35952.36169205]
# Chosen Sample [35918.03420487]
# Chosen Sample [35965.28971679]
# Chosen Sample [36041.06530986]
# Chosen Sample [36067.71861925]
# Chosen Sample [36004.00357456]
# Chosen Sample [36146.30089277]
# Chosen Sample [36025.31043256]
# Chosen Sample [36040.89852571]
# Chosen Sample [35994.92844059]
# Chosen Sample [36040.41977132]
# Chosen Sample [35937.54973945]
# Chosen Sample [35987.0154521]
# Chosen Sample [36014.75393129]
# Chosen Sample [36072.72226171]
# Chosen Sample [35968.37875895]
# Chosen Sample [36005.21056851]
# Chosen Sample [35974.83940334]
# Chosen Sample [36057.69196729]
# Chosen Sample [36005.74696283]
# Chosen Sample [36023.24814569]
# Chosen Sample [36020.41495121]
# Chosen Sample [36126.95748032]
# Chosen Sample [36095.34006592]
# Chosen Sample [36021.73729504]
# Chosen Sample [36040.75499193]
# Chosen Sample [36019.16917193]
# Chosen Sample [35986.40021569]
# Chosen Sample [35965.20168074]
# Chosen Sample [36008.687567]
# Chosen Sample [36055.02099611]
# Chosen Sample [36075.38216386]
# Chosen Sample [36012.57126261]
# Chosen Sample [35975.32372084]
# Chosen Sample [36021.48570227]
# Chosen Sample [35957.22534754]
# Chosen Sample [35977.96288729]
# Chosen Sample [36006.69317908]
# Chosen Sample [36016.19122189]
# Chosen Sample [35929.47016651]
# Chosen Sample [36090.56567292]
# Chosen Sample [36026.23878805]
# Chosen Sample [35988.10673035]
# Chosen Sample [36029.69506587]
# Chosen Sample [35948.63980318]
# Chosen Sample [36064.91745829]
# Chosen Sample [36085.15635771]
# Chosen Sample [35946.81028604]
# Chosen Sample [35933.29676588]
# Chosen Sample [35997.99753634]
# Chosen Sample [36063.07835743]
# Chosen Sample [36050.43462981]
# Chosen Sample [35959.8868687]
# Chosen Sample [35928.09276678]
# Chosen Sample [35970.44031289]
# Chosen Sample [36021.05274624]
# Chosen Sample [36026.73770899]
# Chosen Sample [36098.80151993]
# Chosen Sample [35949.03983833]
# Chosen Sample [36006.93691538]
# Chosen Sample [35933.69515243]
# Chosen Sample [36068.97776703]
# Chosen Sample [35875.2984779]
# Chosen Sample [35955.14898151]
# Chosen Sample [36027.80929468]
# Chosen Sample [35992.50764013]
# Chosen Sample [35948.01090438]
# Chosen Sample [35912.24710877]
# Chosen Sample [36029.60656188]
# Chosen Sample [35961.86799827]
# Chosen Sample [35909.32168232]
# Chosen Sample [35974.89106552]
# Chosen Sample [35993.63046712]
# Chosen Sample [36051.93543145]
# Chosen Sample [35952.11977476]
# Chosen Sample [35933.69515243]
# Chosen Sample [35993.98351519]
# Chosen Sample [35988.46723058]
# Chosen Sample [36065.94965034]
# Chosen Sample [36055.37513793]
# Chosen Sample [35959.50614233]
# Chosen Sample [35944.43240352]
# Chosen Sample [35965.57423049]
# Chosen Sample [35926.33813346]
# Chosen Sample [36060.35895393]
# Chosen Sample [36055.71436823]
# Chosen Sample [36045.63593452]
# Chosen Sample [35990.76909473]
# Chosen Sample [35943.55036425]
# Chosen Sample [35972.24408117]
# Chosen Sample [35963.47991452]
# Chosen Sample [36000.31579543]
# Chosen Sample [35966.35912444]
# Chosen Sample [36008.53695009]
# Chosen Sample [35995.87665181]
# Chosen Sample [35994.1141796]
# Chosen Sample [35983.95337515]
# Chosen Sample [35856.95363452]
# Chosen Sample [36019.41204866]
# Chosen Sample [36037.68856303]
# Chosen Sample [36036.0846644]
# Chosen Sample [35995.61346299]
# Chosen Sample [36049.74539681]
# Chosen Sample [35942.72842699]
# Chosen Sample [35988.17036741]
# Chosen Sample [36043.52538471]
# Chosen Sample [36020.28373373]
# Chosen Sample [35994.90185773]
# Chosen Sample [35940.5432613]
# Chosen Sample [35997.94716077]
# Chosen Sample [35981.43891278]
# Chosen Sample [36044.15170296]
# Chosen Sample [35909.51340792]
# Chosen Sample [36018.50690942]
# Chosen Sample [35897.52364325]
# Chosen Sample [36034.62982868]
# Chosen Sample [35926.33813346]
# Chosen Sample [35995.01667475]
# Chosen Sample [35911.99455227]
# Chosen Sample [35924.65694207]
# Chosen Sample [36102.44758991]
# Chosen Sample [35912.38421254]
# Chosen Sample [35936.16885705]
# Chosen Sample [36117.4606196]
# Chosen Sample [36063.74982595]
# Chosen Sample [35963.59604478]
# Chosen Sample [35978.59711764]
# Chosen Sample [36097.40994462]
# Chosen Sample [35981.92956965]
# Chosen Sample [35951.92270887]
# Chosen Sample [36006.84047502]
# Chosen Sample [36014.10777706]
# Chosen Sample [35977.76034633]
# Chosen Sample [35958.33831576]
# Chosen Sample [35947.29717292]
# Chosen Sample [36055.33257932]
# Chosen Sample [36015.24190268]
# Chosen Sample [36065.51556741]
# Chosen Sample [36079.09229863]
# Chosen Sample [36010.96279398]
# Chosen Sample [36021.16481937]
# Chosen Sample [36107.57744382]
# Chosen Sample [35971.30884336]
# Chosen Sample [36018.61294023]
# Chosen Sample [35992.0492957]
# Chosen Sample [36053.59177596]
# Chosen Sample [35908.11909021]
# Chosen Sample [35985.99005296]
# Chosen Sample [36019.85804659]
# Chosen Sample [36101.65842216]
# Chosen Sample [35955.62643584]
# Chosen Sample [35825.33989027]
# Chosen Sample [36026.0470672]
# Chosen Sample [35884.42194961]
# Chosen Sample [36016.12680896]
# Chosen Sample [36008.4532954]
# Chosen Sample [35885.98652133]
# Chosen Sample [36002.24468954]
# Chosen Sample [36137.60320801]
# Chosen Sample [36072.72226171]
# Chosen Sample [36017.75505036]
# Chosen Sample [36024.8165744]
# Chosen Sample [35937.94704892]
# Chosen Sample [36058.79015648]
# Chosen Sample [36070.02702795]
# Chosen Sample [36088.58838383]
# Chosen Sample [36076.2774768]
# Chosen Sample [36013.91018945]
# Chosen Sample [35879.57811048]
# Chosen Sample [35979.70652181]
# Chosen Sample [35933.9929693]
# Chosen Sample [35945.03697595]
# Chosen Sample [36090.78602224]
# Chosen Sample [35954.4615465]
# Chosen Sample [36019.7977229]
# Chosen Sample [35970.69132805]
# Chosen Sample [35972.50089865]
# Chosen Sample [35993.43142032]
# Chosen Sample [36036.74381728]
# Chosen Sample [35854.47294503]
# Chosen Sample [35963.84801908]
# Chosen Sample [35954.81123968]
# Chosen Sample [35978.48277444]
# Chosen Sample [36044.74439036]
# Chosen Sample [36024.11873009]
# Chosen Sample [35855.38573543]
# Chosen Sample [36098.74162011]
# Chosen Sample [36052.86478737]
# Chosen Sample [35947.50557894]
# Chosen Sample [35885.35983933]
# Chosen Sample [36100.26858125]
# Chosen Sample [36021.11616219]
# Chosen Sample [36064.77402381]
# Chosen Sample [36002.09065969]
# Chosen Sample [35908.15924853]
# Chosen Sample [36085.87666847]
# Chosen Sample [36045.28099147]
# Chosen Sample [36046.92965945]
# Chosen Sample [36023.24814569]
# Chosen Sample [35917.59474891]
# Chosen Sample [36049.39360345]
# Chosen Sample [35972.44833505]
# Chosen Sample [36094.34057002]
# Chosen Sample [35957.83990211]
# Chosen Sample [35992.67429408]
# Chosen Sample [35809.38281473]
# Chosen Sample [35870.24631584]
# Chosen Sample [36091.63560198]
# Chosen Sample [36009.96063939]
# Chosen Sample [36023.67289671]
# Chosen Sample [35972.14525914]
# Chosen Sample [36020.71819318]
# Chosen Sample [35925.6315118]
# Chosen Sample [35909.25297518]
# Chosen Sample [35953.99867831]
# Chosen Sample [35875.74710053]
# Chosen Sample [35944.97674227]
# Chosen Sample [36088.21290323]
# Chosen Sample [35826.98470148]
# Chosen Sample [36081.60368516]
# Chosen Sample [36055.13395832]
# Chosen Sample [35991.84957737]
# Chosen Sample [35961.20086206]
# Chosen Sample [36028.96899862]
# Chosen Sample [35933.62214128]
# Chosen Sample [36072.86568891]
# Chosen Sample [35897.24144028]
# Chosen Sample [36003.16505359]
# Chosen Sample [35981.20037658]
# Chosen Sample [35961.55364022]
# Chosen Sample [35919.60609847]
# Chosen Sample [36005.25043058]
# Chosen Sample [36021.31953743]
# Chosen Sample [35977.66133412]
# Chosen Sample [35989.95864469]
# Chosen Sample [36085.24492078]
# Chosen Sample [35879.57811048]
# Chosen Sample [36016.19122189]
# Chosen Sample [36050.83230476]
# Chosen Sample [35902.10250203]
# Chosen Sample [35887.17137287]
# Chosen Sample [35983.12625119]
# Chosen Sample [35994.40618623]
# Chosen Sample [36002.74422361]
# Chosen Sample [35991.20741827]
# Chosen Sample [36057.44076779]
# Chosen Sample [35956.1385106]
# Chosen Sample [35957.28820409]
# Chosen Sample [36017.36791223]
# Chosen Sample [35959.90431356]
# Chosen Sample [36015.77185803]
# Chosen Sample [36085.3112255]
# Chosen Sample [36056.13681797]
# Chosen Sample [36021.26851471]
# Chosen Sample [35810.21181485]
# Chosen Sample [36065.11804273]
# Chosen Sample [35964.46757406]
# Chosen Sample [35929.74765168]
# Chosen Sample [36001.97663897]
# Chosen Sample [35941.54756816]
# Chosen Sample [36014.33117744]
# Chosen Sample [36024.64014598]
# Chosen Sample [36090.83520521]
# Chosen Sample [35889.29213759]
# Chosen Sample [36042.72261361]
# Chosen Sample [35965.84444423]
# Chosen Sample [35998.7417914]
# Chosen Sample [36055.3663069]
# Chosen Sample [36076.48634143]
# Chosen Sample [36085.62252658]
# Chosen Sample [35975.6596019]
# Chosen Sample [35901.21944764]
# Chosen Sample [36044.99283232]
# Chosen Sample [36016.12874659]
# Chosen Sample [36027.1051146]
# Chosen Sample [35991.27999341]
# Chosen Sample [35970.36648796]
# Chosen Sample [35971.08948477]
# Chosen Sample [35909.14248581]
# Chosen Sample [36171.50977467]
# Chosen Sample [35915.3187435]
# Chosen Sample [36101.94344172]
# Chosen Sample [36040.11721651]
# Chosen Sample [35958.90169207]
# Chosen Sample [36049.2889528]
# Chosen Sample [36001.74832219]
# Chosen Sample [35940.09108581]
# Chosen Sample [36089.09965321]
# Chosen Sample [36036.37216177]
# Chosen Sample [36132.38560028]
# Chosen Sample [35992.11880316]
# Chosen Sample [35988.63813685]
# Chosen Sample [35961.46780924]
# Chosen Sample [35996.68130181]
# Chosen Sample [35837.54620059]
# Chosen Sample [36017.74395836]
# Chosen Sample [35994.34782862]
# Chosen Sample [36063.97079857]
# Chosen Sample [36001.87856307]
# Chosen Sample [36101.32984987]
# Chosen Sample [36004.1209764]
# Chosen Sample [35942.26780306]
# Chosen Sample [35988.82461151]
# Chosen Sample [35921.54399442]
# Chosen Sample [36031.90298974]
# Chosen Sample [36023.79304101]
# Chosen Sample [36116.46238921]
# Chosen Sample [36013.18518721]
# Chosen Sample [35943.58957518]
# Chosen Sample [36026.23281554]
# Chosen Sample [35893.4793545]
# Chosen Sample [36068.1016671]
# Chosen Sample [36134.44409021]
# Chosen Sample [36063.42933583]
# Chosen Sample [36049.34036334]
# Chosen Sample [36084.60366471]
# Chosen Sample [36005.77463121]
# Chosen Sample [36045.64308576]
# Chosen Sample [36048.21287126]
# Chosen Sample [36044.73890325]
# Chosen Sample [36066.75162347]
# Chosen Sample [35989.93111043]
# Chosen Sample [36076.14340725]
# Chosen Sample [35940.68529254]
# Chosen Sample [35990.07433275]
# Chosen Sample [36015.12210989]
# Chosen Sample [36036.32732261]
# Chosen Sample [36100.6928064]
# Chosen Sample [36015.25355741]
# Chosen Sample [36051.71777555]
# Chosen Sample [36018.9044778]
# Chosen Sample [35989.83625906]
# Chosen Sample [35950.63858394]
# Chosen Sample [35980.15478318]
# Chosen Sample [35980.73287856]
# Chosen Sample [36055.82433958]
# Chosen Sample [36008.61629213]
# Chosen Sample [36084.39076902]
# Chosen Sample [36002.71194941]
# Chosen Sample [35939.0333211]
# Chosen Sample [36017.36791223]
# Chosen Sample [35952.54572478]
# Chosen Sample [36064.45503273]
# Chosen Sample [35916.74283545]
# Chosen Sample [36025.2646844]
# Chosen Sample [35965.29337062]
# Chosen Sample [36049.14228786]
# Chosen Sample [36005.86870689]
# Chosen Sample [35998.06739196]
# Chosen Sample [36094.62828094]
# Chosen Sample [36058.27088017]
# Chosen Sample [36060.54680144]
# Chosen Sample [36059.22156402]
# Chosen Sample [36021.33117499]
# Chosen Sample [35908.27580861]
# Chosen Sample [35912.38421254]
# Chosen Sample [35987.37184446]
# Chosen Sample [35978.1493395]
# Chosen Sample [35975.17968878]
# Chosen Sample [36080.73728347]
# Chosen Sample [36008.36170209]
# Chosen Sample [35991.40962689]
# Chosen Sample [35976.47646764]
# Chosen Sample [35950.87336563]
# Chosen Sample [36029.34575873]
# Chosen Sample [36038.78945154]
# Chosen Sample [36101.94074694]
# Chosen Sample [36055.33252061]
# Chosen Sample [36005.07980474]
# Chosen Sample [36063.76244714]
# Chosen Sample [36025.98883049]
# Chosen Sample [35953.07145671]
# Chosen Sample [36005.49942644]
# Chosen Sample [35955.1422576]
# Chosen Sample [35930.95619314]
# Chosen Sample [36021.31953743]
# Chosen Sample [36026.92854926]
# Chosen Sample [36001.04716208]
# Chosen Sample [36015.84687514]
# Chosen Sample [35897.85315375]
# Chosen Sample [35889.7252522]
# Chosen Sample [36070.55360361]
# Chosen Sample [36094.51332433]
# Chosen Sample [36008.5739183]
# Chosen Sample [36045.29284992]
# Chosen Sample [36022.13193754]
# Chosen Sample [35965.95770149]
# Chosen Sample [35952.82745987]
# Chosen Sample [36025.1321077]
# Chosen Sample [36046.63680846]
# Chosen Sample [35858.08730846]
# Chosen Sample [35972.76656995]
# Chosen Sample [36034.31360797]
# Chosen Sample [36024.64372419]
# Chosen Sample [36055.123099]
# Chosen Sample [35986.4764757]
# Chosen Sample [35969.09714541]
# Chosen Sample [35945.96458889]
# Chosen Sample [36012.30786554]
# Chosen Sample [35981.51845602]
# Chosen Sample [36064.1994384]
# Chosen Sample [36021.16164287]
# Chosen Sample [35983.79154636]
# Chosen Sample [35984.71072037]
# Chosen Sample [35944.8632529]
# Chosen Sample [35989.75181239]
# Chosen Sample [36001.3968514]
# Chosen Sample [36098.46171599]
# Chosen Sample [35992.44825439]
# Chosen Sample [35937.88085521]
# Chosen Sample [36039.64036267]
# Chosen Sample [36009.12315628]
# Chosen Sample [35956.21887829]
# Chosen Sample [36130.23722081]
# Chosen Sample [36040.44743113]
# Chosen Sample [35988.76824443]
# Chosen Sample [35972.38044248]
# Chosen Sample [36004.18992311]
# Chosen Sample [36055.68580584]
# Chosen Sample [36065.37374637]
# Chosen Sample [36001.11696244]
# Chosen Sample [35927.65185401]
# Chosen Sample [35973.25865436]
# Chosen Sample [35975.2736236]
# Chosen Sample [36001.04860017]
# Chosen Sample [36020.1164399]
# Chosen Sample [35999.33955054]
# Chosen Sample [36011.71437309]
# Chosen Sample [36036.10165034]
# Chosen Sample [35960.24093114]
# Chosen Sample [35982.55196664]
# Chosen Sample [36124.35621038]
# Chosen Sample [36018.77383017]
# Chosen Sample [36014.3148977]
# Chosen Sample [36033.21193317]
# Chosen Sample [35997.297115]
# Chosen Sample [35954.72964892]
# Chosen Sample [35991.05477397]
# Chosen Sample [36066.5792828]
# Chosen Sample [36021.56291575]
# Chosen Sample [36008.93747351]
# Chosen Sample [35997.55651976]
# Chosen Sample [36007.26039643]
# Chosen Sample [36050.17536329]
# Chosen Sample [35986.62022676]
# Chosen Sample [36027.30912727]
# Chosen Sample [35972.24124272]
# Chosen Sample [36085.3112255]
# Chosen Sample [35990.98757625]
# Chosen Sample [35885.40626726]
# Chosen Sample [35979.88750579]
# Chosen Sample [36099.38017328]
# Chosen Sample [35992.9707956]
# Chosen Sample [36096.35053203]
# Chosen Sample [36062.70108252]
# Chosen Sample [35950.67691605]
# Chosen Sample [35984.16192604]
# Chosen Sample [36013.05285516]
# Chosen Sample [36101.94344172]
# Chosen Sample [35959.85169664]
# Chosen Sample [36017.65406948]
# Chosen Sample [36017.77246893]
# Chosen Sample [35982.04800924]
# Chosen Sample [36010.7753216]
# Chosen Sample [35977.73684768]
# Chosen Sample [35981.51845602]
# Getting PAC Noise...
# The dimensions are - 1
# [array([[36088.2901843]]), array([[35916.44815197]]), array([[36057.29799019]]), array([[35947.0645332]]), array([[36012.49425479]]), array([[35991.76378321]]), array([[35969.09714541]]), array([[36035.25077931]]), array([[36076.40134955]]), array([[35927.97285284]]), array([[35916.1254516]]), array([[36088.24798784]]), array([[35962.85560567]]), array([[36041.31984763]]), array([[35914.52971263]]), array([[36089.6729123]]), array([[36096.35053203]]), array([[35907.77463269]]), array([[36092.88629073]]), array([[35910.74762445]]), array([[36045.49575484]]), array([[35958.78124026]]), array([[35920.12800084]]), array([[36083.64610857]]), array([[36009.82755342]]), array([[35994.43967914]]), array([[36066.5792828]]), array([[35937.88085521]]), array([[36040.30867256]]), array([[35964.28876244]]), array([[35978.48258024]]), array([[36025.80798735]]), array([[36046.07800254]]), array([[35957.98009507]]), array([[36032.25247517]]), array([[35972.15053127]]), array([[36017.20346212]]), array([[35987.13858729]]), array([[36044.48776071]]), array([[35959.85839013]]), array([[36023.51001613]]), array([[35980.80871923]]), array([[35923.899426]]), array([[36080.58571582]]), array([[36053.10672284]]), array([[35950.9155185]]), array([[36001.34837681]]), array([[36002.89636937]]), array([[35940.79490919]]), array([[36063.90590794]]), array([[36063.10085793]]), array([[35940.79259524]]), array([[35858.55407789]]), array([[36145.5265889]]), array([[36015.42834077]]), array([[35988.79083952]]), array([[35964.74250466]]), array([[36040.15214862]]), array([[35970.33650885]]), array([[36033.73954612]]), array([[36051.32881969]]), array([[35952.36169205]]), array([[36004.84616437]]), array([[35999.40348232]]), array([[36034.69023349]]), array([[35969.94643928]]), array([[35984.81407196]]), array([[36019.41204866]]), array([[36074.24765617]]), array([[35929.9726678]]), array([[35953.30027353]]), array([[36051.13008311]]), array([[36051.54345112]]), array([[35953.01355039]]), array([[35955.50327057]]), array([[36048.45256479]]), array([[35978.12981886]]), array([[36026.13407987]]), array([[36030.89895549]]), array([[35973.17998616]]), array([[36042.17321021]]), array([[35961.99958511]]), array([[36078.45584038]]), array([[35925.16117175]]), array([[35937.53364994]]), array([[36066.64586577]]), array([[36065.84786979]]), array([[35938.36873574]]), array([[36120.54214197]]), array([[35883.85605732]]), array([[36077.7690727]]), array([[35926.30846245]]), array([[35957.70848239]]), array([[36046.79838572]]), array([[36058.73380288]]), array([[35945.15572955]]), array([[35982.90074108]]), array([[36021.26851471]]), array([[36008.02439834]]), array([[35996.19396177]]), array([[35902.5114064]]), array([[36101.43743859]]), array([[35982.7296134]]), array([[36021.34507329]]), array([[36047.92594021]]), array([[35956.40964876]]), array([[36028.09518015]]), array([[35976.14263505]]), array([[36194.99992125]]), array([[35808.5364704]]), array([[36011.49247661]]), array([[35992.73665276]]), array([[35991.53677928]]), array([[36012.68912385]]), array([[35917.56725154]]), array([[36086.38341614]]), array([[35930.37884184]]), array([[36073.09819541]]), array([[35925.31873492]]), array([[36078.36763679]]), array([[35928.69881988]]), array([[36075.79368107]]), array([[35933.89119371]]), array([[36070.37308705]]), array([[35993.87731603]]), array([[36010.32537944]]), array([[35999.03687611]]), array([[36005.22283657]]), array([[36023.30225005]]), array([[35981.1223586]]), array([[36057.30910907]]), array([[35946.98035429]]), array([[35908.56383994]]), array([[36095.34006592]]), array([[36008.01707408]]), array([[35996.18687811]]), array([[35930.46398093]]), array([[36073.90014194]]), array([[36061.49320179]]), array([[35942.76248999]]), array([[35921.60984423]]), array([[36081.51902301]]), array([[35990.5662437]]), array([[36013.66047497]]), array([[36026.04193236]]), array([[35978.1493395]]), array([[36155.48708386]]), array([[35849.01356672]]), array([[35980.491923 ...
# est_y.shape: (1, 8192)
# est_y: [[36088.2901843  35916.44815197 36057.29799019 ... 36064.44031486
#   36010.36943383 35993.80177013]]
# fin_var: [3307.94855069]
# sqrt_total_var: 57.5147681094632
# For mi=0.015625, we should add noise from a normal distribution with scale...
# 	32.0 * 57.5147681094632 * [57.51476811] = [105854.35362193]
# pac_noise: [105854.35362193]
# mi=0.015625, scale=[105854.35362193]
# Chosen Sample [36082.84247327]
# Chosen Sample [36104.02407004]
# Chosen Sample [35895.30977306]
# Chosen Sample [36001.2322652]
# Chosen Sample [35966.24973544]
# Chosen Sample [35988.85248886]
# Chosen Sample [36035.80900855]
# Chosen Sample [35892.60210551]
# Chosen Sample [36022.4706076]
# Chosen Sample [36016.35552799]
# Chosen Sample [35966.67790524]
# Chosen Sample [35998.42636983]
# Chosen Sample [36002.23737663]
# Chosen Sample [35953.57748561]
# Chosen Sample [36061.68380539]
# Chosen Sample [36028.11937753]
# Chosen Sample [35913.71938127]
# Chosen Sample [36129.09655961]
# Chosen Sample [35959.53420413]
# Chosen Sample [35909.83853313]
# Chosen Sample [36028.39404142]
# Chosen Sample [36058.9185979]
# Chosen Sample [35969.90066164]
# Chosen Sample [36022.78300125]
# Chosen Sample [35942.14068966]
# Chosen Sample [36089.53209772]
# Chosen Sample [36034.73272285]
# Chosen Sample [35978.88418569]
# Chosen Sample [36042.28609507]
# Chosen Sample [36118.02292765]
# Chosen Sample [35996.40503574]
# Chosen Sample [36004.48924938]
# Chosen Sample [35919.26993384]
# Chosen Sample [36001.45333708]
# Chosen Sample [36078.61185158]
# Chosen Sample [35856.82253857]
# Chosen Sample [35938.79456231]
# Chosen Sample [36128.89759611]
# Chosen Sample [35973.83569499]
# Chosen Sample [35942.54382201]
# Chosen Sample [35959.50614233]
# Chosen Sample [36007.71222913]
# Chosen Sample [35928.88010558]
# Chosen Sample [35875.74710053]
# Chosen Sample [35987.80969957]
# Chosen Sample [35955.77587779]
# Chosen Sample [35926.77236257]
# Chosen Sample [35990.13412264]
# Chosen Sample [35959.26410824]
# Chosen Sample [35949.12067627]
# Chosen Sample [36076.30299837]
# Chosen Sample [36053.30741539]
# Chosen Sample [35923.08062952]
# Chosen Sample [35953.77118847]
# Chosen Sample [36075.78753941]
# Chosen Sample [36065.43112398]
# Chosen Sample [36015.45997845]
# Chosen Sample [35973.26603522]
# Chosen Sample [36045.45453675]
# Chosen Sample [36053.29429099]
# Chosen Sample [35893.89779414]
# Chosen Sample [35962.82462703]
# Chosen Sample [35905.67500291]
# Chosen Sample [36012.68912385]
# Chosen Sample [35928.58959158]
# Chosen Sample [36015.58071728]
# Chosen Sample [36037.9211396]
# Chosen Sample [36102.46826516]
# Chosen Sample [35974.26226963]
# Chosen Sample [36063.34212505]
# Chosen Sample [35969.10579795]
# Chosen Sample [36083.77720005]
# Chosen Sample [35952.74094122]
# Chosen Sample [35995.87665181]
# Chosen Sample [36086.17119112]
# Chosen Sample [36020.42375196]
# Chosen Sample [35999.69780478]
# Chosen Sample [36001.261332]
# Chosen Sample [36003.40278851]
# Chosen Sample [35996.41171855]
# Chosen Sample [36074.24765617]
# Chosen Sample [36004.39807175]
# Chosen Sample [35996.4503679]
# Chosen Sample [35995.93443069]
# Chosen Sample [36010.88431031]
# Chosen Sample [36067.10751029]
# Chosen Sample [35986.15179861]
# Chosen Sample [36008.5739183]
# Chosen Sample [36025.35110964]
# Chosen Sample [35945.6559506]
# Chosen Sample [35990.75538298]
# Chosen Sample [35985.16182345]
# Chosen Sample [36003.0996724]
# Chosen Sample [36041.67775731]
# Chosen Sample [35950.60455964]
# Chosen Sample [35993.09971981]
# Chosen Sample [36030.92700115]
# Chosen Sample [36020.03107136]
# Chosen Sample [36104.69416418]
# Chosen Sample [36120.64526052]
# Chosen Sample [36101.89733103]
# Chosen Sample [35921.98703501]
# Chosen Sample [35967.06308518]
# Chosen Sample [36117.35011021]
# Chosen Sample [36051.00044947]
# Chosen Sample [35947.85371201]
# Chosen Sample [36013.05244735]
# Chosen Sample [36000.29139092]
# Chosen Sample [36057.29799019]
# Chosen Sample [36051.93543145]
# Chosen Sample [36029.22240985]
# Chosen Sample [36045.70744214]
# Chosen Sample [36006.00093243]
# Chosen Sample [35980.33515375]
# Chosen Sample [36034.94097391]
# Chosen Sample [36055.37513793]
# Chosen Sample [36004.95450918]
# Chosen Sample [36142.40400935]
# Chosen Sample [36057.9099893]
# Chosen Sample [35980.10424114]
# Chosen Sample [35981.22607932]
# Chosen Sample [36029.36136429]
# Chosen Sample [35910.84464887]
# Chosen Sample [35942.7339465]
# Chosen Sample [36096.26855608]
# Chosen Sample [36007.72787849]
# Chosen Sample [36047.9275833]
# Chosen Sample [35994.58310183]
# Chosen Sample [36025.59711323]
# Chosen Sample [35991.52645679]
# Chosen Sample [35977.66133412]
# Chosen Sample [35999.70798402]
# Chosen Sample [35939.77391779]
# Chosen Sample [36044.99283232]
# Chosen Sample [36007.63309073]
# Chosen Sample [35985.57328924]
# Chosen Sample [35977.50822236]
# Chosen Sample [36068.14706112]
# Chosen Sample [35957.5122419]
# Chosen Sample [36033.74210418]
# Chosen Sample [35869.27277845]
# Chosen Sample [35978.98819711]
# Chosen Sample [35985.13038216]
# Chosen Sample [35953.15326479]
# Chosen Sample [36015.84687514]
# Chosen Sample [35964.46757406]
# Chosen Sample [35965.59820254]
# Chosen Sample [35973.13861961]
# Chosen Sample [36006.00093243]
# Chosen Sample [35943.61417026]
# Chosen Sample [35997.13575613]
# Chosen Sample [36082.12049892]
# Chosen Sample [35994.37768742]
# Chosen Sample [35908.2847437]
# Chosen Sample [35946.66615709]
# Chosen Sample [35981.56705104]
# Chosen Sample [35970.33688074]
# Chosen Sample [36001.51596607]
# Chosen Sample [35941.17781322]
# Chosen Sample [36016.00881995]
# Chosen Sample [35938.79456231]
# Chosen Sample [35977.9508106]
# Chosen Sample [35965.39960907]
# Chosen Sample [36101.26895679]
# Chosen Sample [36025.04009199]
# Chosen Sample [35906.80013467]
# Chosen Sample [36021.87648875]
# Chosen Sample [35925.5367701]
# Chosen Sample [36036.13859027]
# Chosen Sample [35936.7609871]
# Chosen Sample [35984.63416827]
# Chosen Sample [35909.97916584]
# Chosen Sample [36076.12484211]
# Chosen Sample [36004.37333023]
# Chosen Sample [36045.00172872]
# Chosen Sample [36065.94965034]
# Chosen Sample [36040.55515967]
# Chosen Sample [35945.15572955]
# Chosen Sample [35924.94661906]
# Chosen Sample [35991.11941748]
# Chosen Sample [36027.03028859]
# Chosen Sample [35932.45762305]
# Chosen Sample [35996.88259595]
# Chosen Sample [36021.05274624]
# Chosen Sample [36004.1209764]
# Chosen Sample [36031.10635307]
# Chosen Sample [35999.99943186]
# Chosen Sample [36061.06942162]
# Chosen Sample [35989.00927411]
# Chosen Sample [36128.91485894]
# Chosen Sample [35882.39996603]
# Chosen Sample [35926.68175021]
# Chosen Sample [35997.41292413]
# Chosen Sample [36018.04579238]
# Chosen Sample [35971.6465482]
# Chosen Sample [36030.08709784]
# Chosen Sample [36044.99413785]
# Chosen Sample [35992.49312749]
# Chosen Sample [35982.38994327]
# Chosen Sample [35957.51894616]
# Chosen Sample [36029.22240985]
# Chosen Sample [36038.78945154]
# Chosen Sample [35985.30502718]
# Chosen Sample [35989.75181239]
# Chosen Sample [36033.27586202]
# Chosen Sample [36003.0128133]
# Chosen Sample [36052.537694]
# Chosen Sample [35967.81067771]
# Chosen Sample [35992.05286662]
# Chosen Sample [35991.79988943]
# Chosen Sample [36027.48605117]
# Chosen Sample [35986.4031555]
# Chosen Sample [35944.21886157]
# Chosen Sample [35986.68275605]
# Chosen Sample [36082.65236372]
# Chosen Sample [35966.49977963]
# Chosen Sample [36019.17285948]
# Chosen Sample [36022.75896216]
# Chosen Sample [36063.72078363]
# Chosen Sample [35969.07443762]
# Chosen Sample [35906.94596819]
# Chosen Sample [35982.59600911]
# Chosen Sample [35958.59302379]
# Chosen Sample [36034.68284711]
# Chosen Sample [36008.05539612]
# Chosen Sample [36063.76244714]
# Chosen Sample [35959.82112929]
# Chosen Sample [35946.46996721]
# Chosen Sample [35940.35992749]
# Chosen Sample [36077.82946989]
# Chosen Sample [36002.28875356]
# Chosen Sample [35959.26463145]
# Chosen Sample [36093.65981122]
# Chosen Sample [35995.91799224]
# Chosen Sample [36047.0890935]
# Chosen Sample [36042.4570916]
# Chosen Sample [35941.1213152]
# Chosen Sample [36116.86552066]
# Chosen Sample [35922.15412786]
# Chosen Sample [35979.64078223]
# Chosen Sample [36013.37006049]
# Chosen Sample [35982.55676523]
# Chosen Sample [35915.27043862]
# Chosen Sample [35965.20168074]
# Chosen Sample [36031.00336592]
# Chosen Sample [36031.97309748]
# Chosen Sample [36082.35039268]
# Chosen Sample [35940.79259524]
# Chosen Sample [36011.4320557]
# Chosen Sample [36027.80929468]
# Chosen Sample [35945.09447147]
# Chosen Sample [36076.14340725]
# Chosen Sample [36032.73820823]
# Chosen Sample [36045.8447354]
# Chosen Sample [35921.78601396]
# Chosen Sample [36029.69506587]
# Chosen Sample [35932.85183097]
# Chosen Sample [35972.65518778]
# Chosen Sample [35970.99278316]
# Chosen Sample [35998.40069644]
# Chosen Sample [36029.88719623]
# Chosen Sample [36010.59677267]
# Chosen Sample [35958.01207883]
# Chosen Sample [36053.30231883]
# ...
# Chosen Sample [36057.84505955]
# Chosen Sample [36003.53116171]
# Chosen Sample [35905.72903034]
# Chosen Sample [35970.36648796]
# Chosen Sample [36017.60733983]
# Chosen Sample [36098.74162011]
# Chosen Sample [36012.13474356]
# Chosen Sample [36134.57017131]
# Chosen Sample [35981.14492795]
# Chosen Sample [35985.56893485]
# Chosen Sample [35884.42194961]
# Chosen Sample [36053.54429256]
# Chosen Sample [35923.9823163]
# Chosen Sample [35986.4031555]
# Chosen Sample [35965.34450153]
# Chosen Sample [36027.125948]
# Chosen Sample [36032.25247517]
# Chosen Sample [36029.33817208]
# Chosen Sample [36144.40661264]
# Chosen Sample [35904.75069399]
# Chosen Sample [35978.41981104]
# Chosen Sample [36006.12736402]
# Chosen Sample [35996.99146745]
# Chosen Sample [36102.46826516]
# Chosen Sample [36011.71437309]
# Chosen Sample [36078.79492532]
# Chosen Sample [36012.89395143]
# Chosen Sample [36066.94981772]
# Chosen Sample [36045.49575484]
# Chosen Sample [36042.95285462]
# Chosen Sample [35906.37886521]
# Chosen Sample [35952.57106342]
# Chosen Sample [36111.45304543]
# Chosen Sample [35970.02936012]
# Chosen Sample [36029.09921408]
# Chosen Sample [36038.89482492]
# Chosen Sample [35968.97716661]
# Chosen Sample [36062.90616827]
# Chosen Sample [36046.24385658]
# Chosen Sample [35895.78767011]
# Chosen Sample [35925.94235876]
# Chosen Sample [36045.85808921]
# Chosen Sample [36037.54009157]
# Chosen Sample [36017.13341987]
# Chosen Sample [36029.16806895]
# Chosen Sample [35969.19574662]
# Chosen Sample [36058.80660181]
# Chosen Sample [35982.07405921]
# Chosen Sample [35944.68844028]
# Chosen Sample [36078.86478997]
# Chosen Sample [35948.71886156]
# Chosen Sample [35919.75724287]
# Chosen Sample [35993.43142032]
# Chosen Sample [36079.4825925]
# Chosen Sample [35941.25880059]
# Chosen Sample [35959.99982632]
# Chosen Sample [35955.62643584]
# Chosen Sample [36037.1032062]
# Chosen Sample [36005.15297344]
# Chosen Sample [35945.3056079]
# Chosen Sample [36054.21163652]
# Chosen Sample [36005.74504228]
# Chosen Sample [35997.41292413]
# Chosen Sample [35947.63497007]
# Chosen Sample [35976.50450871]
# Chosen Sample [36067.8874334]
# Chosen Sample [35977.63288553]
# Chosen Sample [36011.04074001]
# Chosen Sample [36008.687567]
# Chosen Sample [36035.89938511]
# Chosen Sample [36075.8038632]
# Chosen Sample [35952.52892337]
# Chosen Sample [35929.0544089]
# Chosen Sample [36011.23300477]
# Chosen Sample [36067.18977543]
# Chosen Sample [35958.5344046]
# Chosen Sample [35940.68529254]
# Chosen Sample [35986.8805576]
# Chosen Sample [36069.74781726]
# Chosen Sample [35976.33731403]
# Chosen Sample [35979.0856399]
# Chosen Sample [35997.55651976]
# Chosen Sample [35985.33839313]
# Chosen Sample [35974.87447578]
# Chosen Sample [35992.38993999]
# Chosen Sample [36019.31962508]
# Chosen Sample [36074.40712538]
# Chosen Sample [35986.19150059]
# Chosen Sample [36034.73272285]
# Chosen Sample [36025.77028312]
# Chosen Sample [36019.00585467]
# Chosen Sample [35950.29367036]
# Chosen Sample [36063.89576107]
# Chosen Sample [35954.72964892]
# Chosen Sample [35985.75416592]
# Chosen Sample [35982.30579652]
# Chosen Sample [35983.27816864]
# Chosen Sample [36099.89886324]
# Chosen Sample [35954.72964892]
# Chosen Sample [36006.24426046]
# Chosen Sample [36011.04074001]
# Chosen Sample [35966.786406]
# Chosen Sample [36068.80969819]
# Chosen Sample [36034.72481079]
# Chosen Sample [35956.12925305]
# Chosen Sample [36007.49238097]
# Chosen Sample [36015.38296217]
# Chosen Sample [35995.68445746]
# Chosen Sample [36046.07800254]
# Chosen Sample [36011.32978163]
# Chosen Sample [35940.7006515]
# Chosen Sample [35937.53364994]
# Chosen Sample [35901.28597754]
# Chosen Sample [35974.05171302]
# Chosen Sample [36020.32395019]
# Chosen Sample [36068.1016671]
# Chosen Sample [36048.08919895]
# Chosen Sample [36058.12330106]
# Chosen Sample [35876.70090042]
# Chosen Sample [36137.60320801]
# Chosen Sample [36030.49603525]
# Chosen Sample [36067.92546086]
# Chosen Sample [36073.82736055]
# Chosen Sample [36061.28124675]
# Chosen Sample [35986.8805576]
# Chosen Sample [35995.57588289]
# Chosen Sample [36067.71861925]
# Chosen Sample [35922.65133737]
# Chosen Sample [35819.16269083]
# Chosen Sample [35995.68445746]
# Chosen Sample [35964.5270845]
# Chosen Sample [35929.72995721]
# Chosen Sample [36048.34302747]
# Chosen Sample [35990.44234113]
# Chosen Sample [35990.5662437]
# Chosen Sample [35855.38573543]
# Chosen Sample [35957.90504438]
# Chosen Sample [36048.48683581]
# Chosen Sample [35969.28210447]
# Chosen Sample [35970.42847633]
# Chosen Sample [36023.61238262]
# Chosen Sample [35924.28632679]
# Chosen Sample [36050.5351293]
# Chosen Sample [35965.57563616]
# Chosen Sample [36079.21709286]
# Chosen Sample [35987.23247004]
# Chosen Sample [36088.10806616]
# Chosen Sample [35949.03983833]
# Chosen Sample [36013.93542301]
# Chosen Sample [35991.83193407]
# Chosen Sample [36036.89692889]
# Chosen Sample [36060.68632476]
# Chosen Sample [35921.80095893]
# Chosen Sample [36002.36770488]
# Chosen Sample [35964.41595669]
# Chosen Sample [35975.31633494]
# Chosen Sample [35916.90290804]
# Chosen Sample [36054.74677669]
# Chosen Sample [36099.15053731]
# Chosen Sample [36015.76608636]
# Chosen Sample [35959.12336893]
# Chosen Sample [35938.4356252]
# Chosen Sample [35964.14891838]
# Chosen Sample [35891.551922]
# Chosen Sample [36018.94755982]
# Chosen Sample [36010.05521286]
# Chosen Sample [36001.57827037]
# Chosen Sample [35967.81067771]
# Chosen Sample [35964.9854242]
# Chosen Sample [35951.59255537]
# Chosen Sample [35954.37861688]
# Chosen Sample [35960.79982322]
# Chosen Sample [35984.16192604]
# Chosen Sample [35997.76495401]
# Chosen Sample [35920.88823241]
# Chosen Sample [35971.40722142]
# Chosen Sample [35993.84112078]
# Chosen Sample [35957.90504438]
# Chosen Sample [36007.63765575]
# Chosen Sample [36039.6144881]
# Chosen Sample [35986.03364697]
# Chosen Sample [36037.22238645]
# Chosen Sample [36119.35834729]
# Chosen Sample [36015.11106976]
# Chosen Sample [35902.78049617]
# Chosen Sample [35985.94598066]
# Chosen Sample [36028.85235393]
# Chosen Sample [35951.23125947]
# Chosen Sample [36023.21388578]
# Chosen Sample [36031.3083303]
# Chosen Sample [36040.44743113]
# Chosen Sample [36125.46517063]
# Chosen Sample [35903.33846783]
# Chosen Sample [36035.08398715]
# Chosen Sample [36005.74696283]
# Chosen Sample [36100.26858125]
# Chosen Sample [36071.085993]
# Chosen Sample [35978.59711764]
# Chosen Sample [35914.31127079]
# Chosen Sample [35956.80681041]
# Chosen Sample [36047.71229716]
# Chosen Sample [35960.88920917]
# Chosen Sample [35936.85643464]
# Chosen Sample [35994.29124272]
# Chosen Sample [35968.4334188]
# Chosen Sample [36050.62762705]
# Chosen Sample [36034.62982868]
# Chosen Sample [35978.83017098]
# Chosen Sample [35944.62290749]
# Chosen Sample [36003.61076325]
# Chosen Sample [35982.53227235]
# Chosen Sample [35965.06163966]
# Chosen Sample [35938.15256831]
# Chosen Sample [36001.54737272]
# Chosen Sample [36067.593081]
# Chosen Sample [35996.22869502]
# Chosen Sample [36083.56402844]
# Chosen Sample [36025.39207551]
# Chosen Sample [35961.97848102]
# Chosen Sample [36055.5113001]
# Chosen Sample [36033.31580496]
# Chosen Sample [35965.20589878]
# Chosen Sample [36050.27665447]
# Chosen Sample [36069.51086047]
# Chosen Sample [36015.05987985]
# Chosen Sample [35973.75875753]
# Chosen Sample [35931.10269973]
# Chosen Sample [36078.33821455]
# Chosen Sample [36016.08753714]
# Chosen Sample [36033.6939044]
# Chosen Sample [36152.7491588]
# Chosen Sample [35948.21925971]
# Chosen Sample [35998.95757612]
# Chosen Sample [35994.48602065]
# Chosen Sample [36005.32113862]
# Chosen Sample [36023.41356992]
# Chosen Sample [35878.92824673]
# Chosen Sample [35967.38710599]
# Chosen Sample [35999.55479776]
# Chosen Sample [36071.58724433]
# Chosen Sample [36013.32159949]
# Chosen Sample [36021.16164287]
# Chosen Sample [35996.40503574]
# Chosen Sample [36038.90375276]
# Chosen Sample [36028.4431504]
# Chosen Sample [36050.34513995]
# Chosen Sample [36000.3483684]
# Chosen Sample [35970.33688074]
# Chosen Sample [36001.1559245]
# Chosen Sample [36016.27158953]
# Chosen Sample [36060.75598036]
# Chosen Sample [35969.20898337]
# Chosen Sample [36012.1775157]
# Chosen Sample [36008.0211972]
# Chosen Sample [36010.34589532]
# Chosen Sample [36057.9099893]
# Chosen Sample [35971.95574787]
# Chosen Sample [36070.36688664]
# Chosen Sample [35938.71908262]
# Chosen Sample [36029.19667434]
# Chosen Sample [36069.01190562]
# Chosen Sample [35957.50717162]
# Chosen Sample [36005.84938081]
# Chosen Sample [35975.42542791]
# Chosen Sample [36112.27760437]
# Chosen Sample [35944.32035537]
# Chosen Sample [36034.37777826]
# Chosen Sample [36007.12190819]
# Chosen Sample [35978.62482709]
# Chosen Sample [35943.09411076]
# Chosen Sample [35993.49456662]
# Chosen Sample [35949.08854586]
# Chosen Sample [35949.76867729]
# Chosen Sample [36058.9185979]
# Chosen Sample [35894.83521721]
# Chosen Sample [35933.0416815]
# Chosen Sample [36113.31634258]
# Chosen Sample [35990.87577109]
# Chosen Sample [35958.5344046]
# Chosen Sample [35983.00174415]
# Chosen Sample [36024.63061076]
# Chosen Sample [35989.50615467]
# Chosen Sample [35945.3056079]
# Chosen Sample [35928.67574677]
# Chosen Sample [35903.6352045]
# Chosen Sample [35971.24881961]
# Chosen Sample [35953.8835845]
# Chosen Sample [35988.46723058]
# Chosen Sample [36034.90002397]
# Chosen Sample [36019.16917193]
# Chosen Sample [35924.45598759]
# Chosen Sample [36090.11878462]
# Chosen Sample [36002.67349317]
# Chosen Sample [36013.46320765]
# Chosen Sample [36018.76492991]
# Chosen Sample [36061.29545187]
# Chosen Sample [36031.86646259]
# Chosen Sample [36061.61566029]
# Chosen Sample [36060.68632476]
# Chosen Sample [36048.2042954]
# Chosen Sample [35960.04950814]
# Chosen Sample [36062.61392178]
# Chosen Sample [35940.45894956]
# Chosen Sample [36101.38097314]
# Chosen Sample [36021.552766]
# Chosen Sample [35943.99599473]
# Chosen Sample [35990.31879724]
# Chosen Sample [36032.49471265]
# Chosen Sample [36029.11979614]
# Chosen Sample [36076.85464092]
# Chosen Sample [36046.08828726]
# Chosen Sample [35971.55855121]
# Chosen Sample [35994.16419998]
# Chosen Sample [35916.49659005]
# Chosen Sample [36007.69812155]
# Chosen Sample [36091.74656501]
# Chosen Sample [35914.04401347]
# Chosen Sample [35947.55031484]
# Chosen Sample [35945.96458889]
# Chosen Sample [35950.07495353]
# Chosen Sample [36005.62557347]
# Chosen Sample [35999.14907865]
# Chosen Sample [36030.58291599]
# Chosen Sample [35937.89540515]
# Chosen Sample [36066.61128444]
# Chosen Sample [35979.29900177]
# Chosen Sample [36002.24616667]
# Chosen Sample [35963.94272268]
# Chosen Sample [35973.65074315]
# Chosen Sample [36050.5351293]
# Chosen Sample [35943.44717539]
# Chosen Sample [35937.05707791]
# Chosen Sample [36013.39624511]
# Chosen Sample [36105.69104335]
# Chosen Sample [36076.40868458]
# Chosen Sample [36101.30050913]
# Chosen Sample [35997.72509836]
# Chosen Sample [35971.02665836]
# Chosen Sample [35980.54724748]
# Chosen Sample [36022.05478342]
# Chosen Sample [36177.75188029]
# Chosen Sample [36016.43421027]
# Chosen Sample [35992.17413811]
# Chosen Sample [35883.20249266]
# Chosen Sample [36038.02236574]
# Chosen Sample [36071.51250681]
# Chosen Sample [36122.53790496]
# Chosen Sample [36034.94869276]
# Chosen Sample [35949.33215131]
# Chosen Sample [35902.78049617]
# Chosen Sample [35955.43222218]
# Chosen Sample [35942.14068966]
# Chosen Sample [35919.04692188]
# Chosen Sample [35912.70461861]
# Chosen Sample [35936.53265056]
# Chosen Sample [35967.43056248]
# Chosen Sample [35964.10335855]
# Chosen Sample [35931.93476744]
# Chosen Sample [35974.75763018]
# Chosen Sample [36088.07546718]
# Chosen Sample [35942.7339465]
# Chosen Sample [35903.23954634]
# Chosen Sample [36017.73902921]
# Chosen Sample [35925.89293949]
# Chosen Sample [35974.80845968]
# Chosen Sample [36033.28490519]
# Chosen Sample [36154.93642309]
# Chosen Sample [36144.41462405]
# Chosen Sample [35872.55823429]
# Chosen Sample [36048.34111751]
# Chosen Sample [35987.02827115]
# Chosen Sample [35945.7128663]
# Chosen Sample [36037.18237214]
# Chosen Sample [35856.60443371]
# Chosen Sample [36036.12265608]
# Chosen Sample [36031.05373774]
# Chosen Sample [36063.63110537]
# Chosen Sample [36032.16575783]
# Chosen Sample [36072.39463135]
# Chosen Sample [35922.21149689]
# Chosen Sample [36043.23964275]
# Chosen Sample [36055.77031672]
# Chosen Sample [35892.13694101]
# Chosen Sample [35984.96542715]
# Chosen Sample [35959.80040435]
# Chosen Sample [35998.02939978]
# Chosen Sample [36021.31730209]
# Chosen Sample [36050.49742727]
# Chosen Sample [35940.86666004]
# Chosen Sample [36036.89692889]
# Chosen Sample [35977.70652409]
# Chosen Sample [35967.08300162]
# Chosen Sample [36004.72694582]
# Chosen Sample [36045.76663201]
# Chosen Sample [36041.82948858]
# Chosen Sample [35962.80526637]
# Chosen Sample [35923.66811347]
# Chosen Sample [36072.39463135]
# Chosen Sample [35994.61993992]
# Chosen Sample [35939.20034824]
# Chosen Sample [36096.46658344]
# Chosen Sample [35889.67110279]
# Chosen Sample [36036.88129855]
# Chosen Sample [36150.2960983]
# Chosen Sample [36001.72187177]
# Chosen Sample [35914.04401347]
# Chosen Sample [36076.26798172]
# Chosen Sample [35966.24973544]
# Chosen Sample [36031.67079953]
# Chosen Sample [36012.30786554]
# Chosen Sample [35941.87055189]
# Chosen Sample [36067.00983998]
# Chosen Sample [36120.31078686]
# Chosen Sample [36028.68490327]
# Chosen Sample [35969.97543389]
# Chosen Sample [36082.47919512]
# Chosen Sample [35958.01207883]
# Chosen Sample [35974.0645451]
# Chosen Sample [35994.1141796]
# Chosen Sample [35973.6775933]
# Chosen Sample [35955.88826573]
# Chosen Sample [36028.45714489]
# Chosen Sample [35946.46996721]
# Chosen Sample [35966.49977963]
# Chosen Sample [36009.35396598]
# Chosen Sample [36014.4620034]
# Chosen Sample [36042.45760827]
# Chosen Sample [35998.51614847]
# Chosen Sample [35965.1782893]
# Chosen Sample [35981.56705104]
# Chosen Sample [36089.99513217]
# Chosen Sample [36083.77720005]
# Chosen Sample [36000.64740229]
# Chosen Sample [36018.76492991]
# Chosen Sample [36062.70108252]
# Chosen Sample [35970.75975784]
# Chosen Sample [35950.44864697]
# Chosen Sample [35985.50101159]
# Chosen Sample [36070.38048129]
# Chosen Sample [35959.48246825]
# Chosen Sample [36176.96230929]
# Chosen Sample [36028.02166676]
# Chosen Sample [35940.97311104]
# Chosen Sample [36018.9758183]
# Chosen Sample [35952.73525232]
# Chosen Sample [36023.42343104]
# Chosen Sample [36001.63893763]
# Chosen Sample [36027.48605117]
# Chosen Sample [35995.79453394]
# Chosen Sample [36042.79681357]
# Chosen Sample [35915.26246746]
# Chosen Sample [35994.05784574]
# Chosen Sample [35905.00592931]
# Chosen Sample [35999.03687611]
# Chosen Sample [35963.44466855]
# Chosen Sample [36056.62501542]
# Chosen Sample [35909.25297518]
# Chosen Sample [36040.14748625]
# Chosen Sample [36071.12731628]
# Chosen Sample [36036.48327461]
# Chosen Sample [36074.91725198]
# Chosen Sample [35951.23103958]
# Chosen Sample [36020.97542923]
# Chosen Sample [36011.62070296]
# Chosen Sample [36058.58540762]
# Chosen Sample [35995.19394939]
# Chosen Sample [35964.04041034]
# Chosen Sample [36168.1064279]
# Chosen Sample [35942.95900238]
# Chosen Sample [36024.24779639]
# Chosen Sample [35941.67592597]
# Chosen Sample [35932.55632046]
# Chosen Sample [36040.15214862]
# Chosen Sample [36060.80310436]
# Chosen Sample [36038.2090895]
# Chosen Sample [35960.13813796]
# Chosen Sample [35965.52117939]
# Chosen Sample [36031.37790723]
# Chosen Sample [36069.14928892]
# Chosen Sample [35924.08067535]
# Chosen Sample [36071.55111962]
# Chosen Sample [35940.81047228]
# Chosen Sample [35980.56989644]
# Chosen Sample [36086.84311759]
# Chosen Sample [36097.40994462]
# Chosen Sample [36008.31393912]
# Chosen Sample [35959.82112929]
# Chosen Sample [36024.98946512]
# Chosen Sample [36029.63479306]
# Chosen Sample [36012.09236556]
# Chosen Sample [36038.57768336]
# Chosen Sample [36049.87547382]
# Chosen Sample [36019.06575884]
# Chosen Sample [35978.68103036]
# Chosen Sample [36105.60364018]
# Chosen Sample [36013.16326445]
# Chosen Sample [35951.83782999]
# Chosen Sample [35933.84703026]
# Chosen Sample [36083.92022262]
# Chosen Sample [35982.04800924]
# Chosen Sample [36007.77994234]
# Chosen Sample [35914.33814142]
# Chosen Sample [36011.96592463]
# Chosen Sample [35998.73119813]
# Chosen Sample [36035.46961455]
# Chosen Sample [35883.9933155]
# Chosen Sample [36062.67714023]
# Chosen Sample [35960.75803242]
# Chosen Sample [35927.78035404]
# Chosen Sample [35903.4227401]
# Chosen Sample [35972.44833505]
# Chosen Sample [36068.01453051]
# Chosen Sample [35926.23238417]
# Chosen Sample [36030.92575828]
# Chosen Sample [36040.44743113]
# Chosen Sample [36044.82991625]
# Chosen Sample [36048.94958023]
# Chosen Sample [36117.35011021]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                 scale        chosen_sample           chosen_noise  \
# 0  0.001248  [1324961.6196499104]  [36035.08398714785]   [131.77549474169942]
# 1  0.001248  [1324961.6196499104]  [36001.99186250609]    [2601.425417836973]
# 2  0.001248  [1324961.6196499104]  [36086.76985753246]  [-1727.7023329449585]
# 3  0.001248  [1324961.6196499104]  [36041.47570063522]    [141.0981566832801]
# 4  0.001248  [1324961.6196499104]  [35946.98035428757]    [431.2824782793293]
#
#                release
# 0  [36166.85948188955]
# 1  [38603.41728034306]
# 2   [34359.0675245875]
# 3   [36182.5738573185]
# 4   [36378.2628325669]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi         scale chosen_sample chosen_noise       release
# query               avg_price     avg_price    avg_price     avg_price
# 0      0.001248  1.324962e+06  36035.083987   131.775495  36166.859482
# 1      0.001248  1.324962e+06  36001.991863  2601.425418  38603.417280
# 2      0.001248  1.324962e+06  36086.769858 -1727.702333  34359.067525
# 3      0.001248  1.324962e+06  36041.475701   141.098157  36182.573857
# 4      0.001248  1.324962e+06  35946.980354   431.282478  36378.262833

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72008/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step              scale chosen_sample chosen_noise       release
# query         avg_price     avg_price    avg_price     avg_price
# mi
# 0.001248   1.324962e+06  36002.221758   -27.176156  35975.045603
# 0.015625   1.058544e+05  36002.319479    14.938458  36017.257937
# 0.031250   5.292718e+04  36003.725102    -9.800746  35993.924356
# 0.062500   2.646359e+04  36002.151130     0.461495  36002.612626
# 0.250000   6.615897e+03  36001.982567    -2.684524  35999.298043
# 1.000000   1.653974e+03  36005.649739    -2.320477  36003.329262
# 2.000000   8.269871e+02  36001.173011     1.415822  36002.588833
# 4.000000   4.134936e+02  36004.323258     1.315655  36005.638913
# 16.000000  1.033734e+02  36000.607363     0.034138  36000.641502

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['avg_price'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi               0.001248
# avg_price    36166.859482
# Name: 0, dtype: float64
# mi               0.001248
# avg_price    38603.417280
# Name: 1, dtype: float64
# mi               0.001248
# avg_price    34359.067525
# Name: 2, dtype: float64
# mi               0.001248
# avg_price    36182.573857
# Name: 3, dtype: float64
# mi               0.001248
# avg_price    36378.262833
# Name: 4, dtype: float64
# mi               0.001248
# avg_price    35987.875784
# Name: 5, dtype: float64
# mi               0.001248
# avg_price    35677.030600
# Name: 6, dtype: float64
# mi               0.001248
# avg_price    36731.157819
# Name: 7, dtype: float64
# mi               0.001248
# avg_price    38046.562584
# Name: 8, dtype: float64
# mi               0.001248
# avg_price    34923.201313
# Name: 9, dtype: float64
# mi               0.001248
# avg_price    35666.317878
# Name: 10, dtype: float64
# mi               0.001248
# avg_price    34472.041849
# Name: 11, dtype: float64
# mi               0.001248
# avg_price    35383.883499
# Name: 12, dtype: float64
# mi               0.001248
# avg_price    36434.161930
# Name: 13, dtype: float64
# mi               0.001248
# avg_price    35652.119844
# Name: 14, dtype: float64
# mi               0.001248
# avg_price    36413.967347
# Name: 15, dtype: float64
# mi               0.001248
# avg_price    38140.466439
# Name: 16, dtype: float64
# mi               0.001248
# avg_price    36142.931831
# Name: 17, dtype: float64
# mi               0.001248
# avg_price    36169.391136
# Name: 18, dtype: float64
# mi               0.001248
# avg_price    36138.638360
# Name: 19, dtype: float64
# mi               0.001248
# avg_price    37378.815490
# Name: 20, dtype: float64
# mi               0.001248
# avg_price    34791.530138
# Name: 21, dtype: float64
# mi               0.001248
# avg_price    32556.737763
# Name: 22, dtype: float64
# mi               0.001248
# avg_price    37211.427349
# Name: 23, dtype: float64
# mi               0.001248
# avg_price    35651.547696
# Name: 24, dtype: float64
# mi               0.001248
# avg_price    35777.897026
# Name: 25, dtype: float64
# mi               0.001248
# avg_price    36255.195680
# Name: 26, dtype: float64
# mi               0.001248
# avg_price    34314.230135
# Name: 27, dtype: float64
# mi               0.001248
# avg_price    37477.342359
# Name: 28, dtype: float64
# mi               0.001248
# avg_price    35816.298572
# Name: 29, dtype: float64
# mi               0.001248
# avg_price    34283.938610
# Name: 30, dtype: float64
# mi               0.001248
# avg_price    35146.182762
# Name: 31, dtype: float64
# mi               0.001248
# avg_price    33748.946902
# Name: 32, dtype: float64
# mi               0.001248
# avg_price    33939.345725
# Name: 33, dtype: float64
# mi               0.001248
# avg_price    34462.733929
# Name: 34, dtype: float64
# mi               0.001248
# avg_price    35143.318634
# Name: 35, dtype: float64
# mi               0.001248
# avg_price    35408.761271
# Name: 36, dtype: float64
# mi               0.001248
# avg_price    35277.311709
# Name: 37, dtype: float64
# mi               0.001248
# avg_price    35385.853559
# Name: 38, dtype: float64
# mi               0.001248
# avg_price    35912.424813
# Name: 39, dtype: float64
# mi               0.001248
# avg_price    36556.272335
# Name: 40, dtype: float64
# mi               0.001248
# avg_price    38286.729011
# Name: 41, dtype: float64
# mi               0.001248
# avg_price    36659.232767
# Name: 42, dtype: float64
# mi               0.001248
# avg_price    34915.524944
# Name: 43, dtype: float64
# mi               0.001248
# avg_price    36983.031221
# Name: 44, dtype: float64
# mi               0.001248
# avg_price    37382.246336
# Name: 45, dtype: float64
# mi               0.001248
# avg_price    36840.724237
# Name: 46, dtype: float64
# mi               0.001248
# avg_price    37006.666869
# Name: 47, dtype: float64
# mi               0.001248
# avg_price    35465.236345
# Name: 48, dtype: float64
# mi               0.001248
# avg_price    35756.969476
# Name: 49, dtype: float64
# mi               0.001248
# avg_price    34381.673827
# Name: 50, dtype: float64
# mi               0.001248
# avg_price    35256.632966
# Name: 51, dtype: float64
# mi               0.001248
# avg_price    37339.121501
# Name: 52, dtype: float64
# mi               0.001248
# avg_price    35484.672057
# Name: 53, dtype: float64
# mi               0.001248
# avg_price    35949.598688
# Name: 54, dtype: float64
# mi               0.001248
# avg_price    34515.520392
# Name: 55, dtype: float64
# mi               0.001248
# avg_price    36185.312512
# Name: 56, dtype: float64
# mi               0.001248
# avg_price    38007.173262
# Name: 57, dtype: float64
# mi               0.001248
# avg_price    34540.879644
# Name: 58, dtype: float64
# mi               0.001248
# avg_price    36431.279315
# Name: 59, dtype: float64
# mi               0.001248
# avg_price    35776.504202
# Name: 60, dtype: float64
# mi               0.001248
# avg_price    36498.403364
# Name: 61, dtype: float64
# mi               0.001248
# avg_price    34127.458868
# Name: 62, dtype: float64
# mi               0.001248
# avg_price    35014.120347
# Name: 63, dtype: float64
# mi               0.001248
# avg_price    36550.400687
# Name: 64, dtype: float64
# mi               0.001248
# avg_price    37180.335192
# Name: 65, dtype: float64
# mi               0.001248
# avg_price    35411.125429
# Name: 66, dtype: float64
# mi               0.001248
# avg_price    37351.631852
# Name: 67, dtype: float64
# mi               0.001248
# avg_price    36793.952729
# Name: 68, dtype: float64
# mi               0.001248
# avg_price    35381.725043
# Name: 69, dtype: float64
# mi               0.001248
# avg_price    36780.816707
# Name: 70, dtype: float64
# mi               0.001248
# avg_price    37074.540347
# Name: 71, dtype: float64
# mi               0.001248
# avg_price    36205.873087
# Name: 72, dtype: float64
# mi               0.001248
# avg_price    35941.893208
# Name: 73, dtype: float64
# mi               0.001248
# avg_price    35475.546121
# Name: 74, dtype: float64
# mi               0.001248
# avg_price    34717.759933
# Name: 75, dtype: float64
# mi               0.001248
# avg_price    37860.952657
# Name: 76, dtype: float64
# mi               0.001248
# avg_price    32533.516022
# Name: 77, dtype: float64
# mi               0.001248
# avg_price    34521.072975
# Name: 78, dtype: float64
# mi               0.001248
# avg_price    35043.500739
# Name: 79, dtype: float64
# mi               0.001248
# avg_price    37567.848493
# Name: 80, dtype: float64
# mi               0.001248
# avg_price    37348.193437
# Name: 81, dtype: float64
# mi               0.001248
# avg_price    36960.614537
# Name: 82, dtype: float64
# mi               0.001248
# avg_price    37733.472609
# Name: 83, dtype: float64
# mi               0.001248
# avg_price    35885.003476
# Name: 84, dtype: float64
# mi               0.001248
# avg_price    37870.538497
# Name: 85, dtype: float64
# mi               0.001248
# avg_price    37640.846818
# Name: 86, dtype: float64
# mi               0.001248
# avg_price    36271.943618
# Name: 87, dtype: float64
# mi               0.001248
# avg_price    34986.640819
# Name: 88, dtype: float64
# mi               0.001248
# avg_price    37603.473985
# Name: 89, dtype: float64
# mi               0.001248
# avg_price    36533.769190
# Name: 90, dtype: float64
# mi               0.001248
# avg_price    38547.309426
# Name: 91, dtype: float64
# mi               0.001248
# avg_price    37437.694011
# Name: 92, dtype: float64
# mi               0.001248
# avg_price    34674.830836
# Name: 93, dtype: float64
# mi               0.001248
# avg_price    37678.935731
# Name: 94, dtype: float64
# mi               0.001248
# avg_price    33270.326773
# Name: 95, dtype: float64
# mi               0.001248
# avg_price    35546.364078
# Name: 96, dtype: float64
# mi               0.001248
# avg_price    36942.705960
# Name: 97, dtype: float64
# mi               0.001248
# avg_price    36799.342027
# Name: 98, dtype: float64
# mi               0.001248
# avg_price    36272.642975
# Name: 99, dtype: float64
# mi               0.001248
# avg_price    36531.935848
# Name: 100, dtype: float64
# mi               0.001248
# avg_price    35744.516368
# Name: 101, dtype: float64
# mi               0.001248
# avg_price    35718.757286
# Name: 102, dtype: float64
# mi               0.001248
# avg_price    37742.552984
# Name: 103, dtype: float64
# mi               0.001248
# avg_price    37138.443817
# Name: 104, dtype: float64
# mi               0.001248
# avg_price    39319.520066
# Name: 105, dtype: float64
# mi               0.001248
# avg_price    33541.718748
# Name: 106, dtype: float64
# mi               0.001248
# avg_price    35926.592364
# Name: 107, dtype: float64
# mi               0.001248
# avg_price    34255.691147
# Name: 108, dtype: float64
# mi               0.001248
# avg_price    33646.711763
# Name: 109, dtype: float64
# mi               0.001248
# avg_price    36951.325257
# Name: 110, dtype: float64
# mi               0.001248
# avg_price    36009.287137
# Name: 111, dtype: float64
# mi               0.001248
# avg_price    34630.436997
# Name: 112, dtype: float64
# mi               0.001248
# avg_price    35277.882693
# Name: 113, dtype: float64
# mi               0.001248
# avg_price    37889.510658
# Name: 114, dtype: float64
# mi               0.001248
# avg_price    34115.788518
# Name: 115, dtype: float64
# mi               0.001248
# avg_price    37065.845469
# Name: 116, dtype: float64
# mi               0.001248
# avg_price    36276.798436
# Name: 117, dtype: float64
# mi               0.001248
# avg_price    36291.316918
# Name: 118, dtype: float64
# mi               0.001248
# avg_price    37486.059693
# Name: 119, dtype: float64
# mi               0.001248
# avg_price    37426.896973
# Name: 120, dtype: float64
# mi               0.001248
# avg_price    35821.834156
# Name: 121, dtype: float64
# mi               0.001248
# avg_price    34293.752774
# Name: 122, dtype: float64
# mi               0.001248
# avg_price    36135.484403
# Name: 123, dtype: float64
# mi               0.001248
# avg_price    36622.272119
# Name: 124, dtype: float64
# mi               0.001248
# avg_price    37490.780836
# Name: 125, dtype: float64
# mi               0.001248
# avg_price    34158.314299
# Name: 126, dtype: float64
# mi               0.001248
# avg_price    37591.542344
# Name: 127, dtype: float64
# mi               0.001248
# avg_price    34951.312851
# Name: 128, dtype: float64
# mi               0.001248
# avg_price    36584.309417
# Name: 129, dtype: float64
# mi               0.001248
# avg_price    36204.847671
# Name: 130, dtype: float64
# mi               0.001248
# avg_price    36840.547251
# Name: 131, dtype: float64
# mi               0.001248
# avg_price    33367.171758
# Name: 132, dtype: float64
# mi               0.001248
# avg_price    36852.625207
# Name: 133, dtype: float64
# mi               0.001248
# avg_price    35838.246187
# Name: 134, dtype: float64
# mi               0.001248
# avg_price    35547.458929
# Name: 135, dtype: float64
# mi               0.001248
# avg_price    35185.028952
# Name: 136, dtype: float64
# mi               0.001248
# avg_price    36105.996644
# Name: 137, dtype: float64
# mi               0.001248
# avg_price    34016.611761
# Name: 138, dtype: float64
# mi               0.001248
# avg_price    34686.982638
# Name: 139, dtype: float64
# mi               0.001248
# avg_price    35566.951799
# Name: 140, dtype: float64
# mi               0.001248
# avg_price    35630.687479
# Name: 141, dtype: float64
# mi               0.001248
# avg_price    35622.430697
# Name: 142, dtype: float64
# mi               0.001248
# avg_price    34000.009821
# Name: 143, dtype: float64
# mi               0.001248
# avg_price    36351.876435
# Name: 144, dtype: float64
# mi               0.001248
# avg_price    37513.889237
# Name: 145, dtype: float64
# mi               0.001248
# avg_price    36835.432954
# Name: 146, dtype: float64
# mi               0.001248
# avg_price    35170.316191
# Name: 147, dtype: float64
# mi               0.001248
# avg_price    34625.892352
# Name: 148, dtype: float64
# mi               0.001248
# avg_price    35634.866728
# Name: 149, dtype: float64
# mi               0.001248
# avg_price    37240.825073
# Name: 150, dtype: float64
# mi               0.001248
# avg_price    36282.325903
# Name: 151, dtype: float64
# mi               0.001248
# avg_price    36283.077857
# Name: 152, dtype: float64
# mi               0.001248
# avg_price    35586.874680
# Name: 153, dtype: float64
# mi               0.001248
# avg_price    35834.153226
# Name: 154, dtype: float64
# mi               0.001248
# avg_price    37527.478036
# Name: 155, dtype: float64
# mi               0.001248
# avg_price    35581.006772
# Name: 156, dtype: float64
# mi               0.001248
# avg_price    35111.235863
# Name: 157, dtype: float64
# mi               0.001248
# avg_price    37071.408202
# Name: 158, dtype: float64
# mi               0.001248
# avg_price    35748.754872
# Name: 159, dtype: float64
# mi               0.001248
# avg_price    34336.636056
# Name: 160, dtype: float64
# mi               0.001248
# avg_price    34710.503428
# Name: 161, dtype: float64
# mi               0.001248
# avg_price    36079.725741
# Name: 162, dtype: float64
# mi               0.001248
# avg_price    34063.328916
# Name: 163, dtype: float64
# mi               0.001248
# avg_price    35749.853925
# Name: 164, dtype: float64
# mi               0.001248
# avg_price    37838.992041
# Name: 165, dtype: float64
# mi               0.001248
# avg_price    34987.897201
# Name: 166, dtype: float64
# mi               0.001248
# avg_price    39955.616142
# Name: 167, dtype: float64
# mi               0.001248
# avg_price    36366.644570
# Name: 168, dtype: float64
# mi               0.001248
# avg_price    35014.709022
# Name: 169, dtype: float64
# mi               0.001248
# avg_price    35440.315777
# Name: 170, dtype: float64
# mi               0.001248
# avg_price    36524.820739
# Name: 171, dtype: float64
# mi               0.001248
# avg_price    34974.577345
# Name: 172, dtype: float64
# mi               0.001248
# avg_price    35419.497380
# Name: 173, dtype: float64
# mi               0.001248
# avg_price    35948.081194
# Name: 174, dtype: float64
# mi               0.001248
# avg_price    35906.931133
# Name: 175, dtype: float64
# mi               0.001248
# avg_price    35560.091673
# Name: 176, dtype: float64
# mi               0.001248
# avg_price    37432.690954
# Name: 177, dtype: float64
# mi               0.001248
# avg_price    35018.280832
# Name: 178, dtype: float64
# mi               0.001248
# avg_price    36066.739633
# Name: 179, dtype: float64
# mi               0.001248
# avg_price    34336.047014
# Name: 180, dtype: float64
# mi               0.001248
# avg_price    36490.857947
# Name: 181, dtype: float64
# mi               0.001248
# avg_price    35736.862229
# Name: 182, dtype: float64
# mi               0.001248
# avg_price    38037.842495
# Name: 183, dtype: float64
# mi               0.001248
# avg_price    38641.084776
# Name: 184, dtype: float64
# mi               0.001248
# avg_price    36494.109210
# Name: 185, dtype: float64
# mi               0.001248
# avg_price    37669.595387
# Name: 186, dtype: float64
# mi               0.001248
# avg_price    34187.269852
# Name: 187, dtype: float64
# mi               0.001248
# avg_price    37337.062603
# Name: 188, dtype: float64
# mi               0.001248
# avg_price    38978.922751
# Name: 189, dtype: float64
# mi               0.001248
# avg_price    34748.173077
# Name: 190, dtype: float64
# mi               0.001248
# avg_price    35550.255231
# Name: 191, dtype: float64
# mi               0.001248
# avg_price    35559.335636
# Name: 192, dtype: float64
# mi               0.001248
# avg_price    33563.458456
# Name: 193, dtype: float64
# mi               0.001248
# avg_price    37222.546633
# Name: 194, dtype: float64
# mi               0.001248
# avg_price    35753.159660
# Name: 195, dtype: float64
# mi               0.001248
# avg_price    36068.286222
# Name: 196, dtype: float64
# mi               0.001248
# avg_price    35531.400190
# Name: 197, dtype: float64
# mi               0.001248
# avg_price    37169.927434
# Name: 198, dtype: float64
# mi               0.001248
# avg_price    34519.706520
# Name: 199, dtype: float64
# mi               0.001248
# avg_price    37209.499416
# Name: 200, dtype: float64
# mi               0.001248
# avg_price    36479.691169
# Name: 201, dtype: float64
# mi               0.001248
# avg_price    36036.463809
# Name: 202, dtype: float64
# mi               0.001248
# avg_price    37101.186979
# Name: 203, dtype: float64
# mi               0.001248
# avg_price    36022.248128
# Name: 204, dtype: float64
# mi               0.001248
# avg_price    37333.259473
# Name: 205, dtype: float64
# mi               0.001248
# avg_price    35977.837874
# Name: 206, dtype: float64
# mi               0.001248
# avg_price    36265.657612
# Name: 207, dtype: float64
# mi               0.001248
# avg_price    36799.184118
# Name: 208, dtype: float64
# mi               0.001248
# avg_price    35046.128798
# Name: 209, dtype: float64
# mi               0.001248
# avg_price    37798.347291
# Name: 210, dtype: float64
# mi               0.001248
# avg_price    35925.791073
# Name: 211, dtype: float64
# mi               0.001248
# avg_price    35074.752952
# Name: 212, dtype: float64
# mi               0.001248
# avg_price    37442.734896
# Name: 213, dtype: float64
# mi               0.001248
# avg_price    34276.205878
# Name: 214, dtype: float64
# mi               0.001248
# avg_price    36183.974467
# Name: 215, dtype: float64
# mi               0.001248
# avg_price    35647.673340
# Name: 216, dtype: float64
# mi               0.001248
# avg_price    36259.629994
# Name: 217, dtype: float64
# mi               0.001248
# avg_price    34534.918362
# Name: 218, dtype: float64
# mi               0.001248
# avg_price    34239.060141
# Name: 219, dtype: float64
# mi               0.001248
# avg_price    37103.760366
# Name: 220, dtype: float64
# mi               0.001248
# avg_price    35284.657209
# Name: 221, dtype: float64
# mi               0.001248
# avg_price    36449.114288
# Name: 222, dtype: float64
# mi               0.001248
# avg_price    34646.692335
# Name: 223, dtype: float64
# mi               0.001248
# avg_price    34549.529400
# Name: 224, dtype: float64
# mi               0.001248
# avg_price    35730.805175
# Name: 225, dtype: float64
# mi               0.001248
# avg_price    36510.699309
# Name: 226, dtype: float64
# mi               0.001248
# avg_price    36063.836145
# Name: 227, dtype: float64
# mi               0.001248
# avg_price    35748.518323
# Name: 228, dtype: float64
# mi               0.001248
# avg_price    36154.657343
# Name: 229, dtype: float64
# mi               0.001248
# avg_price    35476.196768
# Name: 230, dtype: float64
# mi               0.001248
# avg_price    35671.256882
# Name: 231, dtype: float64
# mi               0.001248
# avg_price    35766.385846
# Name: 232, dtype: float64
# mi               0.001248
# avg_price    37608.265249
# Name: 233, dtype: float64
# mi               0.001248
# avg_price    35533.924906
# Name: 234, dtype: float64
# mi               0.001248
# avg_price    38680.885476
# Name: 235, dtype: float64
# mi               0.001248
# avg_price    33517.274497
# Name: 236, dtype: float64
# mi               0.001248
# avg_price    35469.657959
# Name: 237, dtype: float64
# mi               0.001248
# avg_price    35142.947434
# Name: 238, dtype: float64
# mi               0.001248
# avg_price    35562.755728
# Name: 239, dtype: float64
# mi               0.001248
# avg_price    35740.423579
# Name: 240, dtype: float64
# mi               0.001248
# avg_price    36215.670031
# Name: 241, dtype: float64
# mi               0.001248
# avg_price    35761.323528
# Name: 242, dtype: float64
# mi               0.001248
# avg_price    34068.823707
# Name: 243, dtype: float64
# mi               0.001248
# avg_price    36336.349797
# Name: 244, dtype: float64
# mi               0.001248
# avg_price    37001.593673
# Name: 245, dtype: float64
# mi               0.001248
# avg_price    35560.933282
# Name: 246, dtype: float64
# mi               0.001248
# avg_price    37053.942481
# Name: 247, dtype: float64
# mi               0.001248
# avg_price    37333.929863
# Name: 248, dtype: float64
# mi               0.001248
# avg_price    36891.035238
# Name: 249, dtype: float64
# mi               0.001248
# avg_price    36061.542440
# Name: 250, dtype: float64
# mi               0.001248
# avg_price    34814.217822
# Name: 251, dtype: float64
# mi               0.001248
# avg_price    35646.880918
# Name: 252, dtype: float64
# mi               0.001248
# avg_price    34661.321428
# Name: 253, dtype: float64
# mi               0.001248
# avg_price    34962.913978
# Name: 254, dtype: float64
# mi               0.001248
# avg_price    33779.183970
# Name: 255, dtype: float64
# mi               0.001248
# avg_price    35690.895027
# Name: 256, dtype: float64
# mi               0.001248
# avg_price    37364.988931
# Name: 257, dtype: float64
# mi               0.001248
# avg_price    36555.803779
# Name: 258, dtype: float64
# mi               0.001248
# avg_price    35481.109636
# Name: 259, dtype: float64
# mi               0.001248
# avg_price    36924.028185
# Name: 260, dtype: float64
# mi               0.001248
# avg_price    36384.779311
# Name: 261, dtype: float64
# mi               0.001248
# avg_price    38273.197411
# Name: 262, dtype: float64
# mi               0.001248
# avg_price    34174.564238
# Name: 263, dtype: float64
# mi               0.001248
# avg_price    37243.800744
# Name: 264, dtype: float64
# mi               0.001248
# avg_price    34656.731726
# Name: 265, dtype: float64
# mi               0.001248
# avg_price    34302.131699
# Name: 266, dtype: float64
# mi               0.001248
# avg_price    35170.338411
# Name: 267, dtype: float64
# mi               0.001248
# avg_price    36092.340397
# Name: 268, dtype: float64
# mi               0.001248
# avg_price    36397.079966
# Name: 269, dtype: float64
# mi               0.001248
# avg_price    37471.332171
# Name: 270, dtype: float64
# mi               0.001248
# avg_price    35155.484058
# Name: 271, dtype: float64
# mi               0.001248
# avg_price    36823.878571
# Name: 272, dtype: float64
# mi               0.001248
# avg_price    35080.726371
# Name: 273, dtype: float64
# mi               0.001248
# avg_price    37321.185293
# Name: 274, dtype: float64
# mi               0.001248
# avg_price    35960.196327
# Name: 275, dtype: float64
# mi               0.001248
# avg_price    35974.345456
# Name: 276, dtype: float64
# mi               0.001248
# avg_price    36567.985813
# Name: 277, dtype: float64
# mi               0.001248
# avg_price    34361.622342
# Name: 278, dtype: float64
# mi               0.001248
# avg_price    36123.531087
# Name: 279, dtype: float64
# mi               0.001248
# avg_price    37817.373833
# Name: 280, dtype: float64
# mi               0.001248
# avg_price    36963.902676
# Name: 281, dtype: float64
# mi               0.001248
# avg_price    36084.675616
# Name: 282, dtype: float64
# mi               0.001248
# avg_price    34731.042648
# Name: 283, dtype: float64
# mi               0.001248
# avg_price    36431.498811
# Name: 284, dtype: float64
# mi               0.001248
# avg_price    35974.183390
# Name: 285, dtype: float64
# mi               0.001248
# avg_price    35589.971351
# Name: 286, dtype: float64
# mi               0.001248
# avg_price    35868.490070
# Name: 287, dtype: float64
# mi               0.001248
# avg_price    35175.265400
# Name: 288, dtype: float64
# mi               0.001248
# avg_price    35542.024675
# Name: 289, dtype: float64
# mi               0.001248
# avg_price    37633.278087
# Name: 290, dtype: float64
# mi               0.001248
# avg_price    35886.026894
# Name: 291, dtype: float64
# mi               0.001248
# avg_price    36141.302395
# Name: 292, dtype: float64
# mi               0.001248
# avg_price    36014.233202
# Name: 293, dtype: float64
# mi               0.001248
# avg_price    37317.091171
# Name: 294, dtype: float64
# mi               0.001248
# avg_price    35099.774995
# Name: 295, dtype: float64
# mi               0.001248
# avg_price    36067.073611
# Name: 296, dtype: float64
# mi               0.001248
# avg_price    36287.227114
# Name: 297, dtype: float64
# mi               0.001248
# avg_price    35165.987277
# Name: 298, dtype: float64
# mi               0.001248
# avg_price    34797.465607
# Name: 299, dtype: float64
# mi               0.001248
# avg_price    37723.940531
# Name: 300, dtype: float64
# mi               0.001248
# avg_price    35264.757324
# Name: 301, dtype: float64
# mi               0.001248
# avg_price    34640.646526
# Name: 302, dtype: float64
# mi               0.001248
# avg_price    35219.427029
# Name: 303, dtype: float64
# mi               0.001248
# avg_price    36137.190374
# Name: 304, dtype: float64
# mi               0.001248
# avg_price    38632.952795
# Name: 305, dtype: float64
# mi               0.001248
# avg_price    36873.301497
# Name: 306, dtype: float64
# mi               0.001248
# avg_price    37741.510008
# Name: 307, dtype: float64
# mi               0.001248
# avg_price    36614.902283
# Name: 308, dtype: float64
# mi               0.001248
# avg_price    35407.293281
# Name: 309, dtype: float64
# mi               0.001248
# avg_price    36269.983508
# Name: 310, dtype: float64
# mi               0.001248
# avg_price    36910.662861
# Name: 311, dtype: float64
# mi               0.001248
# avg_price    34565.192869
# Name: 312, dtype: float64
# mi               0.001248
# avg_price    36360.573947
# Name: 313, dtype: float64
# mi               0.001248
# avg_price    36217.472749
# Name: 314, dtype: float64
# mi               0.001248
# avg_price    34670.706520
# Name: 315, dtype: float64
# mi               0.001248
# avg_price    36368.048329
# Name: 316, dtype: float64
# mi               0.001248
# avg_price    36675.625561
# Name: 317, dtype: float64
# mi               0.001248
# avg_price    36262.457819
# Name: 318, dtype: float64
# mi               0.001248
# avg_price    34221.071670
# Name: 319, dtype: float64
# mi               0.001248
# avg_price    34415.492385
# Name: 320, dtype: float64
# mi               0.001248
# avg_price    35638.645655
# Name: 321, dtype: float64
# mi               0.001248
# avg_price    37471.245852
# Name: 322, dtype: float64
# mi               0.001248
# avg_price    36450.514105
# Name: 323, dtype: float64
# mi               0.001248
# avg_price    36435.176027
# Name: 324, dtype: float64
# mi               0.001248
# avg_price    35018.857791
# Name: 325, dtype: float64
# mi               0.001248
# avg_price    35591.277446
# Name: 326, dtype: float64
# mi               0.001248
# avg_price    36365.205808
# Name: 327, dtype: float64
# mi               0.001248
# avg_price    34682.266791
# Name: 328, dtype: float64
# mi               0.001248
# avg_price    36365.196722
# Name: 329, dtype: float64
# mi               0.001248
# avg_price    36730.604089
# Name: 330, dtype: float64
# mi               0.001248
# avg_price    35894.630116
# Name: 331, dtype: float64
# mi               0.001248
# avg_price    36386.050184
# Name: 332, dtype: float64
# mi               0.001248
# avg_price    35964.340662
# Name: 333, dtype: float64
# mi               0.001248
# avg_price    33895.040930
# Name: 334, dtype: float64
# mi               0.001248
# avg_price    35420.407376
# Name: 335, dtype: float64
# mi               0.001248
# avg_price    35701.338194
# Name: 336, dtype: float64
# mi               0.001248
# avg_price    34652.408073
# Name: 337, dtype: float64
# mi               0.001248
# avg_price    34142.664320
# Name: 338, dtype: float64
# mi               0.001248
# avg_price    36942.460340
# Name: 339, dtype: float64
# mi               0.001248
# avg_price    36407.312924
# Name: 340, dtype: float64
# mi               0.001248
# avg_price    36628.022057
# Name: 341, dtype: float64
# mi               0.001248
# avg_price    33818.405524
# Name: 342, dtype: float64
# mi               0.001248
# avg_price    36533.579493
# Name: 343, dtype: float64
# mi               0.001248
# avg_price    36527.272522
# Name: 344, dtype: float64
# mi               0.001248
# avg_price    36303.320382
# Name: 345, dtype: float64
# mi               0.001248
# avg_price    35842.995111
# Name: 346, dtype: float64
# mi               0.001248
# avg_price    36270.692157
# Name: 347, dtype: float64
# mi               0.001248
# avg_price    37897.825974
# Name: 348, dtype: float64
# mi               0.001248
# avg_price    36751.611128
# Name: 349, dtype: float64
# mi               0.001248
# avg_price    37028.313965
# Name: 350, dtype: float64
# mi               0.001248
# avg_price    36788.331403
# Name: 351, dtype: float64
# mi               0.001248
# avg_price    34463.324832
# Name: 352, dtype: float64
# mi               0.001248
# avg_price    35825.496301
# Name: 353, dtype: float64
# mi               0.001248
# avg_price    37465.327652
# Name: 354, dtype: float64
# mi               0.001248
# avg_price    36231.913869
# Name: 355, dtype: float64
# mi               0.001248
# avg_price    35451.870902
# Name: 356, dtype: float64
# mi               0.001248
# avg_price    37477.132381
# Name: 357, dtype: float64
# mi               0.001248
# avg_price    36071.783616
# Name: 358, dtype: float64
# mi               0.001248
# avg_price    35861.053038
# Name: 359, dtype: float64
# mi               0.001248
# avg_price    34323.170273
# Name: 360, dtype: float64
# mi               0.001248
# avg_price    36929.845047
# Name: 361, dtype: float64
# mi               0.001248
# avg_price    34733.342204
# Name: 362, dtype: float64
# mi               0.001248
# avg_price    35661.687641
# Name: 363, dtype: float64
# mi               0.001248
# avg_price    38770.529502
# Name: 364, dtype: float64
# mi               0.001248
# avg_price    35915.664708
# Name: 365, dtype: float64
# mi               0.001248
# avg_price    34307.241604
# Name: 366, dtype: float64
# mi               0.001248
# avg_price    33417.936878
# Name: 367, dtype: float64
# mi               0.001248
# avg_price    37663.679133
# Name: 368, dtype: float64
# mi               0.001248
# avg_price    37230.400514
# Name: 369, dtype: float64
# mi               0.001248
# avg_price    37139.898320
# Name: 370, dtype: float64
# mi               0.001248
# avg_price    35004.784708
# Name: 371, dtype: float64
# mi               0.001248
# avg_price    35692.173738
# Name: 372, dtype: float64
# mi               0.001248
# avg_price    37346.075912
# Name: 373, dtype: float64
# mi               0.001248
# avg_price    34057.273104
# Name: 374, dtype: float64
# mi               0.001248
# avg_price    37739.442984
# Name: 375, dtype: float64
# mi               0.001248
# avg_price    36859.626356
# Name: 376, dtype: float64
# mi               0.001248
# avg_price    33805.121922
# Name: 377, dtype: float64
# mi               0.001248
# avg_price    35178.213269
# Name: 378, dtype: float64
# mi               0.001248
# avg_price    35090.838896
# Name: 379, dtype: float64
# mi               0.001248
# avg_price    36178.186896
# Name: 380, dtype: float64
# mi               0.001248
# avg_price    36977.959629
# Name: 381, dtype: float64
# mi               0.001248
# avg_price    36453.977855
# Name: 382, dtype: float64
# mi               0.001248
# avg_price    35365.870458
# Name: 383, dtype: float64
# mi               0.001248
# avg_price    36903.767031
# Name: 384, dtype: float64
# mi               0.001248
# avg_price    34738.708229
# Name: 385, dtype: float64
# mi               0.001248
# avg_price    36242.100730
# Name: 386, dtype: float64
# mi               0.001248
# avg_price    34956.831565
# Name: 387, dtype: float64
# mi               0.001248
# avg_price    37435.431231
# Name: 388, dtype: float64
# mi               0.001248
# avg_price    37450.856026
# Name: 389, dtype: float64
# mi               0.001248
# avg_price    36547.085110
# Name: 390, dtype: float64
# mi               0.001248
# avg_price    37072.448184
# Name: 391, dtype: float64
# mi               0.001248
# avg_price    35141.503849
# Name: 392, dtype: float64
# mi               0.001248
# avg_price    36798.882671
# Name: 393, dtype: float64
# mi               0.001248
# avg_price    36178.286913
# Name: 394, dtype: float64
# mi               0.001248
# avg_price    34572.544618
# Name: 395, dtype: float64
# mi               0.001248
# avg_price    37214.856737
# Name: 396, dtype: float64
# mi               0.001248
# avg_price    35567.071840
# Name: 397, dtype: float64
# mi               0.001248
# avg_price    33840.868901
# Name: 398, dtype: float64
# mi               0.001248
# avg_price    35667.682158
# Name: 399, dtype: float64
# mi               0.001248
# avg_price    35903.100716
# Name: 400, dtype: float64
# mi               0.001248
# avg_price    36531.309410
# Name: 401, dtype: float64
# mi               0.001248
# avg_price    36615.335108
# Name: 402, dtype: float64
# mi               0.001248
# avg_price    36473.024674
# Name: 403, dtype: float64
# mi               0.001248
# avg_price    37064.216801
# Name: 404, dtype: float64
# mi               0.001248
# avg_price    36021.688190
# Name: 405, dtype: float64
# mi               0.001248
# avg_price    35537.035205
# Name: 406, dtype: float64
# mi               0.001248
# avg_price    35223.218260
# Name: 407, dtype: float64
# mi               0.001248
# avg_price    35615.833946
# Name: 408, dtype: float64
# mi               0.001248
# avg_price    34055.892158
# Name: 409, dtype: float64
# mi               0.001248
# avg_price    34438.111307
# Name: 410, dtype: float64
# mi               0.001248
# avg_price    37031.543406
# Name: 411, dtype: float64
# mi               0.001248
# avg_price    36164.259181
# Name: 412, dtype: float64
# mi               0.001248
# avg_price    33978.025258
# Name: 413, dtype: float64
# mi               0.001248
# avg_price    35289.843987
# Name: 414, dtype: float64
# mi               0.001248
# avg_price    33767.840041
# Name: 415, dtype: float64
# mi               0.001248
# avg_price    36085.584076
# Name: 416, dtype: float64
# mi               0.001248
# avg_price    37268.478894
# Name: 417, dtype: float64
# mi               0.001248
# avg_price    36602.899999
# Name: 418, dtype: float64
# mi               0.001248
# avg_price    37412.515224
# Name: 419, dtype: float64
# mi               0.001248
# avg_price    36403.381664
# Name: 420, dtype: float64
# mi               0.001248
# avg_price    34602.431837
# Name: 421, dtype: float64
# mi               0.001248
# avg_price    36296.359316
# Name: 422, dtype: float64
# mi               0.001248
# avg_price    35267.208064
# Name: 423, dtype: float64
# mi               0.001248
# avg_price    34808.998176
# Name: 424, dtype: float64
# mi               0.001248
# avg_price    36662.451687
# Name: 425, dtype: float64
# mi               0.001248
# avg_price    34977.535603
# Name: 426, dtype: float64
# mi               0.001248
# avg_price    35761.774178
# Name: 427, dtype: float64
# mi               0.001248
# avg_price    34527.524568
# Name: 428, dtype: float64
# mi               0.001248
# avg_price    35584.006467
# Name: 429, dtype: float64
# mi               0.001248
# avg_price    37383.466283
# Name: 430, dtype: float64
# mi               0.001248
# avg_price    37212.356277
# Name: 431, dtype: float64
# mi               0.001248
# avg_price    35504.448327
# Name: 432, dtype: float64
# mi               0.001248
# avg_price    36771.452614
# Name: 433, dtype: float64
# mi               0.001248
# avg_price    37076.706699
# Name: 434, dtype: float64
# mi               0.001248
# avg_price    34739.888402
# Name: 435, dtype: float64
# mi               0.001248
# avg_price    35205.476067
# Name: 436, dtype: float64
# mi               0.001248
# avg_price    37201.710609
# Name: 437, dtype: float64
# mi               0.001248
# avg_price    34217.301076
# Name: 438, dtype: float64
# mi               0.001248
# avg_price    35587.889992
# Name: 439, dtype: float64
# mi               0.001248
# avg_price    34975.750202
# Name: 440, dtype: float64
# mi               0.001248
# avg_price    34723.209446
# Name: 441, dtype: float64
# mi               0.001248
# avg_price    36876.338212
# Name: 442, dtype: float64
# mi               0.001248
# avg_price    35428.436936
# Name: 443, dtype: float64
# mi               0.001248
# avg_price    35618.015460
# Name: 444, dtype: float64
# mi               0.001248
# avg_price    36475.164860
# Name: 445, dtype: float64
# mi               0.001248
# avg_price    36448.530721
# Name: 446, dtype: float64
# mi               0.001248
# avg_price    35300.401075
# Name: 447, dtype: float64
# mi               0.001248
# avg_price    34794.295330
# Name: 448, dtype: float64
# mi               0.001248
# avg_price    35940.526237
# Name: 449, dtype: float64
# mi               0.001248
# avg_price    37841.622992
# Name: 450, dtype: float64
# mi               0.001248
# avg_price    37835.593867
# Name: 451, dtype: float64
# mi               0.001248
# avg_price    36162.929096
# Name: 452, dtype: float64
# mi               0.001248
# avg_price    34478.946953
# Name: 453, dtype: float64
# mi               0.001248
# avg_price    37428.751519
# Name: 454, dtype: float64
# mi               0.001248
# avg_price    35487.232382
# Name: 455, dtype: float64
# mi               0.001248
# avg_price    34899.949383
# Name: 456, dtype: float64
# mi               0.001248
# avg_price    34427.979055
# Name: 457, dtype: float64
# mi               0.001248
# avg_price    35655.753547
# Name: 458, dtype: float64
# mi               0.001248
# avg_price    37170.240894
# Name: 459, dtype: float64
# mi               0.001248
# avg_price    35720.559964
# Name: 460, dtype: float64
# mi               0.001248
# avg_price    33029.873609
# Name: 461, dtype: float64
# mi               0.001248
# avg_price    33512.574813
# Name: 462, dtype: float64
# mi               0.001248
# avg_price    38296.911369
# Name: 463, dtype: float64
# mi               0.001248
# avg_price    35002.955342
# Name: 464, dtype: float64
# mi               0.001248
# avg_price    34289.915851
# Name: 465, dtype: float64
# mi               0.001248
# avg_price    36878.919237
# Name: 466, dtype: float64
# mi               0.001248
# avg_price    34214.698905
# Name: 467, dtype: float64
# mi               0.001248
# avg_price    36076.739080
# Name: 468, dtype: float64
# mi               0.001248
# avg_price    32904.322533
# Name: 469, dtype: float64
# mi               0.001248
# avg_price    36900.250978
# Name: 470, dtype: float64
# mi               0.001248
# avg_price    36358.449343
# Name: 471, dtype: float64
# mi               0.001248
# avg_price    35567.565440
# Name: 472, dtype: float64
# mi               0.001248
# avg_price    37043.378384
# Name: 473, dtype: float64
# mi               0.001248
# avg_price    35204.314710
# Name: 474, dtype: float64
# mi               0.001248
# avg_price    35904.855418
# Name: 475, dtype: float64
# mi               0.001248
# avg_price    35076.438435
# Name: 476, dtype: float64
# mi               0.001248
# avg_price    36559.416460
# Name: 477, dtype: float64
# mi               0.001248
# avg_price    36031.656137
# Name: 478, dtype: float64
# mi               0.001248
# avg_price    34526.510990
# Name: 479, dtype: float64
# mi               0.001248
# avg_price    34578.164354
# Name: 480, dtype: float64
# mi               0.001248
# avg_price    35722.469101
# Name: 481, dtype: float64
# mi               0.001248
# avg_price    35080.888381
# Name: 482, dtype: float64
# mi               0.001248
# avg_price    36051.835402
# Name: 483, dtype: float64
# mi               0.001248
# avg_price    35939.925992
# Name: 484, dtype: float64
# mi               0.001248
# avg_price    34834.899125
# Name: 485, dtype: float64
# mi               0.001248
# avg_price    37448.184877
# Name: 486, dtype: float64
# mi               0.001248
# avg_price    37286.371707
# Name: 487, dtype: float64
# mi               0.001248
# avg_price    34462.248300
# Name: 488, dtype: float64
# mi               0.001248
# avg_price    36357.610759
# Name: 489, dtype: float64
# mi               0.001248
# avg_price    34788.111301
# Name: 490, dtype: float64
# mi               0.001248
# avg_price    36657.196712
# Name: 491, dtype: float64
# mi               0.001248
# avg_price    37376.140868
# Name: 492, dtype: float64
# mi               0.001248
# avg_price    35790.448089
# Name: 493, dtype: float64
# mi               0.001248
# avg_price    36238.683202
# Name: 494, dtype: float64
# mi               0.001248
# avg_price    35823.689459
# Name: 495, dtype: float64
# mi               0.001248
# avg_price    35586.500483
# Name: 496, dtype: float64
# mi               0.001248
# avg_price    36732.091108
# Name: 497, dtype: float64
# mi               0.001248
# avg_price    37104.400098
# Name: 498, dtype: float64
# mi               0.001248
# avg_price    34855.295066
# Name: 499, dtype: float64
# mi               0.001248
# avg_price    35193.165221
# Name: 500, dtype: float64
# mi               0.001248
# avg_price    36541.098292
# Name: 501, dtype: float64
# mi               0.001248
# avg_price    35357.763800
# Name: 502, dtype: float64
# mi               0.001248
# avg_price    37551.476426
# Name: 503, dtype: float64
# mi               0.001248
# avg_price    34015.087358
# Name: 504, dtype: float64
# mi               0.001248
# avg_price    35994.599346
# Name: 505, dtype: float64
# mi               0.001248
# avg_price    34925.499731
# Name: 506, dtype: float64
# mi               0.001248
# avg_price    36414.034467
# Name: 507, dtype: float64
# mi               0.001248
# avg_price    36546.618683
# Name: 508, dtype: float64
# mi               0.001248
# avg_price    34487.895062
# Name: 509, dtype: float64
# mi               0.001248
# avg_price    37401.347182
# Name: 510, dtype: float64
# mi               0.001248
# avg_price    36843.654246
# Name: 511, dtype: float64
# mi               0.001248
# avg_price    35551.771326
# Name: 512, dtype: float64
# mi               0.001248
# avg_price    36910.517745
# Name: 513, dtype: float64
# mi               0.001248
# avg_price    33882.479777
# Name: 514, dtype: float64
# mi               0.001248
# avg_price    35087.416978
# Name: 515, dtype: float64
# mi               0.001248
# avg_price    35377.330169
# Name: 516, dtype: float64
# mi               0.001248
# avg_price    38710.783875
# Name: 517, dtype: float64
# mi               0.001248
# avg_price    34800.570641
# Name: 518, dtype: float64
# mi               0.001248
# avg_price    36012.247651
# Name: 519, dtype: float64
# mi               0.001248
# avg_price    35845.708324
# Name: 520, dtype: float64
# mi               0.001248
# avg_price    36369.326870
# Name: 521, dtype: float64
# mi               0.001248
# avg_price    36347.751964
# Name: 522, dtype: float64
# mi               0.001248
# avg_price    37750.451142
# Name: 523, dtype: float64
# mi               0.001248
# avg_price    35331.092730
# Name: 524, dtype: float64
# mi               0.001248
# avg_price    34526.994599
# Name: 525, dtype: float64
# mi               0.001248
# avg_price    35235.396718
# Name: 526, dtype: float64
# mi               0.001248
# avg_price    38695.790703
# Name: 527, dtype: float64
# mi               0.001248
# avg_price    37646.021680
# Name: 528, dtype: float64
# mi               0.001248
# avg_price    35843.084830
# Name: 529, dtype: float64
# mi               0.001248
# avg_price    36121.056478
# Name: 530, dtype: float64
# mi               0.001248
# avg_price    34127.665480
# Name: 531, dtype: float64
# mi               0.001248
# avg_price    37569.237802
# Name: 532, dtype: float64
# mi               0.001248
# avg_price    36447.895254
# Name: 533, dtype: float64
# mi               0.001248
# avg_price    34991.942096
# Name: 534, dtype: float64
# mi               0.001248
# avg_price    36416.332794
# Name: 535, dtype: float64
# mi               0.001248
# avg_price    36676.368926
# Name: 536, dtype: float64
# mi               0.001248
# avg_price    33618.055983
# Name: 537, dtype: float64
# mi               0.001248
# avg_price    34207.470123
# Name: 538, dtype: float64
# mi               0.001248
# avg_price    37139.733026
# Name: 539, dtype: float64
# mi               0.001248
# avg_price    34959.710547
# Name: 540, dtype: float64
# mi               0.001248
# avg_price    35286.181013
# Name: 541, dtype: float64
# mi               0.001248
# avg_price    35397.315747
# Name: 542, dtype: float64
# mi               0.001248
# avg_price    38281.416626
# Name: 543, dtype: float64
# mi               0.001248
# avg_price    33775.388793
# Name: 544, dtype: float64
# mi               0.001248
# avg_price    36409.813261
# Name: 545, dtype: float64
# mi               0.001248
# avg_price    34213.427411
# Name: 546, dtype: float64
# mi               0.001248
# avg_price    36647.996576
# Name: 547, dtype: float64
# mi               0.001248
# avg_price    35656.719594
# Name: 548, dtype: float64
# mi               0.001248
# avg_price    37721.261381
# Name: 549, dtype: float64
# mi               0.001248
# avg_price    36776.283629
# Name: 550, dtype: float64
# mi               0.001248
# avg_price    36689.506014
# Name: 551, dtype: float64
# mi               0.001248
# avg_price    33479.002441
# Name: 552, dtype: float64
# mi               0.001248
# avg_price    36052.556800
# Name: 553, dtype: float64
# mi               0.001248
# avg_price    36215.526199
# Name: 554, dtype: float64
# mi               0.001248
# avg_price    35136.407482
# Name: 555, dtype: float64
# mi               0.001248
# avg_price    34815.234568
# Name: 556, dtype: float64
# mi               0.001248
# avg_price    35887.059294
# Name: 557, dtype: float64
# mi               0.001248
# avg_price    33683.332206
# Name: 558, dtype: float64
# mi               0.001248
# avg_price    35970.143791
# Name: 559, dtype: float64
# mi               0.001248
# avg_price    35636.044042
# Name: 560, dtype: float64
# mi               0.001248
# avg_price    36049.949058
# Name: 561, dtype: float64
# mi               0.001248
# avg_price    36620.976347
# Name: 562, dtype: float64
# mi               0.001248
# avg_price    34538.497517
# Name: 563, dtype: float64
# mi               0.001248
# avg_price    36025.722763
# Name: 564, dtype: float64
# mi               0.001248
# avg_price    35598.800944
# Name: 565, dtype: float64
# mi               0.001248
# avg_price    33926.709724
# Name: 566, dtype: float64
# mi               0.001248
# avg_price    33881.650334
# Name: 567, dtype: float64
# mi               0.001248
# avg_price    37758.453396
# Name: 568, dtype: float64
# mi               0.001248
# avg_price    34906.944198
# Name: 569, dtype: float64
# mi               0.001248
# avg_price    35830.551516
# Name: 570, dtype: float64
# mi               0.001248
# avg_price    37669.099270
# Name: 571, dtype: float64
# mi               0.001248
# avg_price    34816.972763
# Name: 572, dtype: float64
# mi               0.001248
# avg_price    35149.432638
# Name: 573, dtype: float64
# mi               0.001248
# avg_price    35437.831788
# Name: 574, dtype: float64
# mi               0.001248
# avg_price    36758.394306
# Name: 575, dtype: float64
# mi               0.001248
# avg_price    35685.361575
# Name: 576, dtype: float64
# mi               0.001248
# avg_price    35413.717821
# Name: 577, dtype: float64
# mi               0.001248
# avg_price    36634.883126
# Name: 578, dtype: float64
# mi               0.001248
# avg_price    35291.899459
# Name: 579, dtype: float64
# mi               0.001248
# avg_price    35185.204976
# Name: 580, dtype: float64
# mi               0.001248
# avg_price    36534.083468
# Name: 581, dtype: float64
# mi               0.001248
# avg_price    37795.786967
# Name: 582, dtype: float64
# mi               0.001248
# avg_price    37185.008466
# Name: 583, dtype: float64
# mi               0.001248
# avg_price    37929.152637
# Name: 584, dtype: float64
# mi               0.001248
# avg_price    35862.267155
# Name: 585, dtype: float64
# mi               0.001248
# avg_price    34684.976350
# Name: 586, dtype: float64
# mi               0.001248
# avg_price    36993.726316
# Name: 587, dtype: float64
# mi               0.001248
# avg_price    35715.674185
# Name: 588, dtype: float64
# mi               0.001248
# avg_price    35878.258487
# Name: 589, dtype: float64
# mi               0.001248
# avg_price    36907.324595
# Name: 590, dtype: float64
# mi               0.001248
# avg_price    36206.223131
# Name: 591, dtype: float64
# mi               0.001248
# avg_price    37406.748191
# Name: 592, dtype: float64
# mi               0.001248
# avg_price    35212.920064
# Name: 593, dtype: float64
# mi               0.001248
# avg_price    35570.686360
# Name: 594, dtype: float64
# mi               0.001248
# avg_price    35709.497097
# Name: 595, dtype: float64
# mi               0.001248
# avg_price    35317.847960
# Name: 596, dtype: float64
# mi               0.001248
# avg_price    34249.908583
# Name: 597, dtype: float64
# mi               0.001248
# avg_price    35510.103405
# Name: 598, dtype: float64
# mi               0.001248
# avg_price    37614.591089
# Name: 599, dtype: float64
# mi               0.001248
# avg_price    35273.151214
# Name: 600, dtype: float64
# mi               0.001248
# avg_price    34952.397662
# Name: 601, dtype: float64
# mi               0.001248
# avg_price    36062.116404
# Name: 602, dtype: float64
# mi               0.001248
# avg_price    34429.374946
# Name: 603, dtype: float64
# mi               0.001248
# avg_price    37871.069641
# Name: 604, dtype: float64
# mi               0.001248
# avg_price    34732.355254
# Name: 605, dtype: float64
# mi               0.001248
# avg_price    34087.434603
# Name: 606, dtype: float64
# mi               0.001248
# avg_price    38160.870201
# Name: 607, dtype: float64
# mi               0.001248
# avg_price    35755.547455
# Name: 608, dtype: float64
# mi               0.001248
# avg_price    35421.569443
# Name: 609, dtype: float64
# mi               0.001248
# avg_price    35764.201701
# Name: 610, dtype: float64
# mi               0.001248
# avg_price    36447.288517
# Name: 611, dtype: float64
# mi               0.001248
# avg_price    36210.453497
# Name: 612, dtype: float64
# mi               0.001248
# avg_price    36199.832331
# Name: 613, dtype: float64
# mi               0.001248
# avg_price    37366.531142
# Name: 614, dtype: float64
# mi               0.001248
# avg_price    36254.467822
# Name: 615, dtype: float64
# mi               0.001248
# avg_price    37593.911651
# ...
# mi              16.0000
# avg_price    36000.7042
# Name: 8808, dtype: float64
# mi              16.000000
# avg_price    35957.006685
# Name: 8809, dtype: float64
# mi              16.000000
# avg_price    35977.593852
# Name: 8810, dtype: float64
# mi              16.000000
# avg_price    36050.618013
# Name: 8811, dtype: float64
# mi              16.000000
# avg_price    35948.496568
# Name: 8812, dtype: float64
# mi              16.000000
# avg_price    35936.968847
# Name: 8813, dtype: float64
# mi              16.000000
# avg_price    36009.078315
# Name: 8814, dtype: float64
# mi              16.000000
# avg_price    36107.878903
# Name: 8815, dtype: float64
# mi              16.00000
# avg_price    36076.58683
# Name: 8816, dtype: float64
# mi              16.000000
# avg_price    36101.628672
# Name: 8817, dtype: float64
# mi              16.000000
# avg_price    36012.193843
# Name: 8818, dtype: float64
# mi              16.000000
# avg_price    35965.675124
# Name: 8819, dtype: float64
# mi              16.000000
# avg_price    35992.852625
# Name: 8820, dtype: float64
# mi              16.000000
# avg_price    36032.676176
# Name: 8821, dtype: float64
# mi              16.000000
# avg_price    36176.371421
# Name: 8822, dtype: float64
# mi              16.000000
# avg_price    36019.335374
# Name: 8823, dtype: float64
# mi              16.000000
# avg_price    35994.280177
# Name: 8824, dtype: float64
# mi              16.000000
# avg_price    35895.444085
# Name: 8825, dtype: float64
# mi              16.000000
# avg_price    36028.886886
# Name: 8826, dtype: float64
# mi              16.000000
# avg_price    36068.068091
# Name: 8827, dtype: float64
# mi              16.000000
# avg_price    36139.410052
# Name: 8828, dtype: float64
# mi              16.000000
# avg_price    36029.586662
# Name: 8829, dtype: float64
# mi              16.000000
# avg_price    35938.169102
# Name: 8830, dtype: float64
# mi              16.000000
# avg_price    35915.598899
# Name: 8831, dtype: float64
# mi              16.000000
# avg_price    35955.490557
# Name: 8832, dtype: float64
# mi              16.000000
# avg_price    35938.732262
# Name: 8833, dtype: float64
# mi              16.000000
# avg_price    35911.490538
# Name: 8834, dtype: float64
# mi              16.00000
# avg_price    35893.52259
# Name: 8835, dtype: float64
# mi              16.000000
# avg_price    35916.690908
# Name: 8836, dtype: float64
# mi              16.000000
# avg_price    35974.955046
# Name: 8837, dtype: float64
# mi              16.000000
# avg_price    35968.252203
# Name: 8838, dtype: float64
# mi              16.000000
# avg_price    35951.798377
# Name: 8839, dtype: float64
# mi              16.000000
# avg_price    35965.477222
# Name: 8840, dtype: float64
# mi              16.000000
# avg_price    36097.882288
# Name: 8841, dtype: float64
# mi              16.000000
# avg_price    35935.420744
# Name: 8842, dtype: float64
# mi              16.000000
# avg_price    35898.251484
# Name: 8843, dtype: float64
# mi              16.000000
# avg_price    36017.417631
# Name: 8844, dtype: float64
# mi              16.000000
# avg_price    35937.291543
# Name: 8845, dtype: float64
# mi              16.000000
# avg_price    35957.679345
# Name: 8846, dtype: float64
# mi              16.000000
# avg_price    36041.836187
# Name: 8847, dtype: float64
# mi              16.000000
# avg_price    36169.573771
# Name: 8848, dtype: float64
# mi              16.000000
# avg_price    36135.240761
# Name: 8849, dtype: float64
# mi              16.000000
# avg_price    35858.435579
# Name: 8850, dtype: float64
# mi              16.000000
# avg_price    36032.809481
# Name: 8851, dtype: float64
# mi              16.000000
# avg_price    36001.314017
# Name: 8852, dtype: float64
# mi              16.000000
# avg_price    35940.906113
# Name: 8853, dtype: float64
# mi              16.000000
# avg_price    36041.642357
# Name: 8854, dtype: float64
# mi              16.000000
# avg_price    35857.896898
# Name: 8855, dtype: float64
# mi              16.000000
# avg_price    36040.090029
# Name: 8856, dtype: float64
# mi              16.00000
# avg_price    36028.17204
# Name: 8857, dtype: float64
# mi              16.000000
# avg_price    36075.078579
# Name: 8858, dtype: float64
# mi              16.000000
# avg_price    36033.693517
# Name: 8859, dtype: float64
# mi              16.000000
# avg_price    36069.609379
# Name: 8860, dtype: float64
# mi              16.000000
# avg_price    35923.587787
# Name: 8861, dtype: float64
# mi              16.000000
# avg_price    36052.740453
# Name: 8862, dtype: float64
# mi              16.000000
# avg_price    36045.131552
# Name: 8863, dtype: float64
# mi              16.000000
# avg_price    35888.006042
# Name: 8864, dtype: float64
# mi              16.000000
# avg_price    35990.581308
# Name: 8865, dtype: float64
# mi              16.000000
# avg_price    35955.899575
# Name: 8866, dtype: float64
# mi              16.000000
# avg_price    35997.655284
# Name: 8867, dtype: float64
# mi              16.000000
# avg_price    36023.006052
# Name: 8868, dtype: float64
# mi              16.000000
# avg_price    36051.024913
# Name: 8869, dtype: float64
# mi              16.000000
# avg_price    35951.095206
# Name: 8870, dtype: float64
# mi              16.000000
# avg_price    36044.912162
# Name: 8871, dtype: float64
# mi              16.00000
# avg_price    35965.24134
# Name: 8872, dtype: float64
# mi              16.000000
# avg_price    35958.374004
# Name: 8873, dtype: float64
# mi              16.000000
# avg_price    35992.118263
# Name: 8874, dtype: float64
# mi              16.000000
# avg_price    36047.628467
# Name: 8875, dtype: float64
# mi              16.00000
# avg_price    36040.11345
# Name: 8876, dtype: float64
# mi              16.000000
# avg_price    35978.792633
# Name: 8877, dtype: float64
# mi              16.000000
# avg_price    35907.250758
# Name: 8878, dtype: float64
# mi              16.000000
# avg_price    36065.293703
# Name: 8879, dtype: float64
# mi              16.000000
# avg_price    35995.759231
# Name: 8880, dtype: float64
# mi              16.000000
# avg_price    35939.820923
# Name: 8881, dtype: float64
# mi              16.000000
# avg_price    36087.286656
# Name: 8882, dtype: float64
# mi              16.000000
# avg_price    35893.187322
# Name: 8883, dtype: float64
# mi              16.000000
# avg_price    36047.494781
# Name: 8884, dtype: float64
# mi              16.000000
# avg_price    36146.247521
# Name: 8885, dtype: float64
# mi              16.000000
# avg_price    35996.706252
# Name: 8886, dtype: float64
# mi              16.000000
# avg_price    35919.806252
# Name: 8887, dtype: float64
# mi              16.000000
# avg_price    36080.192277
# Name: 8888, dtype: float64
# mi              16.000000
# avg_price    35961.731318
# Name: 8889, dtype: float64
# mi              16.000000
# avg_price    36025.799795
# Name: 8890, dtype: float64
# mi              16.000000
# avg_price    36016.390649
# Name: 8891, dtype: float64
# mi              16.000000
# avg_price    35936.352018
# Name: 8892, dtype: float64
# mi              16.000000
# avg_price    36055.778616
# Name: 8893, dtype: float64
# mi              16.000000
# avg_price    36137.969632
# Name: 8894, dtype: float64
# mi              16.000000
# avg_price    36032.153476
# Name: 8895, dtype: float64
# mi              16.000000
# avg_price    35972.121051
# Name: 8896, dtype: float64
# mi              16.000000
# avg_price    36093.033251
# Name: 8897, dtype: float64
# mi              16.000000
# avg_price    35952.641493
# Name: 8898, dtype: float64
# mi              16.000000
# avg_price    35972.025552
# Name: 8899, dtype: float64
# mi              16.00000
# avg_price    35995.04604
# Name: 8900, dtype: float64
# mi              16.000000
# avg_price    35965.861229
# Name: 8901, dtype: float64
# mi              16.000000
# avg_price    35973.652858
# Name: 8902, dtype: float64
# mi              16.000000
# avg_price    36017.393482
# Name: 8903, dtype: float64
# mi              16.000000
# avg_price    35963.728263
# Name: 8904, dtype: float64
# mi              16.000000
# avg_price    35954.018206
# Name: 8905, dtype: float64
# mi              16.000000
# avg_price    36012.888478
# Name: 8906, dtype: float64
# mi              16.000000
# avg_price    36010.665727
# Name: 8907, dtype: float64
# mi              16.000000
# avg_price    36038.771345
# Name: 8908, dtype: float64
# mi              16.000000
# avg_price    35997.008114
# Name: 8909, dtype: float64
# mi              16.000000
# avg_price    35970.891442
# Name: 8910, dtype: float64
# mi              16.000000
# avg_price    35975.851158
# Name: 8911, dtype: float64
# mi              16.00000
# avg_price    36093.72122
# Name: 8912, dtype: float64
# mi              16.00000
# avg_price    36084.18548
# Name: 8913, dtype: float64
# mi              16.000000
# avg_price    36011.820555
# Name: 8914, dtype: float64
# mi              16.000000
# avg_price    36011.776344
# Name: 8915, dtype: float64
# mi              16.000000
# avg_price    36075.522226
# Name: 8916, dtype: float64
# mi              16.000000
# avg_price    35980.171236
# Name: 8917, dtype: float64
# mi              16.000000
# avg_price    35945.515655
# Name: 8918, dtype: float64
# mi              16.000000
# avg_price    35987.434644
# Name: 8919, dtype: float64
# mi              16.000000
# avg_price    36072.376357
# Name: 8920, dtype: float64
# mi              16.000000
# avg_price    35953.984293
# Name: 8921, dtype: float64
# mi              16.000000
# avg_price    36200.810366
# Name: 8922, dtype: float64
# mi              16.00000
# avg_price    36030.59548
# Name: 8923, dtype: float64
# mi              16.000000
# avg_price    35938.398524
# Name: 8924, dtype: float64
# mi              16.000000
# avg_price    36025.399871
# Name: 8925, dtype: float64
# mi              16.000000
# avg_price    35959.730868
# Name: 8926, dtype: float64
# mi              16.000000
# avg_price    36033.581095
# Name: 8927, dtype: float64
# mi              16.000000
# avg_price    35997.780788
# Name: 8928, dtype: float64
# mi              16.000000
# avg_price    36014.850181
# Name: 8929, dtype: float64
# mi              16.000000
# avg_price    35982.706468
# Name: 8930, dtype: float64
# mi              16.000000
# avg_price    36049.663086
# Name: 8931, dtype: float64
# mi              16.00000
# avg_price    35914.88792
# Name: 8932, dtype: float64
# mi              16.000000
# avg_price    35986.163305
# Name: 8933, dtype: float64
# mi              16.000000
# avg_price    35910.300661
# Name: 8934, dtype: float64
# mi              16.000000
# avg_price    35982.348722
# Name: 8935, dtype: float64
# mi              16.000000
# avg_price    35973.299228
# Name: 8936, dtype: float64
# mi              16.000000
# avg_price    36071.854522
# Name: 8937, dtype: float64
# mi              16.000000
# avg_price    35899.762903
# Name: 8938, dtype: float64
# mi              16.000000
# avg_price    36041.749376
# Name: 8939, dtype: float64
# mi              16.000000
# avg_price    36053.517242
# Name: 8940, dtype: float64
# mi              16.000000
# avg_price    36037.505663
# Name: 8941, dtype: float64
# mi              16.000000
# avg_price    36088.764492
# Name: 8942, dtype: float64
# mi              16.000000
# avg_price    35955.069558
# Name: 8943, dtype: float64
# mi              16.000000
# avg_price    36020.000882
# Name: 8944, dtype: float64
# mi              16.000000
# avg_price    36026.441865
# Name: 8945, dtype: float64
# mi              16.000000
# avg_price    36060.496149
# Name: 8946, dtype: float64
# mi              16.000000
# avg_price    36013.697465
# Name: 8947, dtype: float64
# mi              16.00000
# avg_price    35972.50736
# Name: 8948, dtype: float64
# mi              16.000000
# avg_price    36175.428776
# Name: 8949, dtype: float64
# mi              16.000000
# avg_price    35922.211548
# Name: 8950, dtype: float64
# mi              16.000000
# avg_price    36043.756736
# Name: 8951, dtype: float64
# mi              16.000000
# avg_price    35957.121301
# Name: 8952, dtype: float64
# mi              16.000000
# avg_price    35927.567371
# Name: 8953, dtype: float64
# mi              16.000000
# avg_price    36036.591955
# Name: 8954, dtype: float64
# mi              16.000000
# avg_price    36063.327474
# Name: 8955, dtype: float64
# mi              16.000000
# avg_price    36048.367789
# Name: 8956, dtype: float64
# mi              16.000000
# avg_price    35945.975483
# Name: 8957, dtype: float64
# mi              16.000000
# avg_price    35949.616895
# Name: 8958, dtype: float64
# mi              16.000000
# avg_price    36007.284701
# Name: 8959, dtype: float64
# mi              16.000000
# avg_price    36074.618596
# Name: 8960, dtype: float64
# mi              16.00000
# avg_price    35937.28785
# Name: 8961, dtype: float64
# mi              16.000000
# avg_price    36082.058093
# Name: 8962, dtype: float64
# mi              16.000000
# avg_price    35941.010405
# Name: 8963, dtype: float64
# mi              16.000000
# avg_price    35977.061487
# Name: 8964, dtype: float64
# mi              16.000000
# avg_price    36087.498484
# Name: 8965, dtype: float64
# mi              16.000000
# avg_price    36093.607045
# Name: 8966, dtype: float64
# mi              16.00000
# avg_price    36016.25369
# Name: 8967, dtype: float64
# mi              16.000000
# avg_price    35942.746879
# Name: 8968, dtype: float64
# mi              16.000000
# avg_price    36009.936658
# Name: 8969, dtype: float64
# mi              16.000000
# avg_price    36023.380888
# Name: 8970, dtype: float64
# mi              16.000000
# avg_price    36007.021429
# Name: 8971, dtype: float64
# mi              16.000000
# avg_price    36057.526187
# Name: 8972, dtype: float64
# mi              16.000000
# avg_price    36056.748449
# Name: 8973, dtype: float64
# mi              16.000000
# avg_price    36014.794282
# Name: 8974, dtype: float64
# mi              16.000000
# avg_price    35994.362903
# Name: 8975, dtype: float64
# mi              16.000000
# avg_price    36126.431578
# Name: 8976, dtype: float64
# mi              16.000000
# avg_price    36004.323519
# Name: 8977, dtype: float64
# mi              16.000000
# avg_price    35949.868782
# Name: 8978, dtype: float64
# mi              16.000000
# avg_price    35935.186477
# Name: 8979, dtype: float64
# mi              16.000000
# avg_price    36077.007401
# Name: 8980, dtype: float64
# mi              16.00000
# avg_price    35985.59542
# Name: 8981, dtype: float64
# mi              16.000000
# avg_price    36003.569389
# Name: 8982, dtype: float64
# mi              16.000000
# avg_price    35925.236475
# Name: 8983, dtype: float64
# mi              16.000000
# avg_price    36004.495235
# Name: 8984, dtype: float64
# mi              16.000000
# avg_price    36019.574513
# Name: 8985, dtype: float64
# mi              16.000000
# avg_price    36023.674898
# Name: 8986, dtype: float64
# mi              16.000000
# avg_price    35881.933045
# Name: 8987, dtype: float64
# mi              16.00000
# avg_price    36063.16143
# Name: 8988, dtype: float64
# mi              16.000000
# avg_price    35964.744104
# Name: 8989, dtype: float64
# mi              16.000000
# avg_price    35927.798222
# Name: 8990, dtype: float64
# mi              16.000000
# avg_price    35899.506282
# Name: 8991, dtype: float64
# mi              16.000000
# avg_price    35968.860522
# Name: 8992, dtype: float64
# mi              16.000000
# avg_price    36076.470914
# Name: 8993, dtype: float64
# mi              16.000000
# avg_price    35940.207593
# Name: 8994, dtype: float64
# mi              16.000000
# avg_price    36032.321486
# Name: 8995, dtype: float64
# mi              16.000000
# avg_price    36045.910103
# Name: 8996, dtype: float64
# mi              16.000000
# avg_price    36031.516968
# Name: 8997, dtype: float64
# mi              16.000000
# avg_price    36034.129038
# Name: 8998, dtype: float64
# mi              16.000000
# avg_price    36120.641462
# Name: 8999, dtype: float64
#              mi  absolute error avg_price  relative error avg_price
# 0      0.001248                164.735653                  0.457572
# 1      0.001248               2601.293451                  7.225389
# 2      0.001248               1643.056304                  4.563776
# 3      0.001248                180.450028                  0.501221
# 4      0.001248                376.139004                  1.044769
# ...         ...                       ...                       ...
# 8995  16.000000                 30.197657                  0.083877
# 8996  16.000000                 43.786274                  0.121621
# 8997  16.000000                 29.393139                  0.081643
# 8998  16.000000                 32.005209                  0.088898
# 8999  16.000000                118.517633                  0.329196
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 avg_price mean  avg_price var
# type factor
# pac  0.001248     35975.045603   1.390380e+06
#      0.015625     36017.257937   1.126235e+05
#      0.031250     35993.924356   5.624310e+04
#      0.062500     36002.612626   3.035626e+04
#      0.250000     35999.298043   1.013133e+04
#      1.000000     36003.329262   4.730685e+03
#      2.000000     36002.588833   3.982054e+03
#      4.000000     36005.638913   3.688047e+03
#      16.000000    36000.641502   3.455145e+03

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error avg_price mean  absolute error avg_price var  \
# type factor
# pac  0.001248                      953.042331                 481914.594147
#      0.015625                      269.990885                  39884.738693
#      0.031250                      188.831757                  20617.277565
#      0.062500                      137.781551                  11353.743584
#      0.250000                       81.329013                   3518.297217
#      1.000000                       53.876647                   1826.540437
#      2.000000                       50.092536                   1470.496616
#      4.000000                       48.833558                   1313.311309
#      16.000000                      47.204226                   1226.875211
#
#                 relative error avg_price mean  relative error avg_price var
# type factor
# pac  0.001248                        2.647184                      3.718038
#      0.015625                        0.749930                      0.307716
#      0.031250                        0.524502                      0.159065
#      0.062500                        0.382704                      0.087596
#      0.250000                        0.225901                      0.027144
#      1.000000                        0.149649                      0.014092
#      2.000000                        0.139138                      0.011345
#      4.000000                        0.135641                      0.010132
#      16.000000                       0.131115                      0.009466

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#               avg_price
# mi
# 0.001248   1.390380e+06
# 0.015625   1.126235e+05
# 0.031250   5.624310e+04
# 0.062500   3.035626e+04
# 0.250000   1.013133e+04
# 1.000000   4.730685e+03
# 2.000000   3.982054e+03
# 4.000000   3.688047e+03
# 16.000000  3.455145e+03

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step              scale
# query         avg_price
# mi
# 0.001248   1.324962e+06
# 0.015625   1.058544e+05
# 0.031250   5.292718e+04
# 0.062500   2.646359e+04
# 0.250000   6.615897e+03
# 1.000000   1.653974e+03
# 2.000000   8.269871e+02
# 4.000000   4.134936e+02
# 16.000000  1.033734e+02

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# avg_price    0.127536
# dtype: float64
#            avg_price
# mi
# 0.001248    0.128612
# 0.015625    0.124318
# 0.031250    0.123860
# 0.062500    0.129282
# 0.250000    0.133103
# 1.000000    0.125767
# 2.000000    0.124279
# 4.000000    0.129628
# 16.000000   0.128977

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72008/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query             avg_price
# mi
# 0.001248         953.140114
# 0.015625         265.168350
# 0.031250         181.293838
# 0.062500         130.148845
# 0.250000          63.799421
# 1.000000          33.878071
# 2.000000          22.426203
# 4.000000          16.074188
# 16.000000          7.968651

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72008/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72008/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query         avg_price
# mi
# 0.001248   36002.221758
# 0.015625   36002.319479
# 0.031250   36003.725102
# 0.062500   36002.151130
# 0.250000   36001.982567
# 1.000000   36005.649739
# 2.000000   36001.173011
# 4.000000   36004.323258
# 16.000000  36000.607363
# step   chosen_sample
# query      avg_price
# all mi  36002.683712

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_72008/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#            avg_price
# mi
# 0.001248    2.647184
# 0.015625    0.749930
# 0.031250    0.524502
# 0.062500    0.382704
# 0.250000    0.225901
# 1.000000    0.149649
# 2.000000    0.139138
# 4.000000    0.135641
# 16.000000   0.131115

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#            avg_price
# mi
# 0.001248    2.518572
# 0.015625    0.625613
# 0.031250    0.400642
# 0.062500    0.253422
# 0.250000    0.092797
# 1.000000    0.023882
# 2.000000    0.014859
# 4.000000    0.006013
# 16.000000   0.002138

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()
