# %% [markdown]
# # Modified TPC-H Q1 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#   -- sum(l_quantity) as sum_qty,
#   -- sum(l_extendedprice) as sum_base_price,
#   -- sum(l_extendedprice * (1 - l_discount)) as sum_disc_price,
#   -- sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge,
#   -- avg(l_quantity) as avg_qty,
#   -- avg(l_extendedprice) as avg_price,
#   -- avg(l_discount) as avg_disc,
#   count(*) as count_order
# from
#   lineitem
# where
#   l_shipdate <= '1998-09-02'
#   and l_returnflag = 'N'
#   and l_linestatus = 'O'
# ```

# %%
EXPERIMENT = 'pac-q1-count-order-N-O'
OUTPUT_DIR = f'../outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
### Data Setup
#por_df = pq.read_table(f"./data/student_performance/student-por.parquet").to_pandas()
lineitem_df = pd.read_parquet('../data/tpch/lineitem.parquet')

lineitem_df.shape
# Out:
# (600572, 16)

# %%
type(lineitem_df['l_linestatus'][0])
# Out:
# str

# %%
def runquery(lineitem_df: DataFrame) -> int:
    # 1. Filter lineitem rows where commit date is before receipt date.
    lineitem_filtered = lineitem_df[
        (lineitem_df['l_shipdate'] <= date(1998, 9, 2)) &
        (lineitem_df['l_returnflag'] == 'N') &
        (lineitem_df['l_linestatus'] == 'O')
    ]
    print(lineitem_filtered.shape)

    # 2. Pre-compute
    discounted_price = lineitem_filtered['l_extendedprice'] * (1 - lineitem_filtered['l_discount'])
    charged_price = discounted_price * (1 + lineitem_filtered['l_tax'])

    # 3. Get aggregations
    aggregated_result = [
        # float(lineitem_filtered['l_quantity'].sum()),       # sum_qty
        # float(lineitem_filtered['l_extendedprice'].sum()),  # sum_base_price
        # float(discounted_price.sum()),                      # sum_disc_price
        # float(charged_price.sum()),                         # sum_charge
        # float(lineitem_filtered['l_quantity'].mean()),      # avg_qty
        # float(lineitem_filtered['l_extendedprice'].mean()), # avg_price
        # float(lineitem_filtered['l_discount'].mean()),      # avg_disc
        float(len(lineitem_filtered))                       # count_order (faster than .count())
    ]


    # result = aggregated_result.to_numpy()
    print(aggregated_result)

    return aggregated_result
runquery(lineitem_df)
# Out:
# (292000, 16)
# [292000.0]
# [292000.0]

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

# TODO: how do we modify for multiple columns
OUTPUT_COLS = ['count_order']
# INPUT_COLS = ['count']

true_result = np.array(runquery(lineitem_df)) # Save the true result of the query for later
#true_result = np.divide(true_result, 2) # manually correct count = count * 2

# TODO: What will this be?
number_of_contributing_rows = 147790  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        print(f'iteration : {i}')
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np
# Out:
# (292000, 16)
# [292000.0]

# %%
#s = generate_samples()
#s

#pd.DataFrame(s, columns=INPUT_COLS).hist("count")
#pd.DataFrame(s, columns=INPUT_COLS).hist("sum")
#pd.DataFrame(s, columns=INPUT_COLS).hist("mean")

# %%
# compute variance of pd.DataFrame(s, columns=INPUT_COLS)['sum']
#np.var(pd.DataFrame(s, columns=INPUT_COLS)['count'])

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
# TODO: Change it back to 1000
EXPERIMENTS = 1000

if GENERATE:
    # df = pd.DataFrame([], columns=['mi', 'count', 'sum', 'mean', 'var'])
    experiment_results = []
    saved_steps = []

    out_np = generate_samples() # generate samples (results of running the query)
    print(f"Generate samples... {len(out_np)} samples generated.")

    # print(out_np[0])

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# iteration : 0
# (145946, 16)
# [145946.0]
# (146054, 16)
# [146054.0]
# iteration : 1
# (145662, 16)
# [145662.0]
# (146338, 16)
# [146338.0]
# iteration : 2
# (145933, 16)
# [145933.0]
# (146067, 16)
# [146067.0]
# iteration : 3
# (146375, 16)
# [146375.0]
# (145625, 16)
# [145625.0]
# iteration : 4
# (145906, 16)
# [145906.0]
# (146094, 16)
# [146094.0]
# iteration : 5
# (146318, 16)
# [146318.0]
# (145682, 16)
# [145682.0]
# iteration : 6
# (146074, 16)
# [146074.0]
# (145926, 16)
# [145926.0]
# iteration : 7
# (145876, 16)
# [145876.0]
# (146124, 16)
# [146124.0]
# iteration : 8
# (145754, 16)
# [145754.0]
# (146246, 16)
# [146246.0]
# iteration : 9
# (145902, 16)
# [145902.0]
# (146098, 16)
# [146098.0]
# iteration : 10
# (146132, 16)
# [146132.0]
# (145868, 16)
# [145868.0]
# iteration : 11
# (145665, 16)
# [145665.0]
# (146335, 16)
# [146335.0]
# iteration : 12
# (146382, 16)
# [146382.0]
# (145618, 16)
# [145618.0]
# iteration : 13
# (146033, 16)
# [146033.0]
# (145967, 16)
# [145967.0]
# iteration : 14
# (146204, 16)
# [146204.0]
# (145796, 16)
# [145796.0]
# iteration : 15
# (146092, 16)
# [146092.0]
# (145908, 16)
# [145908.0]
# iteration : 16
# (145710, 16)
# [145710.0]
# (146290, 16)
# [146290.0]
# iteration : 17
# (145991, 16)
# [145991.0]
# (146009, 16)
# [146009.0]
# iteration : 18
# (146723, 16)
# [146723.0]
# (145277, 16)
# Chosen Sample [291784.]
# Chosen Sample [292340.]
# Chosen Sample [292762.]
# Chosen Sample [291390.]
# Chosen Sample [291962.]
# Chosen Sample [292832.]
# Chosen Sample [291066.]
# Chosen Sample [292674.]
# Chosen Sample [292088.]
# Chosen Sample [292392.]
# Chosen Sample [291826.]
# Chosen Sample [292598.]
# Chosen Sample [291266.]
# Chosen Sample [292398.]
# Chosen Sample [290646.]
# Chosen Sample [292028.]
# Chosen Sample [291714.]
# Chosen Sample [292098.]
# Chosen Sample [291554.]
# Chosen Sample [291904.]
# Chosen Sample [292158.]
# Chosen Sample [291970.]
# Chosen Sample [290862.]
# Chosen Sample [291740.]
# Chosen Sample [291508.]
# Chosen Sample [291260.]
# Chosen Sample [292642.]
# Chosen Sample [291562.]
# Chosen Sample [291182.]
# Chosen Sample [291482.]
# Chosen Sample [291552.]
# Chosen Sample [292186.]
# Chosen Sample [291180.]
# Chosen Sample [292040.]
# Chosen Sample [291376.]
# Chosen Sample [292588.]
# Chosen Sample [291364.]
# Chosen Sample [292960.]
# Chosen Sample [292164.]
# Chosen Sample [291490.]
# Chosen Sample [291862.]
# Chosen Sample [291526.]
# Chosen Sample [291768.]
# Chosen Sample [291956.]
# Chosen Sample [292046.]
# Chosen Sample [291998.]
# Chosen Sample [291882.]
# Chosen Sample [292810.]
# Chosen Sample [291750.]
# Chosen Sample [292156.]
# Chosen Sample [291390.]
# Chosen Sample [292496.]
# Chosen Sample [291594.]
# Chosen Sample [291840.]
# Chosen Sample [291092.]
# Chosen Sample [291836.]
# Chosen Sample [291794.]
# Chosen Sample [292692.]
# Chosen Sample [292128.]
# Chosen Sample [292156.]
# Chosen Sample [292478.]
# Chosen Sample [290560.]
# Chosen Sample [292134.]
# Chosen Sample [292086.]
# Chosen Sample [291900.]
# Chosen Sample [292220.]
# Chosen Sample [291940.]
# Chosen Sample [292330.]
# Chosen Sample [291912.]
# Chosen Sample [292122.]
# Chosen Sample [292296.]
# Chosen Sample [291880.]
# Chosen Sample [291418.]
# Chosen Sample [292084.]
# Chosen Sample [292918.]
# Chosen Sample [291362.]
# Chosen Sample [292190.]
# Chosen Sample [291636.]
# Chosen Sample [291314.]
# Chosen Sample [292192.]
# Chosen Sample [290862.]
# Chosen Sample [292240.]
# Chosen Sample [291992.]
# Chosen Sample [292254.]
# Chosen Sample [291590.]
# Chosen Sample [292112.]
# Chosen Sample [292238.]
# Chosen Sample [291402.]
# Chosen Sample [292504.]
# Chosen Sample [292116.]
# Chosen Sample [291676.]
# Chosen Sample [292516.]
# Chosen Sample [291750.]
# Chosen Sample [292686.]
# Chosen Sample [291792.]
# Chosen Sample [291564.]
# Chosen Sample [291470.]
# Chosen Sample [292880.]
# Chosen Sample [292446.]
# Chosen Sample [291386.]
# Chosen Sample [292154.]
# Chosen Sample [293244.]
# Chosen Sample [291692.]
# Chosen Sample [292198.]
# Chosen Sample [292454.]
# Chosen Sample [292656.]
# Chosen Sample [291846.]
# Chosen Sample [291854.]
# Chosen Sample [291394.]
# Chosen Sample [291234.]
# Chosen Sample [292912.]
# Chosen Sample [291740.]
# Chosen Sample [291854.]
# Chosen Sample [290986.]
# Chosen Sample [292074.]
# Chosen Sample [291796.]
# Chosen Sample [291480.]
# Chosen Sample [292750.]
# Chosen Sample [291860.]
# Chosen Sample [291666.]
# Chosen Sample [291594.]
# Chosen Sample [292390.]
# Chosen Sample [292218.]
# Chosen Sample [292462.]
# Chosen Sample [291850.]
# Chosen Sample [292188.]
# Chosen Sample [292406.]
# Chosen Sample [292592.]
# Chosen Sample [290894.]
# Chosen Sample [292980.]
# Chosen Sample [292402.]
# Chosen Sample [292574.]
# Chosen Sample [291660.]
# Chosen Sample [292676.]
# Chosen Sample [293240.]
# Chosen Sample [292062.]
# Chosen Sample [292496.]
# Chosen Sample [291564.]
# Chosen Sample [291894.]
# Chosen Sample [291454.]
# Chosen Sample [292244.]
# Chosen Sample [292008.]
# Chosen Sample [291830.]
# Chosen Sample [291768.]
# Chosen Sample [292802.]
# Chosen Sample [291870.]
# Chosen Sample [291680.]
# Chosen Sample [292626.]
# Chosen Sample [292740.]
# Chosen Sample [292028.]
# Chosen Sample [292536.]
# Chosen Sample [291508.]
# Chosen Sample [291500.]
# Chosen Sample [292970.]
# Chosen Sample [291894.]
# Chosen Sample [290840.]
# Chosen Sample [291330.]
# Chosen Sample [291556.]
# Chosen Sample [292938.]
# Chosen Sample [291808.]
# Chosen Sample [291694.]
# Chosen Sample [292506.]
# Chosen Sample [292574.]
# Chosen Sample [291952.]
# Chosen Sample [292492.]
# Chosen Sample [290950.]
# Chosen Sample [292286.]
# Chosen Sample [292032.]
# Chosen Sample [293716.]
# Chosen Sample [291684.]
# Chosen Sample [291036.]
# Chosen Sample [292662.]
# Chosen Sample [292070.]
# Chosen Sample [292910.]
# Chosen Sample [292162.]
# Chosen Sample [291924.]
# Chosen Sample [291936.]
# Chosen Sample [291922.]
# Chosen Sample [291476.]
# Chosen Sample [292340.]
# Chosen Sample [292710.]
# Chosen Sample [292548.]
# Chosen Sample [292074.]
# Chosen Sample [292084.]
# Chosen Sample [291934.]
# Chosen Sample [291584.]
# Chosen Sample [292900.]
# Chosen Sample [291946.]
# Chosen Sample [292080.]
# Chosen Sample [292092.]
# Chosen Sample [293772.]
# Chosen Sample [292764.]
# Chosen Sample [292934.]
# Chosen Sample [291730.]
# Chosen Sample [291240.]
# Chosen Sample [291674.]
# Chosen Sample [291586.]
# Chosen Sample [292526.]
# Chosen Sample [292054.]
# Chosen Sample [291678.]
# Chosen Sample [291574.]
# Chosen Sample [292456.]
# Chosen Sample [291074.]
# Chosen Sample [292074.]
# Chosen Sample [292608.]
# Chosen Sample [292794.]
# Chosen Sample [291910.]
# Chosen Sample [292476.]
# Chosen Sample [292324.]
# Chosen Sample [292196.]
# Chosen Sample [292846.]
# Chosen Sample [292628.]
# Chosen Sample [291724.]
# Chosen Sample [292062.]
# Chosen Sample [291644.]
# Chosen Sample [292292.]
# Chosen Sample [292056.]
# Chosen Sample [292592.]
# Chosen Sample [292006.]
# Chosen Sample [291160.]
# Chosen Sample [292066.]
# Chosen Sample [291272.]
# Chosen Sample [290968.]
# Chosen Sample [292182.]
# Chosen Sample [291182.]
# Chosen Sample [290870.]
# Chosen Sample [293028.]
# Chosen Sample [291318.]
# Chosen Sample [291656.]
# Chosen Sample [292232.]
# Chosen Sample [292144.]
# Chosen Sample [291206.]
# Chosen Sample [292032.]
# Chosen Sample [292594.]
# Chosen Sample [290832.]
# Chosen Sample [291116.]
# Chosen Sample [291034.]
# Chosen Sample [292860.]
# Chosen Sample [293268.]
# Chosen Sample [292834.]
# Chosen Sample [291384.]
# Chosen Sample [292116.]
# Chosen Sample [291700.]
# Chosen Sample [291178.]
# Chosen Sample [291844.]
# Chosen Sample [291826.]
# Chosen Sample [291492.]
# Chosen Sample [291512.]
# Chosen Sample [291940.]
# Chosen Sample [290228.]
# Chosen Sample [291844.]
# Chosen Sample [292052.]
# Chosen Sample [291628.]
# Chosen Sample [292528.]
# Chosen Sample [292728.]
# Chosen Sample [291668.]
# Chosen Sample [291946.]
# Chosen Sample [291946.]
# Chosen Sample [291402.]
# Chosen Sample [292710.]
# Chosen Sample [291266.]
# Chosen Sample [292726.]
# Chosen Sample [291386.]
# Chosen Sample [292936.]
# Chosen Sample [292274.]
# Chosen Sample [292174.]
# Chosen Sample [291742.]
# Chosen Sample [292504.]
# Chosen Sample [292500.]
# Chosen Sample [292538.]
# Chosen Sample [290764.]
# Chosen Sample [291666.]
# Chosen Sample [292184.]
# Chosen Sample [292134.]
# Chosen Sample [292316.]
# Chosen Sample [292144.]
# Chosen Sample [293130.]
# Chosen Sample [291716.]
# Chosen Sample [292534.]
# Chosen Sample [291968.]
# Chosen Sample [292144.]
# Chosen Sample [291304.]
# Chosen Sample [291716.]
# Chosen Sample [291104.]
# Chosen Sample [292484.]
# Chosen Sample [290984.]
# Chosen Sample [291478.]
# Chosen Sample [291818.]
# Chosen Sample [293016.]
# Chosen Sample [292424.]
# Chosen Sample [291636.]
# Chosen Sample [291372.]
# Chosen Sample [292202.]
# Chosen Sample [291742.]
# Chosen Sample [291594.]
# Chosen Sample [291872.]
# Chosen Sample [291066.]
# Chosen Sample [291362.]
# Chosen Sample [291668.]
# Chosen Sample [291974.]
# Chosen Sample [291090.]
# Chosen Sample [292156.]
# Chosen Sample [291544.]
# Chosen Sample [292468.]
# Chosen Sample [291854.]
# Chosen Sample [292350.]
# Chosen Sample [292716.]
# Chosen Sample [292256.]
# Chosen Sample [291608.]
# Chosen Sample [291544.]
# Chosen Sample [292472.]
# Chosen Sample [291814.]
# Chosen Sample [293350.]
# Chosen Sample [291894.]
# Chosen Sample [292216.]
# Chosen Sample [291510.]
# Chosen Sample [292786.]
# Chosen Sample [291606.]
# Chosen Sample [292390.]
# Chosen Sample [292000.]
# Chosen Sample [292166.]
# Chosen Sample [291754.]
# Chosen Sample [292390.]
# Chosen Sample [292210.]
# Chosen Sample [292196.]
# Chosen Sample [292578.]
# Chosen Sample [292178.]
# Chosen Sample [292166.]
# Chosen Sample [292552.]
# Chosen Sample [292310.]
# Chosen Sample [291226.]
# Chosen Sample [292774.]
# Chosen Sample [292308.]
# Chosen Sample [291878.]
# Chosen Sample [292832.]
# Chosen Sample [292416.]
# Chosen Sample [291908.]
# Chosen Sample [291178.]
# Chosen Sample [292422.]
# Chosen Sample [292332.]
# Chosen Sample [292992.]
# Chosen Sample [291040.]
# Chosen Sample [292174.]
# Chosen Sample [292024.]
# Chosen Sample [292224.]
# Chosen Sample [292358.]
# Chosen Sample [292742.]
# Chosen Sample [291002.]
# Chosen Sample [292078.]
# Chosen Sample [291236.]
# Chosen Sample [291708.]
# Chosen Sample [291034.]
# Chosen Sample [291410.]
# Chosen Sample [291540.]
# Chosen Sample [292090.]
# Chosen Sample [292082.]
# Chosen Sample [292860.]
# Chosen Sample [292956.]
# Chosen Sample [292786.]
# Chosen Sample [292628.]
# Chosen Sample [291082.]
# Chosen Sample [291124.]
# Chosen Sample [291046.]
# Chosen Sample [292620.]
# Chosen Sample [292024.]
# Chosen Sample [291990.]
# Chosen Sample [292200.]
# Chosen Sample [292364.]
# Chosen Sample [292380.]
# Chosen Sample [292436.]
# Chosen Sample [292478.]
# Chosen Sample [292186.]
# Chosen Sample [291982.]
# Chosen Sample [291636.]
# Chosen Sample [292546.]
# Chosen Sample [292216.]
# Chosen Sample [292598.]
# Chosen Sample [291444.]
# Chosen Sample [291260.]
# Chosen Sample [291762.]
# Chosen Sample [292518.]
# Chosen Sample [291592.]
# Chosen Sample [292714.]
# Chosen Sample [292000.]
# Chosen Sample [291308.]
# Chosen Sample [291682.]
# Chosen Sample [291260.]
# Chosen Sample [292086.]
# Chosen Sample [291374.]
# Chosen Sample [291258.]
# Chosen Sample [292894.]
# Chosen Sample [290728.]
# Chosen Sample [291770.]
# Chosen Sample [292376.]
# Chosen Sample [291298.]
# Chosen Sample [291686.]
# Chosen Sample [291852.]
# Chosen Sample [291266.]
# Chosen Sample [291482.]
# Chosen Sample [291682.]
# Chosen Sample [292144.]
# Chosen Sample [292390.]
# Chosen Sample [291588.]
# Chosen Sample [291774.]
# Chosen Sample [291038.]
# Chosen Sample [291902.]
# Chosen Sample [291438.]
# Chosen Sample [292466.]
# Chosen Sample [291132.]
# Chosen Sample [292292.]
# Chosen Sample [292218.]
# Chosen Sample [292190.]
# Chosen Sample [291666.]
# Chosen Sample [292054.]
# Chosen Sample [292060.]
# Chosen Sample [292122.]
# Chosen Sample [293018.]
# Chosen Sample [292788.]
# Chosen Sample [292540.]
# Chosen Sample [291358.]
# Chosen Sample [292074.]
# Chosen Sample [291812.]
# Chosen Sample [291882.]
# Chosen Sample [290992.]
# Chosen Sample [292822.]
# Chosen Sample [292470.]
# Chosen Sample [292188.]
# Chosen Sample [292376.]
# Chosen Sample [292444.]
# Chosen Sample [291640.]
# Chosen Sample [293066.]
# Chosen Sample [291480.]
# Chosen Sample [293004.]
# Chosen Sample [292008.]
# Chosen Sample [291738.]
# Chosen Sample [292662.]
# Chosen Sample [292234.]
# Chosen Sample [292736.]
# Chosen Sample [292412.]
# Chosen Sample [292298.]
# Chosen Sample [292676.]
# Chosen Sample [291974.]
# Chosen Sample [292956.]
# Chosen Sample [292296.]
# Chosen Sample [291450.]
# Chosen Sample [292488.]
# Chosen Sample [291594.]
# Chosen Sample [291796.]
# Chosen Sample [292472.]
# Chosen Sample [291244.]
# Chosen Sample [292516.]
# Chosen Sample [292368.]
# Chosen Sample [290832.]
# Chosen Sample [292102.]
# Chosen Sample [292270.]
# Chosen Sample [292036.]
# Chosen Sample [291622.]
# Chosen Sample [292198.]
# Chosen Sample [292506.]
# Chosen Sample [291730.]
# Chosen Sample [291140.]
# Chosen Sample [292012.]
# Chosen Sample [291120.]
# Chosen Sample [292532.]
# Chosen Sample [292300.]
# Chosen Sample [291814.]
# Chosen Sample [291914.]
# Chosen Sample [291252.]
# Chosen Sample [291792.]
# Chosen Sample [292578.]
# Chosen Sample [292682.]
# Chosen Sample [291770.]
# Chosen Sample [290934.]
# Chosen Sample [291730.]
# Chosen Sample [291888.]
# Chosen Sample [292324.]
# Chosen Sample [291324.]
# Chosen Sample [292602.]
# Chosen Sample [290660.]
# Chosen Sample [291886.]
# Chosen Sample [292178.]
# Chosen Sample [291556.]
# Chosen Sample [292284.]
# Chosen Sample [292294.]
# Chosen Sample [291744.]
# Chosen Sample [291822.]
# Chosen Sample [291784.]
# Chosen Sample [291780.]
# Chosen Sample [292290.]
# Chosen Sample [292912.]
# Chosen Sample [291674.]
# Chosen Sample [292326.]
# Chosen Sample [291986.]
# Chosen Sample [291938.]
# Chosen Sample [292524.]
# Chosen Sample [291410.]
# Chosen Sample [292098.]
# Chosen Sample [291818.]
# Chosen Sample [291796.]
# Chosen Sample [292134.]
# Chosen Sample [293248.]
# Chosen Sample [291660.]
# Chosen Sample [291166.]
# Chosen Sample [291540.]
# Chosen Sample [291952.]
# Chosen Sample [292352.]
# Chosen Sample [291538.]
# Chosen Sample [292570.]
# Chosen Sample [292906.]
# Chosen Sample [292674.]
# Chosen Sample [291160.]
# Chosen Sample [292522.]
# Chosen Sample [291250.]
# Chosen Sample [291826.]
# Chosen Sample [292734.]
# Chosen Sample [291100.]
# Chosen Sample [292072.]
# Chosen Sample [291756.]
# Chosen Sample [292726.]
# Chosen Sample [291850.]
# Chosen Sample [291982.]
# Chosen Sample [292824.]
# Chosen Sample [293332.]
# Chosen Sample [293224.]
# Chosen Sample [291964.]
# Chosen Sample [292164.]
# Chosen Sample [291508.]
# Chosen Sample [291226.]
# Chosen Sample [291420.]
# Chosen Sample [292646.]
# Chosen Sample [292022.]
# Chosen Sample [292512.]
# Chosen Sample [292962.]
# Chosen Sample [292710.]
# Chosen Sample [293170.]
# Chosen Sample [290914.]
# Chosen Sample [292198.]
# Chosen Sample [291464.]
# Chosen Sample [290766.]
# Chosen Sample [292084.]
# Chosen Sample [291972.]
# Chosen Sample [291250.]
# Chosen Sample [292296.]
# Chosen Sample [292588.]
# Chosen Sample [291632.]
# Chosen Sample [291992.]
# Chosen Sample [291752.]
# Chosen Sample [291212.]
# Chosen Sample [292082.]
# Chosen Sample [292006.]
# Chosen Sample [291340.]
# Chosen Sample [292436.]
# Chosen Sample [291316.]
# Chosen Sample [292500.]
# Chosen Sample [291316.]
# Chosen Sample [292202.]
# Chosen Sample [292180.]
# Chosen Sample [291496.]
# Chosen Sample [292078.]
# Chosen Sample [291770.]
# Chosen Sample [291108.]
# Chosen Sample [292554.]
# Chosen Sample [292966.]
# Chosen Sample [292014.]
# Chosen Sample [292000.]
# Chosen Sample [291460.]
# Chosen Sample [292176.]
# Chosen Sample [291692.]
# Chosen Sample [291732.]
# Chosen Sample [291184.]
# Chosen Sample [292180.]
# Chosen Sample [292562.]
# Chosen Sample [292606.]
# Chosen Sample [291852.]
# Chosen Sample [290916.]
# Chosen Sample [291920.]
# Chosen Sample [292164.]
# Chosen Sample [292508.]
# Chosen Sample [292444.]
# Chosen Sample [292038.]
# Chosen Sample [291774.]
# Chosen Sample [292716.]
# Chosen Sample [292850.]
# Chosen Sample [292312.]
# Chosen Sample [292152.]
# Chosen Sample [291982.]
# Chosen Sample [291950.]
# Chosen Sample [292416.]
# Chosen Sample [292300.]
# Chosen Sample [291760.]
# Chosen Sample [291574.]
# Chosen Sample [291292.]
# Chosen Sample [291816.]
# Chosen Sample [292154.]
# Chosen Sample [292646.]
# Chosen Sample [291634.]
# Chosen Sample [292742.]
# Chosen Sample [291876.]
# Chosen Sample [292028.]
# Chosen Sample [292378.]
# Chosen Sample [292302.]
# Chosen Sample [292078.]
# Chosen Sample [291720.]
# Chosen Sample [291696.]
# Chosen Sample [292216.]
# Chosen Sample [292858.]
# Chosen Sample [292716.]
# Chosen Sample [291458.]
# Chosen Sample [292094.]
# Chosen Sample [291380.]
# Chosen Sample [291592.]
# Chosen Sample [292104.]
# Chosen Sample [292376.]
# Chosen Sample [290918.]
# Chosen Sample [291578.]
# Chosen Sample [291714.]
# Chosen Sample [291830.]
# Chosen Sample [292364.]
# Chosen Sample [290862.]
# Chosen Sample [292078.]
# Chosen Sample [292320.]
# Chosen Sample [291140.]
# Chosen Sample [293258.]
# Chosen Sample [292440.]
# Chosen Sample [291718.]
# Chosen Sample [291892.]
# Chosen Sample [291906.]
# Chosen Sample [291836.]
# Chosen Sample [291722.]
# Chosen Sample [291910.]
# Chosen Sample [291446.]
# Chosen Sample [291148.]
# Chosen Sample [291268.]
# Chosen Sample [291676.]
# Chosen Sample [292046.]
# Chosen Sample [291984.]
# Chosen Sample [292254.]
# Chosen Sample [291976.]
# Chosen Sample [291494.]
# Chosen Sample [292422.]
# Chosen Sample [291420.]
# Chosen Sample [291780.]
# Chosen Sample [290744.]
# Chosen Sample [292640.]
# Chosen Sample [291946.]
# Chosen Sample [291270.]
# Chosen Sample [292042.]
# Chosen Sample [292516.]
# Chosen Sample [291540.]
# Chosen Sample [292186.]
# Chosen Sample [292262.]
# Chosen Sample [291968.]
# Chosen Sample [292134.]
# Chosen Sample [292020.]
# Chosen Sample [292230.]
# Chosen Sample [292470.]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                 scale chosen_sample           chosen_noise  \
# 0  0.001248  [118608245.22826938]    [292090.0]   [-17525.19270069361]
# 1  0.001248  [118608245.22826938]    [291942.0]  [-11062.132228173818]
# 2  0.001248  [118608245.22826938]    [292534.0]    [14596.28902760519]
# 3  0.001248  [118608245.22826938]    [292044.0]   [-987.4393963907302]
# 4  0.001248  [118608245.22826938]    [291960.0]  [-16032.625894038287]
#
#                 release
# 0   [274564.8072993064]
# 1  [280879.86777182616]
# 2   [307130.2890276052]
# 3  [291056.56060360925]
# 4   [275927.3741059617]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi         scale chosen_sample  chosen_noise        release
# query             count_order   count_order   count_order    count_order
# 0      0.001248  1.186082e+08      292090.0 -17525.192701  274564.807299
# 1      0.001248  1.186082e+08      291942.0 -11062.132228  280879.867772
# 2      0.001248  1.186082e+08      292534.0  14596.289028  307130.289028
# 3      0.001248  1.186082e+08      292044.0   -987.439396  291056.560604
# 4      0.001248  1.186082e+08      291960.0 -16032.625894  275927.374106

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33351/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step              scale chosen_sample chosen_noise        release
# query       count_order   count_order  count_order    count_order
# mi
# 0.001248   1.186082e+08    292009.936    72.053733  292081.989733
# 0.015625   9.475896e+06    292000.970   -43.749426  291957.220574
# 0.031250   4.737948e+06    291975.846    63.309421  292039.155421
# 0.062500   2.368974e+06    292034.284     5.417276  292039.701276
# 0.250000   5.922435e+05    292013.368    16.174299  292029.542299
# 1.000000   1.480609e+05    291972.926     1.210841  291974.136841
# 2.000000   7.403044e+04    292034.372    -3.325419  292031.046581
# 4.000000   3.701522e+04    291972.418    10.924904  291983.342904
# 16.000000  9.253805e+03    291992.910     4.600261  291997.510261

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['count_order'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi                  0.001248
# count_order    274564.807299
# Name: 0, dtype: float64
# mi                  0.001248
# count_order    280879.867772
# Name: 1, dtype: float64
# mi                  0.001248
# count_order    307130.289028
# Name: 2, dtype: float64
# mi                  0.001248
# count_order    291056.560604
# Name: 3, dtype: float64
# mi                  0.001248
# count_order    275927.374106
# Name: 4, dtype: float64
# mi                  0.001248
# count_order    277204.189645
# Name: 5, dtype: float64
# mi                  0.001248
# count_order    289347.895505
# Name: 6, dtype: float64
# mi                  0.001248
# count_order    289767.902019
# Name: 7, dtype: float64
# mi                  0.001248
# count_order    303552.873431
# Name: 8, dtype: float64
# mi                  0.001248
# count_order    309490.080308
# Name: 9, dtype: float64
# mi                  0.001248
# count_order    278837.304301
# Name: 10, dtype: float64
# mi                  0.001248
# count_order    287083.017355
# Name: 11, dtype: float64
# mi                  0.001248
# count_order    302900.546051
# Name: 12, dtype: float64
# mi                  0.001248
# count_order    273774.783715
# Name: 13, dtype: float64
# mi                  0.001248
# count_order    284094.791365
# Name: 14, dtype: float64
# mi                  0.001248
# count_order    306269.982460
# Name: 15, dtype: float64
# mi                  0.001248
# count_order    290293.208590
# Name: 16, dtype: float64
# mi                  0.001248
# count_order    290698.245421
# Name: 17, dtype: float64
# mi                  0.001248
# count_order    290746.384939
# Name: 18, dtype: float64
# mi                  0.001248
# count_order    292570.518196
# Name: 19, dtype: float64
# mi                  0.001248
# count_order    299192.605104
# Name: 20, dtype: float64
# mi                  0.001248
# count_order    309040.235364
# Name: 21, dtype: float64
# mi                  0.001248
# count_order    269549.477501
# Name: 22, dtype: float64
# mi                  0.001248
# count_order    293622.953444
# Name: 23, dtype: float64
# mi                  0.001248
# count_order    294918.754344
# Name: 24, dtype: float64
# mi                  0.001248
# count_order    304075.368266
# Name: 25, dtype: float64
# mi                  0.001248
# count_order    292894.608625
# Name: 26, dtype: float64
# mi                  0.001248
# count_order    287029.956855
# Name: 27, dtype: float64
# mi                  0.001248
# count_order    280663.311200
# Name: 28, dtype: float64
# mi                  0.001248
# count_order    283131.933928
# Name: 29, dtype: float64
# mi                  0.001248
# count_order    293606.660488
# Name: 30, dtype: float64
# mi                  0.001248
# count_order    276169.925756
# Name: 31, dtype: float64
# mi                  0.001248
# count_order    318229.514500
# Name: 32, dtype: float64
# mi                  0.001248
# count_order    286925.536681
# Name: 33, dtype: float64
# mi                  0.001248
# count_order    268874.542767
# Name: 34, dtype: float64
# mi                  0.001248
# count_order    305425.690194
# Name: 35, dtype: float64
# mi                  0.001248
# count_order    297755.473446
# Name: 36, dtype: float64
# mi                  0.001248
# count_order    272863.473231
# Name: 37, dtype: float64
# mi                  0.001248
# count_order    299259.513644
# Name: 38, dtype: float64
# mi                  0.001248
# count_order    303275.149517
# Name: 39, dtype: float64
# mi                  0.001248
# count_order    313462.437103
# Name: 40, dtype: float64
# mi                  0.001248
# count_order    308733.646998
# Name: 41, dtype: float64
# mi                  0.001248
# count_order    312105.325786
# Name: 42, dtype: float64
# mi                  0.001248
# count_order    306185.363765
# Name: 43, dtype: float64
# mi                  0.001248
# count_order    275880.917499
# Name: 44, dtype: float64
# mi                  0.001248
# count_order    296419.582736
# Name: 45, dtype: float64
# mi                  0.001248
# count_order    283316.028094
# Name: 46, dtype: float64
# mi                  0.001248
# count_order    298179.456297
# Name: 47, dtype: float64
# mi                  0.001248
# count_order    289733.186244
# Name: 48, dtype: float64
# mi                  0.001248
# count_order    297007.528107
# Name: 49, dtype: float64
# mi                  0.001248
# count_order    309300.063994
# Name: 50, dtype: float64
# mi                  0.001248
# count_order    300945.031083
# Name: 51, dtype: float64
# mi                  0.001248
# count_order    318229.717750
# Name: 52, dtype: float64
# mi                  0.001248
# count_order    261556.001378
# Name: 53, dtype: float64
# mi                  0.001248
# count_order    273407.219693
# Name: 54, dtype: float64
# mi                  0.001248
# count_order    288525.146716
# Name: 55, dtype: float64
# mi                  0.001248
# count_order    317598.465233
# Name: 56, dtype: float64
# mi                  0.001248
# count_order    296413.948880
# Name: 57, dtype: float64
# mi                  0.001248
# count_order    284945.664117
# Name: 58, dtype: float64
# mi                  0.001248
# count_order    290512.589663
# Name: 59, dtype: float64
# mi                  0.001248
# count_order    297682.401744
# Name: 60, dtype: float64
# mi                  0.001248
# count_order    291343.050036
# Name: 61, dtype: float64
# mi                  0.001248
# count_order    283793.508175
# Name: 62, dtype: float64
# mi                  0.001248
# count_order    295854.432001
# Name: 63, dtype: float64
# mi                  0.001248
# count_order    308470.640581
# Name: 64, dtype: float64
# mi                  0.001248
# count_order    291981.020005
# Name: 65, dtype: float64
# mi                  0.001248
# count_order    288742.107365
# Name: 66, dtype: float64
# mi                  0.001248
# count_order    300616.807434
# Name: 67, dtype: float64
# mi                  0.001248
# count_order    305358.291969
# Name: 68, dtype: float64
# mi                  0.001248
# count_order    299867.250334
# Name: 69, dtype: float64
# mi                  0.001248
# count_order    279027.499554
# Name: 70, dtype: float64
# mi                  0.001248
# count_order    294896.398433
# Name: 71, dtype: float64
# mi                  0.001248
# count_order    289942.065974
# Name: 72, dtype: float64
# mi                  0.001248
# count_order    287201.490183
# Name: 73, dtype: float64
# mi                  0.001248
# count_order    302926.212860
# Name: 74, dtype: float64
# mi                  0.001248
# count_order    283143.552443
# Name: 75, dtype: float64
# mi                  0.001248
# count_order    287618.681388
# Name: 76, dtype: float64
# mi                  0.001248
# count_order    285221.836258
# Name: 77, dtype: float64
# mi                  0.001248
# count_order    263669.676562
# Name: 78, dtype: float64
# mi                  0.001248
# count_order    278941.556942
# Name: 79, dtype: float64
# mi                  0.001248
# count_order    280877.728582
# Name: 80, dtype: float64
# mi                  0.001248
# count_order    272544.739488
# Name: 81, dtype: float64
# mi                  0.001248
# count_order    275930.161626
# Name: 82, dtype: float64
# mi                  0.001248
# count_order    298042.591064
# Name: 83, dtype: float64
# mi                  0.001248
# count_order    290122.716825
# Name: 84, dtype: float64
# mi                  0.001248
# count_order    287012.470776
# Name: 85, dtype: float64
# mi                  0.001248
# count_order    293649.567254
# Name: 86, dtype: float64
# mi                  0.001248
# count_order    314862.702902
# Name: 87, dtype: float64
# mi                  0.001248
# count_order    297121.117712
# Name: 88, dtype: float64
# mi                  0.001248
# count_order    276971.189742
# Name: 89, dtype: float64
# mi                  0.001248
# count_order    298266.102264
# Name: 90, dtype: float64
# mi                  0.001248
# count_order    297234.841554
# Name: 91, dtype: float64
# mi                  0.001248
# count_order    297494.459336
# Name: 92, dtype: float64
# mi                  0.001248
# count_order    294984.823118
# Name: 93, dtype: float64
# mi                  0.001248
# count_order    303793.823216
# Name: 94, dtype: float64
# mi                  0.001248
# count_order    282434.319175
# Name: 95, dtype: float64
# mi                  0.001248
# count_order    288838.361477
# Name: 96, dtype: float64
# mi                  0.001248
# count_order    290533.692839
# Name: 97, dtype: float64
# mi                  0.001248
# count_order    283575.885849
# Name: 98, dtype: float64
# mi                  0.001248
# count_order    301932.744342
# Name: 99, dtype: float64
# mi                  0.001248
# count_order    299145.292496
# Name: 100, dtype: float64
# mi                  0.001248
# count_order    287892.654927
# Name: 101, dtype: float64
# mi                  0.001248
# count_order    300297.665919
# Name: 102, dtype: float64
# mi                  0.001248
# count_order    286021.778126
# Name: 103, dtype: float64
# mi                  0.001248
# count_order    277068.385407
# Name: 104, dtype: float64
# mi                  0.001248
# count_order    284532.159044
# Name: 105, dtype: float64
# mi                  0.001248
# count_order    279163.211769
# Name: 106, dtype: float64
# mi                  0.001248
# count_order    284499.606280
# Name: 107, dtype: float64
# mi                  0.001248
# count_order    277489.362219
# Name: 108, dtype: float64
# mi                  0.001248
# count_order    290931.726182
# Name: 109, dtype: float64
# mi                  0.001248
# count_order    290456.144711
# Name: 110, dtype: float64
# mi                  0.001248
# count_order    285573.147517
# Name: 111, dtype: float64
# mi                  0.001248
# count_order    282448.346711
# Name: 112, dtype: float64
# mi                  0.001248
# count_order    269708.466058
# Name: 113, dtype: float64
# mi                  0.001248
# count_order    296466.072880
# Name: 114, dtype: float64
# mi                  0.001248
# count_order    273246.016705
# Name: 115, dtype: float64
# mi                  0.001248
# count_order    290462.988727
# Name: 116, dtype: float64
# mi                  0.001248
# count_order    298420.234724
# Name: 117, dtype: float64
# mi                  0.001248
# count_order    305867.972017
# Name: 118, dtype: float64
# mi                  0.001248
# count_order    320527.216192
# Name: 119, dtype: float64
# mi                  0.001248
# count_order    296659.196998
# Name: 120, dtype: float64
# mi                  0.001248
# count_order    287255.387319
# Name: 121, dtype: float64
# mi                  0.001248
# count_order    305505.275352
# Name: 122, dtype: float64
# mi                  0.001248
# count_order    294918.349735
# Name: 123, dtype: float64
# mi                  0.001248
# count_order    292135.000643
# Name: 124, dtype: float64
# mi                  0.001248
# count_order    291271.703733
# Name: 125, dtype: float64
# mi                  0.001248
# count_order    315191.669546
# Name: 126, dtype: float64
# mi                  0.001248
# count_order    292217.229970
# Name: 127, dtype: float64
# mi                  0.001248
# count_order    286170.484839
# Name: 128, dtype: float64
# mi                  0.001248
# count_order    294773.877378
# Name: 129, dtype: float64
# mi                  0.001248
# count_order    308510.002451
# Name: 130, dtype: float64
# mi                  0.001248
# count_order    288209.779963
# Name: 131, dtype: float64
# mi                  0.001248
# count_order    313469.570378
# Name: 132, dtype: float64
# mi                  0.001248
# count_order    303808.238090
# Name: 133, dtype: float64
# mi                  0.001248
# count_order    279780.038935
# Name: 134, dtype: float64
# mi                  0.001248
# count_order    292399.269344
# Name: 135, dtype: float64
# mi                  0.001248
# count_order    293523.987857
# Name: 136, dtype: float64
# mi                  0.001248
# count_order    300065.468338
# Name: 137, dtype: float64
# mi                  0.001248
# count_order    297062.250695
# Name: 138, dtype: float64
# mi                  0.001248
# count_order    304634.174019
# Name: 139, dtype: float64
# mi                  0.001248
# count_order    285000.192304
# Name: 140, dtype: float64
# mi                  0.001248
# count_order    285279.981700
# Name: 141, dtype: float64
# mi                  0.001248
# count_order    290961.839319
# Name: 142, dtype: float64
# mi                  0.001248
# count_order    311688.845070
# Name: 143, dtype: float64
# mi                  0.001248
# count_order    304592.458976
# Name: 144, dtype: float64
# mi                  0.001248
# count_order    305779.808714
# Name: 145, dtype: float64
# mi                  0.001248
# count_order    279843.957132
# Name: 146, dtype: float64
# mi                  0.001248
# count_order    286489.859900
# Name: 147, dtype: float64
# mi                  0.001248
# count_order    306995.656625
# Name: 148, dtype: float64
# mi                  0.001248
# count_order    287943.814157
# Name: 149, dtype: float64
# mi                  0.001248
# count_order    287231.500366
# Name: 150, dtype: float64
# mi                  0.001248
# count_order    293072.295815
# Name: 151, dtype: float64
# mi                  0.001248
# count_order    279298.630944
# Name: 152, dtype: float64
# mi                  0.001248
# count_order    279158.826561
# Name: 153, dtype: float64
# mi                  0.001248
# count_order    312118.866287
# Name: 154, dtype: float64
# mi                  0.001248
# count_order    284711.791344
# Name: 155, dtype: float64
# mi                  0.001248
# count_order    296805.029829
# Name: 156, dtype: float64
# mi                  0.001248
# count_order    279874.028091
# Name: 157, dtype: float64
# mi                  0.001248
# count_order    289899.109417
# Name: 158, dtype: float64
# mi                  0.001248
# count_order    272487.361335
# Name: 159, dtype: float64
# mi                  0.001248
# count_order    289705.070062
# Name: 160, dtype: float64
# mi                  0.001248
# count_order    272159.168836
# Name: 161, dtype: float64
# mi                  0.001248
# count_order    300924.592453
# Name: 162, dtype: float64
# mi                  0.001248
# count_order    300103.608936
# Name: 163, dtype: float64
# mi                  0.001248
# count_order    298716.777303
# Name: 164, dtype: float64
# mi                  0.001248
# count_order    287455.039136
# Name: 165, dtype: float64
# mi                  0.001248
# count_order    300107.608331
# Name: 166, dtype: float64
# mi                  0.001248
# count_order    289769.264852
# Name: 167, dtype: float64
# mi                  0.001248
# count_order    306073.981711
# Name: 168, dtype: float64
# mi                  0.001248
# count_order    275949.314771
# Name: 169, dtype: float64
# mi                  0.001248
# count_order    302630.706142
# Name: 170, dtype: float64
# mi                  0.001248
# count_order    294851.955823
# Name: 171, dtype: float64
# mi                  0.001248
# count_order    278790.548311
# Name: 172, dtype: float64
# mi                  0.001248
# count_order    283384.131547
# Name: 173, dtype: float64
# mi                  0.001248
# count_order    286051.697175
# Name: 174, dtype: float64
# mi                  0.001248
# count_order    290793.925620
# Name: 175, dtype: float64
# mi                  0.001248
# count_order    300254.861526
# Name: 176, dtype: float64
# mi                  0.001248
# count_order    283060.947870
# Name: 177, dtype: float64
# mi                  0.001248
# count_order    301097.678508
# Name: 178, dtype: float64
# mi                  0.001248
# count_order    293105.475679
# Name: 179, dtype: float64
# mi                  0.001248
# count_order    290282.391461
# Name: 180, dtype: float64
# mi                  0.001248
# count_order    293942.866424
# Name: 181, dtype: float64
# mi                  0.001248
# count_order    305906.021027
# Name: 182, dtype: float64
# mi                  0.001248
# count_order    301424.189555
# Name: 183, dtype: float64
# mi                  0.001248
# count_order    300889.761102
# Name: 184, dtype: float64
# mi                  0.001248
# count_order    292432.075396
# Name: 185, dtype: float64
# mi                  0.001248
# count_order    294860.856277
# Name: 186, dtype: float64
# mi                  0.001248
# count_order    284509.997348
# Name: 187, dtype: float64
# mi                  0.001248
# count_order    287226.275688
# Name: 188, dtype: float64
# mi                  0.001248
# count_order    295478.253278
# Name: 189, dtype: float64
# mi                  0.001248
# count_order    310799.778397
# Name: 190, dtype: float64
# mi                  0.001248
# count_order    300608.495750
# Name: 191, dtype: float64
# mi                  0.001248
# count_order    288834.240393
# Name: 192, dtype: float64
# mi                  0.001248
# count_order    300631.563043
# Name: 193, dtype: float64
# mi                  0.001248
# count_order    294541.068479
# Name: 194, dtype: float64
# mi                  0.001248
# count_order    278607.301866
# Name: 195, dtype: float64
# mi                  0.001248
# count_order    312487.970452
# Name: 196, dtype: float64
# mi                  0.001248
# count_order    292577.665014
# Name: 197, dtype: float64
# mi                  0.001248
# count_order    294217.830325
# Name: 198, dtype: float64
# mi                  0.001248
# count_order    296371.090495
# Name: 199, dtype: float64
# mi                  0.001248
# count_order    309142.122615
# Name: 200, dtype: float64
# mi                  0.001248
# count_order    293426.188592
# Name: 201, dtype: float64
# mi                  0.001248
# count_order    322871.102130
# Name: 202, dtype: float64
# mi                  0.001248
# count_order    287702.492790
# Name: 203, dtype: float64
# mi                  0.001248
# count_order    289316.270342
# Name: 204, dtype: float64
# mi                  0.001248
# count_order    301575.180832
# Name: 205, dtype: float64
# mi                  0.001248
# count_order    284839.297216
# Name: 206, dtype: float64
# mi                  0.001248
# count_order    291322.416934
# Name: 207, dtype: float64
# mi                  0.001248
# count_order    284251.050658
# Name: 208, dtype: float64
# mi                  0.001248
# count_order    281955.833249
# Name: 209, dtype: float64
# mi                  0.001248
# count_order    283616.831995
# Name: 210, dtype: float64
# mi                  0.001248
# count_order    290174.953534
# Name: 211, dtype: float64
# mi                  0.001248
# count_order    281437.146283
# Name: 212, dtype: float64
# mi                  0.001248
# count_order    280229.031510
# Name: 213, dtype: float64
# mi                  0.001248
# count_order    288627.017740
# Name: 214, dtype: float64
# mi                  0.001248
# count_order    281843.285877
# Name: 215, dtype: float64
# mi                  0.001248
# count_order    288280.899965
# Name: 216, dtype: float64
# mi                  0.001248
# count_order    290610.667243
# Name: 217, dtype: float64
# mi                  0.001248
# count_order    291786.162776
# Name: 218, dtype: float64
# mi                  0.001248
# count_order    292231.714154
# Name: 219, dtype: float64
# mi                  0.001248
# count_order    301736.196751
# Name: 220, dtype: float64
# mi                  0.001248
# count_order    305452.516024
# Name: 221, dtype: float64
# mi                  0.001248
# count_order    283880.032820
# Name: 222, dtype: float64
# mi                  0.001248
# count_order    293958.588633
# Name: 223, dtype: float64
# mi                  0.001248
# count_order    279235.633361
# Name: 224, dtype: float64
# mi                  0.001248
# count_order    298351.001778
# Name: 225, dtype: float64
# mi                  0.001248
# count_order    291789.426966
# Name: 226, dtype: float64
# mi                  0.001248
# count_order    293844.915551
# Name: 227, dtype: float64
# mi                  0.001248
# count_order    272775.289953
# Name: 228, dtype: float64
# mi                  0.001248
# count_order    304462.650239
# Name: 229, dtype: float64
# mi                  0.001248
# count_order    282918.524643
# Name: 230, dtype: float64
# mi                  0.001248
# count_order    272095.965718
# Name: 231, dtype: float64
# mi                  0.001248
# count_order    273060.413415
# Name: 232, dtype: float64
# mi                  0.001248
# count_order    299518.888533
# Name: 233, dtype: float64
# mi                  0.001248
# count_order    286402.791021
# Name: 234, dtype: float64
# mi                  0.001248
# count_order    287775.383541
# Name: 235, dtype: float64
# mi                  0.001248
# count_order    289057.142978
# Name: 236, dtype: float64
# mi                  0.001248
# count_order    307342.896599
# Name: 237, dtype: float64
# mi                  0.001248
# count_order    300134.641930
# Name: 238, dtype: float64
# mi                  0.001248
# count_order    305896.875776
# Name: 239, dtype: float64
# mi                  0.001248
# count_order    297070.946077
# Name: 240, dtype: float64
# mi                  0.001248
# count_order    311579.419465
# Name: 241, dtype: float64
# mi                  0.001248
# count_order    283994.610522
# Name: 242, dtype: float64
# mi                  0.001248
# count_order    308856.415764
# Name: 243, dtype: float64
# mi                  0.001248
# count_order    290794.542074
# Name: 244, dtype: float64
# mi                  0.001248
# count_order    297933.926246
# Name: 245, dtype: float64
# mi                  0.001248
# count_order    305761.848313
# Name: 246, dtype: float64
# mi                  0.001248
# count_order    293923.860881
# Name: 247, dtype: float64
# mi                  0.001248
# count_order    287608.318182
# Name: 248, dtype: float64
# mi                  0.001248
# count_order    299937.420527
# Name: 249, dtype: float64
# mi                  0.001248
# count_order    311198.261719
# Name: 250, dtype: float64
# mi                  0.001248
# count_order    310625.860837
# Name: 251, dtype: float64
# mi                  0.001248
# count_order    284354.767515
# Name: 252, dtype: float64
# mi                  0.001248
# count_order    290853.751880
# Name: 253, dtype: float64
# mi                  0.001248
# count_order    283834.926915
# Name: 254, dtype: float64
# mi                  0.001248
# count_order    296905.721372
# Name: 255, dtype: float64
# mi                  0.001248
# count_order    277630.349170
# Name: 256, dtype: float64
# mi                  0.001248
# count_order    296545.229886
# Name: 257, dtype: float64
# mi                  0.001248
# count_order    310091.770829
# Name: 258, dtype: float64
# mi                  0.001248
# count_order    297007.868135
# Name: 259, dtype: float64
# mi                  0.001248
# count_order    312951.931353
# Name: 260, dtype: float64
# mi                  0.001248
# count_order    274202.976189
# Name: 261, dtype: float64
# mi                  0.001248
# count_order    294907.890199
# Name: 262, dtype: float64
# mi                  0.001248
# count_order    287663.578533
# Name: 263, dtype: float64
# mi                  0.001248
# count_order    266825.763337
# Name: 264, dtype: float64
# mi                  0.001248
# count_order    292739.276237
# Name: 265, dtype: float64
# mi                  0.001248
# count_order    294055.199084
# Name: 266, dtype: float64
# mi                  0.001248
# count_order    292389.967613
# Name: 267, dtype: float64
# mi                  0.001248
# count_order    306652.680323
# Name: 268, dtype: float64
# mi                  0.001248
# count_order    291227.814155
# Name: 269, dtype: float64
# mi                  0.001248
# count_order    296193.486337
# Name: 270, dtype: float64
# mi                  0.001248
# count_order    288588.590967
# Name: 271, dtype: float64
# mi                  0.001248
# count_order    282772.239188
# Name: 272, dtype: float64
# mi                  0.001248
# count_order    281133.174811
# Name: 273, dtype: float64
# mi                  0.001248
# count_order    291999.147754
# Name: 274, dtype: float64
# mi                  0.001248
# count_order    320904.791964
# Name: 275, dtype: float64
# mi                  0.001248
# count_order    277424.793311
# Name: 276, dtype: float64
# mi                  0.001248
# count_order    285841.992996
# Name: 277, dtype: float64
# mi                  0.001248
# count_order    300353.499343
# Name: 278, dtype: float64
# mi                  0.001248
# count_order    305803.317984
# Name: 279, dtype: float64
# mi                  0.001248
# count_order    300532.223395
# Name: 280, dtype: float64
# mi                  0.001248
# count_order    293933.228437
# Name: 281, dtype: float64
# mi                  0.001248
# count_order    291630.957313
# Name: 282, dtype: float64
# mi                  0.001248
# count_order    313944.293041
# Name: 283, dtype: float64
# mi                  0.001248
# count_order    289668.238063
# Name: 284, dtype: float64
# mi                  0.001248
# count_order    298180.415841
# Name: 285, dtype: float64
# mi                  0.001248
# count_order    281241.517244
# Name: 286, dtype: float64
# mi                  0.001248
# count_order    285492.808554
# Name: 287, dtype: float64
# mi                  0.001248
# count_order    282369.062459
# Name: 288, dtype: float64
# mi                  0.001248
# count_order    302094.353717
# Name: 289, dtype: float64
# mi                  0.001248
# count_order    283477.280430
# Name: 290, dtype: float64
# mi                  0.001248
# count_order    299233.368277
# Name: 291, dtype: float64
# mi                  0.001248
# count_order    284662.890607
# Name: 292, dtype: float64
# mi                  0.001248
# count_order    290697.260722
# Name: 293, dtype: float64
# mi                  0.001248
# count_order    291229.030149
# Name: 294, dtype: float64
# mi                  0.001248
# count_order    271962.781074
# Name: 295, dtype: float64
# mi                  0.001248
# count_order    309706.943767
# Name: 296, dtype: float64
# mi                  0.001248
# count_order    280120.646472
# Name: 297, dtype: float64
# mi                  0.001248
# count_order    283480.269305
# Name: 298, dtype: float64
# mi                  0.001248
# count_order    327388.116537
# Name: 299, dtype: float64
# mi                  0.001248
# count_order    311883.831303
# Name: 300, dtype: float64
# mi                  0.001248
# count_order    293239.662920
# Name: 301, dtype: float64
# mi                  0.001248
# count_order    268471.694612
# Name: 302, dtype: float64
# mi                  0.001248
# count_order    296085.494071
# Name: 303, dtype: float64
# mi                  0.001248
# count_order    302288.719926
# Name: 304, dtype: float64
# mi                  0.001248
# count_order    302814.996848
# Name: 305, dtype: float64
# mi                  0.001248
# count_order    280872.518409
# Name: 306, dtype: float64
# mi                  0.001248
# count_order    292006.785384
# Name: 307, dtype: float64
# mi                  0.001248
# count_order    286209.395776
# Name: 308, dtype: float64
# mi                  0.001248
# count_order    298351.342856
# Name: 309, dtype: float64
# mi                  0.001248
# count_order    270851.749928
# Name: 310, dtype: float64
# mi                  0.001248
# count_order    291175.289546
# Name: 311, dtype: float64
# mi                  0.001248
# count_order    298854.513343
# Name: 312, dtype: float64
# mi                  0.001248
# count_order    314351.810425
# Name: 313, dtype: float64
# mi                  0.001248
# count_order    296670.384094
# Name: 314, dtype: float64
# mi                  0.001248
# count_order    282714.890745
# Name: 315, dtype: float64
# mi                  0.001248
# count_order    287374.136042
# Name: 316, dtype: float64
# mi                  0.001248
# count_order    293785.734545
# Name: 317, dtype: float64
# mi                  0.001248
# count_order    291878.255656
# Name: 318, dtype: float64
# mi                  0.001248
# count_order    283386.546831
# Name: 319, dtype: float64
# mi                  0.001248
# count_order    294794.818213
# Name: 320, dtype: float64
# mi                  0.001248
# count_order    301006.761258
# Name: 321, dtype: float64
# mi                  0.001248
# count_order    300966.617598
# Name: 322, dtype: float64
# mi                  0.001248
# count_order    313673.182795
# Name: 323, dtype: float64
# mi                  0.001248
# count_order    290227.214317
# Name: 324, dtype: float64
# mi                  0.001248
# count_order    296833.819619
# Name: 325, dtype: float64
# mi                  0.001248
# count_order    292423.678800
# Name: 326, dtype: float64
# mi                  0.001248
# count_order    286688.697546
# Name: 327, dtype: float64
# mi                  0.001248
# count_order    284917.250393
# Name: 328, dtype: float64
# mi                  0.001248
# count_order    301400.360669
# Name: 329, dtype: float64
# mi                  0.001248
# count_order    302673.752639
# Name: 330, dtype: float64
# mi                  0.001248
# count_order    307883.192304
# Name: 331, dtype: float64
# mi                  0.001248
# count_order    298202.023818
# Name: 332, dtype: float64
# mi                  0.001248
# count_order    294933.317147
# Name: 333, dtype: float64
# mi                  0.001248
# count_order    309855.499783
# Name: 334, dtype: float64
# mi                  0.001248
# count_order    293366.875672
# Name: 335, dtype: float64
# mi                  0.001248
# count_order    285792.008128
# Name: 336, dtype: float64
# mi                  0.001248
# count_order    289288.189763
# Name: 337, dtype: float64
# mi                  0.001248
# count_order    294775.154183
# Name: 338, dtype: float64
# mi                  0.001248
# count_order    277138.504549
# Name: 339, dtype: float64
# mi                  0.001248
# count_order    289627.724426
# Name: 340, dtype: float64
# mi                  0.001248
# count_order    301534.247193
# Name: 341, dtype: float64
# mi                  0.001248
# count_order    290586.336882
# Name: 342, dtype: float64
# mi                  0.001248
# count_order    294790.986835
# Name: 343, dtype: float64
# mi                  0.001248
# count_order    294330.143397
# Name: 344, dtype: float64
# mi                  0.001248
# count_order    293805.514835
# Name: 345, dtype: float64
# mi                  0.001248
# count_order    279192.043221
# Name: 346, dtype: float64
# mi                  0.001248
# count_order    303001.948706
# Name: 347, dtype: float64
# mi                  0.001248
# count_order    286047.666078
# Name: 348, dtype: float64
# mi                  0.001248
# count_order    292452.667888
# Name: 349, dtype: float64
# mi                  0.001248
# count_order    289364.757874
# Name: 350, dtype: float64
# mi                  0.001248
# count_order    279175.165022
# Name: 351, dtype: float64
# mi                  0.001248
# count_order    314526.309655
# Name: 352, dtype: float64
# mi                  0.001248
# count_order    295324.364134
# Name: 353, dtype: float64
# mi                  0.001248
# count_order    274364.415580
# Name: 354, dtype: float64
# mi                  0.001248
# count_order    310660.923337
# Name: 355, dtype: float64
# mi                  0.001248
# count_order    293457.752579
# Name: 356, dtype: float64
# mi                  0.001248
# count_order    288443.166392
# Name: 357, dtype: float64
# mi                  0.001248
# count_order    290303.557298
# Name: 358, dtype: float64
# mi                  0.001248
# count_order    283102.027569
# Name: 359, dtype: float64
# mi                  0.001248
# count_order    275823.821837
# Name: 360, dtype: float64
# mi                  0.001248
# count_order    297709.470850
# Name: 361, dtype: float64
# mi                  0.001248
# count_order    307973.809994
# Name: 362, dtype: float64
# mi                  0.001248
# count_order    325752.868380
# Name: 363, dtype: float64
# mi                  0.001248
# count_order    299344.294260
# Name: 364, dtype: float64
# mi                  0.001248
# count_order    294752.894438
# Name: 365, dtype: float64
# mi                  0.001248
# count_order    309601.252824
# Name: 366, dtype: float64
# mi                  0.001248
# count_order    292540.121706
# Name: 367, dtype: float64
# mi                  0.001248
# count_order    283443.583433
# Name: 368, dtype: float64
# mi                  0.001248
# count_order    284055.648849
# Name: 369, dtype: float64
# mi                  0.001248
# count_order    281301.906496
# Name: 370, dtype: float64
# mi                  0.001248
# count_order    279093.898472
# Name: 371, dtype: float64
# mi                  0.001248
# count_order    311339.943350
# Name: 372, dtype: float64
# mi                  0.001248
# count_order    296225.226115
# Name: 373, dtype: float64
# mi                  0.001248
# count_order    293457.646516
# Name: 374, dtype: float64
# mi                  0.001248
# count_order    309650.374867
# Name: 375, dtype: float64
# mi                  0.001248
# count_order    297131.808708
# Name: 376, dtype: float64
# mi                  0.001248
# count_order    304257.956637
# Name: 377, dtype: float64
# mi                  0.001248
# count_order    281978.041454
# Name: 378, dtype: float64
# mi                  0.001248
# count_order    299075.692309
# Name: 379, dtype: float64
# mi                  0.001248
# count_order    296009.926514
# Name: 380, dtype: float64
# mi                  0.001248
# count_order    282133.706601
# Name: 381, dtype: float64
# mi                  0.001248
# count_order    285496.692912
# Name: 382, dtype: float64
# mi                  0.001248
# count_order    277557.607856
# Name: 383, dtype: float64
# mi                  0.001248
# count_order    296392.944674
# Name: 384, dtype: float64
# mi                  0.001248
# count_order    312683.367942
# Name: 385, dtype: float64
# mi                  0.001248
# count_order    303024.178053
# Name: 386, dtype: float64
# mi                  0.001248
# count_order    292305.949948
# Name: 387, dtype: float64
# mi                  0.001248
# count_order    277731.520404
# Name: 388, dtype: float64
# mi                  0.001248
# count_order    314294.827644
# Name: 389, dtype: float64
# mi                  0.001248
# count_order    309665.265171
# Name: 390, dtype: float64
# mi                  0.001248
# count_order    308745.185831
# Name: 391, dtype: float64
# mi                  0.001248
# count_order    286401.044006
# Name: 392, dtype: float64
# mi                  0.001248
# count_order    302744.876248
# Name: 393, dtype: float64
# mi                  0.001248
# count_order    271951.659626
# Name: 394, dtype: float64
# mi                  0.001248
# count_order    296023.731657
# Name: 395, dtype: float64
# mi                  0.001248
# count_order    286507.102189
# Name: 396, dtype: float64
# mi                  0.001248
# count_order    320882.007143
# Name: 397, dtype: float64
# mi                  0.001248
# count_order    281060.409093
# Name: 398, dtype: float64
# mi                  0.001248
# count_order    311211.333393
# Name: 399, dtype: float64
# mi                  0.001248
# count_order    289174.123512
# Name: 400, dtype: float64
# mi                  0.001248
# count_order    301373.920426
# Name: 401, dtype: float64
# mi                  0.001248
# count_order    290102.588905
# Name: 402, dtype: float64
# mi                  0.001248
# count_order    296570.924426
# Name: 403, dtype: float64
# mi                  0.001248
# count_order    305830.169600
# Name: 404, dtype: float64
# mi                  0.001248
# count_order    293323.195046
# Name: 405, dtype: float64
# mi                  0.001248
# count_order    314897.492530
# Name: 406, dtype: float64
# mi                  0.001248
# count_order    273779.426855
# Name: 407, dtype: float64
# mi                  0.001248
# count_order    283744.613850
# Name: 408, dtype: float64
# mi                  0.001248
# count_order    301887.618428
# Name: 409, dtype: float64
# mi                  0.001248
# count_order    293886.856445
# Name: 410, dtype: float64
# mi                  0.001248
# count_order    276974.425130
# Name: 411, dtype: float64
# mi                  0.001248
# count_order    295419.918925
# Name: 412, dtype: float64
# mi                  0.001248
# count_order    302524.903593
# Name: 413, dtype: float64
# mi                  0.001248
# count_order    267770.251984
# Name: 414, dtype: float64
# mi                  0.001248
# count_order    293748.381039
# Name: 415, dtype: float64
# mi                  0.001248
# count_order    266029.025120
# Name: 416, dtype: float64
# mi                  0.001248
# count_order    301543.379019
# Name: 417, dtype: float64
# mi                  0.001248
# count_order    280280.321090
# Name: 418, dtype: float64
# mi                  0.001248
# count_order    287245.401715
# Name: 419, dtype: float64
# mi                  0.001248
# count_order    281154.774916
# Name: 420, dtype: float64
# mi                  0.001248
# count_order    288930.143712
# Name: 421, dtype: float64
# mi                  0.001248
# count_order    287200.898436
# Name: 422, dtype: float64
# mi                  0.001248
# count_order    301450.468546
# Name: 423, dtype: float64
# mi                  0.001248
# count_order    293168.927580
# Name: 424, dtype: float64
# mi                  0.001248
# count_order    272756.843688
# Name: 425, dtype: float64
# mi                  0.001248
# count_order    291242.193659
# Name: 426, dtype: float64
# mi                  0.001248
# count_order    303250.568808
# Name: 427, dtype: float64
# mi                  0.001248
# count_order    300691.345014
# Name: 428, dtype: float64
# mi                  0.001248
# count_order    270014.006832
# Name: 429, dtype: float64
# mi                  0.001248
# count_order    282691.254239
# Name: 430, dtype: float64
# mi                  0.001248
# count_order    291341.782355
# Name: 431, dtype: float64
# mi                  0.001248
# count_order    287352.029357
# Name: 432, dtype: float64
# mi                  0.001248
# count_order    306300.879379
# Name: 433, dtype: float64
# mi                  0.001248
# count_order    292369.053674
# Name: 434, dtype: float64
# mi                  0.001248
# count_order    274485.709009
# Name: 435, dtype: float64
# mi                  0.001248
# count_order    292225.163187
# Name: 436, dtype: float64
# mi                  0.001248
# count_order    291238.738129
# Name: 437, dtype: float64
# mi                  0.001248
# count_order    306054.721190
# Name: 438, dtype: float64
# mi                  0.001248
# count_order    290509.586888
# Name: 439, dtype: float64
# mi                  0.001248
# count_order    297192.117066
# Name: 440, dtype: float64
# mi                  0.001248
# count_order    296464.464749
# Name: 441, dtype: float64
# mi                  0.001248
# count_order    299592.607057
# Name: 442, dtype: float64
# mi                  0.001248
# count_order    279970.611658
# Name: 443, dtype: float64
# mi                  0.001248
# count_order    294001.300534
# Name: 444, dtype: float64
# mi                  0.001248
# count_order    291716.988699
# Name: 445, dtype: float64
# mi                  0.001248
# count_order    272188.879135
# Name: 446, dtype: float64
# mi                  0.001248
# count_order    292803.395805
# Name: 447, dtype: float64
# mi                  0.001248
# count_order    261687.965458
# Name: 448, dtype: float64
# mi                  0.001248
# count_order    273016.214822
# Name: 449, dtype: float64
# mi                  0.001248
# count_order    290860.689679
# Name: 450, dtype: float64
# mi                  0.001248
# count_order    285100.993322
# Name: 451, dtype: float64
# mi                  0.001248
# count_order    280794.490544
# Name: 452, dtype: float64
# mi                  0.001248
# count_order    298527.579399
# Name: 453, dtype: float64
# mi                  0.001248
# count_order    287848.202459
# Name: 454, dtype: float64
# mi                  0.001248
# count_order    279275.254718
# Name: 455, dtype: float64
# mi                  0.001248
# count_order    270784.636453
# Name: 456, dtype: float64
# mi                  0.001248
# count_order    299587.159744
# Name: 457, dtype: float64
# mi                  0.001248
# count_order    296819.437784
# Name: 458, dtype: float64
# mi                  0.001248
# count_order    295107.803969
# Name: 459, dtype: float64
# mi                  0.001248
# count_order    279499.079893
# Name: 460, dtype: float64
# mi                  0.001248
# count_order    301253.060026
# Name: 461, dtype: float64
# mi                  0.001248
# count_order    277541.303014
# Name: 462, dtype: float64
# mi                  0.001248
# count_order    280623.049041
# Name: 463, dtype: float64
# mi                  0.001248
# count_order    283342.853119
# Name: 464, dtype: float64
# mi                  0.001248
# count_order    300049.162612
# Name: 465, dtype: float64
# mi                  0.001248
# count_order    294744.502636
# Name: 466, dtype: float64
# mi                  0.001248
# count_order    294644.252444
# Name: 467, dtype: float64
# mi                  0.001248
# count_order    296906.273268
# Name: 468, dtype: float64
# mi                  0.001248
# count_order    291601.686032
# Name: 469, dtype: float64
# mi                  0.001248
# count_order    270215.557183
# Name: 470, dtype: float64
# mi                  0.001248
# count_order    292089.200575
# Name: 471, dtype: float64
# mi                  0.001248
# count_order    283141.063824
# Name: 472, dtype: float64
# mi                  0.001248
# count_order    304073.047841
# Name: 473, dtype: float64
# mi                  0.001248
# count_order    296935.781501
# Name: 474, dtype: float64
# mi                  0.001248
# count_order    290426.312933
# Name: 475, dtype: float64
# mi                  0.001248
# count_order    278390.993389
# Name: 476, dtype: float64
# mi                  0.001248
# count_order    299910.831792
# Name: 477, dtype: float64
# mi                  0.001248
# count_order    270678.313210
# Name: 478, dtype: float64
# mi                  0.001248
# count_order    281983.981459
# Name: 479, dtype: float64
# mi                  0.001248
# count_order    266355.083054
# Name: 480, dtype: float64
# mi                  0.001248
# count_order    288279.279408
# Name: 481, dtype: float64
# mi                  0.001248
# count_order    309033.841904
# Name: 482, dtype: float64
# mi                  0.001248
# count_order    290913.409791
# Name: 483, dtype: float64
# mi                  0.001248
# count_order    294607.912599
# Name: 484, dtype: float64
# mi                  0.001248
# count_order    296253.464542
# Name: 485, dtype: float64
# mi                  0.001248
# count_order    276283.745487
# Name: 486, dtype: float64
# mi                  0.001248
# count_order    294492.009752
# Name: 487, dtype: float64
# mi                  0.001248
# count_order    283603.740745
# Name: 488, dtype: float64
# mi                  0.001248
# count_order    299400.459967
# Name: 489, dtype: float64
# mi                  0.001248
# count_order    291574.279008
# Name: 490, dtype: float64
# mi                  0.001248
# count_order    305268.589544
# Name: 491, dtype: float64
# mi                  0.001248
# count_order    274695.563655
# Name: 492, dtype: float64
# mi                  0.001248
# count_order    283847.711104
# Name: 493, dtype: float64
# mi                  0.001248
# count_order    269450.532831
# Name: 494, dtype: float64
# mi                  0.001248
# count_order    290769.906033
# Name: 495, dtype: float64
# mi                  0.001248
# count_order    288868.967633
# Name: 496, dtype: float64
# mi                  0.001248
# count_order    295918.910437
# Name: 497, dtype: float64
# mi                  0.001248
# count_order    309708.685561
# Name: 498, dtype: float64
# mi                  0.001248
# count_order    281408.543673
# Name: 499, dtype: float64
# mi                  0.001248
# count_order    287265.539033
# Name: 500, dtype: float64
# mi                  0.001248
# count_order    292596.260804
# Name: 501, dtype: float64
# mi                  0.001248
# count_order    286323.550246
# Name: 502, dtype: float64
# mi                  0.001248
# count_order    304617.705401
# Name: 503, dtype: float64
# mi                  0.001248
# count_order    264250.790331
# Name: 504, dtype: float64
# mi                  0.001248
# count_order    278508.568300
# Name: 505, dtype: float64
# mi                  0.001248
# count_order    294359.667348
# Name: 506, dtype: float64
# mi                  0.001248
# count_order    284492.818228
# Name: 507, dtype: float64
# mi                  0.001248
# count_order    309002.327441
# Name: 508, dtype: float64
# mi                  0.001248
# count_order    292328.543412
# Name: 509, dtype: float64
# mi                  0.001248
# count_order    291901.106692
# Name: 510, dtype: float64
# mi                  0.001248
# count_order    291411.492055
# Name: 511, dtype: float64
# mi                  0.001248
# count_order    305574.068084
# Name: 512, dtype: float64
# mi                  0.001248
# count_order    299695.496839
# Name: 513, dtype: float64
# mi                  0.001248
# count_order    289976.880805
# Name: 514, dtype: float64
# mi                  0.001248
# count_order    291424.871313
# Name: 515, dtype: float64
# mi                  0.001248
# count_order    307301.126517
# Name: 516, dtype: float64
# mi                  0.001248
# count_order    297690.255694
# Name: 517, dtype: float64
# mi                  0.001248
# count_order    308750.324644
# Name: 518, dtype: float64
# mi                  0.001248
# count_order    309578.891886
# Name: 519, dtype: float64
# mi                  0.001248
# count_order    290261.162567
# Name: 520, dtype: float64
# mi                  0.001248
# count_order    291901.969113
# Name: 521, dtype: float64
# mi                  0.001248
# count_order    272543.799217
# Name: 522, dtype: float64
# mi                  0.001248
# count_order    279047.635796
# Name: 523, dtype: float64
# mi                  0.001248
# count_order    303246.660233
# Name: 524, dtype: float64
# mi                  0.001248
# count_order    290889.298106
# Name: 525, dtype: float64
# mi                  0.001248
# count_order    289191.724975
# Name: 526, dtype: float64
# mi                  0.001248
# count_order    290252.569918
# Name: 527, dtype: float64
# mi                  0.001248
# count_order    276044.315237
# Name: 528, dtype: float64
# mi                  0.001248
# count_order    288289.797938
# Name: 529, dtype: float64
# mi                  0.001248
# count_order    298932.788959
# Name: 530, dtype: float64
# mi                  0.001248
# count_order    289727.244057
# Name: 531, dtype: float64
# mi                  0.001248
# count_order    322069.352151
# Name: 532, dtype: float64
# mi                  0.001248
# count_order    280451.347583
# Name: 533, dtype: float64
# mi                  0.001248
# count_order    273964.305037
# Name: 534, dtype: float64
# mi                  0.001248
# count_order    297427.083691
# Name: 535, dtype: float64
# mi                  0.001248
# count_order    292225.821446
# Name: 536, dtype: float64
# mi                  0.001248
# count_order    270385.991065
# Name: 537, dtype: float64
# mi                  0.001248
# count_order    288139.096690
# Name: 538, dtype: float64
# mi                  0.001248
# count_order    293229.350202
# Name: 539, dtype: float64
# mi                  0.001248
# count_order    305930.494224
# Name: 540, dtype: float64
# mi                  0.001248
# count_order    284386.574548
# Name: 541, dtype: float64
# mi                  0.001248
# count_order    281913.557305
# Name: 542, dtype: float64
# mi                  0.001248
# count_order    281088.500034
# Name: 543, dtype: float64
# mi                  0.001248
# count_order    281316.488138
# Name: 544, dtype: float64
# mi                  0.001248
# count_order    285478.657515
# Name: 545, dtype: float64
# mi                  0.001248
# count_order    298574.253294
# Name: 546, dtype: float64
# mi                  0.001248
# count_order    296473.961263
# Name: 547, dtype: float64
# mi                  0.001248
# count_order    296342.297251
# Name: 548, dtype: float64
# mi                  0.001248
# count_order    284696.534270
# Name: 549, dtype: float64
# mi                  0.001248
# count_order    308524.780997
# Name: 550, dtype: float64
# mi                  0.001248
# count_order    286562.023407
# Name: 551, dtype: float64
# mi                  0.001248
# count_order    281682.060129
# Name: 552, dtype: float64
# mi                  0.001248
# count_order    284537.380654
# Name: 553, dtype: float64
# mi                  0.001248
# count_order    298117.014483
# Name: 554, dtype: float64
# mi                  0.001248
# count_order    285222.472412
# Name: 555, dtype: float64
# mi                  0.001248
# count_order    283780.552691
# Name: 556, dtype: float64
# mi                  0.001248
# count_order    281260.429726
# Name: 557, dtype: float64
# mi                  0.001248
# count_order    288373.241438
# Name: 558, dtype: float64
# mi                  0.001248
# count_order    293785.661613
# Name: 559, dtype: float64
# mi                  0.001248
# count_order    293710.430477
# Name: 560, dtype: float64
# mi                  0.001248
# count_order    294341.559596
# Name: 561, dtype: float64
# mi                  0.001248
# count_order    282361.864338
# Name: 562, dtype: float64
# mi                  0.001248
# count_order    290560.831674
# Name: 563, dtype: float64
# mi                  0.001248
# count_order    302416.283146
# Name: 564, dtype: float64
# mi                  0.001248
# count_order    307691.585866
# Name: 565, dtype: float64
# mi                  0.001248
# count_order    290357.832052
# Name: 566, dtype: float64
# mi                  0.001248
# count_order    299092.754301
# Name: 567, dtype: float64
# mi                  0.001248
# count_order    277965.103308
# Name: 568, dtype: float64
# mi                  0.001248
# count_order    286445.299538
# Name: 569, dtype: float64
# mi                  0.001248
# count_order    299431.712539
# Name: 570, dtype: float64
# mi                  0.001248
# count_order    284210.468984
# Name: 571, dtype: float64
# mi                  0.001248
# count_order    301657.367156
# ...
# mi                 16.000000
# count_order    290768.037081
# Name: 8822, dtype: float64
# mi                 16.000000
# count_order    291707.984917
# Name: 8823, dtype: float64
# mi                 16.000000
# count_order    292112.129826
# Name: 8824, dtype: float64
# mi                 16.000000
# count_order    291442.551712
# Name: 8825, dtype: float64
# mi                 16.000000
# count_order    292358.693493
# Name: 8826, dtype: float64
# mi                 16.000000
# count_order    292328.414088
# Name: 8827, dtype: float64
# mi                 16.00000
# count_order    291556.20668
# Name: 8828, dtype: float64
# mi                 16.000000
# count_order    291836.741983
# Name: 8829, dtype: float64
# mi                 16.000000
# count_order    291709.089077
# Name: 8830, dtype: float64
# mi                 16.000000
# count_order    291796.952024
# Name: 8831, dtype: float64
# mi                 16.000000
# count_order    292343.561892
# Name: 8832, dtype: float64
# mi                 16.000000
# count_order    293145.955317
# Name: 8833, dtype: float64
# mi                 16.000000
# count_order    291557.804314
# Name: 8834, dtype: float64
# mi                 16.000000
# count_order    292368.135442
# Name: 8835, dtype: float64
# mi                 16.00000
# count_order    292063.04029
# Name: 8836, dtype: float64
# mi                 16.000000
# count_order    292009.276594
# Name: 8837, dtype: float64
# mi                 16.000000
# count_order    292415.832321
# Name: 8838, dtype: float64
# mi                 16.000000
# count_order    291388.616819
# Name: 8839, dtype: float64
# mi                 16.000000
# count_order    292280.600621
# Name: 8840, dtype: float64
# mi                 16.000000
# count_order    291861.917311
# Name: 8841, dtype: float64
# mi                 16.000000
# count_order    291991.084938
# Name: 8842, dtype: float64
# mi                 16.000000
# count_order    292151.764051
# Name: 8843, dtype: float64
# mi                 16.000000
# count_order    293387.173222
# Name: 8844, dtype: float64
# mi                 16.000000
# count_order    291728.385069
# Name: 8845, dtype: float64
# mi                 16.000000
# count_order    290918.843575
# Name: 8846, dtype: float64
# mi                 16.000000
# count_order    291467.848439
# Name: 8847, dtype: float64
# mi                 16.000000
# count_order    292037.445811
# Name: 8848, dtype: float64
# mi                 16.000000
# count_order    292455.781572
# Name: 8849, dtype: float64
# mi                 16.000000
# count_order    291387.137834
# Name: 8850, dtype: float64
# mi                 16.000000
# count_order    292547.733329
# Name: 8851, dtype: float64
# mi                 16.000000
# count_order    292999.370351
# Name: 8852, dtype: float64
# mi                 16.000000
# count_order    292683.863459
# Name: 8853, dtype: float64
# mi                 16.00000
# count_order    291316.19294
# Name: 8854, dtype: float64
# mi                 16.000000
# count_order    292454.098028
# Name: 8855, dtype: float64
# mi                 16.000000
# count_order    291386.081872
# Name: 8856, dtype: float64
# mi                 16.000000
# count_order    291859.177206
# Name: 8857, dtype: float64
# mi                 16.000000
# count_order    292675.180288
# Name: 8858, dtype: float64
# mi                 16.000000
# count_order    291062.251176
# Name: 8859, dtype: float64
# mi                 16.000000
# count_order    292043.728516
# Name: 8860, dtype: float64
# mi                 16.000000
# count_order    291671.118392
# Name: 8861, dtype: float64
# mi                 16.00000
# count_order    292634.51689
# Name: 8862, dtype: float64
# mi                 16.000000
# count_order    291824.091801
# Name: 8863, dtype: float64
# mi                 16.000000
# count_order    292019.563828
# Name: 8864, dtype: float64
# mi                 16.000000
# count_order    292647.307416
# Name: 8865, dtype: float64
# mi                 16.000000
# count_order    293374.834086
# Name: 8866, dtype: float64
# mi                 16.000000
# count_order    293073.592742
# Name: 8867, dtype: float64
# mi                 16.00000
# count_order    291926.28698
# Name: 8868, dtype: float64
# mi                 16.000000
# count_order    292240.393458
# Name: 8869, dtype: float64
# mi                 16.000000
# count_order    291539.660086
# Name: 8870, dtype: float64
# mi                 16.000000
# count_order    291192.030003
# Name: 8871, dtype: float64
# mi                 16.000000
# count_order    291267.834266
# Name: 8872, dtype: float64
# mi                 16.000000
# count_order    292757.527202
# Name: 8873, dtype: float64
# mi                 16.000000
# count_order    292161.832646
# Name: 8874, dtype: float64
# mi                 16.000000
# count_order    292431.366166
# Name: 8875, dtype: float64
# mi                 16.000000
# count_order    292976.636531
# Name: 8876, dtype: float64
# mi                 16.000000
# count_order    292712.231641
# Name: 8877, dtype: float64
# mi                 16.000000
# count_order    293211.341875
# Name: 8878, dtype: float64
# mi                 16.000000
# count_order    290818.481852
# Name: 8879, dtype: float64
# mi                 16.000000
# count_order    292133.742421
# Name: 8880, dtype: float64
# mi                 16.000000
# count_order    291565.159644
# Name: 8881, dtype: float64
# mi                 16.000000
# count_order    290838.040574
# Name: 8882, dtype: float64
# mi                 16.000000
# count_order    292069.735978
# Name: 8883, dtype: float64
# mi                 16.000000
# count_order    291889.575538
# Name: 8884, dtype: float64
# mi                 16.000000
# count_order    291259.456474
# Name: 8885, dtype: float64
# mi                 16.000000
# count_order    292317.830965
# Name: 8886, dtype: float64
# mi                 16.000000
# count_order    292496.790734
# Name: 8887, dtype: float64
# mi                 16.000000
# count_order    291766.679775
# Name: 8888, dtype: float64
# mi                 16.000000
# count_order    291884.355987
# Name: 8889, dtype: float64
# mi                 16.000000
# count_order    291851.110597
# Name: 8890, dtype: float64
# mi                 16.000000
# count_order    291080.620616
# Name: 8891, dtype: float64
# mi                 16.00000
# count_order    292024.99585
# Name: 8892, dtype: float64
# mi                 16.000000
# count_order    292167.131489
# Name: 8893, dtype: float64
# mi                 16.000000
# count_order    291364.297415
# Name: 8894, dtype: float64
# mi                 16.000000
# count_order    292417.091757
# Name: 8895, dtype: float64
# mi                 16.00000
# count_order    291231.34655
# Name: 8896, dtype: float64
# mi                 16.000000
# count_order    292377.006939
# Name: 8897, dtype: float64
# mi                 16.000000
# count_order    291455.505722
# Name: 8898, dtype: float64
# mi                 16.000000
# count_order    292366.640335
# Name: 8899, dtype: float64
# mi                 16.000000
# count_order    292074.297152
# Name: 8900, dtype: float64
# mi                 16.000000
# count_order    291528.389451
# Name: 8901, dtype: float64
# mi                 16.000000
# count_order    292029.089716
# Name: 8902, dtype: float64
# mi                 16.000000
# count_order    291724.155706
# Name: 8903, dtype: float64
# mi                 16.000000
# count_order    291123.576648
# Name: 8904, dtype: float64
# mi                 16.000000
# count_order    292636.268921
# Name: 8905, dtype: float64
# mi                 16.000000
# count_order    293134.055766
# Name: 8906, dtype: float64
# mi                 16.000000
# count_order    292211.339819
# Name: 8907, dtype: float64
# mi                 16.000000
# count_order    291936.480455
# Name: 8908, dtype: float64
# mi                 16.000000
# count_order    291617.599907
# Name: 8909, dtype: float64
# mi                 16.000000
# count_order    292179.125444
# Name: 8910, dtype: float64
# mi                 16.000000
# count_order    291607.620728
# Name: 8911, dtype: float64
# mi                 16.000000
# count_order    291765.041595
# Name: 8912, dtype: float64
# mi                 16.000000
# count_order    291151.468045
# Name: 8913, dtype: float64
# mi                 16.000000
# count_order    291984.526292
# Name: 8914, dtype: float64
# mi                 16.000000
# count_order    292560.857283
# Name: 8915, dtype: float64
# mi                 16.000000
# count_order    292591.974964
# Name: 8916, dtype: float64
# mi                 16.000000
# count_order    291807.612155
# Name: 8917, dtype: float64
# mi                 16.000000
# count_order    290986.097688
# Name: 8918, dtype: float64
# mi                 16.000000
# count_order    291826.376074
# Name: 8919, dtype: float64
# mi                 16.000000
# count_order    292117.549247
# Name: 8920, dtype: float64
# mi                 16.000000
# count_order    292496.983137
# Name: 8921, dtype: float64
# mi                 16.000000
# count_order    292565.596903
# Name: 8922, dtype: float64
# mi                 16.00000
# count_order    292100.75751
# Name: 8923, dtype: float64
# mi                 16.00000
# count_order    291757.12881
# Name: 8924, dtype: float64
# mi                 16.000000
# count_order    293000.435309
# Name: 8925, dtype: float64
# mi                 16.000000
# count_order    292974.216331
# Name: 8926, dtype: float64
# mi                 16.000000
# count_order    292314.622342
# Name: 8927, dtype: float64
# mi                 16.000000
# count_order    292120.061039
# Name: 8928, dtype: float64
# mi                 16.000000
# count_order    291924.252582
# Name: 8929, dtype: float64
# mi                 16.000000
# count_order    291897.574075
# Name: 8930, dtype: float64
# mi                 16.000000
# count_order    292190.886155
# Name: 8931, dtype: float64
# mi                 16.000000
# count_order    292322.018829
# Name: 8932, dtype: float64
# mi                 16.000000
# count_order    291636.654336
# Name: 8933, dtype: float64
# mi                 16.00000
# count_order    291597.48758
# Name: 8934, dtype: float64
# mi                 16.000000
# count_order    291395.164716
# Name: 8935, dtype: float64
# mi                 16.000000
# count_order    291964.346846
# Name: 8936, dtype: float64
# mi                 16.000000
# count_order    292101.674373
# Name: 8937, dtype: float64
# mi                 16.000000
# count_order    292610.867783
# Name: 8938, dtype: float64
# mi                 16.000000
# count_order    291656.525401
# Name: 8939, dtype: float64
# mi                 16.000000
# count_order    292766.390194
# Name: 8940, dtype: float64
# mi                 16.000000
# count_order    291730.677019
# Name: 8941, dtype: float64
# mi                 16.000000
# count_order    292059.547644
# Name: 8942, dtype: float64
# mi                 16.000000
# count_order    292350.912545
# Name: 8943, dtype: float64
# mi                 16.000000
# count_order    292346.616472
# Name: 8944, dtype: float64
# mi                 16.000000
# count_order    291944.786621
# Name: 8945, dtype: float64
# mi                 16.000000
# count_order    291735.122151
# Name: 8946, dtype: float64
# mi                 16.000000
# count_order    291739.242054
# Name: 8947, dtype: float64
# mi                 16.000000
# count_order    292320.641107
# Name: 8948, dtype: float64
# mi                 16.000000
# count_order    292836.206534
# Name: 8949, dtype: float64
# mi                 16.000000
# count_order    292689.459894
# Name: 8950, dtype: float64
# mi                 16.000000
# count_order    291431.333139
# Name: 8951, dtype: float64
# mi                 16.000000
# count_order    292131.006966
# Name: 8952, dtype: float64
# mi                 16.000000
# count_order    291484.607166
# Name: 8953, dtype: float64
# mi                 16.000000
# count_order    291625.591184
# Name: 8954, dtype: float64
# mi                 16.000000
# count_order    292034.741522
# Name: 8955, dtype: float64
# mi                 16.000000
# count_order    292447.621807
# Name: 8956, dtype: float64
# mi                 16.000000
# count_order    290776.105325
# Name: 8957, dtype: float64
# mi                 16.000000
# count_order    291437.485047
# Name: 8958, dtype: float64
# mi                 16.000000
# count_order    291713.954716
# Name: 8959, dtype: float64
# mi                 16.000000
# count_order    291743.226828
# Name: 8960, dtype: float64
# mi                 16.000000
# count_order    292386.901324
# Name: 8961, dtype: float64
# mi                 16.00000
# count_order    290881.04117
# Name: 8962, dtype: float64
# mi                 16.00000
# count_order    292294.30088
# Name: 8963, dtype: float64
# mi                 16.000000
# count_order    292236.689565
# Name: 8964, dtype: float64
# mi                 16.000000
# count_order    291067.324153
# Name: 8965, dtype: float64
# mi                 16.000000
# count_order    293266.198436
# Name: 8966, dtype: float64
# mi                 16.000000
# count_order    292529.016191
# Name: 8967, dtype: float64
# mi                 16.000000
# count_order    291448.340085
# Name: 8968, dtype: float64
# mi                 16.000000
# count_order    292027.948443
# Name: 8969, dtype: float64
# mi                 16.000000
# count_order    291895.381379
# Name: 8970, dtype: float64
# mi                 16.000000
# count_order    291753.504271
# Name: 8971, dtype: float64
# mi                 16.000000
# count_order    291776.827431
# Name: 8972, dtype: float64
# mi                 16.00000
# count_order    291955.00158
# Name: 8973, dtype: float64
# mi                 16.000000
# count_order    291414.129633
# Name: 8974, dtype: float64
# mi                 16.000000
# count_order    291070.993787
# Name: 8975, dtype: float64
# mi                 16.00000
# count_order    291397.12229
# Name: 8976, dtype: float64
# mi                 16.000000
# count_order    291627.656822
# Name: 8977, dtype: float64
# mi                 16.000000
# count_order    291993.561596
# Name: 8978, dtype: float64
# mi                 16.000000
# count_order    292076.107648
# Name: 8979, dtype: float64
# mi                 16.000000
# count_order    292090.499181
# Name: 8980, dtype: float64
# mi                 16.000000
# count_order    291934.769586
# Name: 8981, dtype: float64
# mi                 16.000000
# count_order    291643.493801
# Name: 8982, dtype: float64
# mi                 16.000000
# count_order    292441.964497
# Name: 8983, dtype: float64
# mi                 16.0000
# count_order    291493.9516
# Name: 8984, dtype: float64
# mi                 16.000000
# count_order    291827.651019
# Name: 8985, dtype: float64
# mi                 16.000000
# count_order    290694.358616
# Name: 8986, dtype: float64
# mi                 16.000000
# count_order    292609.162741
# Name: 8987, dtype: float64
# mi                 16.000000
# count_order    291897.120528
# Name: 8988, dtype: float64
# mi                 16.000000
# count_order    291283.499381
# Name: 8989, dtype: float64
# mi                 16.000000
# count_order    291875.702874
# Name: 8990, dtype: float64
# mi                 16.000000
# count_order    292835.722548
# Name: 8991, dtype: float64
# mi                 16.00000
# count_order    291499.90575
# Name: 8992, dtype: float64
# mi                 16.000000
# count_order    292101.944363
# Name: 8993, dtype: float64
# mi                 16.000000
# count_order    292602.320211
# Name: 8994, dtype: float64
# mi                 16.000000
# count_order    291838.695529
# Name: 8995, dtype: float64
# mi                 16.000000
# count_order    292096.002087
# Name: 8996, dtype: float64
# mi                 16.000000
# count_order    291993.772509
# Name: 8997, dtype: float64
# mi                 16.000000
# count_order    292339.848849
# Name: 8998, dtype: float64
# mi                 16.000000
# count_order    292415.992225
# Name: 8999, dtype: float64
#              mi  absolute error count_order  relative error count_order
# 0      0.001248                17435.192701                    5.970956
# 1      0.001248                11120.132228                    3.808264
# 2      0.001248                15130.289028                    5.181606
# 3      0.001248                  943.439396                    0.323096
# 4      0.001248                16072.625894                    5.504324
# ...         ...                         ...                         ...
# 8995  16.000000                  161.304471                    0.055241
# 8996  16.000000                   96.002087                    0.032877
# 8997  16.000000                    6.227491                    0.002133
# 8998  16.000000                  339.848849                    0.116387
# 8999  16.000000                  415.992225                    0.142463
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 count_order mean  count_order var
# type factor
# pac  0.001248      292081.989733     1.204318e+08
#      0.015625      291957.220574     9.980061e+06
#      0.031250      292039.155421     4.752424e+06
#      0.062500      292039.701276     2.825978e+06
#      0.250000      292029.542299     9.469084e+05
#      1.000000      291974.136841     4.678215e+05
#      2.000000      292031.046581     3.909614e+05
#      4.000000      291983.342904     3.223736e+05
#      16.000000     291997.510261     3.178942e+05

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error count_order mean  \
# type factor
# pac  0.001248                       8689.612129
#      0.015625                       2524.923868
#      0.031250                       1743.849030
#      0.062500                       1351.517567
#      0.250000                        782.277215
#      1.000000                        542.691100
#      2.000000                        496.979046
#      4.000000                        450.202757
#      16.000000                       453.946719
#
#                 absolute error count_order var  \
# type factor
# pac  0.001248                     4.485356e+07
#      0.015625                     3.600271e+06
#      0.031250                     1.709905e+06
#      0.062500                     9.991273e+05
#      0.250000                     3.352118e+05
#      1.000000                     1.736826e+05
#      2.000000                     1.446908e+05
#      4.000000                     1.197659e+05
#      16.000000                    1.116265e+05
#
#                 relative error count_order mean  \
# type factor
# pac  0.001248                          2.975895
#      0.015625                          0.864700
#      0.031250                          0.597209
#      0.062500                          0.462848
#      0.250000                          0.267903
#      1.000000                          0.185853
#      2.000000                          0.170198
#      4.000000                          0.154179
#      16.000000                         0.155461
#
#                 relative error count_order var
# type factor
# pac  0.001248                         5.260551
#      0.015625                         0.422250
#      0.031250                         0.200542
#      0.062500                         0.117180
#      0.250000                         0.039315
#      1.000000                         0.020370
#      2.000000                         0.016970
#      4.000000                         0.014046
#      16.000000                        0.013092

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#             count_order
# mi
# 0.001248   1.204318e+08
# 0.015625   9.980061e+06
# 0.031250   4.752424e+06
# 0.062500   2.825978e+06
# 0.250000   9.469084e+05
# 1.000000   4.678215e+05
# 2.000000   3.909614e+05
# 4.000000   3.223736e+05
# 16.000000  3.178942e+05

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step              scale
# query       count_order
# mi
# 0.001248   1.186082e+08
# 0.015625   9.475896e+06
# 0.031250   4.737948e+06
# 0.062500   2.368974e+06
# 0.250000   5.922435e+05
# 1.000000   1.480609e+05
# 2.000000   7.403044e+04
# 4.000000   3.701522e+04
# 16.000000  9.253805e+03

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# count_order    0.150002
# dtype: float64
#            count_order
# mi
# 0.001248      0.144695
# 0.015625      0.148503
# 0.031250      0.153032
# 0.062500      0.150314
# 0.250000      0.153100
# 1.000000      0.151294
# 2.000000      0.151071
# 4.000000      0.145084
# 16.000000     0.152927

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33351/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query           count_order
# mi
# 0.001248        8700.514606
# 0.015625        2479.091519
# 0.031250        1698.653362
# 0.062500        1265.278590
# 0.250000         635.513738
# 1.000000         296.800691
# 2.000000         218.682585
# 4.000000         153.141688
# 16.000000         78.563529

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33351/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33351/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query       count_order
# mi
# 0.001248     292009.936
# 0.015625     292000.970
# 0.031250     291975.846
# 0.062500     292034.284
# 0.250000     292013.368
# 1.000000     291972.926
# 2.000000     292034.372
# 4.000000     291972.418
# 16.000000    291992.910
# step    chosen_sample
# query     count_order
# all mi  292000.781111

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_33351/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#            count_order
# mi
# 0.001248      2.975895
# 0.015625      0.864700
# 0.031250      0.597209
# 0.062500      0.462848
# 0.250000      0.267903
# 1.000000      0.185853
# 2.000000      0.170198
# 4.000000      0.154179
# 16.000000     0.155461

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#            count_order
# mi
# 0.001248      2.831200
# 0.015625      0.716197
# 0.031250      0.444176
# 0.062500      0.312535
# 0.250000      0.114803
# 1.000000      0.034559
# 2.000000      0.019127
# 4.000000      0.009095
# 16.000000     0.002534

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
relative_error_percent(2920374, 292000)
# Out:
# 900.1280821917808
