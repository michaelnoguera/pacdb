# %% [markdown]
# # Modified TPC-H Q15 Microbenchmark
# This file is adapted to use numpy only without Spark.
#
# ```sql
# select
#     l_suppkey as supplier_no,
#     max(l_extendedprice * (1 - l_discount)) as max_revenue
#   from
#     lineitem
#   where
#     l_suppkey = 271;
# ```

# %%
EXPERIMENT = 'pac-q15-modified-max-271'
OUTPUT_DIR = f'./outputs/{EXPERIMENT}'
GENERATE = True
USE_EVEN_NUMBER_OF_INPUT_ROWS = False
SEED_RANDOM_NUMBER_GENERATOR = True

SAMPLING_METHOD = 'poisson' # 'poisson' or 'half'

if GENERATE:
    print("GENERATE = True, so we will generate new samples.")
else:
    print("GENERATE = False, so we will load saved output from files rather than recomputing.")

import os
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
# Out:
# GENERATE = True, so we will generate new samples.

# %%
import pandas as pd
### Data Setup
# nation_df = pd.read_parquet('./data/tpch/nation.parquet')
# region_df = pd.read_parquet('./data/tpch/region.parquet')
lineitem_df = pd.read_parquet('./data/tpch/lineitem.parquet')
# supplier_df = pd.read_parquet('./data/tpch/supplier.parquet')
# part_df = pd.read_parquet('./data/tpch/part.parquet')

# %%
lineitem_df.head()
# Out:
#    l_orderkey  l_partkey  l_suppkey  l_linenumber l_quantity l_extendedprice  \
# 0           1      15519        785             1      17.00        24386.67
# 1           1       6731        732             2      36.00        58958.28
# 2           1       6370        371             3       8.00        10210.96
# 3           1        214        465             4      28.00        31197.88
# 4           1       2403        160             5      24.00        31329.60
#
#   l_discount l_tax l_returnflag l_linestatus  l_shipdate l_commitdate  \
# 0       0.04  0.02            N            O  1996-03-13   1996-02-12
# 1       0.09  0.06            N            O  1996-04-12   1996-02-28
# 2       0.10  0.02            N            O  1996-01-29   1996-03-05
# 3       0.09  0.06            N            O  1996-04-21   1996-03-30
# 4       0.10  0.04            N            O  1996-03-30   1996-03-14
#
#   l_receiptdate     l_shipinstruct l_shipmode  \
# 0    1996-03-22  DELIVER IN PERSON      TRUCK
# 1    1996-04-20   TAKE BACK RETURN       MAIL
# 2    1996-01-31   TAKE BACK RETURN    REG AIR
# 3    1996-05-16               NONE        AIR
# 4    1996-04-01               NONE        FOB
#
#                             l_comment
# 0             to beans x-ray carefull
# 1   according to the final foxes. qui
# 2       ourts cajole above the furiou
# 3             s cajole busily above t
# 4             the regular, regular pa

# %%
import numpy as np
lineitem_df['revenue'] = lineitem_df['l_extendedprice'] * (1 - lineitem_df['l_discount'])
lineitem_df_test = lineitem_df[['l_suppkey', 'revenue']]
grouped = lineitem_df_test.groupby('l_suppkey').agg(
    count=('revenue', 'count'),
    min_revenue=('revenue', 'min'),
    max_revenue=('revenue', 'max')
).reset_index()
grouped['range'] = np.abs(grouped['min_revenue'] - grouped['max_revenue'])
grouped_sorted = grouped.sort_values(by='count', ascending=False)

print(grouped_sorted)
print(grouped_sorted.loc[grouped_sorted['range'].idxmin()])
print(grouped_sorted.loc[grouped_sorted['range'].idxmax()])
# Out:
#      l_suppkey  count min_revenue max_revenue       range
# 73          74    702    925.3665  84466.2000  83540.8335
# 346        347    677    906.4328  85595.1600  84688.7272
# 754        755    675   1090.8280  91828.4598  90737.6318
# 755        756    670   1102.3104  92118.0400  91015.7296
# 450        451    667    990.1620  90009.0800  89018.9180
# ..         ...    ...         ...         ...         ...
# 554        555    536    859.0673  83338.7100  82479.6427
# 188        189    533    983.8620  91027.0350  90043.1730
# 685        686    532    981.1347  88065.3186  87084.1839
# 213        214    530   1082.1216  93197.5000  92115.3784
# 555        556    525    892.0690  80695.9587  79803.8897
#
# [1000 rows x 5 columns]
# l_suppkey             271
# count                 636
# min_revenue      892.4097
# max_revenue    77643.8400
# range          76751.4303
# Name: 270, dtype: object
# l_suppkey             528
# count                 597
# min_revenue      878.4000
# max_revenue    95699.5000
# range          94821.1000
# Name: 527, dtype: object

# %% [markdown]
# ### Running PAC

# %%
from typing import Any, Callable, Dict, List, Tuple, Union

import numpy as np
if SEED_RANDOM_NUMBER_GENERATOR:
    np.random.seed(0)

import pandas as pd
from pandas import DataFrame
import concurrent.futures
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
from numpy.random import laplace
from functools import reduce
import operator
from IPython.display import display, HTML
from datetime import date

# %%
### Mayuri's conversion functions between DP epsilon and PAC MI using posterior advantage for equivalence
def calc_posterior(mi, prior=0.5, prec = 100000):
    test_vals = [x / prec for x in range(1, prec)]
    max_t = None
    for t in test_vals:
        if t*np.log(t/prior)+(1-t)*np.log((1-t)/(1-prior)) <= mi:
            if  max_t is None or t > max_t:
                max_t = t
    return max_t

def dp_epsilon_to_posterior_success(epsilon):
    return 1 - 1./(1+np.exp(epsilon))

def dp_ps_to_epsilon(ps):
    return np.log(ps / (1-ps))

# example usage:
# dp_ps_to_epsilon(calc_posterior(1/256.))

# %%
def runquery(lineitem_df: DataFrame) -> int:
    lineitem_df = lineitem_df[lineitem_df['l_suppkey'] == 261]
    #print(len(lineitem_df))
    
    aggregated_result = [float(lineitem_df['revenue'].max())]

    #print(aggregated_result)

    return aggregated_result

# %%
true_result = runquery(lineitem_df)

# %%
### Query Setup
SAMPLES = 8192
assert SAMPLES % 2 == 0, "We need an even number of samples for paired sampling."
number_of_pairs = SAMPLES // 2

OUTPUT_COLS = ['max_revenue']

number_of_contributing_rows = 584  # hardcode number of eligible rows

def poisson_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select a subset of indices, where each index is selected with probability 0.5.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    mask = np.random.random_sample(len(df)) < 0.5  # Generates a bitmask of length df.shape[0] where each bit is 1 with probability 0.5
    selected = df[mask]
    not_selected = df[~mask]
    return selected, not_selected

def half_paired_sample(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    """
    This will select half of the row indices from the dataframe at random.
    The first result is the dataframe composed of the selected rows.
    The second result is the complement / the dataframe composed of the rows that were not selected.
    """
    indices = np.random.choice(df.index, size=(df.shape[0] // 2), replace=False)
    not_indices = list(set(df.index) - set(indices))
    selected: DataFrame = df.loc[indices]
    not_selected: DataFrame = df.loc[not_indices]
    return (selected, not_selected)

def sample_using_chosen_method(df: DataFrame) -> Tuple[DataFrame, DataFrame]:
    if SAMPLING_METHOD == 'poisson':
        return poisson_paired_sample(df)
    elif SAMPLING_METHOD == 'half':
        return half_paired_sample(df)

def generate_samples(laplace_lambda: float = 1.0, alpha: int = 10) -> List[np.ndarray]:
    # Apply thresholding: if there are less than alpha samples
    # (with some Laplacian noise), then we don't subsample and return None.
    laplace_noise: float = np.random.laplace(scale=laplace_lambda)

    if number_of_contributing_rows + laplace_noise < alpha:  # if we don't get enough results from the query
        print("There are not enough rows contributing to the result for PAC to be meaningful.")
        return []
    
    number_of_pairs = SAMPLES // 2
    out_np: List[np.ndarray] = []
    for i in range(number_of_pairs):
        print(f'iteration : {i}')
        
        for temp_df in sample_using_chosen_method(lineitem_df.reset_index(drop=True)):  # reset index to sequential
            out = runquery(temp_df)
            # double the sums and counts, avg stays the same
            # out[0] *= 2

            # for a 2d array, flatten it
            out_np.append(np.array(out))

    return out_np

# %%
### Compute PAC Noise
def get_pac_noise_scale(out_np_raw: List[np.ndarray],
                           max_mi: float = 1./4) -> np.ndarray:
    if out_np_raw is None or len(out_np_raw) == 0:
        raise ValueError("Input list out_np cannot be empty.")
    out_np = out_np_raw.copy()
    # print(out_np)
    dimensions: int = len(out_np[0])
    print(f'The dimensions are - {dimensions}')

    out_np_2darr = [np.atleast_2d(o) for o in out_np] # make sure all the DF -> np.ndarray conversions result in 2d arrays
    print(out_np_2darr)
    est_y: np.ndarray = np.stack(out_np_2darr, axis=-1).reshape(dimensions, len(out_np))  # shape (dimensions, samples)
    print(f"est_y.shape: {est_y.shape}")
    print(f"est_y: {est_y}")

    # get the scale in each basis direction
    fin_var: np.ndarray = np.var(est_y, axis=1)  # shape (dimensions,)
    print(f"fin_var: {fin_var}")
    # fin_var: np.ndarray = np.array([float(x) for x in fin_var], dtype=np.float64)
    sqrt_total_var: np.floating[Any] = np.sum(np.sqrt(fin_var))
    print(f"sqrt_total_var: {sqrt_total_var}")

    pac_noise: np.ndarray = (1./(2*max_mi)) * sqrt_total_var * np.sqrt(fin_var)  # scale of the PAC noise
    print(f"For mi={max_mi}, we should add noise from a normal distribution with scale...")
    print(f"\t{1./(2*max_mi)} * {sqrt_total_var} * {np.sqrt(fin_var)} = {pac_noise}")
    print(f"pac_noise: {pac_noise}")
    return pac_noise

def do_pac_and_release(out_np: List[np.ndarray],
                       max_mi: float = 1./4,
                       scale: np.ndarray = None,
                       chosen_index: int = None) -> np.ndarray:
    
    if scale is not None:
        pac_noise: np.ndarray = scale
    else:
        pac_noise = get_pac_noise_scale(out_np, max_mi)

    pac_noises_to_add: np.ndarray = np.random.normal(loc=0, scale=pac_noise)
    # Add noise element-wise to the outputs
    if chosen_index is None:  # allow for overriding the chosen index to specify which sample to use for the release
        chosen_index = np.random.choice(range(SAMPLES))
    pac_release = out_np[chosen_index] + pac_noises_to_add
    
    return pac_release

# %% [markdown]
# To replicate the experiment that runs for epsilon=0.01, 0.1, 1, 10
# we use mi=1, 1/4, 1/16, 1/64, 1/256 in the hopes of encompassing a similar range.

# %%
MI_OPTIONS = [0.001248318631131131, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
EXPERIMENTS = 1000

if GENERATE:
    experiment_results = []
    saved_steps = []

    out_np = generate_samples() # generate samples (results of running the query)
    print(f"Generate samples... {len(out_np)} samples generated.")

    for mi in MI_OPTIONS:
        print("Getting PAC Noise...")
        scale = get_pac_noise_scale(out_np, mi) # estimate the stability of the query
        print(f"mi={mi}, scale={scale}")
        
        for e in range(EXPERIMENTS):
            # for each PAC release at this MI, we will choose a sample from the pre-generated out_np list and add noise to it
            steps = {
                "mi": mi,
                "scale": scale,
            }

            # choose our sample
            chosen_index = np.random.choice(range(SAMPLES))
            chosen_sample = out_np[chosen_index].copy()
            steps["chosen_sample"] = chosen_sample
            
            # add noise to it
            # chosen_noise will also be an array
            
            chosen_noise = np.random.normal(loc=0, scale=np.sqrt(scale))
            steps["chosen_noise"] = chosen_noise
            
            print(f'Chosen Sample {chosen_sample}')
            # chosen_sample = np.array([float(x) for x in chosen_sample], dtype=np.float64)
            release = chosen_sample + chosen_noise # do_pac_and_release(out_np, mi, scale, chosen_index)

            #print(f"sample(#{chosen_index}):{chosen_sample} + noise:{chosen_noise} = {release}")
            steps["release"] = release
            #release[0] *= 2   # manually correct count = count * 2

            # manually add sum as count * mean
            #noisy_output = [noisy_output[0], noisy_output[0] * noisy_output[1], noisy_output[1]]
            #chosen_sample = [chosen_sample[0], chosen_sample[0] * chosen_sample[1], chosen_sample[1]]
            experiment_results.append([mi, *release])
            saved_steps.append(steps)
    
    df = pd.DataFrame(experiment_results, columns=['mi', *OUTPUT_COLS])
    
    # Save the new data to outputs/...
    df.to_parquet(f'{OUTPUT_DIR}/pac_results.parquet')
    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'wb') as f:
        pickle.dump(experiment_results, f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'wb') as f:
        pickle.dump(saved_steps, f)
else:
    df = pq.read_table(f"{OUTPUT_DIR}/pac_results.parquet").to_pandas()

    with open(f'{OUTPUT_DIR}/experiment_results.pkl', 'rb') as f:
        experiment_results = pickle.load(f)
    with open(f'{OUTPUT_DIR}/saved_steps.pkl', 'rb') as f:
        saved_steps = pickle.load(f)

# df.head()
# Out:
# iteration : 0
# iteration : 1
# iteration : 2
# iteration : 3
# iteration : 4
# iteration : 5
# iteration : 6
# iteration : 7
# iteration : 8
# iteration : 9
# iteration : 10
# iteration : 11
# iteration : 12
# iteration : 13
# iteration : 14
# iteration : 15
# iteration : 16
# iteration : 17
# iteration : 18
# iteration : 19
# iteration : 20
# iteration : 21
# iteration : 22
# iteration : 23
# iteration : 24
# iteration : 25
# iteration : 26
# iteration : 27
# iteration : 28
# iteration : 29
# iteration : 30
# iteration : 31
# iteration : 32
# iteration : 33
# iteration : 34
# iteration : 35
# iteration : 36
# iteration : 37
# iteration : 38
# iteration : 39
# iteration : 40
# iteration : 41
# iteration : 42
# iteration : 2865
# iteration : 2866
# iteration : 2867
# iteration : 2868
# iteration : 2869
# iteration : 2870
# iteration : 2871
# iteration : 2872
# iteration : 2873
# iteration : 2874
# iteration : 2875
# iteration : 2876
# iteration : 2877
# iteration : 2878
# iteration : 2879
# iteration : 2880
# iteration : 2881
# iteration : 2882
# iteration : 2883
# iteration : 2884
# iteration : 2885
# iteration : 2886
# iteration : 2887
# ...
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [85994.55]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88918.3647]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [83529.3729]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [82157.625]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88918.3647]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [83529.3729]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88956.5845]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88956.5845]
# Chosen Sample [88918.3647]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88956.5845]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88956.5845]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [88918.3647]
# Chosen Sample [82172.57]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88918.3647]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88956.5845]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [85994.55]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88956.5845]
# Chosen Sample [93638.51]
# Chosen Sample [85994.55]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88956.5845]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [85994.55]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [88956.5845]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [78743.125]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [85994.55]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [88956.5845]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [88918.3647]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [88956.5845]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [85994.55]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [89816.53]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [83529.3729]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [95549.5]
# Chosen Sample [93638.51]

# %%
saved_steps_df_temp = pd.DataFrame(saved_steps)
saved_steps_df_temp.head()
# Out:
#          mi                 scale chosen_sample          chosen_noise  \
# 0  0.001248  [2153761146.9292293]  [88918.3647]  [-74679.96930086424]
# 1  0.001248  [2153761146.9292293]     [95549.5]  [-47138.97925752483]
# 2  0.001248  [2153761146.9292293]     [95549.5]   [62199.05453279012]
# 3  0.001248  [2153761146.9292293]    [93638.51]  [-4207.767929764625]
# 4  0.001248  [2153761146.9292293]     [95549.5]  [-68319.70581023244]
#
#                 release
# 0   [14238.39539913577]
# 1   [48410.52074247517]
# 2  [157748.55453279012]
# 3   [89430.74207023537]
# 4  [27229.794189767563]

# %%
### Reconstruct Saved Steps
# Get list of keys from the first dict, excluding 'mi' since it's not a list
steps = [k for k in saved_steps[0].keys() if k not in ('mi')] # pull keys from saved_steps[0]

saved_steps_df_temp = pd.DataFrame(saved_steps)

# Create expanded columns using comprehension
expanded = {
    'mi': saved_steps_df_temp['mi'],
    **{f'{step}_{col}': saved_steps_df_temp[step].str[i] 
        for step in steps
        for i, col in enumerate(OUTPUT_COLS)}
}

# Create MultiIndex DataFrame using OUTPUT_COLS
saved_steps_df = pd.DataFrame(expanded)
saved_steps_df.columns = pd.MultiIndex.from_tuples([('mi',''), *[  # multiindex so that we can do things like saved_steps_df['release'][<aggregation>]
    (step, col) for step in steps for col in OUTPUT_COLS
]], names=["step", "query"])
saved_steps_df.head()
# Out:
# step         mi         scale chosen_sample  chosen_noise        release
# query             max_revenue   max_revenue   max_revenue    max_revenue
# 0      0.001248  2.153761e+09    88918.3647 -74679.969301   14238.395399
# 1      0.001248  2.153761e+09    95549.5000 -47138.979258   48410.520742
# 2      0.001248  2.153761e+09    95549.5000  62199.054533  157748.554533
# 3      0.001248  2.153761e+09    93638.5100  -4207.767930   89430.742070
# 4      0.001248  2.153761e+09    95549.5000 -68319.705810   27229.794190

# %%
saved_steps_df.groupby('mi').mean()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_42843/2569112584.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df.groupby('mi').mean()
# step              scale chosen_sample chosen_noise       release
# query       max_revenue   max_revenue  max_revenue   max_revenue
# mi
# 0.001248   2.153761e+09  94605.784404   307.042021  94912.826426
# 0.015625   1.720691e+08  94440.835454  -186.429095  94254.406359
# 0.031250   8.603457e+07  94559.359219   269.779951  94829.139170
# 0.062500   4.301728e+07  94565.061675    23.084598  94588.146273
# 0.250000   1.075432e+07  94576.053565    68.923416  94644.976981
# 1.000000   2.688580e+06  94563.425462     5.159746  94568.585208
# 2.000000   1.344290e+06  94619.757906   -14.170581  94605.587326
# 4.000000   6.721450e+05  94461.897818    46.554212  94508.452030
# 16.000000  1.680363e+05  94600.646029    19.603055  94620.249085

# %%
saved_steps_df[saved_steps_df['mi'] == 1/4]['chosen_sample']['max_revenue'].hist()
# Out:
# <Axes: >

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of chosen_sample['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['chosen_sample']['mean'].hist()

# %%
if ('mean' in OUTPUT_COLS):
    print("Mean of release['mean'] for mi = 1/32")
    saved_steps_df[saved_steps_df['mi'] == 1/32]['release']['mean'].hist()

# %%
### DEBUG: Save the variables from computing the PAC noises for later reverse engineering
#if GENERATE:
#    saved_pac_variables_df = pd.DataFrame(saved_pac_variables, columns=['mi', 'out_np_0', 'fin_var', 'sqrt_total_var', 'pac_noise', 'pac_noises_to_add', 'pac_release'])
#    saved_pac_variables_df.to_parquet(f'{OUTPUT_DIR}/saved_pac_variables.parquet')
#else:
#    saved_pac_variables_df = pq.read_table(f"{OUTPUT_DIR}/saved_pac_variables.parquet").to_pandas()
#saved_pac_variables_df.head()

# %% [markdown]
# ### Computing PAC Errors

# %%
# functions to calculate errors
def absolute_scaled_error(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return np.abs(est - actual)
def relative_error_percent(est: np.ndarray, actual: np.ndarray) -> np.ndarray:
    return (np.abs(est - actual) / actual) * 100

# %%
#OUTPUT_COLS = OUTPUT_COLS
ERROR_COLS = [*[f'absolute error {i}' for i in OUTPUT_COLS], *[f'relative error {i}' for i in OUTPUT_COLS]]

# %%
# compute errors for PAC (or import from saved file)
if GENERATE:
    errors_list = []
    for i, row in df.iterrows():
        print(row)
        mi = row['mi']
        r = row[OUTPUT_COLS].to_numpy()
        errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
    pac_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
    pac_errors_df.to_parquet(f"{OUTPUT_DIR}/pac_errors.parquet")  # overwrite saved
else:
    pac_errors_df = pq.read_table(f"{OUTPUT_DIR}/pac_errors.parquet").to_pandas()
pac_errors_df
# Out:
# mi                 0.001248
# max_revenue    14238.395399
# Name: 0, dtype: float64
# mi                 0.001248
# max_revenue    48410.520742
# Name: 1, dtype: float64
# mi                  0.001248
# max_revenue    157748.554533
# Name: 2, dtype: float64
# mi                 0.001248
# max_revenue    89430.742070
# Name: 3, dtype: float64
# mi                 0.001248
# max_revenue    27229.794190
# Name: 4, dtype: float64
# mi                 0.001248
# max_revenue    32210.458886
# Name: 5, dtype: float64
# mi                 0.001248
# max_revenue    83029.377841
# Name: 6, dtype: float64
# mi                 0.001248
# max_revenue    82013.286988
# Name: 7, dtype: float64
# mi                  0.001248
# max_revenue    147915.982140
# Name: 8, dtype: float64
# mi                  0.001248
# max_revenue    173122.407856
# Name: 9, dtype: float64
# mi                 0.001248
# max_revenue    42101.406973
# Name: 10, dtype: float64
# mi                 0.001248
# max_revenue    76241.658392
# Name: 11, dtype: float64
# mi                  0.001248
# max_revenue    137243.746646
# Name: 12, dtype: float64
# mi                 0.001248
# max_revenue    20000.126565
# Name: 13, dtype: float64
# mi                 0.001248
# max_revenue    58096.112626
# Name: 14, dtype: float64
# mi                  0.001248
# max_revenue    161122.191687
# Name: 15, dtype: float64
# mi                 0.001248
# max_revenue    90262.125079
# Name: 16, dtype: float64
# mi                 0.001248
# max_revenue    91971.060251
# Name: 17, dtype: float64
# mi                 0.001248
# max_revenue    87471.730074
# Name: 18, dtype: float64
# mi                 0.001248
# max_revenue    95628.411446
# Name: 19, dtype: float64
# mi                  0.001248
# max_revenue    124878.292366
# Name: 20, dtype: float64
# mi                  0.001248
# max_revenue    168785.073002
# Name: 21, dtype: float64
# mi                0.001248
# max_revenue    3043.139502
# Name: 22, dtype: float64
# mi                  0.001248
# max_revenue    102132.998267
# Name: 23, dtype: float64
# mi                  0.001248
# max_revenue    110322.353709
# Name: 24, dtype: float64
# mi                  0.001248
# max_revenue    145736.309104
# Name: 25, dtype: float64
# mi                 0.001248
# max_revenue    98645.791763
# Name: 26, dtype: float64
# mi                 0.001248
# max_revenue    74370.693248
# Name: 27, dtype: float64
# mi                 0.001248
# max_revenue    50001.872362
# Name: 28, dtype: float64
# mi                 0.001248
# max_revenue    59592.433735
# Name: 29, dtype: float64
# mi                 0.001248
# max_revenue    97631.825190
# Name: 30, dtype: float64
# mi                 0.001248
# max_revenue    29200.861991
# Name: 31, dtype: float64
# mi                  0.001248
# max_revenue    200952.827272
# Name: 32, dtype: float64
# mi                 0.001248
# max_revenue    73329.147435
# Name: 33, dtype: float64
# mi                 0.001248
# max_revenue   -11854.756642
# Name: 34, dtype: float64
# mi                  0.001248
# max_revenue    152504.613159
# Name: 35, dtype: float64
# mi                  0.001248
# max_revenue    117211.666422
# Name: 36, dtype: float64
# mi                 0.001248
# max_revenue    19704.774329
# Name: 37, dtype: float64
# mi                  0.001248
# max_revenue    126857.472529
# Name: 38, dtype: float64
# mi                  0.001248
# max_revenue    143741.092138
# Name: 39, dtype: float64
# mi                  0.001248
# max_revenue    187390.734996
# Name: 40, dtype: float64
# mi                  0.001248
# max_revenue    168373.481735
# Name: 41, dtype: float64
# mi                  0.001248
# max_revenue    179357.724595
# Name: 42, dtype: float64
# mi                  0.001248
# max_revenue    154812.842593
# Name: 43, dtype: float64
# mi                 0.001248
# max_revenue    28122.719846
# Name: 44, dtype: float64
# mi                  0.001248
# max_revenue    117269.859196
# Name: 45, dtype: float64
# mi                 0.001248
# max_revenue    60692.248429
# Name: 46, dtype: float64
# mi                  0.001248
# max_revenue    118805.316679
# Name: 47, dtype: float64
# mi                 0.001248
# max_revenue    85097.343547
# Name: 48, dtype: float64
# mi                  0.001248
# max_revenue    118396.538618
# Name: 49, dtype: float64
# mi                  0.001248
# max_revenue    169346.833332
# Name: 50, dtype: float64
# mi                  0.001248
# max_revenue    131024.891129
# Name: 51, dtype: float64
# mi                  0.001248
# max_revenue    210458.306318
# Name: 52, dtype: float64
# mi                 0.001248
# max_revenue   -35928.407788
# Name: 53, dtype: float64
# mi                 0.001248
# max_revenue    11005.700016
# Name: 54, dtype: float64
# mi                 0.001248
# max_revenue    77912.636232
# Name: 55, dtype: float64
# mi                  0.001248
# max_revenue    204989.992206
# Name: 56, dtype: float64
# mi                  0.001248
# max_revenue    115262.020499
# Name: 57, dtype: float64
# mi                 0.001248
# max_revenue    64849.718735
# Name: 58, dtype: float64
# mi                 0.001248
# max_revenue    90268.010231
# Name: 59, dtype: float64
# mi                  0.001248
# max_revenue    121800.772724
# Name: 60, dtype: float64
# mi                 0.001248
# max_revenue    88914.881056
# Name: 61, dtype: float64
# mi                 0.001248
# max_revenue    60315.039175
# Name: 62, dtype: float64
# mi                  0.001248
# max_revenue    111156.193407
# Name: 63, dtype: float64
# mi                  0.001248
# max_revenue    162823.719964
# Name: 64, dtype: float64
# mi                 0.001248
# max_revenue    98033.918677
# Name: 65, dtype: float64
# mi                 0.001248
# max_revenue    76368.348911
# Name: 66, dtype: float64
# mi                  0.001248
# max_revenue    122815.556476
# Name: 67, dtype: float64
# mi                  0.001248
# max_revenue    153154.893931
# Name: 68, dtype: float64
# mi                  0.001248
# max_revenue    125844.093947
# Name: 69, dtype: float64
# mi                 0.001248
# max_revenue    39153.424712
# Name: 70, dtype: float64
# mi                  0.001248
# max_revenue    106758.396677
# Name: 71, dtype: float64
# mi                 0.001248
# max_revenue    88194.790569
# Name: 72, dtype: float64
# mi                 0.001248
# max_revenue    73141.452432
# Name: 73, dtype: float64
# mi                  0.001248
# max_revenue    142516.440126
# Name: 74, dtype: float64
# mi                 0.001248
# max_revenue    57715.839492
# Name: 75, dtype: float64
# mi                 0.001248
# max_revenue    77237.369143
# Name: 76, dtype: float64
# mi                 0.001248
# max_revenue    66307.814256
# Name: 77, dtype: float64
# mi                 0.001248
# max_revenue   -21117.539773
# Name: 78, dtype: float64
# mi                 0.001248
# max_revenue    37835.398116
# Name: 79, dtype: float64
# mi                 0.001248
# max_revenue    48333.224354
# Name: 80, dtype: float64
# mi                 0.001248
# max_revenue    12747.218549
# Name: 81, dtype: float64
# mi                 0.001248
# max_revenue    23455.713999
# Name: 82, dtype: float64
# mi                  0.001248
# max_revenue    121579.992271
# Name: 83, dtype: float64
# mi                 0.001248
# max_revenue    88998.686990
# Name: 84, dtype: float64
# mi                 0.001248
# max_revenue    72685.411453
# Name: 85, dtype: float64
# mi                 0.001248
# max_revenue    92848.726086
# Name: 86, dtype: float64
# mi                  0.001248
# max_revenue    195812.181296
# Name: 87, dtype: float64
# mi                  0.001248
# max_revenue    120747.023174
# Name: 88, dtype: float64
# mi                 0.001248
# max_revenue    28422.170416
# Name: 89, dtype: float64
# mi                  0.001248
# max_revenue    122021.083752
# Name: 90, dtype: float64
# mi                  0.001248
# max_revenue    117573.513852
# Name: 91, dtype: float64
# mi                  0.001248
# max_revenue    116412.813595
# Name: 92, dtype: float64
# mi                  0.001248
# max_revenue    105522.500573
# Name: 93, dtype: float64
# mi                  0.001248
# max_revenue    146539.370738
# Name: 94, dtype: float64
# mi                 0.001248
# max_revenue    47308.073327
# Name: 95, dtype: float64
# mi                 0.001248
# max_revenue    85417.687189
# Name: 96, dtype: float64
# mi                 0.001248
# max_revenue    93042.551205
# Name: 97, dtype: float64
# mi                 0.001248
# max_revenue    61722.875024
# Name: 98, dtype: float64
# mi                  0.001248
# max_revenue    138515.021168
# Name: 99, dtype: float64
# mi                  0.001248
# max_revenue    129969.204591
# Name: 100, dtype: float64
# mi                 0.001248
# max_revenue    69915.223569
# Name: 101, dtype: float64
# mi                  0.001248
# max_revenue    131274.751308
# Name: 102, dtype: float64
# mi                 0.001248
# max_revenue    70705.220224
# Name: 103, dtype: float64
# mi                 0.001248
# max_revenue    25856.174405
# Name: 104, dtype: float64
# mi                 0.001248
# max_revenue    61246.774449
# Name: 105, dtype: float64
# mi                 0.001248
# max_revenue    45203.233487
# Name: 106, dtype: float64
# mi                 0.001248
# max_revenue    65207.420830
# Name: 107, dtype: float64
# mi                 0.001248
# max_revenue    28369.838849
# Name: 108, dtype: float64
# mi                 0.001248
# max_revenue    79840.077050
# Name: 109, dtype: float64
# mi                 0.001248
# max_revenue    89984.868867
# Name: 110, dtype: float64
# mi                 0.001248
# max_revenue    69952.545567
# Name: 111, dtype: float64
# mi                 0.001248
# max_revenue    52341.473176
# Name: 112, dtype: float64
# mi                0.001248
# max_revenue    1155.338234
# Name: 113, dtype: float64
# mi                  0.001248
# max_revenue    114879.032587
# Name: 114, dtype: float64
# mi                 0.001248
# max_revenue    15266.823618
# Name: 115, dtype: float64
# mi                 0.001248
# max_revenue    87482.825576
# Name: 116, dtype: float64
# mi                  0.001248
# max_revenue    123700.597383
# Name: 117, dtype: float64
# mi                  0.001248
# max_revenue    151738.781466
# Name: 118, dtype: float64
# mi                  0.001248
# max_revenue    213745.886714
# Name: 119, dtype: float64
# mi                  0.001248
# max_revenue    113102.602590
# Name: 120, dtype: float64
# mi                 0.001248
# max_revenue    72808.633295
# Name: 121, dtype: float64
# mi                  0.001248
# max_revenue    155059.620793
# Name: 122, dtype: float64
# mi                  0.001248
# max_revenue    105403.098197
# Name: 123, dtype: float64
# mi                  0.001248
# max_revenue    100028.120981
# Name: 124, dtype: float64
# mi                 0.001248
# max_revenue    92906.236273
# Name: 125, dtype: float64
# mi                  0.001248
# max_revenue    197725.359416
# Name: 126, dtype: float64
# mi                 0.001248
# max_revenue    98409.807125
# Name: 127, dtype: float64
# mi                 0.001248
# max_revenue    73478.071752
# Name: 128, dtype: float64
# mi                  0.001248
# max_revenue    102546.019485
# Name: 129, dtype: float64
# mi                  0.001248
# max_revenue    164563.470046
# Name: 130, dtype: float64
# mi                 0.001248
# max_revenue    79253.380475
# Name: 131, dtype: float64
# mi                  0.001248
# max_revenue    187472.267476
# Name: 132, dtype: float64
# mi                  0.001248
# max_revenue    146975.790454
# Name: 133, dtype: float64
# mi                 0.001248
# max_revenue    42128.174182
# Name: 134, dtype: float64
# mi                 0.001248
# max_revenue    94489.585961
# Name: 135, dtype: float64
# mi                 0.001248
# max_revenue    99674.379235
# Name: 136, dtype: float64
# mi                  0.001248
# max_revenue    129407.463318
# Name: 137, dtype: float64
# mi                  0.001248
# max_revenue    114956.493573
# Name: 138, dtype: float64
# mi                  0.001248
# max_revenue    141344.818446
# Name: 139, dtype: float64
# mi                 0.001248
# max_revenue    66658.757443
# Name: 140, dtype: float64
# mi                 0.001248
# max_revenue    66555.588979
# Name: 141, dtype: float64
# mi                 0.001248
# max_revenue    90938.096988
# Name: 142, dtype: float64
# mi                  0.001248
# max_revenue    177847.178636
# Name: 143, dtype: float64
# mi                  0.001248
# max_revenue    147897.170855
# Name: 144, dtype: float64
# mi                  0.001248
# max_revenue    156108.240485
# Name: 145, dtype: float64
# mi                 0.001248
# max_revenue    37602.333140
# Name: 146, dtype: float64
# mi                 0.001248
# max_revenue    74949.815851
# Name: 147, dtype: float64
# mi                  0.001248
# max_revenue    155862.368470
# Name: 148, dtype: float64
# mi                 0.001248
# max_revenue    81895.527430
# Name: 149, dtype: float64
# mi                 0.001248
# max_revenue    71871.630706
# Name: 150, dtype: float64
# mi                 0.001248
# max_revenue    99888.756152
# Name: 151, dtype: float64
# mi                 0.001248
# max_revenue    33681.788987
# Name: 152, dtype: float64
# mi                 0.001248
# max_revenue    41383.474073
# Name: 153, dtype: float64
# mi                  0.001248
# max_revenue    180506.315467
# Name: 154, dtype: float64
# mi                 0.001248
# max_revenue    62385.302883
# Name: 155, dtype: float64
# mi                  0.001248
# max_revenue    111097.151801
# Name: 156, dtype: float64
# mi                 0.001248
# max_revenue    43791.963018
# Name: 157, dtype: float64
# mi                 0.001248
# max_revenue    86946.417035
# Name: 158, dtype: float64
# mi               0.001248
# max_revenue    523.524455
# Name: 159, dtype: float64
# mi                 0.001248
# max_revenue    79755.917353
# Name: 160, dtype: float64
# mi                 0.001248
# max_revenue    10916.692423
# Name: 161, dtype: float64
# mi                  0.001248
# max_revenue    128472.838153
# Name: 162, dtype: float64
# mi                  0.001248
# max_revenue    133456.290161
# Name: 163, dtype: float64
# mi                  0.001248
# max_revenue    121921.689277
# Name: 164, dtype: float64
# mi                 0.001248
# max_revenue    77469.003400
# Name: 165, dtype: float64
# mi                  0.001248
# max_revenue    128289.670239
# Name: 166, dtype: float64
# mi                 0.001248
# max_revenue    84362.805203
# Name: 167, dtype: float64
# mi                  0.001248
# max_revenue    154133.669069
# Name: 168, dtype: float64
# mi                 0.001248
# max_revenue    29956.768441
# Name: 169, dtype: float64
# mi                  0.001248
# max_revenue    138668.264909
# Name: 170, dtype: float64
# mi                  0.001248
# max_revenue    100214.730593
# Name: 171, dtype: float64
# mi                 0.001248
# max_revenue    42115.230651
# Name: 172, dtype: float64
# mi                 0.001248
# max_revenue    63454.006704
# Name: 173, dtype: float64
# mi                 0.001248
# max_revenue    67434.932236
# Name: 174, dtype: float64
# mi                 0.001248
# max_revenue    87597.611549
# Name: 175, dtype: float64
# mi                  0.001248
# max_revenue    131032.691182
# Name: 176, dtype: float64
# mi                 0.001248
# max_revenue    57747.353565
# Name: 177, dtype: float64
# mi                  0.001248
# max_revenue    133804.081567
# Name: 178, dtype: float64
# mi                  0.001248
# max_revenue    102518.739971
# Name: 179, dtype: float64
# mi                 0.001248
# max_revenue    83619.549593
# Name: 180, dtype: float64
# mi                  0.001248
# max_revenue    105149.622422
# Name: 181, dtype: float64
# mi                  0.001248
# max_revenue    151668.878603
# Name: 182, dtype: float64
# mi                  0.001248
# max_revenue    138001.301977
# Name: 183, dtype: float64
# mi                  0.001248
# max_revenue    134564.874594
# Name: 184, dtype: float64
# mi                 0.001248
# max_revenue    97007.183262
# Name: 185, dtype: float64
# mi                  0.001248
# max_revenue    104757.540286
# Name: 186, dtype: float64
# mi                 0.001248
# max_revenue    57809.552759
# Name: 187, dtype: float64
# mi                 0.001248
# max_revenue    73852.174223
# Name: 188, dtype: float64
# mi                  0.001248
# max_revenue    116141.143850
# Name: 189, dtype: float64
# mi                  0.001248
# max_revenue    173257.482680
# Name: 190, dtype: float64
# mi                  0.001248
# max_revenue    131857.823219
# Name: 191, dtype: float64
# mi                 0.001248
# max_revenue    83243.912124
# Name: 192, dtype: float64
# mi                  0.001248
# max_revenue    128161.638484
# Name: 193, dtype: float64
# mi                  0.001248
# max_revenue    107323.742525
# Name: 194, dtype: float64
# mi                 0.001248
# max_revenue    40192.337632
# Name: 195, dtype: float64
# mi                  0.001248
# max_revenue    179377.516873
# Name: 196, dtype: float64
# mi                 0.001248
# max_revenue    97191.000332
# Name: 197, dtype: float64
# mi                  0.001248
# max_revenue    107207.672792
# Name: 198, dtype: float64
# mi                  0.001248
# max_revenue    115394.724024
# Name: 199, dtype: float64
# mi                  0.001248
# max_revenue    152903.976483
# Name: 200, dtype: float64
# mi                  0.001248
# max_revenue    102658.139259
# Name: 201, dtype: float64
# mi                  0.001248
# max_revenue    225941.219325
# Name: 202, dtype: float64
# mi                 0.001248
# max_revenue    75148.532228
# Name: 203, dtype: float64
# mi                 0.001248
# max_revenue    82852.000851
# Name: 204, dtype: float64
# mi                  0.001248
# max_revenue    133232.878684
# Name: 205, dtype: float64
# mi                 0.001248
# max_revenue    63816.922516
# Name: 206, dtype: float64
# mi                 0.001248
# max_revenue    87330.547507
# Name: 207, dtype: float64
# mi                 0.001248
# max_revenue    63029.863038
# Name: 208, dtype: float64
# mi                 0.001248
# max_revenue    47871.519760
# Name: 209, dtype: float64
# mi                 0.001248
# max_revenue    52495.815049
# Name: 210, dtype: float64
# mi                 0.001248
# max_revenue    89502.528174
# Name: 211, dtype: float64
# mi                 0.001248
# max_revenue    52557.945001
# Name: 212, dtype: float64
# mi                 0.001248
# max_revenue    46796.188686
# Name: 213, dtype: float64
# mi                 0.001248
# max_revenue    82233.037052
# Name: 214, dtype: float64
# mi                 0.001248
# max_revenue    52959.101332
# Name: 215, dtype: float64
# mi                 0.001248
# max_revenue    79207.017622
# Name: 216, dtype: float64
# mi                 0.001248
# max_revenue    90634.811962
# Name: 217, dtype: float64
# mi                 0.001248
# max_revenue    91902.527396
# Name: 218, dtype: float64
# mi                 0.001248
# max_revenue    96613.605009
# Name: 219, dtype: float64
# mi                  0.001248
# max_revenue    135732.394086
# Name: 220, dtype: float64
# mi                  0.001248
# max_revenue    149847.154810
# Name: 221, dtype: float64
# mi                 0.001248
# max_revenue    65814.341950
# Name: 222, dtype: float64
# mi                  0.001248
# max_revenue    102174.056622
# Name: 223, dtype: float64
# mi                 0.001248
# max_revenue    43764.713204
# Name: 224, dtype: float64
# mi                  0.001248
# max_revenue    123991.702868
# Name: 225, dtype: float64
# mi                 0.001248
# max_revenue    95905.006692
# Name: 226, dtype: float64
# mi                 0.001248
# max_revenue    93954.720547
# Name: 227, dtype: float64
# mi                0.001248
# max_revenue    9425.756220
# Name: 228, dtype: float64
# mi                  0.001248
# max_revenue    147480.379235
# Name: 229, dtype: float64
# mi                 0.001248
# max_revenue    57864.866257
# Name: 230, dtype: float64
# mi                 0.001248
# max_revenue    12888.805227
# Name: 231, dtype: float64
# mi                 0.001248
# max_revenue    15711.688519
# Name: 232, dtype: float64
# mi                  0.001248
# max_revenue    124308.486966
# Name: 233, dtype: float64
# mi                 0.001248
# max_revenue    74118.570336
# Name: 234, dtype: float64
# mi                 0.001248
# max_revenue    75069.831614
# Name: 235, dtype: float64
# mi                 0.001248
# max_revenue    83529.003599
# Name: 236, dtype: float64
# mi                  0.001248
# max_revenue    160103.376939
# Name: 237, dtype: float64
# mi                  0.001248
# max_revenue    126063.088561
# Name: 238, dtype: float64
# mi                  0.001248
# max_revenue    153839.188479
# Name: 239, dtype: float64
# mi                  0.001248
# max_revenue    116433.863945
# Name: 240, dtype: float64
# mi                  0.001248
# max_revenue    176307.038479
# Name: 241, dtype: float64
# mi                 0.001248
# max_revenue    64453.190160
# Name: 242, dtype: float64
# mi                  0.001248
# max_revenue    160078.489687
# Name: 243, dtype: float64
# mi                 0.001248
# max_revenue    89662.703929
# Name: 244, dtype: float64
# mi                  0.001248
# max_revenue    118815.841854
# Name: 245, dtype: float64
# mi                  0.001248
# max_revenue    157704.063595
# Name: 246, dtype: float64
# mi                  0.001248
# max_revenue    102920.942912
# Name: 247, dtype: float64
# mi                 0.001248
# max_revenue    76281.291934
# Name: 248, dtype: float64
# mi                  0.001248
# max_revenue    126117.541896
# Name: 249, dtype: float64
# mi                  0.001248
# max_revenue    174001.007124
# Name: 250, dtype: float64
# mi                  0.001248
# max_revenue    176036.196581
# Name: 251, dtype: float64
# mi                 0.001248
# max_revenue    59647.121401
# Name: 252, dtype: float64
# mi                 0.001248
# max_revenue    89454.794651
# Name: 253, dtype: float64
# mi                 0.001248
# max_revenue    52463.261777
# Name: 254, dtype: float64
# mi                  0.001248
# max_revenue    107150.279897
# Name: 255, dtype: float64
# mi                 0.001248
# max_revenue    34486.668775
# Name: 256, dtype: float64
# mi                  0.001248
# max_revenue    113937.956030
# Name: 257, dtype: float64
# mi                  0.001248
# max_revenue    170419.429739
# Name: 258, dtype: float64
# mi                  0.001248
# max_revenue    117349.709663
# Name: 259, dtype: float64
# mi                  0.001248
# max_revenue    183306.261796
# Name: 260, dtype: float64
# mi                 0.001248
# max_revenue    19625.953025
# Name: 261, dtype: float64
# mi                  0.001248
# max_revenue    106404.873936
# Name: 262, dtype: float64
# mi                 0.001248
# max_revenue    75119.068557
# Name: 263, dtype: float64
# mi                 0.001248
# max_revenue   -13949.676296
# Name: 264, dtype: float64
# mi                 0.001248
# max_revenue    99517.940290
# Name: 265, dtype: float64
# mi                  0.001248
# max_revenue    104946.497951
# Name: 266, dtype: float64
# mi                 0.001248
# max_revenue    93878.935394
# Name: 267, dtype: float64
# mi                  0.001248
# max_revenue    162633.662970
# Name: 268, dtype: float64
# mi                 0.001248
# max_revenue    93648.171678
# Name: 269, dtype: float64
# mi                  0.001248
# max_revenue    109565.031873
# Name: 270, dtype: float64
# mi                 0.001248
# max_revenue    84123.232243
# Name: 271, dtype: float64
# mi                 0.001248
# max_revenue    54931.880726
# Name: 272, dtype: float64
# mi                 0.001248
# max_revenue    49975.723411
# Name: 273, dtype: float64
# mi                 0.001248
# max_revenue    92545.918527
# Name: 274, dtype: float64
# mi                  0.001248
# max_revenue    216300.854358
# Name: 275, dtype: float64
# mi                 0.001248
# max_revenue    36866.362510
# Name: 276, dtype: float64
# mi                 0.001248
# max_revenue    69862.399967
# Name: 277, dtype: float64
# mi                  0.001248
# max_revenue    130191.673228
# Name: 278, dtype: float64
# mi                  0.001248
# max_revenue    145995.337409
# Name: 279, dtype: float64
# mi                  0.001248
# max_revenue    134549.799387
# Name: 280, dtype: float64
# mi                  0.001248
# max_revenue    102594.389663
# Name: 281, dtype: float64
# mi                 0.001248
# max_revenue    93661.565593
# Name: 282, dtype: float64
# mi                  0.001248
# max_revenue    189887.238417
# Name: 283, dtype: float64
# mi                 0.001248
# max_revenue    81368.933569
# Name: 284, dtype: float64
# mi                  0.001248
# max_revenue    119678.709213
# Name: 285, dtype: float64
# mi                 0.001248
# max_revenue    48809.588520
# Name: 286, dtype: float64
# mi                 0.001248
# max_revenue    67462.506420
# Name: 287, dtype: float64
# mi                 0.001248
# max_revenue    54134.265965
# Name: 288, dtype: float64
# mi                  0.001248
# max_revenue    133203.786353
# Name: 289, dtype: float64
# mi                 0.001248
# max_revenue    51253.428597
# Name: 290, dtype: float64
# mi                  0.001248
# max_revenue    121095.585843
# Name: 291, dtype: float64
# mi                 0.001248
# max_revenue    64982.783937
# Name: 292, dtype: float64
# mi                 0.001248
# max_revenue    90458.366674
# Name: 293, dtype: float64
# mi                 0.001248
# max_revenue    88088.105599
# Name: 294, dtype: float64
# mi                0.001248
# max_revenue    9234.159839
# Name: 295, dtype: float64
# mi                  0.001248
# max_revenue    171421.570374
# Name: 296, dtype: float64
# mi                 0.001248
# max_revenue    43734.940030
# Name: 297, dtype: float64
# mi                 0.001248
# max_revenue    52514.324497
# Name: 298, dtype: float64
# mi                  0.001248
# max_revenue    245061.699416
# Name: 299, dtype: float64
# mi                  0.001248
# max_revenue    181413.821656
# Name: 300, dtype: float64
# mi                 0.001248
# max_revenue    99519.588058
# Name: 301, dtype: float64
# mi                0.001248
# max_revenue   -3705.822381
# Name: 302, dtype: float64
# mi                  0.001248
# max_revenue    113248.752441
# Name: 303, dtype: float64
# mi                  0.001248
# max_revenue    139051.839956
# Name: 304, dtype: float64
# mi                  0.001248
# max_revenue    139001.884495
# Name: 305, dtype: float64
# mi                 0.001248
# max_revenue    49717.248754
# Name: 306, dtype: float64
# mi                 0.001248
# max_revenue    94300.026804
# Name: 307, dtype: float64
# mi                 0.001248
# max_revenue    69823.833664
# Name: 308, dtype: float64
# mi                  0.001248
# max_revenue    116583.168158
# Name: 309, dtype: float64
# mi                0.001248
# max_revenue    3800.879394
# Name: 310, dtype: float64
# mi                 0.001248
# max_revenue    91038.025257
# Name: 311, dtype: float64
# mi                  0.001248
# max_revenue    126855.140988
# Name: 312, dtype: float64
# mi                  0.001248
# max_revenue    190413.582098
# Name: 313, dtype: float64
# mi                  0.001248
# max_revenue    119363.238297
# Name: 314, dtype: float64
# mi                 0.001248
# max_revenue    53170.482175
# Name: 315, dtype: float64
# mi                 0.001248
# max_revenue    76246.425444
# Name: 316, dtype: float64
# mi                  0.001248
# max_revenue    101671.149641
# Name: 317, dtype: float64
# mi                 0.001248
# max_revenue    95669.905610
# Name: 318, dtype: float64
# mi                 0.001248
# max_revenue    64742.686636
# Name: 319, dtype: float64
# mi                  0.001248
# max_revenue    110680.574429
# Name: 320, dtype: float64
# mi                  0.001248
# max_revenue    131294.533004
# Name: 321, dtype: float64
# mi                  0.001248
# max_revenue    136895.189986
# Name: 322, dtype: float64
# mi                  0.001248
# max_revenue    182757.626549
# Name: 323, dtype: float64
# mi                 0.001248
# max_revenue    85446.889143
# Name: 324, dtype: float64
# mi                  0.001248
# max_revenue    114076.830412
# Name: 325, dtype: float64
# mi                 0.001248
# max_revenue    97073.673927
# Name: 326, dtype: float64
# mi                 0.001248
# max_revenue    65927.403715
# Name: 327, dtype: float64
# mi                 0.001248
# max_revenue    71265.461989
# Name: 328, dtype: float64
# mi                  0.001248
# max_revenue    136485.011073
# Name: 329, dtype: float64
# mi                  0.001248
# max_revenue    139115.898741
# Name: 330, dtype: float64
# mi                  0.001248
# max_revenue    156974.917418
# Name: 331, dtype: float64
# mi                  0.001248
# max_revenue    123069.027386
# Name: 332, dtype: float64
# mi                  0.001248
# max_revenue    110657.132777
# Name: 333, dtype: float64
# mi                  0.001248
# max_revenue    171321.668707
# Name: 334, dtype: float64
# mi                 0.001248
# max_revenue    99386.463562
# Name: 335, dtype: float64
# mi                 0.001248
# max_revenue    74524.318262
# Name: 336, dtype: float64
# mi                 0.001248
# max_revenue    87155.562738
# Name: 337, dtype: float64
# mi                  0.001248
# max_revenue    105150.848648
# Name: 338, dtype: float64
# mi                 0.001248
# max_revenue    31308.406808
# Name: 339, dtype: float64
# mi                 0.001248
# max_revenue    86913.016394
# Name: 340, dtype: float64
# mi                  0.001248
# max_revenue    132307.896604
# Name: 341, dtype: float64
# mi                 0.001248
# max_revenue    90275.455645
# Name: 342, dtype: float64
# mi                  0.001248
# max_revenue    106871.697630
# Name: 343, dtype: float64
# mi                  0.001248
# max_revenue    105911.642977
# Name: 344, dtype: float64
# mi                  0.001248
# max_revenue    107751.773813
# Name: 345, dtype: float64
# mi                 0.001248
# max_revenue    41456.839295
# Name: 346, dtype: float64
# mi                  0.001248
# max_revenue    141162.154561
# Name: 347, dtype: float64
# mi                 0.001248
# max_revenue    63779.446452
# Name: 348, dtype: float64
# mi                 0.001248
# max_revenue    99666.823428
# Name: 349, dtype: float64
# mi                 0.001248
# max_revenue    88393.758401
# Name: 350, dtype: float64
# mi                 0.001248
# max_revenue    38759.960276
# Name: 351, dtype: float64
# mi                  0.001248
# max_revenue    190526.503062
# Name: 352, dtype: float64
# mi                  0.001248
# max_revenue    108198.567329
# Name: 353, dtype: float64
# mi                 0.001248
# max_revenue    23262.707762
# Name: 354, dtype: float64
# mi                  0.001248
# max_revenue    170580.476917
# Name: 355, dtype: float64
# mi                 0.001248
# max_revenue    93587.686763
# Name: 356, dtype: float64
# mi                 0.001248
# max_revenue    76930.691805
# Name: 357, dtype: float64
# mi                 0.001248
# max_revenue    80585.519872
# Name: 358, dtype: float64
# mi                 0.001248
# max_revenue    56030.392377
# Name: 359, dtype: float64
# mi                 0.001248
# max_revenue    23865.281160
# Name: 360, dtype: float64
# mi                  0.001248
# max_revenue    115549.751350
# Name: 361, dtype: float64
# mi                  0.001248
# max_revenue    153655.108162
# Name: 362, dtype: float64
# mi                  0.001248
# max_revenue    237181.512420
# Name: 363, dtype: float64
# mi                  0.001248
# max_revenue    126206.490975
# Name: 364, dtype: float64
# mi                  0.001248
# max_revenue    110578.628229
# Name: 365, dtype: float64
# mi                  0.001248
# max_revenue    171610.384221
# Name: 366, dtype: float64
# mi                 0.001248
# max_revenue    88282.983385
# Name: 367, dtype: float64
# mi                 0.001248
# max_revenue    60264.224363
# Name: 368, dtype: float64
# mi                 0.001248
# max_revenue    63946.259696
# Name: 369, dtype: float64
# mi                 0.001248
# max_revenue    49569.757272
# Name: 370, dtype: float64
# mi                 0.001248
# max_revenue    43646.526736
# Name: 371, dtype: float64
# mi                  0.001248
# max_revenue    175746.780317
# Name: 372, dtype: float64
# mi                  0.001248
# max_revenue    113239.088019
# Name: 373, dtype: float64
# mi                 0.001248
# max_revenue    95150.161704
# Name: 374, dtype: float64
# mi                  0.001248
# max_revenue    172535.604718
# Name: 375, dtype: float64
# mi                  0.001248
# max_revenue    121525.522914
# Name: 376, dtype: float64
# mi                  0.001248
# max_revenue    143855.325111
# Name: 377, dtype: float64
# mi                 0.001248
# max_revenue    53379.927712
# Name: 378, dtype: float64
# mi                  0.001248
# max_revenue    123817.602179
# Name: 379, dtype: float64
# mi                  0.001248
# max_revenue    110975.065103
# Name: 380, dtype: float64
# mi                 0.001248
# max_revenue    51955.229166
# Name: 381, dtype: float64
# mi                 0.001248
# max_revenue    64854.102730
# Name: 382, dtype: float64
# mi                 0.001248
# max_revenue    33742.044954
# Name: 383, dtype: float64
# mi                  0.001248
# max_revenue    114192.418197
# Name: 384, dtype: float64
# mi                  0.001248
# max_revenue    181684.569849
# Name: 385, dtype: float64
# mi                  0.001248
# max_revenue    144861.933620
# Name: 386, dtype: float64
# mi                 0.001248
# max_revenue    94236.808675
# Name: 387, dtype: float64
# mi                 0.001248
# max_revenue    37730.241918
# Name: 388, dtype: float64
# mi                  0.001248
# max_revenue    192452.883466
# Name: 389, dtype: float64
# mi                  0.001248
# max_revenue    166716.542203
# Name: 390, dtype: float64
# mi                  0.001248
# max_revenue    168763.555466
# Name: 391, dtype: float64
# mi                 0.001248
# max_revenue    74818.500320
# Name: 392, dtype: float64
# mi                  0.001248
# max_revenue    138703.080118
# Name: 393, dtype: float64
# mi                0.001248
# max_revenue    9998.344676
# Name: 394, dtype: float64
# mi                  0.001248
# max_revenue    115832.108019
# Name: 395, dtype: float64
# mi                 0.001248
# max_revenue    71435.282140
# Name: 396, dtype: float64
# mi                  0.001248
# max_revenue    216348.645512
# Name: 397, dtype: float64
# mi                 0.001248
# max_revenue    52742.300481
# Name: 398, dtype: float64
# mi                  0.001248
# max_revenue    178053.801556
# Name: 399, dtype: float64
# mi                 0.001248
# max_revenue    84675.208286
# Name: 400, dtype: float64
# mi                  0.001248
# max_revenue    131376.175820
# Name: 401, dtype: float64
# mi                 0.001248
# max_revenue    86978.289319
# Name: 402, dtype: float64
# mi                  0.001248
# max_revenue    113108.032628
# Name: 403, dtype: float64
# mi                  0.001248
# max_revenue    157500.890661
# Name: 404, dtype: float64
# mi                  0.001248
# max_revenue    100599.962564
# Name: 405, dtype: float64
# mi                  0.001248
# max_revenue    200051.270710
# Name: 406, dtype: float64
# mi                 0.001248
# max_revenue    18596.640701
# Name: 407, dtype: float64
# mi                 0.001248
# max_revenue    59527.150405
# Name: 408, dtype: float64
# mi                  0.001248
# max_revenue    141868.121678
# Name: 409, dtype: float64
# mi                  0.001248
# max_revenue    103589.946904
# Name: 410, dtype: float64
# mi                 0.001248
# max_revenue    33856.321197
# Name: 411, dtype: float64
# mi                  0.001248
# max_revenue    106006.365903
# Name: 412, dtype: float64
# mi                  0.001248
# max_revenue    140714.526628
# Name: 413, dtype: float64
# mi                 0.001248
# max_revenue   -13836.800429
# Name: 414, dtype: float64
# mi                  0.001248
# max_revenue    102318.055944
# Name: 415, dtype: float64
# mi                 0.001248
# max_revenue   -24751.501256
# Name: 416, dtype: float64
# mi                  0.001248
# max_revenue    138654.087066
# Name: 417, dtype: float64
# mi                 0.001248
# max_revenue    42438.120612
# Name: 418, dtype: float64
# mi                 0.001248
# max_revenue    73459.140557
# Name: 419, dtype: float64
# mi                 0.001248
# max_revenue    44536.045895
# Name: 420, dtype: float64
# mi                 0.001248
# max_revenue    74076.764071
# Name: 421, dtype: float64
# mi                 0.001248
# max_revenue    78814.972211
# Name: 422, dtype: float64
# mi                  0.001248
# max_revenue    138281.805098
# Name: 423, dtype: float64
# mi                  0.001248
# max_revenue    101289.152173
# Name: 424, dtype: float64
# mi                 0.001248
# max_revenue    12355.623680
# Name: 425, dtype: float64
# mi                 0.001248
# max_revenue    88723.734917
# Name: 426, dtype: float64
# mi                  0.001248
# max_revenue    143687.482056
# Name: 427, dtype: float64
# mi                  0.001248
# max_revenue    132585.861878
# Name: 428, dtype: float64
# mi                0.001248
# max_revenue   -2359.854580
# Name: 429, dtype: float64
# mi                 0.001248
# max_revenue    54373.715567
# Name: 430, dtype: float64
# mi                 0.001248
# max_revenue    88413.238152
# Name: 431, dtype: float64
# mi                 0.001248
# max_revenue    73527.266319
# Name: 432, dtype: float64
# mi                  0.001248
# max_revenue    158799.348108
# Name: 433, dtype: float64
# mi                 0.001248
# max_revenue    99363.585358
# Name: 434, dtype: float64
# mi                 0.001248
# max_revenue    18316.597749
# Name: 435, dtype: float64
# mi                 0.001248
# max_revenue    92955.068356
# Name: 436, dtype: float64
# mi                 0.001248
# max_revenue    85252.405553
# Name: 437, dtype: float64
# mi                  0.001248
# max_revenue    155543.046674
# Name: 438, dtype: float64
# mi                 0.001248
# max_revenue    87619.804833
# Name: 439, dtype: float64
# mi                  0.001248
# max_revenue    120120.610447
# Name: 440, dtype: float64
# mi                  0.001248
# max_revenue    111795.526809
# Name: 441, dtype: float64
# mi                  0.001248
# max_revenue    127748.480686
# Name: 442, dtype: float64
# mi                 0.001248
# max_revenue    44646.708235
# Name: 443, dtype: float64
# mi                  0.001248
# max_revenue    106949.737655
# Name: 444, dtype: float64
# mi                 0.001248
# max_revenue    91171.173583
# Name: 445, dtype: float64
# mi                0.001248
# max_revenue    9117.192554
# Name: 446, dtype: float64
# mi                  0.001248
# max_revenue    100481.501869
# Name: 447, dtype: float64
# mi                 0.001248
# max_revenue   -41985.389072
# Name: 448, dtype: float64
# mi                 0.001248
# max_revenue    17475.017282
# Name: 449, dtype: float64
# mi                 0.001248
# max_revenue    90839.449601
# Name: 450, dtype: float64
# mi                 0.001248
# max_revenue    64471.866552
# Name: 451, dtype: float64
# mi                 0.001248
# max_revenue    51217.104914
# Name: 452, dtype: float64
# mi                  0.001248
# max_revenue    124856.876367
# Name: 453, dtype: float64
# mi                 0.001248
# max_revenue    77695.547858
# Name: 454, dtype: float64
# mi                 0.001248
# max_revenue    39748.962319
# Name: 455, dtype: float64
# mi                0.001248
# max_revenue    6516.770095
# Name: 456, dtype: float64
# mi                  0.001248
# max_revenue    131238.504010
# Name: 457, dtype: float64
# mi                  0.001248
# max_revenue    115097.913460
# Name: 458, dtype: float64
# mi                  0.001248
# max_revenue    109892.174650
# Name: 459, dtype: float64
# mi                 0.001248
# max_revenue    41120.353468
# Name: 460, dtype: float64
# mi                  0.001248
# max_revenue    134774.951719
# Name: 461, dtype: float64
# mi                 0.001248
# max_revenue    31661.235271
# Name: 462, dtype: float64
# mi                 0.001248
# max_revenue    50563.245812
# Name: 463, dtype: float64
# mi                 0.001248
# max_revenue    57363.433495
# Name: 464, dtype: float64
# mi                  0.001248
# max_revenue    127624.940334
# Name: 465, dtype: float64
# mi                  0.001248
# max_revenue    107293.832518
# Name: 466, dtype: float64
# mi                  0.001248
# max_revenue    106911.181099
# Name: 467, dtype: float64
# mi                  0.001248
# max_revenue    116771.900296
# Name: 468, dtype: float64
# mi                 0.001248
# max_revenue    88244.307031
# Name: 469, dtype: float64
# mi               0.001248
# max_revenue   -921.453854
# Name: 470, dtype: float64
# mi                 0.001248
# max_revenue    98903.991775
# Name: 471, dtype: float64
# mi                 0.001248
# max_revenue    59435.319444
# Name: 472, dtype: float64
# mi                  0.001248
# max_revenue    146519.021467
# Name: 473, dtype: float64
# mi                  0.001248
# max_revenue    110516.957067
# Name: 474, dtype: float64
# mi                 0.001248
# max_revenue    85483.729971
# Name: 475, dtype: float64
# mi                 0.001248
# max_revenue    37566.067046
# Name: 476, dtype: float64
# mi                  0.001248
# max_revenue    128848.851769
# Name: 477, dtype: float64
# mi                0.001248
# max_revenue    3660.326795
# Name: 478, dtype: float64
# mi                 0.001248
# max_revenue    52007.535928
# Name: 479, dtype: float64
# mi                 0.001248
# max_revenue   -11892.040725
# Name: 480, dtype: float64
# mi                 0.001248
# max_revenue    79754.079958
# Name: 481, dtype: float64
# mi                  0.001248
# max_revenue    165817.536886
# Name: 482, dtype: float64
# mi                 0.001248
# max_revenue    91309.329332
# Name: 483, dtype: float64
# mi                  0.001248
# max_revenue    108026.191513
# Name: 484, dtype: float64
# mi                  0.001248
# max_revenue    113163.400762
# Name: 485, dtype: float64
# mi                 0.001248
# max_revenue    29515.429446
# Name: 486, dtype: float64
# mi                  0.001248
# max_revenue    105921.527096
# Name: 487, dtype: float64
# mi                 0.001248
# max_revenue    58790.487569
# Name: 488, dtype: float64
# mi                  0.001248
# max_revenue    127016.842646
# Name: 489, dtype: float64
# mi                 0.001248
# max_revenue    95482.508257
# Name: 490, dtype: float64
# mi                  0.001248
# max_revenue    153795.355834
# Name: 491, dtype: float64
# mi                 0.001248
# max_revenue    23080.103179
# Name: 492, dtype: float64
# mi                 0.001248
# max_revenue    59830.116587
# Name: 493, dtype: float64
# mi                0.001248
# max_revenue   -7069.235859
# Name: 494, dtype: float64
# mi                 0.001248
# max_revenue    88509.444645
# Name: 495, dtype: float64
# mi                 0.001248
# max_revenue    81542.494176
# Name: 496, dtype: float64
# mi                  0.001248
# max_revenue    112102.308028
# Name: 497, dtype: float64
# mi                  0.001248
# max_revenue    169204.598069
# Name: 498, dtype: float64
# mi                 0.001248
# max_revenue    50083.827552
# Name: 499, dtype: float64
# mi                 0.001248
# max_revenue    75894.455443
# Name: 500, dtype: float64
# mi                 0.001248
# max_revenue    97732.393038
# Name: 501, dtype: float64
# mi                 0.001248
# max_revenue    70636.068483
# Name: 502, dtype: float64
# mi                  0.001248
# max_revenue    151786.849812
# Name: 503, dtype: float64
# mi                 0.001248
# max_revenue   -24308.762930
# Name: 504, dtype: float64
# mi                 0.001248
# max_revenue    39328.430642
# Name: 505, dtype: float64
# mi                  0.001248
# max_revenue    107215.500880
# Name: 506, dtype: float64
# mi                 0.001248
# max_revenue    61189.925332
# Name: 507, dtype: float64
# mi                  0.001248
# max_revenue    167651.961606
# Name: 508, dtype: float64
# mi                 0.001248
# max_revenue    92652.205817
# Name: 509, dtype: float64
# mi                 0.001248
# max_revenue    98562.688326
# Name: 510, dtype: float64
# mi                 0.001248
# max_revenue    90570.146054
# Name: 511, dtype: float64
# mi                  0.001248
# max_revenue    156580.018930
# Name: 512, dtype: float64
# mi                  0.001248
# max_revenue    132134.811858
# Name: 513, dtype: float64
# mi                 0.001248
# max_revenue    83672.770342
# Name: 514, dtype: float64
# mi                 0.001248
# max_revenue    92348.721086
# Name: 515, dtype: float64
# mi                  0.001248
# max_revenue    160445.260073
# Name: 516, dtype: float64
# mi                  0.001248
# max_revenue    120010.407583
# Name: 517, dtype: float64
# mi                  0.001248
# max_revenue    166041.181184
# Name: 518, dtype: float64
# mi                  0.001248
# max_revenue    168402.423287
# Name: 519, dtype: float64
# mi                 0.001248
# max_revenue    86827.327337
# Name: 520, dtype: float64
# mi                 0.001248
# max_revenue    94865.630572
# Name: 521, dtype: float64
# mi                 0.001248
# max_revenue    12317.082544
# Name: 522, dtype: float64
# mi                 0.001248
# max_revenue    36582.914188
# Name: 523, dtype: float64
# mi                  0.001248
# max_revenue    144361.155837
# Name: 524, dtype: float64
# mi                 0.001248
# max_revenue    89938.648315
# Name: 525, dtype: float64
# mi                 0.001248
# max_revenue    81117.661162
# Name: 526, dtype: float64
# mi                 0.001248
# max_revenue    79596.517500
# Name: 527, dtype: float64
# mi                 0.001248
# max_revenue    22676.951309
# Name: 528, dtype: float64
# mi                 0.001248
# max_revenue    82747.716785
# Name: 529, dtype: float64
# mi                  0.001248
# max_revenue    129089.232649
# Name: 530, dtype: float64
# mi                 0.001248
# max_revenue    83075.806302
# Name: 531, dtype: float64
# mi                  0.001248
# max_revenue    223129.831795
# Name: 532, dtype: float64
# mi                 0.001248
# max_revenue    42223.637077
# Name: 533, dtype: float64
# mi                 0.001248
# max_revenue    13996.256137
# Name: 534, dtype: float64
# mi                  0.001248
# max_revenue    119212.812961
# Name: 535, dtype: float64
# mi                 0.001248
# max_revenue    95889.642514
# Name: 536, dtype: float64
# mi                0.001248
# max_revenue   -2737.942008
# Name: 537, dtype: float64
# mi                 0.001248
# max_revenue    81244.753658
# Name: 538, dtype: float64
# mi                  0.001248
# max_revenue    103873.296239
# Name: 539, dtype: float64
# mi                  0.001248
# max_revenue    145215.436371
# Name: 540, dtype: float64
# mi                 0.001248
# max_revenue    65399.043764
# Name: 541, dtype: float64
# mi                 0.001248
# max_revenue    49483.043419
# Name: 542, dtype: float64
# mi                 0.001248
# max_revenue    42322.296442
# Name: 543, dtype: float64
# mi                 0.001248
# max_revenue    47791.015622
# Name: 544, dtype: float64
# mi                 0.001248
# max_revenue    67853.901694
# Name: 545, dtype: float64
# mi                  0.001248
# max_revenue    122950.689064
# Name: 546, dtype: float64
# mi                  0.001248
# max_revenue    115193.892590
# Name: 547, dtype: float64
# mi                  0.001248
# max_revenue    113729.439771
# Name: 548, dtype: float64
# mi                 0.001248
# max_revenue    66148.859581
# Name: 549, dtype: float64
# mi                  0.001248
# max_revenue    164517.583182
# Name: 550, dtype: float64
# mi                 0.001248
# max_revenue    68148.925611
# Name: 551, dtype: float64
# mi                 0.001248
# max_revenue    48831.676561
# Name: 552, dtype: float64
# mi                 0.001248
# max_revenue    64047.387855
# Name: 553, dtype: float64
# mi                  0.001248
# max_revenue    119577.058150
# Name: 554, dtype: float64
# mi                 0.001248
# max_revenue    66088.937890
# Name: 555, dtype: float64
# mi                 0.001248
# max_revenue    61810.942480
# Name: 556, dtype: float64
# mi                 0.001248
# max_revenue    42049.274129
# Name: 557, dtype: float64
# mi                 0.001248
# max_revenue    81449.912505
# Name: 558, dtype: float64
# mi                  0.001248
# max_revenue    105306.417477
# Name: 559, dtype: float64
# mi                  0.001248
# max_revenue    102778.486188
# Name: 560, dtype: float64
# mi                  0.001248
# max_revenue    107402.538582
# Name: 561, dtype: float64
# mi                 0.001248
# max_revenue    52160.443365
# Name: 562, dtype: float64
# mi                 0.001248
# max_revenue    88138.395346
# Name: 563, dtype: float64
# mi                  0.001248
# max_revenue    136680.700172
# Name: 564, dtype: float64
# mi                  0.001248
# max_revenue    160413.127157
# Name: 565, dtype: float64
# mi                 0.001248
# max_revenue    88884.123114
# Name: 566, dtype: float64
# mi                  0.001248
# max_revenue    126702.761255
# Name: 567, dtype: float64
# mi                 0.001248
# max_revenue    36183.945691
# Name: 568, dtype: float64
# mi                 0.001248
# max_revenue    68487.308807
# Name: 569, dtype: float64
# mi                  0.001248
# max_revenue    128181.251734
# Name: 570, dtype: float64
# mi                 0.001248
# max_revenue    62927.044370
# Name: 571, dtype: float64
# mi                  0.001248
# max_revenue    137546.100505
# Name: 572, dtype: float64
# mi                 0.001248
# max_revenue    13342.500632
# Name: 573, dtype: float64
# mi                 0.001248
# max_revenue    93054.672300
# Name: 574, dtype: float64
# mi                 0.001248
# max_revenue    17348.725179
# Name: 575, dtype: float64
# mi                 0.001248
# max_revenue    82539.191329
# Name: 576, dtype: float64
# mi                 0.001248
# max_revenue    81421.744910
# Name: 577, dtype: float64
# mi                  0.001248
# max_revenue    104126.701817
# Name: 578, dtype: float64
# mi                 0.001248
# max_revenue    71030.796131
# Name: 579, dtype: float64
# mi                 0.001248
# max_revenue    77284.358324
# ...
# Name: 8817, dtype: float64
# mi                16.000000
# max_revenue    95080.133144
# Name: 8818, dtype: float64
# mi                16.000000
# max_revenue    96060.332929
# Name: 8819, dtype: float64
# mi                16.000000
# max_revenue    94938.460627
# Name: 8820, dtype: float64
# mi                16.000000
# max_revenue    95281.236141
# Name: 8821, dtype: float64
# mi                16.000000
# max_revenue    96009.877585
# Name: 8822, dtype: float64
# mi                16.000000
# max_revenue    94790.925692
# Name: 8823, dtype: float64
# mi                16.000000
# max_revenue    95268.807932
# Name: 8824, dtype: float64
# mi                16.00000
# max_revenue    95066.06368
# Name: 8825, dtype: float64
# mi                16.000000
# max_revenue    95867.790807
# Name: 8826, dtype: float64
# mi                16.000000
# max_revenue    95696.148489
# Name: 8827, dtype: float64
# mi                16.000000
# max_revenue    94749.257767
# Name: 8828, dtype: float64
# mi                16.000000
# max_revenue    93701.329899
# Name: 8829, dtype: float64
# mi                16.000000
# max_revenue    95230.282658
# Name: 8830, dtype: float64
# mi                16.000000
# max_revenue    89028.822028
# Name: 8831, dtype: float64
# mi                16.000000
# max_revenue    95777.742881
# Name: 8832, dtype: float64
# mi                16.000000
# max_revenue    94635.461999
# Name: 8833, dtype: float64
# mi                16.000000
# max_revenue    95054.356212
# Name: 8834, dtype: float64
# mi                16.000000
# max_revenue    95729.051434
# Name: 8835, dtype: float64
# mi                16.000000
# max_revenue    93966.801198
# Name: 8836, dtype: float64
# mi                16.000000
# max_revenue    90120.260403
# Name: 8837, dtype: float64
# mi                16.0000
# max_revenue    95088.5659
# Name: 8838, dtype: float64
# mi                16.000000
# max_revenue    95458.380013
# Name: 8839, dtype: float64
# mi                16.000000
# max_revenue    96327.614626
# Name: 8840, dtype: float64
# mi                16.000000
# max_revenue    95736.644502
# Name: 8841, dtype: float64
# mi                16.00000
# max_revenue    96380.81395
# Name: 8842, dtype: float64
# mi                16.000000
# max_revenue    95625.197813
# Name: 8843, dtype: float64
# mi                16.000000
# max_revenue    96142.557785
# Name: 8844, dtype: float64
# mi                16.00000
# max_revenue    95840.90877
# Name: 8845, dtype: float64
# mi                16.000000
# max_revenue    94496.294222
# Name: 8846, dtype: float64
# mi                16.000000
# max_revenue    95242.041107
# Name: 8847, dtype: float64
# mi                16.000000
# max_revenue    94002.619578
# Name: 8848, dtype: float64
# mi                16.000000
# max_revenue    94080.753616
# Name: 8849, dtype: float64
# mi                16.00000
# max_revenue    94906.63221
# Name: 8850, dtype: float64
# mi                16.000000
# max_revenue    95454.615206
# Name: 8851, dtype: float64
# mi                16.00000
# max_revenue    95947.37836
# Name: 8852, dtype: float64
# mi                16.000000
# max_revenue    95591.531084
# Name: 8853, dtype: float64
# mi                16.000000
# max_revenue    96215.083778
# Name: 8854, dtype: float64
# mi                16.000000
# max_revenue    93349.159849
# Name: 8855, dtype: float64
# mi                16.00000
# max_revenue    96129.38464
# Name: 8856, dtype: float64
# mi                16.000000
# max_revenue    95690.877772
# Name: 8857, dtype: float64
# mi                16.000000
# max_revenue    95298.852011
# Name: 8858, dtype: float64
# mi                16.000000
# max_revenue    95388.641224
# Name: 8859, dtype: float64
# mi                16.000000
# max_revenue    95429.026943
# Name: 8860, dtype: float64
# mi                16.000000
# max_revenue    95187.794655
# Name: 8861, dtype: float64
# mi                16.000000
# max_revenue    95159.663723
# Name: 8862, dtype: float64
# mi                16.000000
# max_revenue    95439.097588
# Name: 8863, dtype: float64
# mi                16.000000
# max_revenue    93798.580452
# Name: 8864, dtype: float64
# mi                16.000000
# max_revenue    94796.561245
# Name: 8865, dtype: float64
# mi                16.000000
# max_revenue    95732.028563
# Name: 8866, dtype: float64
# mi                16.000000
# max_revenue    94908.570705
# Name: 8867, dtype: float64
# mi                16.000000
# max_revenue    95388.793799
# Name: 8868, dtype: float64
# mi                16.000000
# max_revenue    95875.034857
# Name: 8869, dtype: float64
# mi                16.000000
# max_revenue    95684.412882
# Name: 8870, dtype: float64
# mi                16.000000
# max_revenue    95404.743912
# Name: 8871, dtype: float64
# mi                16.000000
# max_revenue    94901.077326
# Name: 8872, dtype: float64
# mi                16.00000
# max_revenue    96024.75001
# Name: 8873, dtype: float64
# mi                16.000000
# max_revenue    96145.367781
# Name: 8874, dtype: float64
# mi                16.000000
# max_revenue    95205.895661
# Name: 8875, dtype: float64
# mi                16.000000
# max_revenue    95611.870536
# Name: 8876, dtype: float64
# mi                16.000000
# max_revenue    95559.009673
# Name: 8877, dtype: float64
# mi                16.000000
# max_revenue    95725.669817
# Name: 8878, dtype: float64
# mi                16.000000
# max_revenue    95142.469247
# Name: 8879, dtype: float64
# mi                16.000000
# max_revenue    95275.679672
# Name: 8880, dtype: float64
# mi                16.000000
# max_revenue    90247.600816
# Name: 8881, dtype: float64
# mi                16.000000
# max_revenue    95856.485945
# Name: 8882, dtype: float64
# mi                16.000000
# max_revenue    95488.716834
# Name: 8883, dtype: float64
# mi                16.000000
# max_revenue    93287.275272
# Name: 8884, dtype: float64
# mi                16.000000
# max_revenue    95589.796798
# Name: 8885, dtype: float64
# mi                16.000000
# max_revenue    95642.528122
# Name: 8886, dtype: float64
# mi                16.000000
# max_revenue    95160.830654
# Name: 8887, dtype: float64
# mi                16.000000
# max_revenue    96123.409892
# Name: 8888, dtype: float64
# mi                16.000000
# max_revenue    89357.827391
# Name: 8889, dtype: float64
# mi                16.000000
# max_revenue    89340.703929
# Name: 8890, dtype: float64
# mi                16.00000
# max_revenue    94989.65404
# Name: 8891, dtype: float64
# mi                16.000000
# max_revenue    95306.588652
# Name: 8892, dtype: float64
# mi                16.000000
# max_revenue    96236.128378
# Name: 8893, dtype: float64
# mi                16.000000
# max_revenue    95653.038388
# Name: 8894, dtype: float64
# mi                16.000000
# max_revenue    95468.926451
# Name: 8895, dtype: float64
# mi                16.000000
# max_revenue    95188.766901
# Name: 8896, dtype: float64
# mi                16.000000
# max_revenue    95025.390613
# Name: 8897, dtype: float64
# mi                16.000000
# max_revenue    90411.004665
# Name: 8898, dtype: float64
# mi                16.000000
# max_revenue    96251.080596
# Name: 8899, dtype: float64
# mi                16.000000
# max_revenue    95099.069265
# Name: 8900, dtype: float64
# mi                16.000000
# max_revenue    95687.520917
# Name: 8901, dtype: float64
# mi                16.000000
# max_revenue    95341.078982
# Name: 8902, dtype: float64
# mi                16.000000
# max_revenue    95354.144061
# Name: 8903, dtype: float64
# mi                16.000000
# max_revenue    95615.876649
# Name: 8904, dtype: float64
# mi                16.000000
# max_revenue    95900.071921
# Name: 8905, dtype: float64
# mi                16.000000
# max_revenue    96265.634746
# Name: 8906, dtype: float64
# mi                16.000000
# max_revenue    94479.432658
# Name: 8907, dtype: float64
# mi                16.000000
# max_revenue    95278.824648
# Name: 8908, dtype: float64
# mi                16.000000
# max_revenue    96221.079276
# Name: 8909, dtype: float64
# mi                16.000000
# max_revenue    95562.818429
# Name: 8910, dtype: float64
# mi                16.000000
# max_revenue    95189.935254
# Name: 8911, dtype: float64
# mi                16.000000
# max_revenue    95690.299895
# Name: 8912, dtype: float64
# mi                16.000000
# max_revenue    93499.881832
# Name: 8913, dtype: float64
# mi                16.000000
# max_revenue    94716.529387
# Name: 8914, dtype: float64
# mi                16.000000
# max_revenue    95544.630547
# Name: 8915, dtype: float64
# mi                16.000000
# max_revenue    93578.745222
# Name: 8916, dtype: float64
# mi                16.000000
# max_revenue    95360.350418
# Name: 8917, dtype: float64
# mi                16.000000
# max_revenue    95848.206742
# Name: 8918, dtype: float64
# mi                16.000000
# max_revenue    95150.541083
# Name: 8919, dtype: float64
# mi                16.000000
# max_revenue    95351.559764
# Name: 8920, dtype: float64
# mi                16.000000
# max_revenue    95502.553927
# Name: 8921, dtype: float64
# mi                16.000000
# max_revenue    90334.689948
# Name: 8922, dtype: float64
# mi                16.000000
# max_revenue    95816.928098
# Name: 8923, dtype: float64
# mi                16.000000
# max_revenue    93566.616929
# Name: 8924, dtype: float64
# mi                16.000000
# max_revenue    96761.562001
# Name: 8925, dtype: float64
# mi                16.000000
# max_revenue    96078.822097
# Name: 8926, dtype: float64
# mi                16.000000
# max_revenue    93649.684564
# Name: 8927, dtype: float64
# mi                16.00000
# max_revenue    88820.48325
# Name: 8928, dtype: float64
# mi                16.000000
# max_revenue    95303.421371
# Name: 8929, dtype: float64
# mi                16.000000
# max_revenue    95326.097809
# Name: 8930, dtype: float64
# mi                16.000000
# max_revenue    94590.224097
# Name: 8931, dtype: float64
# mi                16.000000
# max_revenue    95643.328667
# Name: 8932, dtype: float64
# mi                16.000000
# max_revenue    89290.918066
# Name: 8933, dtype: float64
# mi                16.000000
# max_revenue    89916.617446
# Name: 8934, dtype: float64
# mi                16.000000
# max_revenue    95989.115011
# Name: 8935, dtype: float64
# mi                16.000000
# max_revenue    96181.649278
# Name: 8936, dtype: float64
# mi                16.000000
# max_revenue    95326.525207
# Name: 8937, dtype: float64
# mi                16.000000
# max_revenue    93488.801352
# Name: 8938, dtype: float64
# mi                16.000000
# max_revenue    93734.497317
# Name: 8939, dtype: float64
# mi                16.000000
# max_revenue    95653.433747
# Name: 8940, dtype: float64
# mi                16.000000
# max_revenue    94930.236296
# Name: 8941, dtype: float64
# mi                16.000000
# max_revenue    95683.933732
# Name: 8942, dtype: float64
# mi                16.000000
# max_revenue    95434.072434
# Name: 8943, dtype: float64
# mi                16.000000
# max_revenue    95739.623829
# Name: 8944, dtype: float64
# mi                16.000000
# max_revenue    94981.838851
# Name: 8945, dtype: float64
# mi                16.000000
# max_revenue    95613.939905
# Name: 8946, dtype: float64
# mi                16.000000
# max_revenue    95733.767031
# Name: 8947, dtype: float64
# mi                16.000000
# max_revenue    95995.406349
# Name: 8948, dtype: float64
# mi                16.000000
# max_revenue    89723.661671
# Name: 8949, dtype: float64
# mi                16.000000
# max_revenue    95436.404851
# Name: 8950, dtype: float64
# mi                16.000000
# max_revenue    95435.864711
# Name: 8951, dtype: float64
# mi                16.000000
# max_revenue    95707.197501
# Name: 8952, dtype: float64
# mi                16.000000
# max_revenue    95995.261716
# Name: 8953, dtype: float64
# mi                16.000000
# max_revenue    95692.641854
# Name: 8954, dtype: float64
# mi                16.000000
# max_revenue    95254.369378
# Name: 8955, dtype: float64
# mi                16.000000
# max_revenue    95854.701459
# Name: 8956, dtype: float64
# mi                16.000000
# max_revenue    93033.855311
# Name: 8957, dtype: float64
# mi                16.000000
# max_revenue    94950.724709
# Name: 8958, dtype: float64
# mi                16.000000
# max_revenue    95549.307033
# Name: 8959, dtype: float64
# mi                16.000000
# max_revenue    95179.734148
# Name: 8960, dtype: float64
# mi                16.000000
# max_revenue    95647.089237
# Name: 8961, dtype: float64
# mi                16.000000
# max_revenue    95630.639993
# Name: 8962, dtype: float64
# mi                16.00000
# max_revenue    96471.22128
# Name: 8963, dtype: float64
# mi                16.00000
# max_revenue    95194.48988
# Name: 8964, dtype: float64
# mi                16.000000
# max_revenue    85684.856971
# Name: 8965, dtype: float64
# mi                16.000000
# max_revenue    95584.435933
# Name: 8966, dtype: float64
# mi                16.000000
# max_revenue    95928.824011
# Name: 8967, dtype: float64
# mi                16.000000
# max_revenue    94400.400272
# Name: 8968, dtype: float64
# mi                16.000000
# max_revenue    96128.816058
# Name: 8969, dtype: float64
# mi                16.00000
# max_revenue    95504.25095
# Name: 8970, dtype: float64
# mi                16.000000
# max_revenue    95197.961584
# Name: 8971, dtype: float64
# mi                16.000000
# max_revenue    90050.165713
# Name: 8972, dtype: float64
# mi                16.000000
# max_revenue    95741.264887
# Name: 8973, dtype: float64
# mi                16.00000
# max_revenue    95413.69105
# Name: 8974, dtype: float64
# mi                16.000000
# max_revenue    89488.384015
# Name: 8975, dtype: float64
# mi                16.000000
# max_revenue    96099.727823
# Name: 8976, dtype: float64
# mi                16.000000
# max_revenue    95343.495588
# Name: 8977, dtype: float64
# mi                16.00000
# max_revenue    89593.07463
# Name: 8978, dtype: float64
# mi                16.000000
# max_revenue    95941.997615
# Name: 8979, dtype: float64
# mi                16.000000
# max_revenue    94852.775214
# Name: 8980, dtype: float64
# mi                16.000000
# max_revenue    95373.805152
# Name: 8981, dtype: float64
# mi                16.000000
# max_revenue    96186.536789
# Name: 8982, dtype: float64
# mi                16.000000
# max_revenue    95634.574556
# Name: 8983, dtype: float64
# mi                16.000000
# max_revenue    95864.629384
# Name: 8984, dtype: float64
# mi                16.000000
# max_revenue    95752.554922
# Name: 8985, dtype: float64
# mi                16.000000
# max_revenue    95337.963551
# Name: 8986, dtype: float64
# mi                16.000000
# max_revenue    95418.093424
# Name: 8987, dtype: float64
# mi                16.000000
# max_revenue    95341.210283
# Name: 8988, dtype: float64
# mi                16.000000
# max_revenue    95607.024811
# Name: 8989, dtype: float64
# mi                16.000000
# max_revenue    94840.859331
# Name: 8990, dtype: float64
# mi                16.000000
# max_revenue    84891.804144
# Name: 8991, dtype: float64
# mi                16.000000
# max_revenue    95378.646681
# Name: 8992, dtype: float64
# mi                16.000000
# max_revenue    95191.314359
# Name: 8993, dtype: float64
# mi                16.000000
# max_revenue    96999.703907
# Name: 8994, dtype: float64
# mi                16.000000
# max_revenue    94998.495849
# Name: 8995, dtype: float64
# mi                16.000000
# max_revenue    95387.579786
# Name: 8996, dtype: float64
# mi                16.000000
# max_revenue    95437.736995
# Name: 8997, dtype: float64
# mi                16.000000
# max_revenue    96017.598058
# Name: 8998, dtype: float64
# mi                16.000000
# max_revenue    93408.367081
# Name: 8999, dtype: float64
#              mi  absolute error max_revenue  relative error max_revenue
# 0      0.001248                81311.104601                   85.098409
# 1      0.001248                47138.979258                   49.334616
# 2      0.001248                62199.054533                   65.096159
# 3      0.001248                 6118.757930                    6.403757
# 4      0.001248                68319.705810                   71.501898
# ...         ...                         ...                         ...
# 8995  16.000000                  551.004151                    0.576669
# 8996  16.000000                  161.920214                    0.169462
# 8997  16.000000                  111.763005                    0.116969
# 8998  16.000000                  468.098058                    0.489901
# 8999  16.000000                 2141.132919                    2.240863
#
# [9000 rows x 3 columns]

# %%
# if GENERATE:
#     mean_df = df.groupby('mi').mean()[['count', 'sum', 'mean', 'var']]
#     std_df = df.groupby('mi').std()[['count', 'sum', 'mean', 'var']].abs()
#     mean_df, std_df

#     # save mean_df, std_df to parquet
#     mean_df.to_parquet('{OUTPUT_DIR}/pac-mean_df_student-por.parquet')
#     std_df.to_parquet('{OUTPUT_DIR}/pac-std_df_student-por.parquet')

# %% [markdown]
# ### Computing DP Errors

# %% [markdown]
# ### Analysis of PAC vs DP
# - import the DP data
# - create a dataframe (`all_df`) containing the query outputs
#     - in this df, each output is the {mean, variance} aggregation over the 500 experiments, grouped by the type of privacy mechanism used (pac or dp) and privacy factor (mi or epsilon)
# - create a dataframe in the same pattern containing the computed error for each privitized output

# %%
# %%script echo skipping# Import Chais saved data from running PipelineDP and use it to compare.
# dp_results_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_results.parquet").to_pandas()
#
# # compute sum from count and mean
# dp_results_df['sum'] = dp_results_df['count'] * dp_results_df['mean']
# dp_results_df = dp_results_df[['mi', 'count', 'sum', 'mean']]
#
# # filter to just MI_OPTIONS
# dp_results_df = dp_results_df[dp_results_df['mi'].isin(MI_OPTIONS)]
#
# dp_results_df
# Out:
# skipping# Import Chais saved data from running PipelineDP and use it to compare.

# %%
# %%script echo skipping# compute errors for DP (or import from saved file)
# GENERATE_DP = True
# if GENERATE_DP:
#     errors_list = []
#     for i, row in dp_results_df.iterrows():
#         mi = row['mi']
#         r = row[OUTPUT_COLS].to_numpy()
#         errors_list.append([mi, *absolute_scaled_error(r, true_result), *relative_error_percent(r, true_result)])
#     dp_errors_df = pd.DataFrame(errors_list, columns=['mi', *ERROR_COLS])
#     dp_errors_df.to_parquet(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet")  # overwrite saved
# else:
#     dp_errors_df = pq.read_table(f"{OUTPUT_DIR}/dp-q4/dp_errors.parquet").to_pandas()
# dp_errors_df
# Out:
# skipping# compute errors for DP (or import from saved file)

# %%
### Make one merged DF to compare results
all_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_results_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_results_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    df.assign(type='pac').rename(columns={'mi': 'factor'})
])
all_df = all_df.groupby(['type', 'factor']).agg(['mean', 'var'])
all_df.columns = [' '.join(col).strip() for col in all_df.columns.values]  # Flatten the columns
#all_df.to_parquet(f"{OUTPUT_DIR}/all_results.parquet")  # Save the merged results
all_df
# Out:
#                 max_revenue mean  max_revenue var
# type factor
# pac  0.001248       94912.826426     2.205117e+09
#      0.015625       94254.406359     1.855212e+08
#      0.031250       94829.139170     8.843014e+07
#      0.062500       94588.146273     5.338779e+07
#      0.250000       94644.976981     1.655799e+07
#      1.000000       94568.585208     7.425675e+06
#      2.000000       94605.587326     6.219106e+06
#      4.000000       94508.452030     6.162986e+06
#      16.000000      94620.249085     5.321163e+06

# %%
### Make another merged df for the errors
errors_df = pd.concat([  # we will call mi and epsilon the "factor" so that the schemas match
    #dp_errors_df.assign(type='dp').rename(columns={'eps': 'factor'}), # switch from eps to mi for indexing DP results
    #dp_errors_df.assign(type='dp').rename(columns={'mi': 'factor'}), # comment out DP results until we have some
    pac_errors_df.assign(type='pac').rename(columns={'mi': 'factor'})
])
errors_df = errors_df.groupby(['type', 'factor']).agg(['mean', 'var'])
# drop absolute * mean and relative * var columns from level 1
#errors_df = errors_df.drop(columns=[('absolute error count', 'mean'), ('absolute error mean', 'mean'), ('relative error count', 'var'), ('relative error mean', 'var')])
errors_df.columns = [' '.join(col).strip() for col in errors_df.columns.values]  # flatten the columns

#errors_df.to_parquet(f"{OUTPUT_DIR}/all_errors.parquet")
errors_df
# Out:
#                 absolute error max_revenue mean  \
# type factor
# pac  0.001248                      37199.309345
#      0.015625                      10937.442701
#      0.031250                       7528.971836
#      0.062500                       5797.504509
#      0.250000                       3200.149350
#      1.000000                       1948.102718
#      2.000000                       1705.717659
#      4.000000                       1565.552515
#      16.000000                      1205.306465
#
#                 absolute error max_revenue var  \
# type factor
# pac  0.001248                     8.203490e+08
#      0.015625                     6.745275e+07
#      0.031250                     3.220742e+07
#      0.062500                     2.066822e+07
#      0.250000                     7.125766e+06
#      1.000000                     4.589929e+06
#      2.000000                     4.198583e+06
#      4.000000                     4.794443e+06
#      16.000000                    4.731317e+06
#
#                 relative error max_revenue mean  \
# type factor
# pac  0.001248                         38.931977
#      0.015625                         11.446886
#      0.031250                          7.879656
#      0.062500                          6.067540
#      0.250000                          3.349206
#      1.000000                          2.038841
#      2.000000                          1.785166
#      4.000000                          1.638473
#      16.000000                         1.261447
#
#                 relative error max_revenue var
# type factor
# pac  0.001248                       898.549110
#      0.015625                        73.882707
#      0.031250                        35.277606
#      0.062500                        22.638421
#      0.250000                         7.805033
#      1.000000                         5.027466
#      2.000000                         4.598815
#      4.000000                         5.251476
#      16.000000                        5.182331

# %%
#abs_error = errors_df.groupby('mi').mean()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

#std_abs_error = errors_df.groupby('mi').std()[['absolute error count', 'absolute error sum', 'absolute error mean', 'absolute error var']]
#sample_mean_rel_error = errors_df.groupby('mi').mean()[['relative error count', 'relative error sum', 'relative error mean', 'relative error var']]

# save std_abs_error, sample_mean_rel_error to parquet
# std_abs_error.to_parquet('outputs/pac-std_abs_error_student-por.parquet')
# sample_mean_rel_error.to_parquet('outputs/pac-sample_mean_rel_error_student-por.parquet')

# %% [markdown]
# ### Plotting Results
#
# We are reproducing Table 14 from this paper: http://arxiv.org/abs/2109.10789
#
# > TABLE 14: Experiments of the queries count, sum, mean, and var on the attribute Absences of the Portuguese education dataset containing 649 individuals (500 experiments per ε).

# %%
### Imports for matplotlib
import matplotlib as mpl
#import seaborn as sns
import matplotlib.pyplot as plt
#sns.reset_orig()

# Michael's matplotlib defaults
# set font to Times New Roman
LATEX = False
if LATEX:
    mpl.rcParams['text.usetex'] = True
    mpl.rcParams["font.family"] = "serif"
    mpl.rcParams["font.serif"] = "Times"
else:
    mpl.rcParams['text.usetex'] = False
    mpl.rcParams["font.family"] = "Times New Roman"
    mpl.rcParams["mathtext.fontset"] = "stix"
    
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['savefig.dpi'] = 300

import matplotlib_inline.backend_inline
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

mpl.rcParams['axes.titleweight'] = 'bold'

# %%
import matplotlib.colors as mcolors

PAC_COLOR = 'tab:blue'
DP_COLOR = 'tab:red'

# Function to lighten a color by blending with white
def lighten_color(color, amount=0.3):
    rgba = mcolors.to_rgba(color)
    return tuple(np.clip(np.array(rgba[:3]) + amount, 0, 1)) + (rgba[3],)

# Create lighter colors
PAC_LIGHT = lighten_color(PAC_COLOR, 0.3)
DP_LIGHT = lighten_color(DP_COLOR, 0.3)

# create legend, use color squares
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
pac_dp_legend_handles = [
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP')
]

# %% [markdown]
# Reproduction of Table 14 (PAC)

# %%
### Reproduction of Table 14 (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 4, figsize=(12, 12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = (i*2)//4
    col = (i*2) % 4
    ax1 = axs[row][col]
    ax2 = axs[row][col+1]

    # Plotting Sample Std of Absolute Scaled Error
    TYPE = 'pac'
    d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
    ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
             #label=query, marker='.')

    ax1.set_yscale('log')

    ax1.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax1.set_xticks(xticks)
    ax1.set_xticklabels(xlabels)

    ax1.set_title(f'{query.capitalize()} Query')
    ax1.set_xlabel('MI')
    ax1.set_ylabel('Sample Std of the Absolute Scaled Error')

    # Plotting Sample Mean of the Relative Error (%)
    d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
    ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)

    ax2.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax2.set_xticks(xticks)
    ax2.set_xticklabels(xlabels)

    ax2.set_title(f'{query.capitalize()} Query')
    ax2.set_xlabel('MI')
    ax2.set_ylabel('Sample Mean of the Relative Error (%)')

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.95, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Reproduction of Table 14 (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/table14_pac.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Reproduction of Table 14 (DP)

# %%
# %%script echo skipping### Reproduction of Table 14 (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     TYPE = 'dp'
#     d = errors_df.loc[TYPE].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#              #label=query, marker='.')
#
#     ax1.set_yscale('log')
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_xlabel('MI')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc[TYPE].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_xlabel('MI')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#
# fig.suptitle("Reproduction of Table 14 (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Reproduction of Table 14 (DP)

# %% [markdown]
# Both on the same axes, aligned

# %%
# %%script echo skipping
# ### Both on the same axes, aligned
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = (i*2)//4
#     col = (i*2) % 4
#     ax1 = axs[row][col]
#     ax2 = axs[row][col+1]
#
#     # Plotting Sample Std of Absolute Scaled Error
#     d = errors_df.loc['pac'].loc[:, f'absolute error {query} var']
#     ax1.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'absolute error {query} var']
#     #print(d)
#     ax1.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax1.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax1.set_xticks(xticks)
#     ax1.set_xticklabels(xlabels)
#
#     ax1.set_title(f'{query.capitalize()} Query')
#     ax1.set_ylabel('Sample Std of the Absolute Scaled Error')
#     ax1.set_xlabel('MI')
#
#     # Plotting Sample Mean of the Relative Error (%)
#     d = errors_df.loc['pac'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=PAC_COLOR)
#
#     d = errors_df.loc['dp'].loc[:, f'relative error {query} mean']
#     ax2.plot(d.index, d, label=query, marker='.', color=DP_COLOR)
#
#     ax2.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax2.set_xticks(xticks)
#     ax2.set_xticklabels(xlabels)
#
#     ax2.set_title(f'{query.capitalize()} Query')
#     ax2.set_ylabel('Sample Mean of the Relative Error (%)')
#     ax2.set_xlabel('MI')
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.legend(handles=pac_dp_legend_handles, loc='upper right', frameon=False)
#
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Reproduction of Table 14 (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/table14_pac_vs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping

# %% [markdown]
# # Additonal Extra Plotting

# %%
### Plotting the actual experiment outputs used (PAC)
# Plotting each query type with their error metrics
fig, axs = plt.subplots(4, 2, figsize=(8,12))
queries = OUTPUT_COLS
#MI_OPTIONS = [1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]

# Loop through each query to create the subplots
for i, query in enumerate(queries):
    # go from top left, to top right, to bottom left, to bottom right
    row = i//2
    col = i%2
    ax = axs[row][col]

    TYPE = 'pac'
    ax.scatter(df['mi'], df[query], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
    
    ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')

    #for mi in MI_OPTIONS:
        #d = df.iloc[:, [0, i]].where(df['mi'] == mi).dropna()
        #ax.scatter(d.iloc[:, 0], d.iloc[:, 1], label=query, marker='.', alpha=0.5, color=PAC_COLOR)
        #ax.boxplot(d.iloc[:, 1], positions=[mi], widths=0.1, showfliers=False)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)

    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Result')

fig.legend(handles=[
    Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
    Line2D([0], [0], color='black', linestyle='--', label='True Result')
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
#fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("Actual outputs of query on subsamples (PAC)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/actual_outputs_pac.jpg", bbox_inches='tight')
plt.show()
# Out:
# Future exception was never retrieved
# future: <Future finished exception=BrokenPipeError(32, 'Broken pipe')>
# Traceback (most recent call last):
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/unix_events.py", line 665, in write
#     n = os.write(self._fileno, data)
# BrokenPipeError: [Errno 32] Broken pipe

# %%
# %%script echo skipping### Plotting the actual experiment outputs used (DP)
# # Plotting each query type with their error metrics
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     TYPE = 'dp'
#
#     ax.scatter(dp_results_df['mi'], dp_results_df[query], label=query, marker='.', alpha=0.5, color=DP_COLOR)
#     ax.axhline(y=true_result[i], color='black', linestyle='--', label='True Result')
#
#     ax.set_xscale('log', base=2)
#     xticks = MI_OPTIONS
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
#     ax.set_xticks(xticks)
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='black', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
#
# fig.suptitle("Actual outputs of query trials (DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Plotting the actual experiment outputs used (DP)

# %%
# %%script echo skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))
# queries = OUTPUT_COLS
# #MI_OPTIONS = [1/256, 1/128, 1/64, 1/32, 1/16, 1/4, 1., 2., 4., 16.]
#
# # Loop through each query to create the subplots
# for i, query in enumerate(queries):
#     # go from top left, to top right, to bottom left, to bottom right
#     row = i//2
#     col = i%2
#     ax = axs[row][col]
#
#     ax.linewidth = 0.25
#
#     # correct answer
#     ax.axhline(y=true_result[i], color='gray', linestyle='--', label='True Result')
#
#     for mi in MI_OPTIONS: # categorical variable
#         position = MI_OPTIONS.index(mi) * 2
#
#         TYPE = 'pac'
#
#         pac_style = {
#             'boxprops': dict(facecolor=PAC_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = df[df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **pac_style)
#
#         position += 1
#         TYPE = 'dp'
#
#         dp_style = {
#             'boxprops': dict(facecolor=DP_LIGHT),
#             'medianprops': dict(color='black')
#         }
#
#         # mi = mi and query is correct
#         d = dp_results_df[dp_results_df['mi'] == mi][query].values
#         ax.boxplot(d, positions=[position], widths=0.6, patch_artist=True, showfliers=False, **dp_style)
#
#
#
#     # override xticks, one for each pair of boxplots
#     # the x axis is actually artificial here to plot both PAC and DP side by side
#     xticks = [0.5+2*i for i in range(len(MI_OPTIONS))]
#     ax.set_xticks(xticks)
#
#     xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in MI_OPTIONS]
#     ax.set_xticklabels(xlabels)
#
#     ax.set_title(f'{query.capitalize()} Query')
#     ax.set_xlabel('MI')
#     ax.set_ylabel('Result')
#
# fig.legend(handles=[
#     Patch(facecolor=PAC_COLOR, edgecolor=PAC_COLOR, label='PAC'),
#     Patch(facecolor=DP_COLOR, edgecolor=DP_COLOR, label='DP'),
#     Line2D([0], [0], color='gray', linestyle='--', label='True Result')
# ], loc='upper right', frameon=False)
#
# # add label in top left corner "sum = count * mean"
# #fig.text(0.75, 0.94, '(sum = count * mean)', ha='center', va='center')
# fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
# fig.suptitle("Actual outputs of query trials (PAC vs DP)")
# plt.tight_layout()
# fig.savefig(f"{OUTPUT_DIR}/actual_outputs_dp_vs_pac.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping### Both, but with side by side fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# %%
df.groupby('mi').var()
# Out:
#             max_revenue
# mi
# 0.001248   2.205117e+09
# 0.015625   1.855212e+08
# 0.031250   8.843014e+07
# 0.062500   5.338779e+07
# 0.250000   1.655799e+07
# 1.000000   7.425675e+06
# 2.000000   6.219106e+06
# 4.000000   6.162986e+06
# 16.000000  5.321163e+06

# %%
# tables
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap

# %%
print("Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)")
saved_steps_df[['mi','scale']].groupby('mi').mean()
# Out:
# Scale of noise added to [Count, Mean] (scale param passed to Normal noise function)
# step              scale
# query       max_revenue
# mi
# 0.001248   2.153761e+09
# 0.015625   1.720691e+08
# 0.031250   8.603457e+07
# 0.062500   4.301728e+07
# 0.250000   1.075432e+07
# 1.000000   2.688580e+06
# 2.000000   1.344290e+06
# 4.000000   6.721450e+05
# 16.000000  1.680363e+05

# %% [markdown]
# Comparison of how much noise is added to the data, by looking at the variance of the distributions from which noise is sampled.

# %%
# %%script echo skipping # Wait until we have DP data to compare
# dp_var_noise = {  # from pipelinedp repo, dp_basic_mean_variances.csv
#     #0.00390625: 0.2784089313555703,
#     #0.0078125: 0.19648087910574175,
#     0.015625: 0.13837628104247293,
#     0.0625: 0.06750340282072995,
#     0.25: 0.03001721300521553,
#     1.0: 0.004282722801885366,
#     2.0: 0.004282722801885366,
#     4.0: 0.004282722801885366,
#     16.0: 0.004282722801885366
# }
# d = dp_var_noise
# fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# plt.plot(d.keys(), d.values(), marker='.', label='DP', color=DP_COLOR)
# plt.xlabel('MI')
# ax.set_xticks(list(d.keys()))
# ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
# plt.suptitle('Noise added by DP to Mean query (scale param passed to Laplace noise function)')
# plt.title('DP')
# plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_dp.jpg", bbox_inches='tight')
# plt.show()
# Out:
# skipping # Wait until we have DP data to compare

# %%
#assert not any(any(saved_steps_df[['mi','scale']].groupby('mi').var().values)) # assume we are only computing scale once per MI
if ('mean' in OUTPUT_COLS):
    pac_var_noise = dict(zip(MI_OPTIONS, saved_steps_df[['mi','scale']].groupby('mi').mean()[[('scale','mean')]].to_numpy().flatten()))
    pac_var_noise

# %%
# Let's compute the same for PAC: what is the scale of the distribution from which noise is sampled to add to PAC?
if ('mean' in OUTPUT_COLS): 
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    d = pac_var_noise
    plt.plot(d.keys(), d.values(), marker='.', label='PAC', color=PAC_COLOR)
    plt.xlabel('MI')
    ax.set_xticks(list(d.keys()))
    ax.set_xticklabels([f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in d.keys()])
    plt.suptitle('Noise added by PAC to Mean query (scale param passed to Normal noise function)')
    plt.title('PAC')
    plt.savefig(f"{OUTPUT_DIR}/noise_distribution_scale_meanquery_pac.jpg", bbox_inches='tight')
    plt.show()

# %%
# How much of PAC error is due to sampling? Compute % error on our samples before noise was added
sample_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()]
sample_errors_df = pd.DataFrame(sample_errors, columns=OUTPUT_COLS)
sample_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Error from Subsampling (as % of true_result, without any noise being added)")
#print("First output: overall mean / Second output: grouped by MI")
display(sample_errors_df[OUTPUT_COLS].mean())
display(sample_errors_df.groupby('mi').mean())
# Out:
# PAC: Error from Subsampling (as % of true_result, without any noise being added)
# max_revenue    1.041075
# dtype: float64
#            max_revenue
# mi
# 0.001248      0.987672
# 0.015625      1.160304
# 0.031250      1.036260
# 0.062500      1.030291
# 0.250000      1.018788
# 1.000000      1.032004
# 2.000000      0.973048
# 4.000000      1.138260
# 16.000000     0.993050

# %%
d=sample_errors_df.groupby('mi').mean()
d.loc['all mi'] = sample_errors_df[OUTPUT_COLS].mean()

fig, ax = plt.subplots(figsize=(5+(0.5*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Error from Subsampling (as % of true_result,\n without any noise being added)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_sample_error.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)")
# abs before mean
saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# Out:
# PAC: How much noise are we adding? (actual noise amounts sampled from the normal distribution, absolute value)
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_42843/2429859456.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})
# step      abs(chosen_noise)
# query           max_revenue
# mi
# 0.001248       37075.436187
# 0.015625       10564.133685
# 0.031250        7238.458548
# 0.062500        5391.721956
# 0.250000        2708.109819
# 1.000000        1264.754507
# 2.000000         931.870422
# 4.000000         652.581499
# 16.000000        334.782162

# %%
d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: How much noise are we adding? (actual noise\n amounts sampled from the normal distribution,\n absolute value)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_chosen_noise.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_42843/211596906.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_noise']].apply(lambda x: np.abs(x)).groupby('mi').mean().rename(columns={'chosen_noise': 'abs(chosen_noise)'})

# %%
print("Avg. value of unnoised sample used by PAC")
display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
display(saved_steps_df[['chosen_sample']].mean().to_frame(name='all mi').T)  # sample shouldn't change with MI, so we can find the overall average
# Out:
# Avg. value of unnoised sample used by PAC
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_42843/883409176.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean())  # average per MI, shouldn't be different
# step      chosen_sample
# query       max_revenue
# mi
# 0.001248   94605.784404
# 0.015625   94440.835454
# 0.031250   94559.359219
# 0.062500   94565.061675
# 0.250000   94576.053565
# 1.000000   94563.425462
# 2.000000   94619.757906
# 4.000000   94461.897818
# 16.000000  94600.646029
# step   chosen_sample
# query    max_revenue
# all mi  94554.757948

# %%
d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()
d.loc['all mi'] = saved_steps_df[['chosen_sample']].mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: (f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}') if type(x) != str else x,
    ),
    *[ColumnDefinition(
        name=c,
        title='\n'.join(c),
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("Avg. value of unnoised sample used by PAC")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_unnoised_samples.jpg", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/g4/jxkqkb_d5170qh291jwd0t_h0000gn/T/ipykernel_42843/3303776140.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   d = saved_steps_df[['mi', 'chosen_sample']].groupby('mi').mean()

# %%
# How much total error is there in PAC? Compute % error on our samples after noise was added
total_errors = [relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]
total_errors_df = pd.DataFrame(total_errors, columns=OUTPUT_COLS)
total_errors_df.insert(0, 'mi', saved_steps_df['mi'].values)  # Insert 'mi' at the beginning
print("PAC: Total Error (as % of true_result)")
total_errors_df.groupby('mi').mean()
# Out:
# PAC: Total Error (as % of true_result)
#            max_revenue
# mi
# 0.001248     38.931977
# 0.015625     11.446886
# 0.031250      7.879656
# 0.062500      6.067540
# 0.250000      3.349206
# 1.000000      2.038841
# 2.000000      1.785166
# 4.000000      1.638473
# 16.000000     1.261447

# %%
d=total_errors_df.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
    column_definitions=col_defs,
    row_dividers=True,
    footer_divider=True,
    ax=ax,
    #textprops={"fontsize": 14},
    #row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    #col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    #column_border_kw={"linewidth": 1, "linestyle": "-"},
    )
plt.title("PAC: Total Error (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_total.jpg", bbox_inches='tight')
plt.show()

# %%
print("PAC: Increase in Avg. % error due to noise being added (as % of true_result)")
delta_error_from_noise = pd.concat(
    [
        saved_steps_df['mi'].reset_index(drop=True),
        pd.DataFrame(
            (np.array([relative_error_percent(s, true_result) for s in saved_steps_df['release'].to_numpy()]) -
             np.array([relative_error_percent(s, true_result) for s in saved_steps_df['chosen_sample'].to_numpy()])),
            columns=OUTPUT_COLS
        )
    ],
    axis=1
)
delta_error_from_noise.groupby('mi').mean()
# Out:
# PAC: Increase in Avg. % error due to noise being added (as % of true_result)
#            max_revenue
# mi
# 0.001248     37.944305
# 0.015625     10.286583
# 0.031250      6.843396
# 0.062500      5.037249
# 0.250000      2.330418
# 1.000000      1.006837
# 2.000000      0.812119
# 4.000000      0.500212
# 16.000000     0.268398

# %%
d=delta_error_from_noise.groupby('mi').mean()

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns]]
tbl = Table(d,
        column_definitions=col_defs,
        row_dividers=True,
        footer_divider=True,
        ax=ax,
        )
plt.title("PAC: Increase in Avg. % error due to noise\nbeing added (as % of true_result)")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_noise.jpg", bbox_inches='tight')
plt.show()

# %%
### Combined % Error Table
d = pd.concat([
    sample_errors_df.groupby('mi').mean(),  # % error from subsampling
    delta_error_from_noise.groupby('mi').mean(),  # % error from noise
    total_errors_df.groupby('mi').mean(),  # % total error
], axis=1)
d.columns = ['Subsampling', 'Added Noise', 'Total Error']

fig, ax = plt.subplots(figsize=(2+(2*len(d.columns)), 3.5))

col_defs = [
    ColumnDefinition(
        name=d.index.name,
        #textprops={"ha": "right"},
        width=0.25,
        formatter=lambda x: f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}',
    ),
    *[ColumnDefinition(
        name=c,
        group="Error Sources",
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    ) for c in d.columns[:-1]],
    ColumnDefinition(
        name=d.columns[-1],
        textprops={"ha": "right"},
        width=0.5,
        formatter=lambda x: f"{x:.3f}%",
    )]
tbl = Table(d,
            column_definitions=col_defs,
            row_dividers=True,
            footer_divider=True,
            ax=ax,
        )
#plt.title("PAC: Error Breakdown")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/tbl-pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 12))

psample_errors = sample_errors_df.groupby('mi').mean()
pnoise_errors = delta_error_from_noise.groupby('mi').mean()

for i, query in enumerate(OUTPUT_COLS):
    row = i//2
    col = i%2
    ax = axs[row][col]

    ax.stackplot(psample_errors.index, psample_errors[query], pnoise_errors[query], 
        labels=['Sample Error', 'Noise Error'], colors=['orange', 'green'], alpha=0.6)
    
    ax.set_xscale('log', base=2)
    xticks = MI_OPTIONS
    xlabels = [f'$\\frac{{1}}{{{int(1/x)}}}$' if x < 1 else f'{int(x)}' for x in xticks]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels)


    ax.set_title(f'{query.capitalize()} Query')
    ax.set_xlabel('MI')
    ax.set_ylabel('Error (%)')

fig.legend(handles=[
    Patch(facecolor='orange', edgecolor='orange', label='Noise from Sampling'),
    Patch(facecolor='green', edgecolor='green', label='Added Noise'),
], loc='upper right', frameon=False)

# add label in top left corner "sum = count * mean"
fig.text(0.05, 0.97, f'({number_of_contributing_rows} rows)', ha='center', va='center')
fig.suptitle("PAC: Stacked Area Plot of Sources of Error")
plt.tight_layout()
fig.savefig(f"{OUTPUT_DIR}/pac_error_breakdown.jpg", bbox_inches='tight')
plt.show()

# %%
# relative_error_percent(38854, 3765)
